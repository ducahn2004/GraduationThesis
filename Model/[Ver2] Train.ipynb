# %%
import numpy as np
import pandas as pd
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import numpy as np
from torch.utils.data import DataLoader, Sampler
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision.utils import make_grid

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
sys.path.append(str(DATASET_PATH))

# %% [markdown]
# # Load Data

# %% [markdown]
# ## HeartSoundDataSet

# %%
import numpy as np
import h5py
import random
import torch
from pathlib import Path
import librosa  # cần import để tính delta

EPS = 1e-8

def standard_normal_variate(data):
    """Chuẩn hóa Z-score trên toàn bộ tensor."""
    mean = np.mean(data)
    std = np.std(data) + EPS
    return (data - mean) / std

class HeartSoundDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 fea_path: str,              # đường dẫn file .h5
                 labels: pd.DataFrame,       # DataFrame với cột 'filename' và 'label'
                 duration: int = 5,          # giây
                 training: bool = True,
                 delta: bool = False,
                 norm: bool = True):
        self._fea_path = fea_path
        self._h5database = None
        self._labels = labels.reset_index(drop=True)
        self._colname = ['filename', 'label']
        self._len = len(self._labels)
        self._duration = duration
        self._delta = delta
        self.train = training
        self.hop_length = 15  # ms
        self.norm = norm

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
      row = self._labels.iloc[idx]
      filename = row['filename']
      target_bin = row['label']

      # Lấy key từ stem của filename
      key = Path(filename).stem if '/' in str(filename) else filename

      # Mở HDF5 nếu chưa mở
      if self._h5database is None:
          self._h5database = h5py.File(self._fea_path, 'r')

      if key not in self._h5database:
          available = list(self._h5database.keys())[:10]
          raise KeyError(f"Key '{key}' not found in HDF5. Sample keys: {available}")

      # Load feature từ HDF5
      feature = self._h5database[key][()]  # (mel_bins, T) hoặc (C, mel_bins, T)

      # Đảm bảo feature là 3D: (C, H, W)
      if feature.ndim == 2:
          feature = feature[np.newaxis, :, :]  # → (1, mel_bins, T)
      elif feature.ndim != 3:
          raise ValueError(f"Unexpected shape {feature.shape} for key '{key}'")

      # Chuẩn hóa toàn bộ tensor (nếu bật)
      if self.norm:
          feature = standard_normal_variate(feature)

      # Thêm delta features (nếu bật)
      if self._delta:
          orig = feature[0]  # (mel_bins, T)
          delta = librosa.feature.delta(orig)
          delta2 = librosa.feature.delta(delta)
          feature = np.stack([orig, delta, delta2], axis=0)  # → (3, mel_bins, T)

      # Lấy shape hiện tại
      channels, mel_bins, num_frames = feature.shape

      # Tính độ dài mong muốn (frames)
      cycle_len = int(self._duration * 1000 / self.hop_length)

      # Crop hoặc pad để đạt đúng cycle_len
      if num_frames >= cycle_len:
          if self.train:
              start_ind = random.randint(0, num_frames - cycle_len)
          else:
              start_ind = (num_frames - cycle_len) // 2
          feature = feature[:, :, start_ind:start_ind + cycle_len]
      elif num_frames < cycle_len:
          pad_width = ((0, 0), (0, 0), (0, cycle_len - num_frames))
          feature = np.pad(feature, pad_width, mode='wrap')

      # === Fix quan trọng cho model gốc: Làm cho tensor luôn là 3D (mel_bins, num_frames) ===
      feature_tensor = torch.from_numpy(feature).float()  # (C, mel_bins, T)

      if channels > 1:  # Có delta → C=3
          # Ghép 3 channels vào chiều mel_bins → (3 * mel_bins, T) = (384, T)
          # Model sẽ view thành (B, 3, 128, T) trong forward
          feature_tensor = feature_tensor.view(channels * mel_bins, -1)  # → (384, T)
      else:
          # Không delta → squeeze về (mel_bins, T) = (128, T)
          feature_tensor = feature_tensor.squeeze(0)

      return feature_tensor, torch.tensor(target_bin, dtype=torch.long)

    def __del__(self):
        """Đóng file HDF5 khi object bị hủy (tốt cho quản lý tài nguyên)."""
        if self._h5database is not None:
            self._h5database.close()

# %% [markdown]
# ## MinimumOccupancySampler

# %%
class MinimumOccupancySampler(Sampler):
    """
        samples at least one instance from each class sequentially
    """
    def __init__(self, labels, sampling_mode='over', random_state=None):
        data_samples = labels.shape
        n_labels = len(np.unique(labels))
        label_to_idx_list, label_to_length = [], []
        self.random_state = np.random.RandomState(seed=random_state)
        for lb_idx in range(n_labels):
            label_indexes = np.where(labels == lb_idx)[0]
            self.random_state.shuffle(label_indexes)
            label_to_length.append(len(label_indexes))
            label_to_idx_list.append(label_indexes)

        self.longest_seq = max(label_to_length)
        self.data_source = np.empty((self.longest_seq, len(label_to_length)), dtype=int)
        # Each column represents one "single instance per class" data piece
        for ix, leng in enumerate(label_to_length):
            self.data_source[:leng, ix] = label_to_idx_list[ix]
        self.label_to_length = label_to_length
        self.label_to_idx_list = label_to_idx_list

        if sampling_mode == 'same':
            self.data_length = data_samples
        elif sampling_mode == 'over':  # Sample all items
            self.data_length = np.prod(self.data_source.shape)

    def _resample(self):
        for ix, leng in enumerate(self.label_to_length):
            leftover = self.longest_seq - leng
            random_idxs = np.random.randint(leng, size=leftover)
            self.data_source[leng:, ix] = self.label_to_idx_list[ix][random_idxs]

    def __iter__(self):
        self._resample()
        n_samples = len(self.data_source)
        random_indices = self.random_state.permutation(n_samples)
        data = np.concatenate(
            self.data_source[random_indices])[:self.data_length]
        return iter(data)

    def __len__(self):
        return self.data_length

# %% [markdown]
# ## HeartSoundDataLoader

# %%
class BaseDataLoader(DataLoader):
    """
    Base class for all data loaders
    """
    def __init__(self, dataset, batch_size, shuffle, validation_split, num_workers, collate_fn=default_collate, sampler_type=None):
        self.validation_split = validation_split
        self.shuffle = shuffle

        self.batch_idx = 0
        self.n_samples = len(dataset)
        self.sampler_type = sampler_type
        self.sampler, self.valid_sampler = self._split_sampler(self.validation_split)
        self.init_kwargs = {
            'dataset': dataset,
            'batch_size': batch_size,
            'shuffle': self.shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.sampler, **self.init_kwargs)

    def _split_sampler(self, split):
        if split == 0.0:
            return None, None

        idx_full = np.arange(self.n_samples)

        np.random.seed(0)
        np.random.shuffle(idx_full)

        if isinstance(split, int):
            assert split > 0
            assert split < self.n_samples, "validation set size is configured to be larger than entire dataset."
            len_valid = split
        else:
            len_valid = int(self.n_samples * split)

        valid_idx = idx_full[0:len_valid]
        train_idx = np.delete(idx_full, np.arange(0, len_valid))
        if self.sampler_type == 'MinimumOccupancySampler':
            train_sampler = MinimumOccupancySampler(np.stack(self.label_df.iloc[train_idx]['label']), random_state=100)
        else:
            train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        # turn off shuffle option which is mutually exclusive with sampler
        self.shuffle = False
        self.n_samples = len(train_idx)

        return train_sampler, valid_sampler

    def split_validation(self):
        if self.valid_sampler is None:
            return None
        else:
            return DataLoader(sampler=self.valid_sampler, **self.init_kwargs)

# %%
class HeartSoundDataLoader(DataLoader):
    def __init__(self,
                 fea_path,
                 label_df,
                 duration,
                 batch_size,
                 delta=False,
                 norm = False,
                 shuffle=True,
                 validation_split=0.0,
                 num_workers=1,
                 training=True,
                 collate_fn=None):
        if training:
            self.train_df, self.val_df = train_test_split(label_df, test_size=validation_split, shuffle=True)

            self.train_sampler = MinimumOccupancySampler(np.stack(self.train_df['label']), random_state=100)
            self.val_dataset = HeartSoundDataSet(fea_path, self.val_df, duration=duration, training=False, delta=delta, norm=norm)

        else:
            self.train_df = label_df
            self.train_sampler = None
        self.dataset = HeartSoundDataSet(fea_path, self.train_df, duration=duration,
                                               training=training, delta=delta, norm=norm)
        self.init_kwargs = {
            'batch_size': batch_size,
            'shuffle': shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.train_sampler,
                         dataset = self.dataset,
                         **self.init_kwargs)

    def split_validation(self):
        return DataLoader(dataset= self.val_dataset, **self.init_kwargs)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"logmel_features.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_balanced.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("Log-Mel Spectrogram (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0001_aug0', 'a0001_aug1', 'a0001_aug2', 'a0002', 'a0002_aug0', 'a0002_aug1', 'a0002_aug2', 'a0003', 'a0003_aug0']
# Batch shape: torch.Size([4, 384, 333])
# Targets: [1 1 1 1]
# Value range: -1.281 ~ 2.987

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"logmel_features_validation.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_validation.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("Log-Mel Spectrogram (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0002', 'a0003', 'a0004', 'a0005', 'a0006', 'a0007', 'a0008', 'a0009', 'a0010']
# Batch shape: torch.Size([4, 384, 333])
# Targets: [1 1 1 1]
# Value range: -0.940 ~ 3.444

# %% [markdown]
# # ConfigParser

# %%
# parse_config.py
import os
import logging
from pathlib import Path
from datetime import datetime
import argparse
import collections
import importlib.util

class ConfigParser:
    def __init__(self, config_dict, resume=None, modification=None, run_id=None):
        self._config = config_dict
        self.resume = resume

        # Apply CLI modifications
        if modification:
            for key_path, value in modification.items():
                keys = key_path.split(';')
                d = self._config
                for k in keys[:-1]:
                    d = d[k]
                d[keys[-1]] = value

        # Setup save and log directories
        save_dir = Path(self.config['trainer']['save_dir'])
        exper_name = self.config['name']
        if run_id is None:
            run_id = datetime.now().strftime(r'%m%d_%H%M%S')
        self._save_dir = save_dir / 'models' / exper_name / run_id
        self._log_dir = save_dir / 'log' / exper_name / run_id

        self.save_dir.mkdir(parents=True, exist_ok=True)
        self.log_dir.mkdir(parents=True, exist_ok=True)

        # Optional: setup logging
        # setup_logging(self.log_dir)

    @classmethod
    def from_args(cls, parser, options=None):
        """
        parser: argparse.ArgumentParser đã được add_argument xong
        options: list các CustomArgs để override
        """
        if options is None:
            options = []

        # Parse arguments (an toàn cho cả terminal và notebook)
        args = parser.parse_args()

        # Xử lý device
        if args.device is not None:
            os.environ["CUDA_VISIBLE_DEVICES"] = args.device

        # Xử lý resume
        if args.resume is not None:
            resume = Path(args.resume)
            cfg_fname = resume.parent / 'config.py'  # hoặc .json nếu bạn dùng cả 2
        else:
            resume = None
            assert args.config is not None, "Phải chỉ định -c config.py"
            cfg_fname = Path(args.config)

        # Đọc config từ file .py
        if not cfg_fname.exists():
            raise FileNotFoundError(f"Không tìm thấy config file: {cfg_fname}")

        if cfg_fname.suffix == '.py':
            spec = importlib.util.spec_from_file_location("config_module", cfg_fname)
            config_module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(config_module)
            if not hasattr(config_module, 'config'):
                raise ValueError(f"File {cfg_fname} phải định nghĩa biến 'config'")
            config_dict = config_module.config
        else:
            raise ValueError("Chỉ hỗ trợ file config .py")

        # Parse custom CLI overrides
        CustomArgs = collections.namedtuple('CustomArgs', 'flags type target')
        modification = {}
        for opt in options:
            for flag in opt.flags:
                arg_name = flag.lstrip('-').replace('-', '_')
                if hasattr(args, arg_name) and getattr(args, arg_name) is not None:
                    modification[opt.target] = opt.type(getattr(args, arg_name))

        return cls(config_dict, resume, modification)

    def init_obj(self, name, module, *args, **kwargs):
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def init_ftn(self, name, module, *args, **kwargs):
        from functools import partial
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def __getitem__(self, name):
        return self.config[name]

    def get_logger(self, name, verbosity=2):
        logger = logging.getLogger(name)
        logger.setLevel({0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}[verbosity])
        return logger

    @property
    def config(self):
        return self._config

    @property
    def save_dir(self):
        return self._save_dir

    @property
    def log_dir(self):
        return self._log_dir

# %% [markdown]
# # Logging

# %%
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %% [markdown]
# #Loss

# %%
import torch.nn.functional as F


def nll_loss(output, target):
    return F.nll_loss(output, target)

def ce_loss(output, target):
    return F.cross_entropy(output, target)

# %% [markdown]
# # Metric

# %%
import torch


def accuracy(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
    return correct / len(target)


def top_k_acc(output, target, k=3):
    with torch.no_grad():
        pred = torch.topk(output, k, dim=1)[1]
        assert pred.shape[0] == len(target)
        correct = 0
        for i in range(k):
            correct += torch.sum(pred[:, i] == target).item()
    return correct / len(target)

# %% [markdown]
# # Model

# %%
import torch.nn as nn
import numpy as np
from abc import abstractmethod


class BaseModel(nn.Module):
    """
    Base class for all models
    """
    @abstractmethod
    def forward(self, *inputs):
        """
        Forward pass logic

        :return: Model output
        """
        raise NotImplementedError

    def __str__(self):
        """
        Model prints with number of trainable parameters
        """
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        params = sum([np.prod(p.size()) for p in model_parameters])
        return super().__str__() + '\nTrainable parameters: {}'.format(params)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# functions of initializing layers
def init_layer(layer):
    """Initialize a Linear or Convolutional layer."""
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, 'bias'):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)

def init_bn(bn):
    """Initialize a Batchnorm layer."""
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.)

def init_rnn(rnn):
    """init_rnn
    Initialized RNN weights, independent of type GRU/LSTM/RNN
    :param rnn: the rnn model
    """
    for name, param in rnn.named_parameters():
        if 'bias' in name:
            nn.init.constant_(param, 0.0)
        elif 'weight' in name:
            nn.init.xavier_uniform_(param)

def reset_parameters(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            init_layer(module)
        elif isinstance(module, nn.Linear):
            init_layer(module)
        elif isinstance(module, nn.BatchNorm2d):
            init_bn(module)
        elif isinstance(module, nn.LSTM):
            init_rnn(module)

# %% [markdown]
# ## Simple CNN Block

# %%
class simple_cnn(BaseModel):
    def __init__(self, num_classes = 2, in_channel = 1):
        super(simple_cnn, self).__init__()
        self.in_channel = in_channel

        # -------- Block 1 --------
        #self.conv1 = nn.Conv2d(in_channel,16,3)
        self.conv1 = nn.Conv2d(in_channel, 8, kernel_size=3, padding=1)
        #self.bn1 = nn.BatchNorm2d(16)
        self.bn1 = nn.BatchNorm2d(8)

        # -------- Block 2 --------
        #self.conv2 = nn.Conv2d(16,32,3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(16)


        # -------- Global pooling --------
        self.gap = nn.AdaptiveAvgPool2d(1)

        # -------- Regularization + Classifier --------
        self.dropout = nn.Dropout(p=0.5)
        self.output = nn.Linear(16, num_classes)

        self.init_weights()

    def init_weights(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        #init_layer(self.conv3)
        #init_layer(self.fc)
        init_layer(self.output)
        init_bn(self.bn1)
        init_bn(self.bn2)


    def forward(self, x):
        """
        x: (B, mel_bins, time_frames)
        """
        B, mel_bins, num_frames = x.size()
        x = x.view(B, self.in_channel, mel_bins, num_frames)

        # -------- Block 1 --------
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, kernel_size=2)

        # -------- Block 2 --------
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, kernel_size=2)

        # -------- Global Average Pooling --------
        x = self.gap(x)                 # (B, 16, 1, 1)
        x = x.view(x.size(0), -1)       # (B, 16)

        # -------- Classifier --------
        x = self.dropout(x)
        out = self.output(x)

        return out

# %% [markdown]
# ## Deeper CNN model, VGG like structure

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels = in_channels,
                               out_channels = out_channels,
                               kernel_size = (3,3),
                               stride = (1,1),
                               padding = (1,1),
                               bias =False)

        self.conv2 = nn.Conv2d(in_channels = out_channels,
                               out_channels = out_channels,
                               kernel_size = (3,3),
                               stride = (1,1),
                               padding = (1,1),
                               bias = False)

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.init_weights()

    def init_weights(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        init_bn(self.bn1)
        init_bn(self.bn2)

    def forward(self, input, pool_size=(2, 2), pool_type='max', activation = 'relu'):
        x = input
        x = F.relu_(self.bn1(self.conv1(x)))
        if activation == 'relu':
            x = F.relu_(self.bn2(self.conv2(x)))
        elif activation == 'sigmoid':
            x = torch.sigmoid(self.bn2(self.conv2(x)))

        if pool_type == 'max':
            x = F.max_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg':
            x = F.avg_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg+max':
            x1 = F.avg_pool2d(x, kernel_size=pool_size)
            x2 = F.max_pool2d(x, kernel_size=pool_size)
            x = x1 + x2
        else:
            raise Exception('Incorrect argument!')

        return x

class VGG_11(BaseModel):
    def __init__(self, num_classes, in_channel):
        super(VGG_11, self).__init__()
        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)
        self.conv1 = ConvBlock(in_channels=in_channel, out_channels=64)
        self.conv2 = ConvBlock(in_channels=64, out_channels=128)
        self.conv3 = ConvBlock(in_channels=128, out_channels=256)
        self.conv4 = ConvBlock(in_channels=256, out_channels=512)
        self.fc_final = nn.Linear(512, num_classes)
        self.init_weights()

    def init_weights(self):
        init_bn(self.bn0)
        init_layer(self.fc_final)

    def forward(self, input):
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        # (samples_num, channel, mel_bins, time_stamps)
        x = self.conv1(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)

        output = F.max_pool2d(x, kernel_size=x.shape[2:])
        output = output.view(output.shape[0:2])
        output = F.log_softmax(self.fc_final(output), dim=-1)
        return output


class VGG_13(BaseModel):
    def __init__(self, num_classes, in_channel):
        super(VGG_13, self).__init__()
        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)
        self.conv1 = ConvBlock(in_channels=in_channel, out_channels=64)
        self.conv2 = ConvBlock(in_channels=64, out_channels=128)
        self.conv3 = ConvBlock(in_channels=128, out_channels=256)
        self.conv4 = ConvBlock(in_channels=256, out_channels=512)
        self.conv5 = ConvBlock(in_channels=512, out_channels=512)
        self.fc_1 = nn.Linear(512 * 4* 10, 4096)
        self.fc_2 = nn.Linear(4096, 4096)
        self.fc_final = nn.Linear(4096, num_classes)
        self.init_weights()

    def init_weights(self):
        init_bn(self.bn0)
        init_layer(self.fc_final)
        init_layer(self.fc_1)
        init_layer(self.fc_2)

    def forward(self, input):
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        # (samples_num, channel, time_stemps, mel_bins)
        x = self.conv1(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv5(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        #output = F.max_pool2d(x, kernel_size=x.shape[2:])
        #output = output.view(output.shape[0:2])
        x = x.view(x.shape[0], -1)
        x = F.relu_(self.fc_1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu_(self.fc_2(x))
        x = F.dropout(x, p=0.5, training=self.training)
        output = F.log_softmax(self.fc_final(x),dim=-1)
        #output = F.log_softmax(self.fc_final(output), dim=-1)
        return output

# %% [markdown]
# ## RNN - BiLTSM

# %%
class BiLSTM(BaseModel):
    def __init__(self,
                 input_dim=200,
                 hidden_dim=256,
                 num_layers =2,
                 dropout=0.2,
                 num_classes=2,
                 pooling='first',
                 model='lstm',
                 BN=False):
        super(BiLSTM,self).__init__()
        if model == 'lstm':
            self.LSTM = nn.LSTM(input_size=input_dim,
                                hidden_size =hidden_dim,
                                num_layers =num_layers,
                                batch_first =True,
                                dropout=dropout,
                                bidirectional=True)
        elif model == 'gru':
            self.LSTM = nn.GRU(input_size=input_dim,
                               hidden_size =hidden_dim,
                               num_layers =num_layers,
                               batch_first =True,
                               dropout=dropout,
                               bidirectional=True)
        init_rnn(self.LSTM)
        self.BN = BN
        if self.BN:
            self.BatchNorm=nn.BatchNorm1d(hidden_dim*2)

        self.layer_out = nn.Linear(hidden_dim*2,num_classes,bias=False)
        self.pooling=pooling

    def forward(self,x):
        x = x.transpose(2,1) #[Batchsize x Time_frames x Mel_bin]
        x,_ = self.LSTM(x)
        if self.BN:
            x = self.BatchNorm(x.transpose(1,2))
            x = x.transpose(1,2)
        dim =1
        x = self.layer_out(x)  #200,2
        if self.pooling == 'avg':
            x = x.mean(dim)   #average pooling
        elif self.pooling == 'first':
            x = x.select(dim,0)  #first time step
        elif self.pooling == 'last':
            x = x.select(dim,-1)  #first time step
        elif self.pooling == 'max':
            x = x.max(dim)[0]
        elif  self.pooling == 'linear':
            (x**2).sum(dim) / x.sum(dim)
        elif self.pooling == 'exp':
            (x.exp() * x).sum(dim) / x.exp().sum(dim)

        # print(out.shape)
        # out = self.LogSoftmax(out)#the input given is expected to contain log-probabilities. Obtaining log-probabilities in a neural network is easily achieved by adding a LogSoftmax layer in the last layer of your network.
        return x#,A

# %% [markdown]
# ## CRNN

# %%
class CNN_Encoder(nn.Module):
    def __init__(self, in_channels):
        super(CNN_Encoder, self).__init__()

        self.conv1 = ConvBlock(in_channels=in_channels, out_channels=32)
        self.conv2 = ConvBlock(in_channels=32, out_channels=64)
        self.conv3 = ConvBlock(in_channels=64, out_channels=128)
        self.conv4 = ConvBlock(in_channels=128, out_channels=256)
    def forward(self, input):
        x = input
        x = self.conv1(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)

        return x

class crnn(BaseModel):
    def __init__(self, in_channel,
                 hidden_dim=128,
                 num_layers = 2,
                 dropout = 0.2,
                 pooling = 'first',
                 model='lstm',
                 BN = True,
                 num_classes=2):
        super(crnn,self).__init__()

        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)

        self.cnn = CNN_Encoder(in_channels=in_channel)
        self.bilstm = BiLSTM(input_dim=256,
                             hidden_dim=hidden_dim,
                             num_layers =num_layers,
                             dropout =dropout,
                             num_classes=num_classes,
                             pooling=pooling,
                             model=model,
                             BN=BN)


    def forward(self,input):
        if isinstance(input, (tuple, list)):
          input = input[0]
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        x = self.cnn(x)
        x = F.max_pool2d(x,kernel_size=(x.size(-2), 1)) # pool mel dimension
        x = x.squeeze(-2)  # [B x C x Time_frames]
        output = self.bilstm(x)
        return output

# %% [markdown]
# # Config

# %% [markdown]
# ## CNN

# %%
from pathlib import Path

config_cnn = {
    "name": "Physionet_simple_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "simple_cnn",
        "args": {
            "num_classes": 2,
            "in_channel": 1 #Declare channel
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"logmel_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
        "accuracy"
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved"/"simple_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_MAcc",
        "early_stop": 20,
        "tensorboard": True
    }
}

# %% [markdown]
# ## CRNN

# %%
from pathlib import Path

config_crnn = {
    "name": "Physionet_CRNN",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "crnn",
        "args": {
            "in_channel": 1,
            "hidden_dim": 256,
            "num_layers": 2,
            "dropout": 0.2,
            "pooling": "first",
            "model": "lstm",
            "BN": True,
            "num_classes": 2
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"logmel_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
        "accuracy"
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved" / "CRNN"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_MAcc",
        "early_stop": 20,
        "tensorboard": True
    }
}

# %% [markdown]
# ## LTSM

# %%
from pathlib import Path

config_lstm = {
    "name": "Physionet_LSTM",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "BiLSTM",
        "args": {
            "input_dim": 128,
            "hidden_dim": 256,
            "num_layers": 2,
            "dropout": 0.2,
            "pooling": "first",
            "model": "lstm",
            "BN": True,
            "num_classes": 2
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"logmel_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
        "accuracy"
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved" / "LSTM"),
        "save_period": 1,
        "verbosity": 2,

        "monitor": "max val_MAcc",
        "early_stop": 20,

        "tensorboard": True
    }
}

# %% [markdown]
# ## VGG

# %%
from pathlib import Path

config_vgg = {
    "name": "Physionet_VGG11",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "VGG_11",
        "args": {
            "num_classes": 2,
            "in_channel": 3
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"logmel_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "delta": True,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
        "accuracy"
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 200,
        "save_dir": str(PROJECT_PATH / "saved" / "VGG11"),
        "save_period": 1,
        "verbosity": 2,

        "monitor": "max val_accuracy",
        "early_stop": 20,

        "tensorboard": True
    }
}

# %% [markdown]
# # Training

# %%
def prepare_device(n_gpu_use):
    """
    setup GPU device if available. get gpu device indices which are used for DataParallel
    """
    n_gpu = torch.cuda.device_count()
    if n_gpu_use > 0 and n_gpu == 0:
        print("Warning: There\'s no GPU available on this machine,"
              "training will be performed on CPU.")
        n_gpu_use = 0
    if n_gpu_use > n_gpu:
        print(f"Warning: The number of GPU\'s configured to use is {n_gpu_use}, but only {n_gpu} are "
              "available on this machine.")
        n_gpu_use = n_gpu
    device = torch.device('cuda:0' if n_gpu_use > 0 else 'cpu')
    list_ids = list(range(n_gpu_use))
    return device, list_ids

# %%
class MetricTracker:
    def __init__(self, *keys, writer=None):
        self.writer = writer
        self._data = pd.DataFrame(index=keys, columns=['total', 'counts', 'average'])
        self.reset()

    def reset(self):
        for col in self._data.columns:
            self._data[col].values[:] = 0

    def update(self, key, value, n=1):
        if self.writer is not None:
            self.writer.add_scalar(key, value)
        df = self._data

        df.loc[key, "total"] += value * n
        df.loc[key, "counts"] += n
        df.loc[key, "average"] = df.loc[key, "total"] / df.loc[key, "counts"]


    def avg(self, key):
        return self._data.average[key]

    def result(self):
        return dict(self._data.average)

# %%
def setup_logging(save_dir, log_config='logger/logger_config.json', default_level=logging.INFO):
    """
    Setup logging configuration
    """
    log_config = Path(log_config)
    if log_config.is_file():
        config = read_json(log_config)
        # modify logging paths based on run config
        for _, handler in config['handlers'].items():
            if 'filename' in handler:
                handler['filename'] = str(save_dir / handler['filename'])

        logging.config.dictConfig(config)
    else:
        print("Warning: logging configuration file is not found in {}.".format(log_config))
        logging.basicConfig(level=default_level)
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %%
import torch
from abc import abstractmethod
from numpy import inf

class BaseTrainer:
    """
    Base class for all trainers
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config):
        self.config = config
        self.logger = config.get_logger('trainer', config['trainer']['verbosity'])

        self.model = model
        self.criterion = criterion
        self.metric_ftns = metric_ftns
        self.optimizer = optimizer

        cfg_trainer = config['trainer']
        self.epochs = cfg_trainer['epochs']
        self.save_period = cfg_trainer['save_period']
        self.monitor = cfg_trainer.get('monitor', 'off')

        # configuration to monitor model performance and save best
        if self.monitor == 'off':
            self.mnt_mode = 'off'
            self.mnt_best = 0
        else:
            self.mnt_mode, self.mnt_metric = self.monitor.split()
            assert self.mnt_mode in ['min', 'max']

            self.mnt_best = inf if self.mnt_mode == 'min' else -inf
            self.early_stop = cfg_trainer.get('early_stop', inf)
            if self.early_stop <= 0:
                self.early_stop = inf

        self.start_epoch = 1

        self.checkpoint_dir = config.save_dir

        self.history = {
            "epoch": [],
            "train_loss": [],
            "train_accuracy": [],
            "val_loss": [],
            "val_accuracy": [],
            "val_f1": []
        }

        self.history_path = Path(self.checkpoint_dir) / "metrics.csv"

        # setup visualization writer instance
        self.writer = TensorboardWriter(config.log_dir, self.logger, cfg_trainer['tensorboard'])

        if config.resume is not None:
            self._resume_checkpoint(config.resume)

    @abstractmethod
    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Current epoch number
        """
        raise NotImplementedError

    def train(self):
        """
        Full training logic
        """
        not_improved_count = 0
        for epoch in range(self.start_epoch, self.epochs + 1):
            result = self._train_epoch(epoch)

            # save logged informations into log dict
            log = {'epoch': epoch}
            log.update(result)

            # ===== GHI METRICS SAU MỖI EPOCH =====
            self.history["epoch"].append(epoch)
            self.history["train_loss"].append(log.get("loss"))
            self.history["train_accuracy"].append(log.get("accuracy"))
            self.history["val_loss"].append(log.get("val_loss"))
            self.history["val_accuracy"].append(log.get("val_accuracy"))
            self.history["val_f1"].append(log.get("val_F1_score"))

            pd.DataFrame(self.history).to_csv(self.history_path, index=False)

            # print logged informations to the screen
            for key, value in log.items():
                self.logger.info('    {:15s}: {}'.format(str(key), value))

            # evaluate model performance according to configured metric, save best checkpoint as model_best
            best = False
            if self.mnt_mode != 'off':
                try:
                    # check whether model performance improved or not, according to specified metric(mnt_metric)
                    improved = (self.mnt_mode == 'min' and log[self.mnt_metric] <= self.mnt_best) or \
                               (self.mnt_mode == 'max' and log[self.mnt_metric] >= self.mnt_best)
                except KeyError:
                    self.logger.warning("Warning: Metric '{}' is not found. "
                                        "Model performance monitoring is disabled.".format(self.mnt_metric))
                    self.mnt_mode = 'off'
                    improved = False

                if improved:
                    self.mnt_best = log[self.mnt_metric]
                    not_improved_count = 0
                    best = True
                else:
                    not_improved_count += 1

                if not_improved_count > self.early_stop:
                    self.logger.info("Validation performance didn\'t improve for {} epochs. "
                                     "Training stops.".format(self.early_stop))
                    break

            if best:
                self._save_best_model(epoch)

    def _save_checkpoint(self, epoch, save_best=False):
        """
        Saving checkpoints

        :param epoch: current epoch number
        :param log: logging information of the epoch
        :param save_best: if True, rename the saved checkpoint to 'model_best.pth'
        """
        arch = type(self.model).__name__
        state = {
            'arch': arch,
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'monitor_best': self.mnt_best,
            'config': self.config
        }
        filename = str(self.checkpoint_dir / 'checkpoint-epoch{}.pth'.format(epoch))
        torch.save(state, filename)
        self.logger.info("Saving checkpoint: {} ...".format(filename))
        if save_best:
            best_path = str(self.checkpoint_dir / 'model_best.pth')
            torch.save(state, best_path)
            self.logger.info("Saving current best: model_best.pth ...")

    def _resume_checkpoint(self, resume_path):
        """
        Resume from saved checkpoints

        :param resume_path: Checkpoint path to be resumed
        """
        resume_path = str(resume_path)
        self.logger.info("Loading checkpoint: {} ...".format(resume_path))
        checkpoint = torch.load(resume_path)
        self.start_epoch = checkpoint['epoch'] + 1
        self.mnt_best = checkpoint['monitor_best']

        # load architecture params from checkpoint.
        if checkpoint['config']['arch'] != self.config['arch']:
            self.logger.warning("Warning: Architecture configuration given in config file is different from that of "
                                "checkpoint. This may yield an exception while state_dict is being loaded.")
        self.model.load_state_dict(checkpoint['state_dict'])

        # load optimizer state from checkpoint only when optimizer type is not changed.
        if checkpoint['config']['optimizer']['type'] != self.config['optimizer']['type']:
            self.logger.warning("Warning: Optimizer type given in config file is different from that of checkpoint. "
                                "Optimizer parameters not being resumed.")
        else:
            self.optimizer.load_state_dict(checkpoint['optimizer'])

        self.logger.info("Checkpoint loaded. Resume training from epoch {}".format(self.start_epoch))

    def _save_best_model(self, epoch):
      """
      Save only the best model according to monitoring metric
      """
      arch = type(self.model).__name__
      state = {
          'arch': arch,
          'epoch': epoch,
          'state_dict': self.model.state_dict(),
          'optimizer': self.optimizer.state_dict(),
          'monitor_best': self.mnt_best,
          'config': self.config
      }

      best_path = self.checkpoint_dir / 'model_best.pth'
      torch.save(state, best_path)

      self.logger.info(
          f"Saving new best model at epoch {epoch}: model_best.pth"
      )

# %%
from itertools import repeat

def inf_loop(data_loader):
    ''' wrapper function for endless data loader. '''
    for loader in repeat(data_loader):
        yield from loader

# %%
class Trainer(BaseTrainer):
    """
    Trainer class
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config, device,
                 data_loader, valid_data_loader=None, lr_scheduler=None, len_epoch=None):
        super().__init__(model, criterion, metric_ftns, optimizer, config)
        self.config = config
        self.device = device
        self.data_loader = data_loader
        if len_epoch is None:
            # epoch-based training
            self.len_epoch = len(self.data_loader)
        else:
            # iteration-based training
            self.data_loader = inf_loop(data_loader)
            self.len_epoch = len_epoch
        self.valid_data_loader = valid_data_loader
        self.do_validation = self.valid_data_loader is not None
        self.lr_scheduler = lr_scheduler
        self.log_step = int(np.sqrt(data_loader.batch_size))

        self.train_metrics = MetricTracker('loss', *[m.__name__ for m in self.metric_ftns], writer=self.writer)
        self.valid_metrics = MetricTracker('loss',*[m.__name__ for m in self.metric_ftns],
                                           'sensitivity', 'specificity', 'MAcc', 'F1_score',
                                           writer = self.writer)


    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains average loss and metric in this epoch.
        """
        self.model.train()
        self.train_metrics.reset()
        for batch_idx, (data, target) in enumerate(self.data_loader):
            data, target = data.to(self.device), target.to(self.device)

            self.optimizer.zero_grad()
            output = self.model(data.float())
            loss = self.criterion(output, target)
            loss.backward()
            self.optimizer.step()

            self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
            self.train_metrics.update('loss', loss.item())
            for met in self.metric_ftns:
                self.train_metrics.update(met.__name__, met(output, target))

            if batch_idx % self.log_step == 0:
                self.logger.debug('Train Epoch: {} {} Loss: {:.6f}'.format(
                    epoch,
                    self._progress(batch_idx),
                    loss.item()))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

            if batch_idx == self.len_epoch:
                break
        log = self.train_metrics.result()

        if self.do_validation:
            val_log = self._valid_epoch(epoch)
            log.update(**{'val_'+k : v for k, v in val_log.items()})

        if self.lr_scheduler is not None:
            self.lr_scheduler.step()
        return log

    def _valid_epoch(self, epoch):
        """
        Validate after training an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains information about validation
        """
        self.model.eval()
        self.valid_metrics.reset()
        val_pred_pos = 0
        val_pred_neg = 0
        val_condition_pos = 0
        val_condition_neg = 0
        val_TP = 0
        val_TN = 0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(self.valid_data_loader):
                data, target = data.to(self.device), target.to(self.device)
                output = self.model(data.float())
                loss = self.criterion(output, target)

                _,indices = torch.max(output, 1)

                pred_pos_idx = [i for i, x in enumerate(indices) if x == 0]
                condition_pos_idx = [i for i, x in enumerate(target) if x == 0]
                pred_neg_idx = [i for i, x in enumerate(indices) if x == 1]
                condition_neg_idx = [i for i, x in enumerate(target) if x == 1]

                val_pred_pos += len(pred_pos_idx)
                val_condition_pos += len(condition_pos_idx)
                val_pred_neg += len(pred_neg_idx)
                val_condition_neg += len(condition_neg_idx)
                val_TP += len([x for x in pred_pos_idx if x in condition_pos_idx])
                val_TN += len([x for x in pred_neg_idx if x in condition_neg_idx])
                correct = (indices == target).float()
                val_correct += torch.sum(correct).item()
                val_total += target.shape[0]

                self.writer.set_step((epoch - 1) * len(self.valid_data_loader) + batch_idx, 'valid')
                self.valid_metrics.update('loss', loss.item())
                for met in self.metric_ftns:
                    self.valid_metrics.update(met.__name__, met(output, target))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

        sensitivity = val_TP / val_condition_pos
        specificity = val_TN / val_condition_neg
        MAcc= (sensitivity + specificity) / 2
        if val_pred_pos == 0:
            precision = 0
            F1_score = 0
        else:
            precision = val_TP / val_pred_pos
            F1_score = 2 * (precision*sensitivity)/(precision+sensitivity)

        self.valid_metrics.update('sensitivity', sensitivity)
        self.valid_metrics.update('specificity', specificity)
        self.valid_metrics.update('MAcc',MAcc)
        self.valid_metrics.update('F1_score', F1_score)

        # add histogram of model parameters to the tensorboard
        for name, p in self.model.named_parameters():
            self.writer.add_histogram(name, p, bins='auto')
        return self.valid_metrics.result()

    def _progress(self, batch_idx):
        base = '[{}/{} ({:.0f}%)]'
        if hasattr(self.data_loader, 'n_samples'):
            current = batch_idx * self.data_loader.batch_size
            total = self.data_loader.n_samples
        else:
            current = batch_idx
            total = self.len_epoch
        return base.format(current, total, 100.0 * current / total)

# %% [markdown]
# ## Simple Train

# %%
current_config = config_cnn
#current_config = config_crnn
#current_config = config_lstm
#current_config = config_vgg

# %%
import os
import argparse
import collections
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

def main(config):

# Tạo ConfigParser từ biến config hiện tại
  config_parser = ConfigParser(config)

  # Train chính thức
  data_loader = config_parser.init_obj('data_loader', globals())  # hoặc import module phù hợp
  valid_data_loader = data_loader.split_validation()

  model = config_parser.init_obj('arch', globals())
  print(model)

  device, device_ids = prepare_device(config_parser['n_gpu'])
  model = model.to(device)
  if len(device_ids) > 1:
      model = torch.nn.DataParallel(model, device_ids=device_ids)

  criterion = ce_loss  # hoặc getattr(...)
  metrics = [accuracy]

  optimizer = config_parser.init_obj('optimizer', torch.optim, filter(lambda p: p.requires_grad, model.parameters()))
  lr_scheduler = config_parser.init_obj('lr_scheduler', torch.optim.lr_scheduler, optimizer)

  trainer = Trainer(
      model=model,
      criterion=criterion,
      metric_ftns=metrics,
      optimizer=optimizer,
      config=config_parser,
      device=device,
      data_loader=data_loader,
      valid_data_loader=valid_data_loader,
      lr_scheduler=lr_scheduler
  )

  trainer.train()

  base_dir = (Path(config_parser['trainer']['save_dir'])/ "models"/ config_parser['name'])

  if not base_dir.exists():
    print("Models directory was not found.")
    return

  # Lấy run (timestamp) mới nhất
  latest_run = max(base_dir.iterdir(), key=os.path.getmtime)

  best_model_path = latest_run / "model_best.pth"

  if best_model_path.exists():
    print("\n=== HOÀN THÀNH TRAINING ===")
    print("Model tốt nhất được lưu tại:")
    print(best_model_path)
  else:
    print("The file 'model_best.pth' was not found.")

  metrics_path = Path(config_parser.save_dir) / "metrics.csv"

  if metrics_path.exists():
    df = pd.read_csv(metrics_path)
    epochs = df["epoch"]
  else:
    print("The file 'metrics.csv' was not found. Unable to display training results.")

  # ===== LOSS =====
  plt.figure(figsize=(6,4))
  #plt.plot(epochs, df["train_loss"], label="Training Loss", marker="o")
  #plt.plot(epochs, df["val_loss"], label="Validation Loss", marker="s")
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training and Validation Loss")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "loss_curve.png", dpi=300)
  plt.close()

  # ===== ACCURACY =====
  plt.figure(figsize=(6,4))
  #plt.plot(epochs, df["train_accuracy"], label="Training Accuracy", marker="o")
  #plt.plot(epochs, df["val_accuracy"], label="Validation Accuracy", marker="s")
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training and Validation Accuracy")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "accuracy_curve.png", dpi=300)
  plt.close()

  # ===== F1-SCORE =====
  plt.figure(figsize=(6,4))
  #plt.plot(epochs, df["val_f1"], label="Validation F1-score", marker="^")
  plt.plot(epochs, df["val_f1"], label="Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.title("Validation F1-score across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "f1_curve.png", dpi=300)
  plt.close()

  print("\nĐã lưu biểu đồ: loss_curve.png, accuracy_curve.png, f1_curve.png")

  for name in ["loss_curve.png", "accuracy_curve.png", "f1_curve.png"]:
    img_path = latest_run / name

    if not img_path.exists():
        print(f"Not Found {img_path}")
        continue

    img = Image.open(img_path)
    plt.figure(figsize=(6, 4))
    plt.imshow(img)
    plt.axis("off")
    plt.title(name.replace("_", " ").replace(".png", ""))
    plt.show()

# %% [markdown]
# # Test

# %%
from sklearn.metrics import f1_score, confusion_matrix
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import pandas as pd

def test_model(config, best_model_path, validation_fea_path, validation_label_csv):
    config_parser = ConfigParser(config)
    device, _ = prepare_device(config_parser['n_gpu'])

    # Khởi tạo model từ config (đảm bảo architecture đúng)
    model = config_parser.init_obj('arch', globals())
    model = model.to(device)

    # === LOAD CHỈ STATE_DICT - AN TOÀN, KHÔNG CẦN WHITELIST ===
    try:
        # Cách 1: Dùng weights_only=True (mặc định từ PT 2.6), chỉ load weights
        checkpoint = torch.load(best_model_path, map_location=device, weights_only=True)
        model.load_state_dict(checkpoint)  # checkpoint ở đây chỉ là state_dict
        print("Loaded model weights with weights_only=True (safe mode)")
    except Exception as e1:
        print(f"weights_only=True failed: {e1}")
        try:
            # Cách 2: Tắt weights_only (chỉ dùng nếu bạn tin tưởng file)
            checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
            model.load_state_dict(checkpoint['state_dict'])
            print("Loaded with weights_only=False (full checkpoint)")
        except Exception as e2:
            print(f"Cả hai cách đều thất bại: {e2}")
            return

    model.eval()

    print("\n=== MODEL ARCHITECTURE ===")
    print(model)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\nSố tham số huấn luyện được: {trainable_params:,}")

    # === Xác định input shape từ config ===
    delta = config['data_loader']['args'].get('delta', False)
    height = 384 if delta else 128
    channels = 3 if delta else 1
    time_frames = 333

    # === Kiểm tra forward với input giả ===
    print("\n=== KIỂM TRA FORWARD PASS ===")
    try:
        with torch.no_grad():
            dummy_input = torch.randn(2, channels * height, time_frames).to(device)
            output = model(dummy_input)
            print(f"Input shape: (B, {channels * height}, {time_frames})")
            print(f"Output shape: {output.shape} → OK")
    except Exception as e:
        print(f"Forward lỗi: {e}")

    # === Load validation data ===
    if not Path(validation_label_csv).exists() or not Path(validation_fea_path).exists():
        print("Không tìm thấy file validation → bỏ qua đánh giá")
        return

    validation_label_df = pd.read_csv(validation_label_csv)
    validation_label_df['filename'] = validation_label_df['filename'].apply(lambda x: Path(x).stem)

    validation_dataset = HeartSoundDataSet(
        fea_path=validation_fea_path,
        labels=validation_label_df,
        duration=config['data_loader']['args']['duration'],
        training=False,
        delta=delta,
        norm=config['data_loader']['args'].get('norm', True)
    )

    print("\n=== DEBUG: SAMPLE FEATURES ===")
    for i in range(min(5, len(validation_dataset))):
        fea, lab = validation_dataset[i]
        print(f"Sample {i}: shape = {fea.shape}, label = {lab.item()}")

    # Tắt pin_memory trên CPU
    pin_memory = (device.type == 'cuda')

    validation_dataloader = DataLoader(
        validation_dataset,
        batch_size=config['data_loader']['args']['batch_size'],
        shuffle=False,
        num_workers=config['data_loader']['args'].get('num_workers', 2),
        pin_memory=pin_memory
    )

    criterion = ce_loss

    print("\n=== ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===")
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    val_TP = val_TN = val_pred_pos = val_condition_pos = 0

    with torch.no_grad():
        for data, target in validation_dataloader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            total_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, 1)
            total_correct += (pred == target).sum().item()
            total_samples += target.size(0)

            pred_pos_idx = (pred == 0)      # class 0 = abnormal (positive)
            condition_pos_idx = (target == 0)

            val_TP += (pred_pos_idx & condition_pos_idx).sum().item()
            val_TN += ((pred == 1) & (target == 1)).sum().item()
            val_pred_pos += pred_pos_idx.sum().item()
            val_condition_pos += condition_pos_idx.sum().item()

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    sensitivity = val_TP / val_condition_pos if val_condition_pos > 0 else 0
    specificity = val_TN / (total_samples - val_condition_pos) if (total_samples - val_condition_pos) > 0 else 0
    MAcc = (sensitivity + specificity) / 2
    precision = val_TP / val_pred_pos if val_pred_pos > 0 else 0
    F1_score = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0

    val_log = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'MAcc': MAcc,
        'F1_score': F1_score
    }

    print("\nKết quả đánh giá:")
    for k, v in val_log.items():
        print(f"    {k}: {v:.4f}")

    metrics_path = Path(best_model_path).parent / "test_on_validation_set_metrics.csv"
    pd.DataFrame([val_log]).to_csv(metrics_path, index=False)
    print(f"\nĐã lưu kết quả tại: {metrics_path}")

# %%
if __name__ == "__main__":
    # Train model với config hiện tại
    main(current_config)

    # Sau khi train xong, tự động test trên tập validation riêng (nếu có file)
    base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
# Out:
# simple_cnn(
#   (conv1): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (output): Linear(in_features=16, out_features=2, bias=True)
# )
# Trainable parameters: 1330
# DEBUG:trainer:Train Epoch: 1 [0/152 (0%)] Loss: 0.955609
# DEBUG:trainer:Train Epoch: 1 [5/152 (3%)] Loss: 1.198905
# DEBUG:trainer:Train Epoch: 1 [10/152 (7%)] Loss: 0.759594
# DEBUG:trainer:Train Epoch: 1 [15/152 (10%)] Loss: 0.591641
# DEBUG:trainer:Train Epoch: 1 [20/152 (13%)] Loss: 1.212394
# DEBUG:trainer:Train Epoch: 1 [25/152 (16%)] Loss: 0.867444
# DEBUG:trainer:Train Epoch: 1 [30/152 (20%)] Loss: 0.683814
# DEBUG:trainer:Train Epoch: 1 [35/152 (23%)] Loss: 0.752973
# DEBUG:trainer:Train Epoch: 1 [40/152 (26%)] Loss: 0.782485
# DEBUG:trainer:Train Epoch: 1 [45/152 (30%)] Loss: 0.917394
# DEBUG:trainer:Train Epoch: 1 [50/152 (33%)] Loss: 0.819089
# DEBUG:trainer:Train Epoch: 1 [55/152 (36%)] Loss: 0.768815
# DEBUG:trainer:Train Epoch: 1 [60/152 (39%)] Loss: 0.623099
# DEBUG:trainer:Train Epoch: 1 [65/152 (43%)] Loss: 0.863969
# DEBUG:trainer:Train Epoch: 1 [70/152 (46%)] Loss: 0.835296
# DEBUG:trainer:Train Epoch: 1 [75/152 (49%)] Loss: 0.745198
# DEBUG:trainer:Train Epoch: 1 [80/152 (53%)] Loss: 0.759331
# DEBUG:trainer:Train Epoch: 1 [85/152 (56%)] Loss: 0.802673
# DEBUG:trainer:Train Epoch: 1 [90/152 (59%)] Loss: 0.879658
# DEBUG:trainer:Train Epoch: 1 [95/152 (62%)] Loss: 0.713641
# DEBUG:trainer:Train Epoch: 1 [100/152 (66%)] Loss: 0.724462
# DEBUG:trainer:Train Epoch: 1 [105/152 (69%)] Loss: 0.673910
# DEBUG:trainer:Train Epoch: 1 [110/152 (72%)] Loss: 0.581060
# DEBUG:trainer:Train Epoch: 1 [115/152 (76%)] Loss: 0.628652
# DEBUG:trainer:Train Epoch: 1 [120/152 (79%)] Loss: 0.738067
# DEBUG:trainer:Train Epoch: 1 [125/152 (82%)] Loss: 0.630960
# DEBUG:trainer:Train Epoch: 1 [130/152 (86%)] Loss: 0.796187
# DEBUG:trainer:Train Epoch: 1 [135/152 (89%)] Loss: 0.720735
# DEBUG:trainer:Train Epoch: 1 [140/152 (92%)] Loss: 0.607550
# DEBUG:trainer:Train Epoch: 1 [145/152 (95%)] Loss: 0.671605
# DEBUG:trainer:Train Epoch: 1 [150/152 (99%)] Loss: 0.579705
# INFO:trainer:    epoch          : 1
# INFO:trainer:    loss           : 0.7688924721197078
# INFO:trainer:    accuracy       : 0.5686677631578947
# INFO:trainer:    val_loss       : 0.5434483219595516
# INFO:trainer:    val_accuracy   : 0.7493872549019608
# INFO:trainer:    val_sensitivity: 0.9166666666666666
# INFO:trainer:    val_specificity: 0.538135593220339
# INFO:trainer:    val_MAcc       : 0.7274011299435028
# INFO:trainer:    val_F1_score   : 0.7987897125567323
# INFO:trainer:Saving new best model at epoch 1: model_best.pth
# DEBUG:trainer:Train Epoch: 2 [0/152 (0%)] Loss: 0.689657
# DEBUG:trainer:Train Epoch: 2 [5/152 (3%)] Loss: 0.673741
# DEBUG:trainer:Train Epoch: 2 [10/152 (7%)] Loss: 1.049728
# DEBUG:trainer:Train Epoch: 2 [15/152 (10%)] Loss: 0.656810
# DEBUG:trainer:Train Epoch: 2 [20/152 (13%)] Loss: 0.713908
# DEBUG:trainer:Train Epoch: 2 [25/152 (16%)] Loss: 0.657021
# DEBUG:trainer:Train Epoch: 2 [30/152 (20%)] Loss: 0.680297
# DEBUG:trainer:Train Epoch: 2 [35/152 (23%)] Loss: 0.586834
# DEBUG:trainer:Train Epoch: 2 [40/152 (26%)] Loss: 0.580063
# DEBUG:trainer:Train Epoch: 2 [45/152 (30%)] Loss: 0.674431
# DEBUG:trainer:Train Epoch: 2 [50/152 (33%)] Loss: 0.846065
# DEBUG:trainer:Train Epoch: 2 [55/152 (36%)] Loss: 0.473559
# DEBUG:trainer:Train Epoch: 2 [60/152 (39%)] Loss: 0.467152
# DEBUG:trainer:Train Epoch: 2 [65/152 (43%)] Loss: 0.529333
# DEBUG:trainer:Train Epoch: 2 [70/152 (46%)] Loss: 0.746081
# DEBUG:trainer:Train Epoch: 2 [75/152 (49%)] Loss: 0.539785
# DEBUG:trainer:Train Epoch: 2 [80/152 (53%)] Loss: 0.718309
# DEBUG:trainer:Train Epoch: 2 [85/152 (56%)] Loss: 0.734672
# DEBUG:trainer:Train Epoch: 2 [90/152 (59%)] Loss: 0.648880
# DEBUG:trainer:Train Epoch: 2 [95/152 (62%)] Loss: 0.872526
# DEBUG:trainer:Train Epoch: 2 [100/152 (66%)] Loss: 0.855449
# DEBUG:trainer:Train Epoch: 2 [105/152 (69%)] Loss: 0.783063
# DEBUG:trainer:Train Epoch: 2 [110/152 (72%)] Loss: 1.034303
# DEBUG:trainer:Train Epoch: 2 [115/152 (76%)] Loss: 0.514299
# DEBUG:trainer:Train Epoch: 2 [120/152 (79%)] Loss: 0.642999
# DEBUG:trainer:Train Epoch: 2 [125/152 (82%)] Loss: 0.721821
# DEBUG:trainer:Train Epoch: 2 [130/152 (86%)] Loss: 0.575646
# DEBUG:trainer:Train Epoch: 2 [135/152 (89%)] Loss: 0.682103
# DEBUG:trainer:Train Epoch: 2 [140/152 (92%)] Loss: 0.542033
# DEBUG:trainer:Train Epoch: 2 [145/152 (95%)] Loss: 0.548942
# DEBUG:trainer:Train Epoch: 2 [150/152 (99%)] Loss: 0.649436
# INFO:trainer:    epoch          : 2
# INFO:trainer:    loss           : 0.678509176365639
# INFO:trainer:    accuracy       : 0.6071134868421053
# INFO:trainer:    val_loss       : 0.5240824222564697
# INFO:trainer:    val_accuracy   : 0.7457107843137255
# INFO:trainer:    val_sensitivity: 0.9201388888888888
# INFO:trainer:    val_specificity: 0.5254237288135594
# INFO:trainer:    val_MAcc       : 0.722781308851224
# INFO:trainer:    val_F1_score   : 0.7969924812030075
# DEBUG:trainer:Train Epoch: 3 [0/152 (0%)] Loss: 0.688837
# DEBUG:trainer:Train Epoch: 3 [5/152 (3%)] Loss: 0.777732
# DEBUG:trainer:Train Epoch: 3 [10/152 (7%)] Loss: 0.690607
# DEBUG:trainer:Train Epoch: 3 [15/152 (10%)] Loss: 0.642343
# DEBUG:trainer:Train Epoch: 3 [20/152 (13%)] Loss: 0.697276
# DEBUG:trainer:Train Epoch: 3 [25/152 (16%)] Loss: 0.678921
# DEBUG:trainer:Train Epoch: 3 [30/152 (20%)] Loss: 0.614026
# DEBUG:trainer:Train Epoch: 3 [35/152 (23%)] Loss: 0.677442
# DEBUG:trainer:Train Epoch: 3 [40/152 (26%)] Loss: 1.020994
# DEBUG:trainer:Train Epoch: 3 [45/152 (30%)] Loss: 0.704684
# DEBUG:trainer:Train Epoch: 3 [50/152 (33%)] Loss: 0.550903
# DEBUG:trainer:Train Epoch: 3 [55/152 (36%)] Loss: 0.560252
# DEBUG:trainer:Train Epoch: 3 [60/152 (39%)] Loss: 0.534830
# DEBUG:trainer:Train Epoch: 3 [65/152 (43%)] Loss: 0.606806
# DEBUG:trainer:Train Epoch: 3 [70/152 (46%)] Loss: 0.702550
# DEBUG:trainer:Train Epoch: 3 [75/152 (49%)] Loss: 0.572595
# DEBUG:trainer:Train Epoch: 3 [80/152 (53%)] Loss: 0.672477
# DEBUG:trainer:Train Epoch: 3 [85/152 (56%)] Loss: 0.620429
# DEBUG:trainer:Train Epoch: 3 [90/152 (59%)] Loss: 0.510798
# DEBUG:trainer:Train Epoch: 3 [95/152 (62%)] Loss: 0.626944
# DEBUG:trainer:Train Epoch: 3 [100/152 (66%)] Loss: 0.739776
# DEBUG:trainer:Train Epoch: 3 [105/152 (69%)] Loss: 0.755157
# DEBUG:trainer:Train Epoch: 3 [110/152 (72%)] Loss: 0.686280
# DEBUG:trainer:Train Epoch: 3 [115/152 (76%)] Loss: 0.686671
# DEBUG:trainer:Train Epoch: 3 [120/152 (79%)] Loss: 0.579065
# DEBUG:trainer:Train Epoch: 3 [125/152 (82%)] Loss: 0.623006
# DEBUG:trainer:Train Epoch: 3 [130/152 (86%)] Loss: 0.590819
# DEBUG:trainer:Train Epoch: 3 [135/152 (89%)] Loss: 0.533170
# DEBUG:trainer:Train Epoch: 3 [140/152 (92%)] Loss: 0.688003
# DEBUG:trainer:Train Epoch: 3 [145/152 (95%)] Loss: 0.665306
# DEBUG:trainer:Train Epoch: 3 [150/152 (99%)] Loss: 0.577382
# INFO:trainer:    epoch          : 3
# INFO:trainer:    loss           : 0.6465547937703761
# INFO:trainer:    accuracy       : 0.631578947368421
# INFO:trainer:    val_loss       : 0.5161318323191475
# INFO:trainer:    val_accuracy   : 0.7549019607843137
# INFO:trainer:    val_sensitivity: 0.9479166666666666
# INFO:trainer:    val_specificity: 0.5127118644067796
# INFO:trainer:    val_MAcc       : 0.7303142655367232
# INFO:trainer:    val_F1_score   : 0.8076923076923077
# INFO:trainer:Saving new best model at epoch 3: model_best.pth
# DEBUG:trainer:Train Epoch: 4 [0/152 (0%)] Loss: 0.575393
# DEBUG:trainer:Train Epoch: 4 [5/152 (3%)] Loss: 0.695211
# DEBUG:trainer:Train Epoch: 4 [10/152 (7%)] Loss: 0.501558
# DEBUG:trainer:Train Epoch: 4 [15/152 (10%)] Loss: 0.696556
# DEBUG:trainer:Train Epoch: 4 [20/152 (13%)] Loss: 0.513154
# DEBUG:trainer:Train Epoch: 4 [25/152 (16%)] Loss: 0.617077
# DEBUG:trainer:Train Epoch: 4 [30/152 (20%)] Loss: 0.659146
# DEBUG:trainer:Train Epoch: 4 [35/152 (23%)] Loss: 0.667406
# DEBUG:trainer:Train Epoch: 4 [40/152 (26%)] Loss: 0.674912
# DEBUG:trainer:Train Epoch: 4 [45/152 (30%)] Loss: 0.541594
# DEBUG:trainer:Train Epoch: 4 [50/152 (33%)] Loss: 0.535150
# DEBUG:trainer:Train Epoch: 4 [55/152 (36%)] Loss: 0.630230
# DEBUG:trainer:Train Epoch: 4 [60/152 (39%)] Loss: 0.657232
# DEBUG:trainer:Train Epoch: 4 [65/152 (43%)] Loss: 0.709403
# DEBUG:trainer:Train Epoch: 4 [70/152 (46%)] Loss: 0.482567
# DEBUG:trainer:Train Epoch: 4 [75/152 (49%)] Loss: 0.635710
# DEBUG:trainer:Train Epoch: 4 [80/152 (53%)] Loss: 0.495052
# DEBUG:trainer:Train Epoch: 4 [85/152 (56%)] Loss: 0.758298
# DEBUG:trainer:Train Epoch: 4 [90/152 (59%)] Loss: 0.589864
# DEBUG:trainer:Train Epoch: 4 [95/152 (62%)] Loss: 0.614047
# DEBUG:trainer:Train Epoch: 4 [100/152 (66%)] Loss: 0.428374
# DEBUG:trainer:Train Epoch: 4 [105/152 (69%)] Loss: 0.752488
# DEBUG:trainer:Train Epoch: 4 [110/152 (72%)] Loss: 0.746808
# DEBUG:trainer:Train Epoch: 4 [115/152 (76%)] Loss: 0.662014
# DEBUG:trainer:Train Epoch: 4 [120/152 (79%)] Loss: 0.660397
# DEBUG:trainer:Train Epoch: 4 [125/152 (82%)] Loss: 0.493653
# DEBUG:trainer:Train Epoch: 4 [130/152 (86%)] Loss: 0.536434
# DEBUG:trainer:Train Epoch: 4 [135/152 (89%)] Loss: 0.652199
# DEBUG:trainer:Train Epoch: 4 [140/152 (92%)] Loss: 0.550804
# DEBUG:trainer:Train Epoch: 4 [145/152 (95%)] Loss: 0.594370
# DEBUG:trainer:Train Epoch: 4 [150/152 (99%)] Loss: 0.689497
# INFO:trainer:    epoch          : 4
# INFO:trainer:    loss           : 0.6161635222011491
# INFO:trainer:    accuracy       : 0.6486430921052632
# INFO:trainer:    val_loss       : 0.5133639644174015
# INFO:trainer:    val_accuracy   : 0.7549019607843137
# INFO:trainer:    val_sensitivity: 0.9375
# INFO:trainer:    val_specificity: 0.5254237288135594
# INFO:trainer:    val_MAcc       : 0.7314618644067796
# INFO:trainer:    val_F1_score   : 0.8059701492537313
# INFO:trainer:Saving new best model at epoch 4: model_best.pth
# DEBUG:trainer:Train Epoch: 5 [0/152 (0%)] Loss: 0.528519
# DEBUG:trainer:Train Epoch: 5 [5/152 (3%)] Loss: 0.699867
# DEBUG:trainer:Train Epoch: 5 [10/152 (7%)] Loss: 0.601902
# DEBUG:trainer:Train Epoch: 5 [15/152 (10%)] Loss: 0.564530
# DEBUG:trainer:Train Epoch: 5 [20/152 (13%)] Loss: 0.499057
# DEBUG:trainer:Train Epoch: 5 [25/152 (16%)] Loss: 0.520484
# DEBUG:trainer:Train Epoch: 5 [30/152 (20%)] Loss: 0.621113
# DEBUG:trainer:Train Epoch: 5 [35/152 (23%)] Loss: 0.749570
# DEBUG:trainer:Train Epoch: 5 [40/152 (26%)] Loss: 0.457117
# DEBUG:trainer:Train Epoch: 5 [45/152 (30%)] Loss: 0.741959
# DEBUG:trainer:Train Epoch: 5 [50/152 (33%)] Loss: 0.553004
# DEBUG:trainer:Train Epoch: 5 [55/152 (36%)] Loss: 0.509621
# DEBUG:trainer:Train Epoch: 5 [60/152 (39%)] Loss: 0.764473
# DEBUG:trainer:Train Epoch: 5 [65/152 (43%)] Loss: 0.695701
# DEBUG:trainer:Train Epoch: 5 [70/152 (46%)] Loss: 0.458194
# DEBUG:trainer:Train Epoch: 5 [75/152 (49%)] Loss: 0.647865
# DEBUG:trainer:Train Epoch: 5 [80/152 (53%)] Loss: 0.815883
# DEBUG:trainer:Train Epoch: 5 [85/152 (56%)] Loss: 0.767580
# DEBUG:trainer:Train Epoch: 5 [90/152 (59%)] Loss: 0.571706
# DEBUG:trainer:Train Epoch: 5 [95/152 (62%)] Loss: 0.550281
# DEBUG:trainer:Train Epoch: 5 [100/152 (66%)] Loss: 0.485264
# DEBUG:trainer:Train Epoch: 5 [105/152 (69%)] Loss: 0.927049
# DEBUG:trainer:Train Epoch: 5 [110/152 (72%)] Loss: 0.563031
# DEBUG:trainer:Train Epoch: 5 [115/152 (76%)] Loss: 0.571720
# DEBUG:trainer:Train Epoch: 5 [120/152 (79%)] Loss: 0.585414
# DEBUG:trainer:Train Epoch: 5 [125/152 (82%)] Loss: 0.501247
# DEBUG:trainer:Train Epoch: 5 [130/152 (86%)] Loss: 0.556604
# DEBUG:trainer:Train Epoch: 5 [135/152 (89%)] Loss: 0.639225
# DEBUG:trainer:Train Epoch: 5 [140/152 (92%)] Loss: 0.564816
# DEBUG:trainer:Train Epoch: 5 [145/152 (95%)] Loss: 0.678973
# DEBUG:trainer:Train Epoch: 5 [150/152 (99%)] Loss: 0.655163
# INFO:trainer:    epoch          : 5
# INFO:trainer:    loss           : 0.6188850193039367
# INFO:trainer:    accuracy       : 0.6369243421052632
# INFO:trainer:    val_loss       : 0.5101712153238409
# INFO:trainer:    val_accuracy   : 0.7475490196078431
# INFO:trainer:    val_sensitivity: 0.9236111111111112
# INFO:trainer:    val_specificity: 0.5254237288135594
# INFO:trainer:    val_MAcc       : 0.7245174199623352
# INFO:trainer:    val_F1_score   : 0.7987987987987988
# DEBUG:trainer:Train Epoch: 6 [0/152 (0%)] Loss: 0.613161
# DEBUG:trainer:Train Epoch: 6 [5/152 (3%)] Loss: 0.718309
# DEBUG:trainer:Train Epoch: 6 [10/152 (7%)] Loss: 0.604228
# DEBUG:trainer:Train Epoch: 6 [15/152 (10%)] Loss: 0.632852
# DEBUG:trainer:Train Epoch: 6 [20/152 (13%)] Loss: 0.425308
# DEBUG:trainer:Train Epoch: 6 [25/152 (16%)] Loss: 0.609423
# DEBUG:trainer:Train Epoch: 6 [30/152 (20%)] Loss: 1.022877
# DEBUG:trainer:Train Epoch: 6 [35/152 (23%)] Loss: 0.657896
# DEBUG:trainer:Train Epoch: 6 [40/152 (26%)] Loss: 0.575163
# DEBUG:trainer:Train Epoch: 6 [45/152 (30%)] Loss: 0.601465
# DEBUG:trainer:Train Epoch: 6 [50/152 (33%)] Loss: 0.641391
# DEBUG:trainer:Train Epoch: 6 [55/152 (36%)] Loss: 0.736336
# DEBUG:trainer:Train Epoch: 6 [60/152 (39%)] Loss: 0.522226
# DEBUG:trainer:Train Epoch: 6 [65/152 (43%)] Loss: 0.605239
# DEBUG:trainer:Train Epoch: 6 [70/152 (46%)] Loss: 0.691327
# DEBUG:trainer:Train Epoch: 6 [75/152 (49%)] Loss: 0.696313
# DEBUG:trainer:Train Epoch: 6 [80/152 (53%)] Loss: 0.531570
# DEBUG:trainer:Train Epoch: 6 [85/152 (56%)] Loss: 0.763289
# DEBUG:trainer:Train Epoch: 6 [90/152 (59%)] Loss: 0.426911
# DEBUG:trainer:Train Epoch: 6 [95/152 (62%)] Loss: 0.617812
# DEBUG:trainer:Train Epoch: 6 [100/152 (66%)] Loss: 0.575973
# DEBUG:trainer:Train Epoch: 6 [105/152 (69%)] Loss: 0.641409
# DEBUG:trainer:Train Epoch: 6 [110/152 (72%)] Loss: 0.547323
# DEBUG:trainer:Train Epoch: 6 [115/152 (76%)] Loss: 0.655689
# DEBUG:trainer:Train Epoch: 6 [120/152 (79%)] Loss: 0.735040
# DEBUG:trainer:Train Epoch: 6 [125/152 (82%)] Loss: 0.441089
# DEBUG:trainer:Train Epoch: 6 [130/152 (86%)] Loss: 0.646669
# DEBUG:trainer:Train Epoch: 6 [135/152 (89%)] Loss: 0.634406
# DEBUG:trainer:Train Epoch: 6 [140/152 (92%)] Loss: 0.698073
# DEBUG:trainer:Train Epoch: 6 [145/152 (95%)] Loss: 0.550465
# DEBUG:trainer:Train Epoch: 6 [150/152 (99%)] Loss: 0.649506
# INFO:trainer:    epoch          : 6
# INFO:trainer:    loss           : 0.6060102950585516
# INFO:trainer:    accuracy       : 0.6439144736842105
# INFO:trainer:    val_loss       : 0.5125650447957656
# INFO:trainer:    val_accuracy   : 0.7493872549019608
# INFO:trainer:    val_sensitivity: 0.9236111111111112
# INFO:trainer:    val_specificity: 0.5296610169491526
# INFO:trainer:    val_MAcc       : 0.7266360640301319
# INFO:trainer:    val_F1_score   : 0.7999999999999999
# DEBUG:trainer:Train Epoch: 7 [0/152 (0%)] Loss: 0.667483
# DEBUG:trainer:Train Epoch: 7 [5/152 (3%)] Loss: 0.600843
# DEBUG:trainer:Train Epoch: 7 [10/152 (7%)] Loss: 0.568109
# DEBUG:trainer:Train Epoch: 7 [15/152 (10%)] Loss: 0.479553
# DEBUG:trainer:Train Epoch: 7 [20/152 (13%)] Loss: 0.687652
# DEBUG:trainer:Train Epoch: 7 [25/152 (16%)] Loss: 0.646447
# DEBUG:trainer:Train Epoch: 7 [30/152 (20%)] Loss: 0.742624
# DEBUG:trainer:Train Epoch: 7 [35/152 (23%)] Loss: 0.623877
# DEBUG:trainer:Train Epoch: 7 [40/152 (26%)] Loss: 0.665587
# DEBUG:trainer:Train Epoch: 7 [45/152 (30%)] Loss: 0.557397
# DEBUG:trainer:Train Epoch: 7 [50/152 (33%)] Loss: 0.690396
# DEBUG:trainer:Train Epoch: 7 [55/152 (36%)] Loss: 0.594884
# DEBUG:trainer:Train Epoch: 7 [60/152 (39%)] Loss: 0.623639
# DEBUG:trainer:Train Epoch: 7 [65/152 (43%)] Loss: 0.531263
# DEBUG:trainer:Train Epoch: 7 [70/152 (46%)] Loss: 0.587204
# DEBUG:trainer:Train Epoch: 7 [75/152 (49%)] Loss: 0.684232
# DEBUG:trainer:Train Epoch: 7 [80/152 (53%)] Loss: 0.576868
# DEBUG:trainer:Train Epoch: 7 [85/152 (56%)] Loss: 0.720002
# DEBUG:trainer:Train Epoch: 7 [90/152 (59%)] Loss: 0.561471
# DEBUG:trainer:Train Epoch: 7 [95/152 (62%)] Loss: 0.561693
# DEBUG:trainer:Train Epoch: 7 [100/152 (66%)] Loss: 0.721949
# DEBUG:trainer:Train Epoch: 7 [105/152 (69%)] Loss: 0.493485
# DEBUG:trainer:Train Epoch: 7 [110/152 (72%)] Loss: 0.550056
# DEBUG:trainer:Train Epoch: 7 [115/152 (76%)] Loss: 0.540098
# DEBUG:trainer:Train Epoch: 7 [120/152 (79%)] Loss: 0.389549
# DEBUG:trainer:Train Epoch: 7 [125/152 (82%)] Loss: 0.555233
# DEBUG:trainer:Train Epoch: 7 [130/152 (86%)] Loss: 0.544677
# DEBUG:trainer:Train Epoch: 7 [135/152 (89%)] Loss: 0.606195
# DEBUG:trainer:Train Epoch: 7 [140/152 (92%)] Loss: 0.676260
# DEBUG:trainer:Train Epoch: 7 [145/152 (95%)] Loss: 0.645574
# DEBUG:trainer:Train Epoch: 7 [150/152 (99%)] Loss: 0.680150
# INFO:trainer:    epoch          : 7
# INFO:trainer:    loss           : 0.5912678437797647
# INFO:trainer:    accuracy       : 0.6599506578947368
# INFO:trainer:    val_loss       : 0.5041760837330538
# INFO:trainer:    val_accuracy   : 0.7530637254901961
# INFO:trainer:    val_sensitivity: 0.9513888888888888
# INFO:trainer:    val_specificity: 0.5042372881355932
# INFO:trainer:    val_MAcc       : 0.727813088512241
# INFO:trainer:    val_F1_score   : 0.8070692194403535
# DEBUG:trainer:Train Epoch: 8 [0/152 (0%)] Loss: 0.505064
# DEBUG:trainer:Train Epoch: 8 [5/152 (3%)] Loss: 0.670408
# DEBUG:trainer:Train Epoch: 8 [10/152 (7%)] Loss: 0.554071
# DEBUG:trainer:Train Epoch: 8 [15/152 (10%)] Loss: 0.567687
# DEBUG:trainer:Train Epoch: 8 [20/152 (13%)] Loss: 0.744484
# DEBUG:trainer:Train Epoch: 8 [25/152 (16%)] Loss: 0.671533
# DEBUG:trainer:Train Epoch: 8 [30/152 (20%)] Loss: 0.499244
# DEBUG:trainer:Train Epoch: 8 [35/152 (23%)] Loss: 0.628660
# DEBUG:trainer:Train Epoch: 8 [40/152 (26%)] Loss: 0.537713
# DEBUG:trainer:Train Epoch: 8 [45/152 (30%)] Loss: 0.536443
# DEBUG:trainer:Train Epoch: 8 [50/152 (33%)] Loss: 0.562524
# DEBUG:trainer:Train Epoch: 8 [55/152 (36%)] Loss: 0.688390
# DEBUG:trainer:Train Epoch: 8 [60/152 (39%)] Loss: 0.546933
# DEBUG:trainer:Train Epoch: 8 [65/152 (43%)] Loss: 0.471147
# DEBUG:trainer:Train Epoch: 8 [70/152 (46%)] Loss: 0.574463
# DEBUG:trainer:Train Epoch: 8 [75/152 (49%)] Loss: 0.677975
# DEBUG:trainer:Train Epoch: 8 [80/152 (53%)] Loss: 0.622965
# DEBUG:trainer:Train Epoch: 8 [85/152 (56%)] Loss: 0.537590
# DEBUG:trainer:Train Epoch: 8 [90/152 (59%)] Loss: 0.750693
# DEBUG:trainer:Train Epoch: 8 [95/152 (62%)] Loss: 0.578483
# DEBUG:trainer:Train Epoch: 8 [100/152 (66%)] Loss: 0.537648
# DEBUG:trainer:Train Epoch: 8 [105/152 (69%)] Loss: 0.685404
# DEBUG:trainer:Train Epoch: 8 [110/152 (72%)] Loss: 0.464414
# DEBUG:trainer:Train Epoch: 8 [115/152 (76%)] Loss: 0.570150
# DEBUG:trainer:Train Epoch: 8 [120/152 (79%)] Loss: 0.587537
# DEBUG:trainer:Train Epoch: 8 [125/152 (82%)] Loss: 0.596919
# DEBUG:trainer:Train Epoch: 8 [130/152 (86%)] Loss: 0.600208
# DEBUG:trainer:Train Epoch: 8 [135/152 (89%)] Loss: 0.592580
# DEBUG:trainer:Train Epoch: 8 [140/152 (92%)] Loss: 0.700080
# DEBUG:trainer:Train Epoch: 8 [145/152 (95%)] Loss: 0.552045
# DEBUG:trainer:Train Epoch: 8 [150/152 (99%)] Loss: 0.574592
# INFO:trainer:    epoch          : 8
# INFO:trainer:    loss           : 0.5860080048441887
# INFO:trainer:    accuracy       : 0.6570723684210527
# INFO:trainer:    val_loss       : 0.5005894198137171
# INFO:trainer:    val_accuracy   : 0.7493872549019608
# INFO:trainer:    val_sensitivity: 0.9340277777777778
# INFO:trainer:    val_specificity: 0.5169491525423728
# INFO:trainer:    val_MAcc       : 0.7254884651600753
# INFO:trainer:    val_F1_score   : 0.8017883755588673
# DEBUG:trainer:Train Epoch: 9 [0/152 (0%)] Loss: 0.625241
# DEBUG:trainer:Train Epoch: 9 [5/152 (3%)] Loss: 0.557890
# DEBUG:trainer:Train Epoch: 9 [10/152 (7%)] Loss: 0.617900
# DEBUG:trainer:Train Epoch: 9 [15/152 (10%)] Loss: 0.493953
# DEBUG:trainer:Train Epoch: 9 [20/152 (13%)] Loss: 0.521731
# DEBUG:trainer:Train Epoch: 9 [25/152 (16%)] Loss: 0.622009
# DEBUG:trainer:Train Epoch: 9 [30/152 (20%)] Loss: 0.670708
# DEBUG:trainer:Train Epoch: 9 [35/152 (23%)] Loss: 0.560227
# DEBUG:trainer:Train Epoch: 9 [40/152 (26%)] Loss: 0.510502
# DEBUG:trainer:Train Epoch: 9 [45/152 (30%)] Loss: 0.612310
# DEBUG:trainer:Train Epoch: 9 [50/152 (33%)] Loss: 0.563863
# DEBUG:trainer:Train Epoch: 9 [55/152 (36%)] Loss: 0.540612
# DEBUG:trainer:Train Epoch: 9 [60/152 (39%)] Loss: 0.511127
# DEBUG:trainer:Train Epoch: 9 [65/152 (43%)] Loss: 0.572907
# DEBUG:trainer:Train Epoch: 9 [70/152 (46%)] Loss: 0.833457
# DEBUG:trainer:Train Epoch: 9 [75/152 (49%)] Loss: 0.335909
# DEBUG:trainer:Train Epoch: 9 [80/152 (53%)] Loss: 0.555642
# DEBUG:trainer:Train Epoch: 9 [85/152 (56%)] Loss: 0.512854
# DEBUG:trainer:Train Epoch: 9 [90/152 (59%)] Loss: 0.548537
# DEBUG:trainer:Train Epoch: 9 [95/152 (62%)] Loss: 0.626706
# DEBUG:trainer:Train Epoch: 9 [100/152 (66%)] Loss: 0.522978
# DEBUG:trainer:Train Epoch: 9 [105/152 (69%)] Loss: 0.581777
# DEBUG:trainer:Train Epoch: 9 [110/152 (72%)] Loss: 0.656816
# DEBUG:trainer:Train Epoch: 9 [115/152 (76%)] Loss: 0.553324
# DEBUG:trainer:Train Epoch: 9 [120/152 (79%)] Loss: 0.428633
# DEBUG:trainer:Train Epoch: 9 [125/152 (82%)] Loss: 0.605301
# DEBUG:trainer:Train Epoch: 9 [130/152 (86%)] Loss: 0.582417
# DEBUG:trainer:Train Epoch: 9 [135/152 (89%)] Loss: 0.538650
# DEBUG:trainer:Train Epoch: 9 [140/152 (92%)] Loss: 0.606789
# DEBUG:trainer:Train Epoch: 9 [145/152 (95%)] Loss: 0.491328
# DEBUG:trainer:Train Epoch: 9 [150/152 (99%)] Loss: 0.557058
# INFO:trainer:    epoch          : 9
# INFO:trainer:    loss           : 0.5821224780459153
# INFO:trainer:    accuracy       : 0.6576891447368421
# INFO:trainer:    val_loss       : 0.5020071864128113
# INFO:trainer:    val_accuracy   : 0.7493872549019608
# INFO:trainer:    val_sensitivity: 0.9236111111111112
# INFO:trainer:    val_specificity: 0.5296610169491526
# INFO:trainer:    val_MAcc       : 0.7266360640301319
# INFO:trainer:    val_F1_score   : 0.7999999999999999
# DEBUG:trainer:Train Epoch: 10 [0/152 (0%)] Loss: 0.431277
# DEBUG:trainer:Train Epoch: 10 [5/152 (3%)] Loss: 0.462464
# DEBUG:trainer:Train Epoch: 10 [10/152 (7%)] Loss: 0.485409
# DEBUG:trainer:Train Epoch: 10 [15/152 (10%)] Loss: 0.633242
# DEBUG:trainer:Train Epoch: 10 [20/152 (13%)] Loss: 0.593104
# DEBUG:trainer:Train Epoch: 10 [25/152 (16%)] Loss: 0.791002
# DEBUG:trainer:Train Epoch: 10 [30/152 (20%)] Loss: 0.650829
# DEBUG:trainer:Train Epoch: 10 [35/152 (23%)] Loss: 0.543342
# DEBUG:trainer:Train Epoch: 10 [40/152 (26%)] Loss: 0.614196
# DEBUG:trainer:Train Epoch: 10 [45/152 (30%)] Loss: 0.576689
# DEBUG:trainer:Train Epoch: 10 [50/152 (33%)] Loss: 0.449933
# DEBUG:trainer:Train Epoch: 10 [55/152 (36%)] Loss: 0.541019
# DEBUG:trainer:Train Epoch: 10 [60/152 (39%)] Loss: 0.607128
# DEBUG:trainer:Train Epoch: 10 [65/152 (43%)] Loss: 0.687668
# DEBUG:trainer:Train Epoch: 10 [70/152 (46%)] Loss: 0.541141
# DEBUG:trainer:Train Epoch: 10 [75/152 (49%)] Loss: 0.537887
# DEBUG:trainer:Train Epoch: 10 [80/152 (53%)] Loss: 0.696145
# DEBUG:trainer:Train Epoch: 10 [85/152 (56%)] Loss: 0.538024
# DEBUG:trainer:Train Epoch: 10 [90/152 (59%)] Loss: 0.684822
# DEBUG:trainer:Train Epoch: 10 [95/152 (62%)] Loss: 0.580398
# DEBUG:trainer:Train Epoch: 10 [100/152 (66%)] Loss: 0.472953
# DEBUG:trainer:Train Epoch: 10 [105/152 (69%)] Loss: 0.455629
# DEBUG:trainer:Train Epoch: 10 [110/152 (72%)] Loss: 0.545799
# DEBUG:trainer:Train Epoch: 10 [115/152 (76%)] Loss: 0.572911
# DEBUG:trainer:Train Epoch: 10 [120/152 (79%)] Loss: 0.567567
# DEBUG:trainer:Train Epoch: 10 [125/152 (82%)] Loss: 0.486436
# DEBUG:trainer:Train Epoch: 10 [130/152 (86%)] Loss: 0.419217
# DEBUG:trainer:Train Epoch: 10 [135/152 (89%)] Loss: 0.550411
# DEBUG:trainer:Train Epoch: 10 [140/152 (92%)] Loss: 0.574077
# DEBUG:trainer:Train Epoch: 10 [145/152 (95%)] Loss: 0.557515
# DEBUG:trainer:Train Epoch: 10 [150/152 (99%)] Loss: 0.708471
# INFO:trainer:    epoch          : 10
# INFO:trainer:    loss           : 0.5808957332843229
# INFO:trainer:    accuracy       : 0.6587171052631579
# INFO:trainer:    val_loss       : 0.5129892668303322
# INFO:trainer:    val_accuracy   : 0.7493872549019608
# INFO:trainer:    val_sensitivity: 0.8645833333333334
# INFO:trainer:    val_specificity: 0.6016949152542372
# INFO:trainer:    val_MAcc       : 0.7331391242937852
# INFO:trainer:    val_F1_score   : 0.7892234548335975
# INFO:trainer:Saving new best model at epoch 10: model_best.pth
# DEBUG:trainer:Train Epoch: 11 [0/152 (0%)] Loss: 0.604217
# DEBUG:trainer:Train Epoch: 11 [5/152 (3%)] Loss: 0.454778
# DEBUG:trainer:Train Epoch: 11 [10/152 (7%)] Loss: 0.365618
# DEBUG:trainer:Train Epoch: 11 [15/152 (10%)] Loss: 0.684715
# DEBUG:trainer:Train Epoch: 11 [20/152 (13%)] Loss: 0.563277
# DEBUG:trainer:Train Epoch: 11 [25/152 (16%)] Loss: 0.541298
# DEBUG:trainer:Train Epoch: 11 [30/152 (20%)] Loss: 0.549352
# DEBUG:trainer:Train Epoch: 11 [35/152 (23%)] Loss: 0.594129
# DEBUG:trainer:Train Epoch: 11 [40/152 (26%)] Loss: 0.587365
# DEBUG:trainer:Train Epoch: 11 [45/152 (30%)] Loss: 0.520442
# DEBUG:trainer:Train Epoch: 11 [50/152 (33%)] Loss: 0.528367
# DEBUG:trainer:Train Epoch: 11 [55/152 (36%)] Loss: 0.537214
# DEBUG:trainer:Train Epoch: 11 [60/152 (39%)] Loss: 0.428161
# DEBUG:trainer:Train Epoch: 11 [65/152 (43%)] Loss: 0.656089
# DEBUG:trainer:Train Epoch: 11 [70/152 (46%)] Loss: 0.559192
# DEBUG:trainer:Train Epoch: 11 [75/152 (49%)] Loss: 0.515952
# DEBUG:trainer:Train Epoch: 11 [80/152 (53%)] Loss: 0.592777
# DEBUG:trainer:Train Epoch: 11 [85/152 (56%)] Loss: 0.557441
# DEBUG:trainer:Train Epoch: 11 [90/152 (59%)] Loss: 0.553914
# DEBUG:trainer:Train Epoch: 11 [95/152 (62%)] Loss: 0.540613
# DEBUG:trainer:Train Epoch: 11 [100/152 (66%)] Loss: 0.659681
# DEBUG:trainer:Train Epoch: 11 [105/152 (69%)] Loss: 0.475366
# DEBUG:trainer:Train Epoch: 11 [110/152 (72%)] Loss: 0.557045
# DEBUG:trainer:Train Epoch: 11 [115/152 (76%)] Loss: 0.709392
# DEBUG:trainer:Train Epoch: 11 [120/152 (79%)] Loss: 0.579916
# DEBUG:trainer:Train Epoch: 11 [125/152 (82%)] Loss: 0.604282
# DEBUG:trainer:Train Epoch: 11 [130/152 (86%)] Loss: 0.390354
# DEBUG:trainer:Train Epoch: 11 [135/152 (89%)] Loss: 0.472345
# DEBUG:trainer:Train Epoch: 11 [140/152 (92%)] Loss: 0.572357
# DEBUG:trainer:Train Epoch: 11 [145/152 (95%)] Loss: 0.489106
# DEBUG:trainer:Train Epoch: 11 [150/152 (99%)] Loss: 0.549992
# INFO:trainer:    epoch          : 11
# INFO:trainer:    loss           : 0.5681861913517902
# INFO:trainer:    accuracy       : 0.6677631578947368
# INFO:trainer:    val_loss       : 0.5015662259915296
# INFO:trainer:    val_accuracy   : 0.7457107843137255
# INFO:trainer:    val_sensitivity: 0.90625
# INFO:trainer:    val_specificity: 0.5423728813559322
# INFO:trainer:    val_MAcc       : 0.724311440677966
# INFO:trainer:    val_F1_score   : 0.7945205479452054
# DEBUG:trainer:Train Epoch: 12 [0/152 (0%)] Loss: 0.633825
# DEBUG:trainer:Train Epoch: 12 [5/152 (3%)] Loss: 0.386553
# DEBUG:trainer:Train Epoch: 12 [10/152 (7%)] Loss: 0.612925
# DEBUG:trainer:Train Epoch: 12 [15/152 (10%)] Loss: 0.560062
# DEBUG:trainer:Train Epoch: 12 [20/152 (13%)] Loss: 0.698899
# DEBUG:trainer:Train Epoch: 12 [25/152 (16%)] Loss: 0.541358
# DEBUG:trainer:Train Epoch: 12 [30/152 (20%)] Loss: 0.644353
# DEBUG:trainer:Train Epoch: 12 [35/152 (23%)] Loss: 0.545386
# DEBUG:trainer:Train Epoch: 12 [40/152 (26%)] Loss: 0.696669
# DEBUG:trainer:Train Epoch: 12 [45/152 (30%)] Loss: 0.531922
# DEBUG:trainer:Train Epoch: 12 [50/152 (33%)] Loss: 0.597267
# DEBUG:trainer:Train Epoch: 12 [55/152 (36%)] Loss: 0.550267
# DEBUG:trainer:Train Epoch: 12 [60/152 (39%)] Loss: 0.513632
# DEBUG:trainer:Train Epoch: 12 [65/152 (43%)] Loss: 0.541295
# DEBUG:trainer:Train Epoch: 12 [70/152 (46%)] Loss: 0.457265
# DEBUG:trainer:Train Epoch: 12 [75/152 (49%)] Loss: 0.557185
# DEBUG:trainer:Train Epoch: 12 [80/152 (53%)] Loss: 0.599546
# DEBUG:trainer:Train Epoch: 12 [85/152 (56%)] Loss: 0.508639
# DEBUG:trainer:Train Epoch: 12 [90/152 (59%)] Loss: 0.595811
# DEBUG:trainer:Train Epoch: 12 [95/152 (62%)] Loss: 0.733936
# DEBUG:trainer:Train Epoch: 12 [100/152 (66%)] Loss: 0.513481
# DEBUG:trainer:Train Epoch: 12 [105/152 (69%)] Loss: 0.557420
# DEBUG:trainer:Train Epoch: 12 [110/152 (72%)] Loss: 0.652235
# DEBUG:trainer:Train Epoch: 12 [115/152 (76%)] Loss: 0.412227
# DEBUG:trainer:Train Epoch: 12 [120/152 (79%)] Loss: 0.557381
# DEBUG:trainer:Train Epoch: 12 [125/152 (82%)] Loss: 0.517880
# DEBUG:trainer:Train Epoch: 12 [130/152 (86%)] Loss: 0.540409
# DEBUG:trainer:Train Epoch: 12 [135/152 (89%)] Loss: 0.582150
# DEBUG:trainer:Train Epoch: 12 [140/152 (92%)] Loss: 0.623697
# DEBUG:trainer:Train Epoch: 12 [145/152 (95%)] Loss: 0.584748
# DEBUG:trainer:Train Epoch: 12 [150/152 (99%)] Loss: 0.544957
# INFO:trainer:    epoch          : 12
# INFO:trainer:    loss           : 0.5595752192955268
# INFO:trainer:    accuracy       : 0.6786595394736842
# INFO:trainer:    val_loss       : 0.5008367229910458
# INFO:trainer:    val_accuracy   : 0.7420343137254902
# INFO:trainer:    val_sensitivity: 0.8993055555555556
# INFO:trainer:    val_specificity: 0.5423728813559322
# INFO:trainer:    val_MAcc       : 0.720839218455744
# INFO:trainer:    val_F1_score   : 0.7908396946564886
# DEBUG:trainer:Train Epoch: 13 [0/152 (0%)] Loss: 0.573645
# DEBUG:trainer:Train Epoch: 13 [5/152 (3%)] Loss: 0.584479
# DEBUG:trainer:Train Epoch: 13 [10/152 (7%)] Loss: 0.585480
# DEBUG:trainer:Train Epoch: 13 [15/152 (10%)] Loss: 0.595457
# DEBUG:trainer:Train Epoch: 13 [20/152 (13%)] Loss: 0.682625
# DEBUG:trainer:Train Epoch: 13 [25/152 (16%)] Loss: 0.550948
# DEBUG:trainer:Train Epoch: 13 [30/152 (20%)] Loss: 0.578130
# DEBUG:trainer:Train Epoch: 13 [35/152 (23%)] Loss: 0.592742
# DEBUG:trainer:Train Epoch: 13 [40/152 (26%)] Loss: 0.540020
# DEBUG:trainer:Train Epoch: 13 [45/152 (30%)] Loss: 0.548377
# DEBUG:trainer:Train Epoch: 13 [50/152 (33%)] Loss: 0.507721
# DEBUG:trainer:Train Epoch: 13 [55/152 (36%)] Loss: 0.562937
# DEBUG:trainer:Train Epoch: 13 [60/152 (39%)] Loss: 0.487064
# DEBUG:trainer:Train Epoch: 13 [65/152 (43%)] Loss: 0.541906
# DEBUG:trainer:Train Epoch: 13 [70/152 (46%)] Loss: 0.578808
# DEBUG:trainer:Train Epoch: 13 [75/152 (49%)] Loss: 0.509989
# DEBUG:trainer:Train Epoch: 13 [80/152 (53%)] Loss: 0.661765
# DEBUG:trainer:Train Epoch: 13 [85/152 (56%)] Loss: 0.553940
# DEBUG:trainer:Train Epoch: 13 [90/152 (59%)] Loss: 0.567799
# DEBUG:trainer:Train Epoch: 13 [95/152 (62%)] Loss: 0.619907
# DEBUG:trainer:Train Epoch: 13 [100/152 (66%)] Loss: 0.566479
# DEBUG:trainer:Train Epoch: 13 [105/152 (69%)] Loss: 0.557306
# DEBUG:trainer:Train Epoch: 13 [110/152 (72%)] Loss: 0.713438
# DEBUG:trainer:Train Epoch: 13 [115/152 (76%)] Loss: 0.571155
# DEBUG:trainer:Train Epoch: 13 [120/152 (79%)] Loss: 0.580505
# DEBUG:trainer:Train Epoch: 13 [125/152 (82%)] Loss: 0.636126
# DEBUG:trainer:Train Epoch: 13 [130/152 (86%)] Loss: 0.439800
# DEBUG:trainer:Train Epoch: 13 [135/152 (89%)] Loss: 0.541610
# DEBUG:trainer:Train Epoch: 13 [140/152 (92%)] Loss: 0.683942
# DEBUG:trainer:Train Epoch: 13 [145/152 (95%)] Loss: 0.541938
# DEBUG:trainer:Train Epoch: 13 [150/152 (99%)] Loss: 0.582621
# INFO:trainer:    epoch          : 13
# INFO:trainer:    loss           : 0.5553903781661862
# INFO:trainer:    accuracy       : 0.6761924342105263
# INFO:trainer:    val_loss       : 0.5016757390078377
# INFO:trainer:    val_accuracy   : 0.7549019607843137
# INFO:trainer:    val_sensitivity: 0.8888888888888888
# INFO:trainer:    val_specificity: 0.5847457627118644
# INFO:trainer:    val_MAcc       : 0.7368173258003766
# INFO:trainer:    val_F1_score   : 0.7975077881619937
# INFO:trainer:Saving new best model at epoch 13: model_best.pth
# DEBUG:trainer:Train Epoch: 14 [0/152 (0%)] Loss: 0.512259
# DEBUG:trainer:Train Epoch: 14 [5/152 (3%)] Loss: 0.603415
# DEBUG:trainer:Train Epoch: 14 [10/152 (7%)] Loss: 0.503883
# DEBUG:trainer:Train Epoch: 14 [15/152 (10%)] Loss: 0.444136
# DEBUG:trainer:Train Epoch: 14 [20/152 (13%)] Loss: 0.718168
# DEBUG:trainer:Train Epoch: 14 [25/152 (16%)] Loss: 0.580569
# DEBUG:trainer:Train Epoch: 14 [30/152 (20%)] Loss: 0.667234
# DEBUG:trainer:Train Epoch: 14 [35/152 (23%)] Loss: 0.643956
# DEBUG:trainer:Train Epoch: 14 [40/152 (26%)] Loss: 0.605720
# DEBUG:trainer:Train Epoch: 14 [45/152 (30%)] Loss: 0.559091
# DEBUG:trainer:Train Epoch: 14 [50/152 (33%)] Loss: 0.493034
# DEBUG:trainer:Train Epoch: 14 [55/152 (36%)] Loss: 0.610345
# DEBUG:trainer:Train Epoch: 14 [60/152 (39%)] Loss: 0.546356
# DEBUG:trainer:Train Epoch: 14 [65/152 (43%)] Loss: 0.655130
# DEBUG:trainer:Train Epoch: 14 [70/152 (46%)] Loss: 0.562195
# DEBUG:trainer:Train Epoch: 14 [75/152 (49%)] Loss: 0.583160
# DEBUG:trainer:Train Epoch: 14 [80/152 (53%)] Loss: 0.593082
# DEBUG:trainer:Train Epoch: 14 [85/152 (56%)] Loss: 0.616865
# DEBUG:trainer:Train Epoch: 14 [90/152 (59%)] Loss: 0.549597
# DEBUG:trainer:Train Epoch: 14 [95/152 (62%)] Loss: 0.640798
# DEBUG:trainer:Train Epoch: 14 [100/152 (66%)] Loss: 0.443124
# DEBUG:trainer:Train Epoch: 14 [105/152 (69%)] Loss: 0.531973
# DEBUG:trainer:Train Epoch: 14 [110/152 (72%)] Loss: 0.537816
# DEBUG:trainer:Train Epoch: 14 [115/152 (76%)] Loss: 0.506632
# DEBUG:trainer:Train Epoch: 14 [120/152 (79%)] Loss: 0.475873
# DEBUG:trainer:Train Epoch: 14 [125/152 (82%)] Loss: 0.619874
# DEBUG:trainer:Train Epoch: 14 [130/152 (86%)] Loss: 0.569478
# DEBUG:trainer:Train Epoch: 14 [135/152 (89%)] Loss: 0.591186
# DEBUG:trainer:Train Epoch: 14 [140/152 (92%)] Loss: 0.571515
# DEBUG:trainer:Train Epoch: 14 [145/152 (95%)] Loss: 0.533348
# DEBUG:trainer:Train Epoch: 14 [150/152 (99%)] Loss: 0.642342
# INFO:trainer:    epoch          : 14
# INFO:trainer:    loss           : 0.5613270217650815
# INFO:trainer:    accuracy       : 0.6815378289473685
# INFO:trainer:    val_loss       : 0.49542391124893637
# INFO:trainer:    val_accuracy   : 0.7493872549019608
# INFO:trainer:    val_sensitivity: 0.9270833333333334
# INFO:trainer:    val_specificity: 0.5254237288135594
# INFO:trainer:    val_MAcc       : 0.7262535310734464
# INFO:trainer:    val_F1_score   : 0.8005997001499252
# DEBUG:trainer:Train Epoch: 15 [0/152 (0%)] Loss: 0.577237
# DEBUG:trainer:Train Epoch: 15 [5/152 (3%)] Loss: 0.546737
# DEBUG:trainer:Train Epoch: 15 [10/152 (7%)] Loss: 0.505318
# DEBUG:trainer:Train Epoch: 15 [15/152 (10%)] Loss: 0.536455
# DEBUG:trainer:Train Epoch: 15 [20/152 (13%)] Loss: 0.627630
# DEBUG:trainer:Train Epoch: 15 [25/152 (16%)] Loss: 0.550014
# DEBUG:trainer:Train Epoch: 15 [30/152 (20%)] Loss: 0.540294
# DEBUG:trainer:Train Epoch: 15 [35/152 (23%)] Loss: 0.635941
# DEBUG:trainer:Train Epoch: 15 [40/152 (26%)] Loss: 0.539979
# DEBUG:trainer:Train Epoch: 15 [45/152 (30%)] Loss: 0.640422
# DEBUG:trainer:Train Epoch: 15 [50/152 (33%)] Loss: 0.552580
# DEBUG:trainer:Train Epoch: 15 [55/152 (36%)] Loss: 0.419849
# DEBUG:trainer:Train Epoch: 15 [60/152 (39%)] Loss: 0.478101
# DEBUG:trainer:Train Epoch: 15 [65/152 (43%)] Loss: 0.574399
# DEBUG:trainer:Train Epoch: 15 [70/152 (46%)] Loss: 0.473476
# DEBUG:trainer:Train Epoch: 15 [75/152 (49%)] Loss: 0.424040
# DEBUG:trainer:Train Epoch: 15 [80/152 (53%)] Loss: 0.573279
# DEBUG:trainer:Train Epoch: 15 [85/152 (56%)] Loss: 0.717620
# DEBUG:trainer:Train Epoch: 15 [90/152 (59%)] Loss: 0.580673
# DEBUG:trainer:Train Epoch: 15 [95/152 (62%)] Loss: 0.473211
# DEBUG:trainer:Train Epoch: 15 [100/152 (66%)] Loss: 0.525386
# DEBUG:trainer:Train Epoch: 15 [105/152 (69%)] Loss: 0.623451
# DEBUG:trainer:Train Epoch: 15 [110/152 (72%)] Loss: 0.467943
# DEBUG:trainer:Train Epoch: 15 [115/152 (76%)] Loss: 0.661126
# DEBUG:trainer:Train Epoch: 15 [120/152 (79%)] Loss: 0.649798
# DEBUG:trainer:Train Epoch: 15 [125/152 (82%)] Loss: 0.623620
# DEBUG:trainer:Train Epoch: 15 [130/152 (86%)] Loss: 0.484323
# DEBUG:trainer:Train Epoch: 15 [135/152 (89%)] Loss: 0.593406
# DEBUG:trainer:Train Epoch: 15 [140/152 (92%)] Loss: 0.536625
# DEBUG:trainer:Train Epoch: 15 [145/152 (95%)] Loss: 0.569631
# DEBUG:trainer:Train Epoch: 15 [150/152 (99%)] Loss: 0.615971
# INFO:trainer:    epoch          : 15
# INFO:trainer:    loss           : 0.552672945943318
# INFO:trainer:    accuracy       : 0.6846217105263158
# INFO:trainer:    val_loss       : 0.5014957066844491
# INFO:trainer:    val_accuracy   : 0.7438725490196079
# INFO:trainer:    val_sensitivity: 0.8958333333333334
# INFO:trainer:    val_specificity: 0.5508474576271186
# INFO:trainer:    val_MAcc       : 0.723340395480226
# INFO:trainer:    val_F1_score   : 0.7914110429447854
# DEBUG:trainer:Train Epoch: 16 [0/152 (0%)] Loss: 0.572724
# DEBUG:trainer:Train Epoch: 16 [5/152 (3%)] Loss: 0.621307
# DEBUG:trainer:Train Epoch: 16 [10/152 (7%)] Loss: 0.572357
# DEBUG:trainer:Train Epoch: 16 [15/152 (10%)] Loss: 0.480578
# DEBUG:trainer:Train Epoch: 16 [20/152 (13%)] Loss: 0.585801
# DEBUG:trainer:Train Epoch: 16 [25/152 (16%)] Loss: 0.644354
# DEBUG:trainer:Train Epoch: 16 [30/152 (20%)] Loss: 0.509996
# DEBUG:trainer:Train Epoch: 16 [35/152 (23%)] Loss: 0.527239
# DEBUG:trainer:Train Epoch: 16 [40/152 (26%)] Loss: 0.516777
# DEBUG:trainer:Train Epoch: 16 [45/152 (30%)] Loss: 0.697194
# DEBUG:trainer:Train Epoch: 16 [50/152 (33%)] Loss: 0.623566
# DEBUG:trainer:Train Epoch: 16 [55/152 (36%)] Loss: 0.512743
# DEBUG:trainer:Train Epoch: 16 [60/152 (39%)] Loss: 0.488147
# DEBUG:trainer:Train Epoch: 16 [65/152 (43%)] Loss: 0.404514
# DEBUG:trainer:Train Epoch: 16 [70/152 (46%)] Loss: 0.536137
# DEBUG:trainer:Train Epoch: 16 [75/152 (49%)] Loss: 0.495948
# DEBUG:trainer:Train Epoch: 16 [80/152 (53%)] Loss: 0.742668
# DEBUG:trainer:Train Epoch: 16 [85/152 (56%)] Loss: 0.745032
# DEBUG:trainer:Train Epoch: 16 [90/152 (59%)] Loss: 0.499862
# DEBUG:trainer:Train Epoch: 16 [95/152 (62%)] Loss: 0.593312
# DEBUG:trainer:Train Epoch: 16 [100/152 (66%)] Loss: 0.609524
# DEBUG:trainer:Train Epoch: 16 [105/152 (69%)] Loss: 0.438715
# DEBUG:trainer:Train Epoch: 16 [110/152 (72%)] Loss: 0.540291
# DEBUG:trainer:Train Epoch: 16 [115/152 (76%)] Loss: 0.667218
# DEBUG:trainer:Train Epoch: 16 [120/152 (79%)] Loss: 0.553709
# DEBUG:trainer:Train Epoch: 16 [125/152 (82%)] Loss: 0.632769
# DEBUG:trainer:Train Epoch: 16 [130/152 (86%)] Loss: 0.529665
# DEBUG:trainer:Train Epoch: 16 [135/152 (89%)] Loss: 0.464331
# DEBUG:trainer:Train Epoch: 16 [140/152 (92%)] Loss: 0.568455
# DEBUG:trainer:Train Epoch: 16 [145/152 (95%)] Loss: 0.581784
# DEBUG:trainer:Train Epoch: 16 [150/152 (99%)] Loss: 0.571493
# INFO:trainer:    epoch          : 16
# INFO:trainer:    loss           : 0.5533800503533137
# INFO:trainer:    accuracy       : 0.6881167763157895
# INFO:trainer:    val_loss       : 0.4931117208564983
# INFO:trainer:    val_accuracy   : 0.7457107843137255
# INFO:trainer:    val_sensitivity: 0.9027777777777778
# INFO:trainer:    val_specificity: 0.5466101694915254
# INFO:trainer:    val_MAcc       : 0.7246939736346516
# INFO:trainer:    val_F1_score   : 0.7938931297709922
# DEBUG:trainer:Train Epoch: 17 [0/152 (0%)] Loss: 0.493964
# DEBUG:trainer:Train Epoch: 17 [5/152 (3%)] Loss: 0.414515
# DEBUG:trainer:Train Epoch: 17 [10/152 (7%)] Loss: 0.609905
# DEBUG:trainer:Train Epoch: 17 [15/152 (10%)] Loss: 0.603496
# DEBUG:trainer:Train Epoch: 17 [20/152 (13%)] Loss: 0.430316
# DEBUG:trainer:Train Epoch: 17 [25/152 (16%)] Loss: 0.600731
# DEBUG:trainer:Train Epoch: 17 [30/152 (20%)] Loss: 0.570954
# DEBUG:trainer:Train Epoch: 17 [35/152 (23%)] Loss: 0.677196
# DEBUG:trainer:Train Epoch: 17 [40/152 (26%)] Loss: 0.624955
# DEBUG:trainer:Train Epoch: 17 [45/152 (30%)] Loss: 0.584423
# DEBUG:trainer:Train Epoch: 17 [50/152 (33%)] Loss: 0.533419
# DEBUG:trainer:Train Epoch: 17 [55/152 (36%)] Loss: 0.579671
# DEBUG:trainer:Train Epoch: 17 [60/152 (39%)] Loss: 0.461219
# DEBUG:trainer:Train Epoch: 17 [65/152 (43%)] Loss: 0.663190
# DEBUG:trainer:Train Epoch: 17 [70/152 (46%)] Loss: 0.654967
# DEBUG:trainer:Train Epoch: 17 [75/152 (49%)] Loss: 0.569005
# DEBUG:trainer:Train Epoch: 17 [80/152 (53%)] Loss: 0.615500
# DEBUG:trainer:Train Epoch: 17 [85/152 (56%)] Loss: 0.558905
# DEBUG:trainer:Train Epoch: 17 [90/152 (59%)] Loss: 0.622936
# DEBUG:trainer:Train Epoch: 17 [95/152 (62%)] Loss: 0.484017
# DEBUG:trainer:Train Epoch: 17 [100/152 (66%)] Loss: 0.531793
# DEBUG:trainer:Train Epoch: 17 [105/152 (69%)] Loss: 0.552530
# DEBUG:trainer:Train Epoch: 17 [110/152 (72%)] Loss: 0.498816
# DEBUG:trainer:Train Epoch: 17 [115/152 (76%)] Loss: 0.410637
# DEBUG:trainer:Train Epoch: 17 [120/152 (79%)] Loss: 0.543002
# DEBUG:trainer:Train Epoch: 17 [125/152 (82%)] Loss: 0.534415
# DEBUG:trainer:Train Epoch: 17 [130/152 (86%)] Loss: 0.508633
# DEBUG:trainer:Train Epoch: 17 [135/152 (89%)] Loss: 0.641321
# DEBUG:trainer:Train Epoch: 17 [140/152 (92%)] Loss: 0.592113
# DEBUG:trainer:Train Epoch: 17 [145/152 (95%)] Loss: 0.660587
# DEBUG:trainer:Train Epoch: 17 [150/152 (99%)] Loss: 0.601084
# INFO:trainer:    epoch          : 17
# INFO:trainer:    loss           : 0.5526852507732416
# INFO:trainer:    accuracy       : 0.6981907894736842
# INFO:trainer:    val_loss       : 0.5048243613804088
# INFO:trainer:    val_accuracy   : 0.7506127450980392
# INFO:trainer:    val_sensitivity: 0.8229166666666666
# INFO:trainer:    val_specificity: 0.6483050847457628
# INFO:trainer:    val_MAcc       : 0.7356108757062148
# INFO:trainer:    val_F1_score   : 0.7796052631578947
# DEBUG:trainer:Train Epoch: 18 [0/152 (0%)] Loss: 0.557507
# DEBUG:trainer:Train Epoch: 18 [5/152 (3%)] Loss: 0.416217
# DEBUG:trainer:Train Epoch: 18 [10/152 (7%)] Loss: 0.462158
# DEBUG:trainer:Train Epoch: 18 [15/152 (10%)] Loss: 0.539918
# DEBUG:trainer:Train Epoch: 18 [20/152 (13%)] Loss: 0.581630
# DEBUG:trainer:Train Epoch: 18 [25/152 (16%)] Loss: 0.558738
# DEBUG:trainer:Train Epoch: 18 [30/152 (20%)] Loss: 0.552132
# DEBUG:trainer:Train Epoch: 18 [35/152 (23%)] Loss: 0.578458
# DEBUG:trainer:Train Epoch: 18 [40/152 (26%)] Loss: 0.503110
# DEBUG:trainer:Train Epoch: 18 [45/152 (30%)] Loss: 0.559392
# DEBUG:trainer:Train Epoch: 18 [50/152 (33%)] Loss: 0.545247
# DEBUG:trainer:Train Epoch: 18 [55/152 (36%)] Loss: 0.598275
# DEBUG:trainer:Train Epoch: 18 [60/152 (39%)] Loss: 0.665923
# DEBUG:trainer:Train Epoch: 18 [65/152 (43%)] Loss: 0.536007
# DEBUG:trainer:Train Epoch: 18 [70/152 (46%)] Loss: 0.532095
# DEBUG:trainer:Train Epoch: 18 [75/152 (49%)] Loss: 0.462616
# DEBUG:trainer:Train Epoch: 18 [80/152 (53%)] Loss: 0.506675
# DEBUG:trainer:Train Epoch: 18 [85/152 (56%)] Loss: 0.566159
# DEBUG:trainer:Train Epoch: 18 [90/152 (59%)] Loss: 0.524363
# DEBUG:trainer:Train Epoch: 18 [95/152 (62%)] Loss: 0.514875
# DEBUG:trainer:Train Epoch: 18 [100/152 (66%)] Loss: 0.511728
# DEBUG:trainer:Train Epoch: 18 [105/152 (69%)] Loss: 0.602945
# DEBUG:trainer:Train Epoch: 18 [110/152 (72%)] Loss: 0.420592
# DEBUG:trainer:Train Epoch: 18 [115/152 (76%)] Loss: 0.554530
# DEBUG:trainer:Train Epoch: 18 [120/152 (79%)] Loss: 0.563254
# DEBUG:trainer:Train Epoch: 18 [125/152 (82%)] Loss: 0.566130
# DEBUG:trainer:Train Epoch: 18 [130/152 (86%)] Loss: 0.616007
# DEBUG:trainer:Train Epoch: 18 [135/152 (89%)] Loss: 0.668493
# DEBUG:trainer:Train Epoch: 18 [140/152 (92%)] Loss: 0.548769
# DEBUG:trainer:Train Epoch: 18 [145/152 (95%)] Loss: 0.597788
# DEBUG:trainer:Train Epoch: 18 [150/152 (99%)] Loss: 0.408039
# INFO:trainer:    epoch          : 18
# INFO:trainer:    loss           : 0.5510725949547792
# INFO:trainer:    accuracy       : 0.6842105263157895
# INFO:trainer:    val_loss       : 0.4915169828078326
# INFO:trainer:    val_accuracy   : 0.7475490196078431
# INFO:trainer:    val_sensitivity: 0.8958333333333334
# INFO:trainer:    val_specificity: 0.559322033898305
# INFO:trainer:    val_MAcc       : 0.7275776836158192
# INFO:trainer:    val_F1_score   : 0.7938461538461538
# DEBUG:trainer:Train Epoch: 19 [0/152 (0%)] Loss: 0.516622
# DEBUG:trainer:Train Epoch: 19 [5/152 (3%)] Loss: 0.668214
# DEBUG:trainer:Train Epoch: 19 [10/152 (7%)] Loss: 0.468939
# DEBUG:trainer:Train Epoch: 19 [15/152 (10%)] Loss: 0.465982
# DEBUG:trainer:Train Epoch: 19 [20/152 (13%)] Loss: 0.446412
# DEBUG:trainer:Train Epoch: 19 [25/152 (16%)] Loss: 0.426612
# DEBUG:trainer:Train Epoch: 19 [30/152 (20%)] Loss: 0.499781
# DEBUG:trainer:Train Epoch: 19 [35/152 (23%)] Loss: 0.511057
# DEBUG:trainer:Train Epoch: 19 [40/152 (26%)] Loss: 0.529238
# DEBUG:trainer:Train Epoch: 19 [45/152 (30%)] Loss: 0.563448
# DEBUG:trainer:Train Epoch: 19 [50/152 (33%)] Loss: 0.568751
# DEBUG:trainer:Train Epoch: 19 [55/152 (36%)] Loss: 0.545789
# DEBUG:trainer:Train Epoch: 19 [60/152 (39%)] Loss: 0.572336
# DEBUG:trainer:Train Epoch: 19 [65/152 (43%)] Loss: 0.583876
# DEBUG:trainer:Train Epoch: 19 [70/152 (46%)] Loss: 0.680765
# DEBUG:trainer:Train Epoch: 19 [75/152 (49%)] Loss: 0.500093
# DEBUG:trainer:Train Epoch: 19 [80/152 (53%)] Loss: 0.501812
# DEBUG:trainer:Train Epoch: 19 [85/152 (56%)] Loss: 0.664652
# DEBUG:trainer:Train Epoch: 19 [90/152 (59%)] Loss: 0.573422
# DEBUG:trainer:Train Epoch: 19 [95/152 (62%)] Loss: 0.526334
# DEBUG:trainer:Train Epoch: 19 [100/152 (66%)] Loss: 0.571091
# DEBUG:trainer:Train Epoch: 19 [105/152 (69%)] Loss: 0.531171
# DEBUG:trainer:Train Epoch: 19 [110/152 (72%)] Loss: 0.537408
# DEBUG:trainer:Train Epoch: 19 [115/152 (76%)] Loss: 0.576594
# DEBUG:trainer:Train Epoch: 19 [120/152 (79%)] Loss: 0.596487
# DEBUG:trainer:Train Epoch: 19 [125/152 (82%)] Loss: 0.624675
# DEBUG:trainer:Train Epoch: 19 [130/152 (86%)] Loss: 0.488636
# DEBUG:trainer:Train Epoch: 19 [135/152 (89%)] Loss: 0.576693
# DEBUG:trainer:Train Epoch: 19 [140/152 (92%)] Loss: 0.652722
# DEBUG:trainer:Train Epoch: 19 [145/152 (95%)] Loss: 0.537820
# DEBUG:trainer:Train Epoch: 19 [150/152 (99%)] Loss: 0.421226
# INFO:trainer:    epoch          : 19
# INFO:trainer:    loss           : 0.5454659520795471
# INFO:trainer:    accuracy       : 0.6953125
# INFO:trainer:    val_loss       : 0.4908473211176255
# INFO:trainer:    val_accuracy   : 0.7475490196078431
# INFO:trainer:    val_sensitivity: 0.8993055555555556
# INFO:trainer:    val_specificity: 0.5550847457627118
# INFO:trainer:    val_MAcc       : 0.7271951506591336
# INFO:trainer:    val_F1_score   : 0.794478527607362
# DEBUG:trainer:Train Epoch: 20 [0/152 (0%)] Loss: 0.503976
# DEBUG:trainer:Train Epoch: 20 [5/152 (3%)] Loss: 0.596266
# DEBUG:trainer:Train Epoch: 20 [10/152 (7%)] Loss: 0.496020
# DEBUG:trainer:Train Epoch: 20 [15/152 (10%)] Loss: 0.368910
# DEBUG:trainer:Train Epoch: 20 [20/152 (13%)] Loss: 0.483032
# DEBUG:trainer:Train Epoch: 20 [25/152 (16%)] Loss: 0.609318
# DEBUG:trainer:Train Epoch: 20 [30/152 (20%)] Loss: 0.593696
# DEBUG:trainer:Train Epoch: 20 [35/152 (23%)] Loss: 0.625225
# DEBUG:trainer:Train Epoch: 20 [40/152 (26%)] Loss: 0.402460
# DEBUG:trainer:Train Epoch: 20 [45/152 (30%)] Loss: 0.700482
# DEBUG:trainer:Train Epoch: 20 [50/152 (33%)] Loss: 0.555253
# DEBUG:trainer:Train Epoch: 20 [55/152 (36%)] Loss: 0.444878
# DEBUG:trainer:Train Epoch: 20 [60/152 (39%)] Loss: 0.570922
# DEBUG:trainer:Train Epoch: 20 [65/152 (43%)] Loss: 0.529426
# DEBUG:trainer:Train Epoch: 20 [70/152 (46%)] Loss: 0.389053
# DEBUG:trainer:Train Epoch: 20 [75/152 (49%)] Loss: 0.509563
# DEBUG:trainer:Train Epoch: 20 [80/152 (53%)] Loss: 0.507755
# DEBUG:trainer:Train Epoch: 20 [85/152 (56%)] Loss: 0.542153
# DEBUG:trainer:Train Epoch: 20 [90/152 (59%)] Loss: 0.467319
# DEBUG:trainer:Train Epoch: 20 [95/152 (62%)] Loss: 0.596637
# DEBUG:trainer:Train Epoch: 20 [100/152 (66%)] Loss: 0.498152
# DEBUG:trainer:Train Epoch: 20 [105/152 (69%)] Loss: 0.453881
# DEBUG:trainer:Train Epoch: 20 [110/152 (72%)] Loss: 0.529874
# DEBUG:trainer:Train Epoch: 20 [115/152 (76%)] Loss: 0.578856
# DEBUG:trainer:Train Epoch: 20 [120/152 (79%)] Loss: 0.585828
# DEBUG:trainer:Train Epoch: 20 [125/152 (82%)] Loss: 0.612800
# DEBUG:trainer:Train Epoch: 20 [130/152 (86%)] Loss: 0.551771
# DEBUG:trainer:Train Epoch: 20 [135/152 (89%)] Loss: 0.560872
# DEBUG:trainer:Train Epoch: 20 [140/152 (92%)] Loss: 0.521218
# DEBUG:trainer:Train Epoch: 20 [145/152 (95%)] Loss: 0.508839
# DEBUG:trainer:Train Epoch: 20 [150/152 (99%)] Loss: 0.510505
# INFO:trainer:    epoch          : 20
# INFO:trainer:    loss           : 0.5403194980401742
# INFO:trainer:    accuracy       : 0.7037417763157895
# INFO:trainer:    val_loss       : 0.4996020197868347
# INFO:trainer:    val_accuracy   : 0.7579656862745098
# INFO:trainer:    val_sensitivity: 0.8715277777777778
# INFO:trainer:    val_specificity: 0.6059322033898306
# INFO:trainer:    val_MAcc       : 0.7387299905838042
# INFO:trainer:    val_F1_score   : 0.7943037974683543
# INFO:trainer:Saving new best model at epoch 20: model_best.pth
# DEBUG:trainer:Train Epoch: 21 [0/152 (0%)] Loss: 0.486890
# DEBUG:trainer:Train Epoch: 21 [5/152 (3%)] Loss: 0.447781
# DEBUG:trainer:Train Epoch: 21 [10/152 (7%)] Loss: 0.546313
# DEBUG:trainer:Train Epoch: 21 [15/152 (10%)] Loss: 0.582028
# DEBUG:trainer:Train Epoch: 21 [20/152 (13%)] Loss: 0.498123
# DEBUG:trainer:Train Epoch: 21 [25/152 (16%)] Loss: 0.453092
# DEBUG:trainer:Train Epoch: 21 [30/152 (20%)] Loss: 0.463651
# DEBUG:trainer:Train Epoch: 21 [35/152 (23%)] Loss: 0.634734
# DEBUG:trainer:Train Epoch: 21 [40/152 (26%)] Loss: 0.518580
# DEBUG:trainer:Train Epoch: 21 [45/152 (30%)] Loss: 0.610927
# DEBUG:trainer:Train Epoch: 21 [50/152 (33%)] Loss: 0.576713
# DEBUG:trainer:Train Epoch: 21 [55/152 (36%)] Loss: 0.608260
# DEBUG:trainer:Train Epoch: 21 [60/152 (39%)] Loss: 0.606357
# DEBUG:trainer:Train Epoch: 21 [65/152 (43%)] Loss: 0.586862
# DEBUG:trainer:Train Epoch: 21 [70/152 (46%)] Loss: 0.535676
# ...
# DEBUG:trainer:Train Epoch: 68 [50/152 (33%)] Loss: 0.511203
# DEBUG:trainer:Train Epoch: 68 [55/152 (36%)] Loss: 0.410573
# DEBUG:trainer:Train Epoch: 68 [60/152 (39%)] Loss: 0.475741
# DEBUG:trainer:Train Epoch: 68 [65/152 (43%)] Loss: 0.401578
# DEBUG:trainer:Train Epoch: 68 [70/152 (46%)] Loss: 0.561388
# DEBUG:trainer:Train Epoch: 68 [75/152 (49%)] Loss: 0.544270
# DEBUG:trainer:Train Epoch: 68 [80/152 (53%)] Loss: 0.478759
# DEBUG:trainer:Train Epoch: 68 [85/152 (56%)] Loss: 0.483043
# DEBUG:trainer:Train Epoch: 68 [90/152 (59%)] Loss: 0.493635
# DEBUG:trainer:Train Epoch: 68 [95/152 (62%)] Loss: 0.621796
# DEBUG:trainer:Train Epoch: 68 [100/152 (66%)] Loss: 0.447782
# DEBUG:trainer:Train Epoch: 68 [105/152 (69%)] Loss: 0.428211
# DEBUG:trainer:Train Epoch: 68 [110/152 (72%)] Loss: 0.535572
# DEBUG:trainer:Train Epoch: 68 [115/152 (76%)] Loss: 0.456672
# DEBUG:trainer:Train Epoch: 68 [120/152 (79%)] Loss: 0.597480
# DEBUG:trainer:Train Epoch: 68 [125/152 (82%)] Loss: 0.586703
# DEBUG:trainer:Train Epoch: 68 [130/152 (86%)] Loss: 0.538957
# DEBUG:trainer:Train Epoch: 68 [135/152 (89%)] Loss: 0.681486
# DEBUG:trainer:Train Epoch: 68 [140/152 (92%)] Loss: 0.611527
# DEBUG:trainer:Train Epoch: 68 [145/152 (95%)] Loss: 0.371707
# DEBUG:trainer:Train Epoch: 68 [150/152 (99%)] Loss: 0.459490
# INFO:trainer:    epoch          : 68
# INFO:trainer:    loss           : 0.517733423137351
# INFO:trainer:    accuracy       : 0.7156661184210527
# INFO:trainer:    val_loss       : 0.4682648760430953
# INFO:trainer:    val_accuracy   : 0.7567401960784315
# INFO:trainer:    val_sensitivity: 0.9166666666666666
# INFO:trainer:    val_specificity: 0.5550847457627118
# INFO:trainer:    val_MAcc       : 0.7358757062146892
# INFO:trainer:    val_F1_score   : 0.8036529680365297
# DEBUG:trainer:Train Epoch: 69 [0/152 (0%)] Loss: 0.526736
# DEBUG:trainer:Train Epoch: 69 [5/152 (3%)] Loss: 0.696775
# DEBUG:trainer:Train Epoch: 69 [10/152 (7%)] Loss: 0.499500
# DEBUG:trainer:Train Epoch: 69 [15/152 (10%)] Loss: 0.576315
# DEBUG:trainer:Train Epoch: 69 [20/152 (13%)] Loss: 0.500576
# DEBUG:trainer:Train Epoch: 69 [25/152 (16%)] Loss: 0.544543
# DEBUG:trainer:Train Epoch: 69 [30/152 (20%)] Loss: 0.616769
# DEBUG:trainer:Train Epoch: 69 [35/152 (23%)] Loss: 0.536805
# DEBUG:trainer:Train Epoch: 69 [40/152 (26%)] Loss: 0.558581
# DEBUG:trainer:Train Epoch: 69 [45/152 (30%)] Loss: 0.523304
# DEBUG:trainer:Train Epoch: 69 [50/152 (33%)] Loss: 0.369236
# DEBUG:trainer:Train Epoch: 69 [55/152 (36%)] Loss: 0.445974
# DEBUG:trainer:Train Epoch: 69 [60/152 (39%)] Loss: 0.459131
# DEBUG:trainer:Train Epoch: 69 [65/152 (43%)] Loss: 0.656021
# DEBUG:trainer:Train Epoch: 69 [70/152 (46%)] Loss: 0.458260
# DEBUG:trainer:Train Epoch: 69 [75/152 (49%)] Loss: 0.418371
# DEBUG:trainer:Train Epoch: 69 [80/152 (53%)] Loss: 0.512376
# DEBUG:trainer:Train Epoch: 69 [85/152 (56%)] Loss: 0.482237
# DEBUG:trainer:Train Epoch: 69 [90/152 (59%)] Loss: 0.456107
# DEBUG:trainer:Train Epoch: 69 [95/152 (62%)] Loss: 0.368050
# DEBUG:trainer:Train Epoch: 69 [100/152 (66%)] Loss: 0.470697
# DEBUG:trainer:Train Epoch: 69 [105/152 (69%)] Loss: 0.535325
# DEBUG:trainer:Train Epoch: 69 [110/152 (72%)] Loss: 0.458682
# DEBUG:trainer:Train Epoch: 69 [115/152 (76%)] Loss: 0.569022
# DEBUG:trainer:Train Epoch: 69 [120/152 (79%)] Loss: 0.587409
# DEBUG:trainer:Train Epoch: 69 [125/152 (82%)] Loss: 0.555077
# DEBUG:trainer:Train Epoch: 69 [130/152 (86%)] Loss: 0.483845
# DEBUG:trainer:Train Epoch: 69 [135/152 (89%)] Loss: 0.481029
# DEBUG:trainer:Train Epoch: 69 [140/152 (92%)] Loss: 0.627756
# DEBUG:trainer:Train Epoch: 69 [145/152 (95%)] Loss: 0.524463
# DEBUG:trainer:Train Epoch: 69 [150/152 (99%)] Loss: 0.514864
# INFO:trainer:    epoch          : 69
# INFO:trainer:    loss           : 0.5110729189687654
# INFO:trainer:    accuracy       : 0.723889802631579
# INFO:trainer:    val_loss       : 0.46863576769828796
# INFO:trainer:    val_accuracy   : 0.7549019607843137
# INFO:trainer:    val_sensitivity: 0.9444444444444444
# INFO:trainer:    val_specificity: 0.5169491525423728
# INFO:trainer:    val_MAcc       : 0.7306967984934086
# INFO:trainer:    val_F1_score   : 0.8071216617210681
# DEBUG:trainer:Train Epoch: 70 [0/152 (0%)] Loss: 0.578997
# DEBUG:trainer:Train Epoch: 70 [5/152 (3%)] Loss: 0.524064
# DEBUG:trainer:Train Epoch: 70 [10/152 (7%)] Loss: 0.526141
# DEBUG:trainer:Train Epoch: 70 [15/152 (10%)] Loss: 0.565048
# DEBUG:trainer:Train Epoch: 70 [20/152 (13%)] Loss: 0.658796
# DEBUG:trainer:Train Epoch: 70 [25/152 (16%)] Loss: 0.453029
# DEBUG:trainer:Train Epoch: 70 [30/152 (20%)] Loss: 0.466210
# DEBUG:trainer:Train Epoch: 70 [35/152 (23%)] Loss: 0.554211
# DEBUG:trainer:Train Epoch: 70 [40/152 (26%)] Loss: 0.444641
# DEBUG:trainer:Train Epoch: 70 [45/152 (30%)] Loss: 0.457455
# DEBUG:trainer:Train Epoch: 70 [50/152 (33%)] Loss: 0.446107
# DEBUG:trainer:Train Epoch: 70 [55/152 (36%)] Loss: 0.466068
# DEBUG:trainer:Train Epoch: 70 [60/152 (39%)] Loss: 0.513420
# DEBUG:trainer:Train Epoch: 70 [65/152 (43%)] Loss: 0.420732
# DEBUG:trainer:Train Epoch: 70 [70/152 (46%)] Loss: 0.383860
# DEBUG:trainer:Train Epoch: 70 [75/152 (49%)] Loss: 0.567035
# DEBUG:trainer:Train Epoch: 70 [80/152 (53%)] Loss: 0.506037
# DEBUG:trainer:Train Epoch: 70 [85/152 (56%)] Loss: 0.485203
# DEBUG:trainer:Train Epoch: 70 [90/152 (59%)] Loss: 0.464399
# DEBUG:trainer:Train Epoch: 70 [95/152 (62%)] Loss: 0.437262
# DEBUG:trainer:Train Epoch: 70 [100/152 (66%)] Loss: 0.488006
# DEBUG:trainer:Train Epoch: 70 [105/152 (69%)] Loss: 0.410555
# DEBUG:trainer:Train Epoch: 70 [110/152 (72%)] Loss: 0.562868
# DEBUG:trainer:Train Epoch: 70 [115/152 (76%)] Loss: 0.639132
# DEBUG:trainer:Train Epoch: 70 [120/152 (79%)] Loss: 0.522800
# DEBUG:trainer:Train Epoch: 70 [125/152 (82%)] Loss: 0.542715
# DEBUG:trainer:Train Epoch: 70 [130/152 (86%)] Loss: 0.445670
# DEBUG:trainer:Train Epoch: 70 [135/152 (89%)] Loss: 0.550725
# DEBUG:trainer:Train Epoch: 70 [140/152 (92%)] Loss: 0.427127
# DEBUG:trainer:Train Epoch: 70 [145/152 (95%)] Loss: 0.691230
# DEBUG:trainer:Train Epoch: 70 [150/152 (99%)] Loss: 0.631155
# INFO:trainer:    epoch          : 70
# INFO:trainer:    loss           : 0.5182521984373268
# INFO:trainer:    accuracy       : 0.7234786184210527
# INFO:trainer:    val_loss       : 0.46947313231580395
# INFO:trainer:    val_accuracy   : 0.7549019607843137
# INFO:trainer:    val_sensitivity: 0.90625
# INFO:trainer:    val_specificity: 0.5635593220338984
# INFO:trainer:    val_MAcc       : 0.7349046610169492
# INFO:trainer:    val_F1_score   : 0.8006134969325153
# DEBUG:trainer:Train Epoch: 71 [0/152 (0%)] Loss: 0.505862
# DEBUG:trainer:Train Epoch: 71 [5/152 (3%)] Loss: 0.352399
# DEBUG:trainer:Train Epoch: 71 [10/152 (7%)] Loss: 0.433535
# DEBUG:trainer:Train Epoch: 71 [15/152 (10%)] Loss: 0.466787
# DEBUG:trainer:Train Epoch: 71 [20/152 (13%)] Loss: 0.410089
# DEBUG:trainer:Train Epoch: 71 [25/152 (16%)] Loss: 0.583921
# DEBUG:trainer:Train Epoch: 71 [30/152 (20%)] Loss: 0.592592
# DEBUG:trainer:Train Epoch: 71 [35/152 (23%)] Loss: 0.526079
# DEBUG:trainer:Train Epoch: 71 [40/152 (26%)] Loss: 0.705276
# DEBUG:trainer:Train Epoch: 71 [45/152 (30%)] Loss: 0.519787
# DEBUG:trainer:Train Epoch: 71 [50/152 (33%)] Loss: 0.556153
# DEBUG:trainer:Train Epoch: 71 [55/152 (36%)] Loss: 0.532554
# DEBUG:trainer:Train Epoch: 71 [60/152 (39%)] Loss: 0.496249
# DEBUG:trainer:Train Epoch: 71 [65/152 (43%)] Loss: 0.567734
# DEBUG:trainer:Train Epoch: 71 [70/152 (46%)] Loss: 0.449677
# DEBUG:trainer:Train Epoch: 71 [75/152 (49%)] Loss: 0.479434
# DEBUG:trainer:Train Epoch: 71 [80/152 (53%)] Loss: 0.573659
# DEBUG:trainer:Train Epoch: 71 [85/152 (56%)] Loss: 0.523794
# DEBUG:trainer:Train Epoch: 71 [90/152 (59%)] Loss: 0.525457
# DEBUG:trainer:Train Epoch: 71 [95/152 (62%)] Loss: 0.609317
# DEBUG:trainer:Train Epoch: 71 [100/152 (66%)] Loss: 0.386142
# DEBUG:trainer:Train Epoch: 71 [105/152 (69%)] Loss: 0.492025
# DEBUG:trainer:Train Epoch: 71 [110/152 (72%)] Loss: 0.609132
# DEBUG:trainer:Train Epoch: 71 [115/152 (76%)] Loss: 0.546294
# DEBUG:trainer:Train Epoch: 71 [120/152 (79%)] Loss: 0.429950
# DEBUG:trainer:Train Epoch: 71 [125/152 (82%)] Loss: 0.578644
# DEBUG:trainer:Train Epoch: 71 [130/152 (86%)] Loss: 0.463620
# DEBUG:trainer:Train Epoch: 71 [135/152 (89%)] Loss: 0.490296
# DEBUG:trainer:Train Epoch: 71 [140/152 (92%)] Loss: 0.466206
# DEBUG:trainer:Train Epoch: 71 [145/152 (95%)] Loss: 0.529687
# DEBUG:trainer:Train Epoch: 71 [150/152 (99%)] Loss: 0.380438
# INFO:trainer:    epoch          : 71
# INFO:trainer:    loss           : 0.5212182477116585
# INFO:trainer:    accuracy       : 0.72265625
# INFO:trainer:    val_loss       : 0.4691891249488382
# INFO:trainer:    val_accuracy   : 0.7585784313725491
# INFO:trainer:    val_sensitivity: 0.9236111111111112
# INFO:trainer:    val_specificity: 0.5508474576271186
# INFO:trainer:    val_MAcc       : 0.7372292843691148
# INFO:trainer:    val_F1_score   : 0.8060606060606061
# DEBUG:trainer:Train Epoch: 72 [0/152 (0%)] Loss: 0.535146
# DEBUG:trainer:Train Epoch: 72 [5/152 (3%)] Loss: 0.382239
# DEBUG:trainer:Train Epoch: 72 [10/152 (7%)] Loss: 0.606094
# DEBUG:trainer:Train Epoch: 72 [15/152 (10%)] Loss: 0.560421
# DEBUG:trainer:Train Epoch: 72 [20/152 (13%)] Loss: 0.567366
# DEBUG:trainer:Train Epoch: 72 [25/152 (16%)] Loss: 0.646216
# DEBUG:trainer:Train Epoch: 72 [30/152 (20%)] Loss: 0.577075
# DEBUG:trainer:Train Epoch: 72 [35/152 (23%)] Loss: 0.506964
# DEBUG:trainer:Train Epoch: 72 [40/152 (26%)] Loss: 0.443173
# DEBUG:trainer:Train Epoch: 72 [45/152 (30%)] Loss: 0.424401
# DEBUG:trainer:Train Epoch: 72 [50/152 (33%)] Loss: 0.486572
# DEBUG:trainer:Train Epoch: 72 [55/152 (36%)] Loss: 0.582253
# DEBUG:trainer:Train Epoch: 72 [60/152 (39%)] Loss: 0.387765
# DEBUG:trainer:Train Epoch: 72 [65/152 (43%)] Loss: 0.472499
# DEBUG:trainer:Train Epoch: 72 [70/152 (46%)] Loss: 0.513026
# DEBUG:trainer:Train Epoch: 72 [75/152 (49%)] Loss: 0.567674
# DEBUG:trainer:Train Epoch: 72 [80/152 (53%)] Loss: 0.635569
# DEBUG:trainer:Train Epoch: 72 [85/152 (56%)] Loss: 0.599884
# DEBUG:trainer:Train Epoch: 72 [90/152 (59%)] Loss: 0.551081
# DEBUG:trainer:Train Epoch: 72 [95/152 (62%)] Loss: 0.409148
# DEBUG:trainer:Train Epoch: 72 [100/152 (66%)] Loss: 0.517511
# DEBUG:trainer:Train Epoch: 72 [105/152 (69%)] Loss: 0.483290
# DEBUG:trainer:Train Epoch: 72 [110/152 (72%)] Loss: 0.376083
# DEBUG:trainer:Train Epoch: 72 [115/152 (76%)] Loss: 0.651697
# DEBUG:trainer:Train Epoch: 72 [120/152 (79%)] Loss: 0.649907
# DEBUG:trainer:Train Epoch: 72 [125/152 (82%)] Loss: 0.449992
# DEBUG:trainer:Train Epoch: 72 [130/152 (86%)] Loss: 0.493660
# DEBUG:trainer:Train Epoch: 72 [135/152 (89%)] Loss: 0.575799
# DEBUG:trainer:Train Epoch: 72 [140/152 (92%)] Loss: 0.448145
# DEBUG:trainer:Train Epoch: 72 [145/152 (95%)] Loss: 0.571179
# DEBUG:trainer:Train Epoch: 72 [150/152 (99%)] Loss: 0.445789
# INFO:trainer:    epoch          : 72
# INFO:trainer:    loss           : 0.5103554129600525
# INFO:trainer:    accuracy       : 0.7249177631578947
# INFO:trainer:    val_loss       : 0.4665958302862504
# INFO:trainer:    val_accuracy   : 0.7585784313725491
# INFO:trainer:    val_sensitivity: 0.9305555555555556
# INFO:trainer:    val_specificity: 0.5423728813559322
# INFO:trainer:    val_MAcc       : 0.736464218455744
# INFO:trainer:    val_F1_score   : 0.8072289156626508
# DEBUG:trainer:Train Epoch: 73 [0/152 (0%)] Loss: 0.486717
# DEBUG:trainer:Train Epoch: 73 [5/152 (3%)] Loss: 0.620540
# DEBUG:trainer:Train Epoch: 73 [10/152 (7%)] Loss: 0.612052
# DEBUG:trainer:Train Epoch: 73 [15/152 (10%)] Loss: 0.601116
# DEBUG:trainer:Train Epoch: 73 [20/152 (13%)] Loss: 0.514215
# DEBUG:trainer:Train Epoch: 73 [25/152 (16%)] Loss: 0.572325
# DEBUG:trainer:Train Epoch: 73 [30/152 (20%)] Loss: 0.526394
# DEBUG:trainer:Train Epoch: 73 [35/152 (23%)] Loss: 0.391898
# DEBUG:trainer:Train Epoch: 73 [40/152 (26%)] Loss: 0.456153
# DEBUG:trainer:Train Epoch: 73 [45/152 (30%)] Loss: 0.639102
# DEBUG:trainer:Train Epoch: 73 [50/152 (33%)] Loss: 0.471284
# DEBUG:trainer:Train Epoch: 73 [55/152 (36%)] Loss: 0.589878
# DEBUG:trainer:Train Epoch: 73 [60/152 (39%)] Loss: 0.471992
# DEBUG:trainer:Train Epoch: 73 [65/152 (43%)] Loss: 0.394623
# DEBUG:trainer:Train Epoch: 73 [70/152 (46%)] Loss: 0.518241
# DEBUG:trainer:Train Epoch: 73 [75/152 (49%)] Loss: 0.505025
# DEBUG:trainer:Train Epoch: 73 [80/152 (53%)] Loss: 0.489363
# DEBUG:trainer:Train Epoch: 73 [85/152 (56%)] Loss: 0.528829
# DEBUG:trainer:Train Epoch: 73 [90/152 (59%)] Loss: 0.409041
# DEBUG:trainer:Train Epoch: 73 [95/152 (62%)] Loss: 0.651515
# DEBUG:trainer:Train Epoch: 73 [100/152 (66%)] Loss: 0.522144
# DEBUG:trainer:Train Epoch: 73 [105/152 (69%)] Loss: 0.484661
# DEBUG:trainer:Train Epoch: 73 [110/152 (72%)] Loss: 0.497387
# DEBUG:trainer:Train Epoch: 73 [115/152 (76%)] Loss: 0.402603
# DEBUG:trainer:Train Epoch: 73 [120/152 (79%)] Loss: 0.545132
# DEBUG:trainer:Train Epoch: 73 [125/152 (82%)] Loss: 0.512107
# DEBUG:trainer:Train Epoch: 73 [130/152 (86%)] Loss: 0.660983
# DEBUG:trainer:Train Epoch: 73 [135/152 (89%)] Loss: 0.482530
# DEBUG:trainer:Train Epoch: 73 [140/152 (92%)] Loss: 0.612041
# DEBUG:trainer:Train Epoch: 73 [145/152 (95%)] Loss: 0.538485
# DEBUG:trainer:Train Epoch: 73 [150/152 (99%)] Loss: 0.515559
# INFO:trainer:    epoch          : 73
# INFO:trainer:    loss           : 0.5133193131340178
# INFO:trainer:    accuracy       : 0.7251233552631579
# INFO:trainer:    val_loss       : 0.47742756850579204
# INFO:trainer:    val_accuracy   : 0.7604166666666667
# INFO:trainer:    val_sensitivity: 0.90625
# INFO:trainer:    val_specificity: 0.576271186440678
# INFO:trainer:    val_MAcc       : 0.741260593220339
# INFO:trainer:    val_F1_score   : 0.8043143297380585
# DEBUG:trainer:Train Epoch: 74 [0/152 (0%)] Loss: 0.517938
# DEBUG:trainer:Train Epoch: 74 [5/152 (3%)] Loss: 0.582973
# DEBUG:trainer:Train Epoch: 74 [10/152 (7%)] Loss: 0.473207
# DEBUG:trainer:Train Epoch: 74 [15/152 (10%)] Loss: 0.419184
# DEBUG:trainer:Train Epoch: 74 [20/152 (13%)] Loss: 0.539158
# DEBUG:trainer:Train Epoch: 74 [25/152 (16%)] Loss: 0.475218
# DEBUG:trainer:Train Epoch: 74 [30/152 (20%)] Loss: 0.606652
# DEBUG:trainer:Train Epoch: 74 [35/152 (23%)] Loss: 0.516597
# DEBUG:trainer:Train Epoch: 74 [40/152 (26%)] Loss: 0.465766
# DEBUG:trainer:Train Epoch: 74 [45/152 (30%)] Loss: 0.515084
# DEBUG:trainer:Train Epoch: 74 [50/152 (33%)] Loss: 0.449113
# DEBUG:trainer:Train Epoch: 74 [55/152 (36%)] Loss: 0.386120
# DEBUG:trainer:Train Epoch: 74 [60/152 (39%)] Loss: 0.594388
# DEBUG:trainer:Train Epoch: 74 [65/152 (43%)] Loss: 0.471449
# DEBUG:trainer:Train Epoch: 74 [70/152 (46%)] Loss: 0.538079
# DEBUG:trainer:Train Epoch: 74 [75/152 (49%)] Loss: 0.519828
# DEBUG:trainer:Train Epoch: 74 [80/152 (53%)] Loss: 0.480442
# DEBUG:trainer:Train Epoch: 74 [85/152 (56%)] Loss: 0.468431
# DEBUG:trainer:Train Epoch: 74 [90/152 (59%)] Loss: 0.585833
# DEBUG:trainer:Train Epoch: 74 [95/152 (62%)] Loss: 0.453280
# DEBUG:trainer:Train Epoch: 74 [100/152 (66%)] Loss: 0.618464
# DEBUG:trainer:Train Epoch: 74 [105/152 (69%)] Loss: 0.446497
# DEBUG:trainer:Train Epoch: 74 [110/152 (72%)] Loss: 0.396966
# DEBUG:trainer:Train Epoch: 74 [115/152 (76%)] Loss: 0.483234
# DEBUG:trainer:Train Epoch: 74 [120/152 (79%)] Loss: 0.614047
# DEBUG:trainer:Train Epoch: 74 [125/152 (82%)] Loss: 0.557649
# DEBUG:trainer:Train Epoch: 74 [130/152 (86%)] Loss: 0.517144
# DEBUG:trainer:Train Epoch: 74 [135/152 (89%)] Loss: 0.463856
# DEBUG:trainer:Train Epoch: 74 [140/152 (92%)] Loss: 0.552973
# DEBUG:trainer:Train Epoch: 74 [145/152 (95%)] Loss: 0.506976
# DEBUG:trainer:Train Epoch: 74 [150/152 (99%)] Loss: 0.546871
# INFO:trainer:    epoch          : 74
# INFO:trainer:    loss           : 0.5101882780068799
# INFO:trainer:    accuracy       : 0.731702302631579
# INFO:trainer:    val_loss       : 0.46752385181539197
# INFO:trainer:    val_accuracy   : 0.7585784313725491
# INFO:trainer:    val_sensitivity: 0.9340277777777778
# INFO:trainer:    val_specificity: 0.538135593220339
# INFO:trainer:    val_MAcc       : 0.7360816854990584
# INFO:trainer:    val_F1_score   : 0.8078078078078079
# INFO:trainer:Validation performance didn't improve for 20 epochs. Training stops.
# === HOÀN THÀNH TRAINING ===
# Model tốt nhất được lưu tại:
# /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/simple_cnn/models/Physionet_simple_cnn/0124_062138/model_best.pth
#
# Đã lưu biểu đồ: loss_curve.png, accuracy_curve.png, f1_curve.png

# %%
base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
if base_dir.exists():
        latest_run = max(base_dir.iterdir(), key=os.path.getmtime)
        best_model_path = latest_run / "model_best.pth"

        validation_fea_path = str(DATASET_PATH / "logmel_features_validation.h5")
        validation_label_csv = str(DATASET_PATH / "label_validation.csv")  # Đảm bảo file này tồn tại!

        if Path(validation_fea_path).exists() and Path(validation_label_csv).exists():
            test_model(current_config, best_model_path, validation_fea_path, validation_label_csv)
        else:
            print("Không tìm thấy file validation .h5 hoặc label_validation.csv → Bỏ qua phần test.")

        size_bytes = os.path.getsize(best_model_path)
        size_mb = size_bytes / (1024 * 1024)

        print(f"Model size: {size_mb:.2f} MB")

else:
    print("Không tìm thấy thư mục saved models.")
# Out:
# weights_only=True failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.ConfigParser was not an allowed global by default. Please use `torch.serialization.add_safe_globals([__main__.ConfigParser])` or the `torch.serialization.safe_globals([__main__.ConfigParser])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Loaded with weights_only=False (full checkpoint)
#
# === MODEL ARCHITECTURE ===
# simple_cnn(
#   (conv1): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (output): Linear(in_features=16, out_features=2, bias=True)
# )
# Trainable parameters: 1330
#
# Số tham số huấn luyện được: 1,330
#
# === KIỂM TRA FORWARD PASS ===
# Input shape: (B, 128, 333)
# Output shape: torch.Size([2, 2]) → OK
#
# === DEBUG: SAMPLE FEATURES ===
# Sample 0: shape = torch.Size([128, 333]), label = 1
# Sample 1: shape = torch.Size([128, 333]), label = 1
# Sample 2: shape = torch.Size([128, 333]), label = 1
# Sample 3: shape = torch.Size([128, 333]), label = 1
# Sample 4: shape = torch.Size([128, 333]), label = 1
#
# === ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===
#
# Kết quả đánh giá:
#     loss: 0.6653
#     accuracy: 0.5947
#     sensitivity: 0.7067
#     specificity: 0.4834
#     MAcc: 0.5951
#     F1_score: 0.6347
#
# Đã lưu kết quả tại: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/simple_cnn/models/Physionet_simple_cnn/0124_062138/test_on_validation_set_metrics.csv
# Model size: 0.17 MB
