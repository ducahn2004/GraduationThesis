# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import numpy as np
from torch.utils.data import DataLoader, Sampler
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision.utils import make_grid
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    balanced_accuracy_score,
    matthews_corrcoef
)

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
sys.path.append(str(DATASET_PATH))

# %% [markdown]
# # Load Data

# %%
N_MFCC = 39
TIME_FRAME = 333

# %% [markdown]
# ## HeartSoundDataSet

# %%
def spec_augment(spec, F=6, T=25, num_masks=2):
    """SpecAugment cho MFCC"""
    cloned = spec.clone()
    num_mel_channels, num_frames = cloned.shape[-2:]

    # Frequency masking
    for _ in range(num_masks):
        f = np.random.randint(0, F)
        f0 = np.random.randint(0, num_mel_channels - f)
        cloned[..., f0:f0+f, :] = cloned[..., f0:f0+f, :].mean()

    # Time masking
    for _ in range(num_masks):
        t = np.random.randint(0, T)
        t0 = np.random.randint(0, num_frames - t)
        cloned[..., :, t0:t0+t] = 0

    return cloned

# %%
import numpy as np
import h5py
import random
import torch
from pathlib import Path
import librosa  # cần import để tính delta

EPS = 1e-8

def standard_normal_variate(data):
    """Chuẩn hóa Z-score trên toàn bộ tensor."""
    mean = np.mean(data)
    std = np.std(data) + EPS
    return (data - mean) / std

class HeartSoundDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 fea_path: str,              # đường dẫn file .h5
                 labels: pd.DataFrame,       # DataFrame với cột 'filename' và 'label'
                 duration: int = 5,          # giây
                 training: bool = True,
                 delta: bool = False,
                 norm: bool = True):
        self._fea_path = fea_path
        self._h5database = None
        self._labels = labels.reset_index(drop=True)
        self._colname = ['filename', 'label']
        self._len = len(self._labels)
        self._duration = duration
        self._delta = delta
        self.train = training
        self.hop_length = 15  # ms
        self.norm = norm

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
      row = self._labels.iloc[idx]
      filename = row['filename']
      target_bin = row['label']

      # Lấy key từ stem của filename
      key = Path(filename).stem if '/' in str(filename) else filename

      # Mở HDF5 nếu chưa mở
      if self._h5database is None:
          self._h5database = h5py.File(self._fea_path, 'r')

      if key not in self._h5database:
          available = list(self._h5database.keys())[:10]
          raise KeyError(f"Key '{key}' not found in HDF5. Sample keys: {available}")

      # Load feature từ HDF5
      feature = self._h5database[key][()]  # (mel_bins, T) hoặc (C, mel_bins, T)

      # Đảm bảo feature là 3D: (C, H, W)
      if feature.ndim == 2:
          feature = feature[np.newaxis, :, :]  # → (1, mel_bins, T)
      elif feature.ndim != 3:
          raise ValueError(f"Unexpected shape {feature.shape} for key '{key}'")

      # Chuẩn hóa toàn bộ tensor (nếu bật)
      if self.norm:
          feature = standard_normal_variate(feature)

      # Lấy shape hiện tại
      channels, mel_bins, num_frames = feature.shape

      # Tính độ dài mong muốn (frames)
      cycle_len = int(self._duration * 1000 / self.hop_length)

      # Crop hoặc pad để đạt đúng cycle_len
      if num_frames >= cycle_len:
          if self.train:
              #feature_tensor = spec_augment(feature_tensor, F=5, T=30, num_masks=1)
              start_ind = random.randint(0, num_frames - cycle_len)
          else:
              start_ind = (num_frames - cycle_len) // 2
          feature = feature[:, :, start_ind:start_ind + cycle_len]
      elif num_frames < cycle_len:
          pad_width = ((0, 0), (0, 0), (0, cycle_len - num_frames))
          feature = np.pad(feature, pad_width, mode='wrap')

      # === Fix quan trọng cho model gốc: Làm cho tensor luôn là 3D (mel_bins, num_frames) ===
      feature_tensor = torch.from_numpy(feature).float()  # (C, mel_bins, T)

      if self.train and np.random.rand() < 0.5:
          feature_tensor = spec_augment(feature_tensor,
                                  F=2,              # giảm từ 4 → 2 (mask tần số nhỏ hơn)
                                  T=10,             # giảm từ 15 → 10 (mask thời gian ngắn hơn)
                                  num_masks=1)

      if channels > 1:  # Có delta → C=3
          # Ghép 3 channels vào chiều mel_bins → (3 * mel_bins, T) = (384, T)
          # Model sẽ view thành (B, 3, 128, T) trong forward
          feature_tensor = feature_tensor.view(channels * mel_bins, -1)  # → (384, T)
      else:
          # Không delta → squeeze về (mel_bins, T) = (128, T)
          feature_tensor = feature_tensor.squeeze(0)

      return feature_tensor, torch.tensor(target_bin, dtype=torch.long)

    def __del__(self):
        """Đóng file HDF5 khi object bị hủy (tốt cho quản lý tài nguyên)."""
        if self._h5database is not None:
            self._h5database.close()

# %% [markdown]
# ## MinimumOccupancySampler

# %%
class MinimumOccupancySampler(Sampler):
    """
        samples at least one instance from each class sequentially
    """
    def __init__(self, labels, sampling_mode='over', random_state=None):
        #data_samples = labels.shape
        data_samples = len(labels)
        n_labels = len(np.unique(labels))
        label_to_idx_list, label_to_length = [], []
        self.random_state = np.random.RandomState(seed=random_state)
        for lb_idx in range(n_labels):
            label_indexes = np.where(labels == lb_idx)[0]
            self.random_state.shuffle(label_indexes)
            label_to_length.append(len(label_indexes))
            label_to_idx_list.append(label_indexes)

        self.longest_seq = max(label_to_length)
        self.data_source = np.empty((self.longest_seq, len(label_to_length)), dtype=int)
        # Each column represents one "single instance per class" data piece
        for ix, leng in enumerate(label_to_length):
            self.data_source[:leng, ix] = label_to_idx_list[ix]
        self.label_to_length = label_to_length
        self.label_to_idx_list = label_to_idx_list

        if sampling_mode == 'same':
            self.data_length = data_samples
        elif sampling_mode == 'over':  # Sample all items
            self.data_length = int(np.prod(self.data_source.shape))

    def _resample(self):
        for ix, leng in enumerate(self.label_to_length):
            leftover = self.longest_seq - leng
            random_idxs = np.random.randint(leng, size=leftover)
            self.data_source[leng:, ix] = self.label_to_idx_list[ix][random_idxs]

    def __iter__(self):
        self._resample()
        n_samples = len(self.data_source)
        random_indices = self.random_state.permutation(n_samples)
        data = np.concatenate(
            self.data_source[random_indices])[:self.data_length]
        return iter(data)

    def __len__(self):
        return self.data_length

# %% [markdown]
# ## HeartSoundDataLoader

# %%
class BaseDataLoader(DataLoader):
    """
    Base class for all data loaders
    """
    def __init__(self, dataset, batch_size, shuffle, validation_split, num_workers, collate_fn=default_collate, sampler_type=None):
        self.validation_split = validation_split
        self.shuffle = shuffle

        self.batch_idx = 0
        self.n_samples = len(dataset)
        self.sampler_type = sampler_type
        self.sampler, self.valid_sampler = self._split_sampler(self.validation_split)
        self.init_kwargs = {
            'dataset': dataset,
            'batch_size': batch_size,
            'shuffle': self.shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.sampler, **self.init_kwargs)

    def _split_sampler(self, split):
        if split == 0.0:
            return None, None

        idx_full = np.arange(self.n_samples)

        np.random.seed(0)
        np.random.shuffle(idx_full)

        if isinstance(split, int):
            assert split > 0
            assert split < self.n_samples, "validation set size is configured to be larger than entire dataset."
            len_valid = split
        else:
            len_valid = int(self.n_samples * split)

        valid_idx = idx_full[0:len_valid]
        train_idx = np.delete(idx_full, np.arange(0, len_valid))
        if self.sampler_type == 'MinimumOccupancySampler':
            train_sampler = MinimumOccupancySampler(np.stack(self.label_df.iloc[train_idx]['label']),sampling_mode='same', random_state=100)
        else:
            train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        # turn off shuffle option which is mutually exclusive with sampler
        self.shuffle = False
        self.n_samples = len(train_idx)

        return train_sampler, valid_sampler
    '''
    def split_validation(self):
        if self.valid_sampler is None:
            return None
        else:
            return DataLoader(sampler=self.valid_sampler, **self.init_kwargs)
    '''
    def split_validation(self):
        return DataLoader(
            dataset=self.val_dataset,
            batch_size=self.init_kwargs['batch_size'],
            shuffle=False,
            num_workers=self.init_kwargs['num_workers']
        )

# %%
class HeartSoundDataLoader(DataLoader):
    def __init__(self,
                 fea_path,
                 label_df,
                 duration,
                 batch_size,
                 delta=False,
                 norm=False,
                 shuffle=True,
                 validation_split=0.0,
                 num_workers=1,
                 training=True,
                 collate_fn=None):

        if training:
            # --- ĐOẠN SỬA ĐỔI ĐỂ CHỐNG DATA LEAKAGE ---
            # 1. Tạo cột base_id bằng cách tách bỏ phần '_augX' trong tên file
            # Ví dụ: 'a0001_aug0' -> 'a0001'
            label_df['base_id'] = label_df['filename'].apply(lambda x: Path(x).stem.split('_aug')[0])

            # 2. Lấy danh sách các ID duy nhất (mỗi bệnh nhân chỉ xuất hiện 1 lần trong danh sách này)
            unique_ids = label_df['base_id'].unique()

            # 3. Chia Train/Val dựa trên danh sách ID duy nhất này
            # Điều này đảm bảo tất cả các bản augment của cùng 1 người sẽ nằm cùng 1 tập
            train_ids, val_ids = train_test_split(unique_ids, test_size=validation_split, random_state=100)

            # 4. Lọc lại DataFrame gốc dựa trên danh sách ID đã chia
            self.train_df = label_df[label_df['base_id'].isin(train_ids)].copy()
            self.val_df = label_df[label_df['base_id'].isin(val_ids)].copy()

            # 5. Xóa cột phụ base_id để tránh ảnh hưởng đến các lớp khác
            self.train_df.drop(columns=['base_id'], inplace=True)
            self.val_df.drop(columns=['base_id'], inplace=True)
            # ------------------------------------------

            # Giữ nguyên logic khởi tạo Sampler và Dataset
            self.train_sampler = MinimumOccupancySampler(np.stack(self.train_df['label']), sampling_mode='same', random_state=100, )
            self.val_dataset = HeartSoundDataSet(fea_path, self.val_df, duration=duration, training=False, delta=delta, norm=norm)

        else:
            self.train_df = label_df
            self.train_sampler = None

        self.dataset = HeartSoundDataSet(fea_path, self.train_df, duration=duration,
                                         training=training, delta=delta, norm=norm)

        self.init_kwargs = {
            'batch_size': batch_size,
            'shuffle': False if self.train_sampler is not None else shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.train_sampler,
                         dataset=self.dataset,
                         **self.init_kwargs)

    def split_validation(self):
        return DataLoader(dataset=self.val_dataset, **self.init_kwargs)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_balanced.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("MFCC (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0001_aug0', 'a0001_aug1', 'a0001_aug2', 'a0002', 'a0002_aug0', 'a0002_aug1', 'a0002_aug2', 'a0003', 'a0003_aug0']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 1 1 1]
# Value range: -7.194 ~ 2.585

# %% [markdown]
# # ConfigParser

# %%
# parse_config.py
import os
import logging
from pathlib import Path
from datetime import datetime
import argparse
import collections
import importlib.util

class ConfigParser:
    def __init__(self, config_dict, resume=None, modification=None, run_id=None):
        self._config = config_dict
        self.resume = resume

        # Apply CLI modifications
        if modification:
            for key_path, value in modification.items():
                keys = key_path.split(';')
                d = self._config
                for k in keys[:-1]:
                    d = d[k]
                d[keys[-1]] = value

        # Setup save and log directories
        save_dir = Path(self.config['trainer']['save_dir'])
        exper_name = self.config['name']
        if run_id is None:
            run_id = datetime.now().strftime(r'%m%d_%H%M%S')
        self._save_dir = save_dir / 'models' / exper_name / run_id
        self._log_dir = save_dir / 'log' / exper_name / run_id

        self.save_dir.mkdir(parents=True, exist_ok=True)
        self.log_dir.mkdir(parents=True, exist_ok=True)

        # Optional: setup logging
        # setup_logging(self.log_dir)

    @classmethod
    def from_args(cls, parser, options=None):
        """
        parser: argparse.ArgumentParser đã được add_argument xong
        options: list các CustomArgs để override
        """
        if options is None:
            options = []

        # Parse arguments (an toàn cho cả terminal và notebook)
        args = parser.parse_args()

        # Xử lý device
        if args.device is not None:
            os.environ["CUDA_VISIBLE_DEVICES"] = args.device

        # Xử lý resume
        if args.resume is not None:
            resume = Path(args.resume)
            cfg_fname = resume.parent / 'config.py'  # hoặc .json nếu bạn dùng cả 2
        else:
            resume = None
            assert args.config is not None, "Phải chỉ định -c config.py"
            cfg_fname = Path(args.config)

        # Đọc config từ file .py
        if not cfg_fname.exists():
            raise FileNotFoundError(f"Không tìm thấy config file: {cfg_fname}")

        if cfg_fname.suffix == '.py':
            spec = importlib.util.spec_from_file_location("config_module", cfg_fname)
            config_module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(config_module)
            if not hasattr(config_module, 'config'):
                raise ValueError(f"File {cfg_fname} phải định nghĩa biến 'config'")
            config_dict = config_module.config
        else:
            raise ValueError("Chỉ hỗ trợ file config .py")

        # Parse custom CLI overrides
        CustomArgs = collections.namedtuple('CustomArgs', 'flags type target')
        modification = {}
        for opt in options:
            for flag in opt.flags:
                arg_name = flag.lstrip('-').replace('-', '_')
                if hasattr(args, arg_name) and getattr(args, arg_name) is not None:
                    modification[opt.target] = opt.type(getattr(args, arg_name))

        return cls(config_dict, resume, modification)

    def init_obj(self, name, module, *args, **kwargs):
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def init_ftn(self, name, module, *args, **kwargs):
        from functools import partial
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def __getitem__(self, name):
        return self.config[name]

    def get_logger(self, name, verbosity=2):
        logger = logging.getLogger(name)
        logger.setLevel({0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}[verbosity])
        return logger

    @property
    def config(self):
        return self._config

    @property
    def save_dir(self):
        return self._save_dir

    @property
    def log_dir(self):
        return self._log_dir

# %% [markdown]
# # Logging

# %%
def mixup_data(x, y, alpha=0.2):
    """Mixup augmentation"""
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %% [markdown]
# #Loss

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=1.5):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        weight = torch.tensor(
            [self.alpha, 1 - self.alpha], device=inputs.device
        ).float()   # [w_normal, w_abnormal]
        ce_loss = F.cross_entropy(inputs, targets, weight=weight, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean()

# %%
class CBFocalLoss(nn.Module):
    def __init__(self, samples_per_class, beta=0.9999, gamma=2.0):
        super().__init__()
        effective_num = 1.0 - np.power(beta, samples_per_class)
        weights = (1.0 - beta) / np.array(effective_num)
        self.weights = weights / np.sum(weights) * len(samples_per_class)
        self.gamma = gamma

    def forward(self, inputs, targets):
        weights = torch.tensor(self.weights, device=inputs.device).float()
        ce_loss = F.cross_entropy(inputs, targets, weight=weights, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# Sử dụng:
# samples_per_class = [số_mẫu_abnormal, số_mẫu_normal]

# %%
class WeightedCELoss(nn.Module):
    """
    Weighted Cross Entropy Loss
    """
    def __init__(self, weights):
        super().__init__()
        self.register_buffer(
            "weights", torch.tensor(weights, dtype=torch.float)
        )

    def forward(self, logits, target):
        return F.cross_entropy(
            logits,
            target,
            weight=self.weights
        )

# %%
class CostSensitiveLoss(nn.Module):
    """
    Cost-sensitive Cross Entropy
    FN (abnormal → normal) bị phạt nặng hơn FP
    """
    def __init__(self, fn_cost=2.5, fp_cost=1.0):
        super().__init__()
        self.fn_cost = fn_cost
        self.fp_cost = fp_cost

    def forward(self, logits, target):
        weights = torch.tensor(
            [self.fp_cost, self.fn_cost],
            device=logits.device
        )

        return F.cross_entropy(
            logits,
            target,
            weight=weights
        )

# %%
class CombinedLoss(nn.Module):
    def __init__(self, alpha=0.7, gamma=2.5, label_smoothing=0.1, focal_weight=0.7):
        self.focal_loss = ImprovedFocalLoss(alpha, gamma, label_smoothing)
        self.ce_loss = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# %%
import torch.nn.functional as F


def nll_loss(output, target):
    return F.nll_loss(output, target)

def ce_loss(output, target):
    return F.cross_entropy(output, target)

def focal_loss(output, target, alpha=0.75, gamma=2.0):
    return FocalLoss(alpha=alpha, gamma=gamma)(output, target)

# Dùng khi tỷ lệ abnormal ≪ normal.
def weighted_ce_loss(output, target, weights):
    return WeightedCELoss(weights)(output, target)

# Đặc biệt phù hợp bài toán y sinh, nơi bỏ sót bệnh (FN) nguy hiểm hơn FP.
def cost_sensitive_loss(output, target, fn_cost=2.5, fp_cost=1.0):
    return CostSensitiveLoss(fn_cost, fp_cost)(output, target)

LOSS_REGISTRY = {
    "ce_loss": lambda: nn.CrossEntropyLoss(),
    "focal_loss": lambda: FocalLoss(alpha=0.75, gamma=2.0),
    "cost_sensitive_loss": lambda: CostSensitiveLoss(fn_cost=2.5, fp_cost=1.0),
    "weighted_ce_loss": lambda weights: WeightedCELoss(weights),
}

# %% [markdown]
# # Metric

# %%
import torch


def accuracy(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
    return correct / len(target)

import torch

def sensitivity(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()
    return tp / (tp + fn + eps)


def f1_score(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)

        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fp = torch.sum((pred == positive_class) & (target != positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()

        precision = tp / (tp + fp + eps)
        recall    = tp / (tp + fn + eps)

        f1 = 2 * precision * recall / (precision + recall + eps)

    return f1

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

# Warmup scheduler
class WarmupCosineScheduler:
    """
    Warmup tuyến tính + Cosine decay một chiều (KHÔNG restart).
    Thêm get_last_lr() để tương thích với Trainer.
    """
    def __init__(self, optimizer, warmup_epochs=5, total_epochs=120, lr_min=1e-6):
        self.optimizer      = optimizer
        self.warmup_epochs  = warmup_epochs
        self.total_epochs   = total_epochs
        self.lr_min         = lr_min
        self.base_lr        = optimizer.param_groups[0]['lr']
        self._current_lr    = self.base_lr

    def step(self, epoch):
        if epoch < self.warmup_epochs:
            # Tuyến tính từ lr_min → base_lr
            lr = self.lr_min + (self.base_lr - self.lr_min) * (epoch + 1) / self.warmup_epochs
        else:
            # Cosine một chiều: base_lr → lr_min (KHÔNG restart)
            progress = (epoch - self.warmup_epochs) / max(
                self.total_epochs - self.warmup_epochs, 1
            )
            progress = min(progress, 1.0)           # clamp tránh vượt 1.0
            lr = self.lr_min + (self.base_lr - self.lr_min) * 0.5 * (
                1.0 + np.cos(np.pi * progress)
            )
        self._current_lr = lr
        for pg in self.optimizer.param_groups:
            pg['lr'] = lr
        return lr

    def get_last_lr(self):
        return [self._current_lr]

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif val_loss > self.best_score - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        else:
            self.best_score = val_loss
            self.counter = 0
        return False

# %% [markdown]
# # Model

# %%
import torch.nn as nn
import numpy as np
from abc import abstractmethod


class BaseModel(nn.Module):
    """
    Base class for all models
    """
    @abstractmethod
    def forward(self, *inputs):
        """
        Forward pass logic

        :return: Model output
        """
        raise NotImplementedError

    def __str__(self):
        """
        Model prints with number of trainable parameters
        """
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        params = sum([np.prod(p.size()) for p in model_parameters])
        return super().__str__() + '\nTrainable parameters: {}'.format(params)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# functions of initializing layers
def init_layer(layer):
    """Initialize a Linear or Convolutional layer."""
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, 'bias'):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)

def init_bn(bn):
    """Initialize a Batchnorm layer."""
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.)

def init_rnn(rnn):
    """init_rnn
    Initialized RNN weights, independent of type GRU/LSTM/RNN
    :param rnn: the rnn model
    """
    for name, param in rnn.named_parameters():
        if 'bias' in name:
            nn.init.constant_(param, 0.0)
        elif 'weight' in name:
            nn.init.xavier_uniform_(param)

def reset_parameters(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            init_layer(module)
        elif isinstance(module, nn.Linear):
            init_layer(module)
        elif isinstance(module, nn.BatchNorm2d):
            init_bn(module)
        elif isinstance(module, nn.LSTM):
            init_rnn(module)

# %% [markdown]
# ## Simple CNN Block

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
class DSConvBlock(nn.Module):
    """Depthwise Separable Conv — đơn giản, dễ quantize INT8."""
    def __init__(self, in_ch, out_ch, stride=1):
        super().__init__()
        self.dw  = nn.Conv2d(in_ch, in_ch, 3, stride, 1, groups=in_ch, bias=False)
        self.pw  = nn.Conv2d(in_ch, out_ch, 1, bias=False)
        self.bn  = nn.BatchNorm2d(out_ch)
        self.act = nn.ReLU6(inplace=True)

    def forward(self, x):
        return self.act(self.bn(self.pw(self.dw(x))))


class LiteSEBlock(nn.Module):
    """SE Block thu gọn: channels=64, reduction=8 → chỉ 1,024 params."""
    def __init__(self, channels, reduction=8):
        super().__init__()
        mid = max(channels // reduction, 4)
        self.gap = nn.AdaptiveAvgPool2d(1)
        self.fc  = nn.Sequential(
            nn.Linear(channels, mid),
            nn.ReLU(inplace=True),
            nn.Linear(mid, channels),
            nn.Sigmoid()
        )

    def forward(self, x):
        B, C, _, _ = x.shape
        s = self.gap(x).view(B, C)
        return x * self.fc(s).view(B, C, 1, 1)

# %%
class LightweightHeartSoundCNN(nn.Module):
    def __init__(self, num_classes=2, in_channel=1, dropout=0.5):
        super().__init__()
        self.stem = nn.Sequential(
            nn.Conv2d(in_channel, 24, kernel_size=(5, 5), stride=1, padding=2, bias=False),
            nn.BatchNorm2d(24),
            nn.ReLU6(inplace=True),
            nn.Dropout2d(0.1)
        )
        self.stage1 = nn.Sequential(
            DSConvBlock(24, 32),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.stage2 = nn.Sequential(
            DSConvBlock(32, 48),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        self.stage3   = DSConvBlock(48, 48)
        self.se       = LiteSEBlock(48, reduction=4)
        self.gap      = nn.AdaptiveAvgPool2d(1)

        # Bổ sung các lớp còn thiếu để forward không lỗi
        self.bn_head  = nn.BatchNorm1d(48)
        self.dropout_layer = nn.Dropout(dropout)

        self.classifier = nn.Sequential(
            nn.Linear(48, 16),
            nn.ReLU6(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(16, num_classes)
        )

        # Gọi hàm khởi tạo trọng số
        self._init_weights()

    # PHẢI THỤT LỀ VÀO TRONG CLASS
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(m, nn.BatchNorm2d) or isinstance(m, nn.BatchNorm1d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def forward(self, x):
        # x: (B, 39, 333)
        if x.dim() == 3:
            x = x.unsqueeze(1)          # (B, 1, 39, 333)

        x = self.stem(x)
        x = self.stage1(x)
        x = self.stage2(x)
        x = self.stage3(x)
        x = self.se(x)
        x = self.gap(x).flatten(1)      # (B, 48)

        x = self.bn_head(x)
        x = self.dropout_layer(x)
        return self.classifier(x)

    def __str__(self):
        params = sum(p.numel() for p in self.parameters() if p.requires_grad)
        return super().__str__() + f'\nTrainable parameters: {params:,}'

# %% [markdown]
# ## Deeper CNN model, VGG like structure

# %% [markdown]
# ## RNN - BiLTSM

# %% [markdown]
# ## CRNN

# %% [markdown]
# # Config

# %% [markdown]
# ## CNN

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
from pathlib import Path

config_light_cnn = {
    "name": "Physionet_lightweight_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "LightweightHeartSoundCNN",
        "args": {
            "num_classes": 2,
            "in_channel": 1, #Declare channel
            "dropout": 0.5
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": True,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "AdamW",
        "args": {
            "lr": 1e-4, #2e-4
            "weight_decay": 1e-3, #0.0
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "combined_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "WarmupCosine",
        "args": {
            #"mode": "max",
            #"factor": 0.5,
            #"patience": 10, # Tránh giảm LR quá sớm khi model chưa kịp học
            #"min_lr": 5e-7
            "warmup_epochs": 10,
            "total_epochs": 100,
            "lr_min": 1e-6
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 150,
        "save_dir": str(PROJECT_PATH / "saved"/"lightweight_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_MAcc",
        "early_stop": 15,
        "tensorboard": True,
        "use_mixup": False,
        "mixup_alpha": 0.1,
        "gradient_clip": 1.0
    }
}

# %% [markdown]
# ## CRNN

# %% [markdown]
# ## LTSM

# %% [markdown]
# ## VGG

# %% [markdown]
# # Training

# %%
def prepare_device(n_gpu_use):
    """
    setup GPU device if available. get gpu device indices which are used for DataParallel
    """
    n_gpu = torch.cuda.device_count()
    if n_gpu_use > 0 and n_gpu == 0:
        print("Warning: There\'s no GPU available on this machine,"
              "training will be performed on CPU.")
        n_gpu_use = 0
    if n_gpu_use > n_gpu:
        print(f"Warning: The number of GPU\'s configured to use is {n_gpu_use}, but only {n_gpu} are "
              "available on this machine.")
        n_gpu_use = n_gpu
    device = torch.device('cuda:0' if n_gpu_use > 0 else 'cpu')
    list_ids = list(range(n_gpu_use))
    return device, list_ids

# %%
class MetricTracker:
    def __init__(self, *keys, writer=None):
        self.writer = writer
        self._data = pd.DataFrame(index=keys, columns=['total', 'counts', 'average'])
        self.reset()

    def reset(self):
        for col in self._data.columns:
            self._data[col].values[:] = 0

    def update(self, key, value, n=1):
        if self.writer is not None:
            self.writer.add_scalar(key, value)
        df = self._data

        df.loc[key, "total"] += value * n
        df.loc[key, "counts"] += n
        df.loc[key, "average"] = df.loc[key, "total"] / df.loc[key, "counts"]


    def avg(self, key):
        return self._data.average[key]

    def result(self):
        return dict(self._data.average)

# %%
def setup_logging(save_dir, log_config='logger/logger_config.json', default_level=logging.INFO):
    """
    Setup logging configuration
    """
    log_config = Path(log_config)
    if log_config.is_file():
        config = read_json(log_config)
        # modify logging paths based on run config
        for _, handler in config['handlers'].items():
            if 'filename' in handler:
                handler['filename'] = str(save_dir / handler['filename'])

        logging.config.dictConfig(config)
    else:
        print("Warning: logging configuration file is not found in {}.".format(log_config))
        logging.basicConfig(level=default_level)
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %%
import torch
from abc import abstractmethod
from numpy import inf

def safe_append(lst, value):
    lst.append(value if value is not None else np.nan)

class BaseTrainer:
    """
    Base class for all trainers
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config):
        self.config = config
        self.logger = config.get_logger('trainer', config['trainer']['verbosity'])

        self.model = model
        self.criterion = criterion
        self.metric_ftns = metric_ftns
        self.optimizer = optimizer

        cfg_trainer = config['trainer']
        self.epochs = cfg_trainer['epochs']
        self.save_period = cfg_trainer['save_period']
        self.monitor = cfg_trainer.get('monitor', 'off')

        # configuration to monitor model performance and save best
        if self.monitor == 'off':
            self.mnt_mode = 'off'
            self.mnt_best = 0
        else:
            self.mnt_mode, self.mnt_metric = self.monitor.split()
            assert self.mnt_mode in ['min', 'max']

            self.mnt_best = inf if self.mnt_mode == 'min' else -inf
            self.early_stop = cfg_trainer.get('early_stop', inf)
            if self.early_stop <= 0:
                self.early_stop = inf

        self.start_epoch = 1

        self.checkpoint_dir = config.save_dir

        self.history = {
            "epoch": [],
            "train_loss": [],
            "train_accuracy": [],
            "val_loss": [],
            "val_accuracy": [],
            "val_F1_score": [],
            "val_sensitivity": [],
            "val_specificity": [],
            "val_MAcc": []
        }


        self.history_path = Path(self.checkpoint_dir) / "metrics.csv"

        # setup visualization writer instance
        self.writer = TensorboardWriter(config.log_dir, self.logger, cfg_trainer['tensorboard'])

        if config.resume is not None:
            self._resume_checkpoint(config.resume)

    @abstractmethod
    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Current epoch number
        """
        raise NotImplementedError

    def train(self):
        """
        Full training logic
        """
        not_improved_count = 0
        for epoch in range(self.start_epoch, self.epochs + 1):
            result = self._train_epoch(epoch)

            # save logged informations into log dict
            log = {'epoch': epoch}
            log.update(result)

            # ===== GHI METRICS SAU MỖI EPOCH =====
            safe_append(self.history["epoch"], epoch)
            safe_append(self.history["train_loss"], log.get("loss"))
            safe_append(self.history["train_accuracy"], log.get("accuracy"))

            safe_append(self.history["val_loss"], log.get("val_loss"))
            safe_append(self.history["val_accuracy"], log.get("val_accuracy"))
            safe_append(self.history["val_F1_score"], log.get("val_F1_score"))
            safe_append(self.history["val_sensitivity"], log.get("val_sensitivity"))
            safe_append(self.history["val_specificity"], log.get("val_specificity"))
            safe_append(self.history["val_MAcc"], log.get("val_MAcc"))



            pd.DataFrame(self.history).to_csv(self.history_path, index=False)

            # print logged informations to the screen
            for key, value in log.items():
                self.logger.info('    {:15s}: {}'.format(str(key), value))

            # evaluate model performance according to configured metric, save best checkpoint as model_best
            best = False
            if self.mnt_mode != 'off':
                try:
                    # check whether model performance improved or not, according to specified metric(mnt_metric)
                    improved = (self.mnt_mode == 'min' and log[self.mnt_metric] <= self.mnt_best) or \
                               (self.mnt_mode == 'max' and log[self.mnt_metric] >= self.mnt_best)
                except KeyError:
                    self.logger.warning("Warning: Metric '{}' is not found. "
                                        "Model performance monitoring is disabled.".format(self.mnt_metric))
                    self.mnt_mode = 'off'
                    improved = False

                if improved:
                    self.mnt_best = log[self.mnt_metric]
                    not_improved_count = 0
                    best = True
                else:
                    not_improved_count += 1

                if not_improved_count > self.early_stop:
                    self.logger.info("Validation performance didn\'t improve for {} epochs. "
                                     "Training stops.".format(self.early_stop))
                    break

            if best:
                self._save_best_model(epoch)

    def _save_checkpoint(self, epoch, save_best=False):
        """
        Saving checkpoints

        :param epoch: current epoch number
        :param log: logging information of the epoch
        :param save_best: if True, rename the saved checkpoint to 'model_best.pth'
        """
        arch = type(self.model).__name__
        state = {
            'arch': arch,
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'monitor_best': self.mnt_best,
            'config': self.config
        }
        filename = str(self.checkpoint_dir / 'checkpoint-epoch{}.pth'.format(epoch))
        torch.save(state, filename)
        self.logger.info("Saving checkpoint: {} ...".format(filename))
        if save_best:
            best_path = str(self.checkpoint_dir / 'model_best.pth')
            torch.save(state, best_path)
            self.logger.info("Saving current best: model_best.pth ...")

    def _resume_checkpoint(self, resume_path):
        """
        Resume from saved checkpoints

        :param resume_path: Checkpoint path to be resumed
        """
        resume_path = str(resume_path)
        self.logger.info("Loading checkpoint: {} ...".format(resume_path))
        checkpoint = torch.load(resume_path)
        self.start_epoch = checkpoint['epoch'] + 1
        self.mnt_best = checkpoint['monitor_best']

        # load architecture params from checkpoint.
        if checkpoint['config']['arch'] != self.config['arch']:
            self.logger.warning("Warning: Architecture configuration given in config file is different from that of "
                                "checkpoint. This may yield an exception while state_dict is being loaded.")
        self.model.load_state_dict(checkpoint['state_dict'])

        # load optimizer state from checkpoint only when optimizer type is not changed.
        if checkpoint['config']['optimizer']['type'] != self.config['optimizer']['type']:
            self.logger.warning("Warning: Optimizer type given in config file is different from that of checkpoint. "
                                "Optimizer parameters not being resumed.")
        else:
            self.optimizer.load_state_dict(checkpoint['optimizer'])

        self.logger.info("Checkpoint loaded. Resume training from epoch {}".format(self.start_epoch))

    def _save_best_model(self, epoch):
      """
      Save only the best model according to monitoring metric
      """
      arch = type(self.model).__name__
      state = {
          'arch': arch,
          'epoch': epoch,
          'state_dict': self.model.state_dict(),
          'optimizer': self.optimizer.state_dict(),
          'monitor_best': self.mnt_best,
          'config': self.config
      }

      best_path = self.checkpoint_dir / 'model_best.pth'
      torch.save(state, best_path)

      self.logger.info(
          f"Saving new best model at epoch {epoch}: model_best.pth"
      )

# %%
from itertools import repeat

def inf_loop(data_loader):
    ''' wrapper function for endless data loader. '''
    for loader in repeat(data_loader):
        yield from loader

# %%
class Trainer(BaseTrainer):
    """
    Trainer class
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config, device,
                 data_loader, valid_data_loader=None, lr_scheduler=None, len_epoch=None):
        super().__init__(model, criterion, metric_ftns, optimizer, config)
        self.config = config
        self.device = device
        self.data_loader = data_loader
        if len_epoch is None:
            # epoch-based training
            self.len_epoch = len(self.data_loader)
        else:
            # iteration-based training
            self.data_loader = inf_loop(data_loader)
            self.len_epoch = len_epoch
        self.valid_data_loader = valid_data_loader
        self.do_validation = self.valid_data_loader is not None
        self.lr_scheduler = lr_scheduler

        cfg_trainer = config['trainer']
        self.use_mixup = cfg_trainer.get("use_mixup", False)
        self.mixup_alpha = cfg_trainer.get("mixup_alpha", 0.2)
        self.gradient_clip = cfg_trainer.get("gradient_clip", 0.0)

        self.log_step = int(np.sqrt(data_loader.batch_size))

        self.train_metrics = MetricTracker('loss', *[m.__name__ for m in self.metric_ftns], writer=self.writer)
        self.valid_metrics = MetricTracker('loss',*[m.__name__ for m in self.metric_ftns],
                                           'sensitivity', 'specificity', 'MAcc', 'F1_score',
                                           writer = self.writer)


    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains average loss and metric in this epoch.
        """
        self.model.train()
        self.train_metrics.reset()
        for batch_idx, (data, target) in enumerate(self.data_loader):
            data, target = data.to(self.device), target.to(self.device)

            self.optimizer.zero_grad()

            if self.use_mixup and np.random.rand() > 0.5:
                data, targets_a, targets_b, lam = mixup_data(data, target, alpha=self.mixup_alpha)
                output = self.model(data)
                loss = mixup_criterion(self.criterion, output, targets_a, targets_b, lam)
            else:
                output = self.model(data)
                loss = self.criterion(output, target)


            if not torch.isfinite(loss):
                print(f"NaN/Inf loss tại epoch {epoch}, batch {batch_idx} — skipping")
                self.optimizer.zero_grad()
                continue

            loss.backward()
            if self.gradient_clip > 0:
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.gradient_clip)


            total_norm = 0
            for p in self.model.parameters():
                if p.grad is not None:
                    total_norm += p.grad.data.norm(2).item() ** 2
            total_norm = total_norm ** 0.5
            if not np.isfinite(total_norm):
                print(f"NaN gradient tại epoch {epoch}, batch {batch_idx} — skipping")
                self.optimizer.zero_grad()
                continue


            self.optimizer.step()
            if hasattr(self, 'ema'):
                self.ema.update()


            self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
            self.train_metrics.update('loss', loss.item())
            for met in self.metric_ftns:
                self.train_metrics.update(met.__name__, met(output, target))

            if batch_idx % self.log_step == 0:
                self.logger.debug('Train Epoch: {} {} Loss: {:.6f}'.format(
                    epoch,
                    self._progress(batch_idx),
                    loss.item()))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

            if batch_idx == self.len_epoch:
                break
        log = self.train_metrics.result()

        if self.do_validation:
            val_log = self._valid_epoch(epoch)
            log.update(**{'val_'+k : v for k, v in val_log.items()})

        #if self.lr_scheduler is not None:
            #self.lr_scheduler.step()

        if self.lr_scheduler is not None:
            if isinstance(self.lr_scheduler, WarmupCosineScheduler):
                self.lr_scheduler.step(epoch - 1)   # epoch 1-based → 0-based
            elif isinstance(self.lr_scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                self.lr_scheduler.step(val_log.get('MAcc', val_log['loss']))
            else:
                self.lr_scheduler.step()
        return log

    def _valid_epoch(self, epoch):
        """
        Validate after training an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains information about validation
        """
        self.model.eval()
        self.valid_metrics.reset()
        val_pred_pos = 0
        val_pred_neg = 0
        val_condition_pos = 0
        val_condition_neg = 0
        val_TP = 0
        val_TN = 0
        val_FP = 0   # ← THÊM DÒNG NÀY
        val_FN = 0   # ← THÊM DÒNG NÀY
        val_correct = 0
        val_total = 0
        use_ema = hasattr(self, 'ema')
        if use_ema:
            self.ema.apply_shadow()
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(self.valid_data_loader):
                data, target = data.to(self.device), target.to(self.device)
                output = self.model(data.float())
                loss = self.criterion(output, target)

                _,indices = torch.max(output, 1)

                val_TP += ((indices == 1) & (target == 1)).sum().item()
                val_TN += ((indices == 0) & (target == 0)).sum().item()
                val_FP += ((indices == 1) & (target == 0)).sum().item()
                val_FN += ((indices == 0) & (target == 1)).sum().item()

                val_correct += (indices == target).sum().item()
                val_total   += target.size(0)

                self.writer.set_step((epoch - 1) * len(self.valid_data_loader) + batch_idx, 'valid')
                self.valid_metrics.update('loss', loss.item())
                for met in self.metric_ftns:
                    self.valid_metrics.update(met.__name__, met(output, target))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

        eps = 1e-8
        sensitivity = val_TP / (val_TP + val_FN + eps)
        specificity = val_TN / (val_TN + val_FP + eps)
        MAcc        = (sensitivity + specificity) / 2
        precision   = val_TP / (val_TP + val_FP + eps)
        F1_score    = 2 * precision * sensitivity / (precision + sensitivity + eps)

        self.valid_metrics.update('sensitivity', sensitivity)
        self.valid_metrics.update('specificity', specificity)
        self.valid_metrics.update('MAcc',MAcc)
        self.valid_metrics.update('F1_score', F1_score)

        # add histogram of model parameters to the tensorboard
        for name, p in self.model.named_parameters():
            self.writer.add_histogram(name, p, bins='auto')

        if use_ema:
            self.ema.restore()

        return self.valid_metrics.result()

    def _progress(self, batch_idx):
        base = '[{}/{} ({:.0f}%)]'
        if hasattr(self.data_loader, 'n_samples'):
            current = batch_idx * self.data_loader.batch_size
            total = self.data_loader.n_samples
        else:
            current = batch_idx
            total = self.len_epoch
        return base.format(current, total, 100.0 * current / total)

# %% [markdown]
# ## Simple Train

# %%
#current_config = config_cnn
current_config  = config_light_cnn
#current_config = config_crnn
#current_config = config_lstm
#current_config = config_vgg

# %%
class EMA:
    def __init__(self, model, decay=0.999):
        self.model = model
        self.decay = decay
        self.shadow = {k: v.clone() for k, v in model.state_dict().items()}

    def update(self):
        for k, v in self.model.state_dict().items():
            self.shadow[k] = self.decay * self.shadow[k] + (1 - self.decay) * v

    def apply_shadow(self):
        self._backup = {k: v.clone() for k, v in self.model.state_dict().items()}
        self.model.load_state_dict(self.shadow)

    def restore(self):
        self.model.load_state_dict(self._backup)

# %%
# === THÊM MỚI trước def main() ===
from torch.optim.swa_utils import AveragedModel, SWALR

def apply_swa(model, data_loader, device, swa_epochs=20, swa_lr=1e-4):
    """
    Chạy SWA: train thêm swa_epochs với lr thấp, lấy trung bình weights.
    Gọi sau trainer.train() hoàn tất.
    """
    swa_model = AveragedModel(model)
    swa_scheduler = SWALR(
        torch.optim.AdamW(model.parameters(), lr=swa_lr),
        swa_lr=swa_lr
    )
    model.train()
    for epoch in range(swa_epochs):
        for data, target in data_loader:
            data, target = data.to(device).float(), target.to(device)
            pred = model(data)
            loss = nn.CrossEntropyLoss(label_smoothing=0.05)(pred, target)
            loss.backward()
            swa_scheduler.step()
        swa_model.update_parameters(model)

    # Cập nhật BatchNorm statistics cho SWA model
    torch.optim.swa_utils.update_bn(data_loader, swa_model, device=device)
    return swa_model

# %%
import os
import argparse
import collections
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

def main(config):

# Tạo ConfigParser từ biến config hiện tại
  config_parser = ConfigParser(config)

  # Train chính thức
  data_loader = config_parser.init_obj('data_loader', globals())  # hoặc import module phù hợp
  valid_data_loader = data_loader.split_validation()

  model = config_parser.init_obj('arch', globals())
  print(model)

  device, device_ids = prepare_device(config_parser['n_gpu'])
  model = model.to(device)
  if len(device_ids) > 1:
      model = torch.nn.DataParallel(model, device_ids=device_ids)

  '''
  # ✅ Gamma thấp = ít amplify, phù hợp dataset balanced
  focal = FocalLoss(alpha=0.5, gamma=0.5)  # gamma: 2.0 → 0.5
  ce_smooth = nn.CrossEntropyLoss(label_smoothing=0.05)
  criterion = lambda p, t: 0.6 * ce_smooth(p, t) + 0.4 * focal(p, t)
  '''
  #criterion = FocalLoss(alpha=0.5, gamma=2.0)
  train_labels = pd.read_csv(config['data_loader']['full_label_csv'])['label']
  n_normal   = (train_labels == 0).sum()
  n_abnormal = (train_labels == 1).sum()

  # Inverse frequency weighting
  w_normal   = (n_normal + n_abnormal) / (2.0 * n_normal) * 1.5  # tăng penalty cho FP
  w_abnormal = (n_normal + n_abnormal) / (2.0 * n_abnormal)

  print(f"Class weights → Normal: {w_normal:.3f}, Abnormal: {w_abnormal:.3f}")

  criterion = nn.CrossEntropyLoss(
      weight=torch.tensor([w_normal, w_abnormal]).to(device).float(),
      label_smoothing=0.05
  )
  '''
  criterion = nn.CrossEntropyLoss(
      weight=torch.tensor([1.0, 1.0]).to(device),  # Index 0 (Normal): 1.0, Index 1 (Abnormal): 2.5
      label_smoothing=0.05
  )
  '''
  #criterion = LOSS_REGISTRY["weighted_ce_loss"]([1.0, 2.5])
  metrics = [
      accuracy,
      f1_score
  ]

  optimizer = config_parser.init_obj('optimizer', torch.optim, filter(lambda p: p.requires_grad, model.parameters()))
  #lr_scheduler = config_parser.init_obj('lr_scheduler', torch.optim.lr_scheduler, optimizer)
  lr_scheduler = WarmupCosineScheduler(
      optimizer    = optimizer,
      warmup_epochs= config['lr_scheduler']['args']['warmup_epochs'],   # = 5
      total_epochs = config['lr_scheduler']['args']['total_epochs'],    # = 120
      lr_min       = config['lr_scheduler']['args']['lr_min']           # = 1e-6
  )

  trainer = Trainer(
      model=model,
      criterion=criterion,
      metric_ftns=metrics,
      optimizer=optimizer,
      config=config_parser,
      device=device,
      data_loader=data_loader,
      valid_data_loader=valid_data_loader,
      lr_scheduler=lr_scheduler
  )

  trainer.train()

  base_dir = (Path(config_parser['trainer']['save_dir'])/ "models"/ config_parser['name'])

  if not base_dir.exists():
    print("Models directory was not found.")
    return

  # Lấy run (timestamp) mới nhất
  latest_run = max(base_dir.iterdir(), key=os.path.getmtime)

  best_model_path = latest_run / "model_best.pth"

  if best_model_path.exists():
    print("\n=== HOÀN THÀNH TRAINING ===")
    print("Model tốt nhất được lưu tại:")
    print(best_model_path)
  else:
    print("The file 'model_best.pth' was not found.")

  metrics_path = Path(config_parser.save_dir) / "metrics.csv"

  if metrics_path.exists():
    df = pd.read_csv(metrics_path)
    epochs = df["epoch"]
  else:
    print("The file 'metrics.csv' was not found. Unable to display training results.")

  # ===== LOSS =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training and Validation Loss")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "loss_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== ACCURACY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_accuracy"], label="Training Accuracy")
  plt.plot(epochs, df["val_accuracy"], label="Validation Accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training and Validation Accuracy")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "accuracy_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== F1-SCORE =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_F1_score"], label="Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.title("Validation F1-score across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "f1_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== SENSITIVITY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_sensitivity"], label="Validation Sensitivity")
  plt.xlabel("Epoch")
  plt.ylabel("Sensitivity")
  plt.title("Validation Sensitivity across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "sensitivity_curve.png", dpi=300)
  plt.show()
  plt.close()

# %%
if __name__ == "__main__":
    # Train model với config hiện tại
    main(current_config)

    # Sau khi train xong, tự động test trên tập validation riêng (nếu có file)
    base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
# Out:
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#     (3): Dropout2d(p=0.1, inplace=False)
#   )
#   (stage1): Sequential(
#     (0): DSConvBlock(
#       (dw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#       (pw): Conv2d(24, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU6(inplace=True)
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (stage2): Sequential(
#     (0): DSConvBlock(
#       (dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (pw): Conv2d(32, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU6(inplace=True)
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (stage3): DSConvBlock(
#     (dw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#     (pw): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): ReLU6(inplace=True)
#   )
#   (se): LiteSEBlock(
#     (gap): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=48, out_features=12, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=12, out_features=48, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (bn_head): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout_layer): Dropout(p=0.5, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=48, out_features=16, bias=True)
#     (1): ReLU6(inplace=True)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Trainable parameters: 8,574
# Class weights → Normal: 1.017, Abnormal: 0.984
# DEBUG:trainer:Train Epoch: 1 [0/66 (0%)] Loss: 1.588806
# DEBUG:trainer:Train Epoch: 1 [8/66 (12%)] Loss: 1.254205
# DEBUG:trainer:Train Epoch: 1 [16/66 (24%)] Loss: 1.536849
# DEBUG:trainer:Train Epoch: 1 [24/66 (36%)] Loss: 1.564638
# DEBUG:trainer:Train Epoch: 1 [32/66 (48%)] Loss: 1.335533
# DEBUG:trainer:Train Epoch: 1 [40/66 (61%)] Loss: 1.187401
# DEBUG:trainer:Train Epoch: 1 [48/66 (73%)] Loss: 1.190722
# DEBUG:trainer:Train Epoch: 1 [56/66 (85%)] Loss: 1.233297
# DEBUG:trainer:Train Epoch: 1 [64/66 (97%)] Loss: 0.921026
# INFO:trainer:    epoch          : 1
# INFO:trainer:    loss           : 1.226788827867219
# INFO:trainer:    accuracy       : 0.4973958333333333
# INFO:trainer:    f1_score       : 0.1540088432043088
# INFO:trainer:    val_loss       : 0.7964233615819145
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 0.9999999999804305
# INFO:trainer:    val_MAcc       : 0.49999999999021527
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 1: model_best.pth
# DEBUG:trainer:Train Epoch: 2 [0/66 (0%)] Loss: 1.215078
# DEBUG:trainer:Train Epoch: 2 [8/66 (12%)] Loss: 0.998990
# DEBUG:trainer:Train Epoch: 2 [16/66 (24%)] Loss: 1.204295
# DEBUG:trainer:Train Epoch: 2 [24/66 (36%)] Loss: 1.094805
# DEBUG:trainer:Train Epoch: 2 [32/66 (48%)] Loss: 1.038974
# DEBUG:trainer:Train Epoch: 2 [40/66 (61%)] Loss: 1.030319
# DEBUG:trainer:Train Epoch: 2 [48/66 (73%)] Loss: 0.999515
# DEBUG:trainer:Train Epoch: 2 [56/66 (85%)] Loss: 1.167036
# DEBUG:trainer:Train Epoch: 2 [64/66 (97%)] Loss: 1.152356
# INFO:trainer:    epoch          : 2
# INFO:trainer:    loss           : 1.0872137718128436
# INFO:trainer:    accuracy       : 0.5142045454545454
# INFO:trainer:    f1_score       : 0.18144269421633524
# INFO:trainer:    val_loss       : 0.7076457756407121
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 0.9999999999804305
# INFO:trainer:    val_MAcc       : 0.49999999999021527
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 2: model_best.pth
# DEBUG:trainer:Train Epoch: 3 [0/66 (0%)] Loss: 1.033612
# DEBUG:trainer:Train Epoch: 3 [8/66 (12%)] Loss: 1.102468
# DEBUG:trainer:Train Epoch: 3 [16/66 (24%)] Loss: 1.178749
# DEBUG:trainer:Train Epoch: 3 [24/66 (36%)] Loss: 1.062519
# DEBUG:trainer:Train Epoch: 3 [32/66 (48%)] Loss: 1.099393
# DEBUG:trainer:Train Epoch: 3 [40/66 (61%)] Loss: 0.862599
# DEBUG:trainer:Train Epoch: 3 [48/66 (73%)] Loss: 0.846103
# DEBUG:trainer:Train Epoch: 3 [56/66 (85%)] Loss: 1.094818
# DEBUG:trainer:Train Epoch: 3 [64/66 (97%)] Loss: 1.001062
# INFO:trainer:    epoch          : 3
# INFO:trainer:    loss           : 1.067030620394331
# INFO:trainer:    accuracy       : 0.517282196969697
# INFO:trainer:    f1_score       : 0.19308546428813994
# INFO:trainer:    val_loss       : 0.6857788913390216
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 0.9999999999804305
# INFO:trainer:    val_MAcc       : 0.49999999999021527
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 3: model_best.pth
# DEBUG:trainer:Train Epoch: 4 [0/66 (0%)] Loss: 1.266014
# DEBUG:trainer:Train Epoch: 4 [8/66 (12%)] Loss: 0.889835
# DEBUG:trainer:Train Epoch: 4 [16/66 (24%)] Loss: 0.854781
# DEBUG:trainer:Train Epoch: 4 [24/66 (36%)] Loss: 1.097802
# DEBUG:trainer:Train Epoch: 4 [32/66 (48%)] Loss: 1.192140
# DEBUG:trainer:Train Epoch: 4 [40/66 (61%)] Loss: 1.077040
# DEBUG:trainer:Train Epoch: 4 [48/66 (73%)] Loss: 1.205729
# DEBUG:trainer:Train Epoch: 4 [56/66 (85%)] Loss: 1.158388
# DEBUG:trainer:Train Epoch: 4 [64/66 (97%)] Loss: 1.035871
# INFO:trainer:    epoch          : 4
# INFO:trainer:    loss           : 1.0604995507182498
# INFO:trainer:    accuracy       : 0.5191761363636364
# INFO:trainer:    f1_score       : 0.20385346646559444
# INFO:trainer:    val_loss       : 0.6950898065286524
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 0.9999999999804305
# INFO:trainer:    val_MAcc       : 0.49999999999021527
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 4: model_best.pth
# DEBUG:trainer:Train Epoch: 5 [0/66 (0%)] Loss: 1.007569
# DEBUG:trainer:Train Epoch: 5 [8/66 (12%)] Loss: 0.993654
# DEBUG:trainer:Train Epoch: 5 [16/66 (24%)] Loss: 0.985668
# DEBUG:trainer:Train Epoch: 5 [24/66 (36%)] Loss: 1.107733
# DEBUG:trainer:Train Epoch: 5 [32/66 (48%)] Loss: 1.253325
# DEBUG:trainer:Train Epoch: 5 [40/66 (61%)] Loss: 0.900155
# DEBUG:trainer:Train Epoch: 5 [48/66 (73%)] Loss: 0.920972
# DEBUG:trainer:Train Epoch: 5 [56/66 (85%)] Loss: 1.220339
# DEBUG:trainer:Train Epoch: 5 [64/66 (97%)] Loss: 0.929738
# INFO:trainer:    epoch          : 5
# INFO:trainer:    loss           : 1.0232273954333682
# INFO:trainer:    accuracy       : 0.5239109848484849
# INFO:trainer:    f1_score       : 0.22561483997989668
# INFO:trainer:    val_loss       : 0.6726355429957894
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 0.9999999999804305
# INFO:trainer:    val_MAcc       : 0.49999999999021527
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 5: model_best.pth
# DEBUG:trainer:Train Epoch: 6 [0/66 (0%)] Loss: 0.938756
# DEBUG:trainer:Train Epoch: 6 [8/66 (12%)] Loss: 1.016003
# DEBUG:trainer:Train Epoch: 6 [16/66 (24%)] Loss: 1.025863
# DEBUG:trainer:Train Epoch: 6 [24/66 (36%)] Loss: 0.970513
# DEBUG:trainer:Train Epoch: 6 [32/66 (48%)] Loss: 1.533887
# DEBUG:trainer:Train Epoch: 6 [40/66 (61%)] Loss: 1.187836
# DEBUG:trainer:Train Epoch: 6 [48/66 (73%)] Loss: 0.908180
# DEBUG:trainer:Train Epoch: 6 [56/66 (85%)] Loss: 0.900515
# DEBUG:trainer:Train Epoch: 6 [64/66 (97%)] Loss: 1.035493
# INFO:trainer:    epoch          : 6
# INFO:trainer:    loss           : 0.9943269671815814
# INFO:trainer:    accuracy       : 0.5319602272727273
# INFO:trainer:    f1_score       : 0.24618421771944496
# INFO:trainer:    val_loss       : 0.6482022755286273
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 0.9999999999804305
# INFO:trainer:    val_MAcc       : 0.49999999999021527
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 6: model_best.pth
# DEBUG:trainer:Train Epoch: 7 [0/66 (0%)] Loss: 0.910033
# DEBUG:trainer:Train Epoch: 7 [8/66 (12%)] Loss: 1.008531
# DEBUG:trainer:Train Epoch: 7 [16/66 (24%)] Loss: 0.942354
# DEBUG:trainer:Train Epoch: 7 [24/66 (36%)] Loss: 0.892527
# DEBUG:trainer:Train Epoch: 7 [32/66 (48%)] Loss: 0.712521
# DEBUG:trainer:Train Epoch: 7 [40/66 (61%)] Loss: 0.859146
# DEBUG:trainer:Train Epoch: 7 [48/66 (73%)] Loss: 0.850347
# DEBUG:trainer:Train Epoch: 7 [56/66 (85%)] Loss: 0.930283
# DEBUG:trainer:Train Epoch: 7 [64/66 (97%)] Loss: 0.768551
# INFO:trainer:    epoch          : 7
# INFO:trainer:    loss           : 0.9478364577799132
# INFO:trainer:    accuracy       : 0.5321969696969697
# INFO:trainer:    f1_score       : 0.2550768472417729
# INFO:trainer:    val_loss       : 0.6238636041388792
# INFO:trainer:    val_accuracy   : 0.5074579831932774
# INFO:trainer:    val_f1_score   : 0.13419349508869743
# INFO:trainer:    val_sensitivity: 0.06569343065573552
# INFO:trainer:    val_specificity: 0.9921722113308773
# INFO:trainer:    val_MAcc       : 0.5289328209933064
# INFO:trainer:    val_F1_score   : 0.12244897831968161
# INFO:trainer:Saving new best model at epoch 7: model_best.pth
# DEBUG:trainer:Train Epoch: 8 [0/66 (0%)] Loss: 0.936233
# DEBUG:trainer:Train Epoch: 8 [8/66 (12%)] Loss: 0.987449
# DEBUG:trainer:Train Epoch: 8 [16/66 (24%)] Loss: 0.637413
# DEBUG:trainer:Train Epoch: 8 [24/66 (36%)] Loss: 0.825040
# DEBUG:trainer:Train Epoch: 8 [32/66 (48%)] Loss: 1.099399
# DEBUG:trainer:Train Epoch: 8 [40/66 (61%)] Loss: 0.732709
# DEBUG:trainer:Train Epoch: 8 [48/66 (73%)] Loss: 0.985386
# DEBUG:trainer:Train Epoch: 8 [56/66 (85%)] Loss: 1.023146
# DEBUG:trainer:Train Epoch: 8 [64/66 (97%)] Loss: 0.992088
# INFO:trainer:    epoch          : 8
# INFO:trainer:    loss           : 0.9078432204145374
# INFO:trainer:    accuracy       : 0.5454545454545454
# INFO:trainer:    f1_score       : 0.3025537168615524
# INFO:trainer:    val_loss       : 0.6140497712528005
# INFO:trainer:    val_accuracy   : 0.530435924369748
# INFO:trainer:    val_f1_score   : 0.20288713410508227
# INFO:trainer:    val_sensitivity: 0.11678832116575204
# INFO:trainer:    val_specificity: 0.9863013698437123
# INFO:trainer:    val_MAcc       : 0.5515448455047322
# INFO:trainer:    val_F1_score   : 0.2067851352806784
# INFO:trainer:Saving new best model at epoch 8: model_best.pth
# DEBUG:trainer:Train Epoch: 9 [0/66 (0%)] Loss: 0.768329
# DEBUG:trainer:Train Epoch: 9 [8/66 (12%)] Loss: 0.975624
# DEBUG:trainer:Train Epoch: 9 [16/66 (24%)] Loss: 0.819126
# DEBUG:trainer:Train Epoch: 9 [24/66 (36%)] Loss: 0.760835
# DEBUG:trainer:Train Epoch: 9 [32/66 (48%)] Loss: 0.881398
# DEBUG:trainer:Train Epoch: 9 [40/66 (61%)] Loss: 0.866074
# DEBUG:trainer:Train Epoch: 9 [48/66 (73%)] Loss: 0.864039
# DEBUG:trainer:Train Epoch: 9 [56/66 (85%)] Loss: 0.733583
# DEBUG:trainer:Train Epoch: 9 [64/66 (97%)] Loss: 0.821950
# INFO:trainer:    epoch          : 9
# INFO:trainer:    loss           : 0.8800445226105776
# INFO:trainer:    accuracy       : 0.5523200757575758
# INFO:trainer:    f1_score       : 0.32672369200331186
# INFO:trainer:    val_loss       : 0.5965900543858024
# INFO:trainer:    val_accuracy   : 0.5984506302521009
# INFO:trainer:    val_f1_score   : 0.4393714146827239
# INFO:trainer:    val_sensitivity: 0.2919708029143801
# INFO:trainer:    val_specificity: 0.9432485322711693
# INFO:trainer:    val_MAcc       : 0.6176096675927747
# INFO:trainer:    val_F1_score   : 0.4341926691732408
# INFO:trainer:Saving new best model at epoch 9: model_best.pth
# DEBUG:trainer:Train Epoch: 10 [0/66 (0%)] Loss: 0.667188
# DEBUG:trainer:Train Epoch: 10 [8/66 (12%)] Loss: 0.828454
# DEBUG:trainer:Train Epoch: 10 [16/66 (24%)] Loss: 0.825622
# DEBUG:trainer:Train Epoch: 10 [24/66 (36%)] Loss: 0.850717
# DEBUG:trainer:Train Epoch: 10 [32/66 (48%)] Loss: 0.850439
# DEBUG:trainer:Train Epoch: 10 [40/66 (61%)] Loss: 0.910423
# DEBUG:trainer:Train Epoch: 10 [48/66 (73%)] Loss: 0.916620
# DEBUG:trainer:Train Epoch: 10 [56/66 (85%)] Loss: 0.747834
# DEBUG:trainer:Train Epoch: 10 [64/66 (97%)] Loss: 0.886514
# INFO:trainer:    epoch          : 10
# INFO:trainer:    loss           : 0.8149736893899513
# INFO:trainer:    accuracy       : 0.5748106060606061
# INFO:trainer:    f1_score       : 0.38044428551870124
# INFO:trainer:    val_loss       : 0.5915549677961013
# INFO:trainer:    val_accuracy   : 0.6370535714285714
# INFO:trainer:    val_f1_score   : 0.6020889698512869
# INFO:trainer:    val_sensitivity: 0.44525547444442964
# INFO:trainer:    val_specificity: 0.8610567514508599
# INFO:trainer:    val_MAcc       : 0.6531561129476448
# INFO:trainer:    val_F1_score   : 0.5654692885147475
# INFO:trainer:Saving new best model at epoch 10: model_best.pth
# DEBUG:trainer:Train Epoch: 11 [0/66 (0%)] Loss: 0.847200
# DEBUG:trainer:Train Epoch: 11 [8/66 (12%)] Loss: 0.816442
# DEBUG:trainer:Train Epoch: 11 [16/66 (24%)] Loss: 0.800566
# DEBUG:trainer:Train Epoch: 11 [24/66 (36%)] Loss: 0.566699
# DEBUG:trainer:Train Epoch: 11 [32/66 (48%)] Loss: 0.802689
# DEBUG:trainer:Train Epoch: 11 [40/66 (61%)] Loss: 0.789352
# DEBUG:trainer:Train Epoch: 11 [48/66 (73%)] Loss: 0.842968
# DEBUG:trainer:Train Epoch: 11 [56/66 (85%)] Loss: 0.797836
# DEBUG:trainer:Train Epoch: 11 [64/66 (97%)] Loss: 0.659554
# INFO:trainer:    epoch          : 11
# INFO:trainer:    loss           : 0.7881795791062441
# INFO:trainer:    accuracy       : 0.5885416666666666
# INFO:trainer:    f1_score       : 0.4191792179614467
# INFO:trainer:    val_loss       : 0.564117480726803
# INFO:trainer:    val_accuracy   : 0.7160976890756303
# INFO:trainer:    val_f1_score   : 0.7082410938488822
# INFO:trainer:    val_sensitivity: 0.6496350364844957
# INFO:trainer:    val_specificity: 0.8101761252287637
# INFO:trainer:    val_MAcc       : 0.7299055808566297
# INFO:trainer:    val_F1_score   : 0.7112887063195348
# INFO:trainer:Saving new best model at epoch 11: model_best.pth
# DEBUG:trainer:Train Epoch: 12 [0/66 (0%)] Loss: 0.745013
# DEBUG:trainer:Train Epoch: 12 [8/66 (12%)] Loss: 0.878213
# DEBUG:trainer:Train Epoch: 12 [16/66 (24%)] Loss: 0.822375
# DEBUG:trainer:Train Epoch: 12 [24/66 (36%)] Loss: 0.768532
# DEBUG:trainer:Train Epoch: 12 [32/66 (48%)] Loss: 0.775586
# DEBUG:trainer:Train Epoch: 12 [40/66 (61%)] Loss: 0.745425
# DEBUG:trainer:Train Epoch: 12 [48/66 (73%)] Loss: 0.857129
# DEBUG:trainer:Train Epoch: 12 [56/66 (85%)] Loss: 0.768544
# DEBUG:trainer:Train Epoch: 12 [64/66 (97%)] Loss: 0.479267
# INFO:trainer:    epoch          : 12
# INFO:trainer:    loss           : 0.7630071861274315
# INFO:trainer:    accuracy       : 0.5935132575757576
# INFO:trainer:    f1_score       : 0.4502188469730201
# INFO:trainer:    val_loss       : 0.5574484257137075
# INFO:trainer:    val_accuracy   : 0.7160976890756303
# INFO:trainer:    val_f1_score   : 0.7170925851669848
# INFO:trainer:    val_sensitivity: 0.6715328467030742
# INFO:trainer:    val_specificity: 0.7866927592801038
# INFO:trainer:    val_MAcc       : 0.729112802991589
# INFO:trainer:    val_F1_score   : 0.7180487754977848
# DEBUG:trainer:Train Epoch: 13 [0/66 (0%)] Loss: 0.665743
# DEBUG:trainer:Train Epoch: 13 [8/66 (12%)] Loss: 0.632890
# DEBUG:trainer:Train Epoch: 13 [16/66 (24%)] Loss: 0.773252
# DEBUG:trainer:Train Epoch: 13 [24/66 (36%)] Loss: 0.655341
# DEBUG:trainer:Train Epoch: 13 [32/66 (48%)] Loss: 0.768502
# DEBUG:trainer:Train Epoch: 13 [40/66 (61%)] Loss: 0.744102
# DEBUG:trainer:Train Epoch: 13 [48/66 (73%)] Loss: 0.694588
# DEBUG:trainer:Train Epoch: 13 [56/66 (85%)] Loss: 0.682861
# DEBUG:trainer:Train Epoch: 13 [64/66 (97%)] Loss: 0.832181
# INFO:trainer:    epoch          : 13
# INFO:trainer:    loss           : 0.7322560887445103
# INFO:trainer:    accuracy       : 0.6178977272727273
# INFO:trainer:    f1_score       : 0.5007074387394289
# INFO:trainer:    val_loss       : 0.5648131002398098
# INFO:trainer:    val_accuracy   : 0.717935924369748
# INFO:trainer:    val_f1_score   : 0.7089509242772255
# INFO:trainer:    val_sensitivity: 0.6715328467030742
# INFO:trainer:    val_specificity: 0.7906066536048805
# INFO:trainer:    val_MAcc       : 0.7310697501539773
# INFO:trainer:    val_F1_score   : 0.7194525854317273
# INFO:trainer:Saving new best model at epoch 13: model_best.pth
# DEBUG:trainer:Train Epoch: 14 [0/66 (0%)] Loss: 0.623599
# DEBUG:trainer:Train Epoch: 14 [8/66 (12%)] Loss: 0.865926
# DEBUG:trainer:Train Epoch: 14 [16/66 (24%)] Loss: 0.568486
# DEBUG:trainer:Train Epoch: 14 [24/66 (36%)] Loss: 0.638872
# DEBUG:trainer:Train Epoch: 14 [32/66 (48%)] Loss: 0.945218
# DEBUG:trainer:Train Epoch: 14 [40/66 (61%)] Loss: 0.856393
# DEBUG:trainer:Train Epoch: 14 [48/66 (73%)] Loss: 0.688118
# DEBUG:trainer:Train Epoch: 14 [56/66 (85%)] Loss: 0.842045
# DEBUG:trainer:Train Epoch: 14 [64/66 (97%)] Loss: 0.567832
# INFO:trainer:    epoch          : 14
# INFO:trainer:    loss           : 0.7121692263718807
# INFO:trainer:    accuracy       : 0.6273674242424242
# INFO:trainer:    f1_score       : 0.5275468216060192
# INFO:trainer:    val_loss       : 0.525957720244632
# INFO:trainer:    val_accuracy   : 0.7326418067226891
# INFO:trainer:    val_f1_score   : 0.7375358067291736
# INFO:trainer:    val_sensitivity: 0.7372262773588097
# INFO:trainer:    val_specificity: 0.7514677103571141
# INFO:trainer:    val_MAcc       : 0.7443469938579619
# INFO:trainer:    val_F1_score   : 0.7488415149132182
# INFO:trainer:Saving new best model at epoch 14: model_best.pth
# DEBUG:trainer:Train Epoch: 15 [0/66 (0%)] Loss: 0.646030
# DEBUG:trainer:Train Epoch: 15 [8/66 (12%)] Loss: 0.718705
# DEBUG:trainer:Train Epoch: 15 [16/66 (24%)] Loss: 0.605124
# DEBUG:trainer:Train Epoch: 15 [24/66 (36%)] Loss: 0.723904
# DEBUG:trainer:Train Epoch: 15 [32/66 (48%)] Loss: 0.585926
# DEBUG:trainer:Train Epoch: 15 [40/66 (61%)] Loss: 0.564618
# DEBUG:trainer:Train Epoch: 15 [48/66 (73%)] Loss: 0.528848
# DEBUG:trainer:Train Epoch: 15 [56/66 (85%)] Loss: 0.630268
# DEBUG:trainer:Train Epoch: 15 [64/66 (97%)] Loss: 0.782804
# INFO:trainer:    epoch          : 15
# INFO:trainer:    loss           : 0.6627013033086603
# INFO:trainer:    accuracy       : 0.6517518939393939
# INFO:trainer:    f1_score       : 0.5753211227051166
# INFO:trainer:    val_loss       : 0.5171806619447821
# INFO:trainer:    val_accuracy   : 0.7344800420168067
# INFO:trainer:    val_f1_score   : 0.7356594576094484
# INFO:trainer:    val_sensitivity: 0.7226277372130907
# INFO:trainer:    val_specificity: 0.7710371819809974
# INFO:trainer:    val_MAcc       : 0.746832459597044
# INFO:trainer:    val_F1_score   : 0.7464655934833587
# INFO:trainer:Saving new best model at epoch 15: model_best.pth
# DEBUG:trainer:Train Epoch: 16 [0/66 (0%)] Loss: 0.695241
# DEBUG:trainer:Train Epoch: 16 [8/66 (12%)] Loss: 0.616024
# DEBUG:trainer:Train Epoch: 16 [16/66 (24%)] Loss: 0.723623
# DEBUG:trainer:Train Epoch: 16 [24/66 (36%)] Loss: 0.653916
# DEBUG:trainer:Train Epoch: 16 [32/66 (48%)] Loss: 0.461662
# DEBUG:trainer:Train Epoch: 16 [40/66 (61%)] Loss: 0.712910
# DEBUG:trainer:Train Epoch: 16 [48/66 (73%)] Loss: 0.587880
# DEBUG:trainer:Train Epoch: 16 [56/66 (85%)] Loss: 0.581637
# DEBUG:trainer:Train Epoch: 16 [64/66 (97%)] Loss: 0.601232
# INFO:trainer:    epoch          : 16
# INFO:trainer:    loss           : 0.6524447175589475
# INFO:trainer:    accuracy       : 0.6555397727272727
# INFO:trainer:    f1_score       : 0.5854674770951471
# INFO:trainer:    val_loss       : 0.5122803879134795
# INFO:trainer:    val_accuracy   : 0.7363182773109244
# INFO:trainer:    val_f1_score   : 0.736652819335994
# INFO:trainer:    val_sensitivity: 0.7372262773588097
# INFO:trainer:    val_specificity: 0.7592954990066674
# INFO:trainer:    val_MAcc       : 0.7482608881827386
# INFO:trainer:    val_F1_score   : 0.7516279019646686
# INFO:trainer:Saving new best model at epoch 16: model_best.pth
# DEBUG:trainer:Train Epoch: 17 [0/66 (0%)] Loss: 0.578656
# DEBUG:trainer:Train Epoch: 17 [8/66 (12%)] Loss: 0.588867
# DEBUG:trainer:Train Epoch: 17 [16/66 (24%)] Loss: 0.613638
# DEBUG:trainer:Train Epoch: 17 [24/66 (36%)] Loss: 0.757726
# DEBUG:trainer:Train Epoch: 17 [32/66 (48%)] Loss: 0.599942
# DEBUG:trainer:Train Epoch: 17 [40/66 (61%)] Loss: 0.749094
# DEBUG:trainer:Train Epoch: 17 [48/66 (73%)] Loss: 0.513106
# DEBUG:trainer:Train Epoch: 17 [56/66 (85%)] Loss: 0.647392
# DEBUG:trainer:Train Epoch: 17 [64/66 (97%)] Loss: 0.565224
# INFO:trainer:    epoch          : 17
# INFO:trainer:    loss           : 0.6120733532941702
# INFO:trainer:    accuracy       : 0.6856060606060606
# INFO:trainer:    f1_score       : 0.640936527341734
# INFO:trainer:    val_loss       : 0.4936584365718505
# INFO:trainer:    val_accuracy   : 0.772452731092437
# INFO:trainer:    val_f1_score   : 0.7863192535340953
# INFO:trainer:    val_sensitivity: 0.8175182481602643
# INFO:trainer:    val_specificity: 0.7436399217075609
# INFO:trainer:    val_MAcc       : 0.7805790849339126
# INFO:trainer:    val_F1_score   : 0.7950310508902955
# INFO:trainer:Saving new best model at epoch 17: model_best.pth
# DEBUG:trainer:Train Epoch: 18 [0/66 (0%)] Loss: 0.556650
# DEBUG:trainer:Train Epoch: 18 [8/66 (12%)] Loss: 0.645888
# DEBUG:trainer:Train Epoch: 18 [16/66 (24%)] Loss: 0.728862
# DEBUG:trainer:Train Epoch: 18 [24/66 (36%)] Loss: 0.548293
# DEBUG:trainer:Train Epoch: 18 [32/66 (48%)] Loss: 0.523057
# DEBUG:trainer:Train Epoch: 18 [40/66 (61%)] Loss: 0.810252
# DEBUG:trainer:Train Epoch: 18 [48/66 (73%)] Loss: 0.672555
# DEBUG:trainer:Train Epoch: 18 [56/66 (85%)] Loss: 0.604039
# DEBUG:trainer:Train Epoch: 18 [64/66 (97%)] Loss: 0.574512
# INFO:trainer:    epoch          : 18
# INFO:trainer:    loss           : 0.607983391844865
# INFO:trainer:    accuracy       : 0.6946022727272727
# INFO:trainer:    f1_score       : 0.6574495928289711
# INFO:trainer:    val_loss       : 0.48427070940242095
# INFO:trainer:    val_accuracy   : 0.7929621848739495
# INFO:trainer:    val_f1_score   : 0.8097010141273373
# INFO:trainer:    val_sensitivity: 0.8686131386702808
# INFO:trainer:    val_specificity: 0.726027397246066
# INFO:trainer:    val_MAcc       : 0.7973202679581735
# INFO:trainer:    val_F1_score   : 0.8178694108105715
# INFO:trainer:Saving new best model at epoch 18: model_best.pth
# DEBUG:trainer:Train Epoch: 19 [0/66 (0%)] Loss: 0.485419
# DEBUG:trainer:Train Epoch: 19 [8/66 (12%)] Loss: 0.550205
# DEBUG:trainer:Train Epoch: 19 [16/66 (24%)] Loss: 0.624998
# DEBUG:trainer:Train Epoch: 19 [24/66 (36%)] Loss: 0.502865
# DEBUG:trainer:Train Epoch: 19 [32/66 (48%)] Loss: 0.586792
# DEBUG:trainer:Train Epoch: 19 [40/66 (61%)] Loss: 0.569418
# DEBUG:trainer:Train Epoch: 19 [48/66 (73%)] Loss: 0.498533
# DEBUG:trainer:Train Epoch: 19 [56/66 (85%)] Loss: 0.682933
# DEBUG:trainer:Train Epoch: 19 [64/66 (97%)] Loss: 0.486043
# INFO:trainer:    epoch          : 19
# INFO:trainer:    loss           : 0.5767148918274677
# INFO:trainer:    accuracy       : 0.7180397727272727
# INFO:trainer:    f1_score       : 0.6947229726836636
# INFO:trainer:    val_loss       : 0.4961009498904733
# INFO:trainer:    val_accuracy   : 0.7602153361344538
# INFO:trainer:    val_f1_score   : 0.7674512113550962
# INFO:trainer:    val_sensitivity: 0.7883211678688262
# INFO:trainer:    val_specificity: 0.7553816046818908
# INFO:trainer:    val_MAcc       : 0.7718513862753584
# INFO:trainer:    val_F1_score   : 0.7819004474748674
# DEBUG:trainer:Train Epoch: 20 [0/66 (0%)] Loss: 0.682648
# DEBUG:trainer:Train Epoch: 20 [8/66 (12%)] Loss: 0.657848
# DEBUG:trainer:Train Epoch: 20 [16/66 (24%)] Loss: 0.511741
# DEBUG:trainer:Train Epoch: 20 [24/66 (36%)] Loss: 0.550669
# DEBUG:trainer:Train Epoch: 20 [32/66 (48%)] Loss: 0.607288
# DEBUG:trainer:Train Epoch: 20 [40/66 (61%)] Loss: 0.588639
# DEBUG:trainer:Train Epoch: 20 [48/66 (73%)] Loss: 0.460741
# DEBUG:trainer:Train Epoch: 20 [56/66 (85%)] Loss: 0.484197
# DEBUG:trainer:Train Epoch: 20 [64/66 (97%)] Loss: 0.583377
# INFO:trainer:    epoch          : 20
# INFO:trainer:    loss           : 0.5730549535064986
# INFO:trainer:    accuracy       : 0.7201704545454546
# INFO:trainer:    f1_score       : 0.6971266493555202
# INFO:trainer:    val_loss       : 0.5036759131094989
# INFO:trainer:    val_accuracy   : 0.7455094537815127
# INFO:trainer:    val_f1_score   : 0.740812047995747
# INFO:trainer:    val_sensitivity: 0.7664233576502477
# INFO:trainer:    val_specificity: 0.7475538160323375
# INFO:trainer:    val_MAcc       : 0.7569885868412927
# INFO:trainer:    val_F1_score   : 0.7657246987235097
# DEBUG:trainer:Train Epoch: 21 [0/66 (0%)] Loss: 0.675815
# DEBUG:trainer:Train Epoch: 21 [8/66 (12%)] Loss: 0.624433
# DEBUG:trainer:Train Epoch: 21 [16/66 (24%)] Loss: 0.449888
# DEBUG:trainer:Train Epoch: 21 [24/66 (36%)] Loss: 0.579257
# DEBUG:trainer:Train Epoch: 21 [32/66 (48%)] Loss: 0.514660
# DEBUG:trainer:Train Epoch: 21 [40/66 (61%)] Loss: 0.629948
# DEBUG:trainer:Train Epoch: 21 [48/66 (73%)] Loss: 0.529570
# DEBUG:trainer:Train Epoch: 21 [56/66 (85%)] Loss: 0.623749
# DEBUG:trainer:Train Epoch: 21 [64/66 (97%)] Loss: 0.570349
# INFO:trainer:    epoch          : 21
# INFO:trainer:    loss           : 0.5678256506269629
# INFO:trainer:    accuracy       : 0.7253787878787878
# INFO:trainer:    f1_score       : 0.7091690153024836
# INFO:trainer:    val_loss       : 0.48357507849440856
# INFO:trainer:    val_accuracy   : 0.766938025210084
# INFO:trainer:    val_f1_score   : 0.7793935461829745
# INFO:trainer:    val_sensitivity: 0.8102189780874047
# INFO:trainer:    val_specificity: 0.7397260273827843
# INFO:trainer:    val_MAcc       : 0.7749725027350944
# INFO:trainer:    val_F1_score   : 0.7893333283226233
# DEBUG:trainer:Train Epoch: 22 [0/66 (0%)] Loss: 0.531161
# DEBUG:trainer:Train Epoch: 22 [8/66 (12%)] Loss: 0.555025
# DEBUG:trainer:Train Epoch: 22 [16/66 (24%)] Loss: 0.491326
# DEBUG:trainer:Train Epoch: 22 [24/66 (36%)] Loss: 0.673155
# DEBUG:trainer:Train Epoch: 22 [32/66 (48%)] Loss: 0.463841
# DEBUG:trainer:Train Epoch: 22 [40/66 (61%)] Loss: 0.696402
# DEBUG:trainer:Train Epoch: 22 [48/66 (73%)] Loss: 0.424681
# DEBUG:trainer:Train Epoch: 22 [56/66 (85%)] Loss: 0.497506
# DEBUG:trainer:Train Epoch: 22 [64/66 (97%)] Loss: 0.521752
# INFO:trainer:    epoch          : 22
# INFO:trainer:    loss           : 0.537828068390037
# INFO:trainer:    accuracy       : 0.7393465909090909
# INFO:trainer:    f1_score       : 0.7219248528177205
# INFO:trainer:    val_loss       : 0.47797006631598754
# INFO:trainer:    val_accuracy   : 0.7794380252100841
# INFO:trainer:    val_f1_score   : 0.78606696502571
# INFO:trainer:    val_sensitivity: 0.8175182481602643
# INFO:trainer:    val_specificity: 0.7358121330580076
# INFO:trainer:    val_MAcc       : 0.776665190609136
# INFO:trainer:    val_F1_score   : 0.7922192699686748
# DEBUG:trainer:Train Epoch: 23 [0/66 (0%)] Loss: 0.456203
# DEBUG:trainer:Train Epoch: 23 [8/66 (12%)] Loss: 0.410525
# DEBUG:trainer:Train Epoch: 23 [16/66 (24%)] Loss: 0.495291
# DEBUG:trainer:Train Epoch: 23 [24/66 (36%)] Loss: 0.526799
# DEBUG:trainer:Train Epoch: 23 [32/66 (48%)] Loss: 0.636935
# DEBUG:trainer:Train Epoch: 23 [40/66 (61%)] Loss: 0.615786
# DEBUG:trainer:Train Epoch: 23 [48/66 (73%)] Loss: 0.540656
# DEBUG:trainer:Train Epoch: 23 [56/66 (85%)] Loss: 0.486985
# DEBUG:trainer:Train Epoch: 23 [64/66 (97%)] Loss: 0.444228
# INFO:trainer:    epoch          : 23
# INFO:trainer:    loss           : 0.534342302065907
# INFO:trainer:    accuracy       : 0.732717803030303
# INFO:trainer:    f1_score       : 0.7157930227358684
# INFO:trainer:    val_loss       : 0.47558649322565866
# INFO:trainer:    val_accuracy   : 0.7959821428571429
# INFO:trainer:    val_f1_score   : 0.8136437663719397
# INFO:trainer:    val_sensitivity: 0.8540145985245617
# INFO:trainer:    val_specificity: 0.7318982387332309
# INFO:trainer:    val_MAcc       : 0.7929564186288963
# INFO:trainer:    val_F1_score   : 0.8117953115636196
# DEBUG:trainer:Train Epoch: 24 [0/66 (0%)] Loss: 0.551075
# DEBUG:trainer:Train Epoch: 24 [8/66 (12%)] Loss: 0.435679
# DEBUG:trainer:Train Epoch: 24 [16/66 (24%)] Loss: 0.673957
# DEBUG:trainer:Train Epoch: 24 [24/66 (36%)] Loss: 0.481852
# DEBUG:trainer:Train Epoch: 24 [32/66 (48%)] Loss: 0.550272
# DEBUG:trainer:Train Epoch: 24 [40/66 (61%)] Loss: 0.437086
# DEBUG:trainer:Train Epoch: 24 [48/66 (73%)] Loss: 0.538310
# DEBUG:trainer:Train Epoch: 24 [56/66 (85%)] Loss: 0.440800
# DEBUG:trainer:Train Epoch: 24 [64/66 (97%)] Loss: 0.668292
# INFO:trainer:    epoch          : 24
# INFO:trainer:    loss           : 0.5223549103195017
# INFO:trainer:    accuracy       : 0.7660984848484849
# INFO:trainer:    f1_score       : 0.7582586943690526
# INFO:trainer:    val_loss       : 0.4829994808225071
# INFO:trainer:    val_accuracy   : 0.7794380252100841
# INFO:trainer:    val_f1_score   : 0.7938927695130796
# INFO:trainer:    val_sensitivity: 0.8175182481602643
# INFO:trainer:    val_specificity: 0.7358121330580076
# INFO:trainer:    val_MAcc       : 0.776665190609136
# INFO:trainer:    val_F1_score   : 0.7922192699686748
# DEBUG:trainer:Train Epoch: 25 [0/66 (0%)] Loss: 0.458093
# DEBUG:trainer:Train Epoch: 25 [8/66 (12%)] Loss: 0.533644
# DEBUG:trainer:Train Epoch: 25 [16/66 (24%)] Loss: 0.583177
# DEBUG:trainer:Train Epoch: 25 [24/66 (36%)] Loss: 0.567182
# DEBUG:trainer:Train Epoch: 25 [32/66 (48%)] Loss: 0.544897
# DEBUG:trainer:Train Epoch: 25 [40/66 (61%)] Loss: 0.409863
# DEBUG:trainer:Train Epoch: 25 [48/66 (73%)] Loss: 0.546483
# DEBUG:trainer:Train Epoch: 25 [56/66 (85%)] Loss: 0.430318
# DEBUG:trainer:Train Epoch: 25 [64/66 (97%)] Loss: 0.451186
# INFO:trainer:    epoch          : 25
# INFO:trainer:    loss           : 0.5067402187621954
# INFO:trainer:    accuracy       : 0.7597064393939394
# INFO:trainer:    f1_score       : 0.7501145877359452
# INFO:trainer:    val_loss       : 0.4751032100004308
# INFO:trainer:    val_accuracy   : 0.7825367647058823
# INFO:trainer:    val_f1_score   : 0.7986628410120791
# INFO:trainer:    val_sensitivity: 0.8394160583788428
# INFO:trainer:    val_specificity: 0.7318982387332309
# INFO:trainer:    val_MAcc       : 0.7856571485560369
# INFO:trainer:    val_F1_score   : 0.8034934447767815
# DEBUG:trainer:Train Epoch: 26 [0/66 (0%)] Loss: 0.463706
# DEBUG:trainer:Train Epoch: 26 [8/66 (12%)] Loss: 0.532334
# DEBUG:trainer:Train Epoch: 26 [16/66 (24%)] Loss: 0.659235
# DEBUG:trainer:Train Epoch: 26 [24/66 (36%)] Loss: 0.456344
# DEBUG:trainer:Train Epoch: 26 [32/66 (48%)] Loss: 0.470852
# DEBUG:trainer:Train Epoch: 26 [40/66 (61%)] Loss: 0.449232
# DEBUG:trainer:Train Epoch: 26 [48/66 (73%)] Loss: 0.689159
# DEBUG:trainer:Train Epoch: 26 [56/66 (85%)] Loss: 0.461031
# DEBUG:trainer:Train Epoch: 26 [64/66 (97%)] Loss: 0.553479
# INFO:trainer:    epoch          : 26
# INFO:trainer:    loss           : 0.5038964500029882
# INFO:trainer:    accuracy       : 0.767282196969697
# INFO:trainer:    f1_score       : 0.7613451677416169
# INFO:trainer:    val_loss       : 0.45647477051791024
# INFO:trainer:    val_accuracy   : 0.8198792016806723
# INFO:trainer:    val_f1_score   : 0.8396987545409133
# INFO:trainer:    val_sensitivity: 0.9197080291802973
# INFO:trainer:    val_specificity: 0.7123287671093478
# INFO:trainer:    val_MAcc       : 0.8160183981448226
# INFO:trainer:    val_F1_score   : 0.8407005788427249
# INFO:trainer:Saving new best model at epoch 26: model_best.pth
# DEBUG:trainer:Train Epoch: 27 [0/66 (0%)] Loss: 0.597591
# DEBUG:trainer:Train Epoch: 27 [8/66 (12%)] Loss: 0.468924
# DEBUG:trainer:Train Epoch: 27 [16/66 (24%)] Loss: 0.518303
# DEBUG:trainer:Train Epoch: 27 [24/66 (36%)] Loss: 0.536612
# DEBUG:trainer:Train Epoch: 27 [32/66 (48%)] Loss: 0.492763
# DEBUG:trainer:Train Epoch: 27 [40/66 (61%)] Loss: 0.521770
# DEBUG:trainer:Train Epoch: 27 [48/66 (73%)] Loss: 0.578309
# DEBUG:trainer:Train Epoch: 27 [56/66 (85%)] Loss: 0.557009
# DEBUG:trainer:Train Epoch: 27 [64/66 (97%)] Loss: 0.417202
# INFO:trainer:    epoch          : 27
# INFO:trainer:    loss           : 0.5005103638677886
# INFO:trainer:    accuracy       : 0.7724905303030303
# INFO:trainer:    f1_score       : 0.7673260487095381
# INFO:trainer:    val_loss       : 0.46786754797486696
# INFO:trainer:    val_accuracy   : 0.7984506302521008
# INFO:trainer:    val_f1_score   : 0.817652111039931
# INFO:trainer:    val_sensitivity: 0.8686131386702808
# INFO:trainer:    val_specificity: 0.7279843444084543
# INFO:trainer:    val_MAcc       : 0.7982987415393675
# INFO:trainer:    val_F1_score   : 0.8185726519242715
# DEBUG:trainer:Train Epoch: 28 [0/66 (0%)] Loss: 0.675389
# DEBUG:trainer:Train Epoch: 28 [8/66 (12%)] Loss: 0.460499
# DEBUG:trainer:Train Epoch: 28 [16/66 (24%)] Loss: 0.506697
# DEBUG:trainer:Train Epoch: 28 [24/66 (36%)] Loss: 0.540345
# DEBUG:trainer:Train Epoch: 28 [32/66 (48%)] Loss: 0.419501
# DEBUG:trainer:Train Epoch: 28 [40/66 (61%)] Loss: 0.531946
# DEBUG:trainer:Train Epoch: 28 [48/66 (73%)] Loss: 0.554226
# DEBUG:trainer:Train Epoch: 28 [56/66 (85%)] Loss: 0.416062
# DEBUG:trainer:Train Epoch: 28 [64/66 (97%)] Loss: 0.483768
# INFO:trainer:    epoch          : 28
# INFO:trainer:    loss           : 0.497695241913651
# INFO:trainer:    accuracy       : 0.7722537878787878
# INFO:trainer:    f1_score       : 0.7701660821044828
# INFO:trainer:    val_loss       : 0.4616411740289015
# INFO:trainer:    val_accuracy   : 0.8217174369747899
# INFO:trainer:    val_f1_score   : 0.8426519463070483
# INFO:trainer:    val_sensitivity: 0.9051094890345783
# INFO:trainer:    val_specificity: 0.7318982387332309
# INFO:trainer:    val_MAcc       : 0.8185038638839046
# INFO:trainer:    val_F1_score   : 0.8399661254096438
# INFO:trainer:Saving new best model at epoch 28: model_best.pth
# DEBUG:trainer:Train Epoch: 29 [0/66 (0%)] Loss: 0.431712
# DEBUG:trainer:Train Epoch: 29 [8/66 (12%)] Loss: 0.498047
# DEBUG:trainer:Train Epoch: 29 [16/66 (24%)] Loss: 0.487725
# DEBUG:trainer:Train Epoch: 29 [24/66 (36%)] Loss: 0.485891
# DEBUG:trainer:Train Epoch: 29 [32/66 (48%)] Loss: 0.513849
# DEBUG:trainer:Train Epoch: 29 [40/66 (61%)] Loss: 0.484611
# DEBUG:trainer:Train Epoch: 29 [48/66 (73%)] Loss: 0.488907
# DEBUG:trainer:Train Epoch: 29 [56/66 (85%)] Loss: 0.395417
# DEBUG:trainer:Train Epoch: 29 [64/66 (97%)] Loss: 0.476195
# INFO:trainer:    epoch          : 29
# INFO:trainer:    loss           : 0.4832742110346303
# INFO:trainer:    accuracy       : 0.7876420454545454
# INFO:trainer:    f1_score       : 0.7879720852026628
# INFO:trainer:    val_loss       : 0.4603765712064855
# INFO:trainer:    val_accuracy   : 0.8125262605042017
# INFO:trainer:    val_f1_score   : 0.8323512950547033
# INFO:trainer:    val_sensitivity: 0.8832116788159998
# INFO:trainer:    val_specificity: 0.7358121330580076
# INFO:trainer:    val_MAcc       : 0.8095119059370037
# INFO:trainer:    val_F1_score   : 0.8294772872065198
# DEBUG:trainer:Train Epoch: 30 [0/66 (0%)] Loss: 0.454842
# DEBUG:trainer:Train Epoch: 30 [8/66 (12%)] Loss: 0.548256
# DEBUG:trainer:Train Epoch: 30 [16/66 (24%)] Loss: 0.508335
# DEBUG:trainer:Train Epoch: 30 [24/66 (36%)] Loss: 0.595839
# DEBUG:trainer:Train Epoch: 30 [32/66 (48%)] Loss: 0.468665
# DEBUG:trainer:Train Epoch: 30 [40/66 (61%)] Loss: 0.364966
# DEBUG:trainer:Train Epoch: 30 [48/66 (73%)] Loss: 0.447081
# DEBUG:trainer:Train Epoch: 30 [56/66 (85%)] Loss: 0.371551
# DEBUG:trainer:Train Epoch: 30 [64/66 (97%)] Loss: 0.461268
# INFO:trainer:    epoch          : 30
# INFO:trainer:    loss           : 0.4739012840119275
# INFO:trainer:    accuracy       : 0.7843276515151515
# INFO:trainer:    f1_score       : 0.7823920709665924
# INFO:trainer:    val_loss       : 0.4709731980281718
# INFO:trainer:    val_accuracy   : 0.8143644957983194
# INFO:trainer:    val_f1_score   : 0.8309873479609644
# INFO:trainer:    val_sensitivity: 0.8759124087431402
# INFO:trainer:    val_specificity: 0.7475538160323375
# INFO:trainer:    val_MAcc       : 0.8117331123877389
# INFO:trainer:    val_F1_score   : 0.8297320606866775
# DEBUG:trainer:Train Epoch: 31 [0/66 (0%)] Loss: 0.665435
# DEBUG:trainer:Train Epoch: 31 [8/66 (12%)] Loss: 0.303268
# DEBUG:trainer:Train Epoch: 31 [16/66 (24%)] Loss: 0.476098
# DEBUG:trainer:Train Epoch: 31 [24/66 (36%)] Loss: 0.438813
# DEBUG:trainer:Train Epoch: 31 [32/66 (48%)] Loss: 0.590835
# DEBUG:trainer:Train Epoch: 31 [40/66 (61%)] Loss: 0.404469
# DEBUG:trainer:Train Epoch: 31 [48/66 (73%)] Loss: 0.469274
# DEBUG:trainer:Train Epoch: 31 [56/66 (85%)] Loss: 0.452945
# DEBUG:trainer:Train Epoch: 31 [64/66 (97%)] Loss: 0.499921
# INFO:trainer:    epoch          : 31
# INFO:trainer:    loss           : 0.46936716319936694
# INFO:trainer:    accuracy       : 0.7959280303030303
# INFO:trainer:    f1_score       : 0.7982531053702815
# INFO:trainer:    val_loss       : 0.46032239847323475
# INFO:trainer:    val_accuracy   : 0.8099264705882353
# INFO:trainer:    val_f1_score   : 0.8325613232169404
# INFO:trainer:    val_sensitivity: 0.8759124087431402
# INFO:trainer:    val_specificity: 0.7397260273827843
# INFO:trainer:    val_MAcc       : 0.8078192180629622
# INFO:trainer:    val_F1_score   : 0.8268733800143481
# DEBUG:trainer:Train Epoch: 32 [0/66 (0%)] Loss: 0.491356
# DEBUG:trainer:Train Epoch: 32 [8/66 (12%)] Loss: 0.555176
# DEBUG:trainer:Train Epoch: 32 [16/66 (24%)] Loss: 0.406785
# DEBUG:trainer:Train Epoch: 32 [24/66 (36%)] Loss: 0.400748
# DEBUG:trainer:Train Epoch: 32 [32/66 (48%)] Loss: 0.481061
# DEBUG:trainer:Train Epoch: 32 [40/66 (61%)] Loss: 0.364747
# DEBUG:trainer:Train Epoch: 32 [48/66 (73%)] Loss: 0.405336
# DEBUG:trainer:Train Epoch: 32 [56/66 (85%)] Loss: 0.402616
# DEBUG:trainer:Train Epoch: 32 [64/66 (97%)] Loss: 0.420658
# INFO:trainer:    epoch          : 32
# INFO:trainer:    loss           : 0.4730978784236041
# INFO:trainer:    accuracy       : 0.7900094696969697
# INFO:trainer:    f1_score       : 0.7932865986167367
# INFO:trainer:    val_loss       : 0.46015337898450737
# INFO:trainer:    val_accuracy   : 0.8217174369747899
# INFO:trainer:    val_f1_score   : 0.8432198920238573
# INFO:trainer:    val_sensitivity: 0.8905109488888593
# INFO:trainer:    val_specificity: 0.7475538160323375
# INFO:trainer:    val_MAcc       : 0.8190323824605984
# INFO:trainer:    val_F1_score   : 0.8377682353465049
# INFO:trainer:Saving new best model at epoch 32: model_best.pth
# DEBUG:trainer:Train Epoch: 33 [0/66 (0%)] Loss: 0.465256
# DEBUG:trainer:Train Epoch: 33 [8/66 (12%)] Loss: 0.511825
# DEBUG:trainer:Train Epoch: 33 [16/66 (24%)] Loss: 0.515820
# DEBUG:trainer:Train Epoch: 33 [24/66 (36%)] Loss: 0.529263
# DEBUG:trainer:Train Epoch: 33 [32/66 (48%)] Loss: 0.503895
# DEBUG:trainer:Train Epoch: 33 [40/66 (61%)] Loss: 0.485670
# DEBUG:trainer:Train Epoch: 33 [48/66 (73%)] Loss: 0.532786
# DEBUG:trainer:Train Epoch: 33 [56/66 (85%)] Loss: 0.519716
# DEBUG:trainer:Train Epoch: 33 [64/66 (97%)] Loss: 0.420296
# INFO:trainer:    epoch          : 33
# INFO:trainer:    loss           : 0.4569387092734828
# INFO:trainer:    accuracy       : 0.8032670454545454
# INFO:trainer:    f1_score       : 0.80453203858338
# INFO:trainer:    val_loss       : 0.44637207599247203
# INFO:trainer:    val_accuracy   : 0.8283088235294118
# INFO:trainer:    val_f1_score   : 0.8514622001991871
# INFO:trainer:    val_sensitivity: 0.9270072992531568
# INFO:trainer:    val_specificity: 0.7240704500836777
# INFO:trainer:    val_MAcc       : 0.8255388746684172
# INFO:trainer:    val_F1_score   : 0.8487886332837384
# INFO:trainer:Saving new best model at epoch 33: model_best.pth
# DEBUG:trainer:Train Epoch: 34 [0/66 (0%)] Loss: 0.432271
# DEBUG:trainer:Train Epoch: 34 [8/66 (12%)] Loss: 0.380688
# DEBUG:trainer:Train Epoch: 34 [16/66 (24%)] Loss: 0.360174
# DEBUG:trainer:Train Epoch: 34 [24/66 (36%)] Loss: 0.398746
# DEBUG:trainer:Train Epoch: 34 [32/66 (48%)] Loss: 0.478978
# DEBUG:trainer:Train Epoch: 34 [40/66 (61%)] Loss: 0.391931
# DEBUG:trainer:Train Epoch: 34 [48/66 (73%)] Loss: 0.486460
# DEBUG:trainer:Train Epoch: 34 [56/66 (85%)] Loss: 0.586246
# DEBUG:trainer:Train Epoch: 34 [64/66 (97%)] Loss: 0.492529
# INFO:trainer:    epoch          : 34
# INFO:trainer:    loss           : 0.4687896411527287
# INFO:trainer:    accuracy       : 0.7923768939393939
# INFO:trainer:    f1_score       : 0.7947855066023397
# INFO:trainer:    val_loss       : 0.46401950015741233
# INFO:trainer:    val_accuracy   : 0.8117647058823529
# INFO:trainer:    val_f1_score   : 0.8281204061365945
# INFO:trainer:    val_sensitivity: 0.8686131386702808
# INFO:trainer:    val_specificity: 0.7514677103571141
# INFO:trainer:    val_MAcc       : 0.8100404245136974
# INFO:trainer:    val_F1_score   : 0.8271068585939172
# DEBUG:trainer:Train Epoch: 35 [0/66 (0%)] Loss: 0.473180
# DEBUG:trainer:Train Epoch: 35 [8/66 (12%)] Loss: 0.398856
# DEBUG:trainer:Train Epoch: 35 [16/66 (24%)] Loss: 0.421961
# DEBUG:trainer:Train Epoch: 35 [24/66 (36%)] Loss: 0.423705
# DEBUG:trainer:Train Epoch: 35 [32/66 (48%)] Loss: 0.631013
# DEBUG:trainer:Train Epoch: 35 [40/66 (61%)] Loss: 0.463634
# DEBUG:trainer:Train Epoch: 35 [48/66 (73%)] Loss: 0.548779
# DEBUG:trainer:Train Epoch: 35 [56/66 (85%)] Loss: 0.399584
# DEBUG:trainer:Train Epoch: 35 [64/66 (97%)] Loss: 0.504468
# INFO:trainer:    epoch          : 35
# INFO:trainer:    loss           : 0.44947530238917377
# INFO:trainer:    accuracy       : 0.8098958333333334
# INFO:trainer:    f1_score       : 0.8136589561498706
# INFO:trainer:    val_loss       : 0.4652659235631718
# INFO:trainer:    val_accuracy   : 0.8117647058823529
# INFO:trainer:    val_f1_score   : 0.8335358596690642
# INFO:trainer:    val_sensitivity: 0.8686131386702808
# INFO:trainer:    val_specificity: 0.7514677103571141
# INFO:trainer:    val_MAcc       : 0.8100404245136974
# INFO:trainer:    val_F1_score   : 0.8271068585939172
# DEBUG:trainer:Train Epoch: 36 [0/66 (0%)] Loss: 0.446711
# DEBUG:trainer:Train Epoch: 36 [8/66 (12%)] Loss: 0.415290
# DEBUG:trainer:Train Epoch: 36 [16/66 (24%)] Loss: 0.435191
# DEBUG:trainer:Train Epoch: 36 [24/66 (36%)] Loss: 0.421985
# DEBUG:trainer:Train Epoch: 36 [32/66 (48%)] Loss: 0.381072
# DEBUG:trainer:Train Epoch: 36 [40/66 (61%)] Loss: 0.386511
# DEBUG:trainer:Train Epoch: 36 [48/66 (73%)] Loss: 0.494725
# DEBUG:trainer:Train Epoch: 36 [56/66 (85%)] Loss: 0.553562
# DEBUG:trainer:Train Epoch: 36 [64/66 (97%)] Loss: 0.403719
# INFO:trainer:    epoch          : 36
# INFO:trainer:    loss           : 0.4477406442165375
# INFO:trainer:    accuracy       : 0.8113162878787878
# INFO:trainer:    f1_score       : 0.8162547282851679
# INFO:trainer:    val_loss       : 0.47377371525063233
# INFO:trainer:    val_accuracy   : 0.8079306722689076
# INFO:trainer:    val_f1_score   : 0.82974732456908
# INFO:trainer:    val_sensitivity: 0.8467153284517023
# INFO:trainer:    val_specificity: 0.7651663404938324
# INFO:trainer:    val_MAcc       : 0.8059408344727673
# INFO:trainer:    val_F1_score   : 0.8197879808562974
# DEBUG:trainer:Train Epoch: 37 [0/66 (0%)] Loss: 0.426068
# DEBUG:trainer:Train Epoch: 37 [8/66 (12%)] Loss: 0.400114
# DEBUG:trainer:Train Epoch: 37 [16/66 (24%)] Loss: 0.470005
# DEBUG:trainer:Train Epoch: 37 [24/66 (36%)] Loss: 0.438726
# DEBUG:trainer:Train Epoch: 37 [32/66 (48%)] Loss: 0.464599
# DEBUG:trainer:Train Epoch: 37 [40/66 (61%)] Loss: 0.481910
# DEBUG:trainer:Train Epoch: 37 [48/66 (73%)] Loss: 0.499253
# DEBUG:trainer:Train Epoch: 37 [56/66 (85%)] Loss: 0.379007
# DEBUG:trainer:Train Epoch: 37 [64/66 (97%)] Loss: 0.379709
# INFO:trainer:    epoch          : 37
# INFO:trainer:    loss           : 0.4443495901245059
# INFO:trainer:    accuracy       : 0.8148674242424242
# INFO:trainer:    f1_score       : 0.8182017337173416
# INFO:trainer:    val_loss       : 0.48927073531291065
# INFO:trainer:    val_accuracy   : 0.8099264705882353
# INFO:trainer:    val_f1_score   : 0.8324136577960468
# INFO:trainer:    val_sensitivity: 0.8321167883059832
# INFO:trainer:    val_specificity: 0.7866927592801038
# INFO:trainer:    val_MAcc       : 0.8094047737930435
# INFO:trainer:    val_F1_score   : 0.8194070030726956
# DEBUG:trainer:Train Epoch: 38 [0/66 (0%)] Loss: 0.410120
# DEBUG:trainer:Train Epoch: 38 [8/66 (12%)] Loss: 0.472161
# DEBUG:trainer:Train Epoch: 38 [16/66 (24%)] Loss: 0.317234
# DEBUG:trainer:Train Epoch: 38 [24/66 (36%)] Loss: 0.439034
# DEBUG:trainer:Train Epoch: 38 [32/66 (48%)] Loss: 0.411594
# DEBUG:trainer:Train Epoch: 38 [40/66 (61%)] Loss: 0.491244
# DEBUG:trainer:Train Epoch: 38 [48/66 (73%)] Loss: 0.509414
# DEBUG:trainer:Train Epoch: 38 [56/66 (85%)] Loss: 0.519247
# DEBUG:trainer:Train Epoch: 38 [64/66 (97%)] Loss: 0.372906
# INFO:trainer:    epoch          : 38
# INFO:trainer:    loss           : 0.4435141497489178
# INFO:trainer:    accuracy       : 0.8134469696969697
# INFO:trainer:    f1_score       : 0.8175614577136278
# INFO:trainer:    val_loss       : 0.44857367610230164
# INFO:trainer:    val_accuracy   : 0.8301470588235295
# INFO:trainer:    val_f1_score   : 0.8542048727813275
# INFO:trainer:    val_sensitivity: 0.9051094890345783
# INFO:trainer:    val_specificity: 0.7514677103571141
# INFO:trainer:    val_MAcc       : 0.8282885996958462
# INFO:trainer:    val_F1_score   : 0.847139192273335
# INFO:trainer:Saving new best model at epoch 38: model_best.pth
# DEBUG:trainer:Train Epoch: 39 [0/66 (0%)] Loss: 0.434123
# DEBUG:trainer:Train Epoch: 39 [8/66 (12%)] Loss: 0.307784
# DEBUG:trainer:Train Epoch: 39 [16/66 (24%)] Loss: 0.384942
# DEBUG:trainer:Train Epoch: 39 [24/66 (36%)] Loss: 0.480868
# DEBUG:trainer:Train Epoch: 39 [32/66 (48%)] Loss: 0.522434
# DEBUG:trainer:Train Epoch: 39 [40/66 (61%)] Loss: 0.408770
# DEBUG:trainer:Train Epoch: 39 [48/66 (73%)] Loss: 0.415699
# DEBUG:trainer:Train Epoch: 39 [56/66 (85%)] Loss: 0.463923
# DEBUG:trainer:Train Epoch: 39 [64/66 (97%)] Loss: 0.623657
# INFO:trainer:    epoch          : 39
# INFO:trainer:    loss           : 0.44132512536915863
# INFO:trainer:    accuracy       : 0.8203125
# INFO:trainer:    f1_score       : 0.8228508120911511
# INFO:trainer:    val_loss       : 0.46027592087493224
# INFO:trainer:    val_accuracy   : 0.8292279411764706
# INFO:trainer:    val_f1_score   : 0.8536177313060622
# INFO:trainer:    val_sensitivity: 0.8978102189617188
# INFO:trainer:    val_specificity: 0.7573385518442791
# INFO:trainer:    val_MAcc       : 0.8275743854029989
# INFO:trainer:    val_F1_score   : 0.845360819744807
# DEBUG:trainer:Train Epoch: 40 [0/66 (0%)] Loss: 0.352389
# DEBUG:trainer:Train Epoch: 40 [8/66 (12%)] Loss: 0.392955
# DEBUG:trainer:Train Epoch: 40 [16/66 (24%)] Loss: 0.386832
# DEBUG:trainer:Train Epoch: 40 [24/66 (36%)] Loss: 0.398469
# DEBUG:trainer:Train Epoch: 40 [32/66 (48%)] Loss: 0.407646
# DEBUG:trainer:Train Epoch: 40 [40/66 (61%)] Loss: 0.479452
# DEBUG:trainer:Train Epoch: 40 [48/66 (73%)] Loss: 0.400865
# DEBUG:trainer:Train Epoch: 40 [56/66 (85%)] Loss: 0.448663
# DEBUG:trainer:Train Epoch: 40 [64/66 (97%)] Loss: 0.420317
# INFO:trainer:    epoch          : 40
# INFO:trainer:    loss           : 0.4412101005966013
# INFO:trainer:    accuracy       : 0.8122632575757576
# INFO:trainer:    f1_score       : 0.8170834688063788
# INFO:trainer:    val_loss       : 0.45032455991296205
# INFO:trainer:    val_accuracy   : 0.8365808823529413
# INFO:trainer:    val_f1_score   : 0.8641065199653628
# INFO:trainer:    val_sensitivity: 0.9197080291802973
# INFO:trainer:    val_specificity: 0.7495107631947258
# INFO:trainer:    val_MAcc       : 0.8346093961875115
# INFO:trainer:    val_F1_score   : 0.8542372831464521
# INFO:trainer:Saving new best model at epoch 40: model_best.pth
# DEBUG:trainer:Train Epoch: 41 [0/66 (0%)] Loss: 0.343104
# DEBUG:trainer:Train Epoch: 41 [8/66 (12%)] Loss: 0.355930
# DEBUG:trainer:Train Epoch: 41 [16/66 (24%)] Loss: 0.661404
# DEBUG:trainer:Train Epoch: 41 [24/66 (36%)] Loss: 0.406120
# DEBUG:trainer:Train Epoch: 41 [32/66 (48%)] Loss: 0.489621
# DEBUG:trainer:Train Epoch: 41 [40/66 (61%)] Loss: 0.399120
# DEBUG:trainer:Train Epoch: 41 [48/66 (73%)] Loss: 0.457826
# DEBUG:trainer:Train Epoch: 41 [56/66 (85%)] Loss: 0.378885
# DEBUG:trainer:Train Epoch: 41 [64/66 (97%)] Loss: 0.416518
# INFO:trainer:    epoch          : 41
# INFO:trainer:    loss           : 0.4365423235929374
# INFO:trainer:    accuracy       : 0.8191287878787878
# INFO:trainer:    f1_score       : 0.8230935067539471
# INFO:trainer:    val_loss       : 0.45022113621234894
# INFO:trainer:    val_accuracy   : 0.8356617647058824
# INFO:trainer:    val_f1_score   : 0.8646740659993227
# INFO:trainer:    val_sensitivity: 0.9270072992531568
# ...
# INFO:trainer:    val_loss       : 0.4429054286550073
# INFO:trainer:    val_accuracy   : 0.8375
# INFO:trainer:    val_f1_score   : 0.8639866670075361
# INFO:trainer:    val_sensitivity: 0.9051094890345783
# INFO:trainer:    val_specificity: 0.7671232876562206
# INFO:trainer:    val_MAcc       : 0.8361163883453995
# INFO:trainer:    val_F1_score   : 0.8529664610380395
# DEBUG:trainer:Train Epoch: 71 [0/66 (0%)] Loss: 0.391158
# DEBUG:trainer:Train Epoch: 71 [8/66 (12%)] Loss: 0.332220
# DEBUG:trainer:Train Epoch: 71 [16/66 (24%)] Loss: 0.492156
# DEBUG:trainer:Train Epoch: 71 [24/66 (36%)] Loss: 0.345393
# DEBUG:trainer:Train Epoch: 71 [32/66 (48%)] Loss: 0.440522
# DEBUG:trainer:Train Epoch: 71 [40/66 (61%)] Loss: 0.316919
# DEBUG:trainer:Train Epoch: 71 [48/66 (73%)] Loss: 0.366895
# DEBUG:trainer:Train Epoch: 71 [56/66 (85%)] Loss: 0.394381
# DEBUG:trainer:Train Epoch: 71 [64/66 (97%)] Loss: 0.412027
# INFO:trainer:    epoch          : 71
# INFO:trainer:    loss           : 0.4052762154376868
# INFO:trainer:    accuracy       : 0.8399621212121212
# INFO:trainer:    f1_score       : 0.8466361227689831
# INFO:trainer:    val_loss       : 0.4520103598342222
# INFO:trainer:    val_accuracy   : 0.827547268907563
# INFO:trainer:    val_f1_score   : 0.8567448489182394
# INFO:trainer:    val_sensitivity: 0.8832116788159998
# INFO:trainer:    val_specificity: 0.7710371819809974
# INFO:trainer:    val_MAcc       : 0.8271244303984986
# INFO:trainer:    val_F1_score   : 0.8424717095303519
# DEBUG:trainer:Train Epoch: 72 [0/66 (0%)] Loss: 0.367101
# DEBUG:trainer:Train Epoch: 72 [8/66 (12%)] Loss: 0.455162
# DEBUG:trainer:Train Epoch: 72 [16/66 (24%)] Loss: 0.360358
# DEBUG:trainer:Train Epoch: 72 [24/66 (36%)] Loss: 0.431522
# DEBUG:trainer:Train Epoch: 72 [32/66 (48%)] Loss: 0.422210
# DEBUG:trainer:Train Epoch: 72 [40/66 (61%)] Loss: 0.436105
# DEBUG:trainer:Train Epoch: 72 [48/66 (73%)] Loss: 0.395806
# DEBUG:trainer:Train Epoch: 72 [56/66 (85%)] Loss: 0.416309
# DEBUG:trainer:Train Epoch: 72 [64/66 (97%)] Loss: 0.370718
# INFO:trainer:    epoch          : 72
# INFO:trainer:    loss           : 0.4039654393087734
# INFO:trainer:    accuracy       : 0.8477746212121212
# INFO:trainer:    f1_score       : 0.8532007444290297
# INFO:trainer:    val_loss       : 0.45437418012058034
# INFO:trainer:    val_accuracy   : 0.8255514705882353
# INFO:trainer:    val_f1_score   : 0.8487182058151306
# INFO:trainer:    val_sensitivity: 0.8759124087431402
# INFO:trainer:    val_specificity: 0.7729941291433856
# INFO:trainer:    val_MAcc       : 0.8244532689432629
# INFO:trainer:    val_F1_score   : 0.839160834154971
# DEBUG:trainer:Train Epoch: 73 [0/66 (0%)] Loss: 0.318698
# DEBUG:trainer:Train Epoch: 73 [8/66 (12%)] Loss: 0.405316
# DEBUG:trainer:Train Epoch: 73 [16/66 (24%)] Loss: 0.424960
# DEBUG:trainer:Train Epoch: 73 [24/66 (36%)] Loss: 0.390977
# DEBUG:trainer:Train Epoch: 73 [32/66 (48%)] Loss: 0.306574
# DEBUG:trainer:Train Epoch: 73 [40/66 (61%)] Loss: 0.380132
# DEBUG:trainer:Train Epoch: 73 [48/66 (73%)] Loss: 0.348406
# DEBUG:trainer:Train Epoch: 73 [56/66 (85%)] Loss: 0.384450
# DEBUG:trainer:Train Epoch: 73 [64/66 (97%)] Loss: 0.459339
# INFO:trainer:    epoch          : 73
# INFO:trainer:    loss           : 0.388521874944369
# INFO:trainer:    accuracy       : 0.8508522727272727
# INFO:trainer:    f1_score       : 0.8567463070165928
# INFO:trainer:    val_loss       : 0.4680478529018514
# INFO:trainer:    val_accuracy   : 0.8145220588235295
# INFO:trainer:    val_f1_score   : 0.8400131233552827
# INFO:trainer:    val_sensitivity: 0.8467153284517023
# INFO:trainer:    val_specificity: 0.7808219177929389
# INFO:trainer:    val_MAcc       : 0.8137686231223206
# INFO:trainer:    val_F1_score   : 0.8256227707891238
# DEBUG:trainer:Train Epoch: 74 [0/66 (0%)] Loss: 0.419249
# DEBUG:trainer:Train Epoch: 74 [8/66 (12%)] Loss: 0.447701
# DEBUG:trainer:Train Epoch: 74 [16/66 (24%)] Loss: 0.375495
# DEBUG:trainer:Train Epoch: 74 [24/66 (36%)] Loss: 0.445504
# DEBUG:trainer:Train Epoch: 74 [32/66 (48%)] Loss: 0.466463
# DEBUG:trainer:Train Epoch: 74 [40/66 (61%)] Loss: 0.391679
# DEBUG:trainer:Train Epoch: 74 [48/66 (73%)] Loss: 0.350494
# DEBUG:trainer:Train Epoch: 74 [56/66 (85%)] Loss: 0.406617
# DEBUG:trainer:Train Epoch: 74 [64/66 (97%)] Loss: 0.392449
# INFO:trainer:    epoch          : 74
# INFO:trainer:    loss           : 0.39962921585097455
# INFO:trainer:    accuracy       : 0.8465909090909091
# INFO:trainer:    f1_score       : 0.8524126917478552
# INFO:trainer:    val_loss       : 0.44458073202301474
# INFO:trainer:    val_accuracy   : 0.8448529411764706
# INFO:trainer:    val_f1_score   : 0.8706633255401854
# INFO:trainer:    val_sensitivity: 0.9270072992531568
# INFO:trainer:    val_specificity: 0.7592954990066674
# INFO:trainer:    val_MAcc       : 0.8431513991299121
# INFO:trainer:    val_F1_score   : 0.8617472384367945
# DEBUG:trainer:Train Epoch: 75 [0/66 (0%)] Loss: 0.389849
# DEBUG:trainer:Train Epoch: 75 [8/66 (12%)] Loss: 0.334706
# DEBUG:trainer:Train Epoch: 75 [16/66 (24%)] Loss: 0.343327
# DEBUG:trainer:Train Epoch: 75 [24/66 (36%)] Loss: 0.476510
# DEBUG:trainer:Train Epoch: 75 [32/66 (48%)] Loss: 0.397824
# DEBUG:trainer:Train Epoch: 75 [40/66 (61%)] Loss: 0.300784
# DEBUG:trainer:Train Epoch: 75 [48/66 (73%)] Loss: 0.414002
# DEBUG:trainer:Train Epoch: 75 [56/66 (85%)] Loss: 0.366153
# DEBUG:trainer:Train Epoch: 75 [64/66 (97%)] Loss: 0.389125
# INFO:trainer:    epoch          : 75
# INFO:trainer:    loss           : 0.38925423631162354
# INFO:trainer:    accuracy       : 0.8589015151515151
# INFO:trainer:    f1_score       : 0.8649293803639412
# INFO:trainer:    val_loss       : 0.44314387878950906
# INFO:trainer:    val_accuracy   : 0.8356617647058824
# INFO:trainer:    val_f1_score   : 0.8596068207524717
# INFO:trainer:    val_sensitivity: 0.9051094890345783
# INFO:trainer:    val_specificity: 0.763209393331444
# INFO:trainer:    val_MAcc       : 0.8341594411830111
# INFO:trainer:    val_F1_score   : 0.8515021409256683
# DEBUG:trainer:Train Epoch: 76 [0/66 (0%)] Loss: 0.393749
# DEBUG:trainer:Train Epoch: 76 [8/66 (12%)] Loss: 0.304534
# DEBUG:trainer:Train Epoch: 76 [16/66 (24%)] Loss: 0.352658
# DEBUG:trainer:Train Epoch: 76 [24/66 (36%)] Loss: 0.343248
# DEBUG:trainer:Train Epoch: 76 [32/66 (48%)] Loss: 0.474820
# DEBUG:trainer:Train Epoch: 76 [40/66 (61%)] Loss: 0.426553
# DEBUG:trainer:Train Epoch: 76 [48/66 (73%)] Loss: 0.300154
# DEBUG:trainer:Train Epoch: 76 [56/66 (85%)] Loss: 0.392792
# DEBUG:trainer:Train Epoch: 76 [64/66 (97%)] Loss: 0.360264
# INFO:trainer:    epoch          : 76
# INFO:trainer:    loss           : 0.38937470813592273
# INFO:trainer:    accuracy       : 0.8456439393939394
# INFO:trainer:    f1_score       : 0.8515506155761846
# INFO:trainer:    val_loss       : 0.4453833892064936
# INFO:trainer:    val_accuracy   : 0.8376575630252101
# INFO:trainer:    val_f1_score   : 0.8638594353689111
# INFO:trainer:    val_sensitivity: 0.9124087591074378
# INFO:trainer:    val_specificity: 0.7612524461690557
# INFO:trainer:    val_MAcc       : 0.8368306026382468
# INFO:trainer:    val_F1_score   : 0.8547008497062459
# DEBUG:trainer:Train Epoch: 77 [0/66 (0%)] Loss: 0.387087
# DEBUG:trainer:Train Epoch: 77 [8/66 (12%)] Loss: 0.448837
# DEBUG:trainer:Train Epoch: 77 [16/66 (24%)] Loss: 0.363911
# DEBUG:trainer:Train Epoch: 77 [24/66 (36%)] Loss: 0.415478
# DEBUG:trainer:Train Epoch: 77 [32/66 (48%)] Loss: 0.437295
# DEBUG:trainer:Train Epoch: 77 [40/66 (61%)] Loss: 0.346473
# DEBUG:trainer:Train Epoch: 77 [48/66 (73%)] Loss: 0.468008
# DEBUG:trainer:Train Epoch: 77 [56/66 (85%)] Loss: 0.496036
# DEBUG:trainer:Train Epoch: 77 [64/66 (97%)] Loss: 0.372917
# INFO:trainer:    epoch          : 77
# INFO:trainer:    loss           : 0.3908316714294029
# INFO:trainer:    accuracy       : 0.8558238636363636
# INFO:trainer:    f1_score       : 0.8617119366748357
# INFO:trainer:    val_loss       : 0.44856927061782165
# INFO:trainer:    val_accuracy   : 0.8375
# INFO:trainer:    val_f1_score   : 0.8623676178492402
# INFO:trainer:    val_sensitivity: 0.9051094890345783
# INFO:trainer:    val_specificity: 0.7671232876562206
# INFO:trainer:    val_MAcc       : 0.8361163883453995
# INFO:trainer:    val_F1_score   : 0.8529664610380395
# DEBUG:trainer:Train Epoch: 78 [0/66 (0%)] Loss: 0.317365
# DEBUG:trainer:Train Epoch: 78 [8/66 (12%)] Loss: 0.423051
# DEBUG:trainer:Train Epoch: 78 [16/66 (24%)] Loss: 0.360401
# DEBUG:trainer:Train Epoch: 78 [24/66 (36%)] Loss: 0.331000
# DEBUG:trainer:Train Epoch: 78 [32/66 (48%)] Loss: 0.396472
# DEBUG:trainer:Train Epoch: 78 [40/66 (61%)] Loss: 0.536792
# DEBUG:trainer:Train Epoch: 78 [48/66 (73%)] Loss: 0.344242
# DEBUG:trainer:Train Epoch: 78 [56/66 (85%)] Loss: 0.329618
# DEBUG:trainer:Train Epoch: 78 [64/66 (97%)] Loss: 0.365375
# INFO:trainer:    epoch          : 78
# INFO:trainer:    loss           : 0.40117944099686365
# INFO:trainer:    accuracy       : 0.8449337121212122
# INFO:trainer:    f1_score       : 0.8513378214717464
# INFO:trainer:    val_loss       : 0.44793977369280424
# INFO:trainer:    val_accuracy   : 0.8338235294117647
# INFO:trainer:    val_f1_score   : 0.8558532124848646
# INFO:trainer:    val_sensitivity: 0.8978102189617188
# INFO:trainer:    val_specificity: 0.7671232876562206
# INFO:trainer:    val_MAcc       : 0.8324667533089697
# INFO:trainer:    val_F1_score   : 0.8490077603150495
# DEBUG:trainer:Train Epoch: 79 [0/66 (0%)] Loss: 0.410572
# DEBUG:trainer:Train Epoch: 79 [8/66 (12%)] Loss: 0.431213
# DEBUG:trainer:Train Epoch: 79 [16/66 (24%)] Loss: 0.418139
# DEBUG:trainer:Train Epoch: 79 [24/66 (36%)] Loss: 0.337421
# DEBUG:trainer:Train Epoch: 79 [32/66 (48%)] Loss: 0.483499
# DEBUG:trainer:Train Epoch: 79 [40/66 (61%)] Loss: 0.472573
# DEBUG:trainer:Train Epoch: 79 [48/66 (73%)] Loss: 0.293977
# DEBUG:trainer:Train Epoch: 79 [56/66 (85%)] Loss: 0.405290
# DEBUG:trainer:Train Epoch: 79 [64/66 (97%)] Loss: 0.450178
# INFO:trainer:    epoch          : 79
# INFO:trainer:    loss           : 0.3878340698552854
# INFO:trainer:    accuracy       : 0.8546401515151515
# INFO:trainer:    f1_score       : 0.8607078328139273
# INFO:trainer:    val_loss       : 0.4638488695901983
# INFO:trainer:    val_accuracy   : 0.8117647058823529
# INFO:trainer:    val_f1_score   : 0.8381754384189692
# INFO:trainer:    val_sensitivity: 0.8394160583788428
# INFO:trainer:    val_specificity: 0.7827788649553272
# INFO:trainer:    val_MAcc       : 0.811097461667085
# INFO:trainer:    val_F1_score   : 0.8221626402063634
# DEBUG:trainer:Train Epoch: 80 [0/66 (0%)] Loss: 0.350537
# DEBUG:trainer:Train Epoch: 80 [8/66 (12%)] Loss: 0.418860
# DEBUG:trainer:Train Epoch: 80 [16/66 (24%)] Loss: 0.369086
# DEBUG:trainer:Train Epoch: 80 [24/66 (36%)] Loss: 0.434026
# DEBUG:trainer:Train Epoch: 80 [32/66 (48%)] Loss: 0.473064
# DEBUG:trainer:Train Epoch: 80 [40/66 (61%)] Loss: 0.371368
# DEBUG:trainer:Train Epoch: 80 [48/66 (73%)] Loss: 0.380382
# DEBUG:trainer:Train Epoch: 80 [56/66 (85%)] Loss: 0.418836
# DEBUG:trainer:Train Epoch: 80 [64/66 (97%)] Loss: 0.315935
# INFO:trainer:    epoch          : 80
# INFO:trainer:    loss           : 0.39882010673031665
# INFO:trainer:    accuracy       : 0.8413825757575758
# INFO:trainer:    f1_score       : 0.8473470681786313
# INFO:trainer:    val_loss       : 0.46772369128816266
# INFO:trainer:    val_accuracy   : 0.8117647058823529
# INFO:trainer:    val_f1_score   : 0.8376675551191264
# INFO:trainer:    val_sensitivity: 0.8394160583788428
# INFO:trainer:    val_specificity: 0.7827788649553272
# INFO:trainer:    val_MAcc       : 0.811097461667085
# INFO:trainer:    val_F1_score   : 0.8221626402063634
# DEBUG:trainer:Train Epoch: 81 [0/66 (0%)] Loss: 0.373593
# DEBUG:trainer:Train Epoch: 81 [8/66 (12%)] Loss: 0.341172
# DEBUG:trainer:Train Epoch: 81 [16/66 (24%)] Loss: 0.379607
# DEBUG:trainer:Train Epoch: 81 [24/66 (36%)] Loss: 0.458924
# DEBUG:trainer:Train Epoch: 81 [32/66 (48%)] Loss: 0.378710
# DEBUG:trainer:Train Epoch: 81 [40/66 (61%)] Loss: 0.320889
# DEBUG:trainer:Train Epoch: 81 [48/66 (73%)] Loss: 0.347908
# DEBUG:trainer:Train Epoch: 81 [56/66 (85%)] Loss: 0.429135
# DEBUG:trainer:Train Epoch: 81 [64/66 (97%)] Loss: 0.458440
# INFO:trainer:    epoch          : 81
# INFO:trainer:    loss           : 0.38489414751529694
# INFO:trainer:    accuracy       : 0.8534564393939394
# INFO:trainer:    f1_score       : 0.8591086612632954
# INFO:trainer:    val_loss       : 0.4460202026016572
# INFO:trainer:    val_accuracy   : 0.8347426470588236
# INFO:trainer:    val_f1_score   : 0.8578642733145275
# INFO:trainer:    val_sensitivity: 0.8978102189617188
# INFO:trainer:    val_specificity: 0.769080234818609
# INFO:trainer:    val_MAcc       : 0.8334452268901639
# INFO:trainer:    val_F1_score   : 0.849740927642144
# DEBUG:trainer:Train Epoch: 82 [0/66 (0%)] Loss: 0.341233
# DEBUG:trainer:Train Epoch: 82 [8/66 (12%)] Loss: 0.373772
# DEBUG:trainer:Train Epoch: 82 [16/66 (24%)] Loss: 0.375561
# DEBUG:trainer:Train Epoch: 82 [24/66 (36%)] Loss: 0.359458
# DEBUG:trainer:Train Epoch: 82 [32/66 (48%)] Loss: 0.423717
# DEBUG:trainer:Train Epoch: 82 [40/66 (61%)] Loss: 0.340114
# DEBUG:trainer:Train Epoch: 82 [48/66 (73%)] Loss: 0.469029
# DEBUG:trainer:Train Epoch: 82 [56/66 (85%)] Loss: 0.473093
# DEBUG:trainer:Train Epoch: 82 [64/66 (97%)] Loss: 0.450170
# INFO:trainer:    epoch          : 82
# INFO:trainer:    loss           : 0.39692804939819104
# INFO:trainer:    accuracy       : 0.8496685606060606
# INFO:trainer:    f1_score       : 0.8557833936070818
# INFO:trainer:    val_loss       : 0.4662841277963975
# INFO:trainer:    val_accuracy   : 0.8117647058823529
# INFO:trainer:    val_f1_score   : 0.8368477672972322
# INFO:trainer:    val_sensitivity: 0.8394160583788428
# INFO:trainer:    val_specificity: 0.7827788649553272
# INFO:trainer:    val_MAcc       : 0.811097461667085
# INFO:trainer:    val_F1_score   : 0.8221626402063634
# DEBUG:trainer:Train Epoch: 83 [0/66 (0%)] Loss: 0.365370
# DEBUG:trainer:Train Epoch: 83 [8/66 (12%)] Loss: 0.403846
# DEBUG:trainer:Train Epoch: 83 [16/66 (24%)] Loss: 0.348840
# DEBUG:trainer:Train Epoch: 83 [24/66 (36%)] Loss: 0.439041
# DEBUG:trainer:Train Epoch: 83 [32/66 (48%)] Loss: 0.287614
# DEBUG:trainer:Train Epoch: 83 [40/66 (61%)] Loss: 0.469063
# DEBUG:trainer:Train Epoch: 83 [48/66 (73%)] Loss: 0.334596
# DEBUG:trainer:Train Epoch: 83 [56/66 (85%)] Loss: 0.394649
# DEBUG:trainer:Train Epoch: 83 [64/66 (97%)] Loss: 0.376317
# INFO:trainer:    epoch          : 83
# INFO:trainer:    loss           : 0.3869512284343893
# INFO:trainer:    accuracy       : 0.8522727272727273
# INFO:trainer:    f1_score       : 0.8576747890465535
# INFO:trainer:    val_loss       : 0.45764532948241515
# INFO:trainer:    val_accuracy   : 0.8227941176470589
# INFO:trainer:    val_f1_score   : 0.8431682975007718
# INFO:trainer:    val_sensitivity: 0.8686131386702808
# INFO:trainer:    val_specificity: 0.774951076305774
# INFO:trainer:    val_MAcc       : 0.8217821074880274
# INFO:trainer:    val_F1_score   : 0.835820890514838
# DEBUG:trainer:Train Epoch: 84 [0/66 (0%)] Loss: 0.288572
# DEBUG:trainer:Train Epoch: 84 [8/66 (12%)] Loss: 0.399731
# DEBUG:trainer:Train Epoch: 84 [16/66 (24%)] Loss: 0.411004
# DEBUG:trainer:Train Epoch: 84 [24/66 (36%)] Loss: 0.405820
# DEBUG:trainer:Train Epoch: 84 [32/66 (48%)] Loss: 0.425370
# DEBUG:trainer:Train Epoch: 84 [40/66 (61%)] Loss: 0.420274
# DEBUG:trainer:Train Epoch: 84 [48/66 (73%)] Loss: 0.336399
# DEBUG:trainer:Train Epoch: 84 [56/66 (85%)] Loss: 0.376390
# DEBUG:trainer:Train Epoch: 84 [64/66 (97%)] Loss: 0.403585
# INFO:trainer:    epoch          : 84
# INFO:trainer:    loss           : 0.38781684998309973
# INFO:trainer:    accuracy       : 0.8529829545454546
# INFO:trainer:    f1_score       : 0.8596682669838848
# INFO:trainer:    val_loss       : 0.4487728485289742
# INFO:trainer:    val_accuracy   : 0.8356617647058824
# INFO:trainer:    val_f1_score   : 0.8635949031815381
# INFO:trainer:    val_sensitivity: 0.8905109488888593
# INFO:trainer:    val_specificity: 0.7788649706305506
# INFO:trainer:    val_MAcc       : 0.834687959759705
# INFO:trainer:    val_F1_score   : 0.8494342856834074
# INFO:trainer:Validation performance didn't improve for 30 epochs. Training stops.
# === HOÀN THÀNH TRAINING ===
# Model tốt nhất được lưu tại:
# /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0305_150252/model_best.pth

# %% [markdown]
# # Test

# %%
from sklearn.metrics import f1_score, confusion_matrix
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import pandas as pd

def test_model(config, best_model_path, validation_fea_path, validation_label_csv):
    config_parser = ConfigParser(config)
    device, _ = prepare_device(config_parser['n_gpu'])

    # Khởi tạo model từ config (đảm bảo architecture đúng)
    model = config_parser.init_obj('arch', globals())
    model = model.to(device)

    # === LOAD CHỈ STATE_DICT - AN TOÀN, KHÔNG CẦN WHITELIST ===
    try:
        # Cách 1: Dùng weights_only=True (mặc định từ PT 2.6), chỉ load weights
        checkpoint = torch.load(best_model_path, map_location=device, weights_only=True)
        model.load_state_dict(checkpoint)  # checkpoint ở đây chỉ là state_dict
        print("Loaded model weights with weights_only=True (safe mode)")
    except Exception as e1:
        print(f"weights_only=True failed: {e1}")
        try:
            # Cách 2: Tắt weights_only (chỉ dùng nếu bạn tin tưởng file)
            checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
            model.load_state_dict(checkpoint['state_dict'])
            print("Loaded with weights_only=False (full checkpoint)")
        except Exception as e2:
            print(f"Cả hai cách đều thất bại: {e2}")
            return

    model.eval()

    print("\n=== MODEL ARCHITECTURE ===")
    print(model)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\nTrainable parameters: {trainable_params:,}")

    # === Xác định input shape từ config ===
    delta = config['data_loader']['args'].get('delta', False)
    n_mfcc = config['data_loader']['args'].get('n_mfcc', N_MFCC)
    actual_duration = config['data_loader']['args'].get('duration', 1.5)
    time_frames = TIME_FRAME

    channels = 3 if delta else 1   # static + Δ + ΔΔ nếu có
    height = n_mfcc

    # === Kiểm tra forward với input giả ===
    print("\n=== VERIFYING FORWARD PASS ===")
    try:
        with torch.no_grad():
            dummy_input = torch.randn(2, channels * height, time_frames).to(device)
            output = model(dummy_input)
            print(f"Input shape: (B, {channels * height}, {time_frames})")
            print(f"Output shape: {output.shape} → OK")
    except Exception as e:
        print(f"Forward pass error: {e}")

    # === Load validation data ===
    if not Path(validation_label_csv).exists() or not Path(validation_fea_path).exists():
        print("Validation files not found → skipping evaluation")
        return

    validation_label_df = pd.read_csv(validation_label_csv)
    validation_label_df['filename'] = validation_label_df['filename'].apply(lambda x: Path(x).stem)

    validation_dataset = HeartSoundDataSet(
        fea_path=validation_fea_path,
        labels=validation_label_df,
        duration=config['data_loader']['args']['duration'],
        training=False,
        delta=delta,
        norm=config['data_loader']['args'].get('norm', True)
    )

    print("\n=== DEBUG: SAMPLE FEATURES ===")
    for i in range(min(5, len(validation_dataset))):
        fea, lab = validation_dataset[i]
        print(f"Sample {i}: shape = {fea.shape}, label = {lab.item()}")

    # Tắt pin_memory trên CPU
    pin_memory = (device.type == 'cuda')

    validation_dataloader = DataLoader(
        validation_dataset,
        batch_size=config['data_loader']['args']['batch_size'],
        shuffle=False,
        num_workers=config['data_loader']['args'].get('num_workers', 2),
        pin_memory=pin_memory
    )

    criterion = nn.CrossEntropyLoss()

    print("\n=== EVALUATING ON VALIDATION SET ===")
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    val_TP = val_TN = val_pred_pos = val_condition_pos = 0

    all_preds = []
    all_targets = []

    with torch.no_grad():
        for data, target in validation_dataloader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            total_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, 1)
            total_correct += (pred == target).sum().item()
            total_samples += target.size(0)

            pred_pos_idx = (pred == 1)      # class 1 = abnormal (positive)
            condition_pos_idx = (target == 1)

            val_TP += (pred_pos_idx & condition_pos_idx).sum().item()
            val_TN += ((pred == 0) & (target == 0)).sum().item()
            val_pred_pos += pred_pos_idx.sum().item()
            val_condition_pos += condition_pos_idx.sum().item()

            all_preds.extend(pred.cpu().numpy())
            all_targets.extend(target.cpu().numpy())

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    sensitivity = val_TP / val_condition_pos if val_condition_pos > 0 else 0
    specificity = val_TN / (total_samples - val_condition_pos) if (total_samples - val_condition_pos) > 0 else 0
    MAcc = (sensitivity + specificity) / 2
    precision = val_TP / val_pred_pos if val_pred_pos > 0 else 0
    F1_score = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0
    cm = confusion_matrix(all_targets, all_preds)
    val_log = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'MAcc': MAcc,
        'F1_score': F1_score
    }

    print(f"\nDetailed Results:")
    for k, v in val_log.items():
        print(f"    {k}: {v:.4f}")


    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal (0)', 'Abnormal (1)'],
                yticklabels=['Normal (0)', 'Abnormal (1)'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix - Heart Sound Classification')

    # Save image to the same directory as the model
    save_path = Path(best_model_path).parent / "confusion_matrix.png"
    plt.savefig(save_path, dpi=300)
    plt.show()
    print(f"\nConfusion Matrix has been saved at: {save_path}")

    # Print detailed classification report
    print("\nClassification Report:")
    print(classification_report(all_targets, all_preds, target_names=['Normal', 'Abnormal']))


    metrics_path = Path(best_model_path).parent / "test_on_validation_set_metrics.csv"
    pd.DataFrame([val_log]).to_csv(metrics_path, index=False)
    print(f"\nĐã lưu kết quả tại: {metrics_path}")

# %%
val_df = pd.read_csv(str(DATASET_PATH / 'label_validation.csv'))
print("\n=== PHÂN PHỐI LABEL (test/val set) ===")
print(val_df['label'].value_counts())
print(f"Tỷ lệ Abnormal: {val_df['label'].mean():.2%}")
# Out:
# === PHÂN PHỐI LABEL (test/val set) ===
# label
# 1    151
# 0    150
# Name: count, dtype: int64
# Tỷ lệ Abnormal: 50.17%

# %%
base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
if base_dir.exists():
        latest_run = max(base_dir.iterdir(), key=os.path.getmtime)
        best_model_path = latest_run / "model_best.pth"

        validation_fea_path = str(DATASET_PATH / "mfcc_features_validation.h5")
        validation_label_csv = str(DATASET_PATH / "label_validation.csv")  # Đảm bảo file này tồn tại!

        if Path(validation_fea_path).exists() and Path(validation_label_csv).exists():
            test_model(current_config, best_model_path, validation_fea_path, validation_label_csv)
        else:
            print("Không tìm thấy file validation .h5 hoặc label_validation.csv → Bỏ qua phần test.")

        size_bytes = os.path.getsize(best_model_path)
        size_mb = size_bytes / (1024 * 1024)

        print(f"Model size: {size_mb:.2f} MB")

else:
    print("Không tìm thấy thư mục saved models.")
# Out:
# weights_only=True failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy._core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([numpy._core.multiarray.scalar])` or the `torch.serialization.safe_globals([numpy._core.multiarray.scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Loaded with weights_only=False (full checkpoint)
#
# === MODEL ARCHITECTURE ===
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 24, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#     (3): Dropout2d(p=0.1, inplace=False)
#   )
#   (stage1): Sequential(
#     (0): DSConvBlock(
#       (dw): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#       (pw): Conv2d(24, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU6(inplace=True)
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (stage2): Sequential(
#     (0): DSConvBlock(
#       (dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (pw): Conv2d(32, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU6(inplace=True)
#     )
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (stage3): DSConvBlock(
#     (dw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#     (pw): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act): ReLU6(inplace=True)
#   )
#   (se): LiteSEBlock(
#     (gap): AdaptiveAvgPool2d(output_size=1)
#     (fc): Sequential(
#       (0): Linear(in_features=48, out_features=12, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=12, out_features=48, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (gap): AdaptiveAvgPool2d(output_size=1)
#   (bn_head): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout_layer): Dropout(p=0.5, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=48, out_features=16, bias=True)
#     (1): ReLU6(inplace=True)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=16, out_features=2, bias=True)
#   )
# )
# Trainable parameters: 8,574
#
# Trainable parameters: 8,574
#
# === VERIFYING FORWARD PASS ===
# Input shape: (B, 39, 333)
# Output shape: torch.Size([2, 2]) → OK
#
# === DEBUG: SAMPLE FEATURES ===
# Sample 0: shape = torch.Size([39, 333]), label = 1
# Sample 1: shape = torch.Size([39, 333]), label = 1
# Sample 2: shape = torch.Size([39, 333]), label = 1
# Sample 3: shape = torch.Size([39, 333]), label = 1
# Sample 4: shape = torch.Size([39, 333]), label = 1
#
# === EVALUATING ON VALIDATION SET ===
#
# Detailed Results:
#     loss: 0.5449
#     accuracy: 0.7143
#     sensitivity: 0.9603
#     specificity: 0.4667
#     MAcc: 0.7135
#     F1_score: 0.7713
# Confusion Matrix has been saved at: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0305_150252/confusion_matrix.png
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.47      0.62       150
#     Abnormal       0.64      0.96      0.77       151
#
#     accuracy                           0.71       301
#    macro avg       0.78      0.71      0.70       301
# weighted avg       0.78      0.71      0.70       301
#
#
# Đã lưu kết quả tại: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0305_150252/test_on_validation_set_metrics.csv
# Model size: 0.38 MB
