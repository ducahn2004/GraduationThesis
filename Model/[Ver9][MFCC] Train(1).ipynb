# %%
import numpy as np
import pandas as pd
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import numpy as np
from torch.utils.data import DataLoader, Sampler
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision.utils import make_grid

from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    balanced_accuracy_score,
    matthews_corrcoef
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
sys.path.append(str(DATASET_PATH))

# %% [markdown]
# # Load Data

# %% [markdown]
# ## HeartSoundDataSet

# %%
def spec_augment(spec, F=6, T=25, num_masks=2):
    """SpecAugment cho MFCC"""
    cloned = spec.clone()
    num_mel_channels, num_frames = cloned.shape[-2:]

    # Frequency masking
    for _ in range(num_masks):
        f = np.random.randint(0, F)
        f0 = np.random.randint(0, num_mel_channels - f)
        cloned[..., f0:f0+f, :] = cloned[..., f0:f0+f, :].mean()

    # Time masking
    for _ in range(num_masks):
        t = np.random.randint(0, T)
        t0 = np.random.randint(0, num_frames - t)
        cloned[..., :, t0:t0+t] = 0

    return cloned

# %%
import numpy as np
import h5py
import random
import torch
from pathlib import Path
import librosa  # cần import để tính delta

EPS = 1e-8

def standard_normal_variate(data):
    """Chuẩn hóa Z-score trên toàn bộ tensor."""
    mean = np.mean(data)
    std = np.std(data) + EPS
    return (data - mean) / std

class HeartSoundDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 fea_path: str,              # đường dẫn file .h5
                 labels: pd.DataFrame,       # DataFrame với cột 'filename' và 'label'
                 duration: int = 5,          # giây
                 training: bool = True,
                 delta: bool = False,
                 norm: bool = True):
        self._fea_path = fea_path
        self._h5database = None
        self._labels = labels.reset_index(drop=True)
        self._colname = ['filename', 'label']
        self._len = len(self._labels)
        self._duration = duration
        self._delta = delta
        self.train = training
        self.hop_length = 15  # ms
        self.norm = norm

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
      row = self._labels.iloc[idx]
      filename = row['filename']
      target_bin = row['label']

      # Lấy key từ stem của filename
      key = Path(filename).stem if '/' in str(filename) else filename

      # Mở HDF5 nếu chưa mở
      if self._h5database is None:
          self._h5database = h5py.File(self._fea_path, 'r')

      if key not in self._h5database:
          available = list(self._h5database.keys())[:10]
          raise KeyError(f"Key '{key}' not found in HDF5. Sample keys: {available}")

      # Load feature từ HDF5
      feature = self._h5database[key][()]  # (mel_bins, T) hoặc (C, mel_bins, T)

      # Đảm bảo feature là 3D: (C, H, W)
      if feature.ndim == 2:
          feature = feature[np.newaxis, :, :]  # → (1, mel_bins, T)
      elif feature.ndim != 3:
          raise ValueError(f"Unexpected shape {feature.shape} for key '{key}'")

      # Chuẩn hóa toàn bộ tensor (nếu bật)
      if self.norm:
          feature = standard_normal_variate(feature)

      # Lấy shape hiện tại
      channels, mel_bins, num_frames = feature.shape

      # Tính độ dài mong muốn (frames)
      cycle_len = int(self._duration * 1000 / self.hop_length)

      # Crop hoặc pad để đạt đúng cycle_len
      if num_frames >= cycle_len:
          if self.train:
              #feature_tensor = spec_augment(feature_tensor, F=5, T=30, num_masks=1)
              start_ind = random.randint(0, num_frames - cycle_len)
          else:
              start_ind = (num_frames - cycle_len) // 2
          feature = feature[:, :, start_ind:start_ind + cycle_len]
      elif num_frames < cycle_len:
          pad_width = ((0, 0), (0, 0), (0, cycle_len - num_frames))
          feature = np.pad(feature, pad_width, mode='wrap')

      # === Fix quan trọng cho model gốc: Làm cho tensor luôn là 3D (mel_bins, num_frames) ===
      feature_tensor = torch.from_numpy(feature).float()  # (C, mel_bins, T)

      if self.train:
          feature_tensor = spec_augment(feature_tensor, F=4, T=15, num_masks=1)

      if channels > 1:  # Có delta → C=3
          # Ghép 3 channels vào chiều mel_bins → (3 * mel_bins, T) = (384, T)
          # Model sẽ view thành (B, 3, 128, T) trong forward
          feature_tensor = feature_tensor.view(channels * mel_bins, -1)  # → (384, T)
      else:
          # Không delta → squeeze về (mel_bins, T) = (128, T)
          feature_tensor = feature_tensor.squeeze(0)

      return feature_tensor, torch.tensor(target_bin, dtype=torch.long)

    def __del__(self):
        """Đóng file HDF5 khi object bị hủy (tốt cho quản lý tài nguyên)."""
        if self._h5database is not None:
            self._h5database.close()

# %% [markdown]
# ## MinimumOccupancySampler

# %%
class MinimumOccupancySampler(Sampler):
    """
        samples at least one instance from each class sequentially
    """
    def __init__(self, labels, sampling_mode='over', random_state=None):
        data_samples = labels.shape
        n_labels = len(np.unique(labels))
        label_to_idx_list, label_to_length = [], []
        self.random_state = np.random.RandomState(seed=random_state)
        for lb_idx in range(n_labels):
            label_indexes = np.where(labels == lb_idx)[0]
            self.random_state.shuffle(label_indexes)
            label_to_length.append(len(label_indexes))
            label_to_idx_list.append(label_indexes)

        self.longest_seq = max(label_to_length)
        self.data_source = np.empty((self.longest_seq, len(label_to_length)), dtype=int)
        # Each column represents one "single instance per class" data piece
        for ix, leng in enumerate(label_to_length):
            self.data_source[:leng, ix] = label_to_idx_list[ix]
        self.label_to_length = label_to_length
        self.label_to_idx_list = label_to_idx_list

        if sampling_mode == 'same':
            self.data_length = data_samples
        elif sampling_mode == 'over':  # Sample all items
            self.data_length = np.prod(self.data_source.shape)

    def _resample(self):
        for ix, leng in enumerate(self.label_to_length):
            leftover = self.longest_seq - leng
            random_idxs = np.random.randint(leng, size=leftover)
            self.data_source[leng:, ix] = self.label_to_idx_list[ix][random_idxs]

    def __iter__(self):
        self._resample()
        n_samples = len(self.data_source)
        random_indices = self.random_state.permutation(n_samples)
        data = np.concatenate(
            self.data_source[random_indices])[:self.data_length]
        return iter(data)

    def __len__(self):
        return self.data_length

# %% [markdown]
# ## HeartSoundDataLoader

# %%
class BaseDataLoader(DataLoader):
    """
    Base class for all data loaders
    """
    def __init__(self, dataset, batch_size, shuffle, validation_split, num_workers, collate_fn=default_collate, sampler_type=None):
        self.validation_split = validation_split
        self.shuffle = shuffle

        self.batch_idx = 0
        self.n_samples = len(dataset)
        self.sampler_type = sampler_type
        self.sampler, self.valid_sampler = self._split_sampler(self.validation_split)
        self.init_kwargs = {
            'dataset': dataset,
            'batch_size': batch_size,
            'shuffle': self.shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.sampler, **self.init_kwargs)

    def _split_sampler(self, split):
        if split == 0.0:
            return None, None

        idx_full = np.arange(self.n_samples)

        np.random.seed(0)
        np.random.shuffle(idx_full)

        if isinstance(split, int):
            assert split > 0
            assert split < self.n_samples, "validation set size is configured to be larger than entire dataset."
            len_valid = split
        else:
            len_valid = int(self.n_samples * split)

        valid_idx = idx_full[0:len_valid]
        train_idx = np.delete(idx_full, np.arange(0, len_valid))
        if self.sampler_type == 'MinimumOccupancySampler':
            train_sampler = MinimumOccupancySampler(np.stack(self.label_df.iloc[train_idx]['label']), random_state=100)
        else:
            train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        # turn off shuffle option which is mutually exclusive with sampler
        self.shuffle = False
        self.n_samples = len(train_idx)

        return train_sampler, valid_sampler

    def split_validation(self):
        if self.valid_sampler is None:
            return None
        else:
            return DataLoader(sampler=self.valid_sampler, **self.init_kwargs)

# %%
class HeartSoundDataLoader(DataLoader):
    def __init__(self,
                 fea_path,
                 label_df,
                 duration,
                 batch_size,
                 delta=False,
                 norm=False,
                 shuffle=True,
                 validation_split=0.0,
                 num_workers=1,
                 training=True,
                 collate_fn=None):

        if training:
            # --- ĐOẠN SỬA ĐỔI ĐỂ CHỐNG DATA LEAKAGE ---
            # 1. Tạo cột base_id bằng cách tách bỏ phần '_augX' trong tên file
            # Ví dụ: 'a0001_aug0' -> 'a0001'
            label_df['base_id'] = label_df['filename'].apply(lambda x: Path(x).stem.split('_aug')[0])

            # 2. Lấy danh sách các ID duy nhất (mỗi bệnh nhân chỉ xuất hiện 1 lần trong danh sách này)
            unique_ids = label_df['base_id'].unique()

            # 3. Chia Train/Val dựa trên danh sách ID duy nhất này
            # Điều này đảm bảo tất cả các bản augment của cùng 1 người sẽ nằm cùng 1 tập
            train_ids, val_ids = train_test_split(unique_ids, test_size=validation_split, random_state=100)

            # 4. Lọc lại DataFrame gốc dựa trên danh sách ID đã chia
            self.train_df = label_df[label_df['base_id'].isin(train_ids)].copy()
            self.val_df = label_df[label_df['base_id'].isin(val_ids)].copy()

            # 5. Xóa cột phụ base_id để tránh ảnh hưởng đến các lớp khác
            self.train_df.drop(columns=['base_id'], inplace=True)
            self.val_df.drop(columns=['base_id'], inplace=True)
            # ------------------------------------------

            # Giữ nguyên logic khởi tạo Sampler và Dataset
            self.train_sampler = MinimumOccupancySampler(np.stack(self.train_df['label']), random_state=100)
            self.val_dataset = HeartSoundDataSet(fea_path, self.val_df, duration=duration, training=False, delta=delta, norm=norm)

        else:
            self.train_df = label_df
            self.train_sampler = None

        self.dataset = HeartSoundDataSet(fea_path, self.train_df, duration=duration,
                                         training=training, delta=delta, norm=norm)

        self.init_kwargs = {
            'batch_size': batch_size,
            'shuffle': shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.train_sampler,
                         dataset=self.dataset,
                         **self.init_kwargs)

    def split_validation(self):
        return DataLoader(dataset=self.val_dataset, **self.init_kwargs)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_balanced.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("MFCC (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0001_aug0', 'a0001_aug1', 'a0001_aug2', 'a0002', 'a0002_aug0', 'a0002_aug1', 'a0002_aug2', 'a0003', 'a0003_aug0']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 1 1 1]
# Value range: -7.194 ~ 2.585

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features_validation.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_validation.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("Log-Mel Spectrogram (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0002', 'a0003', 'a0004', 'a0005', 'a0006', 'a0007', 'a0008', 'a0009', 'a0010']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 1 1 1]
# Value range: -7.711 ~ 3.083

# %% [markdown]
# # ConfigParser

# %%
# parse_config.py
import os
import logging
from pathlib import Path
from datetime import datetime
import argparse
import collections
import importlib.util

class ConfigParser:
    def __init__(self, config_dict, resume=None, modification=None, run_id=None):
        self._config = config_dict
        self.resume = resume

        # Apply CLI modifications
        if modification:
            for key_path, value in modification.items():
                keys = key_path.split(';')
                d = self._config
                for k in keys[:-1]:
                    d = d[k]
                d[keys[-1]] = value

        # Setup save and log directories
        save_dir = Path(self.config['trainer']['save_dir'])
        exper_name = self.config['name']
        if run_id is None:
            run_id = datetime.now().strftime(r'%m%d_%H%M%S')
        self._save_dir = save_dir / 'models' / exper_name / run_id
        self._log_dir = save_dir / 'log' / exper_name / run_id

        self.save_dir.mkdir(parents=True, exist_ok=True)
        self.log_dir.mkdir(parents=True, exist_ok=True)

        # Optional: setup logging
        # setup_logging(self.log_dir)

    @classmethod
    def from_args(cls, parser, options=None):
        """
        parser: argparse.ArgumentParser đã được add_argument xong
        options: list các CustomArgs để override
        """
        if options is None:
            options = []

        # Parse arguments (an toàn cho cả terminal và notebook)
        args = parser.parse_args()

        # Xử lý device
        if args.device is not None:
            os.environ["CUDA_VISIBLE_DEVICES"] = args.device

        # Xử lý resume
        if args.resume is not None:
            resume = Path(args.resume)
            cfg_fname = resume.parent / 'config.py'  # hoặc .json nếu bạn dùng cả 2
        else:
            resume = None
            assert args.config is not None, "Phải chỉ định -c config.py"
            cfg_fname = Path(args.config)

        # Đọc config từ file .py
        if not cfg_fname.exists():
            raise FileNotFoundError(f"Không tìm thấy config file: {cfg_fname}")

        if cfg_fname.suffix == '.py':
            spec = importlib.util.spec_from_file_location("config_module", cfg_fname)
            config_module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(config_module)
            if not hasattr(config_module, 'config'):
                raise ValueError(f"File {cfg_fname} phải định nghĩa biến 'config'")
            config_dict = config_module.config
        else:
            raise ValueError("Chỉ hỗ trợ file config .py")

        # Parse custom CLI overrides
        CustomArgs = collections.namedtuple('CustomArgs', 'flags type target')
        modification = {}
        for opt in options:
            for flag in opt.flags:
                arg_name = flag.lstrip('-').replace('-', '_')
                if hasattr(args, arg_name) and getattr(args, arg_name) is not None:
                    modification[opt.target] = opt.type(getattr(args, arg_name))

        return cls(config_dict, resume, modification)

    def init_obj(self, name, module, *args, **kwargs):
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def init_ftn(self, name, module, *args, **kwargs):
        from functools import partial
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def __getitem__(self, name):
        return self.config[name]

    def get_logger(self, name, verbosity=2):
        logger = logging.getLogger(name)
        logger.setLevel({0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}[verbosity])
        return logger

    @property
    def config(self):
        return self._config

    @property
    def save_dir(self):
        return self._save_dir

    @property
    def log_dir(self):
        return self._log_dir

# %% [markdown]
# # Logging

# %%
def mixup_data(x, y, alpha=0.2):
    """Mixup augmentation"""
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %% [markdown]
# #Loss

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=1.5):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        weight = torch.tensor(
            [1 - self.alpha, self.alpha], device=inputs.device
        ).float()   # [w_normal, w_abnormal]
        ce_loss = F.cross_entropy(inputs, targets, weight=weight, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean()

# %%
class CBFocalLoss(nn.Module):
    def __init__(self, samples_per_class, beta=0.9999, gamma=2.0):
        super().__init__()
        effective_num = 1.0 - np.power(beta, samples_per_class)
        weights = (1.0 - beta) / np.array(effective_num)
        self.weights = weights / np.sum(weights) * len(samples_per_class)
        self.gamma = gamma

    def forward(self, inputs, targets):
        weights = torch.tensor(self.weights, device=inputs.device).float()
        ce_loss = F.cross_entropy(inputs, targets, weight=weights, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# Sử dụng:
# samples_per_class = [số_mẫu_abnormal, số_mẫu_normal]

# %%
class WeightedCELoss(nn.Module):
    """
    Weighted Cross Entropy Loss
    """
    def __init__(self, weights):
        super().__init__()
        self.register_buffer(
            "weights", torch.tensor(weights, dtype=torch.float)
        )

    def forward(self, logits, target):
        return F.cross_entropy(
            logits,
            target,
            weight=self.weights
        )

# %%
class CostSensitiveLoss(nn.Module):
    """
    Cost-sensitive Cross Entropy
    FN (abnormal → normal) bị phạt nặng hơn FP
    """
    def __init__(self, fn_cost=2.5, fp_cost=1.0):
        super().__init__()
        self.fn_cost = fn_cost
        self.fp_cost = fp_cost

    def forward(self, logits, target):
        weights = torch.tensor(
            [self.fp_cost, self.fn_cost],
            device=logits.device
        )

        return F.cross_entropy(
            logits,
            target,
            weight=weights
        )

# %%
class CombinedLoss(nn.Module):
    def __init__(self, alpha=0.7, gamma=2.5, label_smoothing=0.1, focal_weight=0.7):
        self.focal_loss = ImprovedFocalLoss(alpha, gamma, label_smoothing)
        self.ce_loss = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# %%
import torch.nn.functional as F


def nll_loss(output, target):
    return F.nll_loss(output, target)

def ce_loss(output, target):
    return F.cross_entropy(output, target)

def focal_loss(output, target, alpha=0.75, gamma=2.0):
    return FocalLoss(alpha=alpha, gamma=gamma)(output, target)

# Dùng khi tỷ lệ abnormal ≪ normal.
def weighted_ce_loss(output, target, weights):
    return WeightedCELoss(weights)(output, target)

# Đặc biệt phù hợp bài toán y sinh, nơi bỏ sót bệnh (FN) nguy hiểm hơn FP.
def cost_sensitive_loss(output, target, fn_cost=2.5, fp_cost=1.0):
    return CostSensitiveLoss(fn_cost, fp_cost)(output, target)

LOSS_REGISTRY = {
    "ce_loss": lambda: nn.CrossEntropyLoss(),
    "focal_loss": lambda: FocalLoss(alpha=0.75, gamma=2.0),
    "cost_sensitive_loss": lambda: CostSensitiveLoss(fn_cost=2.5, fp_cost=1.0),
    "weighted_ce_loss": lambda weights: WeightedCELoss(weights),
}

# %% [markdown]
# # Metric

# %%
import torch


def accuracy(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
    return correct / len(target)

import torch

def sensitivity(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()
    return tp / (tp + fn + eps)


def f1_score(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)

        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fp = torch.sum((pred == positive_class) & (target != positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()

        precision = tp / (tp + fp + eps)
        recall    = tp / (tp + fn + eps)

        f1 = 2 * precision * recall / (precision + recall + eps)

    return f1

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

# Warmup scheduler
class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, lr_min=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.lr_min = lr_min
        self.base_lr = optimizer.param_groups[0]['lr']

    def step(self, epoch):
        if epoch < self.warmup_epochs:
            lr = self.base_lr * (epoch + 1) / self.warmup_epochs
        else:
            progress = (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs)
            lr = self.lr_min + (self.base_lr - self.lr_min) * 0.5 * (1 + np.cos(np.pi * progress))

        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr
        return lr

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif val_loss > self.best_score - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        else:
            self.best_score = val_loss
            self.counter = 0
        return False

# %% [markdown]
# # Model

# %%
import torch.nn as nn
import numpy as np
from abc import abstractmethod


class BaseModel(nn.Module):
    """
    Base class for all models
    """
    @abstractmethod
    def forward(self, *inputs):
        """
        Forward pass logic

        :return: Model output
        """
        raise NotImplementedError

    def __str__(self):
        """
        Model prints with number of trainable parameters
        """
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        params = sum([np.prod(p.size()) for p in model_parameters])
        return super().__str__() + '\nTrainable parameters: {}'.format(params)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# functions of initializing layers
def init_layer(layer):
    """Initialize a Linear or Convolutional layer."""
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, 'bias'):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)

def init_bn(bn):
    """Initialize a Batchnorm layer."""
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.)

def init_rnn(rnn):
    """init_rnn
    Initialized RNN weights, independent of type GRU/LSTM/RNN
    :param rnn: the rnn model
    """
    for name, param in rnn.named_parameters():
        if 'bias' in name:
            nn.init.constant_(param, 0.0)
        elif 'weight' in name:
            nn.init.xavier_uniform_(param)

def reset_parameters(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            init_layer(module)
        elif isinstance(module, nn.Linear):
            init_layer(module)
        elif isinstance(module, nn.BatchNorm2d):
            init_bn(module)
        elif isinstance(module, nn.LSTM):
            init_rnn(module)

# %% [markdown]
# ## Simple CNN Block

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super().__init__()  # Fix: thiếu dòng này trong code gốc
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(channels, channels // reduction),   # 128→8: 1024 params
            nn.ReLU(),
            nn.Linear(channels // reduction, channels),   # 8→128: 1024 params
            nn.Sigmoid()
        )

    def forward(self, x):  # Fix: thiếu forward() trong code gốc
        B, C, _, _ = x.shape
        s = self.squeeze(x).view(B, C)        # (B, C)
        e = self.excitation(s).view(B, C, 1, 1)  # (B, C, 1, 1)
        return x * e                           # channel-wise scaling


class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size,
                                   stride, padding, groups=in_channels, bias=False)
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU6(inplace=True)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        x = self.bn(x)
        return self.relu(x)

# === THÊM MỚI (chèn sau dòng 1101) ===

class GhostModule(nn.Module):
    """
    Tạo 2*out//2 = out feature maps: nửa từ conv thật, nửa từ depthwise rẻ tiền.
    Tiết kiệm ~50% tham số so với Conv2d thông thường.
    """
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        init_channels = out_channels // 2          # nửa từ conv thật
        ghost_channels = out_channels - init_channels  # nửa còn lại

        # Conv chính: tạo feature maps "thật"
        self.primary = nn.Sequential(
            nn.Conv2d(in_channels, init_channels, kernel_size=1, stride=stride, bias=False),
            nn.BatchNorm2d(init_channels),
            nn.ReLU6(inplace=True)
        )
        # Depthwise: tạo feature maps "ghost" từ primary output
        self.ghost = nn.Sequential(
            nn.Conv2d(init_channels, ghost_channels, kernel_size=3,
                      stride=1, padding=1, groups=init_channels, bias=False),
            nn.BatchNorm2d(ghost_channels),
            nn.ReLU6(inplace=True)
        )

    def forward(self, x):
        p = self.primary(x)         # (B, out//2, H, W)
        g = self.ghost(p)           # (B, out//2, H, W)
        return torch.cat([p, g], dim=1)  # (B, out, H, W)


class ShuffleBlock(nn.Module):
    """
    ShuffleNet V2-style block: split → branch → concat → shuffle.
    Không tốn thêm tham số cho việc trao đổi thông tin giữa các nhóm.
    """
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        self.stride = stride
        branch_channels = out_channels // 2

        if stride == 1:
            # Branch phải: xử lý nửa channels
            self.branch_right = nn.Sequential(
                nn.Conv2d(in_channels // 2, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True),
                nn.Conv2d(branch_channels, branch_channels, 3, stride=1,
                          padding=1, groups=branch_channels, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.Conv2d(branch_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True)
            )
            # Branch trái: identity (không có tham số)
        else:
            # stride=2: cả 2 branch đều có conv để downsample
            self.branch_left = nn.Sequential(
                nn.Conv2d(in_channels, in_channels, 3, stride=stride,
                          padding=1, groups=in_channels, bias=False),
                nn.BatchNorm2d(in_channels),
                nn.Conv2d(in_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True)
            )
            self.branch_right = nn.Sequential(
                nn.Conv2d(in_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True),
                nn.Conv2d(branch_channels, branch_channels, 3, stride=stride,
                          padding=1, groups=branch_channels, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.Conv2d(branch_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True)
            )

    @staticmethod
    def channel_shuffle(x, groups=2):
        """Shuffle channels giữa các group — không tốn tham số."""
        B, C, H, W = x.shape
        x = x.view(B, groups, C // groups, H, W)
        x = x.transpose(1, 2).contiguous()
        return x.view(B, C, H, W)

    def forward(self, x):
        if self.stride == 1:
            # Split: nửa trái identity, nửa phải qua branch
            left, right = x.chunk(2, dim=1)
            out = torch.cat([left, self.branch_right(right)], dim=1)
        else:
            out = torch.cat([self.branch_left(x), self.branch_right(x)], dim=1)

        return self.channel_shuffle(out, groups=2)

# %%
class LightweightHeartSoundCNN(nn.Module):
    """
    Ghost-SE + ShuffleBlock, channel progression: in → 24 → 48 → 96 → 128
    Target: ~25k–35k params
    """
    def __init__(self, num_classes=2, in_channel=1, dropout=0.2):
        super().__init__()
        self.in_channel = in_channel

        # Stem: in_channel → 24
        self.stem = nn.Sequential(
            nn.Conv2d(in_channel, 24, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(24),
            nn.ReLU6(inplace=True)
        )

        # Stage 1: 24 → 48, stride=2
        self.stage1 = ShuffleBlock(24, 48, stride=2)

        # Stage 2: 48 → 96, stride=2
        self.stage2 = ShuffleBlock(48, 96, stride=2)

        # Stage 3: 96 → 128, stride=2
        self.stage3 = ShuffleBlock(96, 128, stride=2)

        self.drop = nn.Dropout2d(0.1)

        # SE block: reduction=16 để tiết kiệm params
        self.se = SEBlock(channels=128, reduction=16)

        # Spatial attention: Conv 128→1
        self.spatial_attn = nn.Sequential(
            nn.Conv2d(128, 1, kernel_size=1, bias=False),
            nn.Sigmoid()
        )

        # Classifier: GAP → FC nhỏ → output
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Sequential(
            nn.Linear(128, 32),
            nn.ReLU6(),
            nn.Dropout(dropout),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        B, F, T = x.shape
        #x = x.view(B, self.in_channel, F // self.in_channel, T)
        x = x.unsqueeze(1)

        x = self.stem(x)           # (B, 24, H, T)

        x = self.stage1(x)         # (B, 48, H/2, T/2)
        x = self.drop(x)
        x = self.stage2(x)         # (B, 96, H/4, T/4)
        x = self.drop(x)
        x = self.stage3(x)         # (B, 128, H/8, T/8)

        # Channel attention
        x = self.se(x)

        # Spatial attention
        attn = self.spatial_attn(x)
        x = x * attn

        # GAP → FC
        x = x.mean(dim=[2, 3])     # (B, 128)
        x = self.dropout(x)
        return self.classifier(x)

# %% [markdown]
# ## Deeper CNN model, VGG like structure

# %% [markdown]
# ## RNN - BiLTSM

# %% [markdown]
# ## CRNN

# %% [markdown]
# # Config

# %% [markdown]
# ## CNN

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
from pathlib import Path

config_light_cnn = {
    "name": "Physionet_lightweight_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "LightweightHeartSoundCNN",
        "args": {
            "num_classes": 2,
            "in_channel": 1, #Declare channel
            "dropout": 0.2
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "AdamW",
        "args": {
            "lr": 2e-4, #2e-4
            "weight_decay": 1e-3, #0.0
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "combined_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "ReduceLROnPlateau",
        "args": {
            "mode": "max",
            "factor": 0.5,
            "patience": 10, # Tránh giảm LR quá sớm khi model chưa kịp học
            "min_lr": 5e-7
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 150,
        "save_dir": str(PROJECT_PATH / "saved"/"lightweight_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_MAcc",
        "early_stop": 30,
        "tensorboard": True,
        "use_mixup": True,
        "mixup_alpha": 0.1,
        "gradient_clip": 1.0
    }
}

# %% [markdown]
# ## CRNN

# %% [markdown]
# ## LTSM

# %% [markdown]
# ## VGG

# %% [markdown]
# # Training

# %%
def prepare_device(n_gpu_use):
    """
    setup GPU device if available. get gpu device indices which are used for DataParallel
    """
    n_gpu = torch.cuda.device_count()
    if n_gpu_use > 0 and n_gpu == 0:
        print("Warning: There\'s no GPU available on this machine,"
              "training will be performed on CPU.")
        n_gpu_use = 0
    if n_gpu_use > n_gpu:
        print(f"Warning: The number of GPU\'s configured to use is {n_gpu_use}, but only {n_gpu} are "
              "available on this machine.")
        n_gpu_use = n_gpu
    device = torch.device('cuda:0' if n_gpu_use > 0 else 'cpu')
    list_ids = list(range(n_gpu_use))
    return device, list_ids

# %%
class MetricTracker:
    def __init__(self, *keys, writer=None):
        self.writer = writer
        self._data = pd.DataFrame(index=keys, columns=['total', 'counts', 'average'])
        self.reset()

    def reset(self):
        for col in self._data.columns:
            self._data[col].values[:] = 0

    def update(self, key, value, n=1):
        if self.writer is not None:
            self.writer.add_scalar(key, value)
        df = self._data

        df.loc[key, "total"] += value * n
        df.loc[key, "counts"] += n
        df.loc[key, "average"] = df.loc[key, "total"] / df.loc[key, "counts"]


    def avg(self, key):
        return self._data.average[key]

    def result(self):
        return dict(self._data.average)

# %%
def setup_logging(save_dir, log_config='logger/logger_config.json', default_level=logging.INFO):
    """
    Setup logging configuration
    """
    log_config = Path(log_config)
    if log_config.is_file():
        config = read_json(log_config)
        # modify logging paths based on run config
        for _, handler in config['handlers'].items():
            if 'filename' in handler:
                handler['filename'] = str(save_dir / handler['filename'])

        logging.config.dictConfig(config)
    else:
        print("Warning: logging configuration file is not found in {}.".format(log_config))
        logging.basicConfig(level=default_level)
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %%
import torch
from abc import abstractmethod
from numpy import inf

def safe_append(lst, value):
    lst.append(value if value is not None else np.nan)

class BaseTrainer:
    """
    Base class for all trainers
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config):
        self.config = config
        self.logger = config.get_logger('trainer', config['trainer']['verbosity'])

        self.model = model
        self.criterion = criterion
        self.metric_ftns = metric_ftns
        self.optimizer = optimizer

        cfg_trainer = config['trainer']
        self.epochs = cfg_trainer['epochs']
        self.save_period = cfg_trainer['save_period']
        self.monitor = cfg_trainer.get('monitor', 'off')

        # configuration to monitor model performance and save best
        if self.monitor == 'off':
            self.mnt_mode = 'off'
            self.mnt_best = 0
        else:
            self.mnt_mode, self.mnt_metric = self.monitor.split()
            assert self.mnt_mode in ['min', 'max']

            self.mnt_best = inf if self.mnt_mode == 'min' else -inf
            self.early_stop = cfg_trainer.get('early_stop', inf)
            if self.early_stop <= 0:
                self.early_stop = inf

        self.start_epoch = 1

        self.checkpoint_dir = config.save_dir

        self.history = {
            "epoch": [],
            "train_loss": [],
            "train_accuracy": [],
            "val_loss": [],
            "val_accuracy": [],
            "val_F1_score": [],
            "val_sensitivity": [],
            "val_specificity": [],
            "val_MAcc": []
        }


        self.history_path = Path(self.checkpoint_dir) / "metrics.csv"

        # setup visualization writer instance
        self.writer = TensorboardWriter(config.log_dir, self.logger, cfg_trainer['tensorboard'])

        if config.resume is not None:
            self._resume_checkpoint(config.resume)

    @abstractmethod
    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Current epoch number
        """
        raise NotImplementedError

    def train(self):
        """
        Full training logic
        """
        not_improved_count = 0
        for epoch in range(self.start_epoch, self.epochs + 1):
            result = self._train_epoch(epoch)

            # save logged informations into log dict
            log = {'epoch': epoch}
            log.update(result)

            # ===== GHI METRICS SAU MỖI EPOCH =====
            safe_append(self.history["epoch"], epoch)
            safe_append(self.history["train_loss"], log.get("loss"))
            safe_append(self.history["train_accuracy"], log.get("accuracy"))

            safe_append(self.history["val_loss"], log.get("val_loss"))
            safe_append(self.history["val_accuracy"], log.get("val_accuracy"))
            safe_append(self.history["val_F1_score"], log.get("val_F1_score"))
            safe_append(self.history["val_sensitivity"], log.get("val_sensitivity"))
            safe_append(self.history["val_specificity"], log.get("val_specificity"))
            safe_append(self.history["val_MAcc"], log.get("val_MAcc"))



            pd.DataFrame(self.history).to_csv(self.history_path, index=False)

            # print logged informations to the screen
            for key, value in log.items():
                self.logger.info('    {:15s}: {}'.format(str(key), value))

            # evaluate model performance according to configured metric, save best checkpoint as model_best
            best = False
            if self.mnt_mode != 'off':
                try:
                    # check whether model performance improved or not, according to specified metric(mnt_metric)
                    improved = (self.mnt_mode == 'min' and log[self.mnt_metric] <= self.mnt_best) or \
                               (self.mnt_mode == 'max' and log[self.mnt_metric] >= self.mnt_best)
                except KeyError:
                    self.logger.warning("Warning: Metric '{}' is not found. "
                                        "Model performance monitoring is disabled.".format(self.mnt_metric))
                    self.mnt_mode = 'off'
                    improved = False

                if improved:
                    self.mnt_best = log[self.mnt_metric]
                    not_improved_count = 0
                    best = True
                else:
                    not_improved_count += 1

                if not_improved_count > self.early_stop:
                    self.logger.info("Validation performance didn\'t improve for {} epochs. "
                                     "Training stops.".format(self.early_stop))
                    break

            if best:
                self._save_best_model(epoch)

    def _save_checkpoint(self, epoch, save_best=False):
        """
        Saving checkpoints

        :param epoch: current epoch number
        :param log: logging information of the epoch
        :param save_best: if True, rename the saved checkpoint to 'model_best.pth'
        """
        arch = type(self.model).__name__
        state = {
            'arch': arch,
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'monitor_best': self.mnt_best,
            'config': self.config
        }
        filename = str(self.checkpoint_dir / 'checkpoint-epoch{}.pth'.format(epoch))
        torch.save(state, filename)
        self.logger.info("Saving checkpoint: {} ...".format(filename))
        if save_best:
            best_path = str(self.checkpoint_dir / 'model_best.pth')
            torch.save(state, best_path)
            self.logger.info("Saving current best: model_best.pth ...")

    def _resume_checkpoint(self, resume_path):
        """
        Resume from saved checkpoints

        :param resume_path: Checkpoint path to be resumed
        """
        resume_path = str(resume_path)
        self.logger.info("Loading checkpoint: {} ...".format(resume_path))
        checkpoint = torch.load(resume_path)
        self.start_epoch = checkpoint['epoch'] + 1
        self.mnt_best = checkpoint['monitor_best']

        # load architecture params from checkpoint.
        if checkpoint['config']['arch'] != self.config['arch']:
            self.logger.warning("Warning: Architecture configuration given in config file is different from that of "
                                "checkpoint. This may yield an exception while state_dict is being loaded.")
        self.model.load_state_dict(checkpoint['state_dict'])

        # load optimizer state from checkpoint only when optimizer type is not changed.
        if checkpoint['config']['optimizer']['type'] != self.config['optimizer']['type']:
            self.logger.warning("Warning: Optimizer type given in config file is different from that of checkpoint. "
                                "Optimizer parameters not being resumed.")
        else:
            self.optimizer.load_state_dict(checkpoint['optimizer'])

        self.logger.info("Checkpoint loaded. Resume training from epoch {}".format(self.start_epoch))

    def _save_best_model(self, epoch):
      """
      Save only the best model according to monitoring metric
      """
      arch = type(self.model).__name__
      state = {
          'arch': arch,
          'epoch': epoch,
          'state_dict': self.model.state_dict(),
          'optimizer': self.optimizer.state_dict(),
          'monitor_best': self.mnt_best,
          'config': self.config
      }

      best_path = self.checkpoint_dir / 'model_best.pth'
      torch.save(state, best_path)

      self.logger.info(
          f"Saving new best model at epoch {epoch}: model_best.pth"
      )

# %%
from itertools import repeat

def inf_loop(data_loader):
    ''' wrapper function for endless data loader. '''
    for loader in repeat(data_loader):
        yield from loader

# %%
class Trainer(BaseTrainer):
    """
    Trainer class
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config, device,
                 data_loader, valid_data_loader=None, lr_scheduler=None, len_epoch=None):
        super().__init__(model, criterion, metric_ftns, optimizer, config)
        self.config = config
        self.device = device
        self.data_loader = data_loader
        if len_epoch is None:
            # epoch-based training
            self.len_epoch = len(self.data_loader)
        else:
            # iteration-based training
            self.data_loader = inf_loop(data_loader)
            self.len_epoch = len_epoch
        self.valid_data_loader = valid_data_loader
        self.do_validation = self.valid_data_loader is not None
        self.lr_scheduler = lr_scheduler

        cfg_trainer = config['trainer']
        self.use_mixup = cfg_trainer.get("use_mixup", False)
        self.mixup_alpha = cfg_trainer.get("mixup_alpha", 0.2)
        self.gradient_clip = cfg_trainer.get("gradient_clip", 0.0)

        self.log_step = int(np.sqrt(data_loader.batch_size))

        self.train_metrics = MetricTracker('loss', *[m.__name__ for m in self.metric_ftns], writer=self.writer)
        self.valid_metrics = MetricTracker('loss',*[m.__name__ for m in self.metric_ftns],
                                           'sensitivity', 'specificity', 'MAcc', 'F1_score',
                                           writer = self.writer)


    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains average loss and metric in this epoch.
        """
        self.model.train()
        self.train_metrics.reset()
        for batch_idx, (data, target) in enumerate(self.data_loader):
            data, target = data.to(self.device), target.to(self.device)

            self.optimizer.zero_grad()

            if self.use_mixup and np.random.rand() > 0.5:
                data, targets_a, targets_b, lam = mixup_data(data, target, alpha=0.2)
                output = self.model(data)
                loss = mixup_criterion(self.criterion, output, targets_a, targets_b, lam)
            else:
                output = self.model(data)
                loss = self.criterion(output, target)

            loss.backward()
            if self.gradient_clip > 0:
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.gradient_clip)

            self.optimizer.step()
            if hasattr(self, 'ema'):
                self.ema.update()


            self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
            self.train_metrics.update('loss', loss.item())
            for met in self.metric_ftns:
                self.train_metrics.update(met.__name__, met(output, target))

            if batch_idx % self.log_step == 0:
                self.logger.debug('Train Epoch: {} {} Loss: {:.6f}'.format(
                    epoch,
                    self._progress(batch_idx),
                    loss.item()))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

            if batch_idx == self.len_epoch:
                break
        log = self.train_metrics.result()

        if self.do_validation:
            val_log = self._valid_epoch(epoch)
            log.update(**{'val_'+k : v for k, v in val_log.items()})

        #if self.lr_scheduler is not None:
            #self.lr_scheduler.step()

        if self.lr_scheduler is not None:
            if isinstance(self.lr_scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                # ReduceLROnPlateau cần metric để theo dõi (thường là val_loss)
                # Lấy giá trị 'loss' từ kết quả của hàm _valid_epoch
                self.lr_scheduler.step(val_log.get('MAcc', val_log['loss']))
            else:
                # Các scheduler khác như StepLR không cần tham số
                self.lr_scheduler.step()
        return log

    def _valid_epoch(self, epoch):
        """
        Validate after training an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains information about validation
        """
        self.model.eval()
        self.valid_metrics.reset()
        val_pred_pos = 0
        val_pred_neg = 0
        val_condition_pos = 0
        val_condition_neg = 0
        val_TP = 0
        val_TN = 0
        val_correct = 0
        val_total = 0
        use_ema = hasattr(self, 'ema')
        if use_ema:
            self.ema.apply_shadow()
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(self.valid_data_loader):
                data, target = data.to(self.device), target.to(self.device)
                output = self.model(data.float())
                loss = self.criterion(output, target)

                _,indices = torch.max(output, 1)

                pred_pos_idx = [i for i, x in enumerate(indices) if x == 1]
                condition_pos_idx = [i for i, x in enumerate(target) if x == 1]
                pred_neg_idx = [i for i, x in enumerate(indices) if x == 0]
                condition_neg_idx = [i for i, x in enumerate(target) if x == 0]

                val_pred_pos += len(pred_pos_idx)
                val_condition_pos += len(condition_pos_idx)
                val_pred_neg += len(pred_neg_idx)
                val_condition_neg += len(condition_neg_idx)
                val_TP += len([x for x in pred_pos_idx if x in condition_pos_idx])
                val_TN += len([x for x in pred_neg_idx if x in condition_neg_idx])
                correct = (indices == target).float()
                val_correct += torch.sum(correct).item()
                val_total += target.shape[0]

                self.writer.set_step((epoch - 1) * len(self.valid_data_loader) + batch_idx, 'valid')
                self.valid_metrics.update('loss', loss.item())
                for met in self.metric_ftns:
                    self.valid_metrics.update(met.__name__, met(output, target))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

        sensitivity = val_TP / val_condition_pos
        specificity = val_TN / val_condition_neg
        MAcc= (sensitivity + specificity) / 2
        if val_pred_pos == 0:
            precision = 0
            F1_score = 0
        else:
            precision = val_TP / val_pred_pos
            F1_score = 2 * (precision*sensitivity)/(precision+sensitivity)

        self.valid_metrics.update('sensitivity', sensitivity)
        self.valid_metrics.update('specificity', specificity)
        self.valid_metrics.update('MAcc',MAcc)
        self.valid_metrics.update('F1_score', F1_score)

        # add histogram of model parameters to the tensorboard
        for name, p in self.model.named_parameters():
            self.writer.add_histogram(name, p, bins='auto')

        if use_ema:
            self.ema.restore()

        return self.valid_metrics.result()

    def _progress(self, batch_idx):
        base = '[{}/{} ({:.0f}%)]'
        if hasattr(self.data_loader, 'n_samples'):
            current = batch_idx * self.data_loader.batch_size
            total = self.data_loader.n_samples
        else:
            current = batch_idx
            total = self.len_epoch
        return base.format(current, total, 100.0 * current / total)

# %% [markdown]
# ## Simple Train

# %%
#current_config = config_cnn
current_config  = config_light_cnn
#current_config = config_crnn
#current_config = config_lstm
#current_config = config_vgg

# %%
class EMA:
    def __init__(self, model, decay=0.999):
        self.model = model
        self.decay = decay
        self.shadow = {k: v.clone() for k, v in model.state_dict().items()}

    def update(self):
        for k, v in self.model.state_dict().items():
            self.shadow[k] = self.decay * self.shadow[k] + (1 - self.decay) * v

    def apply_shadow(self):
        self._backup = {k: v.clone() for k, v in self.model.state_dict().items()}
        self.model.load_state_dict(self.shadow)

    def restore(self):
        self.model.load_state_dict(self._backup)

# %%
# === THÊM MỚI trước def main() ===
from torch.optim.swa_utils import AveragedModel, SWALR

def apply_swa(model, data_loader, device, swa_epochs=20, swa_lr=1e-4):
    """
    Chạy SWA: train thêm swa_epochs với lr thấp, lấy trung bình weights.
    Gọi sau trainer.train() hoàn tất.
    """
    swa_model = AveragedModel(model)
    swa_scheduler = SWALR(
        torch.optim.AdamW(model.parameters(), lr=swa_lr),
        swa_lr=swa_lr
    )
    model.train()
    for epoch in range(swa_epochs):
        for data, target in data_loader:
            data, target = data.to(device).float(), target.to(device)
            pred = model(data)
            loss = nn.CrossEntropyLoss(label_smoothing=0.05)(pred, target)
            loss.backward()
            swa_scheduler.step()
        swa_model.update_parameters(model)

    # Cập nhật BatchNorm statistics cho SWA model
    torch.optim.swa_utils.update_bn(data_loader, swa_model, device=device)
    return swa_model

# %%
import os
import argparse
import collections
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

def main(config):

# Tạo ConfigParser từ biến config hiện tại
  config_parser = ConfigParser(config)

  # Train chính thức
  data_loader = config_parser.init_obj('data_loader', globals())  # hoặc import module phù hợp
  valid_data_loader = data_loader.split_validation()

  model = config_parser.init_obj('arch', globals())
  print(model)

  device, device_ids = prepare_device(config_parser['n_gpu'])
  model = model.to(device)
  if len(device_ids) > 1:
      model = torch.nn.DataParallel(model, device_ids=device_ids)


  focal = FocalLoss(alpha=0.6, gamma=2.0)
  ce_smooth = nn.CrossEntropyLoss(label_smoothing=0.05)

  criterion = lambda pred, target: (
      0.8 * focal(pred, target) +
      0.2 * ce_smooth(pred, target)
  )
  #criterion = FocalLoss(alpha=0.5, gamma=2.0)
  #criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
  '''
  criterion = nn.CrossEntropyLoss(
      weight=torch.tensor([1.0, 1.0]).to(device),  # Index 0 (Normal): 1.0, Index 1 (Abnormal): 2.5
      label_smoothing=0.05
  )
  '''
  #criterion = LOSS_REGISTRY["weighted_ce_loss"]([1.0, 2.5])
  metrics = [
      accuracy,
      f1_score
  ]

  optimizer = config_parser.init_obj('optimizer', torch.optim, filter(lambda p: p.requires_grad, model.parameters()))
  lr_scheduler = config_parser.init_obj('lr_scheduler', torch.optim.lr_scheduler, optimizer)

  trainer = Trainer(
      model=model,
      criterion=criterion,
      metric_ftns=metrics,
      optimizer=optimizer,
      config=config_parser,
      device=device,
      data_loader=data_loader,
      valid_data_loader=valid_data_loader,
      lr_scheduler=lr_scheduler
  )

  trainer.train()

  base_dir = (Path(config_parser['trainer']['save_dir'])/ "models"/ config_parser['name'])

  if not base_dir.exists():
    print("Models directory was not found.")
    return

  # Lấy run (timestamp) mới nhất
  latest_run = max(base_dir.iterdir(), key=os.path.getmtime)

  best_model_path = latest_run / "model_best.pth"

  if best_model_path.exists():
    print("\n=== HOÀN THÀNH TRAINING ===")
    print("Model tốt nhất được lưu tại:")
    print(best_model_path)
  else:
    print("The file 'model_best.pth' was not found.")

  metrics_path = Path(config_parser.save_dir) / "metrics.csv"

  if metrics_path.exists():
    df = pd.read_csv(metrics_path)
    epochs = df["epoch"]
  else:
    print("The file 'metrics.csv' was not found. Unable to display training results.")

  # ===== LOSS =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training and Validation Loss")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "loss_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== ACCURACY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_accuracy"], label="Training Accuracy")
  plt.plot(epochs, df["val_accuracy"], label="Validation Accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training and Validation Accuracy")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "accuracy_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== F1-SCORE =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_F1_score"], label="Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.title("Validation F1-score across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "f1_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== SENSITIVITY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_sensitivity"], label="Validation Sensitivity")
  plt.xlabel("Epoch")
  plt.ylabel("Sensitivity")
  plt.title("Validation Sensitivity across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "sensitivity_curve.png", dpi=300)
  plt.show()
  plt.close()

# %%
if __name__ == "__main__":
    # Train model với config hiện tại
    main(current_config)

    # Sau khi train xong, tự động test trên tập validation riêng (nếu có file)
    base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
# Out:
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (stage1): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage2): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage3): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (drop): Dropout2d(p=0.1, inplace=False)
#   (se): SEBlock(
#     (squeeze): AdaptiveAvgPool2d(output_size=1)
#     (excitation): Sequential(
#       (0): Linear(in_features=128, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (spatial_attn): Sequential(
#     (0): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): Sigmoid()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU6()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# DEBUG:trainer:Train Epoch: 1 [0/66 (0%)] Loss: 0.162019
# DEBUG:trainer:Train Epoch: 1 [8/66 (12%)] Loss: 0.162356
# DEBUG:trainer:Train Epoch: 1 [16/66 (24%)] Loss: 0.161368
# DEBUG:trainer:Train Epoch: 1 [24/66 (36%)] Loss: 0.161624
# DEBUG:trainer:Train Epoch: 1 [32/66 (48%)] Loss: 0.160793
# DEBUG:trainer:Train Epoch: 1 [40/66 (61%)] Loss: 0.161186
# DEBUG:trainer:Train Epoch: 1 [48/66 (73%)] Loss: 0.158536
# DEBUG:trainer:Train Epoch: 1 [56/66 (85%)] Loss: 0.156150
# DEBUG:trainer:Train Epoch: 1 [64/66 (97%)] Loss: 0.155495
# INFO:trainer:    epoch          : 1
# INFO:trainer:    loss           : 0.16032717670455124
# INFO:trainer:    accuracy       : 0.5018939393939394
# INFO:trainer:    f1_score       : 0.667415471562858
# INFO:trainer:    val_loss       : 0.1535958279581631
# INFO:trainer:    val_accuracy   : 0.5645220588235295
# INFO:trainer:    val_f1_score   : 0.6636878387590264
# INFO:trainer:    val_sensitivity: 1.0
# INFO:trainer:    val_specificity: 0.08414872798434442
# INFO:trainer:    val_MAcc       : 0.5420743639921722
# INFO:trainer:    val_F1_score   : 0.70076726342711
# INFO:trainer:Saving new best model at epoch 1: model_best.pth
# DEBUG:trainer:Train Epoch: 2 [0/66 (0%)] Loss: 0.153493
# DEBUG:trainer:Train Epoch: 2 [8/66 (12%)] Loss: 0.150990
# DEBUG:trainer:Train Epoch: 2 [16/66 (24%)] Loss: 0.149091
# DEBUG:trainer:Train Epoch: 2 [24/66 (36%)] Loss: 0.148197
# DEBUG:trainer:Train Epoch: 2 [32/66 (48%)] Loss: 0.145751
# DEBUG:trainer:Train Epoch: 2 [40/66 (61%)] Loss: 0.145564
# DEBUG:trainer:Train Epoch: 2 [48/66 (73%)] Loss: 0.133279
# DEBUG:trainer:Train Epoch: 2 [56/66 (85%)] Loss: 0.148367
# DEBUG:trainer:Train Epoch: 2 [64/66 (97%)] Loss: 0.138625
# INFO:trainer:    epoch          : 2
# INFO:trainer:    loss           : 0.143516795766173
# INFO:trainer:    accuracy       : 0.6536458333333334
# INFO:trainer:    f1_score       : 0.7193711215794896
# INFO:trainer:    val_loss       : 0.12958104294889114
# INFO:trainer:    val_accuracy   : 0.7733718487394958
# INFO:trainer:    val_f1_score   : 0.7843894839551435
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.6673189823874756
# INFO:trainer:    val_MAcc       : 0.7789149656462926
# INFO:trainer:    val_F1_score   : 0.8092868988391376
# INFO:trainer:Saving new best model at epoch 2: model_best.pth
# DEBUG:trainer:Train Epoch: 3 [0/66 (0%)] Loss: 0.130812
# DEBUG:trainer:Train Epoch: 3 [8/66 (12%)] Loss: 0.122781
# DEBUG:trainer:Train Epoch: 3 [16/66 (24%)] Loss: 0.113296
# DEBUG:trainer:Train Epoch: 3 [24/66 (36%)] Loss: 0.132729
# DEBUG:trainer:Train Epoch: 3 [32/66 (48%)] Loss: 0.117424
# DEBUG:trainer:Train Epoch: 3 [40/66 (61%)] Loss: 0.098200
# DEBUG:trainer:Train Epoch: 3 [48/66 (73%)] Loss: 0.128539
# DEBUG:trainer:Train Epoch: 3 [56/66 (85%)] Loss: 0.096475
# DEBUG:trainer:Train Epoch: 3 [64/66 (97%)] Loss: 0.099549
# INFO:trainer:    epoch          : 3
# INFO:trainer:    loss           : 0.11993108102769563
# INFO:trainer:    accuracy       : 0.7469223484848485
# INFO:trainer:    f1_score       : 0.7699971609861004
# INFO:trainer:    val_loss       : 0.11225664440323324
# INFO:trainer:    val_accuracy   : 0.8065913865546218
# INFO:trainer:    val_f1_score   : 0.825030101568814
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.7299412915851272
# INFO:trainer:    val_MAcc       : 0.8102261202451184
# INFO:trainer:    val_F1_score   : 0.8313458262350938
# INFO:trainer:Saving new best model at epoch 3: model_best.pth
# DEBUG:trainer:Train Epoch: 4 [0/66 (0%)] Loss: 0.144890
# DEBUG:trainer:Train Epoch: 4 [8/66 (12%)] Loss: 0.114439
# DEBUG:trainer:Train Epoch: 4 [16/66 (24%)] Loss: 0.112294
# DEBUG:trainer:Train Epoch: 4 [24/66 (36%)] Loss: 0.129299
# DEBUG:trainer:Train Epoch: 4 [32/66 (48%)] Loss: 0.128284
# DEBUG:trainer:Train Epoch: 4 [40/66 (61%)] Loss: 0.098997
# DEBUG:trainer:Train Epoch: 4 [48/66 (73%)] Loss: 0.091832
# DEBUG:trainer:Train Epoch: 4 [56/66 (85%)] Loss: 0.120574
# DEBUG:trainer:Train Epoch: 4 [64/66 (97%)] Loss: 0.098170
# INFO:trainer:    epoch          : 4
# INFO:trainer:    loss           : 0.11533664674921469
# INFO:trainer:    accuracy       : 0.7670454545454546
# INFO:trainer:    f1_score       : 0.7887586252638145
# INFO:trainer:    val_loss       : 0.10755668733926381
# INFO:trainer:    val_accuracy   : 0.8067226890756302
# INFO:trainer:    val_f1_score   : 0.8314288452799989
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7064579256360078
# INFO:trainer:    val_MAcc       : 0.8057837073435514
# INFO:trainer:    val_F1_score   : 0.8308207705192631
# DEBUG:trainer:Train Epoch: 5 [0/66 (0%)] Loss: 0.106793
# DEBUG:trainer:Train Epoch: 5 [8/66 (12%)] Loss: 0.115932
# DEBUG:trainer:Train Epoch: 5 [16/66 (24%)] Loss: 0.119628
# DEBUG:trainer:Train Epoch: 5 [24/66 (36%)] Loss: 0.104617
# DEBUG:trainer:Train Epoch: 5 [32/66 (48%)] Loss: 0.086267
# DEBUG:trainer:Train Epoch: 5 [40/66 (61%)] Loss: 0.092149
# DEBUG:trainer:Train Epoch: 5 [48/66 (73%)] Loss: 0.134277
# DEBUG:trainer:Train Epoch: 5 [56/66 (85%)] Loss: 0.092673
# DEBUG:trainer:Train Epoch: 5 [64/66 (97%)] Loss: 0.199152
# INFO:trainer:    epoch          : 5
# INFO:trainer:    loss           : 0.11170752041719177
# INFO:trainer:    accuracy       : 0.7490530303030303
# INFO:trainer:    f1_score       : 0.7694255082806789
# INFO:trainer:    val_loss       : 0.10731253597666235
# INFO:trainer:    val_accuracy   : 0.8028886554621849
# INFO:trainer:    val_f1_score   : 0.8230991799598926
# INFO:trainer:    val_sensitivity: 0.8321167883211679
# INFO:trainer:    val_specificity: 0.7749510763209393
# INFO:trainer:    val_MAcc       : 0.8035339323210535
# INFO:trainer:    val_F1_score   : 0.8150134048257373
# DEBUG:trainer:Train Epoch: 6 [0/66 (0%)] Loss: 0.089136
# DEBUG:trainer:Train Epoch: 6 [8/66 (12%)] Loss: 0.124057
# DEBUG:trainer:Train Epoch: 6 [16/66 (24%)] Loss: 0.100919
# DEBUG:trainer:Train Epoch: 6 [24/66 (36%)] Loss: 0.120039
# DEBUG:trainer:Train Epoch: 6 [32/66 (48%)] Loss: 0.104981
# DEBUG:trainer:Train Epoch: 6 [40/66 (61%)] Loss: 0.135520
# DEBUG:trainer:Train Epoch: 6 [48/66 (73%)] Loss: 0.105714
# DEBUG:trainer:Train Epoch: 6 [56/66 (85%)] Loss: 0.106730
# DEBUG:trainer:Train Epoch: 6 [64/66 (97%)] Loss: 0.104436
# INFO:trainer:    epoch          : 6
# INFO:trainer:    loss           : 0.10783969870570934
# INFO:trainer:    accuracy       : 0.7755681818181818
# INFO:trainer:    f1_score       : 0.7931952297700104
# INFO:trainer:    val_loss       : 0.10501920716727481
# INFO:trainer:    val_accuracy   : 0.8137605042016807
# INFO:trainer:    val_f1_score   : 0.8356189773461173
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.7495107632093934
# INFO:trainer:    val_MAcc       : 0.8127115859842587
# INFO:trainer:    val_F1_score   : 0.8304498269896193
# INFO:trainer:Saving new best model at epoch 6: model_best.pth
# DEBUG:trainer:Train Epoch: 7 [0/66 (0%)] Loss: 0.080801
# DEBUG:trainer:Train Epoch: 7 [8/66 (12%)] Loss: 0.105983
# DEBUG:trainer:Train Epoch: 7 [16/66 (24%)] Loss: 0.089073
# DEBUG:trainer:Train Epoch: 7 [24/66 (36%)] Loss: 0.082482
# DEBUG:trainer:Train Epoch: 7 [32/66 (48%)] Loss: 0.090807
# DEBUG:trainer:Train Epoch: 7 [40/66 (61%)] Loss: 0.100462
# DEBUG:trainer:Train Epoch: 7 [48/66 (73%)] Loss: 0.090295
# DEBUG:trainer:Train Epoch: 7 [56/66 (85%)] Loss: 0.097182
# DEBUG:trainer:Train Epoch: 7 [64/66 (97%)] Loss: 0.082796
# INFO:trainer:    epoch          : 7
# INFO:trainer:    loss           : 0.10261641826593515
# INFO:trainer:    accuracy       : 0.7462121212121212
# INFO:trainer:    f1_score       : 0.7641295988548189
# INFO:trainer:    val_loss       : 0.10155883803963661
# INFO:trainer:    val_accuracy   : 0.823266806722689
# INFO:trainer:    val_f1_score   : 0.8489486203723241
# INFO:trainer:    val_sensitivity: 0.9197080291970803
# INFO:trainer:    val_specificity: 0.726027397260274
# INFO:trainer:    val_MAcc       : 0.8228677132286771
# INFO:trainer:    val_F1_score   : 0.8456375838926175
# INFO:trainer:Saving new best model at epoch 7: model_best.pth
# DEBUG:trainer:Train Epoch: 8 [0/66 (0%)] Loss: 0.113156
# DEBUG:trainer:Train Epoch: 8 [8/66 (12%)] Loss: 0.100734
# DEBUG:trainer:Train Epoch: 8 [16/66 (24%)] Loss: 0.136551
# DEBUG:trainer:Train Epoch: 8 [24/66 (36%)] Loss: 0.088211
# DEBUG:trainer:Train Epoch: 8 [32/66 (48%)] Loss: 0.108612
# DEBUG:trainer:Train Epoch: 8 [40/66 (61%)] Loss: 0.063747
# DEBUG:trainer:Train Epoch: 8 [48/66 (73%)] Loss: 0.081061
# DEBUG:trainer:Train Epoch: 8 [56/66 (85%)] Loss: 0.084725
# DEBUG:trainer:Train Epoch: 8 [64/66 (97%)] Loss: 0.103308
# INFO:trainer:    epoch          : 8
# INFO:trainer:    loss           : 0.10038804657983058
# INFO:trainer:    accuracy       : 0.7760416666666666
# INFO:trainer:    f1_score       : 0.7927475607772617
# INFO:trainer:    val_loss       : 0.10283139983520788
# INFO:trainer:    val_accuracy   : 0.8176207983193278
# INFO:trainer:    val_f1_score   : 0.8429848327773282
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.7847358121330724
# INFO:trainer:    val_MAcc       : 0.8230248403731055
# INFO:trainer:    val_F1_score   : 0.8353982300884956
# INFO:trainer:Saving new best model at epoch 8: model_best.pth
# DEBUG:trainer:Train Epoch: 9 [0/66 (0%)] Loss: 0.071859
# DEBUG:trainer:Train Epoch: 9 [8/66 (12%)] Loss: 0.079384
# DEBUG:trainer:Train Epoch: 9 [16/66 (24%)] Loss: 0.103258
# DEBUG:trainer:Train Epoch: 9 [24/66 (36%)] Loss: 0.090230
# DEBUG:trainer:Train Epoch: 9 [32/66 (48%)] Loss: 0.089837
# DEBUG:trainer:Train Epoch: 9 [40/66 (61%)] Loss: 0.110449
# DEBUG:trainer:Train Epoch: 9 [48/66 (73%)] Loss: 0.082382
# DEBUG:trainer:Train Epoch: 9 [56/66 (85%)] Loss: 0.074039
# DEBUG:trainer:Train Epoch: 9 [64/66 (97%)] Loss: 0.079222
# INFO:trainer:    epoch          : 9
# INFO:trainer:    loss           : 0.1030518627076438
# INFO:trainer:    accuracy       : 0.7679924242424242
# INFO:trainer:    f1_score       : 0.7831292908894707
# INFO:trainer:    val_loss       : 0.09991274248151218
# INFO:trainer:    val_accuracy   : 0.8413340336134454
# INFO:trainer:    val_f1_score   : 0.8668357472579372
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.776908023483366
# INFO:trainer:    val_MAcc       : 0.8410087562672304
# INFO:trainer:    val_F1_score   : 0.8566493955094991
# INFO:trainer:Saving new best model at epoch 9: model_best.pth
# DEBUG:trainer:Train Epoch: 10 [0/66 (0%)] Loss: 0.158709
# DEBUG:trainer:Train Epoch: 10 [8/66 (12%)] Loss: 0.160188
# DEBUG:trainer:Train Epoch: 10 [16/66 (24%)] Loss: 0.091868
# DEBUG:trainer:Train Epoch: 10 [24/66 (36%)] Loss: 0.096328
# DEBUG:trainer:Train Epoch: 10 [32/66 (48%)] Loss: 0.078209
# DEBUG:trainer:Train Epoch: 10 [40/66 (61%)] Loss: 0.094351
# DEBUG:trainer:Train Epoch: 10 [48/66 (73%)] Loss: 0.121557
# DEBUG:trainer:Train Epoch: 10 [56/66 (85%)] Loss: 0.093108
# DEBUG:trainer:Train Epoch: 10 [64/66 (97%)] Loss: 0.116971
# INFO:trainer:    epoch          : 10
# INFO:trainer:    loss           : 0.10213307110649167
# INFO:trainer:    accuracy       : 0.7587594696969697
# INFO:trainer:    f1_score       : 0.7776532003470225
# INFO:trainer:    val_loss       : 0.0977298036655959
# INFO:trainer:    val_accuracy   : 0.8277048319327731
# INFO:trainer:    val_f1_score   : 0.8565702256554617
# INFO:trainer:    val_sensitivity: 0.8832116788321168
# INFO:trainer:    val_specificity: 0.7729941291585127
# INFO:trainer:    val_MAcc       : 0.8281029039953147
# INFO:trainer:    val_F1_score   : 0.8432055749128919
# DEBUG:trainer:Train Epoch: 11 [0/66 (0%)] Loss: 0.134254
# DEBUG:trainer:Train Epoch: 11 [8/66 (12%)] Loss: 0.092733
# DEBUG:trainer:Train Epoch: 11 [16/66 (24%)] Loss: 0.079207
# DEBUG:trainer:Train Epoch: 11 [24/66 (36%)] Loss: 0.098649
# DEBUG:trainer:Train Epoch: 11 [32/66 (48%)] Loss: 0.078636
# DEBUG:trainer:Train Epoch: 11 [40/66 (61%)] Loss: 0.079715
# DEBUG:trainer:Train Epoch: 11 [48/66 (73%)] Loss: 0.096331
# DEBUG:trainer:Train Epoch: 11 [56/66 (85%)] Loss: 0.082455
# DEBUG:trainer:Train Epoch: 11 [64/66 (97%)] Loss: 0.137282
# INFO:trainer:    epoch          : 11
# INFO:trainer:    loss           : 0.10434280369769443
# INFO:trainer:    accuracy       : 0.7653882575757576
# INFO:trainer:    f1_score       : 0.7811613565667526
# INFO:trainer:    val_loss       : 0.09819869280737989
# INFO:trainer:    val_accuracy   : 0.8387342436974791
# INFO:trainer:    val_f1_score   : 0.8659691297883225
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7729941291585127
# INFO:trainer:    val_MAcc       : 0.8390518091048038
# INFO:trainer:    val_F1_score   : 0.8551724137931034
# DEBUG:trainer:Train Epoch: 12 [0/66 (0%)] Loss: 0.100224
# DEBUG:trainer:Train Epoch: 12 [8/66 (12%)] Loss: 0.083249
# DEBUG:trainer:Train Epoch: 12 [16/66 (24%)] Loss: 0.081259
# DEBUG:trainer:Train Epoch: 12 [24/66 (36%)] Loss: 0.078482
# DEBUG:trainer:Train Epoch: 12 [32/66 (48%)] Loss: 0.090248
# DEBUG:trainer:Train Epoch: 12 [40/66 (61%)] Loss: 0.099373
# DEBUG:trainer:Train Epoch: 12 [48/66 (73%)] Loss: 0.073332
# DEBUG:trainer:Train Epoch: 12 [56/66 (85%)] Loss: 0.082567
# DEBUG:trainer:Train Epoch: 12 [64/66 (97%)] Loss: 0.077901
# INFO:trainer:    epoch          : 12
# INFO:trainer:    loss           : 0.09811429431041081
# INFO:trainer:    accuracy       : 0.7807765151515151
# INFO:trainer:    f1_score       : 0.79754058108657
# INFO:trainer:    val_loss       : 0.09881979818729793
# INFO:trainer:    val_accuracy   : 0.8155987394957984
# INFO:trainer:    val_f1_score   : 0.8362633392852229
# INFO:trainer:    val_sensitivity: 0.8321167883211679
# INFO:trainer:    val_specificity: 0.8003913894324853
# INFO:trainer:    val_MAcc       : 0.8162540888768266
# INFO:trainer:    val_F1_score   : 0.8245931283905967
# DEBUG:trainer:Train Epoch: 13 [0/66 (0%)] Loss: 0.114046
# DEBUG:trainer:Train Epoch: 13 [8/66 (12%)] Loss: 0.136064
# DEBUG:trainer:Train Epoch: 13 [16/66 (24%)] Loss: 0.091903
# DEBUG:trainer:Train Epoch: 13 [24/66 (36%)] Loss: 0.074057
# DEBUG:trainer:Train Epoch: 13 [32/66 (48%)] Loss: 0.086654
# DEBUG:trainer:Train Epoch: 13 [40/66 (61%)] Loss: 0.085557
# DEBUG:trainer:Train Epoch: 13 [48/66 (73%)] Loss: 0.091268
# DEBUG:trainer:Train Epoch: 13 [56/66 (85%)] Loss: 0.093657
# DEBUG:trainer:Train Epoch: 13 [64/66 (97%)] Loss: 0.082799
# INFO:trainer:    epoch          : 13
# INFO:trainer:    loss           : 0.09805222747452332
# INFO:trainer:    accuracy       : 0.7710700757575758
# INFO:trainer:    f1_score       : 0.7873685724124533
# INFO:trainer:    val_loss       : 0.09315645804300028
# INFO:trainer:    val_accuracy   : 0.8425682773109243
# INFO:trainer:    val_f1_score   : 0.8756974083204312
# INFO:trainer:    val_sensitivity: 0.927007299270073
# INFO:trainer:    val_specificity: 0.7592954990215264
# INFO:trainer:    val_MAcc       : 0.8431513991457997
# INFO:trainer:    val_F1_score   : 0.8617472434266327
# INFO:trainer:Saving new best model at epoch 13: model_best.pth
# DEBUG:trainer:Train Epoch: 14 [0/66 (0%)] Loss: 0.090242
# DEBUG:trainer:Train Epoch: 14 [8/66 (12%)] Loss: 0.081807
# DEBUG:trainer:Train Epoch: 14 [16/66 (24%)] Loss: 0.091059
# DEBUG:trainer:Train Epoch: 14 [24/66 (36%)] Loss: 0.182041
# DEBUG:trainer:Train Epoch: 14 [32/66 (48%)] Loss: 0.090924
# DEBUG:trainer:Train Epoch: 14 [40/66 (61%)] Loss: 0.107162
# DEBUG:trainer:Train Epoch: 14 [48/66 (73%)] Loss: 0.112440
# DEBUG:trainer:Train Epoch: 14 [56/66 (85%)] Loss: 0.147799
# DEBUG:trainer:Train Epoch: 14 [64/66 (97%)] Loss: 0.088919
# INFO:trainer:    epoch          : 14
# INFO:trainer:    loss           : 0.10005857129440163
# INFO:trainer:    accuracy       : 0.7511837121212122
# INFO:trainer:    f1_score       : 0.7692478255992573
# INFO:trainer:    val_loss       : 0.095598726588137
# INFO:trainer:    val_accuracy   : 0.8295430672268909
# INFO:trainer:    val_f1_score   : 0.8581869878590433
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.7690802348336595
# INFO:trainer:    val_MAcc       : 0.8297955918693845
# INFO:trainer:    val_F1_score   : 0.8457538994800693
# DEBUG:trainer:Train Epoch: 15 [0/66 (0%)] Loss: 0.160609
# DEBUG:trainer:Train Epoch: 15 [8/66 (12%)] Loss: 0.077797
# DEBUG:trainer:Train Epoch: 15 [16/66 (24%)] Loss: 0.076623
# DEBUG:trainer:Train Epoch: 15 [24/66 (36%)] Loss: 0.107369
# DEBUG:trainer:Train Epoch: 15 [32/66 (48%)] Loss: 0.084237
# DEBUG:trainer:Train Epoch: 15 [40/66 (61%)] Loss: 0.093555
# DEBUG:trainer:Train Epoch: 15 [48/66 (73%)] Loss: 0.083738
# DEBUG:trainer:Train Epoch: 15 [56/66 (85%)] Loss: 0.124144
# DEBUG:trainer:Train Epoch: 15 [64/66 (97%)] Loss: 0.077062
# INFO:trainer:    epoch          : 15
# INFO:trainer:    loss           : 0.09745310325965736
# INFO:trainer:    accuracy       : 0.7698863636363636
# INFO:trainer:    f1_score       : 0.7866369788980884
# INFO:trainer:    val_loss       : 0.09362450548831154
# INFO:trainer:    val_accuracy   : 0.843172268907563
# INFO:trainer:    val_f1_score   : 0.8744563307961563
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7808219178082192
# INFO:trainer:    val_MAcc       : 0.842965703429657
# INFO:trainer:    val_F1_score   : 0.8581314878892734
# DEBUG:trainer:Train Epoch: 16 [0/66 (0%)] Loss: 0.092265
# DEBUG:trainer:Train Epoch: 16 [8/66 (12%)] Loss: 0.082282
# DEBUG:trainer:Train Epoch: 16 [16/66 (24%)] Loss: 0.082367
# DEBUG:trainer:Train Epoch: 16 [24/66 (36%)] Loss: 0.092589
# DEBUG:trainer:Train Epoch: 16 [32/66 (48%)] Loss: 0.134444
# DEBUG:trainer:Train Epoch: 16 [40/66 (61%)] Loss: 0.096910
# DEBUG:trainer:Train Epoch: 16 [48/66 (73%)] Loss: 0.085594
# DEBUG:trainer:Train Epoch: 16 [56/66 (85%)] Loss: 0.144176
# DEBUG:trainer:Train Epoch: 16 [64/66 (97%)] Loss: 0.095660
# INFO:trainer:    epoch          : 16
# INFO:trainer:    loss           : 0.0952793625042294
# INFO:trainer:    accuracy       : 0.7535511363636364
# INFO:trainer:    f1_score       : 0.7713755028022753
# INFO:trainer:    val_loss       : 0.09168597880531759
# INFO:trainer:    val_accuracy   : 0.8490021008403361
# INFO:trainer:    val_f1_score   : 0.8794961287487224
# INFO:trainer:    val_sensitivity: 0.948905109489051
# INFO:trainer:    val_specificity: 0.7495107632093934
# INFO:trainer:    val_MAcc       : 0.8492079363492222
# INFO:trainer:    val_F1_score   : 0.8695652173913043
# INFO:trainer:Saving new best model at epoch 16: model_best.pth
# DEBUG:trainer:Train Epoch: 17 [0/66 (0%)] Loss: 0.091364
# DEBUG:trainer:Train Epoch: 17 [8/66 (12%)] Loss: 0.080647
# DEBUG:trainer:Train Epoch: 17 [16/66 (24%)] Loss: 0.082094
# DEBUG:trainer:Train Epoch: 17 [24/66 (36%)] Loss: 0.093241
# DEBUG:trainer:Train Epoch: 17 [32/66 (48%)] Loss: 0.174431
# DEBUG:trainer:Train Epoch: 17 [40/66 (61%)] Loss: 0.090513
# DEBUG:trainer:Train Epoch: 17 [48/66 (73%)] Loss: 0.071861
# DEBUG:trainer:Train Epoch: 17 [56/66 (85%)] Loss: 0.087142
# DEBUG:trainer:Train Epoch: 17 [64/66 (97%)] Loss: 0.119664
# INFO:trainer:    epoch          : 17
# INFO:trainer:    loss           : 0.09486496663003256
# INFO:trainer:    accuracy       : 0.771780303030303
# INFO:trainer:    f1_score       : 0.7865902413513362
# INFO:trainer:    val_loss       : 0.09118451134246938
# INFO:trainer:    val_accuracy   : 0.8520745798319327
# INFO:trainer:    val_f1_score   : 0.8856207918986605
# INFO:trainer:    val_sensitivity: 0.9416058394160584
# INFO:trainer:    val_specificity: 0.7671232876712328
# INFO:trainer:    val_MAcc       : 0.8543645635436456
# INFO:trainer:    val_F1_score   : 0.8723584108199492
# INFO:trainer:Saving new best model at epoch 17: model_best.pth
# DEBUG:trainer:Train Epoch: 18 [0/66 (0%)] Loss: 0.117729
# DEBUG:trainer:Train Epoch: 18 [8/66 (12%)] Loss: 0.081437
# DEBUG:trainer:Train Epoch: 18 [16/66 (24%)] Loss: 0.084214
# DEBUG:trainer:Train Epoch: 18 [24/66 (36%)] Loss: 0.076138
# DEBUG:trainer:Train Epoch: 18 [32/66 (48%)] Loss: 0.069343
# DEBUG:trainer:Train Epoch: 18 [40/66 (61%)] Loss: 0.113934
# DEBUG:trainer:Train Epoch: 18 [48/66 (73%)] Loss: 0.107181
# DEBUG:trainer:Train Epoch: 18 [56/66 (85%)] Loss: 0.088120
# DEBUG:trainer:Train Epoch: 18 [64/66 (97%)] Loss: 0.097616
# INFO:trainer:    epoch          : 18
# INFO:trainer:    loss           : 0.09364773445960248
# INFO:trainer:    accuracy       : 0.7914299242424242
# INFO:trainer:    f1_score       : 0.8060469653566131
# INFO:trainer:    val_loss       : 0.0926069904337911
# INFO:trainer:    val_accuracy   : 0.8470063025210085
# INFO:trainer:    val_f1_score   : 0.8749612307011008
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7906066536203522
# INFO:trainer:    val_MAcc       : 0.8478580713357236
# INFO:trainer:    val_F1_score   : 0.8618592528236317
# DEBUG:trainer:Train Epoch: 19 [0/66 (0%)] Loss: 0.073683
# DEBUG:trainer:Train Epoch: 19 [8/66 (12%)] Loss: 0.065756
# DEBUG:trainer:Train Epoch: 19 [16/66 (24%)] Loss: 0.100985
# DEBUG:trainer:Train Epoch: 19 [24/66 (36%)] Loss: 0.069206
# DEBUG:trainer:Train Epoch: 19 [32/66 (48%)] Loss: 0.085794
# DEBUG:trainer:Train Epoch: 19 [40/66 (61%)] Loss: 0.106510
# DEBUG:trainer:Train Epoch: 19 [48/66 (73%)] Loss: 0.078064
# DEBUG:trainer:Train Epoch: 19 [56/66 (85%)] Loss: 0.081552
# DEBUG:trainer:Train Epoch: 19 [64/66 (97%)] Loss: 0.145781
# INFO:trainer:    epoch          : 19
# INFO:trainer:    loss           : 0.09632213391137845
# INFO:trainer:    accuracy       : 0.7573390151515151
# INFO:trainer:    f1_score       : 0.7726362237535152
# INFO:trainer:    val_loss       : 0.09004087614662507
# INFO:trainer:    val_accuracy   : 0.8499212184873949
# INFO:trainer:    val_f1_score   : 0.8845908635432143
# INFO:trainer:    val_sensitivity: 0.9343065693430657
# INFO:trainer:    val_specificity: 0.7671232876712328
# INFO:trainer:    val_MAcc       : 0.8507149285071492
# INFO:trainer:    val_F1_score   : 0.8685326547921968
# DEBUG:trainer:Train Epoch: 20 [0/66 (0%)] Loss: 0.131266
# DEBUG:trainer:Train Epoch: 20 [8/66 (12%)] Loss: 0.090740
# DEBUG:trainer:Train Epoch: 20 [16/66 (24%)] Loss: 0.067357
# DEBUG:trainer:Train Epoch: 20 [24/66 (36%)] Loss: 0.081223
# DEBUG:trainer:Train Epoch: 20 [32/66 (48%)] Loss: 0.073791
# DEBUG:trainer:Train Epoch: 20 [40/66 (61%)] Loss: 0.073745
# DEBUG:trainer:Train Epoch: 20 [48/66 (73%)] Loss: 0.095684
# DEBUG:trainer:Train Epoch: 20 [56/66 (85%)] Loss: 0.106941
# DEBUG:trainer:Train Epoch: 20 [64/66 (97%)] Loss: 0.069114
# INFO:trainer:    epoch          : 20
# INFO:trainer:    loss           : 0.09476516130521442
# INFO:trainer:    accuracy       : 0.7774621212121212
# INFO:trainer:    f1_score       : 0.792828712436873
# INFO:trainer:    val_loss       : 0.0903814846978468
# INFO:trainer:    val_accuracy   : 0.8488445378151261
# INFO:trainer:    val_f1_score   : 0.8767776751732036
# INFO:trainer:    val_sensitivity: 0.927007299270073
# INFO:trainer:    val_specificity: 0.7710371819960861
# INFO:trainer:    val_MAcc       : 0.8490222406330795
# INFO:trainer:    val_F1_score   : 0.86615515771526
# DEBUG:trainer:Train Epoch: 21 [0/66 (0%)] Loss: 0.156706
# DEBUG:trainer:Train Epoch: 21 [8/66 (12%)] Loss: 0.092447
# DEBUG:trainer:Train Epoch: 21 [16/66 (24%)] Loss: 0.064640
# DEBUG:trainer:Train Epoch: 21 [24/66 (36%)] Loss: 0.080556
# DEBUG:trainer:Train Epoch: 21 [32/66 (48%)] Loss: 0.078720
# DEBUG:trainer:Train Epoch: 21 [40/66 (61%)] Loss: 0.093307
# DEBUG:trainer:Train Epoch: 21 [48/66 (73%)] Loss: 0.071806
# DEBUG:trainer:Train Epoch: 21 [56/66 (85%)] Loss: 0.080361
# DEBUG:trainer:Train Epoch: 21 [64/66 (97%)] Loss: 0.082645
# INFO:trainer:    epoch          : 21
# INFO:trainer:    loss           : 0.09108525723444694
# INFO:trainer:    accuracy       : 0.7608901515151515
# INFO:trainer:    f1_score       : 0.7749465546952115
# INFO:trainer:    val_loss       : 0.09043542777790743
# INFO:trainer:    val_accuracy   : 0.8424107142857143
# INFO:trainer:    val_f1_score   : 0.8699861065377088
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7729941291585127
# INFO:trainer:    val_MAcc       : 0.8427014441413001
# INFO:trainer:    val_F1_score   : 0.8591065292096219
# DEBUG:trainer:Train Epoch: 22 [0/66 (0%)] Loss: 0.141556
# DEBUG:trainer:Train Epoch: 22 [8/66 (12%)] Loss: 0.093824
# DEBUG:trainer:Train Epoch: 22 [16/66 (24%)] Loss: 0.084717
# DEBUG:trainer:Train Epoch: 22 [24/66 (36%)] Loss: 0.094789
# DEBUG:trainer:Train Epoch: 22 [32/66 (48%)] Loss: 0.078044
# DEBUG:trainer:Train Epoch: 22 [40/66 (61%)] Loss: 0.084639
# DEBUG:trainer:Train Epoch: 22 [48/66 (73%)] Loss: 0.088923
# DEBUG:trainer:Train Epoch: 22 [56/66 (85%)] Loss: 0.073946
# DEBUG:trainer:Train Epoch: 22 [64/66 (97%)] Loss: 0.072195
# INFO:trainer:    epoch          : 22
# INFO:trainer:    loss           : 0.09627498483115976
# INFO:trainer:    accuracy       : 0.7720170454545454
# INFO:trainer:    f1_score       : 0.7862831698378405
# INFO:trainer:    val_loss       : 0.09440964394632508
# INFO:trainer:    val_accuracy   : 0.8578781512605043
# INFO:trainer:    val_f1_score   : 0.8812317319616556
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.8043052837573386
# INFO:trainer:    val_MAcc       : 0.858357021440713
# INFO:trainer:    val_F1_score   : 0.8710801393728222
# INFO:trainer:Saving new best model at epoch 22: model_best.pth
# DEBUG:trainer:Train Epoch: 23 [0/66 (0%)] Loss: 0.145668
# DEBUG:trainer:Train Epoch: 23 [8/66 (12%)] Loss: 0.067861
# DEBUG:trainer:Train Epoch: 23 [16/66 (24%)] Loss: 0.106679
# DEBUG:trainer:Train Epoch: 23 [24/66 (36%)] Loss: 0.088525
# DEBUG:trainer:Train Epoch: 23 [32/66 (48%)] Loss: 0.087616
# DEBUG:trainer:Train Epoch: 23 [40/66 (61%)] Loss: 0.106838
# DEBUG:trainer:Train Epoch: 23 [48/66 (73%)] Loss: 0.080955
# DEBUG:trainer:Train Epoch: 23 [56/66 (85%)] Loss: 0.084351
# DEBUG:trainer:Train Epoch: 23 [64/66 (97%)] Loss: 0.100835
# INFO:trainer:    epoch          : 23
# INFO:trainer:    loss           : 0.09583523158322681
# INFO:trainer:    accuracy       : 0.7890625
# INFO:trainer:    f1_score       : 0.8032423495070824
# INFO:trainer:    val_loss       : 0.0909702199346879
# INFO:trainer:    val_accuracy   : 0.8408876050420168
# INFO:trainer:    val_f1_score   : 0.8696423342247941
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7729941291585127
# INFO:trainer:    val_MAcc       : 0.8427014441413001
# INFO:trainer:    val_F1_score   : 0.8591065292096219
# DEBUG:trainer:Train Epoch: 24 [0/66 (0%)] Loss: 0.087889
# DEBUG:trainer:Train Epoch: 24 [8/66 (12%)] Loss: 0.076789
# DEBUG:trainer:Train Epoch: 24 [16/66 (24%)] Loss: 0.100710
# DEBUG:trainer:Train Epoch: 24 [24/66 (36%)] Loss: 0.083829
# DEBUG:trainer:Train Epoch: 24 [32/66 (48%)] Loss: 0.077173
# DEBUG:trainer:Train Epoch: 24 [40/66 (61%)] Loss: 0.057316
# DEBUG:trainer:Train Epoch: 24 [48/66 (73%)] Loss: 0.080331
# DEBUG:trainer:Train Epoch: 24 [56/66 (85%)] Loss: 0.069934
# DEBUG:trainer:Train Epoch: 24 [64/66 (97%)] Loss: 0.101246
# INFO:trainer:    epoch          : 24
# INFO:trainer:    loss           : 0.09419987441012354
# INFO:trainer:    accuracy       : 0.7736742424242424
# INFO:trainer:    f1_score       : 0.788568732940943
# INFO:trainer:    val_loss       : 0.08993589308331995
# INFO:trainer:    val_accuracy   : 0.8486869747899161
# INFO:trainer:    val_f1_score   : 0.8783749106726368
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7847358121330724
# INFO:trainer:    val_MAcc       : 0.84857228562858
# INFO:trainer:    val_F1_score   : 0.8635578583765112
# DEBUG:trainer:Train Epoch: 25 [0/66 (0%)] Loss: 0.083280
# DEBUG:trainer:Train Epoch: 25 [8/66 (12%)] Loss: 0.081896
# DEBUG:trainer:Train Epoch: 25 [16/66 (24%)] Loss: 0.103504
# DEBUG:trainer:Train Epoch: 25 [24/66 (36%)] Loss: 0.074763
# DEBUG:trainer:Train Epoch: 25 [32/66 (48%)] Loss: 0.073732
# DEBUG:trainer:Train Epoch: 25 [40/66 (61%)] Loss: 0.074726
# DEBUG:trainer:Train Epoch: 25 [48/66 (73%)] Loss: 0.081549
# DEBUG:trainer:Train Epoch: 25 [56/66 (85%)] Loss: 0.088747
# DEBUG:trainer:Train Epoch: 25 [64/66 (97%)] Loss: 0.091154
# INFO:trainer:    epoch          : 25
# INFO:trainer:    loss           : 0.09080797083901637
# INFO:trainer:    accuracy       : 0.7402935606060606
# INFO:trainer:    f1_score       : 0.7565222210360346
# INFO:trainer:    val_loss       : 0.08954416171592824
# INFO:trainer:    val_accuracy   : 0.8447216386554621
# INFO:trainer:    val_f1_score   : 0.8763147369120742
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7984344422700587
# INFO:trainer:    val_MAcc       : 0.8481223306240804
# INFO:trainer:    val_F1_score   : 0.8608923884514434
# DEBUG:trainer:Train Epoch: 26 [0/66 (0%)] Loss: 0.067547
# DEBUG:trainer:Train Epoch: 26 [8/66 (12%)] Loss: 0.077111
# DEBUG:trainer:Train Epoch: 26 [16/66 (24%)] Loss: 0.154555
# DEBUG:trainer:Train Epoch: 26 [24/66 (36%)] Loss: 0.077595
# DEBUG:trainer:Train Epoch: 26 [32/66 (48%)] Loss: 0.064029
# DEBUG:trainer:Train Epoch: 26 [40/66 (61%)] Loss: 0.066986
# DEBUG:trainer:Train Epoch: 26 [48/66 (73%)] Loss: 0.088776
# DEBUG:trainer:Train Epoch: 26 [56/66 (85%)] Loss: 0.089405
# DEBUG:trainer:Train Epoch: 26 [64/66 (97%)] Loss: 0.088229
# INFO:trainer:    epoch          : 26
# INFO:trainer:    loss           : 0.08554273234172301
# INFO:trainer:    accuracy       : 0.8406723484848485
# INFO:trainer:    f1_score       : 0.8503774098433735
# INFO:trainer:    val_loss       : 0.0888805792612188
# INFO:trainer:    val_accuracy   : 0.8571165966386555
# INFO:trainer:    val_f1_score   : 0.8873335594467856
# INFO:trainer:    val_sensitivity: 0.927007299270073
# INFO:trainer:    val_specificity: 0.7886497064579256
# INFO:trainer:    val_MAcc       : 0.8578285028639994
# INFO:trainer:    val_F1_score   : 0.8728522336769758
# DEBUG:trainer:Train Epoch: 27 [0/66 (0%)] Loss: 0.078223
# DEBUG:trainer:Train Epoch: 27 [8/66 (12%)] Loss: 0.178251
# DEBUG:trainer:Train Epoch: 27 [16/66 (24%)] Loss: 0.089814
# DEBUG:trainer:Train Epoch: 27 [24/66 (36%)] Loss: 0.069769
# DEBUG:trainer:Train Epoch: 27 [32/66 (48%)] Loss: 0.159407
# DEBUG:trainer:Train Epoch: 27 [40/66 (61%)] Loss: 0.083160
# DEBUG:trainer:Train Epoch: 27 [48/66 (73%)] Loss: 0.066961
# DEBUG:trainer:Train Epoch: 27 [56/66 (85%)] Loss: 0.143055
# DEBUG:trainer:Train Epoch: 27 [64/66 (97%)] Loss: 0.086806
# INFO:trainer:    epoch          : 27
# INFO:trainer:    loss           : 0.08666485598818822
# INFO:trainer:    accuracy       : 0.7786458333333334
# INFO:trainer:    f1_score       : 0.7926217920646742
# INFO:trainer:    val_loss       : 0.08928251814316301
# INFO:trainer:    val_accuracy   : 0.8424107142857143
# INFO:trainer:    val_f1_score   : 0.8718488378783807
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7886497064579256
# INFO:trainer:    val_MAcc       : 0.843229962718014
# INFO:trainer:    val_F1_score   : 0.8571428571428571
# DEBUG:trainer:Train Epoch: 28 [0/66 (0%)] Loss: 0.096601
# DEBUG:trainer:Train Epoch: 28 [8/66 (12%)] Loss: 0.072511
# DEBUG:trainer:Train Epoch: 28 [16/66 (24%)] Loss: 0.066262
# DEBUG:trainer:Train Epoch: 28 [24/66 (36%)] Loss: 0.134265
# DEBUG:trainer:Train Epoch: 28 [32/66 (48%)] Loss: 0.068411
# DEBUG:trainer:Train Epoch: 28 [40/66 (61%)] Loss: 0.100723
# DEBUG:trainer:Train Epoch: 28 [48/66 (73%)] Loss: 0.078513
# DEBUG:trainer:Train Epoch: 28 [56/66 (85%)] Loss: 0.119119
# DEBUG:trainer:Train Epoch: 28 [64/66 (97%)] Loss: 0.059760
# INFO:trainer:    epoch          : 28
# INFO:trainer:    loss           : 0.0923272967903
# INFO:trainer:    accuracy       : 0.7961647727272727
# INFO:trainer:    f1_score       : 0.8088438472000532
# INFO:trainer:    val_loss       : 0.08823545036070488
# INFO:trainer:    val_accuracy   : 0.844248949579832
# INFO:trainer:    val_f1_score   : 0.8724133579392495
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7925636007827789
# INFO:trainer:    val_MAcc       : 0.8451869098804405
# INFO:trainer:    val_F1_score   : 0.8586387434554974
# DEBUG:trainer:Train Epoch: 29 [0/66 (0%)] Loss: 0.083595
# DEBUG:trainer:Train Epoch: 29 [8/66 (12%)] Loss: 0.071286
# DEBUG:trainer:Train Epoch: 29 [16/66 (24%)] Loss: 0.085235
# DEBUG:trainer:Train Epoch: 29 [24/66 (36%)] Loss: 0.080367
# DEBUG:trainer:Train Epoch: 29 [32/66 (48%)] Loss: 0.080626
# DEBUG:trainer:Train Epoch: 29 [40/66 (61%)] Loss: 0.099631
# DEBUG:trainer:Train Epoch: 29 [48/66 (73%)] Loss: 0.088869
# DEBUG:trainer:Train Epoch: 29 [56/66 (85%)] Loss: 0.085753
# DEBUG:trainer:Train Epoch: 29 [64/66 (97%)] Loss: 0.081803
# INFO:trainer:    epoch          : 29
# INFO:trainer:    loss           : 0.09305478417963693
# INFO:trainer:    accuracy       : 0.803030303030303
# INFO:trainer:    f1_score       : 0.8153024359816268
# INFO:trainer:    val_loss       : 0.09294476951746379
# INFO:trainer:    val_accuracy   : 0.8326155462184873
# INFO:trainer:    val_f1_score   : 0.8517532438617079
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.8101761252446184
# INFO:trainer:    val_MAcc       : 0.8357449969288785
# INFO:trainer:    val_F1_score   : 0.8451208594449418
# DEBUG:trainer:Train Epoch: 30 [0/66 (0%)] Loss: 0.085832
# DEBUG:trainer:Train Epoch: 30 [8/66 (12%)] Loss: 0.071756
# DEBUG:trainer:Train Epoch: 30 [16/66 (24%)] Loss: 0.084494
# DEBUG:trainer:Train Epoch: 30 [24/66 (36%)] Loss: 0.081162
# DEBUG:trainer:Train Epoch: 30 [32/66 (48%)] Loss: 0.097371
# DEBUG:trainer:Train Epoch: 30 [40/66 (61%)] Loss: 0.057319
# DEBUG:trainer:Train Epoch: 30 [48/66 (73%)] Loss: 0.152435
# DEBUG:trainer:Train Epoch: 30 [56/66 (85%)] Loss: 0.076861
# DEBUG:trainer:Train Epoch: 30 [64/66 (97%)] Loss: 0.065468
# INFO:trainer:    epoch          : 30
# INFO:trainer:    loss           : 0.08897876276662856
# INFO:trainer:    accuracy       : 0.8383049242424242
# INFO:trainer:    f1_score       : 0.847831355616494
# INFO:trainer:    val_loss       : 0.09584136449677103
# INFO:trainer:    val_accuracy   : 0.8378151260504202
# INFO:trainer:    val_f1_score   : 0.8565897887685499
# INFO:trainer:    val_sensitivity: 0.8321167883211679
# INFO:trainer:    val_specificity: 0.8493150684931506
# INFO:trainer:    val_MAcc       : 0.8407159284071593
# INFO:trainer:    val_F1_score   : 0.843663274745606
# DEBUG:trainer:Train Epoch: 31 [0/66 (0%)] Loss: 0.104276
# DEBUG:trainer:Train Epoch: 31 [8/66 (12%)] Loss: 0.065389
# DEBUG:trainer:Train Epoch: 31 [16/66 (24%)] Loss: 0.078786
# DEBUG:trainer:Train Epoch: 31 [24/66 (36%)] Loss: 0.078758
# DEBUG:trainer:Train Epoch: 31 [32/66 (48%)] Loss: 0.090963
# DEBUG:trainer:Train Epoch: 31 [40/66 (61%)] Loss: 0.196161
# DEBUG:trainer:Train Epoch: 31 [48/66 (73%)] Loss: 0.071679
# DEBUG:trainer:Train Epoch: 31 [56/66 (85%)] Loss: 0.079908
# DEBUG:trainer:Train Epoch: 31 [64/66 (97%)] Loss: 0.070662
# INFO:trainer:    epoch          : 31
# INFO:trainer:    loss           : 0.08814551929632823
# INFO:trainer:    accuracy       : 0.7682291666666666
# INFO:trainer:    f1_score       : 0.7813242130700344
# INFO:trainer:    val_loss       : 0.0869393819833503
# INFO:trainer:    val_accuracy   : 0.8606355042016807
# INFO:trainer:    val_f1_score   : 0.8947686184125755
# INFO:trainer:    val_sensitivity: 0.948905109489051
# INFO:trainer:    val_specificity: 0.7710371819960861
# INFO:trainer:    val_MAcc       : 0.8599711457425685
# INFO:trainer:    val_F1_score   : 0.8776371308016877
# INFO:trainer:Saving new best model at epoch 31: model_best.pth
# DEBUG:trainer:Train Epoch: 32 [0/66 (0%)] Loss: 0.076815
# DEBUG:trainer:Train Epoch: 32 [8/66 (12%)] Loss: 0.078685
# DEBUG:trainer:Train Epoch: 32 [16/66 (24%)] Loss: 0.170473
# DEBUG:trainer:Train Epoch: 32 [24/66 (36%)] Loss: 0.081743
# DEBUG:trainer:Train Epoch: 32 [32/66 (48%)] Loss: 0.072107
# DEBUG:trainer:Train Epoch: 32 [40/66 (61%)] Loss: 0.131890
# DEBUG:trainer:Train Epoch: 32 [48/66 (73%)] Loss: 0.095556
# DEBUG:trainer:Train Epoch: 32 [56/66 (85%)] Loss: 0.137021
# DEBUG:trainer:Train Epoch: 32 [64/66 (97%)] Loss: 0.077331
# INFO:trainer:    epoch          : 32
# INFO:trainer:    loss           : 0.08768458822459886
# INFO:trainer:    accuracy       : 0.8245738636363636
# INFO:trainer:    f1_score       : 0.8351253706981497
# INFO:trainer:    val_loss       : 0.08862896658041898
# INFO:trainer:    val_accuracy   : 0.8606355042016807
# INFO:trainer:    val_f1_score   : 0.8898216851269003
# INFO:trainer:    val_sensitivity: 0.9197080291970803
# INFO:trainer:    val_specificity: 0.8023483365949119
# INFO:trainer:    val_MAcc       : 0.861028182895996
# INFO:trainer:    val_F1_score   : 0.8742411101474414
# INFO:trainer:Saving new best model at epoch 32: model_best.pth
# DEBUG:trainer:Train Epoch: 33 [0/66 (0%)] Loss: 0.088201
# DEBUG:trainer:Train Epoch: 33 [8/66 (12%)] Loss: 0.080868
# DEBUG:trainer:Train Epoch: 33 [16/66 (24%)] Loss: 0.088407
# DEBUG:trainer:Train Epoch: 33 [24/66 (36%)] Loss: 0.072622
# DEBUG:trainer:Train Epoch: 33 [32/66 (48%)] Loss: 0.086466
# DEBUG:trainer:Train Epoch: 33 [40/66 (61%)] Loss: 0.073648
# DEBUG:trainer:Train Epoch: 33 [48/66 (73%)] Loss: 0.083312
# DEBUG:trainer:Train Epoch: 33 [56/66 (85%)] Loss: 0.098350
# DEBUG:trainer:Train Epoch: 33 [64/66 (97%)] Loss: 0.064138
# INFO:trainer:    epoch          : 33
# INFO:trainer:    loss           : 0.0869045179111488
# INFO:trainer:    accuracy       : 0.7840909090909091
# INFO:trainer:    f1_score       : 0.7972692105391088
# INFO:trainer:    val_loss       : 0.09099535819362192
# INFO:trainer:    val_accuracy   : 0.839968487394958
# INFO:trainer:    val_f1_score   : 0.8621867168252614
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.8258317025440313
# INFO:trainer:    val_MAcc       : 0.843572785578585
# INFO:trainer:    val_F1_score   : 0.8512173128944994
# DEBUG:trainer:Train Epoch: 34 [0/66 (0%)] Loss: 0.056308
# DEBUG:trainer:Train Epoch: 34 [8/66 (12%)] Loss: 0.077101
# DEBUG:trainer:Train Epoch: 34 [16/66 (24%)] Loss: 0.068378
# DEBUG:trainer:Train Epoch: 34 [24/66 (36%)] Loss: 0.069643
# DEBUG:trainer:Train Epoch: 34 [32/66 (48%)] Loss: 0.072875
# DEBUG:trainer:Train Epoch: 34 [40/66 (61%)] Loss: 0.134538
# DEBUG:trainer:Train Epoch: 34 [48/66 (73%)] Loss: 0.095818
# DEBUG:trainer:Train Epoch: 34 [56/66 (85%)] Loss: 0.075956
# DEBUG:trainer:Train Epoch: 34 [64/66 (97%)] Loss: 0.071483
# INFO:trainer:    epoch          : 34
# INFO:trainer:    loss           : 0.09055739009019101
# INFO:trainer:    accuracy       : 0.8224431818181818
# INFO:trainer:    f1_score       : 0.8322675887743898
# INFO:trainer:    val_loss       : 0.08975163343198159
# INFO:trainer:    val_accuracy   : 0.8514443277310925
# INFO:trainer:    val_f1_score   : 0.8722478897070138
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.8062622309197651
# INFO:trainer:    val_MAcc       : 0.8520362249489337
# INFO:trainer:    val_F1_score   : 0.8639157155399473
# DEBUG:trainer:Train Epoch: 35 [0/66 (0%)] Loss: 0.070624
# DEBUG:trainer:Train Epoch: 35 [8/66 (12%)] Loss: 0.067310
# DEBUG:trainer:Train Epoch: 35 [16/66 (24%)] Loss: 0.080394
# DEBUG:trainer:Train Epoch: 35 [24/66 (36%)] Loss: 0.084450
# DEBUG:trainer:Train Epoch: 35 [32/66 (48%)] Loss: 0.068603
# DEBUG:trainer:Train Epoch: 35 [40/66 (61%)] Loss: 0.086734
# DEBUG:trainer:Train Epoch: 35 [48/66 (73%)] Loss: 0.084882
# DEBUG:trainer:Train Epoch: 35 [56/66 (85%)] Loss: 0.075880
# DEBUG:trainer:Train Epoch: 35 [64/66 (97%)] Loss: 0.066668
# INFO:trainer:    epoch          : 35
# INFO:trainer:    loss           : 0.08777097341689197
# INFO:trainer:    accuracy       : 0.7923768939393939
# INFO:trainer:    f1_score       : 0.8049459378014517
# INFO:trainer:    val_loss       : 0.08772403637275976
# INFO:trainer:    val_accuracy   : 0.8597163865546219
# INFO:trainer:    val_f1_score   : 0.8886642543441156
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.8082191780821918
# INFO:trainer:    val_MAcc       : 0.8603139686031397
# INFO:trainer:    val_F1_score   : 0.8726003490401396
# DEBUG:trainer:Train Epoch: 36 [0/66 (0%)] Loss: 0.143824
# DEBUG:trainer:Train Epoch: 36 [8/66 (12%)] Loss: 0.097775
# DEBUG:trainer:Train Epoch: 36 [16/66 (24%)] Loss: 0.081262
# DEBUG:trainer:Train Epoch: 36 [24/66 (36%)] Loss: 0.059287
# DEBUG:trainer:Train Epoch: 36 [32/66 (48%)] Loss: 0.066918
# DEBUG:trainer:Train Epoch: 36 [40/66 (61%)] Loss: 0.074910
# DEBUG:trainer:Train Epoch: 36 [48/66 (73%)] Loss: 0.152494
# DEBUG:trainer:Train Epoch: 36 [56/66 (85%)] Loss: 0.106714
# DEBUG:trainer:Train Epoch: 36 [64/66 (97%)] Loss: 0.073922
# INFO:trainer:    epoch          : 36
# INFO:trainer:    loss           : 0.09217570304419055
# INFO:trainer:    accuracy       : 0.8065814393939394
# INFO:trainer:    f1_score       : 0.8185774521977965
# INFO:trainer:    val_loss       : 0.09018074239001554
# INFO:trainer:    val_accuracy   : 0.8523634453781513
# INFO:trainer:    val_f1_score   : 0.8740529968849652
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8395303326810176
# INFO:trainer:    val_MAcc       : 0.8540717356835745
# INFO:trainer:    val_F1_score   : 0.8607594936708861
# DEBUG:trainer:Train Epoch: 37 [0/66 (0%)] Loss: 0.088052
# DEBUG:trainer:Train Epoch: 37 [8/66 (12%)] Loss: 0.079276
# DEBUG:trainer:Train Epoch: 37 [16/66 (24%)] Loss: 0.126688
# DEBUG:trainer:Train Epoch: 37 [24/66 (36%)] Loss: 0.092440
# DEBUG:trainer:Train Epoch: 37 [32/66 (48%)] Loss: 0.080074
# DEBUG:trainer:Train Epoch: 37 [40/66 (61%)] Loss: 0.067011
# DEBUG:trainer:Train Epoch: 37 [48/66 (73%)] Loss: 0.079428
# DEBUG:trainer:Train Epoch: 37 [56/66 (85%)] Loss: 0.068621
# DEBUG:trainer:Train Epoch: 37 [64/66 (97%)] Loss: 0.129844
# INFO:trainer:    epoch          : 37
# INFO:trainer:    loss           : 0.08881890260134682
# INFO:trainer:    accuracy       : 0.7675189393939394
# INFO:trainer:    f1_score       : 0.7829004479960098
# INFO:trainer:    val_loss       : 0.090076942654217
# INFO:trainer:    val_accuracy   : 0.8438025210084034
# INFO:trainer:    val_f1_score   : 0.8670817832678336
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8277886497064579
# INFO:trainer:    val_MAcc       : 0.8482008941962946
# INFO:trainer:    val_F1_score   : 0.8561151079136692
# DEBUG:trainer:Train Epoch: 38 [0/66 (0%)] Loss: 0.060874
# DEBUG:trainer:Train Epoch: 38 [8/66 (12%)] Loss: 0.077911
# DEBUG:trainer:Train Epoch: 38 [16/66 (24%)] Loss: 0.062775
# DEBUG:trainer:Train Epoch: 38 [24/66 (36%)] Loss: 0.089705
# DEBUG:trainer:Train Epoch: 38 [32/66 (48%)] Loss: 0.062965
# DEBUG:trainer:Train Epoch: 38 [40/66 (61%)] Loss: 0.152622
# DEBUG:trainer:Train Epoch: 38 [48/66 (73%)] Loss: 0.077265
# DEBUG:trainer:Train Epoch: 38 [56/66 (85%)] Loss: 0.074602
# DEBUG:trainer:Train Epoch: 38 [64/66 (97%)] Loss: 0.065923
# INFO:trainer:    epoch          : 38
# INFO:trainer:    loss           : 0.08817525174130093
# INFO:trainer:    accuracy       : 0.8269412878787878
# INFO:trainer:    f1_score       : 0.8350210034027775
# INFO:trainer:    val_loss       : 0.09297216606929022
# INFO:trainer:    val_accuracy   : 0.8491596638655462
# INFO:trainer:    val_f1_score   : 0.8727417443613575
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.8454011741682974
# INFO:trainer:    val_MAcc       : 0.8533575213907181
# INFO:trainer:    val_F1_score   : 0.8589626933575977
# DEBUG:trainer:Train Epoch: 39 [0/66 (0%)] Loss: 0.066866
# DEBUG:trainer:Train Epoch: 39 [8/66 (12%)] Loss: 0.140171
# DEBUG:trainer:Train Epoch: 39 [16/66 (24%)] Loss: 0.064950
# DEBUG:trainer:Train Epoch: 39 [24/66 (36%)] Loss: 0.075722
# DEBUG:trainer:Train Epoch: 39 [32/66 (48%)] Loss: 0.103440
# DEBUG:trainer:Train Epoch: 39 [40/66 (61%)] Loss: 0.083886
# DEBUG:trainer:Train Epoch: 39 [48/66 (73%)] Loss: 0.075221
# DEBUG:trainer:Train Epoch: 39 [56/66 (85%)] Loss: 0.061842
# DEBUG:trainer:Train Epoch: 39 [64/66 (97%)] Loss: 0.116994
# INFO:trainer:    epoch          : 39
# INFO:trainer:    loss           : 0.087378254160285
# INFO:trainer:    accuracy       : 0.7760416666666666
# INFO:trainer:    f1_score       : 0.7882265128676031
# INFO:trainer:    val_loss       : 0.08875120453098241
# INFO:trainer:    val_accuracy   : 0.8581932773109243
# INFO:trainer:    val_f1_score   : 0.8893786772040426
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.8160469667318982
# INFO:trainer:    val_MAcc       : 0.8605782278914966
# INFO:trainer:    val_F1_score   : 0.8717047451669596
# DEBUG:trainer:Train Epoch: 40 [0/66 (0%)] Loss: 0.064793
# DEBUG:trainer:Train Epoch: 40 [8/66 (12%)] Loss: 0.068138
# DEBUG:trainer:Train Epoch: 40 [16/66 (24%)] Loss: 0.051935
# DEBUG:trainer:Train Epoch: 40 [24/66 (36%)] Loss: 0.148842
# DEBUG:trainer:Train Epoch: 40 [32/66 (48%)] Loss: 0.076169
# DEBUG:trainer:Train Epoch: 40 [40/66 (61%)] Loss: 0.085689
# DEBUG:trainer:Train Epoch: 40 [48/66 (73%)] Loss: 0.063015
# ...
# INFO:trainer:    val_accuracy   : 0.8574317226890756
# INFO:trainer:    val_f1_score   : 0.8760550966844778
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8551859099804305
# INFO:trainer:    val_MAcc       : 0.861899524333281
# INFO:trainer:    val_F1_score   : 0.8670309653916211
# DEBUG:trainer:Train Epoch: 92 [0/66 (0%)] Loss: 0.063498
# DEBUG:trainer:Train Epoch: 92 [8/66 (12%)] Loss: 0.045549
# DEBUG:trainer:Train Epoch: 92 [16/66 (24%)] Loss: 0.051808
# DEBUG:trainer:Train Epoch: 92 [24/66 (36%)] Loss: 0.065818
# DEBUG:trainer:Train Epoch: 92 [32/66 (48%)] Loss: 0.072230
# DEBUG:trainer:Train Epoch: 92 [40/66 (61%)] Loss: 0.048421
# DEBUG:trainer:Train Epoch: 92 [48/66 (73%)] Loss: 0.057401
# DEBUG:trainer:Train Epoch: 92 [56/66 (85%)] Loss: 0.050715
# DEBUG:trainer:Train Epoch: 92 [64/66 (97%)] Loss: 0.048591
# INFO:trainer:    epoch          : 92
# INFO:trainer:    loss           : 0.07349858489451987
# INFO:trainer:    accuracy       : 0.8484848484848485
# INFO:trainer:    f1_score       : 0.854454412203557
# INFO:trainer:    val_loss       : 0.0913156728972407
# INFO:trainer:    val_accuracy   : 0.855593487394958
# INFO:trainer:    val_f1_score   : 0.8747075859546873
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8512720156555773
# INFO:trainer:    val_MAcc       : 0.8599425771708544
# INFO:trainer:    val_F1_score   : 0.8654545454545454
# DEBUG:trainer:Train Epoch: 93 [0/66 (0%)] Loss: 0.047659
# DEBUG:trainer:Train Epoch: 93 [8/66 (12%)] Loss: 0.074582
# DEBUG:trainer:Train Epoch: 93 [16/66 (24%)] Loss: 0.058459
# DEBUG:trainer:Train Epoch: 93 [24/66 (36%)] Loss: 0.076821
# DEBUG:trainer:Train Epoch: 93 [32/66 (48%)] Loss: 0.058468
# DEBUG:trainer:Train Epoch: 93 [40/66 (61%)] Loss: 0.053355
# DEBUG:trainer:Train Epoch: 93 [48/66 (73%)] Loss: 0.071418
# DEBUG:trainer:Train Epoch: 93 [56/66 (85%)] Loss: 0.053447
# DEBUG:trainer:Train Epoch: 93 [64/66 (97%)] Loss: 0.150887
# INFO:trainer:    epoch          : 93
# INFO:trainer:    loss           : 0.0710358467291702
# INFO:trainer:    accuracy       : 0.8349905303030303
# INFO:trainer:    f1_score       : 0.8401415874721995
# INFO:trainer:    val_loss       : 0.0923603759968982
# INFO:trainer:    val_accuracy   : 0.8583508403361344
# INFO:trainer:    val_f1_score   : 0.8767862365964901
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8571428571428571
# INFO:trainer:    val_MAcc       : 0.8628779979144943
# INFO:trainer:    val_F1_score   : 0.8678213309024613
# DEBUG:trainer:Train Epoch: 94 [0/66 (0%)] Loss: 0.061834
# DEBUG:trainer:Train Epoch: 94 [8/66 (12%)] Loss: 0.075748
# DEBUG:trainer:Train Epoch: 94 [16/66 (24%)] Loss: 0.108428
# DEBUG:trainer:Train Epoch: 94 [24/66 (36%)] Loss: 0.054318
# DEBUG:trainer:Train Epoch: 94 [32/66 (48%)] Loss: 0.049451
# DEBUG:trainer:Train Epoch: 94 [40/66 (61%)] Loss: 0.062898
# DEBUG:trainer:Train Epoch: 94 [48/66 (73%)] Loss: 0.046555
# DEBUG:trainer:Train Epoch: 94 [56/66 (85%)] Loss: 0.069261
# DEBUG:trainer:Train Epoch: 94 [64/66 (97%)] Loss: 0.050328
# INFO:trainer:    epoch          : 94
# INFO:trainer:    loss           : 0.06712818332016468
# INFO:trainer:    accuracy       : 0.8693181818181818
# INFO:trainer:    f1_score       : 0.8740907407992116
# INFO:trainer:    val_loss       : 0.09281632424715687
# INFO:trainer:    val_accuracy   : 0.860031512605042
# INFO:trainer:    val_f1_score   : 0.8771023260445053
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8590998043052838
# INFO:trainer:    val_MAcc       : 0.8638564714957075
# INFO:trainer:    val_F1_score   : 0.8686131386861314
# DEBUG:trainer:Train Epoch: 95 [0/66 (0%)] Loss: 0.056108
# DEBUG:trainer:Train Epoch: 95 [8/66 (12%)] Loss: 0.046546
# DEBUG:trainer:Train Epoch: 95 [16/66 (24%)] Loss: 0.070047
# DEBUG:trainer:Train Epoch: 95 [24/66 (36%)] Loss: 0.044017
# DEBUG:trainer:Train Epoch: 95 [32/66 (48%)] Loss: 0.052579
# DEBUG:trainer:Train Epoch: 95 [40/66 (61%)] Loss: 0.058324
# DEBUG:trainer:Train Epoch: 95 [48/66 (73%)] Loss: 0.069851
# DEBUG:trainer:Train Epoch: 95 [56/66 (85%)] Loss: 0.061436
# DEBUG:trainer:Train Epoch: 95 [64/66 (97%)] Loss: 0.053668
# INFO:trainer:    epoch          : 95
# INFO:trainer:    loss           : 0.07051366093483838
# INFO:trainer:    accuracy       : 0.8401988636363636
# INFO:trainer:    f1_score       : 0.8451388384239148
# INFO:trainer:    val_loss       : 0.09344528648344909
# INFO:trainer:    val_accuracy   : 0.860031512605042
# INFO:trainer:    val_f1_score   : 0.8777089586271559
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8590998043052838
# INFO:trainer:    val_MAcc       : 0.8638564714957075
# INFO:trainer:    val_F1_score   : 0.8686131386861314
# DEBUG:trainer:Train Epoch: 96 [0/66 (0%)] Loss: 0.056214
# DEBUG:trainer:Train Epoch: 96 [8/66 (12%)] Loss: 0.124173
# DEBUG:trainer:Train Epoch: 96 [16/66 (24%)] Loss: 0.058079
# DEBUG:trainer:Train Epoch: 96 [24/66 (36%)] Loss: 0.135105
# DEBUG:trainer:Train Epoch: 96 [32/66 (48%)] Loss: 0.064046
# DEBUG:trainer:Train Epoch: 96 [40/66 (61%)] Loss: 0.055920
# DEBUG:trainer:Train Epoch: 96 [48/66 (73%)] Loss: 0.092750
# DEBUG:trainer:Train Epoch: 96 [56/66 (85%)] Loss: 0.061721
# DEBUG:trainer:Train Epoch: 96 [64/66 (97%)] Loss: 0.081819
# INFO:trainer:    epoch          : 96
# INFO:trainer:    loss           : 0.07013681514019315
# INFO:trainer:    accuracy       : 0.8378314393939394
# INFO:trainer:    f1_score       : 0.8425609876151721
# INFO:trainer:    val_loss       : 0.09250075600164778
# INFO:trainer:    val_accuracy   : 0.8581932773109243
# INFO:trainer:    val_f1_score   : 0.8760905859941073
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8551859099804305
# INFO:trainer:    val_MAcc       : 0.861899524333281
# INFO:trainer:    val_F1_score   : 0.8670309653916211
# DEBUG:trainer:Train Epoch: 97 [0/66 (0%)] Loss: 0.068141
# DEBUG:trainer:Train Epoch: 97 [8/66 (12%)] Loss: 0.120307
# DEBUG:trainer:Train Epoch: 97 [16/66 (24%)] Loss: 0.130927
# DEBUG:trainer:Train Epoch: 97 [24/66 (36%)] Loss: 0.084156
# DEBUG:trainer:Train Epoch: 97 [32/66 (48%)] Loss: 0.151933
# DEBUG:trainer:Train Epoch: 97 [40/66 (61%)] Loss: 0.083769
# DEBUG:trainer:Train Epoch: 97 [48/66 (73%)] Loss: 0.069616
# DEBUG:trainer:Train Epoch: 97 [56/66 (85%)] Loss: 0.149109
# DEBUG:trainer:Train Epoch: 97 [64/66 (97%)] Loss: 0.067795
# INFO:trainer:    epoch          : 97
# INFO:trainer:    loss           : 0.07481978760298455
# INFO:trainer:    accuracy       : 0.7857481060606061
# INFO:trainer:    f1_score       : 0.789648848688778
# INFO:trainer:    val_loss       : 0.09404531910138972
# INFO:trainer:    val_accuracy   : 0.860031512605042
# INFO:trainer:    val_f1_score   : 0.8751823031907595
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.8669275929549902
# INFO:trainer:    val_MAcc       : 0.8641207307840644
# INFO:trainer:    val_F1_score   : 0.8676470588235293
# DEBUG:trainer:Train Epoch: 98 [0/66 (0%)] Loss: 0.121105
# DEBUG:trainer:Train Epoch: 98 [8/66 (12%)] Loss: 0.046602
# DEBUG:trainer:Train Epoch: 98 [16/66 (24%)] Loss: 0.048154
# DEBUG:trainer:Train Epoch: 98 [24/66 (36%)] Loss: 0.054720
# DEBUG:trainer:Train Epoch: 98 [32/66 (48%)] Loss: 0.066099
# DEBUG:trainer:Train Epoch: 98 [40/66 (61%)] Loss: 0.182242
# DEBUG:trainer:Train Epoch: 98 [48/66 (73%)] Loss: 0.052954
# DEBUG:trainer:Train Epoch: 98 [56/66 (85%)] Loss: 0.043722
# DEBUG:trainer:Train Epoch: 98 [64/66 (97%)] Loss: 0.045602
# INFO:trainer:    epoch          : 98
# INFO:trainer:    loss           : 0.07167768224396488
# INFO:trainer:    accuracy       : 0.8165246212121212
# INFO:trainer:    f1_score       : 0.8207826047626792
# INFO:trainer:    val_loss       : 0.09190942193655406
# INFO:trainer:    val_accuracy   : 0.8574317226890756
# INFO:trainer:    val_f1_score   : 0.8758990038754539
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8551859099804305
# INFO:trainer:    val_MAcc       : 0.861899524333281
# INFO:trainer:    val_F1_score   : 0.8670309653916211
# DEBUG:trainer:Train Epoch: 99 [0/66 (0%)] Loss: 0.065571
# DEBUG:trainer:Train Epoch: 99 [8/66 (12%)] Loss: 0.050877
# DEBUG:trainer:Train Epoch: 99 [16/66 (24%)] Loss: 0.062400
# DEBUG:trainer:Train Epoch: 99 [24/66 (36%)] Loss: 0.189067
# DEBUG:trainer:Train Epoch: 99 [32/66 (48%)] Loss: 0.066326
# DEBUG:trainer:Train Epoch: 99 [40/66 (61%)] Loss: 0.060659
# DEBUG:trainer:Train Epoch: 99 [48/66 (73%)] Loss: 0.062512
# DEBUG:trainer:Train Epoch: 99 [56/66 (85%)] Loss: 0.057968
# DEBUG:trainer:Train Epoch: 99 [64/66 (97%)] Loss: 0.070408
# INFO:trainer:    epoch          : 99
# INFO:trainer:    loss           : 0.06907386462571043
# INFO:trainer:    accuracy       : 0.8387784090909091
# INFO:trainer:    f1_score       : 0.8428762471732089
# INFO:trainer:    val_loss       : 0.09121810546254411
# INFO:trainer:    val_accuracy   : 0.860189075630252
# INFO:trainer:    val_f1_score   : 0.87967490621284
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.8532289628180039
# INFO:trainer:    val_MAcc       : 0.864570685788564
# INFO:trainer:    val_F1_score   : 0.8703535811423392
# DEBUG:trainer:Train Epoch: 100 [0/66 (0%)] Loss: 0.063763
# DEBUG:trainer:Train Epoch: 100 [8/66 (12%)] Loss: 0.123435
# DEBUG:trainer:Train Epoch: 100 [16/66 (24%)] Loss: 0.078447
# DEBUG:trainer:Train Epoch: 100 [24/66 (36%)] Loss: 0.059739
# DEBUG:trainer:Train Epoch: 100 [32/66 (48%)] Loss: 0.165834
# DEBUG:trainer:Train Epoch: 100 [40/66 (61%)] Loss: 0.055099
# DEBUG:trainer:Train Epoch: 100 [48/66 (73%)] Loss: 0.059632
# DEBUG:trainer:Train Epoch: 100 [56/66 (85%)] Loss: 0.086129
# DEBUG:trainer:Train Epoch: 100 [64/66 (97%)] Loss: 0.057701
# INFO:trainer:    epoch          : 100
# INFO:trainer:    loss           : 0.0773273640961358
# INFO:trainer:    accuracy       : 0.7935606060606061
# INFO:trainer:    f1_score       : 0.8001392314246174
# INFO:trainer:    val_loss       : 0.09133835695683956
# INFO:trainer:    val_accuracy   : 0.860189075630252
# INFO:trainer:    val_f1_score   : 0.8774860326089705
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.8532289628180039
# INFO:trainer:    val_MAcc       : 0.864570685788564
# INFO:trainer:    val_F1_score   : 0.8703535811423392
# DEBUG:trainer:Train Epoch: 101 [0/66 (0%)] Loss: 0.071440
# DEBUG:trainer:Train Epoch: 101 [8/66 (12%)] Loss: 0.053035
# DEBUG:trainer:Train Epoch: 101 [16/66 (24%)] Loss: 0.057988
# DEBUG:trainer:Train Epoch: 101 [24/66 (36%)] Loss: 0.054090
# DEBUG:trainer:Train Epoch: 101 [32/66 (48%)] Loss: 0.054320
# DEBUG:trainer:Train Epoch: 101 [40/66 (61%)] Loss: 0.054027
# DEBUG:trainer:Train Epoch: 101 [48/66 (73%)] Loss: 0.057903
# DEBUG:trainer:Train Epoch: 101 [56/66 (85%)] Loss: 0.051681
# DEBUG:trainer:Train Epoch: 101 [64/66 (97%)] Loss: 0.046920
# INFO:trainer:    epoch          : 101
# INFO:trainer:    loss           : 0.07185021567751061
# INFO:trainer:    accuracy       : 0.8394886363636364
# INFO:trainer:    f1_score       : 0.8436873603527312
# INFO:trainer:    val_loss       : 0.09313110711381715
# INFO:trainer:    val_accuracy   : 0.8618697478991596
# INFO:trainer:    val_f1_score   : 0.8792482005475699
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.863013698630137
# INFO:trainer:    val_MAcc       : 0.8658134186581342
# INFO:trainer:    val_F1_score   : 0.870201096892139
# DEBUG:trainer:Train Epoch: 102 [0/66 (0%)] Loss: 0.069667
# DEBUG:trainer:Train Epoch: 102 [8/66 (12%)] Loss: 0.055176
# DEBUG:trainer:Train Epoch: 102 [16/66 (24%)] Loss: 0.064873
# DEBUG:trainer:Train Epoch: 102 [24/66 (36%)] Loss: 0.113730
# DEBUG:trainer:Train Epoch: 102 [32/66 (48%)] Loss: 0.062254
# DEBUG:trainer:Train Epoch: 102 [40/66 (61%)] Loss: 0.079041
# DEBUG:trainer:Train Epoch: 102 [48/66 (73%)] Loss: 0.161464
# DEBUG:trainer:Train Epoch: 102 [56/66 (85%)] Loss: 0.106868
# DEBUG:trainer:Train Epoch: 102 [64/66 (97%)] Loss: 0.058539
# INFO:trainer:    epoch          : 102
# INFO:trainer:    loss           : 0.07468499480323358
# INFO:trainer:    accuracy       : 0.8103693181818182
# INFO:trainer:    f1_score       : 0.8154157191453176
# INFO:trainer:    val_loss       : 0.09141268449671128
# INFO:trainer:    val_accuracy   : 0.8574317226890756
# INFO:trainer:    val_f1_score   : 0.8758990038754539
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8551859099804305
# INFO:trainer:    val_MAcc       : 0.861899524333281
# INFO:trainer:    val_F1_score   : 0.8670309653916211
# DEBUG:trainer:Train Epoch: 103 [0/66 (0%)] Loss: 0.054527
# DEBUG:trainer:Train Epoch: 103 [8/66 (12%)] Loss: 0.067799
# DEBUG:trainer:Train Epoch: 103 [16/66 (24%)] Loss: 0.141711
# DEBUG:trainer:Train Epoch: 103 [24/66 (36%)] Loss: 0.054239
# DEBUG:trainer:Train Epoch: 103 [32/66 (48%)] Loss: 0.051171
# DEBUG:trainer:Train Epoch: 103 [40/66 (61%)] Loss: 0.064735
# DEBUG:trainer:Train Epoch: 103 [48/66 (73%)] Loss: 0.068685
# DEBUG:trainer:Train Epoch: 103 [56/66 (85%)] Loss: 0.054846
# DEBUG:trainer:Train Epoch: 103 [64/66 (97%)] Loss: 0.066328
# INFO:trainer:    epoch          : 103
# INFO:trainer:    loss           : 0.06645184580349561
# INFO:trainer:    accuracy       : 0.8712121212121212
# INFO:trainer:    f1_score       : 0.8758800804270233
# INFO:trainer:    val_loss       : 0.09436405745937544
# INFO:trainer:    val_accuracy   : 0.8627888655462185
# INFO:trainer:    val_f1_score   : 0.8800590512022852
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.8649706457925636
# INFO:trainer:    val_MAcc       : 0.8667918922393475
# INFO:trainer:    val_F1_score   : 0.8709972552607502
# DEBUG:trainer:Train Epoch: 104 [0/66 (0%)] Loss: 0.056041
# DEBUG:trainer:Train Epoch: 104 [8/66 (12%)] Loss: 0.057741
# DEBUG:trainer:Train Epoch: 104 [16/66 (24%)] Loss: 0.093386
# DEBUG:trainer:Train Epoch: 104 [24/66 (36%)] Loss: 0.053231
# DEBUG:trainer:Train Epoch: 104 [32/66 (48%)] Loss: 0.067473
# DEBUG:trainer:Train Epoch: 104 [40/66 (61%)] Loss: 0.074667
# DEBUG:trainer:Train Epoch: 104 [48/66 (73%)] Loss: 0.053151
# DEBUG:trainer:Train Epoch: 104 [56/66 (85%)] Loss: 0.094020
# DEBUG:trainer:Train Epoch: 104 [64/66 (97%)] Loss: 0.057456
# INFO:trainer:    epoch          : 104
# INFO:trainer:    loss           : 0.06806709261780436
# INFO:trainer:    accuracy       : 0.8700284090909091
# INFO:trainer:    f1_score       : 0.8725929881603979
# INFO:trainer:    val_loss       : 0.091361579759156
# INFO:trainer:    val_accuracy   : 0.8574317226890756
# INFO:trainer:    val_f1_score   : 0.877628557383594
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.8473581213307241
# INFO:trainer:    val_MAcc       : 0.8616352650449242
# INFO:trainer:    val_F1_score   : 0.867992766726944
# DEBUG:trainer:Train Epoch: 105 [0/66 (0%)] Loss: 0.045632
# DEBUG:trainer:Train Epoch: 105 [8/66 (12%)] Loss: 0.074005
# DEBUG:trainer:Train Epoch: 105 [16/66 (24%)] Loss: 0.069872
# DEBUG:trainer:Train Epoch: 105 [24/66 (36%)] Loss: 0.041966
# DEBUG:trainer:Train Epoch: 105 [32/66 (48%)] Loss: 0.042404
# DEBUG:trainer:Train Epoch: 105 [40/66 (61%)] Loss: 0.059061
# DEBUG:trainer:Train Epoch: 105 [48/66 (73%)] Loss: 0.048081
# DEBUG:trainer:Train Epoch: 105 [56/66 (85%)] Loss: 0.060681
# DEBUG:trainer:Train Epoch: 105 [64/66 (97%)] Loss: 0.047428
# INFO:trainer:    epoch          : 105
# INFO:trainer:    loss           : 0.06917327625507658
# INFO:trainer:    accuracy       : 0.8641098484848485
# INFO:trainer:    f1_score       : 0.8683304944687676
# INFO:trainer:    val_loss       : 0.09550851649221252
# INFO:trainer:    val_accuracy   : 0.8581932773109243
# INFO:trainer:    val_f1_score   : 0.8726905573425862
# INFO:trainer:    val_sensitivity: 0.8540145985401459
# INFO:trainer:    val_specificity: 0.8708414872798435
# INFO:trainer:    val_MAcc       : 0.8624280429099946
# INFO:trainer:    val_F1_score   : 0.8650646950092421
# INFO:trainer:Validation performance didn't improve for 30 epochs. Training stops.
# === HOÀN THÀNH TRAINING ===
# Model tốt nhất được lưu tại:
# /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0228_045450/model_best.pth

# %% [markdown]
# # Test

# %%
from sklearn.metrics import f1_score, confusion_matrix
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import pandas as pd

def test_model(config, best_model_path, validation_fea_path, validation_label_csv):
    config_parser = ConfigParser(config)
    device, _ = prepare_device(config_parser['n_gpu'])

    # Khởi tạo model từ config (đảm bảo architecture đúng)
    model = config_parser.init_obj('arch', globals())
    model = model.to(device)

    # === LOAD CHỈ STATE_DICT - AN TOÀN, KHÔNG CẦN WHITELIST ===
    try:
        # Cách 1: Dùng weights_only=True (mặc định từ PT 2.6), chỉ load weights
        checkpoint = torch.load(best_model_path, map_location=device, weights_only=True)
        model.load_state_dict(checkpoint)  # checkpoint ở đây chỉ là state_dict
        print("Loaded model weights with weights_only=True (safe mode)")
    except Exception as e1:
        print(f"weights_only=True failed: {e1}")
        try:
            # Cách 2: Tắt weights_only (chỉ dùng nếu bạn tin tưởng file)
            checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
            model.load_state_dict(checkpoint['state_dict'])
            print("Loaded with weights_only=False (full checkpoint)")
        except Exception as e2:
            print(f"Cả hai cách đều thất bại: {e2}")
            return

    model.eval()

    print("\n=== MODEL ARCHITECTURE ===")
    print(model)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\nTrainable parameters: {trainable_params:,}")

    # === Xác định input shape từ config ===
    delta = config['data_loader']['args'].get('delta', False)
    n_mfcc = config['data_loader']['args'].get('n_mfcc', 39)
    time_frames = 333

    channels = 3 if delta else 1   # static + Δ + ΔΔ nếu có
    height = n_mfcc

    # === Kiểm tra forward với input giả ===
    print("\n=== VERIFYING FORWARD PASS ===")
    try:
        with torch.no_grad():
            dummy_input = torch.randn(2, channels * height, time_frames).to(device)
            output = model(dummy_input)
            print(f"Input shape: (B, {channels * height}, {time_frames})")
            print(f"Output shape: {output.shape} → OK")
    except Exception as e:
        print(f"Forward pass error: {e}")

    # === Load validation data ===
    if not Path(validation_label_csv).exists() or not Path(validation_fea_path).exists():
        print("Validation files not found → skipping evaluation")
        return

    validation_label_df = pd.read_csv(validation_label_csv)
    validation_label_df['filename'] = validation_label_df['filename'].apply(lambda x: Path(x).stem)

    validation_dataset = HeartSoundDataSet(
        fea_path=validation_fea_path,
        labels=validation_label_df,
        duration=config['data_loader']['args']['duration'],
        training=False,
        delta=delta,
        norm=config['data_loader']['args'].get('norm', True)
    )

    print("\n=== DEBUG: SAMPLE FEATURES ===")
    for i in range(min(5, len(validation_dataset))):
        fea, lab = validation_dataset[i]
        print(f"Sample {i}: shape = {fea.shape}, label = {lab.item()}")

    # Tắt pin_memory trên CPU
    pin_memory = (device.type == 'cuda')

    validation_dataloader = DataLoader(
        validation_dataset,
        batch_size=config['data_loader']['args']['batch_size'],
        shuffle=False,
        num_workers=config['data_loader']['args'].get('num_workers', 2),
        pin_memory=pin_memory
    )

    criterion = ce_loss

    print("\n=== EVALUATING ON VALIDATION SET ===")
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    val_TP = val_TN = val_pred_pos = val_condition_pos = 0

    with torch.no_grad():
        for data, target in validation_dataloader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            total_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, 1)
            total_correct += (pred == target).sum().item()
            total_samples += target.size(0)

            pred_pos_idx = (pred == 1)      # class 1 = abnormal (positive)
            condition_pos_idx = (target == 1)

            val_TP += (pred_pos_idx & condition_pos_idx).sum().item()
            val_TN += ((pred == 0) & (target == 0)).sum().item()
            val_pred_pos += pred_pos_idx.sum().item()
            val_condition_pos += condition_pos_idx.sum().item()

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    sensitivity = val_TP / val_condition_pos if val_condition_pos > 0 else 0
    specificity = val_TN / (total_samples - val_condition_pos) if (total_samples - val_condition_pos) > 0 else 0
    MAcc = (sensitivity + specificity) / 2
    precision = val_TP / val_pred_pos if val_pred_pos > 0 else 0
    F1_score = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0

    val_log = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'MAcc': MAcc,
        'F1_score': F1_score
    }

    print(f"\nDetailed Results:")
    for k, v in val_log.items():
        print(f"    {k}: {v:.4f}")


    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal (0)', 'Abnormal (1)'],
                yticklabels=['Normal (0)', 'Abnormal (1)'])
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix - Heart Sound Classification')

    # Save image to the same directory as the model
    save_path = Path(best_model_path).parent / "confusion_matrix.png"
    plt.savefig(save_path, dpi=300)
    plt.show()
    print(f"\nConfusion Matrix has been saved at: {save_path}")

    # Print detailed classification report
    print("\nClassification Report:")
    print(classification_report(all_targets, all_preds, target_names=['Normal', 'Abnormal']))


    metrics_path = Path(best_model_path).parent / "test_on_validation_set_metrics.csv"
    pd.DataFrame([val_log]).to_csv(metrics_path, index=False)
    print(f"\nĐã lưu kết quả tại: {metrics_path}")

# %%
base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
if base_dir.exists():
        latest_run = max(base_dir.iterdir(), key=os.path.getmtime)
        best_model_path = latest_run / "model_best.pth"

        validation_fea_path = str(DATASET_PATH / "mfcc_features_validation.h5")
        validation_label_csv = str(DATASET_PATH / "label_validation.csv")  # Đảm bảo file này tồn tại!

        if Path(validation_fea_path).exists() and Path(validation_label_csv).exists():
            test_model(current_config, best_model_path, validation_fea_path, validation_label_csv)
        else:
            print("Không tìm thấy file validation .h5 hoặc label_validation.csv → Bỏ qua phần test.")

        size_bytes = os.path.getsize(best_model_path)
        size_mb = size_bytes / (1024 * 1024)

        print(f"Model size: {size_mb:.2f} MB")

else:
    print("Không tìm thấy thư mục saved models.")
# Out:
# weights_only=True failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.ConfigParser was not an allowed global by default. Please use `torch.serialization.add_safe_globals([__main__.ConfigParser])` or the `torch.serialization.safe_globals([__main__.ConfigParser])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Loaded with weights_only=False (full checkpoint)
#
# === MODEL ARCHITECTURE ===
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (stage1): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage2): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage3): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (drop): Dropout2d(p=0.1, inplace=False)
#   (se): SEBlock(
#     (squeeze): AdaptiveAvgPool2d(output_size=1)
#     (excitation): Sequential(
#       (0): Linear(in_features=128, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (spatial_attn): Sequential(
#     (0): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): Sigmoid()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU6()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
#
# Số tham số huấn luyện được: 35,954
#
# === KIỂM TRA FORWARD PASS ===
# Input shape: (B, 39, 333)
# Output shape: torch.Size([2, 2]) → OK
#
# === DEBUG: SAMPLE FEATURES ===
# Sample 0: shape = torch.Size([39, 333]), label = 1
# Sample 1: shape = torch.Size([39, 333]), label = 1
# Sample 2: shape = torch.Size([39, 333]), label = 1
# Sample 3: shape = torch.Size([39, 333]), label = 1
# Sample 4: shape = torch.Size([39, 333]), label = 1
#
# === ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===
#
# Kết quả đánh giá:
#     loss: 0.3385
#     accuracy: 0.8372
#     sensitivity: 0.9801
#     specificity: 0.6933
#     MAcc: 0.8367
#     F1_score: 0.8580
#
# Đã lưu kết quả tại: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0228_045450/test_on_validation_set_metrics.csv
# Model size: 0.82 MB
