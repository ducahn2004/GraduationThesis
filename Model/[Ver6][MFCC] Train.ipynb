# %%
import numpy as np
import pandas as pd
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import numpy as np
from torch.utils.data import DataLoader, Sampler
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision.utils import make_grid

from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    balanced_accuracy_score,
    matthews_corrcoef
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
sys.path.append(str(DATASET_PATH))

# %% [markdown]
# # Load Data

# %% [markdown]
# ## HeartSoundDataSet

# %%
def spec_augment(spec, F=6, T=25, num_masks=2):
    """SpecAugment cho MFCC"""
    cloned = spec.clone()
    num_mel_channels, num_frames = cloned.shape[-2:]

    # Frequency masking
    for _ in range(num_masks):
        f = np.random.randint(0, F)
        f0 = np.random.randint(0, num_mel_channels - f)
        cloned[..., f0:f0+f, :] = cloned[..., f0:f0+f, :].mean()

    # Time masking
    for _ in range(num_masks):
        t = np.random.randint(0, T)
        t0 = np.random.randint(0, num_frames - t)
        cloned[..., :, t0:t0+t] = 0

    return cloned

# %%
import numpy as np
import h5py
import random
import torch
from pathlib import Path
import librosa  # cần import để tính delta

EPS = 1e-8

def standard_normal_variate(data):
    """Chuẩn hóa Z-score trên toàn bộ tensor."""
    mean = np.mean(data)
    std = np.std(data) + EPS
    return (data - mean) / std

class HeartSoundDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 fea_path: str,              # đường dẫn file .h5
                 labels: pd.DataFrame,       # DataFrame với cột 'filename' và 'label'
                 duration: int = 5,          # giây
                 training: bool = True,
                 delta: bool = False,
                 norm: bool = True):
        self._fea_path = fea_path
        self._h5database = None
        self._labels = labels.reset_index(drop=True)
        self._colname = ['filename', 'label']
        self._len = len(self._labels)
        self._duration = duration
        self._delta = delta
        self.train = training
        self.hop_length = 15  # ms
        self.norm = norm

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
      row = self._labels.iloc[idx]
      filename = row['filename']
      target_bin = row['label']

      # Lấy key từ stem của filename
      key = Path(filename).stem if '/' in str(filename) else filename

      # Mở HDF5 nếu chưa mở
      if self._h5database is None:
          self._h5database = h5py.File(self._fea_path, 'r')

      if key not in self._h5database:
          available = list(self._h5database.keys())[:10]
          raise KeyError(f"Key '{key}' not found in HDF5. Sample keys: {available}")

      # Load feature từ HDF5
      feature = self._h5database[key][()]  # (mel_bins, T) hoặc (C, mel_bins, T)

      # Đảm bảo feature là 3D: (C, H, W)
      if feature.ndim == 2:
          feature = feature[np.newaxis, :, :]  # → (1, mel_bins, T)
      elif feature.ndim != 3:
          raise ValueError(f"Unexpected shape {feature.shape} for key '{key}'")

      # Chuẩn hóa toàn bộ tensor (nếu bật)
      if self.norm:
          feature = standard_normal_variate(feature)

      # Thêm delta features (nếu bật)
      if self._delta:
          orig = feature[0]  # (mel_bins, T)
          delta = librosa.feature.delta(orig)
          delta2 = librosa.feature.delta(delta)
          feature = np.stack([orig, delta, delta2], axis=0)  # → (3, mel_bins, T)

      # Lấy shape hiện tại
      channels, mel_bins, num_frames = feature.shape

      # Tính độ dài mong muốn (frames)
      cycle_len = int(self._duration * 1000 / self.hop_length)

      # Crop hoặc pad để đạt đúng cycle_len
      if num_frames >= cycle_len:
          if self.train:
              feature_tensor = spec_augment(feature_tensor, F=5, T=30, num_masks=1)
              #start_ind = random.randint(0, num_frames - cycle_len)
          else:
              start_ind = (num_frames - cycle_len) // 2
          feature = feature[:, :, start_ind:start_ind + cycle_len]
      elif num_frames < cycle_len:
          pad_width = ((0, 0), (0, 0), (0, cycle_len - num_frames))
          feature = np.pad(feature, pad_width, mode='wrap')

      # === Fix quan trọng cho model gốc: Làm cho tensor luôn là 3D (mel_bins, num_frames) ===
      feature_tensor = torch.from_numpy(feature).float()  # (C, mel_bins, T)

      if channels > 1:  # Có delta → C=3
          # Ghép 3 channels vào chiều mel_bins → (3 * mel_bins, T) = (384, T)
          # Model sẽ view thành (B, 3, 128, T) trong forward
          feature_tensor = feature_tensor.view(channels * mel_bins, -1)  # → (384, T)
      else:
          # Không delta → squeeze về (mel_bins, T) = (128, T)
          feature_tensor = feature_tensor.squeeze(0)

      return feature_tensor, torch.tensor(target_bin, dtype=torch.long)

    def __del__(self):
        """Đóng file HDF5 khi object bị hủy (tốt cho quản lý tài nguyên)."""
        if self._h5database is not None:
            self._h5database.close()

# %% [markdown]
# ## MinimumOccupancySampler

# %%
class MinimumOccupancySampler(Sampler):
    """
        samples at least one instance from each class sequentially
    """
    def __init__(self, labels, sampling_mode='over', random_state=None):
        data_samples = labels.shape
        n_labels = len(np.unique(labels))
        label_to_idx_list, label_to_length = [], []
        self.random_state = np.random.RandomState(seed=random_state)
        for lb_idx in range(n_labels):
            label_indexes = np.where(labels == lb_idx)[0]
            self.random_state.shuffle(label_indexes)
            label_to_length.append(len(label_indexes))
            label_to_idx_list.append(label_indexes)

        self.longest_seq = max(label_to_length)
        self.data_source = np.empty((self.longest_seq, len(label_to_length)), dtype=int)
        # Each column represents one "single instance per class" data piece
        for ix, leng in enumerate(label_to_length):
            self.data_source[:leng, ix] = label_to_idx_list[ix]
        self.label_to_length = label_to_length
        self.label_to_idx_list = label_to_idx_list

        if sampling_mode == 'same':
            self.data_length = data_samples
        elif sampling_mode == 'over':  # Sample all items
            self.data_length = np.prod(self.data_source.shape)

    def _resample(self):
        for ix, leng in enumerate(self.label_to_length):
            leftover = self.longest_seq - leng
            random_idxs = np.random.randint(leng, size=leftover)
            self.data_source[leng:, ix] = self.label_to_idx_list[ix][random_idxs]

    def __iter__(self):
        self._resample()
        n_samples = len(self.data_source)
        random_indices = self.random_state.permutation(n_samples)
        data = np.concatenate(
            self.data_source[random_indices])[:self.data_length]
        return iter(data)

    def __len__(self):
        return self.data_length

# %% [markdown]
# ## HeartSoundDataLoader

# %%
class BaseDataLoader(DataLoader):
    """
    Base class for all data loaders
    """
    def __init__(self, dataset, batch_size, shuffle, validation_split, num_workers, collate_fn=default_collate, sampler_type=None):
        self.validation_split = validation_split
        self.shuffle = shuffle

        self.batch_idx = 0
        self.n_samples = len(dataset)
        self.sampler_type = sampler_type
        self.sampler, self.valid_sampler = self._split_sampler(self.validation_split)
        self.init_kwargs = {
            'dataset': dataset,
            'batch_size': batch_size,
            'shuffle': self.shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.sampler, **self.init_kwargs)

    def _split_sampler(self, split):
        if split == 0.0:
            return None, None

        idx_full = np.arange(self.n_samples)

        np.random.seed(0)
        np.random.shuffle(idx_full)

        if isinstance(split, int):
            assert split > 0
            assert split < self.n_samples, "validation set size is configured to be larger than entire dataset."
            len_valid = split
        else:
            len_valid = int(self.n_samples * split)

        valid_idx = idx_full[0:len_valid]
        train_idx = np.delete(idx_full, np.arange(0, len_valid))
        if self.sampler_type == 'MinimumOccupancySampler':
            train_sampler = MinimumOccupancySampler(np.stack(self.label_df.iloc[train_idx]['label']), random_state=100)
        else:
            train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        # turn off shuffle option which is mutually exclusive with sampler
        self.shuffle = False
        self.n_samples = len(train_idx)

        return train_sampler, valid_sampler

    def split_validation(self):
        if self.valid_sampler is None:
            return None
        else:
            return DataLoader(sampler=self.valid_sampler, **self.init_kwargs)

# %%
class HeartSoundDataLoader(DataLoader):
    def __init__(self,
                 fea_path,
                 label_df,
                 duration,
                 batch_size,
                 delta=False,
                 norm = False,
                 shuffle=True,
                 validation_split=0.0,
                 num_workers=1,
                 training=True,
                 collate_fn=None):
        if training:
            self.train_df, self.val_df = train_test_split(label_df, test_size=validation_split, shuffle=True)

            self.train_sampler = MinimumOccupancySampler(np.stack(self.train_df['label']), random_state=100)
            self.val_dataset = HeartSoundDataSet(fea_path, self.val_df, duration=duration, training=False, delta=delta, norm=norm)

        else:
            self.train_df = label_df
            self.train_sampler = None
        self.dataset = HeartSoundDataSet(fea_path, self.train_df, duration=duration,
                                               training=training, delta=delta, norm=norm)
        self.init_kwargs = {
            'batch_size': batch_size,
            'shuffle': shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.train_sampler,
                         dataset = self.dataset,
                         **self.init_kwargs)

    def split_validation(self):
        return DataLoader(dataset= self.val_dataset, **self.init_kwargs)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_balanced.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("MFCC (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0001_aug0', 'a0001_aug1', 'a0001_aug2', 'a0002', 'a0002_aug0', 'a0002_aug1', 'a0002_aug2', 'a0003', 'a0003_aug0']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 1 1 1]
# Value range: -4.155 ~ 1.561

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features_validation.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_validation.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("Log-Mel Spectrogram (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0002', 'a0003', 'a0004', 'a0005', 'a0006', 'a0007', 'a0008', 'a0009', 'a0010']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 0 1 1]
# Value range: -4.378 ~ 1.684

# %% [markdown]
# # ConfigParser

# %%
# parse_config.py
import os
import logging
from pathlib import Path
from datetime import datetime
import argparse
import collections
import importlib.util

class ConfigParser:
    def __init__(self, config_dict, resume=None, modification=None, run_id=None):
        self._config = config_dict
        self.resume = resume

        # Apply CLI modifications
        if modification:
            for key_path, value in modification.items():
                keys = key_path.split(';')
                d = self._config
                for k in keys[:-1]:
                    d = d[k]
                d[keys[-1]] = value

        # Setup save and log directories
        save_dir = Path(self.config['trainer']['save_dir'])
        exper_name = self.config['name']
        if run_id is None:
            run_id = datetime.now().strftime(r'%m%d_%H%M%S')
        self._save_dir = save_dir / 'models' / exper_name / run_id
        self._log_dir = save_dir / 'log' / exper_name / run_id

        self.save_dir.mkdir(parents=True, exist_ok=True)
        self.log_dir.mkdir(parents=True, exist_ok=True)

        # Optional: setup logging
        # setup_logging(self.log_dir)

    @classmethod
    def from_args(cls, parser, options=None):
        """
        parser: argparse.ArgumentParser đã được add_argument xong
        options: list các CustomArgs để override
        """
        if options is None:
            options = []

        # Parse arguments (an toàn cho cả terminal và notebook)
        args = parser.parse_args()

        # Xử lý device
        if args.device is not None:
            os.environ["CUDA_VISIBLE_DEVICES"] = args.device

        # Xử lý resume
        if args.resume is not None:
            resume = Path(args.resume)
            cfg_fname = resume.parent / 'config.py'  # hoặc .json nếu bạn dùng cả 2
        else:
            resume = None
            assert args.config is not None, "Phải chỉ định -c config.py"
            cfg_fname = Path(args.config)

        # Đọc config từ file .py
        if not cfg_fname.exists():
            raise FileNotFoundError(f"Không tìm thấy config file: {cfg_fname}")

        if cfg_fname.suffix == '.py':
            spec = importlib.util.spec_from_file_location("config_module", cfg_fname)
            config_module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(config_module)
            if not hasattr(config_module, 'config'):
                raise ValueError(f"File {cfg_fname} phải định nghĩa biến 'config'")
            config_dict = config_module.config
        else:
            raise ValueError("Chỉ hỗ trợ file config .py")

        # Parse custom CLI overrides
        CustomArgs = collections.namedtuple('CustomArgs', 'flags type target')
        modification = {}
        for opt in options:
            for flag in opt.flags:
                arg_name = flag.lstrip('-').replace('-', '_')
                if hasattr(args, arg_name) and getattr(args, arg_name) is not None:
                    modification[opt.target] = opt.type(getattr(args, arg_name))

        return cls(config_dict, resume, modification)

    def init_obj(self, name, module, *args, **kwargs):
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def init_ftn(self, name, module, *args, **kwargs):
        from functools import partial
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def __getitem__(self, name):
        return self.config[name]

    def get_logger(self, name, verbosity=2):
        logger = logging.getLogger(name)
        logger.setLevel({0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}[verbosity])
        return logger

    @property
    def config(self):
        return self._config

    @property
    def save_dir(self):
        return self._save_dir

    @property
    def log_dir(self):
        return self._log_dir

# %% [markdown]
# # Logging

# %%
def mixup_data(x, y, alpha=0.2):
    """Mixup augmentation"""
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %% [markdown]
# #Loss

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=1.5):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# %%
class CBFocalLoss(nn.Module):
    def __init__(self, samples_per_class, beta=0.9999, gamma=2.0):
        super().__init__()
        effective_num = 1.0 - np.power(beta, samples_per_class)
        weights = (1.0 - beta) / np.array(effective_num)
        self.weights = weights / np.sum(weights) * len(samples_per_class)
        self.gamma = gamma

    def forward(self, inputs, targets):
        weights = torch.tensor(self.weights, device=inputs.device).float()
        ce_loss = F.cross_entropy(inputs, targets, weight=weights, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# Sử dụng:
# samples_per_class = [số_mẫu_abnormal, số_mẫu_normal]

# %%
class WeightedCELoss(nn.Module):
    """
    Weighted Cross Entropy Loss
    """
    def __init__(self, weights):
        super().__init__()
        self.register_buffer(
            "weights", torch.tensor(weights, dtype=torch.float)
        )

    def forward(self, logits, target):
        return F.cross_entropy(
            logits,
            target,
            weight=self.weights
        )

# %%
class CostSensitiveLoss(nn.Module):
    """
    Cost-sensitive Cross Entropy
    FN (abnormal → normal) bị phạt nặng hơn FP
    """
    def __init__(self, fn_cost=2.5, fp_cost=1.0):
        super().__init__()
        self.fn_cost = fn_cost
        self.fp_cost = fp_cost

    def forward(self, logits, target):
        weights = torch.tensor(
            [self.fp_cost, self.fn_cost],
            device=logits.device
        )

        return F.cross_entropy(
            logits,
            target,
            weight=weights
        )

# %%
class CombinedLoss(nn.Module):
    def __init__(self, alpha=0.7, gamma=2.5, label_smoothing=0.1, focal_weight=0.7):
        self.focal_loss = ImprovedFocalLoss(alpha, gamma, label_smoothing)
        self.ce_loss = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# %%
import torch.nn.functional as F


def nll_loss(output, target):
    return F.nll_loss(output, target)

def ce_loss(output, target):
    return F.cross_entropy(output, target)

def focal_loss(output, target, alpha=0.75, gamma=2.0):
    return FocalLoss(alpha=alpha, gamma=gamma)(output, target)

# Dùng khi tỷ lệ abnormal ≪ normal.
def weighted_ce_loss(output, target, weights):
    return WeightedCELoss(weights)(output, target)

# Đặc biệt phù hợp bài toán y sinh, nơi bỏ sót bệnh (FN) nguy hiểm hơn FP.
def cost_sensitive_loss(output, target, fn_cost=2.5, fp_cost=1.0):
    return CostSensitiveLoss(fn_cost, fp_cost)(output, target)

LOSS_REGISTRY = {
    "ce_loss": lambda: nn.CrossEntropyLoss(),
    "focal_loss": lambda: FocalLoss(alpha=0.75, gamma=2.0),
    "cost_sensitive_loss": lambda: CostSensitiveLoss(fn_cost=2.5, fp_cost=1.0),
    "weighted_ce_loss": lambda weights: WeightedCELoss(weights),
}

# %% [markdown]
# # Metric

# %%
import torch


def accuracy(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
    return correct / len(target)

import torch

def sensitivity(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()
    return tp / (tp + fn + eps)


def f1_score(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)

        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fp = torch.sum((pred == positive_class) & (target != positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()

        precision = tp / (tp + fp + eps)
        recall    = tp / (tp + fn + eps)

        f1 = 2 * precision * recall / (precision + recall + eps)

    return f1

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

# Warmup scheduler
class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, lr_min=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.lr_min = lr_min
        self.base_lr = optimizer.param_groups[0]['lr']

    def step(self, epoch):
        if epoch < self.warmup_epochs:
            lr = self.base_lr * (epoch + 1) / self.warmup_epochs
        else:
            progress = (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs)
            lr = self.lr_min + (self.base_lr - self.lr_min) * 0.5 * (1 + np.cos(np.pi * progress))

        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr
        return lr

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif val_loss > self.best_score - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        else:
            self.best_score = val_loss
            self.counter = 0
        return False

# %% [markdown]
# # Model

# %%
import torch.nn as nn
import numpy as np
from abc import abstractmethod


class BaseModel(nn.Module):
    """
    Base class for all models
    """
    @abstractmethod
    def forward(self, *inputs):
        """
        Forward pass logic

        :return: Model output
        """
        raise NotImplementedError

    def __str__(self):
        """
        Model prints with number of trainable parameters
        """
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        params = sum([np.prod(p.size()) for p in model_parameters])
        return super().__str__() + '\nTrainable parameters: {}'.format(params)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# functions of initializing layers
def init_layer(layer):
    """Initialize a Linear or Convolutional layer."""
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, 'bias'):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)

def init_bn(bn):
    """Initialize a Batchnorm layer."""
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.)

def init_rnn(rnn):
    """init_rnn
    Initialized RNN weights, independent of type GRU/LSTM/RNN
    :param rnn: the rnn model
    """
    for name, param in rnn.named_parameters():
        if 'bias' in name:
            nn.init.constant_(param, 0.0)
        elif 'weight' in name:
            nn.init.xavier_uniform_(param)

def reset_parameters(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            init_layer(module)
        elif isinstance(module, nn.Linear):
            init_layer(module)
        elif isinstance(module, nn.BatchNorm2d):
            init_bn(module)
        elif isinstance(module, nn.LSTM):
            init_rnn(module)

# %% [markdown]
# ## Simple CNN Block

# %%
'''
class simple_cnn(BaseModel):
    def __init__(self, num_classes = 2, in_channel = 1):
        super(simple_cnn, self).__init__()
        self.in_channel = in_channel

        # -------- Block 1 --------
        #self.conv1 = nn.Conv2d(in_channel,16,3)
        self.conv1 = nn.Conv2d(in_channel, 8, kernel_size=3, padding=1)
        #self.bn1 = nn.BatchNorm2d(16)
        self.bn1 = nn.BatchNorm2d(8)

        # -------- Block 2 --------
        #self.conv2 = nn.Conv2d(16,32,3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(16)


        # -------- Global pooling --------
        self.gap = nn.AdaptiveAvgPool2d(1)

        # -------- Regularization + Classifier --------
        self.dropout = nn.Dropout(p=0.5)
        self.output = nn.Linear(16, num_classes)

        self.init_weights()

    def init_weights(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        #init_layer(self.conv3)
        #init_layer(self.fc)
        init_layer(self.output)
        init_bn(self.bn1)
        init_bn(self.bn2)


    def forward(self, x):
        """
        x: (B, mel_bins, time_frames)
        """
        B, mel_bins, num_frames = x.size()
        x = x.view(B, self.in_channel, mel_bins, num_frames)

        # -------- Block 1 --------
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, kernel_size=2)

        # -------- Block 2 --------
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, kernel_size=2)

        # -------- Global Average Pooling --------
        x = self.gap(x)                 # (B, 16, 1, 1)
        x = x.view(x.size(0), -1)       # (B, 16)

        # -------- Classifier --------
        x = self.dropout(x)
        out = self.output(x)

        return out
'''
# Out:
# '\nclass simple_cnn(BaseModel):\n    def __init__(self, num_classes = 2, in_channel = 1):\n        super(simple_cnn, self).__init__()\n        self.in_channel = in_channel\n\n        # -------- Block 1 --------\n        #self.conv1 = nn.Conv2d(in_channel,16,3)\n        self.conv1 = nn.Conv2d(in_channel, 8, kernel_size=3, padding=1)\n        #self.bn1 = nn.BatchNorm2d(16)\n        self.bn1 = nn.BatchNorm2d(8)\n\n        # -------- Block 2 --------\n        #self.conv2 = nn.Conv2d(16,32,3)\n        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)\n        self.bn2 = nn.BatchNorm2d(16)\n\n\n        # -------- Global pooling --------\n        self.gap = nn.AdaptiveAvgPool2d(1)\n\n        # -------- Regularization + Classifier --------\n        self.dropout = nn.Dropout(p=0.5)\n        self.output = nn.Linear(16, num_classes)\n\n        self.init_weights()\n\n    def init_weights(self):\n        init_layer(self.conv1)\n        init_layer(self.conv2)\n        #init_layer(self.conv3)\n        #init_layer(self.fc)\n        init_layer(self.output)\n        init_bn(self.bn1)\n        init_bn(self.bn2)\n\n\n    def forward(self, x):\n        """\n        x: (B, mel_bins, time_frames)\n        """\n        B, mel_bins, num_frames = x.size()\n        x = x.view(B, self.in_channel, mel_bins, num_frames)\n\n        # -------- Block 1 --------\n        x = self.conv1(x)\n        x = self.bn1(x)\n        x = F.relu(x)\n        x = F.max_pool2d(x, kernel_size=2)\n\n        # -------- Block 2 --------\n        x = self.conv2(x)\n        x = self.bn2(x)\n        x = F.relu(x)\n        x = F.max_pool2d(x, kernel_size=2)\n\n        # -------- Global Average Pooling --------\n        x = self.gap(x)                 # (B, 16, 1, 1)\n        x = x.view(x.size(0), -1)       # (B, 16)\n\n        # -------- Classifier --------\n        x = self.dropout(x)\n        out = self.output(x)\n\n        return out\n'

# %%
class simple_cnn(BaseModel):
    def __init__(self, num_classes=2, in_channel=1):
        super(simple_cnn, self).__init__()
        self.in_channel = in_channel

        # -------- Block 1 --------
        self.conv1 = nn.Conv2d(in_channel, 16, kernel_size=(3, 7), padding=(1, 3))
        self.bn1 = nn.BatchNorm2d(16)
        self.drop1 = nn.Dropout2d(p=0.1)

        # -------- Block 2 --------
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 7), padding=(1, 3))
        self.bn2 = nn.BatchNorm2d(32)
        self.drop2 = nn.Dropout2d(p=0.2)

        # -------- Block 3 --------
        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 5), padding=(1, 2))
        self.bn3 = nn.BatchNorm2d(64)
        self.drop3 = nn.Dropout2d(p=0.2)

        # -------- Global pooling --------
        self.gap = nn.AdaptiveAvgPool2d(1)

        # -------- Classifier --------
        self.classifier = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(32, num_classes)
        )

        self.init_weights()

    def init_weights(self):
        # Khởi tạo các lớp Conv
        init_layer(self.conv1)
        init_layer(self.conv2)
        init_layer(self.conv3) # Đừng quên lớp này nhé

        # Khởi tạo các lớp BatchNorm
        init_bn(self.bn1)
        init_bn(self.bn2)
        init_bn(self.bn3) # Khởi tạo thêm BN3

        # Khởi tạo các lớp Linear bên trong Sequential classifier
        for m in self.classifier.modules():
            if isinstance(m, nn.Linear):
                init_layer(m)

    def forward(self, x):
        B, mel_bins, num_frames = x.size()
        x = x.view(B, self.in_channel, mel_bins, num_frames)

        # Block 1
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.drop1(x)
        x = F.max_pool2d(x, kernel_size=(1, 2))

        # Block 2
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.drop2(x)
        x = F.max_pool2d(x, kernel_size=(1, 2))

        # Block 3
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.drop3(x)

        # GAP + Output
        x = self.gap(x).view(x.size(0), -1)
        out = self.classifier(x)
        return out

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=4):
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(channels, channels // reduction),
            nn.ReLU(), nn.Linear(channels // reduction, channels), nn.Sigmoid()
        )
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size,
                                   stride, padding, groups=in_channels, bias=False)
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU6(inplace=True)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        x = self.bn(x)
        return self.relu(x)

class LightweightHeartSoundCNN(nn.Module):
    def __init__(self, num_classes=2, in_channel=1, dropout=0.3):
        super().__init__()
        self.in_channel = in_channel
        # Input: (B, 39, 333) → reshape thành (B, 1, 39, 333)
        self.stem = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU6(inplace=True)
        )

        self.attention_pool = nn.Sequential(
            nn.Conv2d(128, 64, 1), nn.ReLU6(), nn.Conv2d(64, 1, 1), nn.Sigmoid()
        )

        self.features = nn.Sequential(
            DepthwiseSeparableConv(16, 32, stride=2),   # → (B, 32, 10, 83)
            nn.Dropout2d(0.1),
            DepthwiseSeparableConv(32, 64, stride=2),   # → (B, 64, 5, 41)
            nn.Dropout2d(0.15),
            DepthwiseSeparableConv(64, 128, stride=2),  # → (B, 128, 3, 20)
            nn.Dropout2d(0.15),
        )

        # Global Average Pooling (thay vì FC lớn)
        self.pool = nn.AdaptiveAvgPool2d(1)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
      """
      x:
        - delta = False: (B, 13, T)
        - delta = True : (B, 39, T)
      """
      B, F, T = x.shape

      # Reshape feature → (B, C, H, W)
      x = x.view(B, self.in_channel, F // self.in_channel, T)
      # (B, 1, 13, T) hoặc (B, 3, 13, T)

      x = self.stem(x)       # Conv2d expects 4D
      x = self.features(x)
      x = self.pool(x)
      x = x.flatten(1)
      return self.classifier(x)

# %% [markdown]
# ## Deeper CNN model, VGG like structure

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels = in_channels,
                               out_channels = out_channels,
                               kernel_size = (3,3),
                               stride = (1,1),
                               padding = (1,1),
                               bias =False)

        self.conv2 = nn.Conv2d(in_channels = out_channels,
                               out_channels = out_channels,
                               kernel_size = (3,3),
                               stride = (1,1),
                               padding = (1,1),
                               bias = False)

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.init_weights()

    def init_weights(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        init_bn(self.bn1)
        init_bn(self.bn2)

    def forward(self, input, pool_size=(2, 2), pool_type='max', activation = 'relu'):
        x = input
        x = F.relu_(self.bn1(self.conv1(x)))
        if activation == 'relu':
            x = F.relu_(self.bn2(self.conv2(x)))
        elif activation == 'sigmoid':
            x = torch.sigmoid(self.bn2(self.conv2(x)))

        if pool_type == 'max':
            x = F.max_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg':
            x = F.avg_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg+max':
            x1 = F.avg_pool2d(x, kernel_size=pool_size)
            x2 = F.max_pool2d(x, kernel_size=pool_size)
            x = x1 + x2
        else:
            raise Exception('Incorrect argument!')

        return x

class VGG_11(BaseModel):
    def __init__(self, num_classes, in_channel):
        super(VGG_11, self).__init__()
        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)
        self.conv1 = ConvBlock(in_channels=in_channel, out_channels=64)
        self.conv2 = ConvBlock(in_channels=64, out_channels=128)
        self.conv3 = ConvBlock(in_channels=128, out_channels=256)
        self.conv4 = ConvBlock(in_channels=256, out_channels=512)
        self.fc_final = nn.Linear(512, num_classes)
        self.init_weights()

    def init_weights(self):
        init_bn(self.bn0)
        init_layer(self.fc_final)

    def forward(self, input):
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        # (samples_num, channel, mel_bins, time_stamps)
        x = self.conv1(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)

        output = F.max_pool2d(x, kernel_size=x.shape[2:])
        output = output.view(output.shape[0:2])
        output = F.log_softmax(self.fc_final(output), dim=-1)
        return output


class VGG_13(BaseModel):
    def __init__(self, num_classes, in_channel):
        super(VGG_13, self).__init__()
        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)
        self.conv1 = ConvBlock(in_channels=in_channel, out_channels=64)
        self.conv2 = ConvBlock(in_channels=64, out_channels=128)
        self.conv3 = ConvBlock(in_channels=128, out_channels=256)
        self.conv4 = ConvBlock(in_channels=256, out_channels=512)
        self.conv5 = ConvBlock(in_channels=512, out_channels=512)
        self.fc_1 = nn.Linear(512 * 4* 10, 4096)
        self.fc_2 = nn.Linear(4096, 4096)
        self.fc_final = nn.Linear(4096, num_classes)
        self.init_weights()

    def init_weights(self):
        init_bn(self.bn0)
        init_layer(self.fc_final)
        init_layer(self.fc_1)
        init_layer(self.fc_2)

    def forward(self, input):
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        # (samples_num, channel, time_stemps, mel_bins)
        x = self.conv1(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv5(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        #output = F.max_pool2d(x, kernel_size=x.shape[2:])
        #output = output.view(output.shape[0:2])
        x = x.view(x.shape[0], -1)
        x = F.relu_(self.fc_1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu_(self.fc_2(x))
        x = F.dropout(x, p=0.5, training=self.training)
        output = F.log_softmax(self.fc_final(x),dim=-1)
        #output = F.log_softmax(self.fc_final(output), dim=-1)
        return output

# %% [markdown]
# ## RNN - BiLTSM

# %%
class BiLSTM(BaseModel):
    def __init__(self,
                 input_dim=200,
                 hidden_dim=256,
                 num_layers =2,
                 dropout=0.2,
                 num_classes=2,
                 pooling='first',
                 model='lstm',
                 BN=False):
        super(BiLSTM,self).__init__()
        if model == 'lstm':
            self.LSTM = nn.LSTM(input_size=input_dim,
                                hidden_size =hidden_dim,
                                num_layers =num_layers,
                                batch_first =True,
                                dropout=dropout,
                                bidirectional=True)
        elif model == 'gru':
            self.LSTM = nn.GRU(input_size=input_dim,
                               hidden_size =hidden_dim,
                               num_layers =num_layers,
                               batch_first =True,
                               dropout=dropout,
                               bidirectional=True)
        init_rnn(self.LSTM)
        self.BN = BN
        if self.BN:
            self.BatchNorm=nn.BatchNorm1d(hidden_dim*2)

        self.layer_out = nn.Linear(hidden_dim*2,num_classes,bias=False)
        self.pooling=pooling

    def forward(self,x):
        x = x.transpose(2,1) #[Batchsize x Time_frames x Mel_bin]
        x,_ = self.LSTM(x)
        if self.BN:
            x = self.BatchNorm(x.transpose(1,2))
            x = x.transpose(1,2)
        dim =1
        x = self.layer_out(x)  #200,2
        if self.pooling == 'avg':
            x = x.mean(dim)   #average pooling
        elif self.pooling == 'first':
            x = x.select(dim,0)  #first time step
        elif self.pooling == 'last':
            x = x.select(dim,-1)  #first time step
        elif self.pooling == 'max':
            x = x.max(dim)[0]
        elif  self.pooling == 'linear':
            (x**2).sum(dim) / x.sum(dim)
        elif self.pooling == 'exp':
            (x.exp() * x).sum(dim) / x.exp().sum(dim)

        # print(out.shape)
        # out = self.LogSoftmax(out)#the input given is expected to contain log-probabilities. Obtaining log-probabilities in a neural network is easily achieved by adding a LogSoftmax layer in the last layer of your network.
        return x#,A

# %% [markdown]
# ## CRNN

# %%
class CNN_Encoder(nn.Module):
    def __init__(self, in_channels):
        super(CNN_Encoder, self).__init__()

        self.conv1 = ConvBlock(in_channels=in_channels, out_channels=32)
        self.conv2 = ConvBlock(in_channels=32, out_channels=64)
        self.conv3 = ConvBlock(in_channels=64, out_channels=128)
        self.conv4 = ConvBlock(in_channels=128, out_channels=256)
    def forward(self, input):
        x = input
        x = self.conv1(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)

        return x

class crnn(BaseModel):
    def __init__(self, in_channel,
                 hidden_dim=128,
                 num_layers = 2,
                 dropout = 0.2,
                 pooling = 'first',
                 model='lstm',
                 BN = True,
                 num_classes=2):
        super(crnn,self).__init__()

        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)

        self.cnn = CNN_Encoder(in_channels=in_channel)
        self.bilstm = BiLSTM(input_dim=256,
                             hidden_dim=hidden_dim,
                             num_layers =num_layers,
                             dropout =dropout,
                             num_classes=num_classes,
                             pooling=pooling,
                             model=model,
                             BN=BN)


    def forward(self,input):
        if isinstance(input, (tuple, list)):
          input = input[0]
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        x = self.cnn(x)
        x = F.max_pool2d(x,kernel_size=(x.size(-2), 1)) # pool mel dimension
        x = x.squeeze(-2)  # [B x C x Time_frames]
        output = self.bilstm(x)
        return output

# %% [markdown]
# # Config

# %% [markdown]
# ## CNN

# %%
from pathlib import Path

config_cnn = {
    "name": "Physionet_simple_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "simple_cnn",
        "args": {
            "num_classes": 2,
            "in_channel": 1 #Declare channel
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 3e-5, #2e-4
            "weight_decay": 1e-4, #0.0
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "focal_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "ReduceLROnPlateau",
        "args": {
            "mode": "max",
            "factor": 0.5,
            "patience": 7,
            #"verbose": True,
            "min_lr": 1e-6
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved"/"simple_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_sensitivity",
        "early_stop": 20,
        "tensorboard": True
    }
}

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
from pathlib import Path

config_light_cnn = {
    "name": "Physionet_lightweight_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "LightweightHeartSoundCNN",
        "args": {
            "num_classes": 2,
            "in_channel": 1 #Declare channel
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 5e-4, #2e-4
            "weight_decay": 1e-4, #0.0
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "combined_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "CosineAnnealingWarmRestarts",
        "args": {
            "T_0": 10,
            "T_mult": 2,
            "eta_min": 1e-6
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 150,
        "save_dir": str(PROJECT_PATH / "saved"/"lightweight_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_sensitivity",
        "early_stop": 20,
        "tensorboard": True,
        "use_mixup": True,
        "mixup_alpha": 0.2,
        "gradient_clip": 1.0
    }
}

# %% [markdown]
# ## CRNN

# %% [markdown]
# ## LTSM

# %% [markdown]
# ## VGG

# %%
from pathlib import Path

config_vgg = {
    "name": "Physionet_VGG11",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "VGG_11",
        "args": {
            "num_classes": 2,
            "in_channel": 3
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "delta": True,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 200,
        "save_dir": str(PROJECT_PATH / "saved" / "VGG11"),
        "save_period": 1,
        "verbosity": 2,

        "monitor": "max val_F1_score",
        "early_stop": 20,

        "tensorboard": True
    }
}

# %% [markdown]
# # Training

# %%
def prepare_device(n_gpu_use):
    """
    setup GPU device if available. get gpu device indices which are used for DataParallel
    """
    n_gpu = torch.cuda.device_count()
    if n_gpu_use > 0 and n_gpu == 0:
        print("Warning: There\'s no GPU available on this machine,"
              "training will be performed on CPU.")
        n_gpu_use = 0
    if n_gpu_use > n_gpu:
        print(f"Warning: The number of GPU\'s configured to use is {n_gpu_use}, but only {n_gpu} are "
              "available on this machine.")
        n_gpu_use = n_gpu
    device = torch.device('cuda:0' if n_gpu_use > 0 else 'cpu')
    list_ids = list(range(n_gpu_use))
    return device, list_ids

# %%
class MetricTracker:
    def __init__(self, *keys, writer=None):
        self.writer = writer
        self._data = pd.DataFrame(index=keys, columns=['total', 'counts', 'average'])
        self.reset()

    def reset(self):
        for col in self._data.columns:
            self._data[col].values[:] = 0

    def update(self, key, value, n=1):
        if self.writer is not None:
            self.writer.add_scalar(key, value)
        df = self._data

        df.loc[key, "total"] += value * n
        df.loc[key, "counts"] += n
        df.loc[key, "average"] = df.loc[key, "total"] / df.loc[key, "counts"]


    def avg(self, key):
        return self._data.average[key]

    def result(self):
        return dict(self._data.average)

# %%
def setup_logging(save_dir, log_config='logger/logger_config.json', default_level=logging.INFO):
    """
    Setup logging configuration
    """
    log_config = Path(log_config)
    if log_config.is_file():
        config = read_json(log_config)
        # modify logging paths based on run config
        for _, handler in config['handlers'].items():
            if 'filename' in handler:
                handler['filename'] = str(save_dir / handler['filename'])

        logging.config.dictConfig(config)
    else:
        print("Warning: logging configuration file is not found in {}.".format(log_config))
        logging.basicConfig(level=default_level)
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %%
import torch
from abc import abstractmethod
from numpy import inf

def safe_append(lst, value):
    lst.append(value if value is not None else np.nan)

class BaseTrainer:
    """
    Base class for all trainers
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config):
        self.config = config
        self.logger = config.get_logger('trainer', config['trainer']['verbosity'])

        self.model = model
        self.criterion = criterion
        self.metric_ftns = metric_ftns
        self.optimizer = optimizer

        cfg_trainer = config['trainer']
        self.epochs = cfg_trainer['epochs']
        self.save_period = cfg_trainer['save_period']
        self.monitor = cfg_trainer.get('monitor', 'off')

        # configuration to monitor model performance and save best
        if self.monitor == 'off':
            self.mnt_mode = 'off'
            self.mnt_best = 0
        else:
            self.mnt_mode, self.mnt_metric = self.monitor.split()
            assert self.mnt_mode in ['min', 'max']

            self.mnt_best = inf if self.mnt_mode == 'min' else -inf
            self.early_stop = cfg_trainer.get('early_stop', inf)
            if self.early_stop <= 0:
                self.early_stop = inf

        self.start_epoch = 1

        self.checkpoint_dir = config.save_dir

        self.history = {
            "epoch": [],
            "train_loss": [],
            "train_accuracy": [],
            "val_loss": [],
            "val_accuracy": [],
            "val_F1_score": [],
            "val_sensitivity": [],
            "val_specificity": [],
            "val_MAcc": []
        }


        self.history_path = Path(self.checkpoint_dir) / "metrics.csv"

        # setup visualization writer instance
        self.writer = TensorboardWriter(config.log_dir, self.logger, cfg_trainer['tensorboard'])

        if config.resume is not None:
            self._resume_checkpoint(config.resume)

    @abstractmethod
    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Current epoch number
        """
        raise NotImplementedError

    def train(self):
        """
        Full training logic
        """
        not_improved_count = 0
        for epoch in range(self.start_epoch, self.epochs + 1):
            result = self._train_epoch(epoch)

            # save logged informations into log dict
            log = {'epoch': epoch}
            log.update(result)

            # ===== GHI METRICS SAU MỖI EPOCH =====
            safe_append(self.history["epoch"], epoch)
            safe_append(self.history["train_loss"], log.get("loss"))
            safe_append(self.history["train_accuracy"], log.get("accuracy"))

            safe_append(self.history["val_loss"], log.get("val_loss"))
            safe_append(self.history["val_accuracy"], log.get("val_accuracy"))
            safe_append(self.history["val_F1_score"], log.get("val_F1_score"))
            safe_append(self.history["val_sensitivity"], log.get("val_sensitivity"))
            safe_append(self.history["val_specificity"], log.get("val_specificity"))
            safe_append(self.history["val_MAcc"], log.get("val_MAcc"))



            pd.DataFrame(self.history).to_csv(self.history_path, index=False)

            # print logged informations to the screen
            for key, value in log.items():
                self.logger.info('    {:15s}: {}'.format(str(key), value))

            # evaluate model performance according to configured metric, save best checkpoint as model_best
            best = False
            if self.mnt_mode != 'off':
                try:
                    # check whether model performance improved or not, according to specified metric(mnt_metric)
                    improved = (self.mnt_mode == 'min' and log[self.mnt_metric] <= self.mnt_best) or \
                               (self.mnt_mode == 'max' and log[self.mnt_metric] >= self.mnt_best)
                except KeyError:
                    self.logger.warning("Warning: Metric '{}' is not found. "
                                        "Model performance monitoring is disabled.".format(self.mnt_metric))
                    self.mnt_mode = 'off'
                    improved = False

                if improved:
                    self.mnt_best = log[self.mnt_metric]
                    not_improved_count = 0
                    best = True
                else:
                    not_improved_count += 1

                if not_improved_count > self.early_stop:
                    self.logger.info("Validation performance didn\'t improve for {} epochs. "
                                     "Training stops.".format(self.early_stop))
                    break

            if best:
                self._save_best_model(epoch)

    def _save_checkpoint(self, epoch, save_best=False):
        """
        Saving checkpoints

        :param epoch: current epoch number
        :param log: logging information of the epoch
        :param save_best: if True, rename the saved checkpoint to 'model_best.pth'
        """
        arch = type(self.model).__name__
        state = {
            'arch': arch,
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'monitor_best': self.mnt_best,
            'config': self.config
        }
        filename = str(self.checkpoint_dir / 'checkpoint-epoch{}.pth'.format(epoch))
        torch.save(state, filename)
        self.logger.info("Saving checkpoint: {} ...".format(filename))
        if save_best:
            best_path = str(self.checkpoint_dir / 'model_best.pth')
            torch.save(state, best_path)
            self.logger.info("Saving current best: model_best.pth ...")

    def _resume_checkpoint(self, resume_path):
        """
        Resume from saved checkpoints

        :param resume_path: Checkpoint path to be resumed
        """
        resume_path = str(resume_path)
        self.logger.info("Loading checkpoint: {} ...".format(resume_path))
        checkpoint = torch.load(resume_path)
        self.start_epoch = checkpoint['epoch'] + 1
        self.mnt_best = checkpoint['monitor_best']

        # load architecture params from checkpoint.
        if checkpoint['config']['arch'] != self.config['arch']:
            self.logger.warning("Warning: Architecture configuration given in config file is different from that of "
                                "checkpoint. This may yield an exception while state_dict is being loaded.")
        self.model.load_state_dict(checkpoint['state_dict'])

        # load optimizer state from checkpoint only when optimizer type is not changed.
        if checkpoint['config']['optimizer']['type'] != self.config['optimizer']['type']:
            self.logger.warning("Warning: Optimizer type given in config file is different from that of checkpoint. "
                                "Optimizer parameters not being resumed.")
        else:
            self.optimizer.load_state_dict(checkpoint['optimizer'])

        self.logger.info("Checkpoint loaded. Resume training from epoch {}".format(self.start_epoch))

    def _save_best_model(self, epoch):
      """
      Save only the best model according to monitoring metric
      """
      arch = type(self.model).__name__
      state = {
          'arch': arch,
          'epoch': epoch,
          'state_dict': self.model.state_dict(),
          'optimizer': self.optimizer.state_dict(),
          'monitor_best': self.mnt_best,
          'config': self.config
      }

      best_path = self.checkpoint_dir / 'model_best.pth'
      torch.save(state, best_path)

      self.logger.info(
          f"Saving new best model at epoch {epoch}: model_best.pth"
      )

# %%
from itertools import repeat

def inf_loop(data_loader):
    ''' wrapper function for endless data loader. '''
    for loader in repeat(data_loader):
        yield from loader

# %%
class Trainer(BaseTrainer):
    """
    Trainer class
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config, device,
                 data_loader, valid_data_loader=None, lr_scheduler=None, len_epoch=None):
        super().__init__(model, criterion, metric_ftns, optimizer, config)
        self.config = config
        self.device = device
        self.data_loader = data_loader
        if len_epoch is None:
            # epoch-based training
            self.len_epoch = len(self.data_loader)
        else:
            # iteration-based training
            self.data_loader = inf_loop(data_loader)
            self.len_epoch = len_epoch
        self.valid_data_loader = valid_data_loader
        self.do_validation = self.valid_data_loader is not None
        self.lr_scheduler = lr_scheduler

        cfg_trainer = config['trainer']
        self.use_mixup = cfg_trainer.get("use_mixup", False)
        self.mixup_alpha = cfg_trainer.get("mixup_alpha", 0.2)
        self.gradient_clip = cfg_trainer.get("gradient_clip", 0.0)

        self.log_step = int(np.sqrt(data_loader.batch_size))

        self.train_metrics = MetricTracker('loss', *[m.__name__ for m in self.metric_ftns], writer=self.writer)
        self.valid_metrics = MetricTracker('loss',*[m.__name__ for m in self.metric_ftns],
                                           'sensitivity', 'specificity', 'MAcc', 'F1_score',
                                           writer = self.writer)


    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains average loss and metric in this epoch.
        """
        self.model.train()
        self.train_metrics.reset()
        for batch_idx, (data, target) in enumerate(self.data_loader):
            data, target = data.to(self.device), target.to(self.device)

            self.optimizer.zero_grad()

            if self.use_mixup and np.random.rand() > 0.5:
                data, targets_a, targets_b, lam = mixup_data(data, target, alpha=0.2)
                output = self.model(data)
                loss = mixup_criterion(self.criterion, output, targets_a, targets_b, lam)
            else:
                output = self.model(data)
                loss = self.criterion(output, target)

            loss.backward()
            if self.gradient_clip > 0:
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.gradient_clip)

            self.optimizer.step()

            self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
            self.train_metrics.update('loss', loss.item())
            for met in self.metric_ftns:
                self.train_metrics.update(met.__name__, met(output, target))

            if batch_idx % self.log_step == 0:
                self.logger.debug('Train Epoch: {} {} Loss: {:.6f}'.format(
                    epoch,
                    self._progress(batch_idx),
                    loss.item()))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

            if batch_idx == self.len_epoch:
                break
        log = self.train_metrics.result()

        if self.do_validation:
            val_log = self._valid_epoch(epoch)
            log.update(**{'val_'+k : v for k, v in val_log.items()})

        #if self.lr_scheduler is not None:
            #self.lr_scheduler.step()

        if self.lr_scheduler is not None:
            if isinstance(self.lr_scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                # ReduceLROnPlateau cần metric để theo dõi (thường là val_loss)
                # Lấy giá trị 'loss' từ kết quả của hàm _valid_epoch
                self.lr_scheduler.step(val_log['loss'])
            else:
                # Các scheduler khác như StepLR không cần tham số
                self.lr_scheduler.step()
        return log

    def _valid_epoch(self, epoch):
        """
        Validate after training an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains information about validation
        """
        self.model.eval()
        self.valid_metrics.reset()
        val_pred_pos = 0
        val_pred_neg = 0
        val_condition_pos = 0
        val_condition_neg = 0
        val_TP = 0
        val_TN = 0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(self.valid_data_loader):
                data, target = data.to(self.device), target.to(self.device)
                output = self.model(data.float())
                loss = self.criterion(output, target)

                _,indices = torch.max(output, 1)

                pred_pos_idx = [i for i, x in enumerate(indices) if x == 0]
                condition_pos_idx = [i for i, x in enumerate(target) if x == 0]
                pred_neg_idx = [i for i, x in enumerate(indices) if x == 1]
                condition_neg_idx = [i for i, x in enumerate(target) if x == 1]

                val_pred_pos += len(pred_pos_idx)
                val_condition_pos += len(condition_pos_idx)
                val_pred_neg += len(pred_neg_idx)
                val_condition_neg += len(condition_neg_idx)
                val_TP += len([x for x in pred_pos_idx if x in condition_pos_idx])
                val_TN += len([x for x in pred_neg_idx if x in condition_neg_idx])
                correct = (indices == target).float()
                val_correct += torch.sum(correct).item()
                val_total += target.shape[0]

                self.writer.set_step((epoch - 1) * len(self.valid_data_loader) + batch_idx, 'valid')
                self.valid_metrics.update('loss', loss.item())
                for met in self.metric_ftns:
                    self.valid_metrics.update(met.__name__, met(output, target))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

        sensitivity = val_TP / val_condition_pos
        specificity = val_TN / val_condition_neg
        MAcc= (sensitivity + specificity) / 2
        if val_pred_pos == 0:
            precision = 0
            F1_score = 0
        else:
            precision = val_TP / val_pred_pos
            F1_score = 2 * (precision*sensitivity)/(precision+sensitivity)

        self.valid_metrics.update('sensitivity', sensitivity)
        self.valid_metrics.update('specificity', specificity)
        self.valid_metrics.update('MAcc',MAcc)
        self.valid_metrics.update('F1_score', F1_score)

        # add histogram of model parameters to the tensorboard
        for name, p in self.model.named_parameters():
            self.writer.add_histogram(name, p, bins='auto')
        return self.valid_metrics.result()

    def _progress(self, batch_idx):
        base = '[{}/{} ({:.0f}%)]'
        if hasattr(self.data_loader, 'n_samples'):
            current = batch_idx * self.data_loader.batch_size
            total = self.data_loader.n_samples
        else:
            current = batch_idx
            total = self.len_epoch
        return base.format(current, total, 100.0 * current / total)

# %% [markdown]
# ## Simple Train

# %%
#current_config = config_cnn
current_config  = config_light_cnn
#current_config = config_crnn
#current_config = config_lstm
#current_config = config_vgg

# %%
import os
import argparse
import collections
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

def main(config):

# Tạo ConfigParser từ biến config hiện tại
  config_parser = ConfigParser(config)

  # Train chính thức
  data_loader = config_parser.init_obj('data_loader', globals())  # hoặc import module phù hợp
  valid_data_loader = data_loader.split_validation()

  model = config_parser.init_obj('arch', globals())
  print(model)

  device, device_ids = prepare_device(config_parser['n_gpu'])
  model = model.to(device)
  if len(device_ids) > 1:
      model = torch.nn.DataParallel(model, device_ids=device_ids)

  #criterion = FocalLoss(alpha=0.25, gamma=2.0)
  criterion = CBFocalLoss(
      samples_per_class=[150, 150],
      beta=0.9999,
      gamma=2.0
  )
  #criterion = LOSS_REGISTRY["weighted_ce_loss"]([1.0, 2.5])
  metrics = [
      accuracy,
      f1_score
  ]

  optimizer = config_parser.init_obj('optimizer', torch.optim, filter(lambda p: p.requires_grad, model.parameters()))
  lr_scheduler = config_parser.init_obj('lr_scheduler', torch.optim.lr_scheduler, optimizer)

  trainer = Trainer(
      model=model,
      criterion=criterion,
      metric_ftns=metrics,
      optimizer=optimizer,
      config=config_parser,
      device=device,
      data_loader=data_loader,
      valid_data_loader=valid_data_loader,
      lr_scheduler=lr_scheduler
  )

  trainer.train()

  base_dir = (Path(config_parser['trainer']['save_dir'])/ "models"/ config_parser['name'])

  if not base_dir.exists():
    print("Models directory was not found.")
    return

  # Lấy run (timestamp) mới nhất
  latest_run = max(base_dir.iterdir(), key=os.path.getmtime)

  best_model_path = latest_run / "model_best.pth"

  if best_model_path.exists():
    print("\n=== HOÀN THÀNH TRAINING ===")
    print("Model tốt nhất được lưu tại:")
    print(best_model_path)
  else:
    print("The file 'model_best.pth' was not found.")

  metrics_path = Path(config_parser.save_dir) / "metrics.csv"

  if metrics_path.exists():
    df = pd.read_csv(metrics_path)
    epochs = df["epoch"]
  else:
    print("The file 'metrics.csv' was not found. Unable to display training results.")

  # ===== LOSS =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training and Validation Loss")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "loss_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== ACCURACY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_accuracy"], label="Training Accuracy")
  plt.plot(epochs, df["val_accuracy"], label="Validation Accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training and Validation Accuracy")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "accuracy_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== F1-SCORE =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_F1_score"], label="Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.title("Validation F1-score across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "f1_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== SENSITIVITY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_sensitivity"], label="Validation Sensitivity")
  plt.xlabel("Epoch")
  plt.ylabel("Sensitivity")
  plt.title("Validation Sensitivity across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "sensitivity_curve.png", dpi=300)
  plt.show()
  plt.close()

# %%
if __name__ == "__main__":
    # Train model với config hiện tại
    main(current_config)

    # Sau khi train xong, tự động test trên tập validation riêng (nếu có file)
    base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
# Out:
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (attention_pool): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU6()
#     (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     (3): Sigmoid()
#   )
#   (features): Sequential(
#     (0): DepthwiseSeparableConv(
#       (depthwise): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#       (pointwise): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (1): Dropout2d(p=0.1, inplace=False)
#     (2): DepthwiseSeparableConv(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (pointwise): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (3): Dropout2d(p=0.15, inplace=False)
#     (4): DepthwiseSeparableConv(
#       (depthwise): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (5): Dropout2d(p=0.15, inplace=False)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# Warning: There's no GPU available on this machine,training will be performed on CPU.
# DEBUG:trainer:Train Epoch: 1 [0/134 (0%)] Loss: 0.234725
# DEBUG:trainer:Train Epoch: 1 [5/134 (4%)] Loss: 0.236568
# DEBUG:trainer:Train Epoch: 1 [10/134 (7%)] Loss: 0.166774
# DEBUG:trainer:Train Epoch: 1 [15/134 (11%)] Loss: 0.156474
# DEBUG:trainer:Train Epoch: 1 [20/134 (15%)] Loss: 0.166014
# DEBUG:trainer:Train Epoch: 1 [25/134 (19%)] Loss: 0.208113
# DEBUG:trainer:Train Epoch: 1 [30/134 (22%)] Loss: 0.193785
# DEBUG:trainer:Train Epoch: 1 [35/134 (26%)] Loss: 0.179962
# DEBUG:trainer:Train Epoch: 1 [40/134 (30%)] Loss: 0.160044
# DEBUG:trainer:Train Epoch: 1 [45/134 (34%)] Loss: 0.172669
# DEBUG:trainer:Train Epoch: 1 [50/134 (37%)] Loss: 0.145963
# DEBUG:trainer:Train Epoch: 1 [55/134 (41%)] Loss: 0.172164
# DEBUG:trainer:Train Epoch: 1 [60/134 (45%)] Loss: 0.222210
# DEBUG:trainer:Train Epoch: 1 [65/134 (49%)] Loss: 0.166900
# DEBUG:trainer:Train Epoch: 1 [70/134 (52%)] Loss: 0.161919
# DEBUG:trainer:Train Epoch: 1 [75/134 (56%)] Loss: 0.173047
# DEBUG:trainer:Train Epoch: 1 [80/134 (60%)] Loss: 0.166141
# DEBUG:trainer:Train Epoch: 1 [85/134 (63%)] Loss: 0.176598
# DEBUG:trainer:Train Epoch: 1 [90/134 (67%)] Loss: 0.135869
# DEBUG:trainer:Train Epoch: 1 [95/134 (71%)] Loss: 0.125811
# DEBUG:trainer:Train Epoch: 1 [100/134 (75%)] Loss: 0.154932
# DEBUG:trainer:Train Epoch: 1 [105/134 (78%)] Loss: 0.189205
# DEBUG:trainer:Train Epoch: 1 [110/134 (82%)] Loss: 0.119634
# DEBUG:trainer:Train Epoch: 1 [115/134 (86%)] Loss: 0.131043
# DEBUG:trainer:Train Epoch: 1 [120/134 (90%)] Loss: 0.130294
# DEBUG:trainer:Train Epoch: 1 [125/134 (93%)] Loss: 0.131460
# DEBUG:trainer:Train Epoch: 1 [130/134 (97%)] Loss: 0.106669
# INFO:trainer:    epoch          : 1
# INFO:trainer:    loss           : 0.1698734979353734
# INFO:trainer:    accuracy       : 0.6136727078891259
# INFO:trainer:    f1_score       : 0.6173344759241886
# INFO:trainer:    val_loss       : 0.12897236916151913
# INFO:trainer:    val_accuracy   : 0.7747035573122529
# INFO:trainer:    val_f1_score   : 0.7885089464897576
# INFO:trainer:    val_sensitivity: 0.6877394636015326
# INFO:trainer:    val_specificity: 0.8647619047619047
# INFO:trainer:    val_MAcc       : 0.7762506841817187
# INFO:trainer:    val_F1_score   : 0.7542016806722689
# INFO:trainer:Saving new best model at epoch 1: model_best.pth
# DEBUG:trainer:Train Epoch: 2 [0/134 (0%)] Loss: 0.157751
# DEBUG:trainer:Train Epoch: 2 [5/134 (4%)] Loss: 0.149392
# DEBUG:trainer:Train Epoch: 2 [10/134 (7%)] Loss: 0.113046
# DEBUG:trainer:Train Epoch: 2 [15/134 (11%)] Loss: 0.122238
# DEBUG:trainer:Train Epoch: 2 [20/134 (15%)] Loss: 0.160773
# DEBUG:trainer:Train Epoch: 2 [25/134 (19%)] Loss: 0.168844
# DEBUG:trainer:Train Epoch: 2 [30/134 (22%)] Loss: 0.131104
# DEBUG:trainer:Train Epoch: 2 [35/134 (26%)] Loss: 0.130824
# DEBUG:trainer:Train Epoch: 2 [40/134 (30%)] Loss: 0.140636
# DEBUG:trainer:Train Epoch: 2 [45/134 (34%)] Loss: 0.160410
# DEBUG:trainer:Train Epoch: 2 [50/134 (37%)] Loss: 0.123281
# DEBUG:trainer:Train Epoch: 2 [55/134 (41%)] Loss: 0.164101
# DEBUG:trainer:Train Epoch: 2 [60/134 (45%)] Loss: 0.151072
# DEBUG:trainer:Train Epoch: 2 [65/134 (49%)] Loss: 0.130061
# DEBUG:trainer:Train Epoch: 2 [70/134 (52%)] Loss: 0.112323
# DEBUG:trainer:Train Epoch: 2 [75/134 (56%)] Loss: 0.162652
# DEBUG:trainer:Train Epoch: 2 [80/134 (60%)] Loss: 0.124949
# DEBUG:trainer:Train Epoch: 2 [85/134 (63%)] Loss: 0.128312
# DEBUG:trainer:Train Epoch: 2 [90/134 (67%)] Loss: 0.135951
# DEBUG:trainer:Train Epoch: 2 [95/134 (71%)] Loss: 0.136768
# DEBUG:trainer:Train Epoch: 2 [100/134 (75%)] Loss: 0.166534
# DEBUG:trainer:Train Epoch: 2 [105/134 (78%)] Loss: 0.141523
# DEBUG:trainer:Train Epoch: 2 [110/134 (82%)] Loss: 0.100385
# DEBUG:trainer:Train Epoch: 2 [115/134 (86%)] Loss: 0.121383
# DEBUG:trainer:Train Epoch: 2 [120/134 (90%)] Loss: 0.114565
# DEBUG:trainer:Train Epoch: 2 [125/134 (93%)] Loss: 0.116120
# DEBUG:trainer:Train Epoch: 2 [130/134 (97%)] Loss: 0.093338
# INFO:trainer:    epoch          : 2
# INFO:trainer:    loss           : 0.13798973131090847
# INFO:trainer:    accuracy       : 0.6889992004264393
# INFO:trainer:    f1_score       : 0.6984850309902425
# INFO:trainer:    val_loss       : 0.11892269777529167
# INFO:trainer:    val_accuracy   : 0.7760210803689065
# INFO:trainer:    val_f1_score   : 0.7888141245959857
# INFO:trainer:    val_sensitivity: 0.6839080459770115
# INFO:trainer:    val_specificity: 0.8704761904761905
# INFO:trainer:    val_MAcc       : 0.7771921182266011
# INFO:trainer:    val_F1_score   : 0.7539598732840549
# DEBUG:trainer:Train Epoch: 3 [0/134 (0%)] Loss: 0.149852
# DEBUG:trainer:Train Epoch: 3 [5/134 (4%)] Loss: 0.103829
# DEBUG:trainer:Train Epoch: 3 [10/134 (7%)] Loss: 0.116146
# DEBUG:trainer:Train Epoch: 3 [15/134 (11%)] Loss: 0.109483
# DEBUG:trainer:Train Epoch: 3 [20/134 (15%)] Loss: 0.112747
# DEBUG:trainer:Train Epoch: 3 [25/134 (19%)] Loss: 0.156991
# DEBUG:trainer:Train Epoch: 3 [30/134 (22%)] Loss: 0.239290
# DEBUG:trainer:Train Epoch: 3 [35/134 (26%)] Loss: 0.113868
# DEBUG:trainer:Train Epoch: 3 [40/134 (30%)] Loss: 0.188477
# DEBUG:trainer:Train Epoch: 3 [45/134 (34%)] Loss: 0.138593
# DEBUG:trainer:Train Epoch: 3 [50/134 (37%)] Loss: 0.109999
# DEBUG:trainer:Train Epoch: 3 [55/134 (41%)] Loss: 0.123169
# DEBUG:trainer:Train Epoch: 3 [60/134 (45%)] Loss: 0.117372
# DEBUG:trainer:Train Epoch: 3 [65/134 (49%)] Loss: 0.129034
# DEBUG:trainer:Train Epoch: 3 [70/134 (52%)] Loss: 0.157018
# DEBUG:trainer:Train Epoch: 3 [75/134 (56%)] Loss: 0.134585
# DEBUG:trainer:Train Epoch: 3 [80/134 (60%)] Loss: 0.151297
# DEBUG:trainer:Train Epoch: 3 [85/134 (63%)] Loss: 0.138921
# DEBUG:trainer:Train Epoch: 3 [90/134 (67%)] Loss: 0.160453
# DEBUG:trainer:Train Epoch: 3 [95/134 (71%)] Loss: 0.153404
# DEBUG:trainer:Train Epoch: 3 [100/134 (75%)] Loss: 0.134294
# DEBUG:trainer:Train Epoch: 3 [105/134 (78%)] Loss: 0.131342
# DEBUG:trainer:Train Epoch: 3 [110/134 (82%)] Loss: 0.115162
# DEBUG:trainer:Train Epoch: 3 [115/134 (86%)] Loss: 0.107194
# DEBUG:trainer:Train Epoch: 3 [120/134 (90%)] Loss: 0.129433
# DEBUG:trainer:Train Epoch: 3 [125/134 (93%)] Loss: 0.130769
# DEBUG:trainer:Train Epoch: 3 [130/134 (97%)] Loss: 0.080684
# INFO:trainer:    epoch          : 3
# INFO:trainer:    loss           : 0.1271735207358403
# INFO:trainer:    accuracy       : 0.7096548507462687
# INFO:trainer:    f1_score       : 0.7255697878300454
# INFO:trainer:    val_loss       : 0.11426287415352734
# INFO:trainer:    val_accuracy   : 0.7978013833992095
# INFO:trainer:    val_f1_score   : 0.8100464364365931
# INFO:trainer:    val_sensitivity: 0.7011494252873564
# INFO:trainer:    val_specificity: 0.8971428571428571
# INFO:trainer:    val_MAcc       : 0.7991461412151067
# INFO:trainer:    val_F1_score   : 0.7770700636942675
# INFO:trainer:Saving new best model at epoch 3: model_best.pth
# DEBUG:trainer:Train Epoch: 4 [0/134 (0%)] Loss: 0.095840
# DEBUG:trainer:Train Epoch: 4 [5/134 (4%)] Loss: 0.138059
# DEBUG:trainer:Train Epoch: 4 [10/134 (7%)] Loss: 0.111605
# DEBUG:trainer:Train Epoch: 4 [15/134 (11%)] Loss: 0.127481
# DEBUG:trainer:Train Epoch: 4 [20/134 (15%)] Loss: 0.106640
# DEBUG:trainer:Train Epoch: 4 [25/134 (19%)] Loss: 0.095992
# DEBUG:trainer:Train Epoch: 4 [30/134 (22%)] Loss: 0.120225
# DEBUG:trainer:Train Epoch: 4 [35/134 (26%)] Loss: 0.084035
# DEBUG:trainer:Train Epoch: 4 [40/134 (30%)] Loss: 0.100353
# DEBUG:trainer:Train Epoch: 4 [45/134 (34%)] Loss: 0.142871
# DEBUG:trainer:Train Epoch: 4 [50/134 (37%)] Loss: 0.103361
# DEBUG:trainer:Train Epoch: 4 [55/134 (41%)] Loss: 0.109620
# DEBUG:trainer:Train Epoch: 4 [60/134 (45%)] Loss: 0.134811
# DEBUG:trainer:Train Epoch: 4 [65/134 (49%)] Loss: 0.086851
# DEBUG:trainer:Train Epoch: 4 [70/134 (52%)] Loss: 0.094974
# DEBUG:trainer:Train Epoch: 4 [75/134 (56%)] Loss: 0.118264
# DEBUG:trainer:Train Epoch: 4 [80/134 (60%)] Loss: 0.132712
# DEBUG:trainer:Train Epoch: 4 [85/134 (63%)] Loss: 0.101285
# DEBUG:trainer:Train Epoch: 4 [90/134 (67%)] Loss: 0.093285
# DEBUG:trainer:Train Epoch: 4 [95/134 (71%)] Loss: 0.117042
# DEBUG:trainer:Train Epoch: 4 [100/134 (75%)] Loss: 0.123362
# DEBUG:trainer:Train Epoch: 4 [105/134 (78%)] Loss: 0.118922
# DEBUG:trainer:Train Epoch: 4 [110/134 (82%)] Loss: 0.108163
# DEBUG:trainer:Train Epoch: 4 [115/134 (86%)] Loss: 0.180746
# DEBUG:trainer:Train Epoch: 4 [120/134 (90%)] Loss: 0.180188
# DEBUG:trainer:Train Epoch: 4 [125/134 (93%)] Loss: 0.130254
# DEBUG:trainer:Train Epoch: 4 [130/134 (97%)] Loss: 0.117436
# INFO:trainer:    epoch          : 4
# INFO:trainer:    loss           : 0.12287162833694201
# INFO:trainer:    accuracy       : 0.7232142857142858
# INFO:trainer:    f1_score       : 0.7408312479773858
# INFO:trainer:    val_loss       : 0.11367496170780876
# INFO:trainer:    val_accuracy   : 0.7926959815546772
# INFO:trainer:    val_f1_score   : 0.8092967349906666
# INFO:trainer:    val_sensitivity: 0.6704980842911877
# INFO:trainer:    val_specificity: 0.9180952380952381
# INFO:trainer:    val_MAcc       : 0.794296661193213
# INFO:trainer:    val_F1_score   : 0.7650273224043715
# DEBUG:trainer:Train Epoch: 5 [0/134 (0%)] Loss: 0.098985
# DEBUG:trainer:Train Epoch: 5 [5/134 (4%)] Loss: 0.119140
# DEBUG:trainer:Train Epoch: 5 [10/134 (7%)] Loss: 0.114943
# DEBUG:trainer:Train Epoch: 5 [15/134 (11%)] Loss: 0.090959
# DEBUG:trainer:Train Epoch: 5 [20/134 (15%)] Loss: 0.092469
# DEBUG:trainer:Train Epoch: 5 [25/134 (19%)] Loss: 0.107478
# DEBUG:trainer:Train Epoch: 5 [30/134 (22%)] Loss: 0.083751
# DEBUG:trainer:Train Epoch: 5 [35/134 (26%)] Loss: 0.138114
# DEBUG:trainer:Train Epoch: 5 [40/134 (30%)] Loss: 0.153931
# DEBUG:trainer:Train Epoch: 5 [45/134 (34%)] Loss: 0.135599
# DEBUG:trainer:Train Epoch: 5 [50/134 (37%)] Loss: 0.145988
# DEBUG:trainer:Train Epoch: 5 [55/134 (41%)] Loss: 0.098499
# DEBUG:trainer:Train Epoch: 5 [60/134 (45%)] Loss: 0.160620
# DEBUG:trainer:Train Epoch: 5 [65/134 (49%)] Loss: 0.148983
# DEBUG:trainer:Train Epoch: 5 [70/134 (52%)] Loss: 0.121987
# DEBUG:trainer:Train Epoch: 5 [75/134 (56%)] Loss: 0.067798
# DEBUG:trainer:Train Epoch: 5 [80/134 (60%)] Loss: 0.102476
# DEBUG:trainer:Train Epoch: 5 [85/134 (63%)] Loss: 0.131638
# DEBUG:trainer:Train Epoch: 5 [90/134 (67%)] Loss: 0.178459
# DEBUG:trainer:Train Epoch: 5 [95/134 (71%)] Loss: 0.118500
# DEBUG:trainer:Train Epoch: 5 [100/134 (75%)] Loss: 0.119918
# DEBUG:trainer:Train Epoch: 5 [105/134 (78%)] Loss: 0.205493
# DEBUG:trainer:Train Epoch: 5 [110/134 (82%)] Loss: 0.128988
# DEBUG:trainer:Train Epoch: 5 [115/134 (86%)] Loss: 0.150769
# DEBUG:trainer:Train Epoch: 5 [120/134 (90%)] Loss: 0.136231
# DEBUG:trainer:Train Epoch: 5 [125/134 (93%)] Loss: 0.123780
# DEBUG:trainer:Train Epoch: 5 [130/134 (97%)] Loss: 0.116358
# INFO:trainer:    epoch          : 5
# INFO:trainer:    loss           : 0.1185268159788936
# INFO:trainer:    accuracy       : 0.7314432302771855
# INFO:trainer:    f1_score       : 0.7478394890548171
# INFO:trainer:    val_loss       : 0.1088816040393078
# INFO:trainer:    val_accuracy   : 0.8133234519104083
# INFO:trainer:    val_f1_score   : 0.8229045082118049
# INFO:trainer:    val_sensitivity: 0.7337164750957854
# INFO:trainer:    val_specificity: 0.8952380952380953
# INFO:trainer:    val_MAcc       : 0.8144772851669404
# INFO:trainer:    val_F1_score   : 0.7979166666666665
# INFO:trainer:Saving new best model at epoch 5: model_best.pth
# DEBUG:trainer:Train Epoch: 6 [0/134 (0%)] Loss: 0.181223
# DEBUG:trainer:Train Epoch: 6 [5/134 (4%)] Loss: 0.102729
# DEBUG:trainer:Train Epoch: 6 [10/134 (7%)] Loss: 0.103062
# DEBUG:trainer:Train Epoch: 6 [15/134 (11%)] Loss: 0.119092
# DEBUG:trainer:Train Epoch: 6 [20/134 (15%)] Loss: 0.125406
# DEBUG:trainer:Train Epoch: 6 [25/134 (19%)] Loss: 0.086884
# DEBUG:trainer:Train Epoch: 6 [30/134 (22%)] Loss: 0.093852
# DEBUG:trainer:Train Epoch: 6 [35/134 (26%)] Loss: 0.072150
# DEBUG:trainer:Train Epoch: 6 [40/134 (30%)] Loss: 0.095353
# DEBUG:trainer:Train Epoch: 6 [45/134 (34%)] Loss: 0.099363
# DEBUG:trainer:Train Epoch: 6 [50/134 (37%)] Loss: 0.147346
# DEBUG:trainer:Train Epoch: 6 [55/134 (41%)] Loss: 0.111016
# DEBUG:trainer:Train Epoch: 6 [60/134 (45%)] Loss: 0.103349
# DEBUG:trainer:Train Epoch: 6 [65/134 (49%)] Loss: 0.110616
# DEBUG:trainer:Train Epoch: 6 [70/134 (52%)] Loss: 0.101788
# DEBUG:trainer:Train Epoch: 6 [75/134 (56%)] Loss: 0.087229
# DEBUG:trainer:Train Epoch: 6 [80/134 (60%)] Loss: 0.094601
# DEBUG:trainer:Train Epoch: 6 [85/134 (63%)] Loss: 0.099476
# DEBUG:trainer:Train Epoch: 6 [90/134 (67%)] Loss: 0.094815
# DEBUG:trainer:Train Epoch: 6 [95/134 (71%)] Loss: 0.100753
# DEBUG:trainer:Train Epoch: 6 [100/134 (75%)] Loss: 0.094091
# DEBUG:trainer:Train Epoch: 6 [105/134 (78%)] Loss: 0.173204
# DEBUG:trainer:Train Epoch: 6 [110/134 (82%)] Loss: 0.071875
# DEBUG:trainer:Train Epoch: 6 [115/134 (86%)] Loss: 0.162790
# DEBUG:trainer:Train Epoch: 6 [120/134 (90%)] Loss: 0.080204
# DEBUG:trainer:Train Epoch: 6 [125/134 (93%)] Loss: 0.093939
# DEBUG:trainer:Train Epoch: 6 [130/134 (97%)] Loss: 0.095544
# INFO:trainer:    epoch          : 6
# INFO:trainer:    loss           : 0.11449998083399303
# INFO:trainer:    accuracy       : 0.7456023454157783
# INFO:trainer:    f1_score       : 0.7637388793014162
# INFO:trainer:    val_loss       : 0.10767006332224066
# INFO:trainer:    val_accuracy   : 0.7934370882740448
# INFO:trainer:    val_f1_score   : 0.800874672872878
# INFO:trainer:    val_sensitivity: 0.7241379310344828
# INFO:trainer:    val_specificity: 0.8647619047619047
# INFO:trainer:    val_MAcc       : 0.7944499178981937
# INFO:trainer:    val_F1_score   : 0.7785787847579816
# DEBUG:trainer:Train Epoch: 7 [0/134 (0%)] Loss: 0.086422
# DEBUG:trainer:Train Epoch: 7 [5/134 (4%)] Loss: 0.080114
# DEBUG:trainer:Train Epoch: 7 [10/134 (7%)] Loss: 0.161649
# DEBUG:trainer:Train Epoch: 7 [15/134 (11%)] Loss: 0.105356
# DEBUG:trainer:Train Epoch: 7 [20/134 (15%)] Loss: 0.128771
# DEBUG:trainer:Train Epoch: 7 [25/134 (19%)] Loss: 0.110944
# DEBUG:trainer:Train Epoch: 7 [30/134 (22%)] Loss: 0.072366
# DEBUG:trainer:Train Epoch: 7 [35/134 (26%)] Loss: 0.134993
# DEBUG:trainer:Train Epoch: 7 [40/134 (30%)] Loss: 0.057119
# DEBUG:trainer:Train Epoch: 7 [45/134 (34%)] Loss: 0.227976
# DEBUG:trainer:Train Epoch: 7 [50/134 (37%)] Loss: 0.178381
# DEBUG:trainer:Train Epoch: 7 [55/134 (41%)] Loss: 0.094509
# DEBUG:trainer:Train Epoch: 7 [60/134 (45%)] Loss: 0.157755
# DEBUG:trainer:Train Epoch: 7 [65/134 (49%)] Loss: 0.078426
# DEBUG:trainer:Train Epoch: 7 [70/134 (52%)] Loss: 0.127594
# DEBUG:trainer:Train Epoch: 7 [75/134 (56%)] Loss: 0.078480
# DEBUG:trainer:Train Epoch: 7 [80/134 (60%)] Loss: 0.118209
# DEBUG:trainer:Train Epoch: 7 [85/134 (63%)] Loss: 0.152655
# DEBUG:trainer:Train Epoch: 7 [90/134 (67%)] Loss: 0.130500
# DEBUG:trainer:Train Epoch: 7 [95/134 (71%)] Loss: 0.116215
# DEBUG:trainer:Train Epoch: 7 [100/134 (75%)] Loss: 0.090396
# DEBUG:trainer:Train Epoch: 7 [105/134 (78%)] Loss: 0.080294
# DEBUG:trainer:Train Epoch: 7 [110/134 (82%)] Loss: 0.149899
# DEBUG:trainer:Train Epoch: 7 [115/134 (86%)] Loss: 0.063666
# DEBUG:trainer:Train Epoch: 7 [120/134 (90%)] Loss: 0.082454
# DEBUG:trainer:Train Epoch: 7 [125/134 (93%)] Loss: 0.121040
# DEBUG:trainer:Train Epoch: 7 [130/134 (97%)] Loss: 0.102122
# INFO:trainer:    epoch          : 7
# INFO:trainer:    loss           : 0.11620738852157522
# INFO:trainer:    accuracy       : 0.7348081023454157
# INFO:trainer:    f1_score       : 0.7520915486898767
# INFO:trainer:    val_loss       : 0.10734293045419635
# INFO:trainer:    val_accuracy   : 0.8010128458498024
# INFO:trainer:    val_f1_score   : 0.8051014724873807
# INFO:trainer:    val_sensitivity: 0.7490421455938697
# INFO:trainer:    val_specificity: 0.8552380952380952
# INFO:trainer:    val_MAcc       : 0.8021401204159825
# INFO:trainer:    val_F1_score   : 0.7906976744186046
# INFO:trainer:Saving new best model at epoch 7: model_best.pth
# DEBUG:trainer:Train Epoch: 8 [0/134 (0%)] Loss: 0.100087
# DEBUG:trainer:Train Epoch: 8 [5/134 (4%)] Loss: 0.135607
# DEBUG:trainer:Train Epoch: 8 [10/134 (7%)] Loss: 0.127661
# DEBUG:trainer:Train Epoch: 8 [15/134 (11%)] Loss: 0.084182
# DEBUG:trainer:Train Epoch: 8 [20/134 (15%)] Loss: 0.120439
# DEBUG:trainer:Train Epoch: 8 [25/134 (19%)] Loss: 0.093684
# DEBUG:trainer:Train Epoch: 8 [30/134 (22%)] Loss: 0.158328
# DEBUG:trainer:Train Epoch: 8 [35/134 (26%)] Loss: 0.100764
# DEBUG:trainer:Train Epoch: 8 [40/134 (30%)] Loss: 0.087391
# DEBUG:trainer:Train Epoch: 8 [45/134 (34%)] Loss: 0.102536
# DEBUG:trainer:Train Epoch: 8 [50/134 (37%)] Loss: 0.120206
# DEBUG:trainer:Train Epoch: 8 [55/134 (41%)] Loss: 0.097552
# DEBUG:trainer:Train Epoch: 8 [60/134 (45%)] Loss: 0.081206
# DEBUG:trainer:Train Epoch: 8 [65/134 (49%)] Loss: 0.088116
# DEBUG:trainer:Train Epoch: 8 [70/134 (52%)] Loss: 0.081016
# DEBUG:trainer:Train Epoch: 8 [75/134 (56%)] Loss: 0.124088
# DEBUG:trainer:Train Epoch: 8 [80/134 (60%)] Loss: 0.148589
# DEBUG:trainer:Train Epoch: 8 [85/134 (63%)] Loss: 0.124271
# DEBUG:trainer:Train Epoch: 8 [90/134 (67%)] Loss: 0.144937
# DEBUG:trainer:Train Epoch: 8 [95/134 (71%)] Loss: 0.110674
# DEBUG:trainer:Train Epoch: 8 [100/134 (75%)] Loss: 0.089422
# DEBUG:trainer:Train Epoch: 8 [105/134 (78%)] Loss: 0.087936
# DEBUG:trainer:Train Epoch: 8 [110/134 (82%)] Loss: 0.104198
# DEBUG:trainer:Train Epoch: 8 [115/134 (86%)] Loss: 0.140080
# DEBUG:trainer:Train Epoch: 8 [120/134 (90%)] Loss: 0.172094
# DEBUG:trainer:Train Epoch: 8 [125/134 (93%)] Loss: 0.073461
# DEBUG:trainer:Train Epoch: 8 [130/134 (97%)] Loss: 0.092902
# INFO:trainer:    epoch          : 8
# INFO:trainer:    loss           : 0.11626163436405694
# INFO:trainer:    accuracy       : 0.7218816631130064
# INFO:trainer:    f1_score       : 0.7401414252951326
# INFO:trainer:    val_loss       : 0.10543981713779045
# INFO:trainer:    val_accuracy   : 0.8127470355731226
# INFO:trainer:    val_f1_score   : 0.8217320097363682
# INFO:trainer:    val_sensitivity: 0.7375478927203065
# INFO:trainer:    val_specificity: 0.8895238095238095
# INFO:trainer:    val_MAcc       : 0.8135358511220581
# INFO:trainer:    val_F1_score   : 0.7979274611398963
# DEBUG:trainer:Train Epoch: 9 [0/134 (0%)] Loss: 0.091507
# DEBUG:trainer:Train Epoch: 9 [5/134 (4%)] Loss: 0.145042
# DEBUG:trainer:Train Epoch: 9 [10/134 (7%)] Loss: 0.123551
# DEBUG:trainer:Train Epoch: 9 [15/134 (11%)] Loss: 0.101941
# DEBUG:trainer:Train Epoch: 9 [20/134 (15%)] Loss: 0.117334
# DEBUG:trainer:Train Epoch: 9 [25/134 (19%)] Loss: 0.099792
# DEBUG:trainer:Train Epoch: 9 [30/134 (22%)] Loss: 0.103312
# DEBUG:trainer:Train Epoch: 9 [35/134 (26%)] Loss: 0.141843
# DEBUG:trainer:Train Epoch: 9 [40/134 (30%)] Loss: 0.088153
# DEBUG:trainer:Train Epoch: 9 [45/134 (34%)] Loss: 0.098637
# DEBUG:trainer:Train Epoch: 9 [50/134 (37%)] Loss: 0.107586
# DEBUG:trainer:Train Epoch: 9 [55/134 (41%)] Loss: 0.088210
# DEBUG:trainer:Train Epoch: 9 [60/134 (45%)] Loss: 0.160113
# DEBUG:trainer:Train Epoch: 9 [65/134 (49%)] Loss: 0.114475
# DEBUG:trainer:Train Epoch: 9 [70/134 (52%)] Loss: 0.099168
# DEBUG:trainer:Train Epoch: 9 [75/134 (56%)] Loss: 0.106546
# DEBUG:trainer:Train Epoch: 9 [80/134 (60%)] Loss: 0.170831
# DEBUG:trainer:Train Epoch: 9 [85/134 (63%)] Loss: 0.120446
# DEBUG:trainer:Train Epoch: 9 [90/134 (67%)] Loss: 0.131288
# DEBUG:trainer:Train Epoch: 9 [95/134 (71%)] Loss: 0.089937
# DEBUG:trainer:Train Epoch: 9 [100/134 (75%)] Loss: 0.096848
# DEBUG:trainer:Train Epoch: 9 [105/134 (78%)] Loss: 0.109238
# DEBUG:trainer:Train Epoch: 9 [110/134 (82%)] Loss: 0.113902
# DEBUG:trainer:Train Epoch: 9 [115/134 (86%)] Loss: 0.104767
# DEBUG:trainer:Train Epoch: 9 [120/134 (90%)] Loss: 0.116007
# DEBUG:trainer:Train Epoch: 9 [125/134 (93%)] Loss: 0.080914
# DEBUG:trainer:Train Epoch: 9 [130/134 (97%)] Loss: 0.131043
# INFO:trainer:    epoch          : 9
# INFO:trainer:    loss           : 0.11625823261800097
# INFO:trainer:    accuracy       : 0.7619936034115139
# INFO:trainer:    f1_score       : 0.778011338207031
# INFO:trainer:    val_loss       : 0.10567662661725824
# INFO:trainer:    val_accuracy   : 0.8038537549407114
# INFO:trainer:    val_f1_score   : 0.8115722372341438
# INFO:trainer:    val_sensitivity: 0.7318007662835249
# INFO:trainer:    val_specificity: 0.878095238095238
# INFO:trainer:    val_MAcc       : 0.8049480021893815
# INFO:trainer:    val_F1_score   : 0.7892561983471075
# DEBUG:trainer:Train Epoch: 10 [0/134 (0%)] Loss: 0.100426
# DEBUG:trainer:Train Epoch: 10 [5/134 (4%)] Loss: 0.183367
# DEBUG:trainer:Train Epoch: 10 [10/134 (7%)] Loss: 0.081728
# DEBUG:trainer:Train Epoch: 10 [15/134 (11%)] Loss: 0.137035
# DEBUG:trainer:Train Epoch: 10 [20/134 (15%)] Loss: 0.115063
# DEBUG:trainer:Train Epoch: 10 [25/134 (19%)] Loss: 0.107173
# DEBUG:trainer:Train Epoch: 10 [30/134 (22%)] Loss: 0.104221
# DEBUG:trainer:Train Epoch: 10 [35/134 (26%)] Loss: 0.133108
# DEBUG:trainer:Train Epoch: 10 [40/134 (30%)] Loss: 0.113894
# DEBUG:trainer:Train Epoch: 10 [45/134 (34%)] Loss: 0.105309
# DEBUG:trainer:Train Epoch: 10 [50/134 (37%)] Loss: 0.131713
# DEBUG:trainer:Train Epoch: 10 [55/134 (41%)] Loss: 0.141361
# DEBUG:trainer:Train Epoch: 10 [60/134 (45%)] Loss: 0.087215
# DEBUG:trainer:Train Epoch: 10 [65/134 (49%)] Loss: 0.096781
# DEBUG:trainer:Train Epoch: 10 [70/134 (52%)] Loss: 0.114680
# DEBUG:trainer:Train Epoch: 10 [75/134 (56%)] Loss: 0.093505
# DEBUG:trainer:Train Epoch: 10 [80/134 (60%)] Loss: 0.155116
# DEBUG:trainer:Train Epoch: 10 [85/134 (63%)] Loss: 0.154244
# DEBUG:trainer:Train Epoch: 10 [90/134 (67%)] Loss: 0.109598
# DEBUG:trainer:Train Epoch: 10 [95/134 (71%)] Loss: 0.117769
# DEBUG:trainer:Train Epoch: 10 [100/134 (75%)] Loss: 0.084189
# DEBUG:trainer:Train Epoch: 10 [105/134 (78%)] Loss: 0.081161
# DEBUG:trainer:Train Epoch: 10 [110/134 (82%)] Loss: 0.116576
# DEBUG:trainer:Train Epoch: 10 [115/134 (86%)] Loss: 0.167430
# DEBUG:trainer:Train Epoch: 10 [120/134 (90%)] Loss: 0.116786
# DEBUG:trainer:Train Epoch: 10 [125/134 (93%)] Loss: 0.088132
# DEBUG:trainer:Train Epoch: 10 [130/134 (97%)] Loss: 0.096843
# INFO:trainer:    epoch          : 10
# INFO:trainer:    loss           : 0.11412603591582668
# INFO:trainer:    accuracy       : 0.7355743603411514
# INFO:trainer:    f1_score       : 0.7552682458057254
# INFO:trainer:    val_loss       : 0.10547976331277327
# INFO:trainer:    val_accuracy   : 0.8095355731225296
# INFO:trainer:    val_f1_score   : 0.8161788900157106
# INFO:trainer:    val_sensitivity: 0.7432950191570882
# INFO:trainer:    val_specificity: 0.878095238095238
# INFO:trainer:    val_MAcc       : 0.8106951286261631
# INFO:trainer:    val_F1_score   : 0.7967145790554415
# DEBUG:trainer:Train Epoch: 11 [0/134 (0%)] Loss: 0.091481
# DEBUG:trainer:Train Epoch: 11 [5/134 (4%)] Loss: 0.120687
# DEBUG:trainer:Train Epoch: 11 [10/134 (7%)] Loss: 0.112658
# DEBUG:trainer:Train Epoch: 11 [15/134 (11%)] Loss: 0.149697
# DEBUG:trainer:Train Epoch: 11 [20/134 (15%)] Loss: 0.182784
# DEBUG:trainer:Train Epoch: 11 [25/134 (19%)] Loss: 0.090543
# DEBUG:trainer:Train Epoch: 11 [30/134 (22%)] Loss: 0.145636
# DEBUG:trainer:Train Epoch: 11 [35/134 (26%)] Loss: 0.102948
# DEBUG:trainer:Train Epoch: 11 [40/134 (30%)] Loss: 0.145099
# DEBUG:trainer:Train Epoch: 11 [45/134 (34%)] Loss: 0.137567
# DEBUG:trainer:Train Epoch: 11 [50/134 (37%)] Loss: 0.130309
# DEBUG:trainer:Train Epoch: 11 [55/134 (41%)] Loss: 0.095950
# DEBUG:trainer:Train Epoch: 11 [60/134 (45%)] Loss: 0.104120
# DEBUG:trainer:Train Epoch: 11 [65/134 (49%)] Loss: 0.091481
# DEBUG:trainer:Train Epoch: 11 [70/134 (52%)] Loss: 0.080790
# DEBUG:trainer:Train Epoch: 11 [75/134 (56%)] Loss: 0.170716
# DEBUG:trainer:Train Epoch: 11 [80/134 (60%)] Loss: 0.123317
# DEBUG:trainer:Train Epoch: 11 [85/134 (63%)] Loss: 0.134197
# DEBUG:trainer:Train Epoch: 11 [90/134 (67%)] Loss: 0.103173
# DEBUG:trainer:Train Epoch: 11 [95/134 (71%)] Loss: 0.071406
# DEBUG:trainer:Train Epoch: 11 [100/134 (75%)] Loss: 0.077083
# DEBUG:trainer:Train Epoch: 11 [105/134 (78%)] Loss: 0.088769
# DEBUG:trainer:Train Epoch: 11 [110/134 (82%)] Loss: 0.076014
# DEBUG:trainer:Train Epoch: 11 [115/134 (86%)] Loss: 0.115952
# DEBUG:trainer:Train Epoch: 11 [120/134 (90%)] Loss: 0.109950
# DEBUG:trainer:Train Epoch: 11 [125/134 (93%)] Loss: 0.108306
# DEBUG:trainer:Train Epoch: 11 [130/134 (97%)] Loss: 0.074694
# INFO:trainer:    epoch          : 11
# INFO:trainer:    loss           : 0.11956102506660704
# INFO:trainer:    accuracy       : 0.732442697228145
# INFO:trainer:    f1_score       : 0.7491942333399718
# INFO:trainer:    val_loss       : 0.10510351192770583
# INFO:trainer:    val_accuracy   : 0.8108530961791831
# INFO:trainer:    val_f1_score   : 0.8160304322417274
# INFO:trainer:    val_sensitivity: 0.7567049808429118
# INFO:trainer:    val_specificity: 0.8666666666666667
# INFO:trainer:    val_MAcc       : 0.8116858237547893
# INFO:trainer:    val_F1_score   : 0.8004052684903749
# INFO:trainer:Saving new best model at epoch 11: model_best.pth
# DEBUG:trainer:Train Epoch: 12 [0/134 (0%)] Loss: 0.102073
# DEBUG:trainer:Train Epoch: 12 [5/134 (4%)] Loss: 0.118072
# DEBUG:trainer:Train Epoch: 12 [10/134 (7%)] Loss: 0.075337
# DEBUG:trainer:Train Epoch: 12 [15/134 (11%)] Loss: 0.131144
# DEBUG:trainer:Train Epoch: 12 [20/134 (15%)] Loss: 0.081892
# DEBUG:trainer:Train Epoch: 12 [25/134 (19%)] Loss: 0.070666
# DEBUG:trainer:Train Epoch: 12 [30/134 (22%)] Loss: 0.128657
# DEBUG:trainer:Train Epoch: 12 [35/134 (26%)] Loss: 0.088300
# DEBUG:trainer:Train Epoch: 12 [40/134 (30%)] Loss: 0.114301
# DEBUG:trainer:Train Epoch: 12 [45/134 (34%)] Loss: 0.134692
# DEBUG:trainer:Train Epoch: 12 [50/134 (37%)] Loss: 0.078012
# DEBUG:trainer:Train Epoch: 12 [55/134 (41%)] Loss: 0.082035
# DEBUG:trainer:Train Epoch: 12 [60/134 (45%)] Loss: 0.141344
# DEBUG:trainer:Train Epoch: 12 [65/134 (49%)] Loss: 0.079876
# DEBUG:trainer:Train Epoch: 12 [70/134 (52%)] Loss: 0.138067
# DEBUG:trainer:Train Epoch: 12 [75/134 (56%)] Loss: 0.128847
# DEBUG:trainer:Train Epoch: 12 [80/134 (60%)] Loss: 0.080010
# DEBUG:trainer:Train Epoch: 12 [85/134 (63%)] Loss: 0.128675
# DEBUG:trainer:Train Epoch: 12 [90/134 (67%)] Loss: 0.116129
# DEBUG:trainer:Train Epoch: 12 [95/134 (71%)] Loss: 0.105491
# DEBUG:trainer:Train Epoch: 12 [100/134 (75%)] Loss: 0.101722
# DEBUG:trainer:Train Epoch: 12 [105/134 (78%)] Loss: 0.122089
# DEBUG:trainer:Train Epoch: 12 [110/134 (82%)] Loss: 0.097192
# DEBUG:trainer:Train Epoch: 12 [115/134 (86%)] Loss: 0.117354
# DEBUG:trainer:Train Epoch: 12 [120/134 (90%)] Loss: 0.158093
# DEBUG:trainer:Train Epoch: 12 [125/134 (93%)] Loss: 0.126795
# DEBUG:trainer:Train Epoch: 12 [130/134 (97%)] Loss: 0.129852
# INFO:trainer:    epoch          : 12
# INFO:trainer:    loss           : 0.11101506339080298
# INFO:trainer:    accuracy       : 0.7447694562899786
# INFO:trainer:    f1_score       : 0.7605883581877922
# INFO:trainer:    val_loss       : 0.10381833960612614
# INFO:trainer:    val_accuracy   : 0.8045948616600791
# INFO:trainer:    val_f1_score   : 0.8054329126382558
# INFO:trainer:    val_sensitivity: 0.7720306513409961
# INFO:trainer:    val_specificity: 0.8380952380952381
# INFO:trainer:    val_MAcc       : 0.8050629447181171
# INFO:trainer:    val_F1_score   : 0.7980198019801981
# INFO:trainer:Saving new best model at epoch 12: model_best.pth
# DEBUG:trainer:Train Epoch: 13 [0/134 (0%)] Loss: 0.125756
# DEBUG:trainer:Train Epoch: 13 [5/134 (4%)] Loss: 0.095175
# DEBUG:trainer:Train Epoch: 13 [10/134 (7%)] Loss: 0.083234
# DEBUG:trainer:Train Epoch: 13 [15/134 (11%)] Loss: 0.122130
# DEBUG:trainer:Train Epoch: 13 [20/134 (15%)] Loss: 0.219747
# DEBUG:trainer:Train Epoch: 13 [25/134 (19%)] Loss: 0.098466
# DEBUG:trainer:Train Epoch: 13 [30/134 (22%)] Loss: 0.088526
# DEBUG:trainer:Train Epoch: 13 [35/134 (26%)] Loss: 0.081122
# DEBUG:trainer:Train Epoch: 13 [40/134 (30%)] Loss: 0.080718
# DEBUG:trainer:Train Epoch: 13 [45/134 (34%)] Loss: 0.069254
# DEBUG:trainer:Train Epoch: 13 [50/134 (37%)] Loss: 0.098659
# DEBUG:trainer:Train Epoch: 13 [55/134 (41%)] Loss: 0.104225
# DEBUG:trainer:Train Epoch: 13 [60/134 (45%)] Loss: 0.088279
# DEBUG:trainer:Train Epoch: 13 [65/134 (49%)] Loss: 0.104361
# DEBUG:trainer:Train Epoch: 13 [70/134 (52%)] Loss: 0.075686
# DEBUG:trainer:Train Epoch: 13 [75/134 (56%)] Loss: 0.098526
# DEBUG:trainer:Train Epoch: 13 [80/134 (60%)] Loss: 0.106356
# DEBUG:trainer:Train Epoch: 13 [85/134 (63%)] Loss: 0.097427
# DEBUG:trainer:Train Epoch: 13 [90/134 (67%)] Loss: 0.132656
# DEBUG:trainer:Train Epoch: 13 [95/134 (71%)] Loss: 0.098545
# DEBUG:trainer:Train Epoch: 13 [100/134 (75%)] Loss: 0.099412
# DEBUG:trainer:Train Epoch: 13 [105/134 (78%)] Loss: 0.068496
# DEBUG:trainer:Train Epoch: 13 [110/134 (82%)] Loss: 0.103375
# DEBUG:trainer:Train Epoch: 13 [115/134 (86%)] Loss: 0.057898
# DEBUG:trainer:Train Epoch: 13 [120/134 (90%)] Loss: 0.119121
# DEBUG:trainer:Train Epoch: 13 [125/134 (93%)] Loss: 0.178654
# DEBUG:trainer:Train Epoch: 13 [130/134 (97%)] Loss: 0.090499
# INFO:trainer:    epoch          : 13
# INFO:trainer:    loss           : 0.10998342736665882
# INFO:trainer:    accuracy       : 0.7533648720682303
# INFO:trainer:    f1_score       : 0.767403181440765
# INFO:trainer:    val_loss       : 0.10072246487393524
# INFO:trainer:    val_accuracy   : 0.8286396574440054
# INFO:trainer:    val_f1_score   : 0.8337225266609001
# INFO:trainer:    val_sensitivity: 0.7701149425287356
# INFO:trainer:    val_specificity: 0.8876190476190476
# INFO:trainer:    val_MAcc       : 0.8288669950738916
# INFO:trainer:    val_F1_score   : 0.8179043743641913
# DEBUG:trainer:Train Epoch: 14 [0/134 (0%)] Loss: 0.094132
# DEBUG:trainer:Train Epoch: 14 [5/134 (4%)] Loss: 0.122368
# DEBUG:trainer:Train Epoch: 14 [10/134 (7%)] Loss: 0.109900
# DEBUG:trainer:Train Epoch: 14 [15/134 (11%)] Loss: 0.129881
# DEBUG:trainer:Train Epoch: 14 [20/134 (15%)] Loss: 0.127224
# DEBUG:trainer:Train Epoch: 14 [25/134 (19%)] Loss: 0.120993
# DEBUG:trainer:Train Epoch: 14 [30/134 (22%)] Loss: 0.079428
# DEBUG:trainer:Train Epoch: 14 [35/134 (26%)] Loss: 0.164512
# DEBUG:trainer:Train Epoch: 14 [40/134 (30%)] Loss: 0.135760
# DEBUG:trainer:Train Epoch: 14 [45/134 (34%)] Loss: 0.076630
# DEBUG:trainer:Train Epoch: 14 [50/134 (37%)] Loss: 0.110027
# DEBUG:trainer:Train Epoch: 14 [55/134 (41%)] Loss: 0.136789
# DEBUG:trainer:Train Epoch: 14 [60/134 (45%)] Loss: 0.134465
# DEBUG:trainer:Train Epoch: 14 [65/134 (49%)] Loss: 0.109022
# DEBUG:trainer:Train Epoch: 14 [70/134 (52%)] Loss: 0.097288
# DEBUG:trainer:Train Epoch: 14 [75/134 (56%)] Loss: 0.085292
# DEBUG:trainer:Train Epoch: 14 [80/134 (60%)] Loss: 0.101134
# DEBUG:trainer:Train Epoch: 14 [85/134 (63%)] Loss: 0.109847
# DEBUG:trainer:Train Epoch: 14 [90/134 (67%)] Loss: 0.140518
# DEBUG:trainer:Train Epoch: 14 [95/134 (71%)] Loss: 0.074875
# DEBUG:trainer:Train Epoch: 14 [100/134 (75%)] Loss: 0.126189
# DEBUG:trainer:Train Epoch: 14 [105/134 (78%)] Loss: 0.089344
# DEBUG:trainer:Train Epoch: 14 [110/134 (82%)] Loss: 0.108674
# DEBUG:trainer:Train Epoch: 14 [115/134 (86%)] Loss: 0.072594
# DEBUG:trainer:Train Epoch: 14 [120/134 (90%)] Loss: 0.083919
# DEBUG:trainer:Train Epoch: 14 [125/134 (93%)] Loss: 0.175679
# DEBUG:trainer:Train Epoch: 14 [130/134 (97%)] Loss: 0.129004
# INFO:trainer:    epoch          : 14
# INFO:trainer:    loss           : 0.10712515843559557
# INFO:trainer:    accuracy       : 0.7432369402985075
# INFO:trainer:    f1_score       : 0.7588267137791145
# INFO:trainer:    val_loss       : 0.10365449129180475
# INFO:trainer:    val_accuracy   : 0.8030714756258235
# INFO:trainer:    val_f1_score   : 0.7990925423970316
# INFO:trainer:    val_sensitivity: 0.7988505747126436
# INFO:trainer:    val_specificity: 0.8076190476190476
# INFO:trainer:    val_MAcc       : 0.8032348111658456
# INFO:trainer:    val_F1_score   : 0.8019230769230768
# INFO:trainer:Saving new best model at epoch 14: model_best.pth
# DEBUG:trainer:Train Epoch: 15 [0/134 (0%)] Loss: 0.140383
# DEBUG:trainer:Train Epoch: 15 [5/134 (4%)] Loss: 0.118324
# DEBUG:trainer:Train Epoch: 15 [10/134 (7%)] Loss: 0.086718
# DEBUG:trainer:Train Epoch: 15 [15/134 (11%)] Loss: 0.093186
# DEBUG:trainer:Train Epoch: 15 [20/134 (15%)] Loss: 0.060785
# DEBUG:trainer:Train Epoch: 15 [25/134 (19%)] Loss: 0.085113
# DEBUG:trainer:Train Epoch: 15 [30/134 (22%)] Loss: 0.089237
# DEBUG:trainer:Train Epoch: 15 [35/134 (26%)] Loss: 0.081056
# DEBUG:trainer:Train Epoch: 15 [40/134 (30%)] Loss: 0.059702
# DEBUG:trainer:Train Epoch: 15 [45/134 (34%)] Loss: 0.086875
# DEBUG:trainer:Train Epoch: 15 [50/134 (37%)] Loss: 0.072273
# DEBUG:trainer:Train Epoch: 15 [55/134 (41%)] Loss: 0.063545
# DEBUG:trainer:Train Epoch: 15 [60/134 (45%)] Loss: 0.165931
# DEBUG:trainer:Train Epoch: 15 [65/134 (49%)] Loss: 0.166075
# DEBUG:trainer:Train Epoch: 15 [70/134 (52%)] Loss: 0.089301
# DEBUG:trainer:Train Epoch: 15 [75/134 (56%)] Loss: 0.105348
# DEBUG:trainer:Train Epoch: 15 [80/134 (60%)] Loss: 0.068979
# DEBUG:trainer:Train Epoch: 15 [85/134 (63%)] Loss: 0.101907
# DEBUG:trainer:Train Epoch: 15 [90/134 (67%)] Loss: 0.073676
# DEBUG:trainer:Train Epoch: 15 [95/134 (71%)] Loss: 0.114259
# DEBUG:trainer:Train Epoch: 15 [100/134 (75%)] Loss: 0.113701
# DEBUG:trainer:Train Epoch: 15 [105/134 (78%)] Loss: 0.115375
# DEBUG:trainer:Train Epoch: 15 [110/134 (82%)] Loss: 0.094569
# DEBUG:trainer:Train Epoch: 15 [115/134 (86%)] Loss: 0.178491
# DEBUG:trainer:Train Epoch: 15 [120/134 (90%)] Loss: 0.063042
# DEBUG:trainer:Train Epoch: 15 [125/134 (93%)] Loss: 0.069140
# DEBUG:trainer:Train Epoch: 15 [130/134 (97%)] Loss: 0.080363
# INFO:trainer:    epoch          : 15
# INFO:trainer:    loss           : 0.10535352721587936
# INFO:trainer:    accuracy       : 0.767657249466951
# INFO:trainer:    f1_score       : 0.7798763330858144
# INFO:trainer:    val_loss       : 0.09902178236480916
# INFO:trainer:    val_accuracy   : 0.8216403162055336
# INFO:trainer:    val_f1_score   : 0.8303306611428338
# INFO:trainer:    val_sensitivity: 0.7413793103448276
# INFO:trainer:    val_specificity: 0.9028571428571428
# INFO:trainer:    val_MAcc       : 0.8221182266009852
# INFO:trainer:    val_F1_score   : 0.80625
# DEBUG:trainer:Train Epoch: 16 [0/134 (0%)] Loss: 0.080278
# DEBUG:trainer:Train Epoch: 16 [5/134 (4%)] Loss: 0.146719
# DEBUG:trainer:Train Epoch: 16 [10/134 (7%)] Loss: 0.076145
# DEBUG:trainer:Train Epoch: 16 [15/134 (11%)] Loss: 0.128107
# DEBUG:trainer:Train Epoch: 16 [20/134 (15%)] Loss: 0.090921
# DEBUG:trainer:Train Epoch: 16 [25/134 (19%)] Loss: 0.093651
# DEBUG:trainer:Train Epoch: 16 [30/134 (22%)] Loss: 0.081101
# DEBUG:trainer:Train Epoch: 16 [35/134 (26%)] Loss: 0.078540
# DEBUG:trainer:Train Epoch: 16 [40/134 (30%)] Loss: 0.075298
# DEBUG:trainer:Train Epoch: 16 [45/134 (34%)] Loss: 0.093055
# DEBUG:trainer:Train Epoch: 16 [50/134 (37%)] Loss: 0.107750
# DEBUG:trainer:Train Epoch: 16 [55/134 (41%)] Loss: 0.175355
# DEBUG:trainer:Train Epoch: 16 [60/134 (45%)] Loss: 0.153365
# DEBUG:trainer:Train Epoch: 16 [65/134 (49%)] Loss: 0.155026
# DEBUG:trainer:Train Epoch: 16 [70/134 (52%)] Loss: 0.135587
# DEBUG:trainer:Train Epoch: 16 [75/134 (56%)] Loss: 0.082682
# DEBUG:trainer:Train Epoch: 16 [80/134 (60%)] Loss: 0.172157
# DEBUG:trainer:Train Epoch: 16 [85/134 (63%)] Loss: 0.111509
# DEBUG:trainer:Train Epoch: 16 [90/134 (67%)] Loss: 0.138479
# DEBUG:trainer:Train Epoch: 16 [95/134 (71%)] Loss: 0.104811
# DEBUG:trainer:Train Epoch: 16 [100/134 (75%)] Loss: 0.098468
# DEBUG:trainer:Train Epoch: 16 [105/134 (78%)] Loss: 0.111637
# DEBUG:trainer:Train Epoch: 16 [110/134 (82%)] Loss: 0.092633
# DEBUG:trainer:Train Epoch: 16 [115/134 (86%)] Loss: 0.172237
# DEBUG:trainer:Train Epoch: 16 [120/134 (90%)] Loss: 0.083343
# DEBUG:trainer:Train Epoch: 16 [125/134 (93%)] Loss: 0.133351
# DEBUG:trainer:Train Epoch: 16 [130/134 (97%)] Loss: 0.073391
# INFO:trainer:    epoch          : 16
# INFO:trainer:    loss           : 0.10539239294715781
# INFO:trainer:    accuracy       : 0.7645589019189766
# INFO:trainer:    f1_score       : 0.7778287870813654
# INFO:trainer:    val_loss       : 0.10024777709534674
# INFO:trainer:    val_accuracy   : 0.8229578392621871
# INFO:trainer:    val_f1_score   : 0.8330799675632897
# INFO:trainer:    val_sensitivity: 0.7337164750957854
# INFO:trainer:    val_specificity: 0.9123809523809524
# INFO:trainer:    val_MAcc       : 0.8230487137383689
# INFO:trainer:    val_F1_score   : 0.8054679284963195
# DEBUG:trainer:Train Epoch: 17 [0/134 (0%)] Loss: 0.091919
# DEBUG:trainer:Train Epoch: 17 [5/134 (4%)] Loss: 0.074769
# DEBUG:trainer:Train Epoch: 17 [10/134 (7%)] Loss: 0.123780
# DEBUG:trainer:Train Epoch: 17 [15/134 (11%)] Loss: 0.097431
# DEBUG:trainer:Train Epoch: 17 [20/134 (15%)] Loss: 0.101115
# DEBUG:trainer:Train Epoch: 17 [25/134 (19%)] Loss: 0.075981
# DEBUG:trainer:Train Epoch: 17 [30/134 (22%)] Loss: 0.131561
# DEBUG:trainer:Train Epoch: 17 [35/134 (26%)] Loss: 0.083764
# DEBUG:trainer:Train Epoch: 17 [40/134 (30%)] Loss: 0.126118
# DEBUG:trainer:Train Epoch: 17 [45/134 (34%)] Loss: 0.082110
# DEBUG:trainer:Train Epoch: 17 [50/134 (37%)] Loss: 0.085081
# DEBUG:trainer:Train Epoch: 17 [55/134 (41%)] Loss: 0.079253
# DEBUG:trainer:Train Epoch: 17 [60/134 (45%)] Loss: 0.094794
# DEBUG:trainer:Train Epoch: 17 [65/134 (49%)] Loss: 0.151310
# DEBUG:trainer:Train Epoch: 17 [70/134 (52%)] Loss: 0.099484
# DEBUG:trainer:Train Epoch: 17 [75/134 (56%)] Loss: 0.118012
# DEBUG:trainer:Train Epoch: 17 [80/134 (60%)] Loss: 0.172265
# DEBUG:trainer:Train Epoch: 17 [85/134 (63%)] Loss: 0.067173
# DEBUG:trainer:Train Epoch: 17 [90/134 (67%)] Loss: 0.073477
# DEBUG:trainer:Train Epoch: 17 [95/134 (71%)] Loss: 0.075878
# DEBUG:trainer:Train Epoch: 17 [100/134 (75%)] Loss: 0.097697
# DEBUG:trainer:Train Epoch: 17 [105/134 (78%)] Loss: 0.113577
# DEBUG:trainer:Train Epoch: 17 [110/134 (82%)] Loss: 0.134507
# DEBUG:trainer:Train Epoch: 17 [115/134 (86%)] Loss: 0.116613
# DEBUG:trainer:Train Epoch: 17 [120/134 (90%)] Loss: 0.196420
# DEBUG:trainer:Train Epoch: 17 [125/134 (93%)] Loss: 0.083316
# DEBUG:trainer:Train Epoch: 17 [130/134 (97%)] Loss: 0.068611
# INFO:trainer:    epoch          : 17
# INFO:trainer:    loss           : 0.1028380310579912
# INFO:trainer:    accuracy       : 0.7661913646055437
# INFO:trainer:    f1_score       : 0.7788477649703904
# INFO:trainer:    val_loss       : 0.09624456919052383
# INFO:trainer:    val_accuracy   : 0.8280632411067194
# INFO:trainer:    val_f1_score   : 0.830594423884368
# INFO:trainer:    val_sensitivity: 0.7796934865900383
# INFO:trainer:    val_specificity: 0.8761904761904762
# INFO:trainer:    val_MAcc       : 0.8279419813902573
# INFO:trainer:    val_F1_score   : 0.818913480885312
# DEBUG:trainer:Train Epoch: 18 [0/134 (0%)] Loss: 0.072571
# DEBUG:trainer:Train Epoch: 18 [5/134 (4%)] Loss: 0.108302
# DEBUG:trainer:Train Epoch: 18 [10/134 (7%)] Loss: 0.130580
# DEBUG:trainer:Train Epoch: 18 [15/134 (11%)] Loss: 0.084523
# DEBUG:trainer:Train Epoch: 18 [20/134 (15%)] Loss: 0.107620
# DEBUG:trainer:Train Epoch: 18 [25/134 (19%)] Loss: 0.138414
# DEBUG:trainer:Train Epoch: 18 [30/134 (22%)] Loss: 0.156030
# DEBUG:trainer:Train Epoch: 18 [35/134 (26%)] Loss: 0.176769
# DEBUG:trainer:Train Epoch: 18 [40/134 (30%)] Loss: 0.103005
# DEBUG:trainer:Train Epoch: 18 [45/134 (34%)] Loss: 0.125617
# DEBUG:trainer:Train Epoch: 18 [50/134 (37%)] Loss: 0.125195
# DEBUG:trainer:Train Epoch: 18 [55/134 (41%)] Loss: 0.075068
# DEBUG:trainer:Train Epoch: 18 [60/134 (45%)] Loss: 0.093358
# DEBUG:trainer:Train Epoch: 18 [65/134 (49%)] Loss: 0.115644
# DEBUG:trainer:Train Epoch: 18 [70/134 (52%)] Loss: 0.081983
# DEBUG:trainer:Train Epoch: 18 [75/134 (56%)] Loss: 0.105511
# DEBUG:trainer:Train Epoch: 18 [80/134 (60%)] Loss: 0.091755
# DEBUG:trainer:Train Epoch: 18 [85/134 (63%)] Loss: 0.087010
# DEBUG:trainer:Train Epoch: 18 [90/134 (67%)] Loss: 0.087225
# DEBUG:trainer:Train Epoch: 18 [95/134 (71%)] Loss: 0.128775
# DEBUG:trainer:Train Epoch: 18 [100/134 (75%)] Loss: 0.078195
# DEBUG:trainer:Train Epoch: 18 [105/134 (78%)] Loss: 0.091559
# DEBUG:trainer:Train Epoch: 18 [110/134 (82%)] Loss: 0.161373
# DEBUG:trainer:Train Epoch: 18 [115/134 (86%)] Loss: 0.078965
# DEBUG:trainer:Train Epoch: 18 [120/134 (90%)] Loss: 0.069435
# DEBUG:trainer:Train Epoch: 18 [125/134 (93%)] Loss: 0.102630
# DEBUG:trainer:Train Epoch: 18 [130/134 (97%)] Loss: 0.133639
# INFO:trainer:    epoch          : 18
# INFO:trainer:    loss           : 0.10474664748493415
# INFO:trainer:    accuracy       : 0.7677238805970149
# INFO:trainer:    f1_score       : 0.7800378549829233
# INFO:trainer:    val_loss       : 0.09747255141987946
# INFO:trainer:    val_accuracy   : 0.810070816864295
# INFO:trainer:    val_f1_score   : 0.806274150707686
# INFO:trainer:    val_sensitivity: 0.8007662835249042
# INFO:trainer:    val_specificity: 0.819047619047619
# INFO:trainer:    val_MAcc       : 0.8099069512862616
# INFO:trainer:    val_F1_score   : 0.8077294685990338
# INFO:trainer:Saving new best model at epoch 18: model_best.pth
# DEBUG:trainer:Train Epoch: 19 [0/134 (0%)] Loss: 0.054269
# DEBUG:trainer:Train Epoch: 19 [5/134 (4%)] Loss: 0.114506
# DEBUG:trainer:Train Epoch: 19 [10/134 (7%)] Loss: 0.061367
# DEBUG:trainer:Train Epoch: 19 [15/134 (11%)] Loss: 0.114226
# DEBUG:trainer:Train Epoch: 19 [20/134 (15%)] Loss: 0.117511
# DEBUG:trainer:Train Epoch: 19 [25/134 (19%)] Loss: 0.083481
# DEBUG:trainer:Train Epoch: 19 [30/134 (22%)] Loss: 0.149153
# DEBUG:trainer:Train Epoch: 19 [35/134 (26%)] Loss: 0.093898
# DEBUG:trainer:Train Epoch: 19 [40/134 (30%)] Loss: 0.114412
# DEBUG:trainer:Train Epoch: 19 [45/134 (34%)] Loss: 0.070678
# DEBUG:trainer:Train Epoch: 19 [50/134 (37%)] Loss: 0.103640
# DEBUG:trainer:Train Epoch: 19 [55/134 (41%)] Loss: 0.120176
# DEBUG:trainer:Train Epoch: 19 [60/134 (45%)] Loss: 0.076143
# DEBUG:trainer:Train Epoch: 19 [65/134 (49%)] Loss: 0.077064
# DEBUG:trainer:Train Epoch: 19 [70/134 (52%)] Loss: 0.075340
# DEBUG:trainer:Train Epoch: 19 [75/134 (56%)] Loss: 0.079393
# DEBUG:trainer:Train Epoch: 19 [80/134 (60%)] Loss: 0.200202
# DEBUG:trainer:Train Epoch: 19 [85/134 (63%)] Loss: 0.108354
# DEBUG:trainer:Train Epoch: 19 [90/134 (67%)] Loss: 0.079570
# DEBUG:trainer:Train Epoch: 19 [95/134 (71%)] Loss: 0.099451
# DEBUG:trainer:Train Epoch: 19 [100/134 (75%)] Loss: 0.151505
# DEBUG:trainer:Train Epoch: 19 [105/134 (78%)] Loss: 0.118542
# DEBUG:trainer:Train Epoch: 19 [110/134 (82%)] Loss: 0.078042
# DEBUG:trainer:Train Epoch: 19 [115/134 (86%)] Loss: 0.070397
# DEBUG:trainer:Train Epoch: 19 [120/134 (90%)] Loss: 0.073963
# DEBUG:trainer:Train Epoch: 19 [125/134 (93%)] Loss: 0.091406
# DEBUG:trainer:Train Epoch: 19 [130/134 (97%)] Loss: 0.118511
# INFO:trainer:    epoch          : 19
# INFO:trainer:    loss           : 0.10755329106503458
# INFO:trainer:    accuracy       : 0.7494003198294243
# INFO:trainer:    f1_score       : 0.7624817784633886
# INFO:trainer:    val_loss       : 0.09638607648737503
# INFO:trainer:    val_accuracy   : 0.8356389986824769
# INFO:trainer:    val_f1_score   : 0.8412489360992648
# INFO:trainer:    val_sensitivity: 0.7681992337164751
# INFO:trainer:    val_specificity: 0.9028571428571428
# INFO:trainer:    val_MAcc       : 0.835528188286809
# INFO:trainer:    val_F1_score   : 0.8234086242299795
# DEBUG:trainer:Train Epoch: 20 [0/134 (0%)] Loss: 0.096326
# DEBUG:trainer:Train Epoch: 20 [5/134 (4%)] Loss: 0.131746
# DEBUG:trainer:Train Epoch: 20 [10/134 (7%)] Loss: 0.123585
# DEBUG:trainer:Train Epoch: 20 [15/134 (11%)] Loss: 0.080091
# DEBUG:trainer:Train Epoch: 20 [20/134 (15%)] Loss: 0.095590
# DEBUG:trainer:Train Epoch: 20 [25/134 (19%)] Loss: 0.126473
# DEBUG:trainer:Train Epoch: 20 [30/134 (22%)] Loss: 0.137349
# DEBUG:trainer:Train Epoch: 20 [35/134 (26%)] Loss: 0.100109
# DEBUG:trainer:Train Epoch: 20 [40/134 (30%)] Loss: 0.072972
# DEBUG:trainer:Train Epoch: 20 [45/134 (34%)] Loss: 0.130993
# DEBUG:trainer:Train Epoch: 20 [50/134 (37%)] Loss: 0.094925
# DEBUG:trainer:Train Epoch: 20 [55/134 (41%)] Loss: 0.188058
# DEBUG:trainer:Train Epoch: 20 [60/134 (45%)] Loss: 0.065495
# DEBUG:trainer:Train Epoch: 20 [65/134 (49%)] Loss: 0.086865
# DEBUG:trainer:Train Epoch: 20 [70/134 (52%)] Loss: 0.092021
# DEBUG:trainer:Train Epoch: 20 [75/134 (56%)] Loss: 0.088987
# DEBUG:trainer:Train Epoch: 20 [80/134 (60%)] Loss: 0.127499
# DEBUG:trainer:Train Epoch: 20 [85/134 (63%)] Loss: 0.129971
# DEBUG:trainer:Train Epoch: 20 [90/134 (67%)] Loss: 0.133695
# DEBUG:trainer:Train Epoch: 20 [95/134 (71%)] Loss: 0.099098
# DEBUG:trainer:Train Epoch: 20 [100/134 (75%)] Loss: 0.106459
# DEBUG:trainer:Train Epoch: 20 [105/134 (78%)] Loss: 0.090524
# DEBUG:trainer:Train Epoch: 20 [110/134 (82%)] Loss: 0.118216
# DEBUG:trainer:Train Epoch: 20 [115/134 (86%)] Loss: 0.090323
# DEBUG:trainer:Train Epoch: 20 [120/134 (90%)] Loss: 0.094903
# DEBUG:trainer:Train Epoch: 20 [125/134 (93%)] Loss: 0.123026
# DEBUG:trainer:Train Epoch: 20 [130/134 (97%)] Loss: 0.089699
# INFO:trainer:    epoch          : 20
# INFO:trainer:    loss           : 0.10227045744879922
# INFO:trainer:    accuracy       : 0.740271855010661
# INFO:trainer:    f1_score       : 0.7551949941647724
# INFO:trainer:    val_loss       : 0.09470707155538327
# INFO:trainer:    val_accuracy   : 0.8271162714097496
# INFO:trainer:    val_f1_score   : 0.8288617453782562
# INFO:trainer:    val_sensitivity: 0.7777777777777778
# INFO:trainer:    val_specificity: 0.8761904761904762
# INFO:trainer:    val_MAcc       : 0.8269841269841269
# INFO:trainer:    val_F1_score   : 0.8177240684793554
# DEBUG:trainer:Train Epoch: 21 [0/134 (0%)] Loss: 0.087010
# DEBUG:trainer:Train Epoch: 21 [5/134 (4%)] Loss: 0.115306
# DEBUG:trainer:Train Epoch: 21 [10/134 (7%)] Loss: 0.103719
# DEBUG:trainer:Train Epoch: 21 [15/134 (11%)] Loss: 0.109920
# DEBUG:trainer:Train Epoch: 21 [20/134 (15%)] Loss: 0.080582
# DEBUG:trainer:Train Epoch: 21 [25/134 (19%)] Loss: 0.090122
# DEBUG:trainer:Train Epoch: 21 [30/134 (22%)] Loss: 0.115413
# DEBUG:trainer:Train Epoch: 21 [35/134 (26%)] Loss: 0.085260
# DEBUG:trainer:Train Epoch: 21 [40/134 (30%)] Loss: 0.073922
# DEBUG:trainer:Train Epoch: 21 [45/134 (34%)] Loss: 0.061558
# DEBUG:trainer:Train Epoch: 21 [50/134 (37%)] Loss: 0.134734
# DEBUG:trainer:Train Epoch: 21 [55/134 (41%)] Loss: 0.138516
# DEBUG:trainer:Train Epoch: 21 [60/134 (45%)] Loss: 0.120262
# DEBUG:trainer:Train Epoch: 21 [65/134 (49%)] Loss: 0.114682
# DEBUG:trainer:Train Epoch: 21 [70/134 (52%)] Loss: 0.086481
# DEBUG:trainer:Train Epoch: 21 [75/134 (56%)] Loss: 0.072488
# DEBUG:trainer:Train Epoch: 21 [80/134 (60%)] Loss: 0.100790
# DEBUG:trainer:Train Epoch: 21 [85/134 (63%)] Loss: 0.076217
# DEBUG:trainer:Train Epoch: 21 [90/134 (67%)] Loss: 0.137992
# DEBUG:trainer:Train Epoch: 21 [95/134 (71%)] Loss: 0.100744
# DEBUG:trainer:Train Epoch: 21 [100/134 (75%)] Loss: 0.121629
# DEBUG:trainer:Train Epoch: 21 [105/134 (78%)] Loss: 0.088894
# DEBUG:trainer:Train Epoch: 21 [110/134 (82%)] Loss: 0.102588
# DEBUG:trainer:Train Epoch: 21 [115/134 (86%)] Loss: 0.119045
# DEBUG:trainer:Train Epoch: 21 [120/134 (90%)] Loss: 0.107209
# DEBUG:trainer:Train Epoch: 21 [125/134 (93%)] Loss: 0.106482
# DEBUG:trainer:Train Epoch: 21 [130/134 (97%)] Loss: 0.106795
# INFO:trainer:    epoch          : 21
# INFO:trainer:    loss           : 0.10197878256440163
# INFO:trainer:    accuracy       : 0.7651252665245202
# INFO:trainer:    f1_score       : 0.7754889906665815
# INFO:trainer:    val_loss       : 0.09755849759235527
# INFO:trainer:    val_accuracy   : 0.8252223320158103
# INFO:trainer:    val_f1_score   : 0.8283489365895534
# INFO:trainer:    val_sensitivity: 0.7739463601532567
# ...
# INFO:trainer:    val_loss       : 0.07541032186286016
# INFO:trainer:    val_accuracy   : 0.8786231884057971
# INFO:trainer:    val_f1_score   : 0.8826591239717609
# INFO:trainer:    val_sensitivity: 0.8007662835249042
# INFO:trainer:    val_specificity: 0.9561904761904761
# INFO:trainer:    val_MAcc       : 0.8784783798576902
# INFO:trainer:    val_F1_score   : 0.8681204569055037
# DEBUG:trainer:Train Epoch: 66 [0/134 (0%)] Loss: 0.080030
# DEBUG:trainer:Train Epoch: 66 [5/134 (4%)] Loss: 0.053360
# DEBUG:trainer:Train Epoch: 66 [10/134 (7%)] Loss: 0.047239
# DEBUG:trainer:Train Epoch: 66 [15/134 (11%)] Loss: 0.220060
# DEBUG:trainer:Train Epoch: 66 [20/134 (15%)] Loss: 0.115847
# DEBUG:trainer:Train Epoch: 66 [25/134 (19%)] Loss: 0.109276
# DEBUG:trainer:Train Epoch: 66 [30/134 (22%)] Loss: 0.099358
# DEBUG:trainer:Train Epoch: 66 [35/134 (26%)] Loss: 0.085434
# DEBUG:trainer:Train Epoch: 66 [40/134 (30%)] Loss: 0.063413
# DEBUG:trainer:Train Epoch: 66 [45/134 (34%)] Loss: 0.064473
# DEBUG:trainer:Train Epoch: 66 [50/134 (37%)] Loss: 0.064430
# DEBUG:trainer:Train Epoch: 66 [55/134 (41%)] Loss: 0.087755
# DEBUG:trainer:Train Epoch: 66 [60/134 (45%)] Loss: 0.088226
# DEBUG:trainer:Train Epoch: 66 [65/134 (49%)] Loss: 0.090921
# DEBUG:trainer:Train Epoch: 66 [70/134 (52%)] Loss: 0.047870
# DEBUG:trainer:Train Epoch: 66 [75/134 (56%)] Loss: 0.123505
# DEBUG:trainer:Train Epoch: 66 [80/134 (60%)] Loss: 0.081073
# DEBUG:trainer:Train Epoch: 66 [85/134 (63%)] Loss: 0.120142
# DEBUG:trainer:Train Epoch: 66 [90/134 (67%)] Loss: 0.099038
# DEBUG:trainer:Train Epoch: 66 [95/134 (71%)] Loss: 0.158477
# DEBUG:trainer:Train Epoch: 66 [100/134 (75%)] Loss: 0.069508
# DEBUG:trainer:Train Epoch: 66 [105/134 (78%)] Loss: 0.078094
# DEBUG:trainer:Train Epoch: 66 [110/134 (82%)] Loss: 0.065413
# DEBUG:trainer:Train Epoch: 66 [115/134 (86%)] Loss: 0.044346
# DEBUG:trainer:Train Epoch: 66 [120/134 (90%)] Loss: 0.073544
# DEBUG:trainer:Train Epoch: 66 [125/134 (93%)] Loss: 0.069203
# DEBUG:trainer:Train Epoch: 66 [130/134 (97%)] Loss: 0.094234
# INFO:trainer:    epoch          : 66
# INFO:trainer:    loss           : 0.08318170718848705
# INFO:trainer:    accuracy       : 0.7847481343283582
# INFO:trainer:    f1_score       : 0.7915121852195207
# INFO:trainer:    val_loss       : 0.07464147923570691
# INFO:trainer:    val_accuracy   : 0.8714179841897234
# INFO:trainer:    val_f1_score   : 0.8746805557346876
# INFO:trainer:    val_sensitivity: 0.8084291187739464
# INFO:trainer:    val_specificity: 0.9333333333333333
# INFO:trainer:    val_MAcc       : 0.8708812260536398
# INFO:trainer:    val_F1_score   : 0.8621041879468847
# DEBUG:trainer:Train Epoch: 67 [0/134 (0%)] Loss: 0.062472
# DEBUG:trainer:Train Epoch: 67 [5/134 (4%)] Loss: 0.086355
# DEBUG:trainer:Train Epoch: 67 [10/134 (7%)] Loss: 0.143964
# DEBUG:trainer:Train Epoch: 67 [15/134 (11%)] Loss: 0.067377
# DEBUG:trainer:Train Epoch: 67 [20/134 (15%)] Loss: 0.062619
# DEBUG:trainer:Train Epoch: 67 [25/134 (19%)] Loss: 0.056418
# DEBUG:trainer:Train Epoch: 67 [30/134 (22%)] Loss: 0.077392
# DEBUG:trainer:Train Epoch: 67 [35/134 (26%)] Loss: 0.076313
# DEBUG:trainer:Train Epoch: 67 [40/134 (30%)] Loss: 0.092916
# DEBUG:trainer:Train Epoch: 67 [45/134 (34%)] Loss: 0.086595
# DEBUG:trainer:Train Epoch: 67 [50/134 (37%)] Loss: 0.081404
# DEBUG:trainer:Train Epoch: 67 [55/134 (41%)] Loss: 0.058385
# DEBUG:trainer:Train Epoch: 67 [60/134 (45%)] Loss: 0.178689
# DEBUG:trainer:Train Epoch: 67 [65/134 (49%)] Loss: 0.073977
# DEBUG:trainer:Train Epoch: 67 [70/134 (52%)] Loss: 0.101418
# DEBUG:trainer:Train Epoch: 67 [75/134 (56%)] Loss: 0.046562
# DEBUG:trainer:Train Epoch: 67 [80/134 (60%)] Loss: 0.064009
# DEBUG:trainer:Train Epoch: 67 [85/134 (63%)] Loss: 0.061287
# DEBUG:trainer:Train Epoch: 67 [90/134 (67%)] Loss: 0.070257
# DEBUG:trainer:Train Epoch: 67 [95/134 (71%)] Loss: 0.144997
# DEBUG:trainer:Train Epoch: 67 [100/134 (75%)] Loss: 0.092062
# DEBUG:trainer:Train Epoch: 67 [105/134 (78%)] Loss: 0.057062
# DEBUG:trainer:Train Epoch: 67 [110/134 (82%)] Loss: 0.045459
# DEBUG:trainer:Train Epoch: 67 [115/134 (86%)] Loss: 0.077041
# DEBUG:trainer:Train Epoch: 67 [120/134 (90%)] Loss: 0.065590
# DEBUG:trainer:Train Epoch: 67 [125/134 (93%)] Loss: 0.036243
# DEBUG:trainer:Train Epoch: 67 [130/134 (97%)] Loss: 0.056788
# INFO:trainer:    epoch          : 67
# INFO:trainer:    loss           : 0.08295550447568964
# INFO:trainer:    accuracy       : 0.7895788912579957
# INFO:trainer:    f1_score       : 0.7966393255802069
# INFO:trainer:    val_loss       : 0.07521189032404711
# INFO:trainer:    val_accuracy   : 0.8805171277997365
# INFO:trainer:    val_f1_score   : 0.88566252846327
# INFO:trainer:    val_sensitivity: 0.8045977011494253
# INFO:trainer:    val_specificity: 0.9561904761904761
# INFO:trainer:    val_MAcc       : 0.8803940886699507
# INFO:trainer:    val_F1_score   : 0.8704663212435234
# DEBUG:trainer:Train Epoch: 68 [0/134 (0%)] Loss: 0.080726
# DEBUG:trainer:Train Epoch: 68 [5/134 (4%)] Loss: 0.101094
# DEBUG:trainer:Train Epoch: 68 [10/134 (7%)] Loss: 0.071328
# DEBUG:trainer:Train Epoch: 68 [15/134 (11%)] Loss: 0.046541
# DEBUG:trainer:Train Epoch: 68 [20/134 (15%)] Loss: 0.105389
# DEBUG:trainer:Train Epoch: 68 [25/134 (19%)] Loss: 0.060678
# DEBUG:trainer:Train Epoch: 68 [30/134 (22%)] Loss: 0.086363
# DEBUG:trainer:Train Epoch: 68 [35/134 (26%)] Loss: 0.068321
# DEBUG:trainer:Train Epoch: 68 [40/134 (30%)] Loss: 0.071848
# DEBUG:trainer:Train Epoch: 68 [45/134 (34%)] Loss: 0.085695
# DEBUG:trainer:Train Epoch: 68 [50/134 (37%)] Loss: 0.101490
# DEBUG:trainer:Train Epoch: 68 [55/134 (41%)] Loss: 0.097886
# DEBUG:trainer:Train Epoch: 68 [60/134 (45%)] Loss: 0.049657
# DEBUG:trainer:Train Epoch: 68 [65/134 (49%)] Loss: 0.079662
# DEBUG:trainer:Train Epoch: 68 [70/134 (52%)] Loss: 0.142625
# DEBUG:trainer:Train Epoch: 68 [75/134 (56%)] Loss: 0.065402
# DEBUG:trainer:Train Epoch: 68 [80/134 (60%)] Loss: 0.060899
# DEBUG:trainer:Train Epoch: 68 [85/134 (63%)] Loss: 0.039561
# DEBUG:trainer:Train Epoch: 68 [90/134 (67%)] Loss: 0.069562
# DEBUG:trainer:Train Epoch: 68 [95/134 (71%)] Loss: 0.226903
# DEBUG:trainer:Train Epoch: 68 [100/134 (75%)] Loss: 0.053529
# DEBUG:trainer:Train Epoch: 68 [105/134 (78%)] Loss: 0.097134
# DEBUG:trainer:Train Epoch: 68 [110/134 (82%)] Loss: 0.051497
# DEBUG:trainer:Train Epoch: 68 [115/134 (86%)] Loss: 0.077093
# DEBUG:trainer:Train Epoch: 68 [120/134 (90%)] Loss: 0.101130
# DEBUG:trainer:Train Epoch: 68 [125/134 (93%)] Loss: 0.047508
# DEBUG:trainer:Train Epoch: 68 [130/134 (97%)] Loss: 0.043576
# INFO:trainer:    epoch          : 68
# INFO:trainer:    loss           : 0.07534023463281232
# INFO:trainer:    accuracy       : 0.8204624200426439
# INFO:trainer:    f1_score       : 0.8280235539609453
# INFO:trainer:    val_loss       : 0.07598765595166972
# INFO:trainer:    val_accuracy   : 0.8833580368906456
# INFO:trainer:    val_f1_score   : 0.8882190643773872
# INFO:trainer:    val_sensitivity: 0.8007662835249042
# INFO:trainer:    val_specificity: 0.9657142857142857
# INFO:trainer:    val_MAcc       : 0.883240284619595
# INFO:trainer:    val_F1_score   : 0.872651356993737
# DEBUG:trainer:Train Epoch: 69 [0/134 (0%)] Loss: 0.035495
# DEBUG:trainer:Train Epoch: 69 [5/134 (4%)] Loss: 0.043160
# DEBUG:trainer:Train Epoch: 69 [10/134 (7%)] Loss: 0.055914
# DEBUG:trainer:Train Epoch: 69 [15/134 (11%)] Loss: 0.093687
# DEBUG:trainer:Train Epoch: 69 [20/134 (15%)] Loss: 0.077780
# DEBUG:trainer:Train Epoch: 69 [25/134 (19%)] Loss: 0.104858
# DEBUG:trainer:Train Epoch: 69 [30/134 (22%)] Loss: 0.108429
# DEBUG:trainer:Train Epoch: 69 [35/134 (26%)] Loss: 0.050467
# DEBUG:trainer:Train Epoch: 69 [40/134 (30%)] Loss: 0.058792
# DEBUG:trainer:Train Epoch: 69 [45/134 (34%)] Loss: 0.067894
# DEBUG:trainer:Train Epoch: 69 [50/134 (37%)] Loss: 0.132647
# DEBUG:trainer:Train Epoch: 69 [55/134 (41%)] Loss: 0.093506
# DEBUG:trainer:Train Epoch: 69 [60/134 (45%)] Loss: 0.060676
# DEBUG:trainer:Train Epoch: 69 [65/134 (49%)] Loss: 0.063208
# DEBUG:trainer:Train Epoch: 69 [70/134 (52%)] Loss: 0.073167
# DEBUG:trainer:Train Epoch: 69 [75/134 (56%)] Loss: 0.067801
# DEBUG:trainer:Train Epoch: 69 [80/134 (60%)] Loss: 0.118771
# DEBUG:trainer:Train Epoch: 69 [85/134 (63%)] Loss: 0.075536
# DEBUG:trainer:Train Epoch: 69 [90/134 (67%)] Loss: 0.128770
# DEBUG:trainer:Train Epoch: 69 [95/134 (71%)] Loss: 0.043820
# DEBUG:trainer:Train Epoch: 69 [100/134 (75%)] Loss: 0.055484
# DEBUG:trainer:Train Epoch: 69 [105/134 (78%)] Loss: 0.063416
# DEBUG:trainer:Train Epoch: 69 [110/134 (82%)] Loss: 0.071774
# DEBUG:trainer:Train Epoch: 69 [115/134 (86%)] Loss: 0.052955
# DEBUG:trainer:Train Epoch: 69 [120/134 (90%)] Loss: 0.071823
# DEBUG:trainer:Train Epoch: 69 [125/134 (93%)] Loss: 0.067557
# DEBUG:trainer:Train Epoch: 69 [130/134 (97%)] Loss: 0.134546
# INFO:trainer:    epoch          : 69
# INFO:trainer:    loss           : 0.08098721600123751
# INFO:trainer:    accuracy       : 0.7824160447761194
# INFO:trainer:    f1_score       : 0.7890611377025295
# INFO:trainer:    val_loss       : 0.07502426252220616
# INFO:trainer:    val_accuracy   : 0.8757822793148881
# INFO:trainer:    val_f1_score   : 0.8805267148321441
# INFO:trainer:    val_sensitivity: 0.8084291187739464
# INFO:trainer:    val_specificity: 0.9428571428571428
# INFO:trainer:    val_MAcc       : 0.8756431308155446
# INFO:trainer:    val_F1_score   : 0.8665297741273101
# DEBUG:trainer:Train Epoch: 70 [0/134 (0%)] Loss: 0.050590
# DEBUG:trainer:Train Epoch: 70 [5/134 (4%)] Loss: 0.061547
# DEBUG:trainer:Train Epoch: 70 [10/134 (7%)] Loss: 0.131730
# DEBUG:trainer:Train Epoch: 70 [15/134 (11%)] Loss: 0.211014
# DEBUG:trainer:Train Epoch: 70 [20/134 (15%)] Loss: 0.098748
# DEBUG:trainer:Train Epoch: 70 [25/134 (19%)] Loss: 0.048192
# DEBUG:trainer:Train Epoch: 70 [30/134 (22%)] Loss: 0.066000
# DEBUG:trainer:Train Epoch: 70 [35/134 (26%)] Loss: 0.077919
# DEBUG:trainer:Train Epoch: 70 [40/134 (30%)] Loss: 0.195462
# DEBUG:trainer:Train Epoch: 70 [45/134 (34%)] Loss: 0.038267
# DEBUG:trainer:Train Epoch: 70 [50/134 (37%)] Loss: 0.076263
# DEBUG:trainer:Train Epoch: 70 [55/134 (41%)] Loss: 0.056295
# DEBUG:trainer:Train Epoch: 70 [60/134 (45%)] Loss: 0.085244
# DEBUG:trainer:Train Epoch: 70 [65/134 (49%)] Loss: 0.071390
# DEBUG:trainer:Train Epoch: 70 [70/134 (52%)] Loss: 0.040607
# DEBUG:trainer:Train Epoch: 70 [75/134 (56%)] Loss: 0.047381
# DEBUG:trainer:Train Epoch: 70 [80/134 (60%)] Loss: 0.062461
# DEBUG:trainer:Train Epoch: 70 [85/134 (63%)] Loss: 0.072167
# DEBUG:trainer:Train Epoch: 70 [90/134 (67%)] Loss: 0.050712
# DEBUG:trainer:Train Epoch: 70 [95/134 (71%)] Loss: 0.060189
# DEBUG:trainer:Train Epoch: 70 [100/134 (75%)] Loss: 0.081044
# DEBUG:trainer:Train Epoch: 70 [105/134 (78%)] Loss: 0.066284
# DEBUG:trainer:Train Epoch: 70 [110/134 (82%)] Loss: 0.040594
# DEBUG:trainer:Train Epoch: 70 [115/134 (86%)] Loss: 0.059797
# DEBUG:trainer:Train Epoch: 70 [120/134 (90%)] Loss: 0.132934
# DEBUG:trainer:Train Epoch: 70 [125/134 (93%)] Loss: 0.039845
# DEBUG:trainer:Train Epoch: 70 [130/134 (97%)] Loss: 0.077547
# INFO:trainer:    epoch          : 70
# INFO:trainer:    loss           : 0.07878478994565223
# INFO:trainer:    accuracy       : 0.8189965351812366
# INFO:trainer:    f1_score       : 0.8243087194572496
# INFO:trainer:    val_loss       : 0.0753456267782233
# INFO:trainer:    val_accuracy   : 0.8767292490118577
# INFO:trainer:    val_f1_score   : 0.8814552379036596
# INFO:trainer:    val_sensitivity: 0.8026819923371648
# INFO:trainer:    val_specificity: 0.9504761904761905
# INFO:trainer:    val_MAcc       : 0.8765790914066776
# INFO:trainer:    val_F1_score   : 0.8665977249224405
# DEBUG:trainer:Train Epoch: 71 [0/134 (0%)] Loss: 0.070652
# DEBUG:trainer:Train Epoch: 71 [5/134 (4%)] Loss: 0.113945
# DEBUG:trainer:Train Epoch: 71 [10/134 (7%)] Loss: 0.091108
# DEBUG:trainer:Train Epoch: 71 [15/134 (11%)] Loss: 0.059327
# DEBUG:trainer:Train Epoch: 71 [20/134 (15%)] Loss: 0.048648
# DEBUG:trainer:Train Epoch: 71 [25/134 (19%)] Loss: 0.088257
# DEBUG:trainer:Train Epoch: 71 [30/134 (22%)] Loss: 0.058092
# DEBUG:trainer:Train Epoch: 71 [35/134 (26%)] Loss: 0.072732
# DEBUG:trainer:Train Epoch: 71 [40/134 (30%)] Loss: 0.052235
# DEBUG:trainer:Train Epoch: 71 [45/134 (34%)] Loss: 0.143598
# DEBUG:trainer:Train Epoch: 71 [50/134 (37%)] Loss: 0.135051
# DEBUG:trainer:Train Epoch: 71 [55/134 (41%)] Loss: 0.065061
# DEBUG:trainer:Train Epoch: 71 [60/134 (45%)] Loss: 0.119547
# DEBUG:trainer:Train Epoch: 71 [65/134 (49%)] Loss: 0.045553
# DEBUG:trainer:Train Epoch: 71 [70/134 (52%)] Loss: 0.098270
# DEBUG:trainer:Train Epoch: 71 [75/134 (56%)] Loss: 0.092412
# DEBUG:trainer:Train Epoch: 71 [80/134 (60%)] Loss: 0.158963
# DEBUG:trainer:Train Epoch: 71 [85/134 (63%)] Loss: 0.070191
# DEBUG:trainer:Train Epoch: 71 [90/134 (67%)] Loss: 0.068105
# DEBUG:trainer:Train Epoch: 71 [95/134 (71%)] Loss: 0.071069
# DEBUG:trainer:Train Epoch: 71 [100/134 (75%)] Loss: 0.054423
# DEBUG:trainer:Train Epoch: 71 [105/134 (78%)] Loss: 0.063442
# DEBUG:trainer:Train Epoch: 71 [110/134 (82%)] Loss: 0.063758
# DEBUG:trainer:Train Epoch: 71 [115/134 (86%)] Loss: 0.039751
# DEBUG:trainer:Train Epoch: 71 [120/134 (90%)] Loss: 0.044422
# DEBUG:trainer:Train Epoch: 71 [125/134 (93%)] Loss: 0.060883
# DEBUG:trainer:Train Epoch: 71 [130/134 (97%)] Loss: 0.178082
# INFO:trainer:    epoch          : 71
# INFO:trainer:    loss           : 0.08352574433630972
# INFO:trainer:    accuracy       : 0.7427038912579957
# INFO:trainer:    f1_score       : 0.7513127977945571
# INFO:trainer:    val_loss       : 0.07608077799280484
# INFO:trainer:    val_accuracy   : 0.8744647562582345
# INFO:trainer:    val_f1_score   : 0.8796882292504734
# INFO:trainer:    val_sensitivity: 0.7969348659003831
# INFO:trainer:    val_specificity: 0.9523809523809523
# INFO:trainer:    val_MAcc       : 0.8746579091406677
# INFO:trainer:    val_F1_score   : 0.8639667705088264
# DEBUG:trainer:Train Epoch: 72 [0/134 (0%)] Loss: 0.063067
# DEBUG:trainer:Train Epoch: 72 [5/134 (4%)] Loss: 0.104420
# DEBUG:trainer:Train Epoch: 72 [10/134 (7%)] Loss: 0.147999
# DEBUG:trainer:Train Epoch: 72 [15/134 (11%)] Loss: 0.146816
# DEBUG:trainer:Train Epoch: 72 [20/134 (15%)] Loss: 0.102930
# DEBUG:trainer:Train Epoch: 72 [25/134 (19%)] Loss: 0.157072
# DEBUG:trainer:Train Epoch: 72 [30/134 (22%)] Loss: 0.117106
# DEBUG:trainer:Train Epoch: 72 [35/134 (26%)] Loss: 0.083305
# DEBUG:trainer:Train Epoch: 72 [40/134 (30%)] Loss: 0.080205
# DEBUG:trainer:Train Epoch: 72 [45/134 (34%)] Loss: 0.047477
# DEBUG:trainer:Train Epoch: 72 [50/134 (37%)] Loss: 0.066628
# DEBUG:trainer:Train Epoch: 72 [55/134 (41%)] Loss: 0.068479
# DEBUG:trainer:Train Epoch: 72 [60/134 (45%)] Loss: 0.110992
# DEBUG:trainer:Train Epoch: 72 [65/134 (49%)] Loss: 0.083260
# DEBUG:trainer:Train Epoch: 72 [70/134 (52%)] Loss: 0.077258
# DEBUG:trainer:Train Epoch: 72 [75/134 (56%)] Loss: 0.044996
# DEBUG:trainer:Train Epoch: 72 [80/134 (60%)] Loss: 0.078758
# DEBUG:trainer:Train Epoch: 72 [85/134 (63%)] Loss: 0.095323
# DEBUG:trainer:Train Epoch: 72 [90/134 (67%)] Loss: 0.055201
# DEBUG:trainer:Train Epoch: 72 [95/134 (71%)] Loss: 0.057227
# DEBUG:trainer:Train Epoch: 72 [100/134 (75%)] Loss: 0.093364
# DEBUG:trainer:Train Epoch: 72 [105/134 (78%)] Loss: 0.084207
# DEBUG:trainer:Train Epoch: 72 [110/134 (82%)] Loss: 0.097777
# DEBUG:trainer:Train Epoch: 72 [115/134 (86%)] Loss: 0.076749
# DEBUG:trainer:Train Epoch: 72 [120/134 (90%)] Loss: 0.085707
# DEBUG:trainer:Train Epoch: 72 [125/134 (93%)] Loss: 0.073848
# DEBUG:trainer:Train Epoch: 72 [130/134 (97%)] Loss: 0.077395
# INFO:trainer:    epoch          : 72
# INFO:trainer:    loss           : 0.08646705410262542
# INFO:trainer:    accuracy       : 0.7919109808102346
# INFO:trainer:    f1_score       : 0.7978111026434179
# INFO:trainer:    val_loss       : 0.07590144381604412
# INFO:trainer:    val_accuracy   : 0.8767292490118577
# INFO:trainer:    val_f1_score   : 0.8825929406015568
# INFO:trainer:    val_sensitivity: 0.7988505747126436
# INFO:trainer:    val_specificity: 0.9542857142857143
# INFO:trainer:    val_MAcc       : 0.876568144499179
# INFO:trainer:    val_F1_score   : 0.8660436137071651
# INFO:trainer:Validation performance didn't improve for 20 epochs. Training stops.
# === HOÀN THÀNH TRAINING ===
# Model tốt nhất được lưu tại:
# /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/Light_CNN/models/Physionet_lightweight_cnn/0203_150307/model_best.pth

# %% [markdown]
# # Test

# %%
from sklearn.metrics import f1_score, confusion_matrix
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import pandas as pd

def test_model(config, best_model_path, validation_fea_path, validation_label_csv):
    config_parser = ConfigParser(config)
    device, _ = prepare_device(config_parser['n_gpu'])

    # Khởi tạo model từ config (đảm bảo architecture đúng)
    model = config_parser.init_obj('arch', globals())
    model = model.to(device)

    # === LOAD CHỈ STATE_DICT - AN TOÀN, KHÔNG CẦN WHITELIST ===
    try:
        # Cách 1: Dùng weights_only=True (mặc định từ PT 2.6), chỉ load weights
        checkpoint = torch.load(best_model_path, map_location=device, weights_only=True)
        model.load_state_dict(checkpoint)  # checkpoint ở đây chỉ là state_dict
        print("Loaded model weights with weights_only=True (safe mode)")
    except Exception as e1:
        print(f"weights_only=True failed: {e1}")
        try:
            # Cách 2: Tắt weights_only (chỉ dùng nếu bạn tin tưởng file)
            checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
            model.load_state_dict(checkpoint['state_dict'])
            print("Loaded with weights_only=False (full checkpoint)")
        except Exception as e2:
            print(f"Cả hai cách đều thất bại: {e2}")
            return

    model.eval()

    print("\n=== MODEL ARCHITECTURE ===")
    print(model)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\nSố tham số huấn luyện được: {trainable_params:,}")

    # === Xác định input shape từ config ===
    delta = config['data_loader']['args'].get('delta', False)
    n_mfcc = config['data_loader']['args'].get('n_mfcc', 39)
    time_frames = 333

    channels = 3 if delta else 1   # static + Δ + ΔΔ nếu có
    height = n_mfcc

    # === Kiểm tra forward với input giả ===
    print("\n=== KIỂM TRA FORWARD PASS ===")
    try:
        with torch.no_grad():
            dummy_input = torch.randn(2, channels * height, time_frames)
            output = model(dummy_input)
            print(f"Input shape: (B, {channels * height}, {time_frames})")
            print(f"Output shape: {output.shape} → OK")
    except Exception as e:
        print(f"Forward lỗi: {e}")

    # === Load validation data ===
    if not Path(validation_label_csv).exists() or not Path(validation_fea_path).exists():
        print("Không tìm thấy file validation → bỏ qua đánh giá")
        return

    validation_label_df = pd.read_csv(validation_label_csv)
    validation_label_df['filename'] = validation_label_df['filename'].apply(lambda x: Path(x).stem)

    validation_dataset = HeartSoundDataSet(
        fea_path=validation_fea_path,
        labels=validation_label_df,
        duration=config['data_loader']['args']['duration'],
        training=False,
        delta=delta,
        norm=config['data_loader']['args'].get('norm', True)
    )

    print("\n=== DEBUG: SAMPLE FEATURES ===")
    for i in range(min(5, len(validation_dataset))):
        fea, lab = validation_dataset[i]
        print(f"Sample {i}: shape = {fea.shape}, label = {lab.item()}")

    # Tắt pin_memory trên CPU
    pin_memory = (device.type == 'cuda')

    validation_dataloader = DataLoader(
        validation_dataset,
        batch_size=config['data_loader']['args']['batch_size'],
        shuffle=False,
        num_workers=config['data_loader']['args'].get('num_workers', 2),
        pin_memory=pin_memory
    )

    criterion = ce_loss

    print("\n=== ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===")
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    val_TP = val_TN = val_pred_pos = val_condition_pos = 0

    with torch.no_grad():
        for data, target in validation_dataloader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            total_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, 1)
            total_correct += (pred == target).sum().item()
            total_samples += target.size(0)

            pred_pos_idx = (pred == 0)      # class 0 = abnormal (positive)
            condition_pos_idx = (target == 0)

            val_TP += (pred_pos_idx & condition_pos_idx).sum().item()
            val_TN += ((pred == 1) & (target == 1)).sum().item()
            val_pred_pos += pred_pos_idx.sum().item()
            val_condition_pos += condition_pos_idx.sum().item()

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    sensitivity = val_TP / val_condition_pos if val_condition_pos > 0 else 0
    specificity = val_TN / (total_samples - val_condition_pos) if (total_samples - val_condition_pos) > 0 else 0
    MAcc = (sensitivity + specificity) / 2
    precision = val_TP / val_pred_pos if val_pred_pos > 0 else 0
    F1_score = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0

    val_log = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'MAcc': MAcc,
        'F1_score': F1_score
    }

    print("\nKết quả đánh giá:")
    for k, v in val_log.items():
        print(f"    {k}: {v:.4f}")

    metrics_path = Path(best_model_path).parent / "test_on_validation_set_metrics.csv"
    pd.DataFrame([val_log]).to_csv(metrics_path, index=False)
    print(f"\nĐã lưu kết quả tại: {metrics_path}")

# %%
base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
if base_dir.exists():
        latest_run = max(base_dir.iterdir(), key=os.path.getmtime)
        best_model_path = latest_run / "model_best.pth"

        validation_fea_path = str(DATASET_PATH / "mfcc_features_validation.h5")
        validation_label_csv = str(DATASET_PATH / "label_validation.csv")  # Đảm bảo file này tồn tại!

        if Path(validation_fea_path).exists() and Path(validation_label_csv).exists():
            test_model(current_config, best_model_path, validation_fea_path, validation_label_csv)
        else:
            print("Không tìm thấy file validation .h5 hoặc label_validation.csv → Bỏ qua phần test.")

        size_bytes = os.path.getsize(best_model_path)
        size_mb = size_bytes / (1024 * 1024)

        print(f"Model size: {size_mb:.2f} MB")

else:
    print("Không tìm thấy thư mục saved models.")
# Out:
# Warning: There's no GPU available on this machine,training will be performed on CPU.
# weights_only=True failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.ConfigParser was not an allowed global by default. Please use `torch.serialization.add_safe_globals([__main__.ConfigParser])` or the `torch.serialization.safe_globals([__main__.ConfigParser])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Loaded with weights_only=False (full checkpoint)
#
# === MODEL ARCHITECTURE ===
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (attention_pool): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU6()
#     (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     (3): Sigmoid()
#   )
#   (features): Sequential(
#     (0): DepthwiseSeparableConv(
#       (depthwise): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#       (pointwise): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (1): Dropout2d(p=0.1, inplace=False)
#     (2): DepthwiseSeparableConv(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (pointwise): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (3): Dropout2d(p=0.15, inplace=False)
#     (4): DepthwiseSeparableConv(
#       (depthwise): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (5): Dropout2d(p=0.15, inplace=False)
#   )
#   (pool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
#
# Số tham số huấn luyện được: 20,963
#
# === KIỂM TRA FORWARD PASS ===
# Input shape: (B, 39, 333)
# Output shape: torch.Size([2, 2]) → OK
#
# === DEBUG: SAMPLE FEATURES ===
# Sample 0: shape = torch.Size([13, 333]), label = 1
# Sample 1: shape = torch.Size([13, 333]), label = 1
# Sample 2: shape = torch.Size([13, 333]), label = 1
# Sample 3: shape = torch.Size([13, 333]), label = 1
# Sample 4: shape = torch.Size([13, 333]), label = 1
#
# === ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===
#
# Kết quả đánh giá:
#     loss: 0.8263
#     accuracy: 0.5415
#     sensitivity: 0.9133
#     specificity: 0.1722
#     MAcc: 0.5428
#     F1_score: 0.6650
#
# Đã lưu kết quả tại: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/Light_CNN/models/Physionet_lightweight_cnn/0203_150307/test_on_validation_set_metrics.csv
# Model size: 0.39 MB
