# %%
import numpy as np
import pandas as pd
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import numpy as np
from torch.utils.data import DataLoader, Sampler
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision.utils import make_grid

from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    balanced_accuracy_score,
    matthews_corrcoef
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
sys.path.append(str(DATASET_PATH))

# %% [markdown]
# # Load Data

# %% [markdown]
# ## HeartSoundDataSet

# %%
def spec_augment(spec, F=6, T=25, num_masks=2):
    """SpecAugment cho MFCC"""
    cloned = spec.clone()
    num_mel_channels, num_frames = cloned.shape[-2:]

    # Frequency masking
    for _ in range(num_masks):
        f = np.random.randint(0, F)
        f0 = np.random.randint(0, num_mel_channels - f)
        cloned[..., f0:f0+f, :] = cloned[..., f0:f0+f, :].mean()

    # Time masking
    for _ in range(num_masks):
        t = np.random.randint(0, T)
        t0 = np.random.randint(0, num_frames - t)
        cloned[..., :, t0:t0+t] = 0

    return cloned

# %%
import numpy as np
import h5py
import random
import torch
from pathlib import Path
import librosa  # cần import để tính delta

EPS = 1e-8

def standard_normal_variate(data):
    """Chuẩn hóa Z-score trên toàn bộ tensor."""
    mean = np.mean(data)
    std = np.std(data) + EPS
    return (data - mean) / std

class HeartSoundDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 fea_path: str,              # đường dẫn file .h5
                 labels: pd.DataFrame,       # DataFrame với cột 'filename' và 'label'
                 duration: int = 5,          # giây
                 training: bool = True,
                 delta: bool = False,
                 norm: bool = True):
        self._fea_path = fea_path
        self._h5database = None
        self._labels = labels.reset_index(drop=True)
        self._colname = ['filename', 'label']
        self._len = len(self._labels)
        self._duration = duration
        self._delta = delta
        self.train = training
        self.hop_length = 15  # ms
        self.norm = norm

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
      row = self._labels.iloc[idx]
      filename = row['filename']
      target_bin = row['label']

      # Lấy key từ stem của filename
      key = Path(filename).stem if '/' in str(filename) else filename

      # Mở HDF5 nếu chưa mở
      if self._h5database is None:
          self._h5database = h5py.File(self._fea_path, 'r')

      if key not in self._h5database:
          available = list(self._h5database.keys())[:10]
          raise KeyError(f"Key '{key}' not found in HDF5. Sample keys: {available}")

      # Load feature từ HDF5
      feature = self._h5database[key][()]  # (mel_bins, T) hoặc (C, mel_bins, T)

      # Đảm bảo feature là 3D: (C, H, W)
      if feature.ndim == 2:
          feature = feature[np.newaxis, :, :]  # → (1, mel_bins, T)
      elif feature.ndim != 3:
          raise ValueError(f"Unexpected shape {feature.shape} for key '{key}'")

      # Chuẩn hóa toàn bộ tensor (nếu bật)
      if self.norm:
          feature = standard_normal_variate(feature)

      # Thêm delta features (nếu bật)
      if self._delta:
          orig = feature[0]  # (mel_bins, T)
          delta = librosa.feature.delta(orig)
          delta2 = librosa.feature.delta(delta)
          feature = np.stack([orig, delta, delta2], axis=0)  # → (3, mel_bins, T)

      # Lấy shape hiện tại
      channels, mel_bins, num_frames = feature.shape

      # Tính độ dài mong muốn (frames)
      cycle_len = int(self._duration * 1000 / self.hop_length)

      # Crop hoặc pad để đạt đúng cycle_len
      if num_frames >= cycle_len:
          if self.train:
              #feature_tensor = spec_augment(feature_tensor, F=5, T=30, num_masks=1)
              start_ind = random.randint(0, num_frames - cycle_len)
          else:
              start_ind = (num_frames - cycle_len) // 2
          feature = feature[:, :, start_ind:start_ind + cycle_len]
      elif num_frames < cycle_len:
          pad_width = ((0, 0), (0, 0), (0, cycle_len - num_frames))
          feature = np.pad(feature, pad_width, mode='wrap')

      # === Fix quan trọng cho model gốc: Làm cho tensor luôn là 3D (mel_bins, num_frames) ===
      feature_tensor = torch.from_numpy(feature).float()  # (C, mel_bins, T)

      if self.train:
          feature_tensor = spec_augment(feature_tensor, F=5, T=30, num_masks=1)

      if channels > 1:  # Có delta → C=3
          # Ghép 3 channels vào chiều mel_bins → (3 * mel_bins, T) = (384, T)
          # Model sẽ view thành (B, 3, 128, T) trong forward
          feature_tensor = feature_tensor.view(channels * mel_bins, -1)  # → (384, T)
      else:
          # Không delta → squeeze về (mel_bins, T) = (128, T)
          feature_tensor = feature_tensor.squeeze(0)

      return feature_tensor, torch.tensor(target_bin, dtype=torch.long)

    def __del__(self):
        """Đóng file HDF5 khi object bị hủy (tốt cho quản lý tài nguyên)."""
        if self._h5database is not None:
            self._h5database.close()

# %% [markdown]
# ## MinimumOccupancySampler

# %%
class MinimumOccupancySampler(Sampler):
    """
        samples at least one instance from each class sequentially
    """
    def __init__(self, labels, sampling_mode='over', random_state=None):
        data_samples = labels.shape
        n_labels = len(np.unique(labels))
        label_to_idx_list, label_to_length = [], []
        self.random_state = np.random.RandomState(seed=random_state)
        for lb_idx in range(n_labels):
            label_indexes = np.where(labels == lb_idx)[0]
            self.random_state.shuffle(label_indexes)
            label_to_length.append(len(label_indexes))
            label_to_idx_list.append(label_indexes)

        self.longest_seq = max(label_to_length)
        self.data_source = np.empty((self.longest_seq, len(label_to_length)), dtype=int)
        # Each column represents one "single instance per class" data piece
        for ix, leng in enumerate(label_to_length):
            self.data_source[:leng, ix] = label_to_idx_list[ix]
        self.label_to_length = label_to_length
        self.label_to_idx_list = label_to_idx_list

        if sampling_mode == 'same':
            self.data_length = data_samples
        elif sampling_mode == 'over':  # Sample all items
            self.data_length = np.prod(self.data_source.shape)

    def _resample(self):
        for ix, leng in enumerate(self.label_to_length):
            leftover = self.longest_seq - leng
            random_idxs = np.random.randint(leng, size=leftover)
            self.data_source[leng:, ix] = self.label_to_idx_list[ix][random_idxs]

    def __iter__(self):
        self._resample()
        n_samples = len(self.data_source)
        random_indices = self.random_state.permutation(n_samples)
        data = np.concatenate(
            self.data_source[random_indices])[:self.data_length]
        return iter(data)

    def __len__(self):
        return self.data_length

# %% [markdown]
# ## HeartSoundDataLoader

# %%
class BaseDataLoader(DataLoader):
    """
    Base class for all data loaders
    """
    def __init__(self, dataset, batch_size, shuffle, validation_split, num_workers, collate_fn=default_collate, sampler_type=None):
        self.validation_split = validation_split
        self.shuffle = shuffle

        self.batch_idx = 0
        self.n_samples = len(dataset)
        self.sampler_type = sampler_type
        self.sampler, self.valid_sampler = self._split_sampler(self.validation_split)
        self.init_kwargs = {
            'dataset': dataset,
            'batch_size': batch_size,
            'shuffle': self.shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.sampler, **self.init_kwargs)

    def _split_sampler(self, split):
        if split == 0.0:
            return None, None

        idx_full = np.arange(self.n_samples)

        np.random.seed(0)
        np.random.shuffle(idx_full)

        if isinstance(split, int):
            assert split > 0
            assert split < self.n_samples, "validation set size is configured to be larger than entire dataset."
            len_valid = split
        else:
            len_valid = int(self.n_samples * split)

        valid_idx = idx_full[0:len_valid]
        train_idx = np.delete(idx_full, np.arange(0, len_valid))
        if self.sampler_type == 'MinimumOccupancySampler':
            train_sampler = MinimumOccupancySampler(np.stack(self.label_df.iloc[train_idx]['label']), random_state=100)
        else:
            train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        # turn off shuffle option which is mutually exclusive with sampler
        self.shuffle = False
        self.n_samples = len(train_idx)

        return train_sampler, valid_sampler

    def split_validation(self):
        if self.valid_sampler is None:
            return None
        else:
            return DataLoader(sampler=self.valid_sampler, **self.init_kwargs)

# %%
class HeartSoundDataLoader(DataLoader):
    def __init__(self,
                 fea_path,
                 label_df,
                 duration,
                 batch_size,
                 delta=False,
                 norm=False,
                 shuffle=True,
                 validation_split=0.0,
                 num_workers=1,
                 training=True,
                 collate_fn=None):

        if training:
            # --- ĐOẠN SỬA ĐỔI ĐỂ CHỐNG DATA LEAKAGE ---
            # 1. Tạo cột base_id bằng cách tách bỏ phần '_augX' trong tên file
            # Ví dụ: 'a0001_aug0' -> 'a0001'
            label_df['base_id'] = label_df['filename'].apply(lambda x: Path(x).stem.split('_aug')[0])

            # 2. Lấy danh sách các ID duy nhất (mỗi bệnh nhân chỉ xuất hiện 1 lần trong danh sách này)
            unique_ids = label_df['base_id'].unique()

            # 3. Chia Train/Val dựa trên danh sách ID duy nhất này
            # Điều này đảm bảo tất cả các bản augment của cùng 1 người sẽ nằm cùng 1 tập
            train_ids, val_ids = train_test_split(unique_ids, test_size=validation_split, random_state=100)

            # 4. Lọc lại DataFrame gốc dựa trên danh sách ID đã chia
            self.train_df = label_df[label_df['base_id'].isin(train_ids)].copy()
            self.val_df = label_df[label_df['base_id'].isin(val_ids)].copy()

            # 5. Xóa cột phụ base_id để tránh ảnh hưởng đến các lớp khác
            self.train_df.drop(columns=['base_id'], inplace=True)
            self.val_df.drop(columns=['base_id'], inplace=True)
            # ------------------------------------------

            # Giữ nguyên logic khởi tạo Sampler và Dataset
            self.train_sampler = MinimumOccupancySampler(np.stack(self.train_df['label']), random_state=100)
            self.val_dataset = HeartSoundDataSet(fea_path, self.val_df, duration=duration, training=False, delta=delta, norm=norm)

        else:
            self.train_df = label_df
            self.train_sampler = None

        self.dataset = HeartSoundDataSet(fea_path, self.train_df, duration=duration,
                                         training=training, delta=delta, norm=norm)

        self.init_kwargs = {
            'batch_size': batch_size,
            'shuffle': shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.train_sampler,
                         dataset=self.dataset,
                         **self.init_kwargs)

    def split_validation(self):
        return DataLoader(dataset=self.val_dataset, **self.init_kwargs)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_balanced.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("MFCC (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0001_aug0', 'a0001_aug1', 'a0001_aug2', 'a0002', 'a0002_aug0', 'a0002_aug1', 'a0002_aug2', 'a0003', 'a0003_aug0']
# Batch shape: torch.Size([4, 117, 333])
# Targets: [1 1 1 1]
# Value range: -7.194 ~ 2.585

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features_validation.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_validation.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("Log-Mel Spectrogram (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0002', 'a0003', 'a0004', 'a0005', 'a0006', 'a0007', 'a0008', 'a0009', 'a0010']
# Batch shape: torch.Size([4, 117, 333])
# Targets: [1 0 1 1]
# Value range: -7.711 ~ 3.083

# %% [markdown]
# # ConfigParser

# %%
# parse_config.py
import os
import logging
from pathlib import Path
from datetime import datetime
import argparse
import collections
import importlib.util

class ConfigParser:
    def __init__(self, config_dict, resume=None, modification=None, run_id=None):
        self._config = config_dict
        self.resume = resume

        # Apply CLI modifications
        if modification:
            for key_path, value in modification.items():
                keys = key_path.split(';')
                d = self._config
                for k in keys[:-1]:
                    d = d[k]
                d[keys[-1]] = value

        # Setup save and log directories
        save_dir = Path(self.config['trainer']['save_dir'])
        exper_name = self.config['name']
        if run_id is None:
            run_id = datetime.now().strftime(r'%m%d_%H%M%S')
        self._save_dir = save_dir / 'models' / exper_name / run_id
        self._log_dir = save_dir / 'log' / exper_name / run_id

        self.save_dir.mkdir(parents=True, exist_ok=True)
        self.log_dir.mkdir(parents=True, exist_ok=True)

        # Optional: setup logging
        # setup_logging(self.log_dir)

    @classmethod
    def from_args(cls, parser, options=None):
        """
        parser: argparse.ArgumentParser đã được add_argument xong
        options: list các CustomArgs để override
        """
        if options is None:
            options = []

        # Parse arguments (an toàn cho cả terminal và notebook)
        args = parser.parse_args()

        # Xử lý device
        if args.device is not None:
            os.environ["CUDA_VISIBLE_DEVICES"] = args.device

        # Xử lý resume
        if args.resume is not None:
            resume = Path(args.resume)
            cfg_fname = resume.parent / 'config.py'  # hoặc .json nếu bạn dùng cả 2
        else:
            resume = None
            assert args.config is not None, "Phải chỉ định -c config.py"
            cfg_fname = Path(args.config)

        # Đọc config từ file .py
        if not cfg_fname.exists():
            raise FileNotFoundError(f"Không tìm thấy config file: {cfg_fname}")

        if cfg_fname.suffix == '.py':
            spec = importlib.util.spec_from_file_location("config_module", cfg_fname)
            config_module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(config_module)
            if not hasattr(config_module, 'config'):
                raise ValueError(f"File {cfg_fname} phải định nghĩa biến 'config'")
            config_dict = config_module.config
        else:
            raise ValueError("Chỉ hỗ trợ file config .py")

        # Parse custom CLI overrides
        CustomArgs = collections.namedtuple('CustomArgs', 'flags type target')
        modification = {}
        for opt in options:
            for flag in opt.flags:
                arg_name = flag.lstrip('-').replace('-', '_')
                if hasattr(args, arg_name) and getattr(args, arg_name) is not None:
                    modification[opt.target] = opt.type(getattr(args, arg_name))

        return cls(config_dict, resume, modification)

    def init_obj(self, name, module, *args, **kwargs):
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def init_ftn(self, name, module, *args, **kwargs):
        from functools import partial
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def __getitem__(self, name):
        return self.config[name]

    def get_logger(self, name, verbosity=2):
        logger = logging.getLogger(name)
        logger.setLevel({0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}[verbosity])
        return logger

    @property
    def config(self):
        return self._config

    @property
    def save_dir(self):
        return self._save_dir

    @property
    def log_dir(self):
        return self._log_dir

# %% [markdown]
# # Logging

# %%
def mixup_data(x, y, alpha=0.2):
    """Mixup augmentation"""
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %% [markdown]
# #Loss

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=1.5):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# %%
class CBFocalLoss(nn.Module):
    def __init__(self, samples_per_class, beta=0.9999, gamma=2.0):
        super().__init__()
        effective_num = 1.0 - np.power(beta, samples_per_class)
        weights = (1.0 - beta) / np.array(effective_num)
        self.weights = weights / np.sum(weights) * len(samples_per_class)
        self.gamma = gamma

    def forward(self, inputs, targets):
        weights = torch.tensor(self.weights, device=inputs.device).float()
        ce_loss = F.cross_entropy(inputs, targets, weight=weights, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# Sử dụng:
# samples_per_class = [số_mẫu_abnormal, số_mẫu_normal]

# %%
class WeightedCELoss(nn.Module):
    """
    Weighted Cross Entropy Loss
    """
    def __init__(self, weights):
        super().__init__()
        self.register_buffer(
            "weights", torch.tensor(weights, dtype=torch.float)
        )

    def forward(self, logits, target):
        return F.cross_entropy(
            logits,
            target,
            weight=self.weights
        )

# %%
class CostSensitiveLoss(nn.Module):
    """
    Cost-sensitive Cross Entropy
    FN (abnormal → normal) bị phạt nặng hơn FP
    """
    def __init__(self, fn_cost=2.5, fp_cost=1.0):
        super().__init__()
        self.fn_cost = fn_cost
        self.fp_cost = fp_cost

    def forward(self, logits, target):
        weights = torch.tensor(
            [self.fp_cost, self.fn_cost],
            device=logits.device
        )

        return F.cross_entropy(
            logits,
            target,
            weight=weights
        )

# %%
class CombinedLoss(nn.Module):
    def __init__(self, alpha=0.7, gamma=2.5, label_smoothing=0.1, focal_weight=0.7):
        self.focal_loss = ImprovedFocalLoss(alpha, gamma, label_smoothing)
        self.ce_loss = nn.CrossEntropyLoss(label_smoothing=label_smoothing)

# %%
import torch.nn.functional as F


def nll_loss(output, target):
    return F.nll_loss(output, target)

def ce_loss(output, target):
    return F.cross_entropy(output, target)

def focal_loss(output, target, alpha=0.75, gamma=2.0):
    return FocalLoss(alpha=alpha, gamma=gamma)(output, target)

# Dùng khi tỷ lệ abnormal ≪ normal.
def weighted_ce_loss(output, target, weights):
    return WeightedCELoss(weights)(output, target)

# Đặc biệt phù hợp bài toán y sinh, nơi bỏ sót bệnh (FN) nguy hiểm hơn FP.
def cost_sensitive_loss(output, target, fn_cost=2.5, fp_cost=1.0):
    return CostSensitiveLoss(fn_cost, fp_cost)(output, target)

LOSS_REGISTRY = {
    "ce_loss": lambda: nn.CrossEntropyLoss(),
    "focal_loss": lambda: FocalLoss(alpha=0.75, gamma=2.0),
    "cost_sensitive_loss": lambda: CostSensitiveLoss(fn_cost=2.5, fp_cost=1.0),
    "weighted_ce_loss": lambda weights: WeightedCELoss(weights),
}

# %% [markdown]
# # Metric

# %%
import torch


def accuracy(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
    return correct / len(target)

import torch

def sensitivity(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()
    return tp / (tp + fn + eps)


def f1_score(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)

        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fp = torch.sum((pred == positive_class) & (target != positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()

        precision = tp / (tp + fp + eps)
        recall    = tp / (tp + fn + eps)

        f1 = 2 * precision * recall / (precision + recall + eps)

    return f1

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

# Warmup scheduler
class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, lr_min=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.lr_min = lr_min
        self.base_lr = optimizer.param_groups[0]['lr']

    def step(self, epoch):
        if epoch < self.warmup_epochs:
            lr = self.base_lr * (epoch + 1) / self.warmup_epochs
        else:
            progress = (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs)
            lr = self.lr_min + (self.base_lr - self.lr_min) * 0.5 * (1 + np.cos(np.pi * progress))

        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr
        return lr

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif val_loss > self.best_score - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        else:
            self.best_score = val_loss
            self.counter = 0
        return False

# %% [markdown]
# # Model

# %%
import torch.nn as nn
import numpy as np
from abc import abstractmethod


class BaseModel(nn.Module):
    """
    Base class for all models
    """
    @abstractmethod
    def forward(self, *inputs):
        """
        Forward pass logic

        :return: Model output
        """
        raise NotImplementedError

    def __str__(self):
        """
        Model prints with number of trainable parameters
        """
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        params = sum([np.prod(p.size()) for p in model_parameters])
        return super().__str__() + '\nTrainable parameters: {}'.format(params)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# functions of initializing layers
def init_layer(layer):
    """Initialize a Linear or Convolutional layer."""
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, 'bias'):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)

def init_bn(bn):
    """Initialize a Batchnorm layer."""
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.)

def init_rnn(rnn):
    """init_rnn
    Initialized RNN weights, independent of type GRU/LSTM/RNN
    :param rnn: the rnn model
    """
    for name, param in rnn.named_parameters():
        if 'bias' in name:
            nn.init.constant_(param, 0.0)
        elif 'weight' in name:
            nn.init.xavier_uniform_(param)

def reset_parameters(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            init_layer(module)
        elif isinstance(module, nn.Linear):
            init_layer(module)
        elif isinstance(module, nn.BatchNorm2d):
            init_bn(module)
        elif isinstance(module, nn.LSTM):
            init_rnn(module)

# %% [markdown]
# ## Simple CNN Block

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super().__init__()  # Fix: thiếu dòng này trong code gốc
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Linear(channels, channels // reduction),   # 128→8: 1024 params
            nn.ReLU(),
            nn.Linear(channels // reduction, channels),   # 8→128: 1024 params
            nn.Sigmoid()
        )

    def forward(self, x):  # Fix: thiếu forward() trong code gốc
        B, C, _, _ = x.shape
        s = self.squeeze(x).view(B, C)        # (B, C)
        e = self.excitation(s).view(B, C, 1, 1)  # (B, C, 1, 1)
        return x * e                           # channel-wise scaling


class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size,
                                   stride, padding, groups=in_channels, bias=False)
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU6(inplace=True)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        x = self.bn(x)
        return self.relu(x)

# === THÊM MỚI (chèn sau dòng 1101) ===

class GhostModule(nn.Module):
    """
    Tạo 2*out//2 = out feature maps: nửa từ conv thật, nửa từ depthwise rẻ tiền.
    Tiết kiệm ~50% tham số so với Conv2d thông thường.
    """
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        init_channels = out_channels // 2          # nửa từ conv thật
        ghost_channels = out_channels - init_channels  # nửa còn lại

        # Conv chính: tạo feature maps "thật"
        self.primary = nn.Sequential(
            nn.Conv2d(in_channels, init_channels, kernel_size=1, stride=stride, bias=False),
            nn.BatchNorm2d(init_channels),
            nn.ReLU6(inplace=True)
        )
        # Depthwise: tạo feature maps "ghost" từ primary output
        self.ghost = nn.Sequential(
            nn.Conv2d(init_channels, ghost_channels, kernel_size=3,
                      stride=1, padding=1, groups=init_channels, bias=False),
            nn.BatchNorm2d(ghost_channels),
            nn.ReLU6(inplace=True)
        )

    def forward(self, x):
        p = self.primary(x)         # (B, out//2, H, W)
        g = self.ghost(p)           # (B, out//2, H, W)
        return torch.cat([p, g], dim=1)  # (B, out, H, W)


class ShuffleBlock(nn.Module):
    """
    ShuffleNet V2-style block: split → branch → concat → shuffle.
    Không tốn thêm tham số cho việc trao đổi thông tin giữa các nhóm.
    """
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        self.stride = stride
        branch_channels = out_channels // 2

        if stride == 1:
            # Branch phải: xử lý nửa channels
            self.branch_right = nn.Sequential(
                nn.Conv2d(in_channels // 2, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True),
                nn.Conv2d(branch_channels, branch_channels, 3, stride=1,
                          padding=1, groups=branch_channels, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.Conv2d(branch_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True)
            )
            # Branch trái: identity (không có tham số)
        else:
            # stride=2: cả 2 branch đều có conv để downsample
            self.branch_left = nn.Sequential(
                nn.Conv2d(in_channels, in_channels, 3, stride=stride,
                          padding=1, groups=in_channels, bias=False),
                nn.BatchNorm2d(in_channels),
                nn.Conv2d(in_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True)
            )
            self.branch_right = nn.Sequential(
                nn.Conv2d(in_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True),
                nn.Conv2d(branch_channels, branch_channels, 3, stride=stride,
                          padding=1, groups=branch_channels, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.Conv2d(branch_channels, branch_channels, 1, bias=False),
                nn.BatchNorm2d(branch_channels),
                nn.ReLU6(inplace=True)
            )

    @staticmethod
    def channel_shuffle(x, groups=2):
        """Shuffle channels giữa các group — không tốn tham số."""
        B, C, H, W = x.shape
        x = x.view(B, groups, C // groups, H, W)
        x = x.transpose(1, 2).contiguous()
        return x.view(B, C, H, W)

    def forward(self, x):
        if self.stride == 1:
            # Split: nửa trái identity, nửa phải qua branch
            left, right = x.chunk(2, dim=1)
            out = torch.cat([left, self.branch_right(right)], dim=1)
        else:
            out = torch.cat([self.branch_left(x), self.branch_right(x)], dim=1)

        return self.channel_shuffle(out, groups=2)

# %%
class LightweightHeartSoundCNN(nn.Module):
    """
    Ghost-SE + ShuffleBlock, channel progression: in → 24 → 48 → 96 → 128
    Target: ~25k–35k params
    """
    def __init__(self, num_classes=2, in_channel=1, dropout=0.3):
        super().__init__()
        self.in_channel = in_channel

        # Stem: in_channel → 24
        self.stem = nn.Sequential(
            nn.Conv2d(in_channel, 24, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(24),
            nn.ReLU6(inplace=True)
        )

        # Stage 1: 24 → 48, stride=2
        self.stage1 = ShuffleBlock(24, 48, stride=2)

        # Stage 2: 48 → 96, stride=2
        self.stage2 = ShuffleBlock(48, 96, stride=2)

        # Stage 3: 96 → 128, stride=2
        self.stage3 = ShuffleBlock(96, 128, stride=2)

        self.drop = nn.Dropout2d(0.3)

        # SE block: reduction=16 để tiết kiệm params
        self.se = SEBlock(channels=128, reduction=16)

        # Spatial attention: Conv 128→1
        self.spatial_attn = nn.Sequential(
            nn.Conv2d(128, 1, kernel_size=1, bias=False),
            nn.Sigmoid()
        )

        # Classifier: GAP → FC nhỏ → output
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Sequential(
            nn.Linear(128, 32),
            nn.ReLU6(),
            nn.Dropout(dropout),
            nn.Linear(32, num_classes)
        )

    def forward(self, x):
        B, F, T = x.shape
        x = x.view(B, self.in_channel, F // self.in_channel, T)

        x = self.stem(x)           # (B, 24, H, T)

        x = self.stage1(x)         # (B, 48, H/2, T/2)
        x = self.drop(x)
        x = self.stage2(x)         # (B, 96, H/4, T/4)
        x = self.drop(x)
        x = self.stage3(x)         # (B, 128, H/8, T/8)

        # Channel attention
        x = self.se(x)

        # Spatial attention
        attn = self.spatial_attn(x)
        x = x * attn

        # GAP → FC
        x = x.mean(dim=[2, 3])     # (B, 128)
        x = self.dropout(x)
        return self.classifier(x)

# %% [markdown]
# ## Deeper CNN model, VGG like structure

# %% [markdown]
# ## RNN - BiLTSM

# %% [markdown]
# ## CRNN

# %% [markdown]
# # Config

# %% [markdown]
# ## CNN

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
from pathlib import Path

config_light_cnn = {
    "name": "Physionet_lightweight_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "LightweightHeartSoundCNN",
        "args": {
            "num_classes": 2,
            "in_channel": 3, #Declare channel
            "dropout": 0.4
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "AdamW",
        "args": {
            "lr": 1e-4, #2e-4
            "weight_decay": 1e-3, #0.0
            "amsgrad": False
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "combined_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "CosineAnnealingWarmRestarts",
        "args": {
            "T_0": 20,
            "T_mult": 2,
            "eta_min": 5e-6
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 300,
        "save_dir": str(PROJECT_PATH / "saved"/"lightweight_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_MAcc",
        "early_stop": 30,
        "tensorboard": True,
        "use_mixup": True,
        "mixup_alpha": 0.2,
        "gradient_clip": 1.0
    }
}

# %% [markdown]
# ## CRNN

# %% [markdown]
# ## LTSM

# %% [markdown]
# ## VGG

# %% [markdown]
# # Training

# %%
def prepare_device(n_gpu_use):
    """
    setup GPU device if available. get gpu device indices which are used for DataParallel
    """
    n_gpu = torch.cuda.device_count()
    if n_gpu_use > 0 and n_gpu == 0:
        print("Warning: There\'s no GPU available on this machine,"
              "training will be performed on CPU.")
        n_gpu_use = 0
    if n_gpu_use > n_gpu:
        print(f"Warning: The number of GPU\'s configured to use is {n_gpu_use}, but only {n_gpu} are "
              "available on this machine.")
        n_gpu_use = n_gpu
    device = torch.device('cuda:0' if n_gpu_use > 0 else 'cpu')
    list_ids = list(range(n_gpu_use))
    return device, list_ids

# %%
class MetricTracker:
    def __init__(self, *keys, writer=None):
        self.writer = writer
        self._data = pd.DataFrame(index=keys, columns=['total', 'counts', 'average'])
        self.reset()

    def reset(self):
        for col in self._data.columns:
            self._data[col].values[:] = 0

    def update(self, key, value, n=1):
        if self.writer is not None:
            self.writer.add_scalar(key, value)
        df = self._data

        df.loc[key, "total"] += value * n
        df.loc[key, "counts"] += n
        df.loc[key, "average"] = df.loc[key, "total"] / df.loc[key, "counts"]


    def avg(self, key):
        return self._data.average[key]

    def result(self):
        return dict(self._data.average)

# %%
def setup_logging(save_dir, log_config='logger/logger_config.json', default_level=logging.INFO):
    """
    Setup logging configuration
    """
    log_config = Path(log_config)
    if log_config.is_file():
        config = read_json(log_config)
        # modify logging paths based on run config
        for _, handler in config['handlers'].items():
            if 'filename' in handler:
                handler['filename'] = str(save_dir / handler['filename'])

        logging.config.dictConfig(config)
    else:
        print("Warning: logging configuration file is not found in {}.".format(log_config))
        logging.basicConfig(level=default_level)
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %%
import torch
from abc import abstractmethod
from numpy import inf

def safe_append(lst, value):
    lst.append(value if value is not None else np.nan)

class BaseTrainer:
    """
    Base class for all trainers
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config):
        self.config = config
        self.logger = config.get_logger('trainer', config['trainer']['verbosity'])

        self.model = model
        self.criterion = criterion
        self.metric_ftns = metric_ftns
        self.optimizer = optimizer

        cfg_trainer = config['trainer']
        self.epochs = cfg_trainer['epochs']
        self.save_period = cfg_trainer['save_period']
        self.monitor = cfg_trainer.get('monitor', 'off')

        # configuration to monitor model performance and save best
        if self.monitor == 'off':
            self.mnt_mode = 'off'
            self.mnt_best = 0
        else:
            self.mnt_mode, self.mnt_metric = self.monitor.split()
            assert self.mnt_mode in ['min', 'max']

            self.mnt_best = inf if self.mnt_mode == 'min' else -inf
            self.early_stop = cfg_trainer.get('early_stop', inf)
            if self.early_stop <= 0:
                self.early_stop = inf

        self.start_epoch = 1

        self.checkpoint_dir = config.save_dir

        self.history = {
            "epoch": [],
            "train_loss": [],
            "train_accuracy": [],
            "val_loss": [],
            "val_accuracy": [],
            "val_F1_score": [],
            "val_sensitivity": [],
            "val_specificity": [],
            "val_MAcc": []
        }


        self.history_path = Path(self.checkpoint_dir) / "metrics.csv"

        # setup visualization writer instance
        self.writer = TensorboardWriter(config.log_dir, self.logger, cfg_trainer['tensorboard'])

        if config.resume is not None:
            self._resume_checkpoint(config.resume)

    @abstractmethod
    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Current epoch number
        """
        raise NotImplementedError

    def train(self):
        """
        Full training logic
        """
        not_improved_count = 0
        for epoch in range(self.start_epoch, self.epochs + 1):
            result = self._train_epoch(epoch)

            # save logged informations into log dict
            log = {'epoch': epoch}
            log.update(result)

            # ===== GHI METRICS SAU MỖI EPOCH =====
            safe_append(self.history["epoch"], epoch)
            safe_append(self.history["train_loss"], log.get("loss"))
            safe_append(self.history["train_accuracy"], log.get("accuracy"))

            safe_append(self.history["val_loss"], log.get("val_loss"))
            safe_append(self.history["val_accuracy"], log.get("val_accuracy"))
            safe_append(self.history["val_F1_score"], log.get("val_F1_score"))
            safe_append(self.history["val_sensitivity"], log.get("val_sensitivity"))
            safe_append(self.history["val_specificity"], log.get("val_specificity"))
            safe_append(self.history["val_MAcc"], log.get("val_MAcc"))



            pd.DataFrame(self.history).to_csv(self.history_path, index=False)

            # print logged informations to the screen
            for key, value in log.items():
                self.logger.info('    {:15s}: {}'.format(str(key), value))

            # evaluate model performance according to configured metric, save best checkpoint as model_best
            best = False
            if self.mnt_mode != 'off':
                try:
                    # check whether model performance improved or not, according to specified metric(mnt_metric)
                    improved = (self.mnt_mode == 'min' and log[self.mnt_metric] <= self.mnt_best) or \
                               (self.mnt_mode == 'max' and log[self.mnt_metric] >= self.mnt_best)
                except KeyError:
                    self.logger.warning("Warning: Metric '{}' is not found. "
                                        "Model performance monitoring is disabled.".format(self.mnt_metric))
                    self.mnt_mode = 'off'
                    improved = False

                if improved:
                    self.mnt_best = log[self.mnt_metric]
                    not_improved_count = 0
                    best = True
                else:
                    not_improved_count += 1

                if not_improved_count > self.early_stop:
                    self.logger.info("Validation performance didn\'t improve for {} epochs. "
                                     "Training stops.".format(self.early_stop))
                    break

            if best:
                self._save_best_model(epoch)

    def _save_checkpoint(self, epoch, save_best=False):
        """
        Saving checkpoints

        :param epoch: current epoch number
        :param log: logging information of the epoch
        :param save_best: if True, rename the saved checkpoint to 'model_best.pth'
        """
        arch = type(self.model).__name__
        state = {
            'arch': arch,
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'monitor_best': self.mnt_best,
            'config': self.config
        }
        filename = str(self.checkpoint_dir / 'checkpoint-epoch{}.pth'.format(epoch))
        torch.save(state, filename)
        self.logger.info("Saving checkpoint: {} ...".format(filename))
        if save_best:
            best_path = str(self.checkpoint_dir / 'model_best.pth')
            torch.save(state, best_path)
            self.logger.info("Saving current best: model_best.pth ...")

    def _resume_checkpoint(self, resume_path):
        """
        Resume from saved checkpoints

        :param resume_path: Checkpoint path to be resumed
        """
        resume_path = str(resume_path)
        self.logger.info("Loading checkpoint: {} ...".format(resume_path))
        checkpoint = torch.load(resume_path)
        self.start_epoch = checkpoint['epoch'] + 1
        self.mnt_best = checkpoint['monitor_best']

        # load architecture params from checkpoint.
        if checkpoint['config']['arch'] != self.config['arch']:
            self.logger.warning("Warning: Architecture configuration given in config file is different from that of "
                                "checkpoint. This may yield an exception while state_dict is being loaded.")
        self.model.load_state_dict(checkpoint['state_dict'])

        # load optimizer state from checkpoint only when optimizer type is not changed.
        if checkpoint['config']['optimizer']['type'] != self.config['optimizer']['type']:
            self.logger.warning("Warning: Optimizer type given in config file is different from that of checkpoint. "
                                "Optimizer parameters not being resumed.")
        else:
            self.optimizer.load_state_dict(checkpoint['optimizer'])

        self.logger.info("Checkpoint loaded. Resume training from epoch {}".format(self.start_epoch))

    def _save_best_model(self, epoch):
      """
      Save only the best model according to monitoring metric
      """
      arch = type(self.model).__name__
      state = {
          'arch': arch,
          'epoch': epoch,
          'state_dict': self.model.state_dict(),
          'optimizer': self.optimizer.state_dict(),
          'monitor_best': self.mnt_best,
          'config': self.config
      }

      best_path = self.checkpoint_dir / 'model_best.pth'
      torch.save(state, best_path)

      self.logger.info(
          f"Saving new best model at epoch {epoch}: model_best.pth"
      )

# %%
from itertools import repeat

def inf_loop(data_loader):
    ''' wrapper function for endless data loader. '''
    for loader in repeat(data_loader):
        yield from loader

# %%
class Trainer(BaseTrainer):
    """
    Trainer class
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config, device,
                 data_loader, valid_data_loader=None, lr_scheduler=None, len_epoch=None):
        super().__init__(model, criterion, metric_ftns, optimizer, config)
        self.config = config
        self.device = device
        self.data_loader = data_loader
        if len_epoch is None:
            # epoch-based training
            self.len_epoch = len(self.data_loader)
        else:
            # iteration-based training
            self.data_loader = inf_loop(data_loader)
            self.len_epoch = len_epoch
        self.valid_data_loader = valid_data_loader
        self.do_validation = self.valid_data_loader is not None
        self.lr_scheduler = lr_scheduler

        cfg_trainer = config['trainer']
        self.use_mixup = cfg_trainer.get("use_mixup", False)
        self.mixup_alpha = cfg_trainer.get("mixup_alpha", 0.2)
        self.gradient_clip = cfg_trainer.get("gradient_clip", 0.0)

        self.log_step = int(np.sqrt(data_loader.batch_size))

        self.train_metrics = MetricTracker('loss', *[m.__name__ for m in self.metric_ftns], writer=self.writer)
        self.valid_metrics = MetricTracker('loss',*[m.__name__ for m in self.metric_ftns],
                                           'sensitivity', 'specificity', 'MAcc', 'F1_score',
                                           writer = self.writer)


    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains average loss and metric in this epoch.
        """
        self.model.train()
        self.train_metrics.reset()
        for batch_idx, (data, target) in enumerate(self.data_loader):
            data, target = data.to(self.device), target.to(self.device)

            self.optimizer.zero_grad()

            if self.use_mixup and np.random.rand() > 0.5:
                data, targets_a, targets_b, lam = mixup_data(data, target, alpha=0.2)
                output = self.model(data)
                loss = mixup_criterion(self.criterion, output, targets_a, targets_b, lam)
            else:
                output = self.model(data)
                loss = self.criterion(output, target)

            loss.backward()
            if self.gradient_clip > 0:
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.gradient_clip)

            self.optimizer.step()
            if hasattr(self, 'ema'):
                self.ema.update()


            self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
            self.train_metrics.update('loss', loss.item())
            for met in self.metric_ftns:
                self.train_metrics.update(met.__name__, met(output, target))

            if batch_idx % self.log_step == 0:
                self.logger.debug('Train Epoch: {} {} Loss: {:.6f}'.format(
                    epoch,
                    self._progress(batch_idx),
                    loss.item()))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

            if batch_idx == self.len_epoch:
                break
        log = self.train_metrics.result()

        if self.do_validation:
            val_log = self._valid_epoch(epoch)
            log.update(**{'val_'+k : v for k, v in val_log.items()})

        #if self.lr_scheduler is not None:
            #self.lr_scheduler.step()

        if self.lr_scheduler is not None:
            if isinstance(self.lr_scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                # ReduceLROnPlateau cần metric để theo dõi (thường là val_loss)
                # Lấy giá trị 'loss' từ kết quả của hàm _valid_epoch
                self.lr_scheduler.step(val_log.get('MAcc', val_log['loss']))
            else:
                # Các scheduler khác như StepLR không cần tham số
                self.lr_scheduler.step()
        return log

    def _valid_epoch(self, epoch):
        """
        Validate after training an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains information about validation
        """
        self.model.eval()
        self.valid_metrics.reset()
        val_pred_pos = 0
        val_pred_neg = 0
        val_condition_pos = 0
        val_condition_neg = 0
        val_TP = 0
        val_TN = 0
        val_correct = 0
        val_total = 0
        use_ema = hasattr(self, 'ema')
        if use_ema:
            self.ema.apply_shadow()
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(self.valid_data_loader):
                data, target = data.to(self.device), target.to(self.device)
                output = self.model(data.float())
                loss = self.criterion(output, target)

                _,indices = torch.max(output, 1)

                pred_pos_idx = [i for i, x in enumerate(indices) if x == 1]
                condition_pos_idx = [i for i, x in enumerate(target) if x == 1]
                pred_neg_idx = [i for i, x in enumerate(indices) if x == 0]
                condition_neg_idx = [i for i, x in enumerate(target) if x == 0]

                val_pred_pos += len(pred_pos_idx)
                val_condition_pos += len(condition_pos_idx)
                val_pred_neg += len(pred_neg_idx)
                val_condition_neg += len(condition_neg_idx)
                val_TP += len([x for x in pred_pos_idx if x in condition_pos_idx])
                val_TN += len([x for x in pred_neg_idx if x in condition_neg_idx])
                correct = (indices == target).float()
                val_correct += torch.sum(correct).item()
                val_total += target.shape[0]

                self.writer.set_step((epoch - 1) * len(self.valid_data_loader) + batch_idx, 'valid')
                self.valid_metrics.update('loss', loss.item())
                for met in self.metric_ftns:
                    self.valid_metrics.update(met.__name__, met(output, target))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

        sensitivity = val_TP / val_condition_pos
        specificity = val_TN / val_condition_neg
        MAcc= (sensitivity + specificity) / 2
        if val_pred_pos == 0:
            precision = 0
            F1_score = 0
        else:
            precision = val_TP / val_pred_pos
            F1_score = 2 * (precision*sensitivity)/(precision+sensitivity)

        self.valid_metrics.update('sensitivity', sensitivity)
        self.valid_metrics.update('specificity', specificity)
        self.valid_metrics.update('MAcc',MAcc)
        self.valid_metrics.update('F1_score', F1_score)

        # add histogram of model parameters to the tensorboard
        for name, p in self.model.named_parameters():
            self.writer.add_histogram(name, p, bins='auto')

        if use_ema:
            self.ema.restore()

        return self.valid_metrics.result()

    def _progress(self, batch_idx):
        base = '[{}/{} ({:.0f}%)]'
        if hasattr(self.data_loader, 'n_samples'):
            current = batch_idx * self.data_loader.batch_size
            total = self.data_loader.n_samples
        else:
            current = batch_idx
            total = self.len_epoch
        return base.format(current, total, 100.0 * current / total)

# %% [markdown]
# ## Simple Train

# %%
#current_config = config_cnn
current_config  = config_light_cnn
#current_config = config_crnn
#current_config = config_lstm
#current_config = config_vgg

# %%
class EMA:
    def __init__(self, model, decay=0.999):
        self.model = model
        self.decay = decay
        self.shadow = {k: v.clone() for k, v in model.state_dict().items()}

    def update(self):
        for k, v in self.model.state_dict().items():
            self.shadow[k] = self.decay * self.shadow[k] + (1 - self.decay) * v

    def apply_shadow(self):
        self._backup = {k: v.clone() for k, v in self.model.state_dict().items()}
        self.model.load_state_dict(self.shadow)

    def restore(self):
        self.model.load_state_dict(self._backup)

# %%
# === THÊM MỚI trước def main() ===
from torch.optim.swa_utils import AveragedModel, SWALR

def apply_swa(model, data_loader, device, swa_epochs=20, swa_lr=1e-4):
    """
    Chạy SWA: train thêm swa_epochs với lr thấp, lấy trung bình weights.
    Gọi sau trainer.train() hoàn tất.
    """
    swa_model = AveragedModel(model)
    swa_scheduler = SWALR(
        torch.optim.AdamW(model.parameters(), lr=swa_lr),
        swa_lr=swa_lr
    )
    model.train()
    for epoch in range(swa_epochs):
        for data, target in data_loader:
            data, target = data.to(device).float(), target.to(device)
            pred = model(data)
            loss = nn.CrossEntropyLoss(label_smoothing=0.05)(pred, target)
            loss.backward()
            swa_scheduler.step()
        swa_model.update_parameters(model)

    # Cập nhật BatchNorm statistics cho SWA model
    torch.optim.swa_utils.update_bn(data_loader, swa_model, device=device)
    return swa_model

# %%
import os
import argparse
import collections
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

def main(config):

# Tạo ConfigParser từ biến config hiện tại
  config_parser = ConfigParser(config)

  # Train chính thức
  data_loader = config_parser.init_obj('data_loader', globals())  # hoặc import module phù hợp
  valid_data_loader = data_loader.split_validation()

  model = config_parser.init_obj('arch', globals())
  print(model)

  device, device_ids = prepare_device(config_parser['n_gpu'])
  model = model.to(device)
  if len(device_ids) > 1:
      model = torch.nn.DataParallel(model, device_ids=device_ids)

  #criterion = FocalLoss(alpha=0.25, gamma=2.0)
  #criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
  criterion = nn.CrossEntropyLoss(
      weight=torch.tensor([1.0, 1.0]).to(device),  # Index 0 (Normal): 1.0, Index 1 (Abnormal): 2.5
      label_smoothing=0.05
  )
  #criterion = LOSS_REGISTRY["weighted_ce_loss"]([1.0, 2.5])
  metrics = [
      accuracy,
      f1_score
  ]

  optimizer = config_parser.init_obj('optimizer', torch.optim, filter(lambda p: p.requires_grad, model.parameters()))
  lr_scheduler = config_parser.init_obj('lr_scheduler', torch.optim.lr_scheduler, optimizer)

  trainer = Trainer(
      model=model,
      criterion=criterion,
      metric_ftns=metrics,
      optimizer=optimizer,
      config=config_parser,
      device=device,
      data_loader=data_loader,
      valid_data_loader=valid_data_loader,
      lr_scheduler=lr_scheduler
  )

  trainer.train()

  base_dir = (Path(config_parser['trainer']['save_dir'])/ "models"/ config_parser['name'])

  if not base_dir.exists():
    print("Models directory was not found.")
    return

  # Lấy run (timestamp) mới nhất
  latest_run = max(base_dir.iterdir(), key=os.path.getmtime)

  best_model_path = latest_run / "model_best.pth"

  if best_model_path.exists():
    print("\n=== HOÀN THÀNH TRAINING ===")
    print("Model tốt nhất được lưu tại:")
    print(best_model_path)
  else:
    print("The file 'model_best.pth' was not found.")

  metrics_path = Path(config_parser.save_dir) / "metrics.csv"

  if metrics_path.exists():
    df = pd.read_csv(metrics_path)
    epochs = df["epoch"]
  else:
    print("The file 'metrics.csv' was not found. Unable to display training results.")

  # ===== LOSS =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training and Validation Loss")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "loss_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== ACCURACY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_accuracy"], label="Training Accuracy")
  plt.plot(epochs, df["val_accuracy"], label="Validation Accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training and Validation Accuracy")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "accuracy_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== F1-SCORE =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_F1_score"], label="Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.title("Validation F1-score across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "f1_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== SENSITIVITY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_sensitivity"], label="Validation Sensitivity")
  plt.xlabel("Epoch")
  plt.ylabel("Sensitivity")
  plt.title("Validation Sensitivity across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "sensitivity_curve.png", dpi=300)
  plt.show()
  plt.close()

# %%
if __name__ == "__main__":
    # Train model với config hiện tại
    main(current_config)

    # Sau khi train xong, tự động test trên tập validation riêng (nếu có file)
    base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
# Out:
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (stage1): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage2): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage3): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (drop): Dropout2d(p=0.3, inplace=False)
#   (se): SEBlock(
#     (squeeze): AdaptiveAvgPool2d(output_size=1)
#     (excitation): Sequential(
#       (0): Linear(in_features=128, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (spatial_attn): Sequential(
#     (0): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): Sigmoid()
#   )
#   (dropout): Dropout(p=0.4, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU6()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
# DEBUG:trainer:Train Epoch: 1 [0/66 (0%)] Loss: 0.690846
# DEBUG:trainer:Train Epoch: 1 [8/66 (12%)] Loss: 0.696236
# DEBUG:trainer:Train Epoch: 1 [16/66 (24%)] Loss: 0.694239
# DEBUG:trainer:Train Epoch: 1 [24/66 (36%)] Loss: 0.691039
# DEBUG:trainer:Train Epoch: 1 [32/66 (48%)] Loss: 0.696115
# DEBUG:trainer:Train Epoch: 1 [40/66 (61%)] Loss: 0.688617
# DEBUG:trainer:Train Epoch: 1 [48/66 (73%)] Loss: 0.688187
# DEBUG:trainer:Train Epoch: 1 [56/66 (85%)] Loss: 0.686418
# DEBUG:trainer:Train Epoch: 1 [64/66 (97%)] Loss: 0.691970
# INFO:trainer:    epoch          : 1
# INFO:trainer:    loss           : 0.6929391170992996
# INFO:trainer:    accuracy       : 0.5075757575757576
# INFO:trainer:    f1_score       : 0.13780799178655442
# INFO:trainer:    val_loss       : 0.6922974621548372
# INFO:trainer:    val_accuracy   : 0.475
# INFO:trainer:    val_f1_score   : 0.0
# INFO:trainer:    val_sensitivity: 0.0
# INFO:trainer:    val_specificity: 1.0
# INFO:trainer:    val_MAcc       : 0.5
# INFO:trainer:    val_F1_score   : 0.0
# INFO:trainer:Saving new best model at epoch 1: model_best.pth
# DEBUG:trainer:Train Epoch: 2 [0/66 (0%)] Loss: 0.682699
# DEBUG:trainer:Train Epoch: 2 [8/66 (12%)] Loss: 0.690982
# DEBUG:trainer:Train Epoch: 2 [16/66 (24%)] Loss: 0.676864
# DEBUG:trainer:Train Epoch: 2 [24/66 (36%)] Loss: 0.697298
# DEBUG:trainer:Train Epoch: 2 [32/66 (48%)] Loss: 0.687190
# DEBUG:trainer:Train Epoch: 2 [40/66 (61%)] Loss: 0.688607
# DEBUG:trainer:Train Epoch: 2 [48/66 (73%)] Loss: 0.684239
# DEBUG:trainer:Train Epoch: 2 [56/66 (85%)] Loss: 0.698610
# DEBUG:trainer:Train Epoch: 2 [64/66 (97%)] Loss: 0.689466
# INFO:trainer:    epoch          : 2
# INFO:trainer:    loss           : 0.6885876240152301
# INFO:trainer:    accuracy       : 0.5338541666666666
# INFO:trainer:    f1_score       : 0.35131639322776137
# INFO:trainer:    val_loss       : 0.6826845232178184
# INFO:trainer:    val_accuracy   : 0.6220588235294118
# INFO:trainer:    val_f1_score   : 0.53065383884137
# INFO:trainer:    val_sensitivity: 0.44525547445255476
# INFO:trainer:    val_specificity: 0.8356164383561644
# INFO:trainer:    val_MAcc       : 0.6404359564043596
# INFO:trainer:    val_F1_score   : 0.5570776255707762
# INFO:trainer:Saving new best model at epoch 2: model_best.pth
# DEBUG:trainer:Train Epoch: 3 [0/66 (0%)] Loss: 0.677274
# DEBUG:trainer:Train Epoch: 3 [8/66 (12%)] Loss: 0.681009
# DEBUG:trainer:Train Epoch: 3 [16/66 (24%)] Loss: 0.665223
# DEBUG:trainer:Train Epoch: 3 [24/66 (36%)] Loss: 0.673138
# DEBUG:trainer:Train Epoch: 3 [32/66 (48%)] Loss: 0.675201
# DEBUG:trainer:Train Epoch: 3 [40/66 (61%)] Loss: 0.674189
# DEBUG:trainer:Train Epoch: 3 [48/66 (73%)] Loss: 0.678453
# DEBUG:trainer:Train Epoch: 3 [56/66 (85%)] Loss: 0.650888
# DEBUG:trainer:Train Epoch: 3 [64/66 (97%)] Loss: 0.657364
# INFO:trainer:    epoch          : 3
# INFO:trainer:    loss           : 0.6745513406666842
# INFO:trainer:    accuracy       : 0.6046401515151515
# INFO:trainer:    f1_score       : 0.552673786760038
# INFO:trainer:    val_loss       : 0.6585824384408838
# INFO:trainer:    val_accuracy   : 0.7700367647058823
# INFO:trainer:    val_f1_score   : 0.7719315726776302
# INFO:trainer:    val_sensitivity: 0.8540145985401459
# INFO:trainer:    val_specificity: 0.7123287671232876
# INFO:trainer:    val_MAcc       : 0.7831716828317168
# INFO:trainer:    val_F1_score   : 0.8048151332760103
# INFO:trainer:Saving new best model at epoch 3: model_best.pth
# DEBUG:trainer:Train Epoch: 4 [0/66 (0%)] Loss: 0.656449
# DEBUG:trainer:Train Epoch: 4 [8/66 (12%)] Loss: 0.670278
# DEBUG:trainer:Train Epoch: 4 [16/66 (24%)] Loss: 0.655671
# DEBUG:trainer:Train Epoch: 4 [24/66 (36%)] Loss: 0.642832
# DEBUG:trainer:Train Epoch: 4 [32/66 (48%)] Loss: 0.660564
# DEBUG:trainer:Train Epoch: 4 [40/66 (61%)] Loss: 0.640496
# DEBUG:trainer:Train Epoch: 4 [48/66 (73%)] Loss: 0.612633
# DEBUG:trainer:Train Epoch: 4 [56/66 (85%)] Loss: 0.656080
# DEBUG:trainer:Train Epoch: 4 [64/66 (97%)] Loss: 0.631963
# INFO:trainer:    epoch          : 4
# INFO:trainer:    loss           : 0.6443173903407473
# INFO:trainer:    accuracy       : 0.6796875
# INFO:trainer:    f1_score       : 0.6886523442011065
# INFO:trainer:    val_loss       : 0.6148400271640104
# INFO:trainer:    val_accuracy   : 0.7767594537815127
# INFO:trainer:    val_f1_score   : 0.7869619238120189
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.7123287671232876
# INFO:trainer:    val_MAcc       : 0.7868213178682131
# INFO:trainer:    val_F1_score   : 0.8089117395029991
# INFO:trainer:Saving new best model at epoch 4: model_best.pth
# DEBUG:trainer:Train Epoch: 5 [0/66 (0%)] Loss: 0.631074
# DEBUG:trainer:Train Epoch: 5 [8/66 (12%)] Loss: 0.638250
# DEBUG:trainer:Train Epoch: 5 [16/66 (24%)] Loss: 0.628288
# DEBUG:trainer:Train Epoch: 5 [24/66 (36%)] Loss: 0.598660
# DEBUG:trainer:Train Epoch: 5 [32/66 (48%)] Loss: 0.586504
# DEBUG:trainer:Train Epoch: 5 [40/66 (61%)] Loss: 0.596502
# DEBUG:trainer:Train Epoch: 5 [48/66 (73%)] Loss: 0.556878
# DEBUG:trainer:Train Epoch: 5 [56/66 (85%)] Loss: 0.544804
# DEBUG:trainer:Train Epoch: 5 [64/66 (97%)] Loss: 0.570624
# INFO:trainer:    epoch          : 5
# INFO:trainer:    loss           : 0.6041961763844346
# INFO:trainer:    accuracy       : 0.6863162878787878
# INFO:trainer:    f1_score       : 0.7004198416547329
# INFO:trainer:    val_loss       : 0.5654365823549383
# INFO:trainer:    val_accuracy   : 0.7831932773109244
# INFO:trainer:    val_f1_score   : 0.7949586328878679
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.726027397260274
# INFO:trainer:    val_MAcc       : 0.7936706329367063
# INFO:trainer:    val_F1_score   : 0.8137931034482758
# INFO:trainer:Saving new best model at epoch 5: model_best.pth
# DEBUG:trainer:Train Epoch: 6 [0/66 (0%)] Loss: 0.522714
# DEBUG:trainer:Train Epoch: 6 [8/66 (12%)] Loss: 0.574338
# DEBUG:trainer:Train Epoch: 6 [16/66 (24%)] Loss: 0.555444
# DEBUG:trainer:Train Epoch: 6 [24/66 (36%)] Loss: 0.685003
# DEBUG:trainer:Train Epoch: 6 [32/66 (48%)] Loss: 0.573190
# DEBUG:trainer:Train Epoch: 6 [40/66 (61%)] Loss: 0.518711
# DEBUG:trainer:Train Epoch: 6 [48/66 (73%)] Loss: 0.552227
# DEBUG:trainer:Train Epoch: 6 [56/66 (85%)] Loss: 0.503123
# DEBUG:trainer:Train Epoch: 6 [64/66 (97%)] Loss: 0.548438
# INFO:trainer:    epoch          : 6
# INFO:trainer:    loss           : 0.5650242530938351
# INFO:trainer:    accuracy       : 0.7161458333333334
# INFO:trainer:    f1_score       : 0.7314885287527345
# INFO:trainer:    val_loss       : 0.5288011291447807
# INFO:trainer:    val_accuracy   : 0.7896271008403362
# INFO:trainer:    val_f1_score   : 0.8023686840806484
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.7240704500978473
# INFO:trainer:    val_MAcc       : 0.7999914294284858
# INFO:trainer:    val_F1_score   : 0.8212147134302822
# INFO:trainer:Saving new best model at epoch 6: model_best.pth
# DEBUG:trainer:Train Epoch: 7 [0/66 (0%)] Loss: 0.483174
# DEBUG:trainer:Train Epoch: 7 [8/66 (12%)] Loss: 0.483084
# DEBUG:trainer:Train Epoch: 7 [16/66 (24%)] Loss: 0.573810
# DEBUG:trainer:Train Epoch: 7 [24/66 (36%)] Loss: 0.477302
# DEBUG:trainer:Train Epoch: 7 [32/66 (48%)] Loss: 0.536836
# DEBUG:trainer:Train Epoch: 7 [40/66 (61%)] Loss: 0.517198
# DEBUG:trainer:Train Epoch: 7 [48/66 (73%)] Loss: 0.542463
# DEBUG:trainer:Train Epoch: 7 [56/66 (85%)] Loss: 0.505968
# DEBUG:trainer:Train Epoch: 7 [64/66 (97%)] Loss: 0.475489
# INFO:trainer:    epoch          : 7
# INFO:trainer:    loss           : 0.5352748867237207
# INFO:trainer:    accuracy       : 0.7057291666666666
# INFO:trainer:    f1_score       : 0.7257314865837433
# INFO:trainer:    val_loss       : 0.5046788874794456
# INFO:trainer:    val_accuracy   : 0.79359243697479
# INFO:trainer:    val_f1_score   : 0.8102808847012891
# INFO:trainer:    val_sensitivity: 0.8832116788321168
# INFO:trainer:    val_specificity: 0.7181996086105675
# INFO:trainer:    val_MAcc       : 0.8007056437213422
# INFO:trainer:    val_F1_score   : 0.8231292517006802
# INFO:trainer:Saving new best model at epoch 7: model_best.pth
# DEBUG:trainer:Train Epoch: 8 [0/66 (0%)] Loss: 0.512364
# DEBUG:trainer:Train Epoch: 8 [8/66 (12%)] Loss: 0.610392
# DEBUG:trainer:Train Epoch: 8 [16/66 (24%)] Loss: 0.499795
# DEBUG:trainer:Train Epoch: 8 [24/66 (36%)] Loss: 0.511423
# DEBUG:trainer:Train Epoch: 8 [32/66 (48%)] Loss: 0.603029
# DEBUG:trainer:Train Epoch: 8 [40/66 (61%)] Loss: 0.425491
# DEBUG:trainer:Train Epoch: 8 [48/66 (73%)] Loss: 0.513587
# DEBUG:trainer:Train Epoch: 8 [56/66 (85%)] Loss: 0.413337
# DEBUG:trainer:Train Epoch: 8 [64/66 (97%)] Loss: 0.632512
# INFO:trainer:    epoch          : 8
# INFO:trainer:    loss           : 0.5171840421178124
# INFO:trainer:    accuracy       : 0.7346117424242424
# INFO:trainer:    f1_score       : 0.7535369785269712
# INFO:trainer:    val_loss       : 0.4887719259542577
# INFO:trainer:    val_accuracy   : 0.7917542016806722
# INFO:trainer:    val_f1_score   : 0.8065389894519724
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.7064579256360078
# INFO:trainer:    val_MAcc       : 0.7984844372705586
# INFO:trainer:    val_F1_score   : 0.8229342327150084
# DEBUG:trainer:Train Epoch: 9 [0/66 (0%)] Loss: 0.556537
# DEBUG:trainer:Train Epoch: 9 [8/66 (12%)] Loss: 0.439451
# DEBUG:trainer:Train Epoch: 9 [16/66 (24%)] Loss: 0.525895
# DEBUG:trainer:Train Epoch: 9 [24/66 (36%)] Loss: 0.456087
# DEBUG:trainer:Train Epoch: 9 [32/66 (48%)] Loss: 0.545870
# DEBUG:trainer:Train Epoch: 9 [40/66 (61%)] Loss: 0.508668
# DEBUG:trainer:Train Epoch: 9 [48/66 (73%)] Loss: 0.460925
# DEBUG:trainer:Train Epoch: 9 [56/66 (85%)] Loss: 0.398405
# DEBUG:trainer:Train Epoch: 9 [64/66 (97%)] Loss: 0.456744
# INFO:trainer:    epoch          : 9
# INFO:trainer:    loss           : 0.49866669557311316
# INFO:trainer:    accuracy       : 0.7043087121212122
# INFO:trainer:    f1_score       : 0.722945634384177
# INFO:trainer:    val_loss       : 0.47691985789467306
# INFO:trainer:    val_accuracy   : 0.8039915966386555
# INFO:trainer:    val_f1_score   : 0.8228021413513069
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7103718199608611
# INFO:trainer:    val_MAcc       : 0.807740654505978
# INFO:trainer:    val_F1_score   : 0.8322147651006713
# INFO:trainer:Saving new best model at epoch 9: model_best.pth
# DEBUG:trainer:Train Epoch: 10 [0/66 (0%)] Loss: 0.479209
# DEBUG:trainer:Train Epoch: 10 [8/66 (12%)] Loss: 0.533338
# DEBUG:trainer:Train Epoch: 10 [16/66 (24%)] Loss: 0.495050
# DEBUG:trainer:Train Epoch: 10 [24/66 (36%)] Loss: 0.512724
# DEBUG:trainer:Train Epoch: 10 [32/66 (48%)] Loss: 0.389924
# DEBUG:trainer:Train Epoch: 10 [40/66 (61%)] Loss: 0.448101
# DEBUG:trainer:Train Epoch: 10 [48/66 (73%)] Loss: 0.487886
# DEBUG:trainer:Train Epoch: 10 [56/66 (85%)] Loss: 0.510485
# DEBUG:trainer:Train Epoch: 10 [64/66 (97%)] Loss: 0.490893
# INFO:trainer:    epoch          : 10
# INFO:trainer:    loss           : 0.4988306783365481
# INFO:trainer:    accuracy       : 0.7391098484848485
# INFO:trainer:    f1_score       : 0.7582696663795309
# INFO:trainer:    val_loss       : 0.4720386722508599
# INFO:trainer:    val_accuracy   : 0.8003151260504202
# INFO:trainer:    val_f1_score   : 0.8178709421928088
# INFO:trainer:    val_sensitivity: 0.8832116788321168
# INFO:trainer:    val_specificity: 0.726027397260274
# INFO:trainer:    val_MAcc       : 0.8046195380461953
# INFO:trainer:    val_F1_score   : 0.8259385665529011
# DEBUG:trainer:Train Epoch: 11 [0/66 (0%)] Loss: 0.577736
# DEBUG:trainer:Train Epoch: 11 [8/66 (12%)] Loss: 0.465937
# DEBUG:trainer:Train Epoch: 11 [16/66 (24%)] Loss: 0.545923
# DEBUG:trainer:Train Epoch: 11 [24/66 (36%)] Loss: 0.352664
# DEBUG:trainer:Train Epoch: 11 [32/66 (48%)] Loss: 0.422445
# DEBUG:trainer:Train Epoch: 11 [40/66 (61%)] Loss: 0.440861
# DEBUG:trainer:Train Epoch: 11 [48/66 (73%)] Loss: 0.484017
# DEBUG:trainer:Train Epoch: 11 [56/66 (85%)] Loss: 0.668820
# DEBUG:trainer:Train Epoch: 11 [64/66 (97%)] Loss: 0.542804
# INFO:trainer:    epoch          : 11
# INFO:trainer:    loss           : 0.4953683352831638
# INFO:trainer:    accuracy       : 0.7379261363636364
# INFO:trainer:    f1_score       : 0.7559726995754189
# INFO:trainer:    val_loss       : 0.4647875112645766
# INFO:trainer:    val_accuracy   : 0.8025997899159664
# INFO:trainer:    val_f1_score   : 0.8212180900974753
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.7181996086105675
# INFO:trainer:    val_MAcc       : 0.8043552787578385
# INFO:trainer:    val_F1_score   : 0.8271186440677967
# DEBUG:trainer:Train Epoch: 12 [0/66 (0%)] Loss: 0.455353
# DEBUG:trainer:Train Epoch: 12 [8/66 (12%)] Loss: 0.470164
# DEBUG:trainer:Train Epoch: 12 [16/66 (24%)] Loss: 0.483088
# DEBUG:trainer:Train Epoch: 12 [24/66 (36%)] Loss: 0.498716
# DEBUG:trainer:Train Epoch: 12 [32/66 (48%)] Loss: 0.462083
# DEBUG:trainer:Train Epoch: 12 [40/66 (61%)] Loss: 0.685158
# DEBUG:trainer:Train Epoch: 12 [48/66 (73%)] Loss: 0.416738
# DEBUG:trainer:Train Epoch: 12 [56/66 (85%)] Loss: 0.547920
# DEBUG:trainer:Train Epoch: 12 [64/66 (97%)] Loss: 0.389289
# INFO:trainer:    epoch          : 12
# INFO:trainer:    loss           : 0.4810087143471747
# INFO:trainer:    accuracy       : 0.7488162878787878
# INFO:trainer:    f1_score       : 0.7682657770443289
# INFO:trainer:    val_loss       : 0.4615600065273397
# INFO:trainer:    val_accuracy   : 0.8117909663865546
# INFO:trainer:    val_f1_score   : 0.8333386810958083
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7142857142857143
# INFO:trainer:    val_MAcc       : 0.8133472367049009
# INFO:trainer:    val_F1_score   : 0.8375209380234506
# INFO:trainer:Saving new best model at epoch 12: model_best.pth
# DEBUG:trainer:Train Epoch: 13 [0/66 (0%)] Loss: 0.437930
# DEBUG:trainer:Train Epoch: 13 [8/66 (12%)] Loss: 0.532690
# DEBUG:trainer:Train Epoch: 13 [16/66 (24%)] Loss: 0.541127
# DEBUG:trainer:Train Epoch: 13 [24/66 (36%)] Loss: 0.369312
# DEBUG:trainer:Train Epoch: 13 [32/66 (48%)] Loss: 0.409576
# DEBUG:trainer:Train Epoch: 13 [40/66 (61%)] Loss: 0.470157
# DEBUG:trainer:Train Epoch: 13 [48/66 (73%)] Loss: 0.497477
# DEBUG:trainer:Train Epoch: 13 [56/66 (85%)] Loss: 0.472058
# DEBUG:trainer:Train Epoch: 13 [64/66 (97%)] Loss: 0.463486
# INFO:trainer:    epoch          : 13
# INFO:trainer:    loss           : 0.47480014824506006
# INFO:trainer:    accuracy       : 0.7450284090909091
# INFO:trainer:    f1_score       : 0.7624945384210177
# INFO:trainer:    val_loss       : 0.4573182077968822
# INFO:trainer:    val_accuracy   : 0.8059611344537815
# INFO:trainer:    val_f1_score   : 0.8253817662485515
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7142857142857143
# INFO:trainer:    val_MAcc       : 0.8060479666319083
# INFO:trainer:    val_F1_score   : 0.8296795952782462
# DEBUG:trainer:Train Epoch: 14 [0/66 (0%)] Loss: 0.481334
# DEBUG:trainer:Train Epoch: 14 [8/66 (12%)] Loss: 0.417519
# DEBUG:trainer:Train Epoch: 14 [16/66 (24%)] Loss: 0.606683
# DEBUG:trainer:Train Epoch: 14 [24/66 (36%)] Loss: 0.555349
# DEBUG:trainer:Train Epoch: 14 [32/66 (48%)] Loss: 0.592501
# DEBUG:trainer:Train Epoch: 14 [40/66 (61%)] Loss: 0.585645
# DEBUG:trainer:Train Epoch: 14 [48/66 (73%)] Loss: 0.533848
# DEBUG:trainer:Train Epoch: 14 [56/66 (85%)] Loss: 0.556573
# DEBUG:trainer:Train Epoch: 14 [64/66 (97%)] Loss: 0.423871
# INFO:trainer:    epoch          : 14
# INFO:trainer:    loss           : 0.4861593779289361
# INFO:trainer:    accuracy       : 0.7154356060606061
# INFO:trainer:    f1_score       : 0.7343132661052648
# INFO:trainer:    val_loss       : 0.45528628457995024
# INFO:trainer:    val_accuracy   : 0.8123949579831933
# INFO:trainer:    val_f1_score   : 0.8306302890533198
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7123287671232876
# INFO:trainer:    val_MAcc       : 0.8123687631236876
# INFO:trainer:    val_F1_score   : 0.8368200836820083
# DEBUG:trainer:Train Epoch: 15 [0/66 (0%)] Loss: 0.580057
# DEBUG:trainer:Train Epoch: 15 [8/66 (12%)] Loss: 0.391927
# DEBUG:trainer:Train Epoch: 15 [16/66 (24%)] Loss: 0.462608
# DEBUG:trainer:Train Epoch: 15 [24/66 (36%)] Loss: 0.492550
# DEBUG:trainer:Train Epoch: 15 [32/66 (48%)] Loss: 0.465567
# DEBUG:trainer:Train Epoch: 15 [40/66 (61%)] Loss: 0.481793
# DEBUG:trainer:Train Epoch: 15 [48/66 (73%)] Loss: 0.427269
# DEBUG:trainer:Train Epoch: 15 [56/66 (85%)] Loss: 0.487707
# DEBUG:trainer:Train Epoch: 15 [64/66 (97%)] Loss: 0.492129
# INFO:trainer:    epoch          : 15
# INFO:trainer:    loss           : 0.4817941509412997
# INFO:trainer:    accuracy       : 0.7466856060606061
# INFO:trainer:    f1_score       : 0.7642685969415051
# INFO:trainer:    val_loss       : 0.45460933359230266
# INFO:trainer:    val_accuracy   : 0.8142331932773109
# INFO:trainer:    val_f1_score   : 0.8361787116118258
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7162426614481409
# INFO:trainer:    val_MAcc       : 0.8143257102861142
# INFO:trainer:    val_F1_score   : 0.8382229673093043
# INFO:trainer:Saving new best model at epoch 15: model_best.pth
# DEBUG:trainer:Train Epoch: 16 [0/66 (0%)] Loss: 0.513728
# DEBUG:trainer:Train Epoch: 16 [8/66 (12%)] Loss: 0.536730
# DEBUG:trainer:Train Epoch: 16 [16/66 (24%)] Loss: 0.417415
# DEBUG:trainer:Train Epoch: 16 [24/66 (36%)] Loss: 0.470283
# DEBUG:trainer:Train Epoch: 16 [32/66 (48%)] Loss: 0.387366
# DEBUG:trainer:Train Epoch: 16 [40/66 (61%)] Loss: 0.612677
# DEBUG:trainer:Train Epoch: 16 [48/66 (73%)] Loss: 0.458817
# DEBUG:trainer:Train Epoch: 16 [56/66 (85%)] Loss: 0.545523
# DEBUG:trainer:Train Epoch: 16 [64/66 (97%)] Loss: 0.581649
# INFO:trainer:    epoch          : 16
# INFO:trainer:    loss           : 0.4759498265656558
# INFO:trainer:    accuracy       : 0.7320075757575758
# INFO:trainer:    f1_score       : 0.7478083998851974
# INFO:trainer:    val_loss       : 0.4544760856558295
# INFO:trainer:    val_accuracy   : 0.8029149159663865
# INFO:trainer:    val_f1_score   : 0.8234283322150672
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.7221135029354208
# INFO:trainer:    val_MAcc       : 0.8063122259202651
# INFO:trainer:    val_F1_score   : 0.8285229202037352
# DEBUG:trainer:Train Epoch: 17 [0/66 (0%)] Loss: 0.427394
# DEBUG:trainer:Train Epoch: 17 [8/66 (12%)] Loss: 0.511486
# DEBUG:trainer:Train Epoch: 17 [16/66 (24%)] Loss: 0.507794
# DEBUG:trainer:Train Epoch: 17 [24/66 (36%)] Loss: 0.517823
# DEBUG:trainer:Train Epoch: 17 [32/66 (48%)] Loss: 0.455121
# DEBUG:trainer:Train Epoch: 17 [40/66 (61%)] Loss: 0.552371
# DEBUG:trainer:Train Epoch: 17 [48/66 (73%)] Loss: 0.752486
# DEBUG:trainer:Train Epoch: 17 [56/66 (85%)] Loss: 0.422103
# DEBUG:trainer:Train Epoch: 17 [64/66 (97%)] Loss: 0.448701
# INFO:trainer:    epoch          : 17
# INFO:trainer:    loss           : 0.4791591194542972
# INFO:trainer:    accuracy       : 0.7265625
# INFO:trainer:    f1_score       : 0.7449345686518295
# INFO:trainer:    val_loss       : 0.4540766275980893
# INFO:trainer:    val_accuracy   : 0.8142331932773109
# INFO:trainer:    val_f1_score   : 0.8339034555077981
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7240704500978473
# INFO:trainer:    val_MAcc       : 0.8145899695744712
# INFO:trainer:    val_F1_score   : 0.8371308016877637
# INFO:trainer:Saving new best model at epoch 17: model_best.pth
# DEBUG:trainer:Train Epoch: 18 [0/66 (0%)] Loss: 0.492705
# DEBUG:trainer:Train Epoch: 18 [8/66 (12%)] Loss: 0.433480
# DEBUG:trainer:Train Epoch: 18 [16/66 (24%)] Loss: 0.460588
# DEBUG:trainer:Train Epoch: 18 [24/66 (36%)] Loss: 0.458067
# DEBUG:trainer:Train Epoch: 18 [32/66 (48%)] Loss: 0.438814
# DEBUG:trainer:Train Epoch: 18 [40/66 (61%)] Loss: 0.605974
# DEBUG:trainer:Train Epoch: 18 [48/66 (73%)] Loss: 0.533360
# DEBUG:trainer:Train Epoch: 18 [56/66 (85%)] Loss: 0.499410
# DEBUG:trainer:Train Epoch: 18 [64/66 (97%)] Loss: 0.650642
# INFO:trainer:    epoch          : 18
# INFO:trainer:    loss           : 0.4786637348659111
# INFO:trainer:    accuracy       : 0.7296401515151515
# INFO:trainer:    f1_score       : 0.7464948413487519
# INFO:trainer:    val_loss       : 0.4525647452648948
# INFO:trainer:    val_accuracy   : 0.813314075630252
# INFO:trainer:    val_f1_score   : 0.8327077205453177
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7299412915851272
# INFO:trainer:    val_MAcc       : 0.8138757552816147
# INFO:trainer:    val_F1_score   : 0.8353140916808149
# DEBUG:trainer:Train Epoch: 19 [0/66 (0%)] Loss: 0.418986
# DEBUG:trainer:Train Epoch: 19 [8/66 (12%)] Loss: 0.571288
# DEBUG:trainer:Train Epoch: 19 [16/66 (24%)] Loss: 0.474381
# DEBUG:trainer:Train Epoch: 19 [24/66 (36%)] Loss: 0.361599
# DEBUG:trainer:Train Epoch: 19 [32/66 (48%)] Loss: 0.451329
# DEBUG:trainer:Train Epoch: 19 [40/66 (61%)] Loss: 0.393429
# DEBUG:trainer:Train Epoch: 19 [48/66 (73%)] Loss: 0.628852
# DEBUG:trainer:Train Epoch: 19 [56/66 (85%)] Loss: 0.472251
# DEBUG:trainer:Train Epoch: 19 [64/66 (97%)] Loss: 0.461937
# INFO:trainer:    epoch          : 19
# INFO:trainer:    loss           : 0.4743485681035302
# INFO:trainer:    accuracy       : 0.7322443181818182
# INFO:trainer:    f1_score       : 0.7493519363495228
# INFO:trainer:    val_loss       : 0.4502616428277072
# INFO:trainer:    val_accuracy   : 0.8160714285714286
# INFO:trainer:    val_f1_score   : 0.8356852337980597
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7201565557729941
# INFO:trainer:    val_MAcc       : 0.8162826574485409
# INFO:trainer:    val_F1_score   : 0.8396305625524769
# INFO:trainer:Saving new best model at epoch 19: model_best.pth
# DEBUG:trainer:Train Epoch: 20 [0/66 (0%)] Loss: 0.413848
# DEBUG:trainer:Train Epoch: 20 [8/66 (12%)] Loss: 0.473269
# DEBUG:trainer:Train Epoch: 20 [16/66 (24%)] Loss: 0.428576
# DEBUG:trainer:Train Epoch: 20 [24/66 (36%)] Loss: 0.456941
# DEBUG:trainer:Train Epoch: 20 [32/66 (48%)] Loss: 0.344904
# DEBUG:trainer:Train Epoch: 20 [40/66 (61%)] Loss: 0.445982
# DEBUG:trainer:Train Epoch: 20 [48/66 (73%)] Loss: 0.419884
# DEBUG:trainer:Train Epoch: 20 [56/66 (85%)] Loss: 0.482829
# DEBUG:trainer:Train Epoch: 20 [64/66 (97%)] Loss: 0.505845
# INFO:trainer:    epoch          : 20
# INFO:trainer:    loss           : 0.47443426468155603
# INFO:trainer:    accuracy       : 0.7289299242424242
# INFO:trainer:    f1_score       : 0.7454485593328313
# INFO:trainer:    val_loss       : 0.4517279302372652
# INFO:trainer:    val_accuracy   : 0.818828781512605
# INFO:trainer:    val_f1_score   : 0.8398508207840197
# INFO:trainer:    val_sensitivity: 0.9197080291970803
# INFO:trainer:    val_specificity: 0.7181996086105675
# INFO:trainer:    val_MAcc       : 0.8189538189038239
# INFO:trainer:    val_F1_score   : 0.8428093645484951
# INFO:trainer:Saving new best model at epoch 20: model_best.pth
# DEBUG:trainer:Train Epoch: 21 [0/66 (0%)] Loss: 0.598259
# DEBUG:trainer:Train Epoch: 21 [8/66 (12%)] Loss: 0.379353
# DEBUG:trainer:Train Epoch: 21 [16/66 (24%)] Loss: 0.580406
# DEBUG:trainer:Train Epoch: 21 [24/66 (36%)] Loss: 0.453396
# DEBUG:trainer:Train Epoch: 21 [32/66 (48%)] Loss: 0.362709
# DEBUG:trainer:Train Epoch: 21 [40/66 (61%)] Loss: 0.500712
# DEBUG:trainer:Train Epoch: 21 [48/66 (73%)] Loss: 0.384468
# DEBUG:trainer:Train Epoch: 21 [56/66 (85%)] Loss: 0.449588
# DEBUG:trainer:Train Epoch: 21 [64/66 (97%)] Loss: 0.470547
# INFO:trainer:    epoch          : 21
# INFO:trainer:    loss           : 0.4813062399625778
# INFO:trainer:    accuracy       : 0.7395833333333334
# INFO:trainer:    f1_score       : 0.7549613644888451
# INFO:trainer:    val_loss       : 0.44620633826536293
# INFO:trainer:    val_accuracy   : 0.8261817226890756
# INFO:trainer:    val_f1_score   : 0.8510170803896051
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7495107632093934
# INFO:trainer:    val_MAcc       : 0.8273101261302441
# INFO:trainer:    val_F1_score   : 0.8464163822525597
# INFO:trainer:Saving new best model at epoch 21: model_best.pth
# DEBUG:trainer:Train Epoch: 22 [0/66 (0%)] Loss: 0.477783
# DEBUG:trainer:Train Epoch: 22 [8/66 (12%)] Loss: 0.522772
# DEBUG:trainer:Train Epoch: 22 [16/66 (24%)] Loss: 0.443351
# DEBUG:trainer:Train Epoch: 22 [24/66 (36%)] Loss: 0.553118
# DEBUG:trainer:Train Epoch: 22 [32/66 (48%)] Loss: 0.435077
# DEBUG:trainer:Train Epoch: 22 [40/66 (61%)] Loss: 0.660313
# DEBUG:trainer:Train Epoch: 22 [48/66 (73%)] Loss: 0.408263
# DEBUG:trainer:Train Epoch: 22 [56/66 (85%)] Loss: 0.518142
# DEBUG:trainer:Train Epoch: 22 [64/66 (97%)] Loss: 0.396500
# INFO:trainer:    epoch          : 22
# INFO:trainer:    loss           : 0.46634204956618225
# INFO:trainer:    accuracy       : 0.734375
# INFO:trainer:    f1_score       : 0.750432981808719
# INFO:trainer:    val_loss       : 0.44354623731444864
# INFO:trainer:    val_accuracy   : 0.8261817226890756
# INFO:trainer:    val_f1_score   : 0.8503191223527309
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7573385518590998
# INFO:trainer:    val_MAcc       : 0.8275743854186011
# INFO:trainer:    val_F1_score   : 0.845360824742268
# INFO:trainer:Saving new best model at epoch 22: model_best.pth
# DEBUG:trainer:Train Epoch: 23 [0/66 (0%)] Loss: 0.383057
# DEBUG:trainer:Train Epoch: 23 [8/66 (12%)] Loss: 0.544930
# DEBUG:trainer:Train Epoch: 23 [16/66 (24%)] Loss: 0.441366
# DEBUG:trainer:Train Epoch: 23 [24/66 (36%)] Loss: 0.520405
# DEBUG:trainer:Train Epoch: 23 [32/66 (48%)] Loss: 0.690234
# DEBUG:trainer:Train Epoch: 23 [40/66 (61%)] Loss: 0.425392
# DEBUG:trainer:Train Epoch: 23 [48/66 (73%)] Loss: 0.426357
# DEBUG:trainer:Train Epoch: 23 [56/66 (85%)] Loss: 0.448939
# DEBUG:trainer:Train Epoch: 23 [64/66 (97%)] Loss: 0.499018
# INFO:trainer:    epoch          : 23
# INFO:trainer:    loss           : 0.4805366726535739
# INFO:trainer:    accuracy       : 0.7476325757575758
# INFO:trainer:    f1_score       : 0.7616161638464268
# INFO:trainer:    val_loss       : 0.43878667319522185
# INFO:trainer:    val_accuracy   : 0.8312237394957984
# INFO:trainer:    val_f1_score   : 0.8553780386637374
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7553816046966731
# INFO:trainer:    val_MAcc       : 0.8302455468738841
# INFO:trainer:    val_F1_score   : 0.8485885372112917
# INFO:trainer:Saving new best model at epoch 23: model_best.pth
# DEBUG:trainer:Train Epoch: 24 [0/66 (0%)] Loss: 0.450228
# DEBUG:trainer:Train Epoch: 24 [8/66 (12%)] Loss: 0.381730
# DEBUG:trainer:Train Epoch: 24 [16/66 (24%)] Loss: 0.462137
# DEBUG:trainer:Train Epoch: 24 [24/66 (36%)] Loss: 0.400667
# DEBUG:trainer:Train Epoch: 24 [32/66 (48%)] Loss: 0.383230
# DEBUG:trainer:Train Epoch: 24 [40/66 (61%)] Loss: 0.416750
# DEBUG:trainer:Train Epoch: 24 [48/66 (73%)] Loss: 0.463867
# DEBUG:trainer:Train Epoch: 24 [56/66 (85%)] Loss: 0.434206
# DEBUG:trainer:Train Epoch: 24 [64/66 (97%)] Loss: 0.532444
# INFO:trainer:    epoch          : 24
# INFO:trainer:    loss           : 0.47027181630784815
# INFO:trainer:    accuracy       : 0.7582859848484849
# INFO:trainer:    f1_score       : 0.772170328195779
# INFO:trainer:    val_loss       : 0.43656351811745586
# INFO:trainer:    val_accuracy   : 0.8271008403361344
# INFO:trainer:    val_f1_score   : 0.8539625447180895
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7592954990215264
# INFO:trainer:    val_MAcc       : 0.8285528589998143
# INFO:trainer:    val_F1_score   : 0.8460877042132416
# DEBUG:trainer:Train Epoch: 25 [0/66 (0%)] Loss: 0.435310
# DEBUG:trainer:Train Epoch: 25 [8/66 (12%)] Loss: 0.656194
# DEBUG:trainer:Train Epoch: 25 [16/66 (24%)] Loss: 0.569503
# DEBUG:trainer:Train Epoch: 25 [24/66 (36%)] Loss: 0.399282
# DEBUG:trainer:Train Epoch: 25 [32/66 (48%)] Loss: 0.414831
# DEBUG:trainer:Train Epoch: 25 [40/66 (61%)] Loss: 0.464784
# DEBUG:trainer:Train Epoch: 25 [48/66 (73%)] Loss: 0.509620
# DEBUG:trainer:Train Epoch: 25 [56/66 (85%)] Loss: 0.432393
# DEBUG:trainer:Train Epoch: 25 [64/66 (97%)] Loss: 0.412765
# INFO:trainer:    epoch          : 25
# INFO:trainer:    loss           : 0.4695402374773314
# INFO:trainer:    accuracy       : 0.7346117424242424
# INFO:trainer:    f1_score       : 0.7501334198293914
# INFO:trainer:    val_loss       : 0.43354132070260887
# INFO:trainer:    val_accuracy   : 0.827547268907563
# INFO:trainer:    val_f1_score   : 0.8538349656558404
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7553816046966731
# INFO:trainer:    val_MAcc       : 0.8265959118373877
# INFO:trainer:    val_F1_score   : 0.8446351931330472
# DEBUG:trainer:Train Epoch: 26 [0/66 (0%)] Loss: 0.420769
# DEBUG:trainer:Train Epoch: 26 [8/66 (12%)] Loss: 0.447023
# DEBUG:trainer:Train Epoch: 26 [16/66 (24%)] Loss: 0.419672
# DEBUG:trainer:Train Epoch: 26 [24/66 (36%)] Loss: 0.440020
# DEBUG:trainer:Train Epoch: 26 [32/66 (48%)] Loss: 0.519725
# DEBUG:trainer:Train Epoch: 26 [40/66 (61%)] Loss: 0.408043
# DEBUG:trainer:Train Epoch: 26 [48/66 (73%)] Loss: 0.554226
# DEBUG:trainer:Train Epoch: 26 [56/66 (85%)] Loss: 0.445481
# DEBUG:trainer:Train Epoch: 26 [64/66 (97%)] Loss: 0.510353
# INFO:trainer:    epoch          : 26
# INFO:trainer:    loss           : 0.45585237804687384
# INFO:trainer:    accuracy       : 0.7753314393939394
# INFO:trainer:    f1_score       : 0.7875631467530144
# INFO:trainer:    val_loss       : 0.4310161935932496
# INFO:trainer:    val_accuracy   : 0.8321428571428572
# INFO:trainer:    val_f1_score   : 0.862365887167499
# INFO:trainer:    val_sensitivity: 0.9124087591240876
# INFO:trainer:    val_specificity: 0.7495107632093934
# INFO:trainer:    val_MAcc       : 0.8309597611667405
# INFO:trainer:    val_F1_score   : 0.8503401360544217
# INFO:trainer:Saving new best model at epoch 26: model_best.pth
# DEBUG:trainer:Train Epoch: 27 [0/66 (0%)] Loss: 0.435158
# DEBUG:trainer:Train Epoch: 27 [8/66 (12%)] Loss: 0.401029
# DEBUG:trainer:Train Epoch: 27 [16/66 (24%)] Loss: 0.462660
# DEBUG:trainer:Train Epoch: 27 [24/66 (36%)] Loss: 0.540237
# DEBUG:trainer:Train Epoch: 27 [32/66 (48%)] Loss: 0.460535
# DEBUG:trainer:Train Epoch: 27 [40/66 (61%)] Loss: 0.552294
# DEBUG:trainer:Train Epoch: 27 [48/66 (73%)] Loss: 0.361505
# DEBUG:trainer:Train Epoch: 27 [56/66 (85%)] Loss: 0.415885
# DEBUG:trainer:Train Epoch: 27 [64/66 (97%)] Loss: 0.495239
# INFO:trainer:    epoch          : 27
# INFO:trainer:    loss           : 0.4606271810603864
# INFO:trainer:    accuracy       : 0.7819602272727273
# INFO:trainer:    f1_score       : 0.7943323288980225
# INFO:trainer:    val_loss       : 0.4282991798485027
# INFO:trainer:    val_accuracy   : 0.8284663865546219
# INFO:trainer:    val_f1_score   : 0.8558843287674913
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7495107632093934
# INFO:trainer:    val_MAcc       : 0.8273101261302441
# INFO:trainer:    val_F1_score   : 0.8464163822525597
# DEBUG:trainer:Train Epoch: 28 [0/66 (0%)] Loss: 0.530968
# DEBUG:trainer:Train Epoch: 28 [8/66 (12%)] Loss: 0.413598
# DEBUG:trainer:Train Epoch: 28 [16/66 (24%)] Loss: 0.424405
# DEBUG:trainer:Train Epoch: 28 [24/66 (36%)] Loss: 0.398821
# DEBUG:trainer:Train Epoch: 28 [32/66 (48%)] Loss: 0.392819
# DEBUG:trainer:Train Epoch: 28 [40/66 (61%)] Loss: 0.421668
# DEBUG:trainer:Train Epoch: 28 [48/66 (73%)] Loss: 0.529195
# DEBUG:trainer:Train Epoch: 28 [56/66 (85%)] Loss: 0.359877
# DEBUG:trainer:Train Epoch: 28 [64/66 (97%)] Loss: 0.333382
# INFO:trainer:    epoch          : 28
# INFO:trainer:    loss           : 0.44977966899221594
# INFO:trainer:    accuracy       : 0.779592803030303
# INFO:trainer:    f1_score       : 0.7902330566772883
# INFO:trainer:    val_loss       : 0.42622478919870715
# INFO:trainer:    val_accuracy   : 0.8257090336134454
# INFO:trainer:    val_f1_score   : 0.8534525995347233
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7514677103718199
# INFO:trainer:    val_MAcc       : 0.824638964674961
# INFO:trainer:    val_F1_score   : 0.8431876606683806
# DEBUG:trainer:Train Epoch: 29 [0/66 (0%)] Loss: 0.509168
# DEBUG:trainer:Train Epoch: 29 [8/66 (12%)] Loss: 0.427411
# DEBUG:trainer:Train Epoch: 29 [16/66 (24%)] Loss: 0.416065
# DEBUG:trainer:Train Epoch: 29 [24/66 (36%)] Loss: 0.369170
# DEBUG:trainer:Train Epoch: 29 [32/66 (48%)] Loss: 0.486711
# DEBUG:trainer:Train Epoch: 29 [40/66 (61%)] Loss: 0.405668
# DEBUG:trainer:Train Epoch: 29 [48/66 (73%)] Loss: 0.414898
# DEBUG:trainer:Train Epoch: 29 [56/66 (85%)] Loss: 0.417960
# DEBUG:trainer:Train Epoch: 29 [64/66 (97%)] Loss: 0.449975
# INFO:trainer:    epoch          : 29
# INFO:trainer:    loss           : 0.4608721520864602
# INFO:trainer:    accuracy       : 0.7239583333333334
# INFO:trainer:    f1_score       : 0.7380970752468364
# INFO:trainer:    val_loss       : 0.42924018905443306
# INFO:trainer:    val_accuracy   : 0.8200367647058824
# INFO:trainer:    val_f1_score   : 0.8446312058380046
# INFO:trainer:    val_sensitivity: 0.8540145985401459
# INFO:trainer:    val_specificity: 0.7847358121330724
# INFO:trainer:    val_MAcc       : 0.8193752053366092
# INFO:trainer:    val_F1_score   : 0.8312611012433393
# DEBUG:trainer:Train Epoch: 30 [0/66 (0%)] Loss: 0.651303
# DEBUG:trainer:Train Epoch: 30 [8/66 (12%)] Loss: 0.466626
# DEBUG:trainer:Train Epoch: 30 [16/66 (24%)] Loss: 0.435007
# DEBUG:trainer:Train Epoch: 30 [24/66 (36%)] Loss: 0.429680
# DEBUG:trainer:Train Epoch: 30 [32/66 (48%)] Loss: 0.449235
# DEBUG:trainer:Train Epoch: 30 [40/66 (61%)] Loss: 0.333157
# DEBUG:trainer:Train Epoch: 30 [48/66 (73%)] Loss: 0.491302
# DEBUG:trainer:Train Epoch: 30 [56/66 (85%)] Loss: 0.439610
# DEBUG:trainer:Train Epoch: 30 [64/66 (97%)] Loss: 0.385804
# INFO:trainer:    epoch          : 30
# INFO:trainer:    loss           : 0.4460106559775092
# INFO:trainer:    accuracy       : 0.7720170454545454
# INFO:trainer:    f1_score       : 0.7837327481069755
# INFO:trainer:    val_loss       : 0.42401996956152077
# INFO:trainer:    val_accuracy   : 0.8257090336134454
# INFO:trainer:    val_f1_score   : 0.8556964940633278
# INFO:trainer:    val_sensitivity: 0.8905109489051095
# INFO:trainer:    val_specificity: 0.7592954990215264
# INFO:trainer:    val_MAcc       : 0.8249032239633179
# INFO:trainer:    val_F1_score   : 0.8421052631578947
# DEBUG:trainer:Train Epoch: 31 [0/66 (0%)] Loss: 0.458030
# DEBUG:trainer:Train Epoch: 31 [8/66 (12%)] Loss: 0.352216
# DEBUG:trainer:Train Epoch: 31 [16/66 (24%)] Loss: 0.442933
# DEBUG:trainer:Train Epoch: 31 [24/66 (36%)] Loss: 0.463051
# DEBUG:trainer:Train Epoch: 31 [32/66 (48%)] Loss: 0.587920
# DEBUG:trainer:Train Epoch: 31 [40/66 (61%)] Loss: 0.409985
# DEBUG:trainer:Train Epoch: 31 [48/66 (73%)] Loss: 0.676448
# DEBUG:trainer:Train Epoch: 31 [56/66 (85%)] Loss: 0.372437
# DEBUG:trainer:Train Epoch: 31 [64/66 (97%)] Loss: 0.638404
# INFO:trainer:    epoch          : 31
# INFO:trainer:    loss           : 0.45162644937182916
# INFO:trainer:    accuracy       : 0.7445549242424242
# INFO:trainer:    f1_score       : 0.7597461698975017
# INFO:trainer:    val_loss       : 0.42504455149173737
# INFO:trainer:    val_accuracy   : 0.8171481092436974
# INFO:trainer:    val_f1_score   : 0.8444273349726354
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.7710371819960861
# INFO:trainer:    val_MAcc       : 0.8198251603411087
# INFO:trainer:    val_F1_score   : 0.834355828220859
# DEBUG:trainer:Train Epoch: 32 [0/66 (0%)] Loss: 0.366045
# DEBUG:trainer:Train Epoch: 32 [8/66 (12%)] Loss: 0.401392
# DEBUG:trainer:Train Epoch: 32 [16/66 (24%)] Loss: 0.402226
# DEBUG:trainer:Train Epoch: 32 [24/66 (36%)] Loss: 0.353976
# DEBUG:trainer:Train Epoch: 32 [32/66 (48%)] Loss: 0.693841
# DEBUG:trainer:Train Epoch: 32 [40/66 (61%)] Loss: 0.708455
# DEBUG:trainer:Train Epoch: 32 [48/66 (73%)] Loss: 0.439043
# DEBUG:trainer:Train Epoch: 32 [56/66 (85%)] Loss: 0.358203
# DEBUG:trainer:Train Epoch: 32 [64/66 (97%)] Loss: 0.346613
# INFO:trainer:    epoch          : 32
# INFO:trainer:    loss           : 0.4653077577099656
# INFO:trainer:    accuracy       : 0.7301136363636364
# INFO:trainer:    f1_score       : 0.741761510434198
# INFO:trainer:    val_loss       : 0.42216479690635905
# INFO:trainer:    val_accuracy   : 0.828623949579832
# INFO:trainer:    val_f1_score   : 0.8608719349411186
# INFO:trainer:    val_sensitivity: 0.8978102189781022
# INFO:trainer:    val_specificity: 0.7592954990215264
# INFO:trainer:    val_MAcc       : 0.8285528589998143
# INFO:trainer:    val_F1_score   : 0.8460877042132416
# DEBUG:trainer:Train Epoch: 33 [0/66 (0%)] Loss: 0.444547
# DEBUG:trainer:Train Epoch: 33 [8/66 (12%)] Loss: 0.437664
# DEBUG:trainer:Train Epoch: 33 [16/66 (24%)] Loss: 0.462653
# DEBUG:trainer:Train Epoch: 33 [24/66 (36%)] Loss: 0.470595
# DEBUG:trainer:Train Epoch: 33 [32/66 (48%)] Loss: 0.409921
# DEBUG:trainer:Train Epoch: 33 [40/66 (61%)] Loss: 0.382643
# DEBUG:trainer:Train Epoch: 33 [48/66 (73%)] Loss: 0.394896
# DEBUG:trainer:Train Epoch: 33 [56/66 (85%)] Loss: 0.459188
# DEBUG:trainer:Train Epoch: 33 [64/66 (97%)] Loss: 0.348418
# INFO:trainer:    epoch          : 33
# INFO:trainer:    loss           : 0.4418272348967465
# INFO:trainer:    accuracy       : 0.7810132575757576
# INFO:trainer:    f1_score       : 0.7919548925722876
# INFO:trainer:    val_loss       : 0.42322853207588196
# INFO:trainer:    val_accuracy   : 0.8247899159663866
# INFO:trainer:    val_f1_score   : 0.8571145842458023
# INFO:trainer:    val_sensitivity: 0.8832116788321168
# INFO:trainer:    val_specificity: 0.7651663405088063
# INFO:trainer:    val_MAcc       : 0.8241890096704616
# INFO:trainer:    val_F1_score   : 0.8402777777777778
# DEBUG:trainer:Train Epoch: 34 [0/66 (0%)] Loss: 0.555796
# DEBUG:trainer:Train Epoch: 34 [8/66 (12%)] Loss: 0.395113
# DEBUG:trainer:Train Epoch: 34 [16/66 (24%)] Loss: 0.411069
# DEBUG:trainer:Train Epoch: 34 [24/66 (36%)] Loss: 0.407110
# DEBUG:trainer:Train Epoch: 34 [32/66 (48%)] Loss: 0.494616
# DEBUG:trainer:Train Epoch: 34 [40/66 (61%)] Loss: 0.378359
# DEBUG:trainer:Train Epoch: 34 [48/66 (73%)] Loss: 0.770791
# DEBUG:trainer:Train Epoch: 34 [56/66 (85%)] Loss: 0.623250
# DEBUG:trainer:Train Epoch: 34 [64/66 (97%)] Loss: 0.448850
# INFO:trainer:    epoch          : 34
# INFO:trainer:    loss           : 0.46397716574596637
# INFO:trainer:    accuracy       : 0.7587594696969697
# INFO:trainer:    f1_score       : 0.7693786553913686
# INFO:trainer:    val_loss       : 0.4241120052688262
# INFO:trainer:    val_accuracy   : 0.803361344537815
# INFO:trainer:    val_f1_score   : 0.8300832894012842
# INFO:trainer:    val_sensitivity: 0.8394160583941606
# INFO:trainer:    val_specificity: 0.7729941291585127
# INFO:trainer:    val_MAcc       : 0.8062050937763366
# INFO:trainer:    val_F1_score   : 0.8185053380782918
# DEBUG:trainer:Train Epoch: 35 [0/66 (0%)] Loss: 0.387552
# DEBUG:trainer:Train Epoch: 35 [8/66 (12%)] Loss: 0.400726
# DEBUG:trainer:Train Epoch: 35 [16/66 (24%)] Loss: 0.362471
# DEBUG:trainer:Train Epoch: 35 [24/66 (36%)] Loss: 0.570566
# DEBUG:trainer:Train Epoch: 35 [32/66 (48%)] Loss: 0.419652
# DEBUG:trainer:Train Epoch: 35 [40/66 (61%)] Loss: 0.445976
# DEBUG:trainer:Train Epoch: 35 [48/66 (73%)] Loss: 0.439598
# DEBUG:trainer:Train Epoch: 35 [56/66 (85%)] Loss: 0.505655
# DEBUG:trainer:Train Epoch: 35 [64/66 (97%)] Loss: 0.495449
# INFO:trainer:    epoch          : 35
# INFO:trainer:    loss           : 0.4277995034600749
# INFO:trainer:    accuracy       : 0.7658617424242424
# INFO:trainer:    f1_score       : 0.7756158541576388
# INFO:trainer:    val_loss       : 0.4186922031290391
# INFO:trainer:    val_accuracy   : 0.8175945378151261
# INFO:trainer:    val_f1_score   : 0.8517009990218449
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.7592954990215264
# INFO:trainer:    val_MAcc       : 0.8176039538903253
# INFO:trainer:    val_F1_score   : 0.8340573414422242
# DEBUG:trainer:Train Epoch: 36 [0/66 (0%)] Loss: 0.678013
# DEBUG:trainer:Train Epoch: 36 [8/66 (12%)] Loss: 0.384754
# DEBUG:trainer:Train Epoch: 36 [16/66 (24%)] Loss: 0.461389
# DEBUG:trainer:Train Epoch: 36 [24/66 (36%)] Loss: 0.353687
# DEBUG:trainer:Train Epoch: 36 [32/66 (48%)] Loss: 0.302111
# DEBUG:trainer:Train Epoch: 36 [40/66 (61%)] Loss: 0.414801
# DEBUG:trainer:Train Epoch: 36 [48/66 (73%)] Loss: 0.389949
# DEBUG:trainer:Train Epoch: 36 [56/66 (85%)] Loss: 0.413151
# DEBUG:trainer:Train Epoch: 36 [64/66 (97%)] Loss: 0.410857
# INFO:trainer:    epoch          : 36
# INFO:trainer:    loss           : 0.443617455887072
# INFO:trainer:    accuracy       : 0.7485795454545454
# INFO:trainer:    f1_score       : 0.7608172783095961
# INFO:trainer:    val_loss       : 0.41894442193648396
# INFO:trainer:    val_accuracy   : 0.8047268907563025
# INFO:trainer:    val_f1_score   : 0.8336047276210561
# INFO:trainer:    val_sensitivity: 0.8467153284671532
# INFO:trainer:    val_specificity: 0.7632093933463796
# INFO:trainer:    val_MAcc       : 0.8049623609067664
# INFO:trainer:    val_F1_score   : 0.8190644307149162
# DEBUG:trainer:Train Epoch: 37 [0/66 (0%)] Loss: 0.438346
# DEBUG:trainer:Train Epoch: 37 [8/66 (12%)] Loss: 0.574174
# DEBUG:trainer:Train Epoch: 37 [16/66 (24%)] Loss: 0.392702
# DEBUG:trainer:Train Epoch: 37 [24/66 (36%)] Loss: 0.474154
# DEBUG:trainer:Train Epoch: 37 [32/66 (48%)] Loss: 0.472865
# DEBUG:trainer:Train Epoch: 37 [40/66 (61%)] Loss: 0.384973
# DEBUG:trainer:Train Epoch: 37 [48/66 (73%)] Loss: 0.437012
# DEBUG:trainer:Train Epoch: 37 [56/66 (85%)] Loss: 0.557283
# DEBUG:trainer:Train Epoch: 37 [64/66 (97%)] Loss: 0.419180
# INFO:trainer:    epoch          : 37
# INFO:trainer:    loss           : 0.4734714184746598
# INFO:trainer:    accuracy       : 0.7341382575757576
# INFO:trainer:    f1_score       : 0.7476033175092127
# INFO:trainer:    val_loss       : 0.42217066708733053
# INFO:trainer:    val_accuracy   : 0.7952468487394958
# INFO:trainer:    val_f1_score   : 0.8220279839009733
# INFO:trainer:    val_sensitivity: 0.8248175182481752
# INFO:trainer:    val_specificity: 0.7729941291585127
# INFO:trainer:    val_MAcc       : 0.798905823703344
# INFO:trainer:    val_F1_score   : 0.8100358422939068
# DEBUG:trainer:Train Epoch: 38 [0/66 (0%)] Loss: 0.365160
# DEBUG:trainer:Train Epoch: 38 [8/66 (12%)] Loss: 0.575739
# DEBUG:trainer:Train Epoch: 38 [16/66 (24%)] Loss: 0.318183
# DEBUG:trainer:Train Epoch: 38 [24/66 (36%)] Loss: 0.592022
# DEBUG:trainer:Train Epoch: 38 [32/66 (48%)] Loss: 0.344507
# DEBUG:trainer:Train Epoch: 38 [40/66 (61%)] Loss: 0.692085
# DEBUG:trainer:Train Epoch: 38 [48/66 (73%)] Loss: 0.476901
# DEBUG:trainer:Train Epoch: 38 [56/66 (85%)] Loss: 0.523442
# DEBUG:trainer:Train Epoch: 38 [64/66 (97%)] Loss: 0.621240
# INFO:trainer:    epoch          : 38
# INFO:trainer:    loss           : 0.4435849054293199
# INFO:trainer:    accuracy       : 0.7556818181818182
# INFO:trainer:    f1_score       : 0.769433167039128
# INFO:trainer:    val_loss       : 0.417099671328769
# INFO:trainer:    val_accuracy   : 0.8185136554621849
# INFO:trainer:    val_f1_score   : 0.8524653725665307
# INFO:trainer:    val_sensitivity: 0.8759124087591241
# INFO:trainer:    val_specificity: 0.761252446183953
# INFO:trainer:    val_MAcc       : 0.8185824274715385
# INFO:trainer:    val_F1_score   : 0.8347826086956521
# DEBUG:trainer:Train Epoch: 39 [0/66 (0%)] Loss: 0.392840
# DEBUG:trainer:Train Epoch: 39 [8/66 (12%)] Loss: 0.305972
# DEBUG:trainer:Train Epoch: 39 [16/66 (24%)] Loss: 0.389048
# DEBUG:trainer:Train Epoch: 39 [24/66 (36%)] Loss: 0.454617
# DEBUG:trainer:Train Epoch: 39 [32/66 (48%)] Loss: 0.450276
# DEBUG:trainer:Train Epoch: 39 [40/66 (61%)] Loss: 0.467723
# DEBUG:trainer:Train Epoch: 39 [48/66 (73%)] Loss: 0.356403
# DEBUG:trainer:Train Epoch: 39 [56/66 (85%)] Loss: 0.556410
# DEBUG:trainer:Train Epoch: 39 [64/66 (97%)] Loss: 0.446581
# INFO:trainer:    epoch          : 39
# INFO:trainer:    loss           : 0.4416056726918076
# INFO:trainer:    accuracy       : 0.7559185606060606
# INFO:trainer:    f1_score       : 0.7683209732095623
# INFO:trainer:    val_loss       : 0.4173363824101055
# INFO:trainer:    val_accuracy   : 0.8221901260504202
# INFO:trainer:    val_f1_score   : 0.8541945523831385
# INFO:trainer:    val_sensitivity: 0.8832116788321168
# INFO:trainer:    val_specificity: 0.761252446183953
# INFO:trainer:    val_MAcc       : 0.8222320625080349
# INFO:trainer:    val_F1_score   : 0.8388214904679376
# DEBUG:trainer:Train Epoch: 40 [0/66 (0%)] Loss: 0.386602
# DEBUG:trainer:Train Epoch: 40 [8/66 (12%)] Loss: 0.405979
# DEBUG:trainer:Train Epoch: 40 [16/66 (24%)] Loss: 0.330378
# DEBUG:trainer:Train Epoch: 40 [24/66 (36%)] Loss: 0.455523
# ...
# INFO:trainer:    val_loss       : 0.4166632320951013
# INFO:trainer:    val_accuracy   : 0.8093224789915967
# INFO:trainer:    val_f1_score   : 0.838242060842055
# INFO:trainer:    val_sensitivity: 0.8540145985401459
# INFO:trainer:    val_specificity: 0.7651663405088063
# INFO:trainer:    val_MAcc       : 0.8095904695244761
# INFO:trainer:    val_F1_score   : 0.823943661971831
# DEBUG:trainer:Train Epoch: 44 [0/66 (0%)] Loss: 0.414545
# DEBUG:trainer:Train Epoch: 44 [8/66 (12%)] Loss: 0.343551
# DEBUG:trainer:Train Epoch: 44 [16/66 (24%)] Loss: 0.399648
# DEBUG:trainer:Train Epoch: 44 [24/66 (36%)] Loss: 0.371870
# DEBUG:trainer:Train Epoch: 44 [32/66 (48%)] Loss: 0.386717
# DEBUG:trainer:Train Epoch: 44 [40/66 (61%)] Loss: 0.406866
# DEBUG:trainer:Train Epoch: 44 [48/66 (73%)] Loss: 0.404571
# DEBUG:trainer:Train Epoch: 44 [56/66 (85%)] Loss: 0.321844
# DEBUG:trainer:Train Epoch: 44 [64/66 (97%)] Loss: 0.432860
# INFO:trainer:    epoch          : 44
# INFO:trainer:    loss           : 0.42544167556545953
# INFO:trainer:    accuracy       : 0.7821969696969697
# INFO:trainer:    f1_score       : 0.791826561277525
# INFO:trainer:    val_loss       : 0.4144333022482255
# INFO:trainer:    val_accuracy   : 0.8304621848739496
# INFO:trainer:    val_f1_score   : 0.8656632770320408
# INFO:trainer:    val_sensitivity: 0.9051094890510949
# INFO:trainer:    val_specificity: 0.7553816046966731
# INFO:trainer:    val_MAcc       : 0.8302455468738841
# INFO:trainer:    val_F1_score   : 0.8485885372112917
# DEBUG:trainer:Train Epoch: 45 [0/66 (0%)] Loss: 0.645349
# DEBUG:trainer:Train Epoch: 45 [8/66 (12%)] Loss: 0.332105
# DEBUG:trainer:Train Epoch: 45 [16/66 (24%)] Loss: 0.362839
# DEBUG:trainer:Train Epoch: 45 [24/66 (36%)] Loss: 0.610934
# DEBUG:trainer:Train Epoch: 45 [32/66 (48%)] Loss: 0.347361
# DEBUG:trainer:Train Epoch: 45 [40/66 (61%)] Loss: 0.379599
# DEBUG:trainer:Train Epoch: 45 [48/66 (73%)] Loss: 0.561650
# DEBUG:trainer:Train Epoch: 45 [56/66 (85%)] Loss: 0.684382
# DEBUG:trainer:Train Epoch: 45 [64/66 (97%)] Loss: 0.682147
# INFO:trainer:    epoch          : 45
# INFO:trainer:    loss           : 0.45328529766111664
# INFO:trainer:    accuracy       : 0.7526041666666666
# INFO:trainer:    f1_score       : 0.7634204980829863
# INFO:trainer:    val_loss       : 0.4178296494133332
# INFO:trainer:    val_accuracy   : 0.8008928571428572
# INFO:trainer:    val_f1_score   : 0.8270295937459998
# INFO:trainer:    val_sensitivity: 0.8321167883211679
# INFO:trainer:    val_specificity: 0.7690802348336595
# INFO:trainer:    val_MAcc       : 0.8005985115774137
# INFO:trainer:    val_F1_score   : 0.8128342245989305
# DEBUG:trainer:Train Epoch: 46 [0/66 (0%)] Loss: 0.387343
# DEBUG:trainer:Train Epoch: 46 [8/66 (12%)] Loss: 0.457432
# DEBUG:trainer:Train Epoch: 46 [16/66 (24%)] Loss: 0.442082
# DEBUG:trainer:Train Epoch: 46 [24/66 (36%)] Loss: 0.459253
# DEBUG:trainer:Train Epoch: 46 [32/66 (48%)] Loss: 0.386630
# DEBUG:trainer:Train Epoch: 46 [40/66 (61%)] Loss: 0.380777
# DEBUG:trainer:Train Epoch: 46 [48/66 (73%)] Loss: 0.380452
# DEBUG:trainer:Train Epoch: 46 [56/66 (85%)] Loss: 0.350861
# DEBUG:trainer:Train Epoch: 46 [64/66 (97%)] Loss: 0.444914
# INFO:trainer:    epoch          : 46
# INFO:trainer:    loss           : 0.4126113757039561
# INFO:trainer:    accuracy       : 0.7649147727272727
# INFO:trainer:    f1_score       : 0.7750000913497177
# INFO:trainer:    val_loss       : 0.41565194463028626
# INFO:trainer:    val_accuracy   : 0.812998949579832
# INFO:trainer:    val_f1_score   : 0.8452422211752196
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.7651663405088063
# INFO:trainer:    val_MAcc       : 0.8132401045609725
# INFO:trainer:    val_F1_score   : 0.8280701754385965
# DEBUG:trainer:Train Epoch: 47 [0/66 (0%)] Loss: 0.402866
# DEBUG:trainer:Train Epoch: 47 [8/66 (12%)] Loss: 0.339025
# DEBUG:trainer:Train Epoch: 47 [16/66 (24%)] Loss: 0.457035
# DEBUG:trainer:Train Epoch: 47 [24/66 (36%)] Loss: 0.365116
# DEBUG:trainer:Train Epoch: 47 [32/66 (48%)] Loss: 0.480703
# DEBUG:trainer:Train Epoch: 47 [40/66 (61%)] Loss: 0.333642
# DEBUG:trainer:Train Epoch: 47 [48/66 (73%)] Loss: 0.419664
# DEBUG:trainer:Train Epoch: 47 [56/66 (85%)] Loss: 0.532982
# DEBUG:trainer:Train Epoch: 47 [64/66 (97%)] Loss: 0.327832
# INFO:trainer:    epoch          : 47
# INFO:trainer:    loss           : 0.437076980417425
# INFO:trainer:    accuracy       : 0.7556818181818182
# INFO:trainer:    f1_score       : 0.7671304435494597
# INFO:trainer:    val_loss       : 0.41684815199936137
# INFO:trainer:    val_accuracy   : 0.7969275210084034
# INFO:trainer:    val_f1_score   : 0.8256876743127616
# INFO:trainer:    val_sensitivity: 0.8321167883211679
# INFO:trainer:    val_specificity: 0.7671232876712328
# INFO:trainer:    val_MAcc       : 0.7996200379962004
# INFO:trainer:    val_F1_score   : 0.8121104185218164
# DEBUG:trainer:Train Epoch: 48 [0/66 (0%)] Loss: 0.386749
# DEBUG:trainer:Train Epoch: 48 [8/66 (12%)] Loss: 0.340244
# DEBUG:trainer:Train Epoch: 48 [16/66 (24%)] Loss: 0.506090
# DEBUG:trainer:Train Epoch: 48 [24/66 (36%)] Loss: 0.620841
# DEBUG:trainer:Train Epoch: 48 [32/66 (48%)] Loss: 0.428358
# DEBUG:trainer:Train Epoch: 48 [40/66 (61%)] Loss: 0.408185
# DEBUG:trainer:Train Epoch: 48 [48/66 (73%)] Loss: 0.329633
# DEBUG:trainer:Train Epoch: 48 [56/66 (85%)] Loss: 0.338827
# DEBUG:trainer:Train Epoch: 48 [64/66 (97%)] Loss: 0.319012
# INFO:trainer:    epoch          : 48
# INFO:trainer:    loss           : 0.41967911250663525
# INFO:trainer:    accuracy       : 0.7630208333333334
# INFO:trainer:    f1_score       : 0.7752645670147463
# INFO:trainer:    val_loss       : 0.41395174755769615
# INFO:trainer:    val_accuracy   : 0.8148371848739496
# INFO:trainer:    val_f1_score   : 0.8486456628632085
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.761252446183953
# INFO:trainer:    val_MAcc       : 0.8149327924350422
# INFO:trainer:    val_F1_score   : 0.830715532286213
# DEBUG:trainer:Train Epoch: 49 [0/66 (0%)] Loss: 0.416018
# DEBUG:trainer:Train Epoch: 49 [8/66 (12%)] Loss: 0.290839
# DEBUG:trainer:Train Epoch: 49 [16/66 (24%)] Loss: 0.411237
# DEBUG:trainer:Train Epoch: 49 [24/66 (36%)] Loss: 0.410777
# DEBUG:trainer:Train Epoch: 49 [32/66 (48%)] Loss: 0.522970
# DEBUG:trainer:Train Epoch: 49 [40/66 (61%)] Loss: 0.486786
# DEBUG:trainer:Train Epoch: 49 [48/66 (73%)] Loss: 0.332333
# DEBUG:trainer:Train Epoch: 49 [56/66 (85%)] Loss: 0.350722
# DEBUG:trainer:Train Epoch: 49 [64/66 (97%)] Loss: 0.411650
# INFO:trainer:    epoch          : 49
# INFO:trainer:    loss           : 0.4149737105225072
# INFO:trainer:    accuracy       : 0.7734375
# INFO:trainer:    f1_score       : 0.7847023109123455
# INFO:trainer:    val_loss       : 0.41552282782161937
# INFO:trainer:    val_accuracy   : 0.8166754201680673
# INFO:trainer:    val_f1_score   : 0.8494431180545805
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.7651663405088063
# INFO:trainer:    val_MAcc       : 0.8168897395974688
# INFO:trainer:    val_F1_score   : 0.8321678321678322
# DEBUG:trainer:Train Epoch: 50 [0/66 (0%)] Loss: 0.417777
# DEBUG:trainer:Train Epoch: 50 [8/66 (12%)] Loss: 0.403887
# DEBUG:trainer:Train Epoch: 50 [16/66 (24%)] Loss: 0.390443
# DEBUG:trainer:Train Epoch: 50 [24/66 (36%)] Loss: 0.394330
# DEBUG:trainer:Train Epoch: 50 [32/66 (48%)] Loss: 0.466903
# DEBUG:trainer:Train Epoch: 50 [40/66 (61%)] Loss: 0.529731
# DEBUG:trainer:Train Epoch: 50 [48/66 (73%)] Loss: 0.515498
# DEBUG:trainer:Train Epoch: 50 [56/66 (85%)] Loss: 0.695446
# DEBUG:trainer:Train Epoch: 50 [64/66 (97%)] Loss: 0.428360
# INFO:trainer:    epoch          : 50
# INFO:trainer:    loss           : 0.4369690409212401
# INFO:trainer:    accuracy       : 0.7419507575757576
# INFO:trainer:    f1_score       : 0.7537878150436287
# INFO:trainer:    val_loss       : 0.4170640181092655
# INFO:trainer:    val_accuracy   : 0.8038077731092438
# INFO:trainer:    val_f1_score   : 0.8326499186301769
# INFO:trainer:    val_sensitivity: 0.8394160583941606
# INFO:trainer:    val_specificity: 0.7690802348336595
# INFO:trainer:    val_MAcc       : 0.80424814661391
# INFO:trainer:    val_F1_score   : 0.8170515097690941
# DEBUG:trainer:Train Epoch: 51 [0/66 (0%)] Loss: 0.362099
# DEBUG:trainer:Train Epoch: 51 [8/66 (12%)] Loss: 0.665038
# DEBUG:trainer:Train Epoch: 51 [16/66 (24%)] Loss: 0.344798
# DEBUG:trainer:Train Epoch: 51 [24/66 (36%)] Loss: 0.522675
# DEBUG:trainer:Train Epoch: 51 [32/66 (48%)] Loss: 0.385261
# DEBUG:trainer:Train Epoch: 51 [40/66 (61%)] Loss: 0.393928
# DEBUG:trainer:Train Epoch: 51 [48/66 (73%)] Loss: 0.460698
# DEBUG:trainer:Train Epoch: 51 [56/66 (85%)] Loss: 0.466081
# DEBUG:trainer:Train Epoch: 51 [64/66 (97%)] Loss: 0.415795
# INFO:trainer:    epoch          : 51
# INFO:trainer:    loss           : 0.4396004162051461
# INFO:trainer:    accuracy       : 0.7632575757575758
# INFO:trainer:    f1_score       : 0.7728444596271636
# INFO:trainer:    val_loss       : 0.4166213274002075
# INFO:trainer:    val_accuracy   : 0.7992121848739496
# INFO:trainer:    val_f1_score   : 0.8261450293946601
# INFO:trainer:    val_sensitivity: 0.8321167883211679
# INFO:trainer:    val_specificity: 0.7671232876712328
# INFO:trainer:    val_MAcc       : 0.7996200379962004
# INFO:trainer:    val_F1_score   : 0.8121104185218164
# DEBUG:trainer:Train Epoch: 52 [0/66 (0%)] Loss: 0.396353
# DEBUG:trainer:Train Epoch: 52 [8/66 (12%)] Loss: 0.329922
# DEBUG:trainer:Train Epoch: 52 [16/66 (24%)] Loss: 0.322338
# DEBUG:trainer:Train Epoch: 52 [24/66 (36%)] Loss: 0.422880
# DEBUG:trainer:Train Epoch: 52 [32/66 (48%)] Loss: 0.449326
# DEBUG:trainer:Train Epoch: 52 [40/66 (61%)] Loss: 0.564489
# DEBUG:trainer:Train Epoch: 52 [48/66 (73%)] Loss: 0.392182
# DEBUG:trainer:Train Epoch: 52 [56/66 (85%)] Loss: 0.362136
# DEBUG:trainer:Train Epoch: 52 [64/66 (97%)] Loss: 0.495023
# INFO:trainer:    epoch          : 52
# INFO:trainer:    loss           : 0.4325087869709188
# INFO:trainer:    accuracy       : 0.7713068181818182
# INFO:trainer:    f1_score       : 0.7795948165480878
# INFO:trainer:    val_loss       : 0.41470075004241047
# INFO:trainer:    val_accuracy   : 0.8139180672268909
# INFO:trainer:    val_f1_score   : 0.8448108167994759
# INFO:trainer:    val_sensitivity: 0.8613138686131386
# INFO:trainer:    val_specificity: 0.7671232876712328
# INFO:trainer:    val_MAcc       : 0.8142185781421858
# INFO:trainer:    val_F1_score   : 0.8287971905179982
# DEBUG:trainer:Train Epoch: 53 [0/66 (0%)] Loss: 0.453641
# DEBUG:trainer:Train Epoch: 53 [8/66 (12%)] Loss: 0.645442
# DEBUG:trainer:Train Epoch: 53 [16/66 (24%)] Loss: 0.457965
# DEBUG:trainer:Train Epoch: 53 [24/66 (36%)] Loss: 0.335773
# DEBUG:trainer:Train Epoch: 53 [32/66 (48%)] Loss: 0.348099
# DEBUG:trainer:Train Epoch: 53 [40/66 (61%)] Loss: 0.365943
# DEBUG:trainer:Train Epoch: 53 [48/66 (73%)] Loss: 0.387993
# DEBUG:trainer:Train Epoch: 53 [56/66 (85%)] Loss: 0.379757
# DEBUG:trainer:Train Epoch: 53 [64/66 (97%)] Loss: 0.353263
# INFO:trainer:    epoch          : 53
# INFO:trainer:    loss           : 0.4264011306293083
# INFO:trainer:    accuracy       : 0.7653882575757576
# INFO:trainer:    f1_score       : 0.7745779351442841
# INFO:trainer:    val_loss       : 0.41349967525285836
# INFO:trainer:    val_accuracy   : 0.8148371848739496
# INFO:trainer:    val_f1_score   : 0.8487097337955145
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.761252446183953
# INFO:trainer:    val_MAcc       : 0.8149327924350422
# INFO:trainer:    val_F1_score   : 0.830715532286213
# DEBUG:trainer:Train Epoch: 54 [0/66 (0%)] Loss: 0.375157
# DEBUG:trainer:Train Epoch: 54 [8/66 (12%)] Loss: 0.364764
# DEBUG:trainer:Train Epoch: 54 [16/66 (24%)] Loss: 0.415537
# DEBUG:trainer:Train Epoch: 54 [24/66 (36%)] Loss: 0.418128
# DEBUG:trainer:Train Epoch: 54 [32/66 (48%)] Loss: 0.353054
# DEBUG:trainer:Train Epoch: 54 [40/66 (61%)] Loss: 0.378964
# DEBUG:trainer:Train Epoch: 54 [48/66 (73%)] Loss: 0.404211
# DEBUG:trainer:Train Epoch: 54 [56/66 (85%)] Loss: 0.458846
# DEBUG:trainer:Train Epoch: 54 [64/66 (97%)] Loss: 0.418050
# INFO:trainer:    epoch          : 54
# INFO:trainer:    loss           : 0.41745158397790155
# INFO:trainer:    accuracy       : 0.7618371212121212
# INFO:trainer:    f1_score       : 0.7737566982716821
# INFO:trainer:    val_loss       : 0.4144594853415209
# INFO:trainer:    val_accuracy   : 0.8157563025210085
# INFO:trainer:    val_f1_score   : 0.8490716010285837
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.7632093933463796
# INFO:trainer:    val_MAcc       : 0.8159112660162555
# INFO:trainer:    val_F1_score   : 0.8314410480349343
# DEBUG:trainer:Train Epoch: 55 [0/66 (0%)] Loss: 0.357148
# DEBUG:trainer:Train Epoch: 55 [8/66 (12%)] Loss: 0.431446
# DEBUG:trainer:Train Epoch: 55 [16/66 (24%)] Loss: 0.373599
# DEBUG:trainer:Train Epoch: 55 [24/66 (36%)] Loss: 0.361179
# DEBUG:trainer:Train Epoch: 55 [32/66 (48%)] Loss: 0.357934
# DEBUG:trainer:Train Epoch: 55 [40/66 (61%)] Loss: 0.316925
# DEBUG:trainer:Train Epoch: 55 [48/66 (73%)] Loss: 0.445418
# DEBUG:trainer:Train Epoch: 55 [56/66 (85%)] Loss: 0.377868
# DEBUG:trainer:Train Epoch: 55 [64/66 (97%)] Loss: 0.358420
# INFO:trainer:    epoch          : 55
# INFO:trainer:    loss           : 0.4402362528172406
# INFO:trainer:    accuracy       : 0.7933238636363636
# INFO:trainer:    f1_score       : 0.8023261200718081
# INFO:trainer:    val_loss       : 0.4125986397266388
# INFO:trainer:    val_accuracy   : 0.8148371848739496
# INFO:trainer:    val_f1_score   : 0.8487097337955145
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.761252446183953
# INFO:trainer:    val_MAcc       : 0.8149327924350422
# INFO:trainer:    val_F1_score   : 0.830715532286213
# DEBUG:trainer:Train Epoch: 56 [0/66 (0%)] Loss: 0.360263
# DEBUG:trainer:Train Epoch: 56 [8/66 (12%)] Loss: 0.629257
# DEBUG:trainer:Train Epoch: 56 [16/66 (24%)] Loss: 0.425913
# DEBUG:trainer:Train Epoch: 56 [24/66 (36%)] Loss: 0.382796
# DEBUG:trainer:Train Epoch: 56 [32/66 (48%)] Loss: 0.398756
# DEBUG:trainer:Train Epoch: 56 [40/66 (61%)] Loss: 0.338016
# DEBUG:trainer:Train Epoch: 56 [48/66 (73%)] Loss: 0.347295
# DEBUG:trainer:Train Epoch: 56 [56/66 (85%)] Loss: 0.432342
# DEBUG:trainer:Train Epoch: 56 [64/66 (97%)] Loss: 0.607732
# INFO:trainer:    epoch          : 56
# INFO:trainer:    loss           : 0.41947297119733057
# INFO:trainer:    accuracy       : 0.7975852272727273
# INFO:trainer:    f1_score       : 0.805950946229958
# INFO:trainer:    val_loss       : 0.41401783508412976
# INFO:trainer:    val_accuracy   : 0.8157563025210085
# INFO:trainer:    val_f1_score   : 0.8490716010285837
# INFO:trainer:    val_sensitivity: 0.8686131386861314
# INFO:trainer:    val_specificity: 0.7632093933463796
# INFO:trainer:    val_MAcc       : 0.8159112660162555
# INFO:trainer:    val_F1_score   : 0.8314410480349343
# DEBUG:trainer:Train Epoch: 57 [0/66 (0%)] Loss: 0.420095
# DEBUG:trainer:Train Epoch: 57 [8/66 (12%)] Loss: 0.377506
# DEBUG:trainer:Train Epoch: 57 [16/66 (24%)] Loss: 0.532900
# DEBUG:trainer:Train Epoch: 57 [24/66 (36%)] Loss: 0.376706
# DEBUG:trainer:Train Epoch: 57 [32/66 (48%)] Loss: 0.379499
# DEBUG:trainer:Train Epoch: 57 [40/66 (61%)] Loss: 0.471239
# DEBUG:trainer:Train Epoch: 57 [48/66 (73%)] Loss: 0.508651
# DEBUG:trainer:Train Epoch: 57 [56/66 (85%)] Loss: 0.427125
# DEBUG:trainer:Train Epoch: 57 [64/66 (97%)] Loss: 0.449411
# INFO:trainer:    epoch          : 57
# INFO:trainer:    loss           : 0.4362016139608441
# INFO:trainer:    accuracy       : 0.7679924242424242
# INFO:trainer:    f1_score       : 0.776615220650945
# INFO:trainer:    val_loss       : 0.4149998356314266
# INFO:trainer:    val_accuracy   : 0.8065651260504202
# INFO:trainer:    val_f1_score   : 0.8344126809886909
# INFO:trainer:    val_sensitivity: 0.8467153284671532
# INFO:trainer:    val_specificity: 0.7671232876712328
# INFO:trainer:    val_MAcc       : 0.806919308069193
# INFO:trainer:    val_F1_score   : 0.8205128205128205
# INFO:trainer:Validation performance didn't improve for 30 epochs. Training stops.
# === HOÀN THÀNH TRAINING ===
# Model tốt nhất được lưu tại:
# /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0226_172452/model_best.pth

# %% [markdown]
# # Test

# %%
from sklearn.metrics import f1_score, confusion_matrix
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import pandas as pd

def test_model(config, best_model_path, validation_fea_path, validation_label_csv):
    config_parser = ConfigParser(config)
    device, _ = prepare_device(config_parser['n_gpu'])

    # Khởi tạo model từ config (đảm bảo architecture đúng)
    model = config_parser.init_obj('arch', globals())
    model = model.to(device)

    # === LOAD CHỈ STATE_DICT - AN TOÀN, KHÔNG CẦN WHITELIST ===
    try:
        # Cách 1: Dùng weights_only=True (mặc định từ PT 2.6), chỉ load weights
        checkpoint = torch.load(best_model_path, map_location=device, weights_only=True)
        model.load_state_dict(checkpoint)  # checkpoint ở đây chỉ là state_dict
        print("Loaded model weights with weights_only=True (safe mode)")
    except Exception as e1:
        print(f"weights_only=True failed: {e1}")
        try:
            # Cách 2: Tắt weights_only (chỉ dùng nếu bạn tin tưởng file)
            checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
            model.load_state_dict(checkpoint['state_dict'])
            print("Loaded with weights_only=False (full checkpoint)")
        except Exception as e2:
            print(f"Cả hai cách đều thất bại: {e2}")
            return

    model.eval()

    print("\n=== MODEL ARCHITECTURE ===")
    print(model)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\nSố tham số huấn luyện được: {trainable_params:,}")

    # === Xác định input shape từ config ===
    delta = config['data_loader']['args'].get('delta', False)
    n_mfcc = config['data_loader']['args'].get('n_mfcc', 39)
    time_frames = 333

    channels = 3 if delta else 1   # static + Δ + ΔΔ nếu có
    height = n_mfcc

    # === Kiểm tra forward với input giả ===
    print("\n=== KIỂM TRA FORWARD PASS ===")
    try:
        with torch.no_grad():
            dummy_input = torch.randn(2, channels * height, time_frames)
            output = model(dummy_input)
            print(f"Input shape: (B, {channels * height}, {time_frames})")
            print(f"Output shape: {output.shape} → OK")
    except Exception as e:
        print(f"Forward lỗi: {e}")

    # === Load validation data ===
    if not Path(validation_label_csv).exists() or not Path(validation_fea_path).exists():
        print("Không tìm thấy file validation → bỏ qua đánh giá")
        return

    validation_label_df = pd.read_csv(validation_label_csv)
    validation_label_df['filename'] = validation_label_df['filename'].apply(lambda x: Path(x).stem)

    validation_dataset = HeartSoundDataSet(
        fea_path=validation_fea_path,
        labels=validation_label_df,
        duration=config['data_loader']['args']['duration'],
        training=False,
        delta=delta,
        norm=config['data_loader']['args'].get('norm', True)
    )

    print("\n=== DEBUG: SAMPLE FEATURES ===")
    for i in range(min(5, len(validation_dataset))):
        fea, lab = validation_dataset[i]
        print(f"Sample {i}: shape = {fea.shape}, label = {lab.item()}")

    # Tắt pin_memory trên CPU
    pin_memory = (device.type == 'cuda')

    validation_dataloader = DataLoader(
        validation_dataset,
        batch_size=config['data_loader']['args']['batch_size'],
        shuffle=False,
        num_workers=config['data_loader']['args'].get('num_workers', 2),
        pin_memory=pin_memory
    )

    criterion = ce_loss

    print("\n=== ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===")
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    val_TP = val_TN = val_pred_pos = val_condition_pos = 0

    with torch.no_grad():
        for data, target in validation_dataloader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            total_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, 1)
            total_correct += (pred == target).sum().item()
            total_samples += target.size(0)

            pred_pos_idx = (pred == 1)      # class 1 = abnormal (positive)
            condition_pos_idx = (target == 1)

            val_TP += (pred_pos_idx & condition_pos_idx).sum().item()
            val_TN += ((pred == 0) & (target == 0)).sum().item()
            val_pred_pos += pred_pos_idx.sum().item()
            val_condition_pos += condition_pos_idx.sum().item()

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    sensitivity = val_TP / val_condition_pos if val_condition_pos > 0 else 0
    specificity = val_TN / (total_samples - val_condition_pos) if (total_samples - val_condition_pos) > 0 else 0
    MAcc = (sensitivity + specificity) / 2
    precision = val_TP / val_pred_pos if val_pred_pos > 0 else 0
    F1_score = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0

    val_log = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'MAcc': MAcc,
        'F1_score': F1_score
    }

    print("\nKết quả đánh giá:")
    for k, v in val_log.items():
        print(f"    {k}: {v:.4f}")

    metrics_path = Path(best_model_path).parent / "test_on_validation_set_metrics.csv"
    pd.DataFrame([val_log]).to_csv(metrics_path, index=False)
    print(f"\nĐã lưu kết quả tại: {metrics_path}")

# %%
base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
if base_dir.exists():
        latest_run = max(base_dir.iterdir(), key=os.path.getmtime)
        best_model_path = latest_run / "model_best.pth"

        validation_fea_path = str(DATASET_PATH / "mfcc_features_validation.h5")
        validation_label_csv = str(DATASET_PATH / "label_validation.csv")  # Đảm bảo file này tồn tại!

        if Path(validation_fea_path).exists() and Path(validation_label_csv).exists():
            test_model(current_config, best_model_path, validation_fea_path, validation_label_csv)
        else:
            print("Không tìm thấy file validation .h5 hoặc label_validation.csv → Bỏ qua phần test.")

        size_bytes = os.path.getsize(best_model_path)
        size_mb = size_bytes / (1024 * 1024)

        print(f"Model size: {size_mb:.2f} MB")

else:
    print("Không tìm thấy thư mục saved models.")
# Out:
# weights_only=True failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.ConfigParser was not an allowed global by default. Please use `torch.serialization.add_safe_globals([__main__.ConfigParser])` or the `torch.serialization.safe_globals([__main__.ConfigParser])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Loaded with weights_only=False (full checkpoint)
#
# === MODEL ARCHITECTURE ===
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (stage1): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#       (4): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage2): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48, bias=False)
#       (4): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (stage3): ShuffleBlock(
#     (branch_left): Sequential(
#       (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#       (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU6(inplace=True)
#     )
#     (branch_right): Sequential(
#       (0): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU6(inplace=True)
#     )
#   )
#   (drop): Dropout2d(p=0.3, inplace=False)
#   (se): SEBlock(
#     (squeeze): AdaptiveAvgPool2d(output_size=1)
#     (excitation): Sequential(
#       (0): Linear(in_features=128, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (spatial_attn): Sequential(
#     (0): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): Sigmoid()
#   )
#   (dropout): Dropout(p=0.4, inplace=False)
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU6()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=32, out_features=2, bias=True)
#   )
# )
#
# Số tham số huấn luyện được: 36,386
#
# === KIỂM TRA FORWARD PASS ===
# Forward lỗi: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor
#
# === DEBUG: SAMPLE FEATURES ===
# Sample 0: shape = torch.Size([39, 333]), label = 1
# Sample 1: shape = torch.Size([39, 333]), label = 1
# Sample 2: shape = torch.Size([39, 333]), label = 1
# Sample 3: shape = torch.Size([39, 333]), label = 1
# Sample 4: shape = torch.Size([39, 333]), label = 1
#
# === ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===
#
# Kết quả đánh giá:
#     loss: 0.5844
#     accuracy: 0.6844
#     sensitivity: 0.9139
#     specificity: 0.4533
#     MAcc: 0.6836
#     F1_score: 0.7439
#
# Đã lưu kết quả tại: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0226_172452/test_on_validation_set_metrics.csv
# Model size: 0.68 MB
