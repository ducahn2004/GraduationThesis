# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/wav_example')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/wav_example')

# %% [markdown]
# ```
# <base>/
# ├── annotations/
# ├── papers/
# ├── sources/
# ├── training-a/
# ├── training-b/
# ├── training-c/
# ├── training-d/
# ├── training-e/
# ├── training-f/
# ├── validation/
# ├── training.zip
# ├── validation.zip
# └── README / figure / sample files
# ```

# %% [markdown]
# ```
# training-a/
# ├── a0001.wav
# ├── a0001.hea
# ├── a0001.dat
# ├── a0002.wav
# ├── a0002.hea
# ├── a0002.dat
# ├── ...
# ├── REFERENCE.csv
# ├── REFERENCE-SQI.csv
# ├── RECORDS
# ├── RECORDS-normal
# ├── RECORDS-abnormal
# ├── MD5SUMS / SHA1SUMS / SHA256SUMS
# ```

# %%
import numpy as np
import pandas as pd
import librosa
from tqdm import tqdm
import soundfile
import h5py
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import json
import torch
import librosa
from pathlib import Path
from itertools import repeat
from collections import OrderedDict
from scipy.signal import butter, lfilter
from sklearn.model_selection import train_test_split
import glob
import os
from collections import Counter

import librosa

# %%
wav_files = glob.glob("/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/wav_example/*.wav")

normal_files = []
abnormal_files = []

for f in wav_files:
    hea_file = f.replace(".wav", ".hea")
    if os.path.exists(hea_file):
        with open(hea_file, "r") as hf:
            for line in hf:
                line = line.strip().lower()
                if line.startswith("# normal"):
                    normal_files.append(f)
                    break
                elif line.startswith("# abnormal"):
                    abnormal_files.append(f)
                    break

print("Tổng số file:", len(wav_files))
print("Normal:", len(normal_files))
print("Abnormal:", len(abnormal_files))
# Out:
# Tổng số file: 10
# Normal: 2
# Abnormal: 8

# %% [markdown]
# # Đọc audio & tiền xử lý tín hiệu

# %%
def read_audio(path, target_fs=None, filter=False,
               lowcut = 25, hightcut = 400):
    (audio, fs) = soundfile.read(path)

    if audio.ndim > 1:
        audio = np.mean(audio, axis=1)

    if target_fs is not None and fs != target_fs:
        audio = librosa.resample(audio, orig_sr = fs, target_sr = target_fs)
        fs = target_fs
    if filter:
        # apply bandpass filter
        audio = butter_bandpass_filter(audio, lowcut, hightcut, fs)
    return audio, fs

# %%
def butter_bandpass(lowcut, hightcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = hightcut / nyq
    b, a = butter(order, [low, high], btype='bandpass')
    return b, a

def butter_bandpass_filter(data, lowcut, hightcut, fs, order=5):
    b, a = butter_bandpass(lowcut, hightcut, fs, order=order)
    y = lfilter(b,a, data)
    return y

# %%
def augment_audio(audio, fs):
    """Apply random augmentations to audio signal."""
    if random.random() < 0.5:
        # Add Gaussian noise
        noise = np.random.normal(0, 0.01 * np.std(audio), len(audio))
        audio += noise

    if random.random() < 0.5:
        # Time shift (roll)
        shift = random.randint(-len(audio)//10, len(audio)//10)
        audio = np.roll(audio, shift)

    if random.random() < 0.5:
        # Pitch shift
        n_steps = random.uniform(-2, 2)
        audio = librosa.effects.pitch_shift(audio, sr=fs, n_steps=n_steps)

    if random.random() < 0.5:
        # Time stretch
        rate = random.uniform(0.8, 1.2)
        audio = librosa.effects.time_stretch(audio, rate=rate)

    if random.random() < 0.2:
        # Polarity inversion
        audio = -audio

    return audio

# %% [markdown]
# # MFCC Extractor

# %%
import numpy as np
import librosa

def MfccExtractor(
    data,
    sr,
    n_mfcc=13,
    window='hamming',
    hoplen=15,   # ms
    winlen=25,   # ms
    T_fixed=100,
    pre_emphasis=0.97,
    snv=False
):
    """
    MFCC extraction pipeline (academic / thesis-consistent):

    Steps:
    1. Pre-emphasis
    2. Framing & Windowing (librosa, Hamming)
    3. FFT + Power Spectrum
    4. Mel filter banks
    5. DCT → MFCC (12 cepstral + 1 energy)
    6. Delta & Delta-Delta
    7. Temporal truncation / zero-padding to fixed T

    Output:
        MFCC feature map with shape (39, T_fixed)
    """

    # =========================
    # 1. Pre-emphasis
    # =========================
    if pre_emphasis is not None:
        data = np.append(data[0], data[1:] - pre_emphasis * data[:-1])

    # =========================
    # 2. MFCC computation
    # =========================
    hop_length = int(sr * hoplen / 1000)
    win_length = int(sr * winlen / 1000)

    mfcc = librosa.feature.mfcc(
        y=data,
        sr=sr,
        n_mfcc=n_mfcc,
        window=window,
        hop_length=hop_length,
        win_length=win_length
    )  # (13, T)

    # =========================
    # 3. Delta & Delta-Delta
    # =========================
    delta = librosa.feature.delta(mfcc, order=1)
    delta2 = librosa.feature.delta(mfcc, order=2)

    mfcc_39 = np.vstack([mfcc, delta, delta2])  # (39, T)

    # =========================
    # 4. Optional SNV normalization
    # =========================
    if snv:
        mean = np.mean(mfcc_39, axis=1, keepdims=True)
        std = np.std(mfcc_39, axis=1, keepdims=True) + 1e-8
        mfcc_39 = (mfcc_39 - mean) / std

    # =========================
    # 5. Temporal normalization
    # =========================
    T = mfcc_39.shape[1]

    if T >= T_fixed:
        mfcc_39 = mfcc_39[:, :T_fixed]
    else:
        pad = T_fixed - T
        mfcc_39 = np.pad(
            mfcc_39,
            ((0, 0), (0, pad)),
            mode="constant"
        )

    return mfcc_39.astype(np.float32)  # (39, T_fixed)

# %%
EPS = 1E-8
def LogMelExtractor(
    data,
    sr,
    mel_bins=128,
    hoplen=15,
    winlen=25,
    log=True,
    snv=False
):
    """
    Log-Mel spectrogram extractor
    """

    hop_length = int(sr * hoplen / 1000)
    win_length = int(sr * winlen / 1000)

    mel = librosa.feature.melspectrogram(
        y=data,
        sr=sr,
        n_mels=mel_bins,
        hop_length=hop_length,
        win_length=win_length
    )

    if log:
        mel = np.log(mel + EPS)

    if snv:
        mel = standard_normal_variate(mel)

    return mel.astype(np.float32)

# %%
def standard_normal_variate(data):
    mean = np.mean(data)
    std = np.std(data)

    return (data - mean) / std

# %%
data_processing_path = Path(PROJECT_PATH) / 'data_processing'
data_processing_path.mkdir(parents=True, exist_ok=True)

# %%
import pandas as pd
import os
import sys
from pathlib import Path
from tqdm import tqdm  # Included as in original, though not used here

# Define the training folders based on the provided dataset structure

# Collect labels from each folder's REFERENCE.csv
dfs = []

ref_path = DATASET_PATH / 'REFERENCE.csv'
df = pd.read_csv(ref_path, header=None, names=['basename', 'label'])

# Correct way to create full filenames
df['filename'] = [str(DATASET_PATH / (base + '.wav')) for base in df['basename']]

# Convert labels: -1 → 0, 1 → 1 (or abnormal → 1)
df['label'] = (df['label'] + 1) // 2

dfs.append(df[['filename', 'label']])

# Concatenate all dataframes and save to label.csv
all_df = pd.concat(dfs, ignore_index=True)
save_path = PROJECT_PATH / 'data' / 'label.csv'
save_dir = save_path.parent
os.makedirs(str(save_dir), exist_ok=True)
all_df.to_csv(str(save_path), index=False)

print(f"Created {str(save_path)} with {len(all_df)} entries.")
# Out:
# Created /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/wav_example/data/label.csv with 10 entries.

# %%
print(type(df['filename']))
print(df['filename'].head(10))
print(repr(df['filename'].iloc[0]))
print("First element type:", type(df['filename'].iloc[0]) if len(df) > 0 else "empty")
# Out:
# <class 'pandas.core.series.Series'>
# 0    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 1    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 2    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 3    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 4    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 5    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 6    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 7    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 8    /content/drive/MyDrive/AutomaticHeartSoundClas...
# 9    /content/drive/MyDrive/AutomaticHeartSoundClas...
# Name: filename, dtype: object
# '/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/wav_example/a0001.wav'
# First element type: <class 'str'>

# %%
import os
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter
from pathlib import Path

# =========================
# read_audio()
# augment_audio()
# PROJECT_PATH
# MfccExtractor()
# LogMelExtractor()
# =========================

if __name__ == "__main__":

    df = pd.read_csv(PROJECT_PATH / "data" / "label.csv")

    logmel_folder = PROJECT_PATH / "logmel_features"
    mfcc_folder   = PROJECT_PATH / "mfcc_features"

    os.makedirs(logmel_folder, exist_ok=True)
    os.makedirs(mfcc_folder, exist_ok=True)

    # ===== Class balancing =====
    label_counts = Counter(df["label"])
    n_normal   = label_counts[0]
    n_abnormal = label_counts[1]

    target_abnormal = n_normal
    augment_per_abnormal = int(
        np.ceil((target_abnormal - n_abnormal) / n_abnormal)
    )

    print("=== ORIGINAL DISTRIBUTION ===")
    print(f"Normal  : {n_normal}")
    print(f"Abnormal: {n_abnormal}")
    print(f"Augment per abnormal sample: {augment_per_abnormal}")

    # ===== Feature parameters =====
    mel_bins = 128
    n_mfcc   = 13
    hoplen   = 15   # ms
    winlen   = 25   # ms
    T_fixed  = 100
    # =========================
    # Feature extraction
    # =========================
    for _, row in tqdm(df.iterrows(), total=len(df)):

        filename = row["filename"]
        label    = row["label"]

        audio, fs = read_audio(filename, filter=True)
        basename = Path(filename).stem

        # ===== ORIGINAL SAMPLE =====
        logmel = LogMelExtractor(
            audio, fs,
            mel_bins=mel_bins,
            hoplen=hoplen,
            winlen=winlen
        )

        mfcc = MfccExtractor(
            audio, fs,
            n_mfcc=n_mfcc,
            hoplen=hoplen,
            winlen=winlen,
            T_fixed=T_fixed
        )

        np.save(logmel_folder / f"{basename}.npy", logmel)
        np.save(mfcc_folder   / f"{basename}.npy", mfcc)

        # ===== AUGMENTATION (Abnormal only) =====
        if label == 1:
            for k in range(augment_per_abnormal):

                aug_audio = augment_audio(audio.copy(), fs)
                aug_name = f"{basename}_aug{k}"

                logmel_aug = LogMelExtractor(
                    aug_audio, fs,
                    mel_bins=mel_bins,
                    hoplen=hoplen,
                    winlen=winlen
                )

                mfcc_aug = MfccExtractor(
                    aug_audio, fs,
                    n_mfcc=n_mfcc,
                    hoplen=hoplen,
                    winlen=winlen,
                    T_fixed=T_fixed
                )

                np.save(logmel_folder / f"{aug_name}.npy", logmel_aug)
                np.save(mfcc_folder   / f"{aug_name}.npy", mfcc_aug)

    print("\n✅ Feature extraction + augmentation completed.")
# Out:
# === ORIGINAL DISTRIBUTION ===
# Normal  : 2
# Abnormal: 8
# Augment per abnormal sample: 0
# 100%|██████████| 10/10 [00:23<00:00,  2.37s/it]
# ✅ Feature extraction + augmentation completed.

# %%
logmel_folder = PROJECT_PATH / "logmel_features"
mfcc_folder   = PROJECT_PATH / "mfcc_features"

label_counts = Counter(df["label"])
n_normal   = label_counts[0]
n_abnormal = label_counts[1]

target_abnormal = n_normal
augment_per_abnormal = int(
    np.ceil((target_abnormal - n_abnormal) / n_abnormal)
)

# %%
aug_rows = []

for _, row in df.iterrows():
    if row["label"] == 1:
        base = Path(row["filename"]).stem
        for k in range(augment_per_abnormal):
            aug_rows.append({
                "filename": f"{base}_aug{k}",  # hoặc .npy tùy Dataset loader
                "label": 1
            })

df_balanced = pd.concat([df, pd.DataFrame(aug_rows)], ignore_index=True)
df_balanced.to_csv(PROJECT_PATH / "data" / "label_balanced.csv", index=False)

# %%
import os
import random
import numpy as np
import librosa.display
import matplotlib.pyplot as plt
from pathlib import Path

# ========================
# Kiểm tra một mẫu ngẫu nhiên: audio gốc + MFCC + LogMel đã trích xuất
# ========================

# Đường dẫn tới các thư mục
original_audio_root = Path("/content/drive/MyDrive/physionet2016")  # thư mục chứa training-a đến training-f
logmel_folder = Path(logmel_folder)  # giữ nguyên từ phần main trước đó
mfcc_folder   = Path(mfcc_folder)

# Lấy danh sách tất cả các file .npy đã lưu (cùng basename)
logmel_files = {f.stem: f for f in logmel_folder.glob("*.npy")}
mfcc_files   = {f.stem: f for f in mfcc_folder.glob("*.npy")}

# Tìm các basename có cả MFCC và LogMel
common_basenames = set(logmel_files.keys()) & set(mfcc_files.keys())

if len(common_basenames) == 0:
    print("Không tìm thấy file đặc trưng nào trong thư mục.")
else:
    # Chọn ngẫu nhiên một basename
    chosen_basename = random.choice(list(common_basenames))
    print(f"Đã chọn mẫu ngẫu nhiên: {chosen_basename}.wav\n")

    # Tìm đường dẫn file .wav gốc (dựa trên cấu trúc PhysioNet 2016)
    folder_letter = chosen_basename[0]  # a, b, c, d, e, f
    wav_path = original_audio_root / f"training-{folder_letter}" / f"{chosen_basename}.wav"

    if not wav_path.exists():
        print(f"Không tìm thấy file audio gốc: {wav_path}")
    else:
        print(f"Đường dẫn audio gốc: {wav_path}")

        # 1. Đọc file .wav gốc
        audio, sr = librosa.load(wav_path, sr=None)  # giữ nguyên sampling rate gốc (thường là 2000 Hz)
        print(f"   Audio length: {len(audio)} samples | Duration: {len(audio)/sr:.2f} seconds | SR: {sr} Hz")

        # 2. Đọc file Log Mel đã lưu
        logmel_path = logmel_folder / logmel_files[chosen_basename]
        logmel_feat = np.load(logmel_path)
        print(f"   Log Mel shape: {logmel_feat.shape} | dtype: {logmel_feat.dtype}")
        print(f"   Log Mel min/max: {logmel_feat.min():.4f} / {logmel_feat.max():.4f}")

        # 3. Đọc file MFCC đã lưu
        mfcc_path = mfcc_folder / mfcc_files[chosen_basename]
        mfcc_feat = np.load(mfcc_path)
        print(f"   MFCC shape   : {mfcc_feat.shape} | dtype: {mfcc_feat.dtype}")
        print(f"   MFCC min/max : {mfcc_feat.min():.4f} / {mfcc_feat.max():.4f}")

        # ========================
        # Tùy chọn: Vẽ waveform + spectrogram + MFCC để kiểm tra trực quan
        # ========================
        plt.figure(figsize=(14, 8))

        # Waveform
        plt.subplot(3, 1, 1)
        librosa.display.waveshow(audio, sr=sr)
        plt.title(f"Waveform - {chosen_basename}.wav")

        # Log Mel Spectrogram
        plt.subplot(3, 1, 2)
        librosa.display.specshow(logmel_feat, sr=sr, hop_length=int(sr * 15 / 1000), x_axis='time', y_axis='mel', cmap='viridis')
        plt.colorbar(format='%+2.0f dB')
        plt.title("Log Mel Spectrogram")

        # MFCC
        plt.subplot(3, 1, 3)
        librosa.display.specshow(mfcc_feat, sr=sr, hop_length=int(sr * 15 / 1000), x_axis='time', cmap='viridis')
        plt.colorbar()
        plt.title("MFCC")

        plt.tight_layout()
        plt.show()
# Out:
# Đã chọn mẫu ngẫu nhiên: a0009.wav
#
# Đường dẫn audio gốc: /content/drive/MyDrive/physionet2016/training-a/a0009.wav
#    Audio length: 71611 samples | Duration: 35.81 seconds | SR: 2000 Hz
#    Log Mel shape: (128, 2388) | dtype: float32
#    Log Mel min/max: -18.4207 / 0.0691
#    MFCC shape   : (39, 100) | dtype: float32
#    MFCC min/max : -802.9960 / 290.4186

# %% [markdown]
# ## Create .h5py for logmel_features

# %%
# Cell: Chuyển tất cả file .npy sang một file .h5 lớn (CHỈ CHẠY 1 LẦN)
import numpy as np
import h5py
from pathlib import Path
from tqdm.notebook import tqdm  # Để có progress bar đẹp

FEATURES_DIR = PROJECT_PATH /"logmel_features"  # Thư mục chứa các .npy
OUTPUT_H5 = PROJECT_PATH /"data"/"logmel_features.h5"   # File output

if OUTPUT_H5.exists():
    print(f"File {OUTPUT_H5} ĐÃ TỒN TẠI – bỏ qua việc tạo lại.")
    print("Nếu muốn tạo lại, xóa file này trước: !rm '{OUTPUT_H5}'")
else:
    print("Đang chuyển đổi tất cả .npy sang .h5 ... (có thể mất vài phút tùy số lượng file)")
    npy_files = list(FEATURES_DIR.glob("*.npy"))
    print(f"Tìm thấy {len(npy_files)} file .npy")

    with h5py.File(OUTPUT_H5, 'w') as f_out:
      for npy_file in tqdm(npy_files):
          key = npy_file.stem
          data = np.load(npy_file)

          # Chỉ chấp nhận (M, T)
          assert data.ndim == 2, f"{key} has invalid shape {data.shape}"

          f_out.create_dataset(
              key,
              data=data.astype(np.float32),
              compression="gzip"
          )

    print(f"HOÀN THÀNH! File đã tạo: {OUTPUT_H5}")
# Out:
# Đang chuyển đổi tất cả .npy sang .h5 ... (có thể mất vài phút tùy số lượng file)
# Tìm thấy 5235 file .npy
#   0%|          | 0/5235 [00:00<?, ?it/s]
# HOÀN THÀNH! File đã tạo: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/logmel_features.h5

# %%
import h5py

OUTPUT_H5 = PROJECT_PATH /"data"/"logmel_features.h5"
h5_path = str(OUTPUT_H5)

with h5py.File(h5_path, "r") as f:
    for key in f.keys():
        obj = f[key]
        if isinstance(obj, h5py.Group):
            print(f"[GROUP]   {key}")
            for subkey in obj.keys():
                subobj = obj[subkey]
                if isinstance(subobj, h5py.Dataset):
                    print(f"    └── [DATASET] {subkey}, shape={subobj.shape}")
        else:
            print(f"[DATASET] {key}, shape={obj.shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [DATASET] a0075_aug1, shape=(128, 2383)
# [DATASET] a0075_aug2, shape=(128, 2383)
# [DATASET] a0076, shape=(128, 2378)
# [DATASET] a0076_aug0, shape=(128, 2692)
# [DATASET] a0076_aug1, shape=(128, 2378)
# [DATASET] a0076_aug2, shape=(128, 2378)
# [DATASET] a0077, shape=(128, 2383)
# [DATASET] a0077_aug0, shape=(128, 2383)
# [DATASET] a0077_aug1, shape=(128, 2447)
# [DATASET] a0077_aug2, shape=(128, 2022)
# [DATASET] a0078, shape=(128, 2383)
# [DATASET] a0078_aug0, shape=(128, 2383)
# [DATASET] a0078_aug1, shape=(128, 2687)
# [DATASET] a0078_aug2, shape=(128, 2448)
# [DATASET] a0079, shape=(128, 2044)
# [DATASET] a0079_aug0, shape=(128, 2044)
# [DATASET] a0079_aug1, shape=(128, 1843)
# [DATASET] a0079_aug2, shape=(128, 2044)
# [DATASET] a0080, shape=(128, 2067)
# [DATASET] a0081, shape=(128, 2378)
# [DATASET] a0082, shape=(128, 2044)
# [DATASET] a0082_aug0, shape=(128, 1715)
# [DATASET] a0082_aug1, shape=(128, 1964)
# [DATASET] a0082_aug2, shape=(128, 2044)
# [DATASET] a0083, shape=(128, 2378)
# [DATASET] a0083_aug0, shape=(128, 2228)
# [DATASET] a0083_aug1, shape=(128, 2725)
# [DATASET] a0083_aug2, shape=(128, 2378)
# [DATASET] a0084, shape=(128, 2053)
# [DATASET] a0084_aug0, shape=(128, 2479)
# [DATASET] a0084_aug1, shape=(128, 1881)
# [DATASET] a0084_aug2, shape=(128, 1957)
# [DATASET] a0400_aug2, shape=(128, 1027)
# [DATASET] a0401, shape=(128, 2415)
# [DATASET] a0402, shape=(128, 2420)
# [DATASET] a0402_aug0, shape=(128, 2169)
# [DATASET] a0402_aug1, shape=(128, 2420)
# [DATASET] a0402_aug2, shape=(128, 2420)
# [DATASET] a0403, shape=(128, 2420)
# [DATASET] a0403_aug0, shape=(128, 2627)
# [DATASET] a0403_aug1, shape=(128, 2420)
# [DATASET] a0403_aug2, shape=(128, 2091)
# [DATASET] a0404, shape=(128, 2053)
# [DATASET] a0404_aug0, shape=(128, 2407)
# [DATASET] a0404_aug1, shape=(128, 2400)
# [DATASET] a0404_aug2, shape=(128, 2053)
# [DATASET] a0405, shape=(128, 836)
# [DATASET] a0406, shape=(128, 2374)
# [DATASET] a0407, shape=(128, 2378)
# [DATASET] a0408, shape=(128, 2039)
# [DATASET] a0409, shape=(128, 2049)
# [DATASET] b0001, shape=(128, 534)
# [DATASET] b0002, shape=(128, 534)
# [DATASET] b0003, shape=(128, 534)
# [DATASET] b0004, shape=(128, 534)
# [DATASET] b0005, shape=(128, 534)
# [DATASET] b0006, shape=(128, 534)
# [DATASET] b0007, shape=(128, 534)
# [DATASET] b0008, shape=(128, 534)
# [DATASET] b0008_aug0, shape=(128, 534)
# [DATASET] b0008_aug1, shape=(128, 534)
# [DATASET] b0008_aug2, shape=(128, 534)
# [DATASET] b0009, shape=(128, 534)
# [DATASET] b0010, shape=(128, 534)
# [DATASET] b0011, shape=(128, 534)
# [DATASET] b0012, shape=(128, 534)
# [DATASET] b0013, shape=(128, 534)
# [DATASET] b0013_aug0, shape=(128, 534)
# [DATASET] b0013_aug1, shape=(128, 450)
# [DATASET] b0013_aug2, shape=(128, 534)
# [DATASET] b0014, shape=(128, 534)
# [DATASET] b0015, shape=(128, 534)
# [DATASET] b0016, shape=(128, 534)
# [DATASET] b0016_aug0, shape=(128, 526)
# [DATASET] b0016_aug1, shape=(128, 534)
# [DATASET] b0016_aug2, shape=(128, 622)
# [DATASET] b0017, shape=(128, 534)
# [DATASET] b0018, shape=(128, 534)
# [DATASET] b0018_aug0, shape=(128, 534)
# [DATASET] b0018_aug1, shape=(128, 498)
# [DATASET] b0018_aug2, shape=(128, 534)
# [DATASET] b0019, shape=(128, 534)
# [DATASET] b0020, shape=(128, 534)
# [DATASET] b0021, shape=(128, 534)
# [DATASET] b0022, shape=(128, 534)
# [DATASET] b0022_aug0, shape=(128, 534)
# [DATASET] b0022_aug1, shape=(128, 563)
# [DATASET] b0022_aug2, shape=(128, 568)
# [DATASET] b0023, shape=(128, 534)
# [DATASET] b0023_aug0, shape=(128, 601)
# [DATASET] b0023_aug1, shape=(128, 489)
# [DATASET] b0023_aug2, shape=(128, 534)
# [DATASET] b0024, shape=(128, 534)
# [DATASET] b0025, shape=(128, 534)
# [DATASET] b0026, shape=(128, 534)
# [DATASET] b0027, shape=(128, 534)
# [DATASET] b0028, shape=(128, 534)
# [DATASET] b0029, shape=(128, 534)
# [DATASET] b0030, shape=(128, 534)
# [DATASET] b0114, shape=(128, 534)
# [DATASET] b0115, shape=(128, 534)
# [DATASET] b0116, shape=(128, 534)
# [DATASET] b0117, shape=(128, 534)
# [DATASET] b0117_aug0, shape=(128, 572)
# [DATASET] b0117_aug1, shape=(128, 534)
# [DATASET] b0117_aug2, shape=(128, 499)
# [DATASET] b0118, shape=(128, 534)
# [DATASET] b0119, shape=(128, 534)
# [DATASET] b0120, shape=(128, 534)
# [DATASET] b0120_aug0, shape=(128, 537)
# [DATASET] b0120_aug1, shape=(128, 534)
# [DATASET] b0120_aug2, shape=(128, 534)
# [DATASET] b0121, shape=(128, 534)
# [DATASET] b0122, shape=(128, 524)
# [DATASET] b0123, shape=(128, 534)
# [DATASET] b0124, shape=(128, 534)
# [DATASET] b0125, shape=(128, 534)
# [DATASET] b0126, shape=(128, 534)
# [DATASET] b0127, shape=(128, 534)
# [DATASET] b0128, shape=(128, 518)
# [DATASET] b0129, shape=(128, 534)
# [DATASET] b0130, shape=(128, 534)
# [DATASET] b0130_aug0, shape=(128, 566)
# [DATASET] b0130_aug1, shape=(128, 485)
# [DATASET] b0130_aug2, shape=(128, 631)
# [DATASET] b0131, shape=(128, 534)
# ...
# [DATASET] e01979, shape=(128, 2539)
# [DATASET] e01980, shape=(128, 963)
# [DATASET] e01981, shape=(128, 2396)
# [DATASET] e01982, shape=(128, 2052)
# [DATASET] e01983, shape=(128, 1304)
# [DATASET] e01984, shape=(128, 949)
# [DATASET] e01985, shape=(128, 1217)
# [DATASET] e01986, shape=(128, 3129)
# [DATASET] e01987, shape=(128, 1208)
# [DATASET] e01988, shape=(128, 1109)
# [DATASET] e01989, shape=(128, 1158)
# [DATASET] e01990, shape=(128, 749)
# [DATASET] e01991, shape=(128, 691)
# [DATASET] e01992, shape=(128, 1586)
# [DATASET] e01992_aug0, shape=(128, 1586)
# [DATASET] e01992_aug1, shape=(128, 1499)
# [DATASET] e01992_aug2, shape=(128, 1586)
# [DATASET] e01993, shape=(128, 4282)
# [DATASET] e01994, shape=(128, 1063)
# [DATASET] e01995, shape=(128, 1434)
# [DATASET] e01995_aug0, shape=(128, 1292)
# [DATASET] e01995_aug1, shape=(128, 1583)
# [DATASET] e01995_aug2, shape=(128, 1434)
# [DATASET] e01996, shape=(128, 1791)
# [DATASET] e01997, shape=(128, 937)
# [DATASET] e01998, shape=(128, 1473)
# [DATASET] e01999, shape=(128, 727)
# [DATASET] e02000, shape=(128, 1787)
# [DATASET] e02001, shape=(128, 1521)
# [DATASET] e02002, shape=(128, 1166)
# [DATASET] e02003, shape=(128, 4287)
# [DATASET] e02004, shape=(128, 898)
# [DATASET] e02005, shape=(128, 1017)
# [DATASET] e02006, shape=(128, 611)
# [DATASET] e02007, shape=(128, 1301)
# [DATASET] e02008, shape=(128, 1172)
# [DATASET] e02009, shape=(128, 1862)
# [DATASET] e02010, shape=(128, 1408)
# [DATASET] e02011, shape=(128, 1471)
# [DATASET] e02012, shape=(128, 1245)
# [DATASET] e02013, shape=(128, 1330)
# [DATASET] e02014, shape=(128, 2230)
# [DATASET] e02015, shape=(128, 705)
# [DATASET] e02016, shape=(128, 1431)
# [DATASET] e02017, shape=(128, 2920)
# [DATASET] e02018, shape=(128, 2818)
# [DATASET] e02019, shape=(128, 1148)
# [DATASET] e02020, shape=(128, 1240)
# [DATASET] e02021, shape=(128, 989)
# [DATASET] e02022, shape=(128, 2185)
# [DATASET] e02023, shape=(128, 1130)
# [DATASET] e02024, shape=(128, 1940)
# [DATASET] e02025, shape=(128, 1944)
# [DATASET] e02026, shape=(128, 1663)
# [DATASET] e02027, shape=(128, 1528)
# [DATASET] e02028, shape=(128, 2535)
# [DATASET] e02029, shape=(128, 901)
# [DATASET] e02030, shape=(128, 1118)
# [DATASET] e02030_aug0, shape=(128, 1235)
# [DATASET] e02030_aug1, shape=(128, 1100)
# [DATASET] e02030_aug2, shape=(128, 1118)
# [DATASET] e02031, shape=(128, 612)
# [DATASET] e02032, shape=(128, 634)
# [DATASET] e02032_aug0, shape=(128, 581)
# [DATASET] e02032_aug1, shape=(128, 676)
# [DATASET] e02032_aug2, shape=(128, 675)
# [DATASET] e02033, shape=(128, 2212)
# [DATASET] e02034, shape=(128, 1427)
# [DATASET] e02035, shape=(128, 1634)
# [DATASET] e02036, shape=(128, 2772)
# [DATASET] e02037, shape=(128, 1703)
# [DATASET] e02038, shape=(128, 3415)
# [DATASET] e02039, shape=(128, 749)
# [DATASET] e02040, shape=(128, 2597)
# [DATASET] e02041, shape=(128, 589)
# [DATASET] e02042, shape=(128, 2129)
# [DATASET] e02043, shape=(128, 1460)
# [DATASET] e02044, shape=(128, 2087)
# [DATASET] e02044_aug0, shape=(128, 1898)
# [DATASET] e02044_aug1, shape=(128, 2012)
# [DATASET] e02044_aug2, shape=(128, 1799)
# [DATASET] e02045, shape=(128, 1393)
# [DATASET] e02046, shape=(128, 1408)
# [DATASET] e02047, shape=(128, 1459)
# [DATASET] e02048, shape=(128, 2589)
# [DATASET] e02049, shape=(128, 3614)
# [DATASET] e02050, shape=(128, 1404)
# [DATASET] e02051, shape=(128, 1207)
# [DATASET] e02052, shape=(128, 644)
# [DATASET] e02053, shape=(128, 1647)
# [DATASET] e02054, shape=(128, 1433)
# [DATASET] e02055, shape=(128, 984)
# [DATASET] e02056, shape=(128, 996)
# [DATASET] e02057, shape=(128, 832)
# [DATASET] e02058, shape=(128, 2097)
# [DATASET] e02059, shape=(128, 769)
# [DATASET] e02060, shape=(128, 2029)
# [DATASET] e02061, shape=(128, 971)
# [DATASET] e02062, shape=(128, 1463)
# [DATASET] e02063, shape=(128, 1250)
# [DATASET] e02064, shape=(128, 2132)
# [DATASET] e02065, shape=(128, 1059)
# [DATASET] e02065_aug0, shape=(128, 1272)
# [DATASET] e02065_aug1, shape=(128, 1059)
# [DATASET] e02065_aug2, shape=(128, 1059)
# [DATASET] e02066, shape=(128, 733)
# [DATASET] e02067, shape=(128, 1680)
# [DATASET] e02068, shape=(128, 540)
# [DATASET] e02069, shape=(128, 2503)
# [DATASET] e02070, shape=(128, 824)
# [DATASET] e02071, shape=(128, 1211)
# [DATASET] e02072, shape=(128, 736)
# [DATASET] e02073, shape=(128, 1304)
# [DATASET] e02074, shape=(128, 1346)
# [DATASET] e02074_aug0, shape=(128, 1240)
# [DATASET] e02074_aug1, shape=(128, 1346)
# [DATASET] e02074_aug2, shape=(128, 1485)
# [DATASET] e02075, shape=(128, 2009)
# [DATASET] e02076, shape=(128, 1705)
# [DATASET] e02077, shape=(128, 2519)
# [DATASET] e02078, shape=(128, 580)
# [DATASET] e02079, shape=(128, 1772)
# [DATASET] e02080, shape=(128, 2093)
# [DATASET] e02081, shape=(128, 1062)
# [DATASET] e02082, shape=(128, 1266)
# [DATASET] e02083, shape=(128, 1108)
# [DATASET] e02084, shape=(128, 2050)
# [DATASET] e02085, shape=(128, 864)
# [DATASET] e02085_aug0, shape=(128, 864)
# [DATASET] e02085_aug1, shape=(128, 864)
# [DATASET] e02085_aug2, shape=(128, 817)
# [DATASET] e02086, shape=(128, 1379)
# [DATASET] e02087, shape=(128, 616)
# [DATASET] e02088, shape=(128, 1264)
# [DATASET] e02089, shape=(128, 640)
# [DATASET] e02090, shape=(128, 1491)
# [DATASET] e02091, shape=(128, 1919)
# [DATASET] e02092, shape=(128, 860)
# [DATASET] e02093, shape=(128, 1067)
# [DATASET] e02094, shape=(128, 2438)
# [DATASET] e02095, shape=(128, 1022)
# [DATASET] e02096, shape=(128, 1155)
# [DATASET] e02097, shape=(128, 1118)
# [DATASET] e02097_aug0, shape=(128, 1128)
# [DATASET] e02097_aug1, shape=(128, 1118)
# [DATASET] e02097_aug2, shape=(128, 1189)
# [DATASET] e02098, shape=(128, 892)
# [DATASET] e02099, shape=(128, 2073)
# [DATASET] e02100, shape=(128, 819)
# [DATASET] e02101, shape=(128, 790)
# [DATASET] e02101_aug0, shape=(128, 664)
# [DATASET] e02101_aug1, shape=(128, 790)
# [DATASET] e02101_aug2, shape=(128, 913)
# [DATASET] e02102, shape=(128, 1556)
# [DATASET] e02102_aug0, shape=(128, 1556)
# [DATASET] e02102_aug1, shape=(128, 1454)
# [DATASET] e02102_aug2, shape=(128, 1341)
# [DATASET] e02103, shape=(128, 1701)
# [DATASET] e02104, shape=(128, 1038)
# [DATASET] e02105, shape=(128, 1473)
# [DATASET] e02106, shape=(128, 1307)
# [DATASET] e02107, shape=(128, 1526)
# [DATASET] e02108, shape=(128, 1281)
# [DATASET] e02108_aug0, shape=(128, 1254)
# [DATASET] e02108_aug1, shape=(128, 1240)
# [DATASET] e02108_aug2, shape=(128, 1089)
# [DATASET] e02109, shape=(128, 1686)
# [DATASET] e02110, shape=(128, 969)
# [DATASET] e02111, shape=(128, 1511)
# [DATASET] e02112, shape=(128, 1382)
# [DATASET] e02113, shape=(128, 1164)
# [DATASET] e02114, shape=(128, 2076)
# [DATASET] e02115, shape=(128, 606)
# [DATASET] e02116, shape=(128, 1496)
# [DATASET] e02117, shape=(128, 1787)
# [DATASET] e02118, shape=(128, 1419)
# [DATASET] e02119, shape=(128, 747)
# [DATASET] e02120, shape=(128, 1633)
# [DATASET] e02121, shape=(128, 838)
# [DATASET] f0082_aug2, shape=(128, 1811)
# [DATASET] f0083, shape=(128, 2359)
# [DATASET] f0083_aug0, shape=(128, 2336)
# [DATASET] f0083_aug1, shape=(128, 2359)
# [DATASET] f0083_aug2, shape=(128, 2169)
# [DATASET] f0084, shape=(128, 2282)
# [DATASET] f0085, shape=(128, 2004)
# [DATASET] f0085_aug0, shape=(128, 2004)
# [DATASET] f0085_aug1, shape=(128, 2004)
# [DATASET] f0085_aug2, shape=(128, 2004)
# [DATASET] f0086, shape=(128, 2113)
# [DATASET] f0087, shape=(128, 2119)
# [DATASET] f0088, shape=(128, 2084)
# [DATASET] f0089, shape=(128, 2164)
# [DATASET] f0089_aug0, shape=(128, 2164)
# [DATASET] f0089_aug1, shape=(128, 1857)
# [DATASET] f0089_aug2, shape=(128, 2164)
# [DATASET] f0090, shape=(128, 2001)
# [DATASET] f0090_aug0, shape=(128, 2276)
# [DATASET] f0090_aug1, shape=(128, 1925)
# [DATASET] f0090_aug2, shape=(128, 2455)
# [DATASET] f0091, shape=(128, 2490)
# [DATASET] f0092, shape=(128, 2122)
# [DATASET] f0093, shape=(128, 2045)
# [DATASET] f0093_aug0, shape=(128, 2045)
# [DATASET] f0093_aug1, shape=(128, 2045)
# [DATASET] f0093_aug2, shape=(128, 2315)
# [DATASET] f0094, shape=(128, 2023)
# [DATASET] f0095, shape=(128, 2740)
# [DATASET] f0096, shape=(128, 2167)
# [DATASET] f0096_aug0, shape=(128, 2167)
# [DATASET] f0096_aug1, shape=(128, 1851)
# [DATASET] f0096_aug2, shape=(128, 2032)
# [DATASET] f0097, shape=(128, 3780)
# [DATASET] f0098, shape=(128, 1975)
# [DATASET] f0099, shape=(128, 2033)
# [DATASET] f0099_aug0, shape=(128, 2452)
# [DATASET] f0099_aug1, shape=(128, 2033)
# [DATASET] f0099_aug2, shape=(128, 2033)
# [DATASET] f0100, shape=(128, 2090)
# [DATASET] f0101, shape=(128, 2065)
# [DATASET] f0102, shape=(128, 2077)
# [DATASET] f0103, shape=(128, 2116)
# [DATASET] f0103_aug0, shape=(128, 2331)
# [DATASET] f0103_aug1, shape=(128, 2116)
# [DATASET] f0103_aug2, shape=(128, 2164)
# [DATASET] f0104, shape=(128, 2058)
# [DATASET] f0105, shape=(128, 2023)
# [DATASET] f0106, shape=(128, 2155)
# [DATASET] f0107, shape=(128, 2039)
# [DATASET] f0108, shape=(128, 2036)
# [DATASET] f0109, shape=(128, 2052)
# [DATASET] f0110, shape=(128, 2045)
# [DATASET] f0111, shape=(128, 1959)
# [DATASET] f0112, shape=(128, 2029)
# [DATASET] f0113, shape=(128, 2199)
# [DATASET] f0114, shape=(128, 2093)

# %% [markdown]
# ## Create .h5py for MFCC

# %%
# ==============================
# MERGE MFCC .npy → HDF5
# ==============================
import numpy as np
import h5py
from pathlib import Path
from tqdm.notebook import tqdm

MFCC_DIR = PROJECT_PATH / "mfcc_features"          # Thư mục chứa MFCC .npy
OUTPUT_H5 = PROJECT_PATH / "data" / "mfcc_features.h5"

if OUTPUT_H5.exists():
    print(f"File {OUTPUT_H5} đã tồn tại – bỏ qua.")
else:
    npy_files = sorted(MFCC_DIR.glob("*.npy"))
    print(f"🔎 Found {len(npy_files)} MFCC files")

    with h5py.File(OUTPUT_H5, "w") as f_out:
        for npy_file in tqdm(npy_files, desc="Converting MFCC"):
            key = npy_file.stem
            data = np.load(npy_file)

            # MFCC chuẩn: (n_mfcc, time)
            assert data.ndim == 2, f"{key} invalid shape {data.shape}"

            f_out.create_dataset(
                key,
                data=data.astype(np.float32),
                compression="gzip"
            )

    print(f"✅ MFCC HDF5 created: {OUTPUT_H5}")
# Out:
# 🔎 Found 5235 MFCC files
# Converting MFCC:   0%|          | 0/5235 [00:00<?, ?it/s]
# ✅ MFCC HDF5 created: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/mfcc_features.h5

# %%
# ==============================
# INSPECT MFCC HDF5
# ==============================
import h5py

h5_path = str(PROJECT_PATH / "data" / "mfcc_features.h5")

with h5py.File(h5_path, "r") as f:
    print(f"Total samples: {len(f.keys())}\n")
    for i, key in enumerate(f.keys()):
        print(f"[DATASET] {key}, shape={f[key].shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [DATASET] a0075_aug1, shape=(13, 100)
# [DATASET] a0075_aug2, shape=(13, 100)
# [DATASET] a0076, shape=(13, 100)
# [DATASET] a0076_aug0, shape=(13, 100)
# [DATASET] a0076_aug1, shape=(13, 100)
# [DATASET] a0076_aug2, shape=(13, 100)
# [DATASET] a0077, shape=(13, 100)
# [DATASET] a0077_aug0, shape=(13, 100)
# [DATASET] a0077_aug1, shape=(13, 100)
# [DATASET] a0077_aug2, shape=(13, 100)
# [DATASET] a0078, shape=(13, 100)
# [DATASET] a0078_aug0, shape=(13, 100)
# [DATASET] a0078_aug1, shape=(13, 100)
# [DATASET] a0078_aug2, shape=(13, 100)
# [DATASET] a0079, shape=(13, 100)
# [DATASET] a0079_aug0, shape=(13, 100)
# [DATASET] a0079_aug1, shape=(13, 100)
# [DATASET] a0079_aug2, shape=(13, 100)
# [DATASET] a0080, shape=(13, 100)
# [DATASET] a0081, shape=(13, 100)
# [DATASET] a0082, shape=(13, 100)
# [DATASET] a0082_aug0, shape=(13, 100)
# [DATASET] a0082_aug1, shape=(13, 100)
# [DATASET] a0082_aug2, shape=(13, 100)
# [DATASET] a0083, shape=(13, 100)
# [DATASET] a0083_aug0, shape=(13, 100)
# [DATASET] a0083_aug1, shape=(13, 100)
# [DATASET] a0083_aug2, shape=(13, 100)
# [DATASET] a0084, shape=(13, 100)
# [DATASET] a0084_aug0, shape=(13, 100)
# [DATASET] a0084_aug1, shape=(13, 100)
# [DATASET] a0084_aug2, shape=(13, 100)
# [DATASET] a0085, shape=(13, 100)
# [DATASET] a0086, shape=(13, 100)
# [DATASET] a0087, shape=(13, 100)
# [DATASET] a0087_aug0, shape=(13, 100)
# [DATASET] a0087_aug1, shape=(13, 100)
# [DATASET] a0087_aug2, shape=(13, 100)
# [DATASET] a0088, shape=(13, 100)
# [DATASET] a0089, shape=(13, 100)
# [DATASET] a0089_aug0, shape=(13, 100)
# [DATASET] a0089_aug1, shape=(13, 100)
# [DATASET] a0089_aug2, shape=(13, 100)
# [DATASET] a0090, shape=(13, 100)
# [DATASET] a0090_aug0, shape=(13, 100)
# [DATASET] a0090_aug1, shape=(13, 100)
# [DATASET] a0090_aug2, shape=(13, 100)
# [DATASET] a0091, shape=(13, 100)
# [DATASET] a0092, shape=(13, 100)
# [DATASET] a0092_aug0, shape=(13, 100)
# [DATASET] a0092_aug1, shape=(13, 100)
# [DATASET] a0092_aug2, shape=(13, 100)
# [DATASET] a0093, shape=(13, 100)
# [DATASET] a0094, shape=(13, 100)
# [DATASET] a0095, shape=(13, 100)
# [DATASET] a0095_aug0, shape=(13, 100)
# [DATASET] a0095_aug1, shape=(13, 100)
# [DATASET] a0095_aug2, shape=(13, 100)
# [DATASET] a0096, shape=(13, 100)
# [DATASET] a0096_aug0, shape=(13, 100)
# [DATASET] a0096_aug1, shape=(13, 100)
# [DATASET] a0096_aug2, shape=(13, 100)
# [DATASET] a0097, shape=(13, 100)
# [DATASET] a0097_aug0, shape=(13, 100)
# [DATASET] a0097_aug1, shape=(13, 100)
# [DATASET] a0097_aug2, shape=(13, 100)
# [DATASET] a0098, shape=(13, 100)
# [DATASET] a0098_aug0, shape=(13, 100)
# [DATASET] a0098_aug1, shape=(13, 100)
# [DATASET] a0098_aug2, shape=(13, 100)
# [DATASET] a0099, shape=(13, 100)
# [DATASET] a0099_aug0, shape=(13, 100)
# [DATASET] a0099_aug1, shape=(13, 100)
# [DATASET] a0099_aug2, shape=(13, 100)
# [DATASET] a0100, shape=(13, 100)
# [DATASET] a0100_aug0, shape=(13, 100)
# [DATASET] a0100_aug1, shape=(13, 100)
# [DATASET] a0100_aug2, shape=(13, 100)
# [DATASET] a0101, shape=(13, 100)
# [DATASET] a0101_aug0, shape=(13, 100)
# [DATASET] a0101_aug1, shape=(13, 100)
# [DATASET] a0101_aug2, shape=(13, 100)
# [DATASET] a0102, shape=(13, 100)
# [DATASET] a0103, shape=(13, 100)
# [DATASET] a0103_aug0, shape=(13, 100)
# [DATASET] a0103_aug1, shape=(13, 100)
# [DATASET] a0103_aug2, shape=(13, 100)
# [DATASET] a0104, shape=(13, 100)
# [DATASET] a0104_aug0, shape=(13, 100)
# [DATASET] a0104_aug1, shape=(13, 100)
# [DATASET] a0104_aug2, shape=(13, 100)
# [DATASET] a0105, shape=(13, 100)
# [DATASET] a0106, shape=(13, 100)
# [DATASET] a0107, shape=(13, 100)
# [DATASET] a0107_aug0, shape=(13, 100)
# [DATASET] a0107_aug1, shape=(13, 100)
# [DATASET] a0107_aug2, shape=(13, 100)
# [DATASET] a0108, shape=(13, 100)
# [DATASET] a0109, shape=(13, 100)
# [DATASET] a0110, shape=(13, 100)
# [DATASET] a0110_aug0, shape=(13, 100)
# [DATASET] a0110_aug1, shape=(13, 100)
# [DATASET] a0110_aug2, shape=(13, 100)
# [DATASET] a0111, shape=(13, 100)
# [DATASET] a0111_aug0, shape=(13, 100)
# [DATASET] a0111_aug1, shape=(13, 100)
# [DATASET] a0111_aug2, shape=(13, 100)
# [DATASET] a0112, shape=(13, 100)
# [DATASET] a0112_aug0, shape=(13, 100)
# [DATASET] a0112_aug1, shape=(13, 100)
# [DATASET] a0112_aug2, shape=(13, 100)
# [DATASET] a0113, shape=(13, 100)
# [DATASET] a0113_aug0, shape=(13, 100)
# [DATASET] a0113_aug1, shape=(13, 100)
# [DATASET] a0113_aug2, shape=(13, 100)
# [DATASET] a0114, shape=(13, 100)
# [DATASET] a0114_aug0, shape=(13, 100)
# [DATASET] a0114_aug1, shape=(13, 100)
# [DATASET] a0114_aug2, shape=(13, 100)
# [DATASET] a0115, shape=(13, 100)
# [DATASET] a0115_aug0, shape=(13, 100)
# [DATASET] a0115_aug1, shape=(13, 100)
# [DATASET] a0115_aug2, shape=(13, 100)
# [DATASET] a0116, shape=(13, 100)
# [DATASET] a0116_aug0, shape=(13, 100)
# [DATASET] a0116_aug1, shape=(13, 100)
# [DATASET] a0116_aug2, shape=(13, 100)
# [DATASET] a0117, shape=(13, 100)
# [DATASET] a0117_aug0, shape=(13, 100)
# [DATASET] a0117_aug1, shape=(13, 100)
# [DATASET] a0117_aug2, shape=(13, 100)
# [DATASET] a0118, shape=(13, 100)
# [DATASET] a0119, shape=(13, 100)
# [DATASET] a0119_aug0, shape=(13, 100)
# [DATASET] a0119_aug1, shape=(13, 100)
# [DATASET] a0119_aug2, shape=(13, 100)
# [DATASET] a0120, shape=(13, 100)
# [DATASET] a0120_aug0, shape=(13, 100)
# [DATASET] a0120_aug1, shape=(13, 100)
# [DATASET] a0120_aug2, shape=(13, 100)
# [DATASET] a0121, shape=(13, 100)
# [DATASET] a0121_aug0, shape=(13, 100)
# [DATASET] a0121_aug1, shape=(13, 100)
# [DATASET] a0121_aug2, shape=(13, 100)
# [DATASET] a0122, shape=(13, 100)
# [DATASET] a0122_aug0, shape=(13, 100)
# [DATASET] a0122_aug1, shape=(13, 100)
# [DATASET] a0122_aug2, shape=(13, 100)
# [DATASET] a0123, shape=(13, 100)
# [DATASET] a0123_aug0, shape=(13, 100)
# [DATASET] a0123_aug1, shape=(13, 100)
# [DATASET] a0123_aug2, shape=(13, 100)
# [DATASET] a0124, shape=(13, 100)
# [DATASET] a0124_aug0, shape=(13, 100)
# [DATASET] a0124_aug1, shape=(13, 100)
# [DATASET] a0124_aug2, shape=(13, 100)
# [DATASET] a0125, shape=(13, 100)
# [DATASET] a0126, shape=(13, 100)
# [DATASET] a0126_aug0, shape=(13, 100)
# [DATASET] a0126_aug1, shape=(13, 100)
# [DATASET] a0126_aug2, shape=(13, 100)
# [DATASET] a0127, shape=(13, 100)
# [DATASET] a0128, shape=(13, 100)
# [DATASET] a0128_aug0, shape=(13, 100)
# [DATASET] a0128_aug1, shape=(13, 100)
# [DATASET] a0128_aug2, shape=(13, 100)
# [DATASET] a0129, shape=(13, 100)
# [DATASET] a0130, shape=(13, 100)
# [DATASET] a0130_aug0, shape=(13, 100)
# [DATASET] a0130_aug1, shape=(13, 100)
# [DATASET] a0130_aug2, shape=(13, 100)
# [DATASET] a0150_aug0, shape=(13, 100)
# [DATASET] a0150_aug1, shape=(13, 100)
# [DATASET] a0150_aug2, shape=(13, 100)
# [DATASET] a0151, shape=(13, 100)
# [DATASET] a0151_aug0, shape=(13, 100)
# [DATASET] a0151_aug1, shape=(13, 100)
# [DATASET] a0151_aug2, shape=(13, 100)
# [DATASET] a0152, shape=(13, 100)
# [DATASET] a0152_aug0, shape=(13, 100)
# [DATASET] a0152_aug1, shape=(13, 100)
# [DATASET] a0152_aug2, shape=(13, 100)
# [DATASET] a0153, shape=(13, 100)
# [DATASET] a0154, shape=(13, 100)
# [DATASET] a0155, shape=(13, 100)
# [DATASET] a0156, shape=(13, 100)
# [DATASET] a0156_aug0, shape=(13, 100)
# [DATASET] a0156_aug1, shape=(13, 100)
# [DATASET] a0156_aug2, shape=(13, 100)
# [DATASET] a0157, shape=(13, 100)
# [DATASET] a0157_aug0, shape=(13, 100)
# [DATASET] a0157_aug1, shape=(13, 100)
# [DATASET] a0157_aug2, shape=(13, 100)
# [DATASET] a0158, shape=(13, 100)
# [DATASET] a0158_aug0, shape=(13, 100)
# [DATASET] a0158_aug1, shape=(13, 100)
# [DATASET] a0158_aug2, shape=(13, 100)
# [DATASET] a0159, shape=(13, 100)
# [DATASET] a0159_aug0, shape=(13, 100)
# [DATASET] a0159_aug1, shape=(13, 100)
# [DATASET] a0159_aug2, shape=(13, 100)
# [DATASET] a0160, shape=(13, 100)
# [DATASET] a0160_aug0, shape=(13, 100)
# [DATASET] a0160_aug1, shape=(13, 100)
# [DATASET] a0160_aug2, shape=(13, 100)
# [DATASET] a0161, shape=(13, 100)
# [DATASET] a0162, shape=(13, 100)
# [DATASET] a0162_aug0, shape=(13, 100)
# [DATASET] a0162_aug1, shape=(13, 100)
# [DATASET] a0162_aug2, shape=(13, 100)
# [DATASET] a0163, shape=(13, 100)
# [DATASET] a0163_aug0, shape=(13, 100)
# [DATASET] a0163_aug1, shape=(13, 100)
# [DATASET] a0163_aug2, shape=(13, 100)
# [DATASET] a0164, shape=(13, 100)
# [DATASET] a0164_aug0, shape=(13, 100)
# [DATASET] a0164_aug1, shape=(13, 100)
# [DATASET] a0164_aug2, shape=(13, 100)
# [DATASET] a0165, shape=(13, 100)
# [DATASET] a0166, shape=(13, 100)
# [DATASET] a0166_aug0, shape=(13, 100)
# [DATASET] a0166_aug1, shape=(13, 100)
# [DATASET] a0166_aug2, shape=(13, 100)
# [DATASET] a0167, shape=(13, 100)
# [DATASET] a0167_aug0, shape=(13, 100)
# [DATASET] a0167_aug1, shape=(13, 100)
# [DATASET] a0167_aug2, shape=(13, 100)
# [DATASET] a0168, shape=(13, 100)
# [DATASET] a0168_aug0, shape=(13, 100)
# [DATASET] a0168_aug1, shape=(13, 100)
# [DATASET] a0168_aug2, shape=(13, 100)
# [DATASET] a0169, shape=(13, 100)
# [DATASET] a0169_aug0, shape=(13, 100)
# [DATASET] a0169_aug1, shape=(13, 100)
# [DATASET] a0169_aug2, shape=(13, 100)
# [DATASET] a0170, shape=(13, 100)
# [DATASET] a0170_aug0, shape=(13, 100)
# [DATASET] a0170_aug1, shape=(13, 100)
# [DATASET] a0170_aug2, shape=(13, 100)
# [DATASET] a0171, shape=(13, 100)
# [DATASET] a0172, shape=(13, 100)
# [DATASET] a0172_aug0, shape=(13, 100)
# [DATASET] a0172_aug1, shape=(13, 100)
# [DATASET] a0172_aug2, shape=(13, 100)
# [DATASET] a0173, shape=(13, 100)
# [DATASET] a0173_aug0, shape=(13, 100)
# [DATASET] a0173_aug1, shape=(13, 100)
# [DATASET] a0173_aug2, shape=(13, 100)
# [DATASET] a0174, shape=(13, 100)
# [DATASET] a0174_aug0, shape=(13, 100)
# [DATASET] a0174_aug1, shape=(13, 100)
# [DATASET] a0174_aug2, shape=(13, 100)
# [DATASET] a0175, shape=(13, 100)
# [DATASET] a0175_aug0, shape=(13, 100)
# [DATASET] a0175_aug1, shape=(13, 100)
# [DATASET] a0175_aug2, shape=(13, 100)
# [DATASET] a0176, shape=(13, 100)
# [DATASET] a0176_aug0, shape=(13, 100)
# [DATASET] a0176_aug1, shape=(13, 100)
# [DATASET] a0176_aug2, shape=(13, 100)
# [DATASET] a0177, shape=(13, 100)
# [DATASET] a0177_aug0, shape=(13, 100)
# [DATASET] a0177_aug1, shape=(13, 100)
# [DATASET] a0177_aug2, shape=(13, 100)
# [DATASET] a0178, shape=(13, 100)
# [DATASET] a0179, shape=(13, 100)
# [DATASET] a0180, shape=(13, 100)
# [DATASET] a0180_aug0, shape=(13, 100)
# [DATASET] a0180_aug1, shape=(13, 100)
# [DATASET] a0180_aug2, shape=(13, 100)
# [DATASET] a0181, shape=(13, 100)
# [DATASET] a0182, shape=(13, 100)
# [DATASET] a0182_aug0, shape=(13, 100)
# [DATASET] a0182_aug1, shape=(13, 100)
# [DATASET] a0182_aug2, shape=(13, 100)
# [DATASET] a0183, shape=(13, 100)
# [DATASET] a0183_aug0, shape=(13, 100)
# [DATASET] a0183_aug1, shape=(13, 100)
# [DATASET] a0183_aug2, shape=(13, 100)
# [DATASET] a0184, shape=(13, 100)
# [DATASET] a0185, shape=(13, 100)
# [DATASET] a0186, shape=(13, 100)
# [DATASET] a0186_aug0, shape=(13, 100)
# [DATASET] a0186_aug1, shape=(13, 100)
# [DATASET] a0186_aug2, shape=(13, 100)
# [DATASET] a0187, shape=(13, 100)
# [DATASET] a0187_aug0, shape=(13, 100)
# [DATASET] a0187_aug1, shape=(13, 100)
# [DATASET] a0187_aug2, shape=(13, 100)
# [DATASET] a0188, shape=(13, 100)
# [DATASET] a0188_aug0, shape=(13, 100)
# [DATASET] a0188_aug1, shape=(13, 100)
# [DATASET] a0188_aug2, shape=(13, 100)
# [DATASET] a0189, shape=(13, 100)
# [DATASET] a0190, shape=(13, 100)
# [DATASET] a0190_aug0, shape=(13, 100)
# [DATASET] a0190_aug1, shape=(13, 100)
# [DATASET] a0190_aug2, shape=(13, 100)
# [DATASET] a0191, shape=(13, 100)
# [DATASET] a0191_aug0, shape=(13, 100)
# [DATASET] a0191_aug1, shape=(13, 100)
# [DATASET] a0191_aug2, shape=(13, 100)
# [DATASET] a0192, shape=(13, 100)
# [DATASET] a0192_aug0, shape=(13, 100)
# [DATASET] a0192_aug1, shape=(13, 100)
# [DATASET] a0192_aug2, shape=(13, 100)
# [DATASET] a0193, shape=(13, 100)
# [DATASET] a0194, shape=(13, 100)
# [DATASET] a0194_aug0, shape=(13, 100)
# [DATASET] a0194_aug1, shape=(13, 100)
# [DATASET] a0194_aug2, shape=(13, 100)
# [DATASET] a0195, shape=(13, 100)
# [DATASET] a0196, shape=(13, 100)
# [DATASET] a0197, shape=(13, 100)
# [DATASET] a0197_aug0, shape=(13, 100)
# [DATASET] a0197_aug1, shape=(13, 100)
# [DATASET] a0197_aug2, shape=(13, 100)
# [DATASET] a0198, shape=(13, 100)
# [DATASET] a0198_aug0, shape=(13, 100)
# [DATASET] a0198_aug1, shape=(13, 100)
# [DATASET] a0198_aug2, shape=(13, 100)
# [DATASET] a0199, shape=(13, 100)
# [DATASET] a0200, shape=(13, 100)
# [DATASET] a0200_aug0, shape=(13, 100)
# [DATASET] a0200_aug1, shape=(13, 100)
# [DATASET] a0200_aug2, shape=(13, 100)
# [DATASET] a0201, shape=(13, 100)
# [DATASET] a0201_aug0, shape=(13, 100)
# [DATASET] a0201_aug1, shape=(13, 100)
# [DATASET] a0201_aug2, shape=(13, 100)
# [DATASET] a0202, shape=(13, 100)
# [DATASET] a0202_aug0, shape=(13, 100)
# [DATASET] a0202_aug1, shape=(13, 100)
# [DATASET] a0202_aug2, shape=(13, 100)
# [DATASET] a0203, shape=(13, 100)
# [DATASET] a0203_aug0, shape=(13, 100)
# [DATASET] a0203_aug1, shape=(13, 100)
# [DATASET] a0203_aug2, shape=(13, 100)
# [DATASET] a0204, shape=(13, 100)
# [DATASET] a0205, shape=(13, 100)
# [DATASET] a0205_aug0, shape=(13, 100)
# [DATASET] a0205_aug1, shape=(13, 100)
# [DATASET] a0205_aug2, shape=(13, 100)
# [DATASET] a0206, shape=(13, 100)
# [DATASET] a0206_aug0, shape=(13, 100)
# [DATASET] a0206_aug1, shape=(13, 100)
# [DATASET] a0206_aug2, shape=(13, 100)
# [DATASET] a0207, shape=(13, 100)
# [DATASET] a0207_aug0, shape=(13, 100)
# [DATASET] a0207_aug1, shape=(13, 100)
# [DATASET] a0207_aug2, shape=(13, 100)
# [DATASET] a0208, shape=(13, 100)
# [DATASET] a0209, shape=(13, 100)
# [DATASET] a0209_aug0, shape=(13, 100)
# [DATASET] a0209_aug1, shape=(13, 100)
# [DATASET] a0209_aug2, shape=(13, 100)
# [DATASET] a0210, shape=(13, 100)
# [DATASET] a0211, shape=(13, 100)
# [DATASET] a0212, shape=(13, 100)
# [DATASET] a0213, shape=(13, 100)
# [DATASET] a0213_aug0, shape=(13, 100)
# [DATASET] a0213_aug1, shape=(13, 100)
# [DATASET] a0213_aug2, shape=(13, 100)
# [DATASET] a0214, shape=(13, 100)
# [DATASET] a0214_aug0, shape=(13, 100)
# [DATASET] a0214_aug1, shape=(13, 100)
# [DATASET] a0214_aug2, shape=(13, 100)
# [DATASET] a0215, shape=(13, 100)
# [DATASET] a0215_aug0, shape=(13, 100)
# [DATASET] a0215_aug1, shape=(13, 100)
# [DATASET] a0215_aug2, shape=(13, 100)
# [DATASET] a0216, shape=(13, 100)
# [DATASET] a0216_aug0, shape=(13, 100)
# [DATASET] a0216_aug1, shape=(13, 100)
# [DATASET] a0216_aug2, shape=(13, 100)
# [DATASET] a0217, shape=(13, 100)
# [DATASET] a0217_aug0, shape=(13, 100)
# [DATASET] a0217_aug1, shape=(13, 100)
# [DATASET] a0217_aug2, shape=(13, 100)
# [DATASET] a0218, shape=(13, 100)
# [DATASET] a0218_aug0, shape=(13, 100)
# [DATASET] a0218_aug1, shape=(13, 100)
# [DATASET] a0218_aug2, shape=(13, 100)
# [DATASET] a0219, shape=(13, 100)
# [DATASET] a0219_aug0, shape=(13, 100)
# [DATASET] a0219_aug1, shape=(13, 100)
# [DATASET] a0219_aug2, shape=(13, 100)
# [DATASET] a0220, shape=(13, 100)
# [DATASET] a0220_aug0, shape=(13, 100)
# [DATASET] a0220_aug1, shape=(13, 100)
# [DATASET] a0220_aug2, shape=(13, 100)
# [DATASET] a0221, shape=(13, 100)
# [DATASET] a0221_aug0, shape=(13, 100)
# [DATASET] a0221_aug1, shape=(13, 100)
# [DATASET] a0221_aug2, shape=(13, 100)
# [DATASET] a0222, shape=(13, 100)
# [DATASET] a0222_aug0, shape=(13, 100)
# [DATASET] a0222_aug1, shape=(13, 100)
# [DATASET] a0222_aug2, shape=(13, 100)
# [DATASET] a0223, shape=(13, 100)
# [DATASET] a0223_aug0, shape=(13, 100)
# [DATASET] a0223_aug1, shape=(13, 100)
# [DATASET] a0223_aug2, shape=(13, 100)
# [DATASET] a0224, shape=(13, 100)
# [DATASET] a0224_aug0, shape=(13, 100)
# [DATASET] a0224_aug1, shape=(13, 100)
# [DATASET] a0224_aug2, shape=(13, 100)
# [DATASET] a0225, shape=(13, 100)
# [DATASET] a0225_aug0, shape=(13, 100)
# [DATASET] a0225_aug1, shape=(13, 100)
# [DATASET] a0225_aug2, shape=(13, 100)
# [DATASET] a0226, shape=(13, 100)
# [DATASET] a0226_aug0, shape=(13, 100)
# [DATASET] a0226_aug1, shape=(13, 100)
# [DATASET] a0226_aug2, shape=(13, 100)
# [DATASET] a0227, shape=(13, 100)
# [DATASET] a0228, shape=(13, 100)
# [DATASET] a0228_aug0, shape=(13, 100)
# [DATASET] a0228_aug1, shape=(13, 100)
# [DATASET] a0228_aug2, shape=(13, 100)
# [DATASET] a0229, shape=(13, 100)
# [DATASET] a0230, shape=(13, 100)
# [DATASET] a0230_aug0, shape=(13, 100)
# [DATASET] a0230_aug1, shape=(13, 100)
# [DATASET] a0230_aug2, shape=(13, 100)
# [DATASET] a0231, shape=(13, 100)
# [DATASET] a0232, shape=(13, 100)
# [DATASET] a0232_aug0, shape=(13, 100)
# [DATASET] a0232_aug1, shape=(13, 100)
# [DATASET] a0232_aug2, shape=(13, 100)
# [DATASET] a0233, shape=(13, 100)
# [DATASET] a0233_aug0, shape=(13, 100)
# [DATASET] a0233_aug1, shape=(13, 100)
# [DATASET] a0233_aug2, shape=(13, 100)
# [DATASET] a0234, shape=(13, 100)
# [DATASET] a0234_aug0, shape=(13, 100)
# [DATASET] a0234_aug1, shape=(13, 100)
# [DATASET] a0234_aug2, shape=(13, 100)
# [DATASET] a0235, shape=(13, 100)
# [DATASET] a0236, shape=(13, 100)
# [DATASET] a0236_aug0, shape=(13, 100)
# [DATASET] a0236_aug1, shape=(13, 100)
# [DATASET] a0236_aug2, shape=(13, 100)
# [DATASET] a0237, shape=(13, 100)
# [DATASET] a0237_aug0, shape=(13, 100)
# [DATASET] a0237_aug1, shape=(13, 100)
# [DATASET] a0237_aug2, shape=(13, 100)
# [DATASET] a0238, shape=(13, 100)
# [DATASET] a0239, shape=(13, 100)
# [DATASET] a0239_aug0, shape=(13, 100)
# [DATASET] a0239_aug1, shape=(13, 100)
# [DATASET] a0239_aug2, shape=(13, 100)
# [DATASET] a0240, shape=(13, 100)
# [DATASET] a0240_aug0, shape=(13, 100)
# [DATASET] a0240_aug1, shape=(13, 100)
# [DATASET] a0240_aug2, shape=(13, 100)
# [DATASET] a0241, shape=(13, 100)
# [DATASET] a0242, shape=(13, 100)
# [DATASET] a0242_aug0, shape=(13, 100)
# [DATASET] a0242_aug1, shape=(13, 100)
# [DATASET] a0242_aug2, shape=(13, 100)
# [DATASET] a0243, shape=(13, 100)
# [DATASET] a0244, shape=(13, 100)
# [DATASET] a0244_aug0, shape=(13, 100)
# [DATASET] a0244_aug1, shape=(13, 100)
# [DATASET] a0244_aug2, shape=(13, 100)
# [DATASET] a0245, shape=(13, 100)
# [DATASET] a0245_aug0, shape=(13, 100)
# [DATASET] a0245_aug1, shape=(13, 100)
# [DATASET] a0245_aug2, shape=(13, 100)
# [DATASET] a0246, shape=(13, 100)
# [DATASET] a0246_aug0, shape=(13, 100)
# [DATASET] a0246_aug1, shape=(13, 100)
# [DATASET] a0246_aug2, shape=(13, 100)
# [DATASET] a0247, shape=(13, 100)
# [DATASET] a0247_aug0, shape=(13, 100)
# [DATASET] a0247_aug1, shape=(13, 100)
# [DATASET] a0247_aug2, shape=(13, 100)
# [DATASET] a0248, shape=(13, 100)
# [DATASET] a0248_aug0, shape=(13, 100)
# [DATASET] a0248_aug1, shape=(13, 100)
# [DATASET] a0248_aug2, shape=(13, 100)
# [DATASET] a0249, shape=(13, 100)
# [DATASET] a0249_aug0, shape=(13, 100)
# [DATASET] a0249_aug1, shape=(13, 100)
# [DATASET] a0249_aug2, shape=(13, 100)
# [DATASET] a0250, shape=(13, 100)
# [DATASET] a0251, shape=(13, 100)
# [DATASET] a0251_aug0, shape=(13, 100)
# [DATASET] a0251_aug1, shape=(13, 100)
# [DATASET] a0251_aug2, shape=(13, 100)
# [DATASET] a0252, shape=(13, 100)
# [DATASET] a0252_aug0, shape=(13, 100)
# [DATASET] a0252_aug1, shape=(13, 100)
# [DATASET] a0252_aug2, shape=(13, 100)
# [DATASET] a0253, shape=(13, 100)
# [DATASET] a0254, shape=(13, 100)
# [DATASET] a0254_aug0, shape=(13, 100)
# [DATASET] a0254_aug1, shape=(13, 100)
# [DATASET] a0254_aug2, shape=(13, 100)
# [DATASET] a0255, shape=(13, 100)
# [DATASET] a0255_aug0, shape=(13, 100)
# [DATASET] a0255_aug1, shape=(13, 100)
# [DATASET] a0255_aug2, shape=(13, 100)
# [DATASET] a0256, shape=(13, 100)
# [DATASET] a0256_aug0, shape=(13, 100)
# [DATASET] a0256_aug1, shape=(13, 100)
# [DATASET] a0256_aug2, shape=(13, 100)
# [DATASET] a0257, shape=(13, 100)
# [DATASET] a0257_aug0, shape=(13, 100)
# [DATASET] a0257_aug1, shape=(13, 100)
# [DATASET] a0257_aug2, shape=(13, 100)
# [DATASET] a0258, shape=(13, 100)
# [DATASET] a0258_aug0, shape=(13, 100)
# [DATASET] a0258_aug1, shape=(13, 100)
# [DATASET] a0258_aug2, shape=(13, 100)
# [DATASET] a0259, shape=(13, 100)
# [DATASET] a0259_aug0, shape=(13, 100)
# [DATASET] a0259_aug1, shape=(13, 100)
# [DATASET] a0259_aug2, shape=(13, 100)
# [DATASET] a0260, shape=(13, 100)
# [DATASET] a0260_aug0, shape=(13, 100)
# [DATASET] a0260_aug1, shape=(13, 100)
# [DATASET] a0260_aug2, shape=(13, 100)
# [DATASET] a0261, shape=(13, 100)
# [DATASET] a0261_aug0, shape=(13, 100)
# [DATASET] a0261_aug1, shape=(13, 100)
# [DATASET] a0261_aug2, shape=(13, 100)
# [DATASET] a0262, shape=(13, 100)
# [DATASET] a0262_aug0, shape=(13, 100)
# [DATASET] a0262_aug1, shape=(13, 100)
# [DATASET] a0262_aug2, shape=(13, 100)
# [DATASET] a0263, shape=(13, 100)
# [DATASET] a0263_aug0, shape=(13, 100)
# [DATASET] a0263_aug1, shape=(13, 100)
# [DATASET] a0263_aug2, shape=(13, 100)
# [DATASET] a0264, shape=(13, 100)
# [DATASET] a0265, shape=(13, 100)
# [DATASET] a0265_aug0, shape=(13, 100)
# [DATASET] a0265_aug1, shape=(13, 100)
# [DATASET] a0265_aug2, shape=(13, 100)
# [DATASET] a0266, shape=(13, 100)
# [DATASET] a0267, shape=(13, 100)
# [DATASET] a0267_aug0, shape=(13, 100)
# [DATASET] a0267_aug1, shape=(13, 100)
# [DATASET] a0267_aug2, shape=(13, 100)
# [DATASET] a0268, shape=(13, 100)
# [DATASET] a0268_aug0, shape=(13, 100)
# [DATASET] a0268_aug1, shape=(13, 100)
# [DATASET] a0268_aug2, shape=(13, 100)
# [DATASET] a0269, shape=(13, 100)
# [DATASET] a0269_aug0, shape=(13, 100)
# [DATASET] a0269_aug1, shape=(13, 100)
# [DATASET] a0269_aug2, shape=(13, 100)
# [DATASET] a0270, shape=(13, 100)
# [DATASET] a0271, shape=(13, 100)
# [DATASET] a0272, shape=(13, 100)
# [DATASET] a0272_aug0, shape=(13, 100)
# [DATASET] a0272_aug1, shape=(13, 100)
# [DATASET] a0272_aug2, shape=(13, 100)
# [DATASET] a0273, shape=(13, 100)
# [DATASET] a0273_aug0, shape=(13, 100)
# [DATASET] a0273_aug1, shape=(13, 100)
# [DATASET] a0273_aug2, shape=(13, 100)
# [DATASET] a0274, shape=(13, 100)
# [DATASET] a0275, shape=(13, 100)
# [DATASET] a0275_aug0, shape=(13, 100)
# [DATASET] a0275_aug1, shape=(13, 100)
# [DATASET] a0275_aug2, shape=(13, 100)
# [DATASET] a0276, shape=(13, 100)
# [DATASET] a0276_aug0, shape=(13, 100)
# [DATASET] a0276_aug1, shape=(13, 100)
# [DATASET] a0276_aug2, shape=(13, 100)
# [DATASET] a0277, shape=(13, 100)
# [DATASET] a0277_aug0, shape=(13, 100)
# [DATASET] a0277_aug1, shape=(13, 100)
# [DATASET] a0277_aug2, shape=(13, 100)
# [DATASET] a0278, shape=(13, 100)
# [DATASET] a0278_aug0, shape=(13, 100)
# [DATASET] a0278_aug1, shape=(13, 100)
# [DATASET] a0278_aug2, shape=(13, 100)
# [DATASET] a0279, shape=(13, 100)
# [DATASET] a0279_aug0, shape=(13, 100)
# [DATASET] a0279_aug1, shape=(13, 100)
# [DATASET] a0279_aug2, shape=(13, 100)
# [DATASET] a0280, shape=(13, 100)
# [DATASET] a0280_aug0, shape=(13, 100)
# [DATASET] a0280_aug1, shape=(13, 100)
# [DATASET] a0280_aug2, shape=(13, 100)
# [DATASET] a0281, shape=(13, 100)
# [DATASET] a0281_aug0, shape=(13, 100)
# [DATASET] a0281_aug1, shape=(13, 100)
# [DATASET] a0281_aug2, shape=(13, 100)
# [DATASET] a0282, shape=(13, 100)
# [DATASET] a0282_aug0, shape=(13, 100)
# [DATASET] a0282_aug1, shape=(13, 100)
# [DATASET] a0282_aug2, shape=(13, 100)
# [DATASET] a0283, shape=(13, 100)
# [DATASET] a0284, shape=(13, 100)
# [DATASET] a0284_aug0, shape=(13, 100)
# [DATASET] a0284_aug1, shape=(13, 100)
# [DATASET] a0284_aug2, shape=(13, 100)
# [DATASET] a0285, shape=(13, 100)
# [DATASET] a0286, shape=(13, 100)
# [DATASET] a0286_aug0, shape=(13, 100)
# [DATASET] a0286_aug1, shape=(13, 100)
# [DATASET] a0286_aug2, shape=(13, 100)
# [DATASET] a0287, shape=(13, 100)
# [DATASET] a0288, shape=(13, 100)
# [DATASET] a0288_aug0, shape=(13, 100)
# [DATASET] a0288_aug1, shape=(13, 100)
# [DATASET] a0288_aug2, shape=(13, 100)
# [DATASET] a0289, shape=(13, 100)
# [DATASET] a0290, shape=(13, 100)
# [DATASET] a0291, shape=(13, 100)
# [DATASET] a0291_aug0, shape=(13, 100)
# [DATASET] a0291_aug1, shape=(13, 100)
# [DATASET] a0291_aug2, shape=(13, 100)
# [DATASET] a0292, shape=(13, 100)
# [DATASET] a0292_aug0, shape=(13, 100)
# [DATASET] a0292_aug1, shape=(13, 100)
# [DATASET] a0292_aug2, shape=(13, 100)
# [DATASET] a0293, shape=(13, 100)
# [DATASET] a0294, shape=(13, 100)
# [DATASET] a0295, shape=(13, 100)
# [DATASET] a0295_aug0, shape=(13, 100)
# [DATASET] a0295_aug1, shape=(13, 100)
# [DATASET] a0295_aug2, shape=(13, 100)
# [DATASET] a0296, shape=(13, 100)
# [DATASET] a0296_aug0, shape=(13, 100)
# [DATASET] a0296_aug1, shape=(13, 100)
# [DATASET] a0296_aug2, shape=(13, 100)
# [DATASET] a0297, shape=(13, 100)
# [DATASET] a0297_aug0, shape=(13, 100)
# [DATASET] a0297_aug1, shape=(13, 100)
# [DATASET] a0297_aug2, shape=(13, 100)
# [DATASET] a0298, shape=(13, 100)
# [DATASET] a0299, shape=(13, 100)
# [DATASET] a0300, shape=(13, 100)
# [DATASET] a0300_aug0, shape=(13, 100)
# [DATASET] a0300_aug1, shape=(13, 100)
# [DATASET] a0300_aug2, shape=(13, 100)
# [DATASET] a0301, shape=(13, 100)
# [DATASET] a0302, shape=(13, 100)
# [DATASET] a0303, shape=(13, 100)
# [DATASET] a0303_aug0, shape=(13, 100)
# [DATASET] a0303_aug1, shape=(13, 100)
# [DATASET] a0303_aug2, shape=(13, 100)
# [DATASET] a0304, shape=(13, 100)
# [DATASET] a0305, shape=(13, 100)
# [DATASET] a0305_aug0, shape=(13, 100)
# [DATASET] a0305_aug1, shape=(13, 100)
# [DATASET] a0305_aug2, shape=(13, 100)
# [DATASET] a0306, shape=(13, 100)
# [DATASET] a0306_aug0, shape=(13, 100)
# [DATASET] a0306_aug1, shape=(13, 100)
# [DATASET] a0306_aug2, shape=(13, 100)
# [DATASET] a0307, shape=(13, 100)
# [DATASET] a0307_aug0, shape=(13, 100)
# [DATASET] a0307_aug1, shape=(13, 100)
# [DATASET] a0307_aug2, shape=(13, 100)
# [DATASET] a0308, shape=(13, 100)
# [DATASET] a0308_aug0, shape=(13, 100)
# [DATASET] a0308_aug1, shape=(13, 100)
# [DATASET] a0308_aug2, shape=(13, 100)
# [DATASET] a0309, shape=(13, 100)
# [DATASET] a0310, shape=(13, 100)
# [DATASET] a0311, shape=(13, 100)
# [DATASET] a0312, shape=(13, 100)
# [DATASET] a0312_aug0, shape=(13, 100)
# [DATASET] a0312_aug1, shape=(13, 100)
# [DATASET] a0312_aug2, shape=(13, 100)
# [DATASET] a0313, shape=(13, 100)
# [DATASET] a0313_aug0, shape=(13, 100)
# [DATASET] a0313_aug1, shape=(13, 100)
# [DATASET] a0313_aug2, shape=(13, 100)
# [DATASET] a0314, shape=(13, 100)
# [DATASET] a0314_aug0, shape=(13, 100)
# [DATASET] a0314_aug1, shape=(13, 100)
# [DATASET] a0314_aug2, shape=(13, 100)
# [DATASET] a0315, shape=(13, 100)
# [DATASET] a0315_aug0, shape=(13, 100)
# [DATASET] a0315_aug1, shape=(13, 100)
# [DATASET] a0315_aug2, shape=(13, 100)
# [DATASET] a0316, shape=(13, 100)
# [DATASET] a0316_aug0, shape=(13, 100)
# [DATASET] a0316_aug1, shape=(13, 100)
# [DATASET] a0316_aug2, shape=(13, 100)
# [DATASET] a0317, shape=(13, 100)
# [DATASET] a0317_aug0, shape=(13, 100)
# [DATASET] a0317_aug1, shape=(13, 100)
# [DATASET] a0317_aug2, shape=(13, 100)
# [DATASET] a0318, shape=(13, 100)
# [DATASET] a0318_aug0, shape=(13, 100)
# [DATASET] a0318_aug1, shape=(13, 100)
# [DATASET] a0318_aug2, shape=(13, 100)
# [DATASET] a0319, shape=(13, 100)
# [DATASET] a0319_aug0, shape=(13, 100)
# [DATASET] a0319_aug1, shape=(13, 100)
# [DATASET] a0319_aug2, shape=(13, 100)
# [DATASET] a0320, shape=(13, 100)
# [DATASET] a0320_aug0, shape=(13, 100)
# [DATASET] a0320_aug1, shape=(13, 100)
# [DATASET] a0320_aug2, shape=(13, 100)
# [DATASET] a0321, shape=(13, 100)
# [DATASET] a0321_aug0, shape=(13, 100)
# [DATASET] a0321_aug1, shape=(13, 100)
# [DATASET] a0321_aug2, shape=(13, 100)
# [DATASET] a0322, shape=(13, 100)
# [DATASET] a0322_aug0, shape=(13, 100)
# [DATASET] a0322_aug1, shape=(13, 100)
# [DATASET] a0322_aug2, shape=(13, 100)
# [DATASET] a0323, shape=(13, 100)
# [DATASET] a0324, shape=(13, 100)
# [DATASET] a0324_aug0, shape=(13, 100)
# [DATASET] a0324_aug1, shape=(13, 100)
# [DATASET] a0324_aug2, shape=(13, 100)
# [DATASET] a0325, shape=(13, 100)
# [DATASET] a0326, shape=(13, 100)
# [DATASET] a0326_aug0, shape=(13, 100)
# [DATASET] a0326_aug1, shape=(13, 100)
# [DATASET] a0326_aug2, shape=(13, 100)
# [DATASET] a0327, shape=(13, 100)
# [DATASET] a0327_aug0, shape=(13, 100)
# [DATASET] a0327_aug1, shape=(13, 100)
# [DATASET] a0327_aug2, shape=(13, 100)
# [DATASET] a0328, shape=(13, 100)
# [DATASET] a0329, shape=(13, 100)
# [DATASET] a0330, shape=(13, 100)
# [DATASET] a0331, shape=(13, 100)
# [DATASET] a0331_aug0, shape=(13, 100)
# [DATASET] a0331_aug1, shape=(13, 100)
# [DATASET] a0331_aug2, shape=(13, 100)
# [DATASET] a0332, shape=(13, 100)
# [DATASET] a0333, shape=(13, 100)
# [DATASET] a0333_aug0, shape=(13, 100)
# [DATASET] a0333_aug1, shape=(13, 100)
# [DATASET] a0333_aug2, shape=(13, 100)
# [DATASET] a0334, shape=(13, 100)
# [DATASET] a0335, shape=(13, 100)
# [DATASET] a0335_aug0, shape=(13, 100)
# [DATASET] a0335_aug1, shape=(13, 100)
# [DATASET] a0335_aug2, shape=(13, 100)
# [DATASET] a0336, shape=(13, 100)
# [DATASET] a0336_aug0, shape=(13, 100)
# [DATASET] a0336_aug1, shape=(13, 100)
# [DATASET] a0336_aug2, shape=(13, 100)
# [DATASET] a0337, shape=(13, 100)
# [DATASET] a0338, shape=(13, 100)
# [DATASET] a0338_aug0, shape=(13, 100)
# [DATASET] a0338_aug1, shape=(13, 100)
# [DATASET] a0338_aug2, shape=(13, 100)
# [DATASET] a0339, shape=(13, 100)
# [DATASET] a0339_aug0, shape=(13, 100)
# [DATASET] a0339_aug1, shape=(13, 100)
# [DATASET] a0339_aug2, shape=(13, 100)
# [DATASET] a0340, shape=(13, 100)
# [DATASET] a0341, shape=(13, 100)
# [DATASET] a0341_aug0, shape=(13, 100)
# [DATASET] a0341_aug1, shape=(13, 100)
# [DATASET] a0341_aug2, shape=(13, 100)
# [DATASET] a0342, shape=(13, 100)
# [DATASET] a0343, shape=(13, 100)
# [DATASET] a0343_aug0, shape=(13, 100)
# [DATASET] a0343_aug1, shape=(13, 100)
# [DATASET] a0343_aug2, shape=(13, 100)
# [DATASET] a0344, shape=(13, 100)
# [DATASET] a0344_aug0, shape=(13, 100)
# [DATASET] a0344_aug1, shape=(13, 100)
# [DATASET] a0344_aug2, shape=(13, 100)
# [DATASET] a0345, shape=(13, 100)
# [DATASET] a0345_aug0, shape=(13, 100)
# [DATASET] a0345_aug1, shape=(13, 100)
# [DATASET] a0345_aug2, shape=(13, 100)
# [DATASET] a0346, shape=(13, 100)
# [DATASET] a0346_aug0, shape=(13, 100)
# [DATASET] a0346_aug1, shape=(13, 100)
# [DATASET] a0346_aug2, shape=(13, 100)
# [DATASET] a0347, shape=(13, 100)
# [DATASET] a0347_aug0, shape=(13, 100)
# [DATASET] a0347_aug1, shape=(13, 100)
# [DATASET] a0347_aug2, shape=(13, 100)
# [DATASET] a0348, shape=(13, 100)
# [DATASET] a0348_aug0, shape=(13, 100)
# [DATASET] a0348_aug1, shape=(13, 100)
# [DATASET] a0348_aug2, shape=(13, 100)
# [DATASET] a0349, shape=(13, 100)
# [DATASET] a0349_aug0, shape=(13, 100)
# [DATASET] a0349_aug1, shape=(13, 100)
# [DATASET] a0349_aug2, shape=(13, 100)
# [DATASET] a0350, shape=(13, 100)
# [DATASET] a0350_aug0, shape=(13, 100)
# [DATASET] a0350_aug1, shape=(13, 100)
# [DATASET] a0350_aug2, shape=(13, 100)
# [DATASET] a0351, shape=(13, 100)
# [DATASET] a0352, shape=(13, 100)
# [DATASET] a0353, shape=(13, 100)
# [DATASET] a0354, shape=(13, 100)
# [DATASET] a0354_aug0, shape=(13, 100)
# [DATASET] a0354_aug1, shape=(13, 100)
# [DATASET] a0354_aug2, shape=(13, 100)
# [DATASET] a0355, shape=(13, 100)
# [DATASET] a0356, shape=(13, 100)
# [DATASET] a0356_aug0, shape=(13, 100)
# [DATASET] a0356_aug1, shape=(13, 100)
# [DATASET] a0356_aug2, shape=(13, 100)
# [DATASET] a0357, shape=(13, 100)
# [DATASET] a0357_aug0, shape=(13, 100)
# [DATASET] a0357_aug1, shape=(13, 100)
# [DATASET] a0357_aug2, shape=(13, 100)
# [DATASET] a0358, shape=(13, 100)
# [DATASET] a0358_aug0, shape=(13, 100)
# [DATASET] a0358_aug1, shape=(13, 100)
# [DATASET] a0358_aug2, shape=(13, 100)
# [DATASET] a0359, shape=(13, 100)
# [DATASET] a0360, shape=(13, 100)
# [DATASET] a0360_aug0, shape=(13, 100)
# [DATASET] a0360_aug1, shape=(13, 100)
# [DATASET] a0360_aug2, shape=(13, 100)
# [DATASET] a0361, shape=(13, 100)
# [DATASET] a0362, shape=(13, 100)
# [DATASET] a0362_aug0, shape=(13, 100)
# [DATASET] a0362_aug1, shape=(13, 100)
# [DATASET] a0362_aug2, shape=(13, 100)
# [DATASET] a0363, shape=(13, 100)
# [DATASET] a0363_aug0, shape=(13, 100)
# [DATASET] a0363_aug1, shape=(13, 100)
# [DATASET] a0363_aug2, shape=(13, 100)
# [DATASET] a0364, shape=(13, 100)
# [DATASET] a0364_aug0, shape=(13, 100)
# [DATASET] a0364_aug1, shape=(13, 100)
# [DATASET] a0364_aug2, shape=(13, 100)
# [DATASET] a0365, shape=(13, 100)
# [DATASET] a0365_aug0, shape=(13, 100)
# [DATASET] a0365_aug1, shape=(13, 100)
# [DATASET] a0365_aug2, shape=(13, 100)
# [DATASET] a0366, shape=(13, 100)
# [DATASET] a0366_aug0, shape=(13, 100)
# [DATASET] a0366_aug1, shape=(13, 100)
# [DATASET] a0366_aug2, shape=(13, 100)
# [DATASET] a0367, shape=(13, 100)
# [DATASET] a0367_aug0, shape=(13, 100)
# [DATASET] a0367_aug1, shape=(13, 100)
# [DATASET] a0367_aug2, shape=(13, 100)
# [DATASET] a0368, shape=(13, 100)
# [DATASET] a0368_aug0, shape=(13, 100)
# [DATASET] a0368_aug1, shape=(13, 100)
# [DATASET] a0368_aug2, shape=(13, 100)
# [DATASET] a0369, shape=(13, 100)
# [DATASET] a0369_aug0, shape=(13, 100)
# [DATASET] a0369_aug1, shape=(13, 100)
# [DATASET] a0369_aug2, shape=(13, 100)
# [DATASET] a0370, shape=(13, 100)
# [DATASET] a0370_aug0, shape=(13, 100)
# [DATASET] a0370_aug1, shape=(13, 100)
# [DATASET] a0370_aug2, shape=(13, 100)
# [DATASET] a0371, shape=(13, 100)
# [DATASET] a0371_aug0, shape=(13, 100)
# [DATASET] a0371_aug1, shape=(13, 100)
# [DATASET] a0371_aug2, shape=(13, 100)
# [DATASET] a0372, shape=(13, 100)
# [DATASET] a0372_aug0, shape=(13, 100)
# [DATASET] a0372_aug1, shape=(13, 100)
# [DATASET] a0372_aug2, shape=(13, 100)
# [DATASET] a0373, shape=(13, 100)
# [DATASET] a0373_aug0, shape=(13, 100)
# [DATASET] a0373_aug1, shape=(13, 100)
# [DATASET] a0373_aug2, shape=(13, 100)
# [DATASET] a0374, shape=(13, 100)
# [DATASET] a0374_aug0, shape=(13, 100)
# [DATASET] a0374_aug1, shape=(13, 100)
# [DATASET] a0374_aug2, shape=(13, 100)
# [DATASET] a0375, shape=(13, 100)
# [DATASET] a0375_aug0, shape=(13, 100)
# [DATASET] a0375_aug1, shape=(13, 100)
# [DATASET] a0375_aug2, shape=(13, 100)
# [DATASET] a0376, shape=(13, 100)
# [DATASET] a0376_aug0, shape=(13, 100)
# [DATASET] a0376_aug1, shape=(13, 100)
# [DATASET] a0376_aug2, shape=(13, 100)
# [DATASET] a0377, shape=(13, 100)
# [DATASET] a0377_aug0, shape=(13, 100)
# [DATASET] a0377_aug1, shape=(13, 100)
# [DATASET] a0377_aug2, shape=(13, 100)
# [DATASET] a0378, shape=(13, 100)
# [DATASET] a0378_aug0, shape=(13, 100)
# [DATASET] a0378_aug1, shape=(13, 100)
# [DATASET] a0378_aug2, shape=(13, 100)
# [DATASET] a0379, shape=(13, 100)
# [DATASET] a0379_aug0, shape=(13, 100)
# [DATASET] a0379_aug1, shape=(13, 100)
# [DATASET] a0379_aug2, shape=(13, 100)
# [DATASET] a0380, shape=(13, 100)
# [DATASET] a0380_aug0, shape=(13, 100)
# [DATASET] a0380_aug1, shape=(13, 100)
# [DATASET] a0380_aug2, shape=(13, 100)
# [DATASET] a0381, shape=(13, 100)
# [DATASET] a0381_aug0, shape=(13, 100)
# [DATASET] a0381_aug1, shape=(13, 100)
# [DATASET] a0381_aug2, shape=(13, 100)
# [DATASET] a0382, shape=(13, 100)
# [DATASET] a0382_aug0, shape=(13, 100)
# [DATASET] a0382_aug1, shape=(13, 100)
# [DATASET] a0382_aug2, shape=(13, 100)
# [DATASET] a0383, shape=(13, 100)
# [DATASET] a0383_aug0, shape=(13, 100)
# [DATASET] a0383_aug1, shape=(13, 100)
# [DATASET] a0383_aug2, shape=(13, 100)
# [DATASET] a0384, shape=(13, 100)
# [DATASET] a0384_aug0, shape=(13, 100)
# [DATASET] a0384_aug1, shape=(13, 100)
# [DATASET] a0384_aug2, shape=(13, 100)
# [DATASET] a0385, shape=(13, 100)
# [DATASET] a0386, shape=(13, 100)
# [DATASET] a0387, shape=(13, 100)
# [DATASET] a0387_aug0, shape=(13, 100)
# [DATASET] a0387_aug1, shape=(13, 100)
# [DATASET] a0387_aug2, shape=(13, 100)
# [DATASET] a0388, shape=(13, 100)
# [DATASET] a0388_aug0, shape=(13, 100)
# [DATASET] a0388_aug1, shape=(13, 100)
# [DATASET] a0388_aug2, shape=(13, 100)
# [DATASET] a0389, shape=(13, 100)
# [DATASET] a0389_aug0, shape=(13, 100)
# [DATASET] a0389_aug1, shape=(13, 100)
# [DATASET] a0389_aug2, shape=(13, 100)
# [DATASET] a0390, shape=(13, 100)
# [DATASET] a0390_aug0, shape=(13, 100)
# [DATASET] a0390_aug1, shape=(13, 100)
# [DATASET] a0390_aug2, shape=(13, 100)
# [DATASET] a0391, shape=(13, 100)
# [DATASET] a0391_aug0, shape=(13, 100)
# [DATASET] a0391_aug1, shape=(13, 100)
# [DATASET] a0391_aug2, shape=(13, 100)
# [DATASET] a0392, shape=(13, 100)
# [DATASET] a0392_aug0, shape=(13, 100)
# [DATASET] a0392_aug1, shape=(13, 100)
# [DATASET] a0392_aug2, shape=(13, 100)
# [DATASET] a0393, shape=(13, 100)
# [DATASET] a0394, shape=(13, 100)
# [DATASET] a0394_aug0, shape=(13, 100)
# [DATASET] a0394_aug1, shape=(13, 100)
# [DATASET] a0394_aug2, shape=(13, 100)
# [DATASET] a0395, shape=(13, 100)
# [DATASET] a0395_aug0, shape=(13, 100)
# [DATASET] a0395_aug1, shape=(13, 100)
# [DATASET] a0395_aug2, shape=(13, 100)
# [DATASET] a0396, shape=(13, 100)
# [DATASET] a0396_aug0, shape=(13, 100)
# [DATASET] a0396_aug1, shape=(13, 100)
# [DATASET] a0396_aug2, shape=(13, 100)
# [DATASET] a0397, shape=(13, 100)
# [DATASET] a0397_aug0, shape=(13, 100)
# [DATASET] a0397_aug1, shape=(13, 100)
# [DATASET] a0397_aug2, shape=(13, 100)
# [DATASET] a0398, shape=(13, 100)
# [DATASET] a0398_aug0, shape=(13, 100)
# [DATASET] a0398_aug1, shape=(13, 100)
# [DATASET] a0398_aug2, shape=(13, 100)
# [DATASET] a0399, shape=(13, 100)
# [DATASET] a0399_aug0, shape=(13, 100)
# [DATASET] a0399_aug1, shape=(13, 100)
# [DATASET] a0399_aug2, shape=(13, 100)
# [DATASET] a0400, shape=(13, 100)
# [DATASET] a0400_aug0, shape=(13, 100)
# [DATASET] a0400_aug1, shape=(13, 100)
# [DATASET] a0400_aug2, shape=(13, 100)
# [DATASET] a0401, shape=(13, 100)
# [DATASET] a0402, shape=(13, 100)
# [DATASET] a0402_aug0, shape=(13, 100)
# [DATASET] a0402_aug1, shape=(13, 100)
# [DATASET] a0402_aug2, shape=(13, 100)
# [DATASET] a0403, shape=(13, 100)
# [DATASET] a0403_aug0, shape=(13, 100)
# [DATASET] a0403_aug1, shape=(13, 100)
# [DATASET] a0403_aug2, shape=(13, 100)
# [DATASET] a0404, shape=(13, 100)
# [DATASET] a0404_aug0, shape=(13, 100)
# [DATASET] a0404_aug1, shape=(13, 100)
# [DATASET] a0404_aug2, shape=(13, 100)
# [DATASET] a0405, shape=(13, 100)
# [DATASET] a0406, shape=(13, 100)
# [DATASET] a0407, shape=(13, 100)
# [DATASET] a0408, shape=(13, 100)
# [DATASET] a0409, shape=(13, 100)
# [DATASET] b0001, shape=(13, 100)
# [DATASET] b0002, shape=(13, 100)
# [DATASET] b0003, shape=(13, 100)
# [DATASET] b0004, shape=(13, 100)
# [DATASET] b0005, shape=(13, 100)
# [DATASET] b0006, shape=(13, 100)
# [DATASET] b0007, shape=(13, 100)
# [DATASET] b0008, shape=(13, 100)
# [DATASET] b0008_aug0, shape=(13, 100)
# [DATASET] b0008_aug1, shape=(13, 100)
# [DATASET] b0008_aug2, shape=(13, 100)
# [DATASET] b0009, shape=(13, 100)
# [DATASET] b0010, shape=(13, 100)
# [DATASET] b0011, shape=(13, 100)
# [DATASET] b0012, shape=(13, 100)
# [DATASET] b0013, shape=(13, 100)
# [DATASET] b0013_aug0, shape=(13, 100)
# [DATASET] b0013_aug1, shape=(13, 100)
# [DATASET] b0013_aug2, shape=(13, 100)
# [DATASET] b0014, shape=(13, 100)
# [DATASET] b0015, shape=(13, 100)
# [DATASET] b0016, shape=(13, 100)
# [DATASET] b0016_aug0, shape=(13, 100)
# [DATASET] b0016_aug1, shape=(13, 100)
# [DATASET] b0016_aug2, shape=(13, 100)
# [DATASET] b0017, shape=(13, 100)
# [DATASET] b0018, shape=(13, 100)
# [DATASET] b0018_aug0, shape=(13, 100)
# [DATASET] b0018_aug1, shape=(13, 100)
# [DATASET] b0018_aug2, shape=(13, 100)
# [DATASET] b0019, shape=(13, 100)
# [DATASET] b0020, shape=(13, 100)
# [DATASET] b0021, shape=(13, 100)
# [DATASET] b0022, shape=(13, 100)
# [DATASET] b0022_aug0, shape=(13, 100)
# [DATASET] b0022_aug1, shape=(13, 100)
# [DATASET] b0022_aug2, shape=(13, 100)
# [DATASET] b0023, shape=(13, 100)
# [DATASET] b0023_aug0, shape=(13, 100)
# [DATASET] b0023_aug1, shape=(13, 100)
# [DATASET] b0023_aug2, shape=(13, 100)
# [DATASET] b0024, shape=(13, 100)
# [DATASET] b0025, shape=(13, 100)
# [DATASET] b0026, shape=(13, 100)
# [DATASET] b0027, shape=(13, 100)
# [DATASET] b0028, shape=(13, 100)
# [DATASET] b0029, shape=(13, 100)
# [DATASET] b0030, shape=(13, 100)
# [DATASET] b0030_aug0, shape=(13, 100)
# [DATASET] b0030_aug1, shape=(13, 100)
# [DATASET] b0030_aug2, shape=(13, 100)
# [DATASET] b0031, shape=(13, 100)
# [DATASET] b0032, shape=(13, 100)
# [DATASET] b0032_aug0, shape=(13, 100)
# [DATASET] b0032_aug1, shape=(13, 100)
# [DATASET] b0032_aug2, shape=(13, 100)
# [DATASET] b0033, shape=(13, 100)
# [DATASET] b0033_aug0, shape=(13, 100)
# [DATASET] b0033_aug1, shape=(13, 100)
# [DATASET] b0033_aug2, shape=(13, 100)
# [DATASET] b0034, shape=(13, 100)
# [DATASET] b0035, shape=(13, 100)
# [DATASET] b0036, shape=(13, 100)
# [DATASET] b0037, shape=(13, 100)
# [DATASET] b0037_aug0, shape=(13, 100)
# [DATASET] b0037_aug1, shape=(13, 100)
# [DATASET] b0037_aug2, shape=(13, 100)
# [DATASET] b0038, shape=(13, 100)
# [DATASET] b0039, shape=(13, 100)
# [DATASET] b0040, shape=(13, 100)
# [DATASET] b0040_aug0, shape=(13, 100)
# [DATASET] b0040_aug1, shape=(13, 100)
# [DATASET] b0040_aug2, shape=(13, 100)
# [DATASET] b0041, shape=(13, 100)
# [DATASET] b0041_aug0, shape=(13, 100)
# [DATASET] b0041_aug1, shape=(13, 100)
# [DATASET] b0041_aug2, shape=(13, 100)
# [DATASET] b0042, shape=(13, 100)
# [DATASET] b0043, shape=(13, 100)
# [DATASET] b0043_aug0, shape=(13, 100)
# [DATASET] b0043_aug1, shape=(13, 100)
# [DATASET] b0043_aug2, shape=(13, 100)
# [DATASET] b0044, shape=(13, 100)
# [DATASET] b0045, shape=(13, 100)
# [DATASET] b0046, shape=(13, 100)
# [DATASET] b0046_aug0, shape=(13, 100)
# [DATASET] b0046_aug1, shape=(13, 100)
# [DATASET] b0046_aug2, shape=(13, 100)
# [DATASET] b0047, shape=(13, 100)
# [DATASET] b0048, shape=(13, 100)
# [DATASET] b0048_aug0, shape=(13, 100)
# [DATASET] b0048_aug1, shape=(13, 100)
# [DATASET] b0048_aug2, shape=(13, 100)
# [DATASET] b0049, shape=(13, 100)
# [DATASET] b0050, shape=(13, 100)
# [DATASET] b0051, shape=(13, 100)
# [DATASET] b0052, shape=(13, 100)
# [DATASET] b0053, shape=(13, 100)
# [DATASET] b0054, shape=(13, 100)
# [DATASET] b0054_aug0, shape=(13, 100)
# [DATASET] b0054_aug1, shape=(13, 100)
# [DATASET] b0054_aug2, shape=(13, 100)
# [DATASET] b0055, shape=(13, 100)
# [DATASET] b0056, shape=(13, 100)
# [DATASET] b0057, shape=(13, 100)
# [DATASET] b0057_aug0, shape=(13, 100)
# [DATASET] b0057_aug1, shape=(13, 100)
# [DATASET] b0057_aug2, shape=(13, 100)
# [DATASET] b0058, shape=(13, 100)
# [DATASET] b0059, shape=(13, 100)
# [DATASET] b0060, shape=(13, 100)
# [DATASET] b0061, shape=(13, 100)
# [DATASET] b0062, shape=(13, 100)
# [DATASET] b0063, shape=(13, 100)
# [DATASET] b0063_aug0, shape=(13, 100)
# [DATASET] b0063_aug1, shape=(13, 100)
# [DATASET] b0063_aug2, shape=(13, 100)
# [DATASET] b0064, shape=(13, 100)
# [DATASET] b0065, shape=(13, 100)
# [DATASET] b0066, shape=(13, 100)
# [DATASET] b0067, shape=(13, 100)
# [DATASET] b0068, shape=(13, 100)
# [DATASET] b0068_aug0, shape=(13, 100)
# [DATASET] b0068_aug1, shape=(13, 100)
# [DATASET] b0068_aug2, shape=(13, 100)
# [DATASET] b0069, shape=(13, 100)
# [DATASET] b0070, shape=(13, 100)
# [DATASET] b0071, shape=(13, 100)
# [DATASET] b0072, shape=(13, 100)
# [DATASET] b0073, shape=(13, 100)
# [DATASET] b0074, shape=(13, 100)
# [DATASET] b0075, shape=(13, 100)
# [DATASET] b0076, shape=(13, 100)
# [DATASET] b0077, shape=(13, 100)
# [DATASET] b0077_aug0, shape=(13, 100)
# [DATASET] b0077_aug1, shape=(13, 100)
# [DATASET] b0077_aug2, shape=(13, 100)
# [DATASET] b0078, shape=(13, 100)
# [DATASET] b0079, shape=(13, 100)
# [DATASET] b0080, shape=(13, 100)
# [DATASET] b0081, shape=(13, 100)
# [DATASET] b0081_aug0, shape=(13, 100)
# [DATASET] b0081_aug1, shape=(13, 100)
# [DATASET] b0081_aug2, shape=(13, 100)
# [DATASET] b0082, shape=(13, 100)
# [DATASET] b0083, shape=(13, 100)
# [DATASET] b0084, shape=(13, 100)
# [DATASET] b0085, shape=(13, 100)
# [DATASET] b0086, shape=(13, 100)
# [DATASET] b0086_aug0, shape=(13, 100)
# [DATASET] b0086_aug1, shape=(13, 100)
# [DATASET] b0086_aug2, shape=(13, 100)
# [DATASET] b0087, shape=(13, 100)
# [DATASET] b0088, shape=(13, 100)
# [DATASET] b0089, shape=(13, 100)
# [DATASET] b0090, shape=(13, 100)
# [DATASET] b0091, shape=(13, 100)
# [DATASET] b0092, shape=(13, 100)
# [DATASET] b0093, shape=(13, 100)
# [DATASET] b0094, shape=(13, 100)
# [DATASET] b0095, shape=(13, 100)
# [DATASET] b0096, shape=(13, 100)
# [DATASET] b0096_aug0, shape=(13, 100)
# [DATASET] b0096_aug1, shape=(13, 100)
# [DATASET] b0096_aug2, shape=(13, 100)
# [DATASET] b0097, shape=(13, 100)
# [DATASET] b0098, shape=(13, 100)
# [DATASET] b0099, shape=(13, 100)
# [DATASET] b0100, shape=(13, 100)
# [DATASET] b0101, shape=(13, 100)
# [DATASET] b0102, shape=(13, 100)
# [DATASET] b0103, shape=(13, 100)
# [DATASET] b0104, shape=(13, 100)
# [DATASET] b0105, shape=(13, 100)
# [DATASET] b0106, shape=(13, 100)
# [DATASET] b0106_aug0, shape=(13, 100)
# [DATASET] b0106_aug1, shape=(13, 100)
# [DATASET] b0106_aug2, shape=(13, 100)
# [DATASET] b0107, shape=(13, 100)
# [DATASET] b0108, shape=(13, 100)
# [DATASET] b0109, shape=(13, 100)
# [DATASET] b0110, shape=(13, 100)
# [DATASET] b0111, shape=(13, 100)
# [DATASET] b0112, shape=(13, 100)
# [DATASET] b0113, shape=(13, 100)
# [DATASET] b0114, shape=(13, 100)
# [DATASET] b0115, shape=(13, 100)
# [DATASET] b0116, shape=(13, 100)
# [DATASET] b0117, shape=(13, 100)
# [DATASET] b0117_aug0, shape=(13, 100)
# [DATASET] b0117_aug1, shape=(13, 100)
# [DATASET] b0117_aug2, shape=(13, 100)
# [DATASET] b0118, shape=(13, 100)
# [DATASET] b0119, shape=(13, 100)
# [DATASET] b0120, shape=(13, 100)
# [DATASET] b0120_aug0, shape=(13, 100)
# [DATASET] b0120_aug1, shape=(13, 100)
# [DATASET] b0120_aug2, shape=(13, 100)
# [DATASET] b0121, shape=(13, 100)
# [DATASET] b0122, shape=(13, 100)
# [DATASET] b0123, shape=(13, 100)
# [DATASET] b0124, shape=(13, 100)
# [DATASET] b0125, shape=(13, 100)
# [DATASET] b0126, shape=(13, 100)
# [DATASET] b0127, shape=(13, 100)
# [DATASET] b0128, shape=(13, 100)
# [DATASET] b0129, shape=(13, 100)
# [DATASET] b0130, shape=(13, 100)
# [DATASET] b0130_aug0, shape=(13, 100)
# [DATASET] b0130_aug1, shape=(13, 100)
# [DATASET] b0130_aug2, shape=(13, 100)
# [DATASET] b0131, shape=(13, 100)
# [DATASET] b0132, shape=(13, 100)
# [DATASET] b0133, shape=(13, 100)
# [DATASET] b0134, shape=(13, 100)
# [DATASET] b0135, shape=(13, 100)
# [DATASET] b0136, shape=(13, 100)
# [DATASET] b0136_aug0, shape=(13, 100)
# [DATASET] b0136_aug1, shape=(13, 100)
# [DATASET] b0136_aug2, shape=(13, 100)
# [DATASET] b0137, shape=(13, 100)
# [DATASET] b0137_aug0, shape=(13, 100)
# [DATASET] b0137_aug1, shape=(13, 100)
# [DATASET] b0137_aug2, shape=(13, 100)
# [DATASET] b0138, shape=(13, 100)
# [DATASET] b0139, shape=(13, 100)
# [DATASET] b0140, shape=(13, 100)
# [DATASET] b0140_aug0, shape=(13, 100)
# [DATASET] b0140_aug1, shape=(13, 100)
# [DATASET] b0140_aug2, shape=(13, 100)
# [DATASET] b0141, shape=(13, 100)
# [DATASET] b0142, shape=(13, 100)
# [DATASET] b0143, shape=(13, 100)
# [DATASET] b0144, shape=(13, 100)
# [DATASET] b0145, shape=(13, 100)
# [DATASET] b0146, shape=(13, 100)
# [DATASET] b0147, shape=(13, 100)
# [DATASET] b0148, shape=(13, 100)
# [DATASET] b0148_aug0, shape=(13, 100)
# [DATASET] b0148_aug1, shape=(13, 100)
# [DATASET] b0148_aug2, shape=(13, 100)
# [DATASET] b0149, shape=(13, 100)
# [DATASET] b0150, shape=(13, 100)
# [DATASET] b0151, shape=(13, 100)
# [DATASET] b0152, shape=(13, 100)
# [DATASET] b0153, shape=(13, 100)
# [DATASET] b0154, shape=(13, 100)
# [DATASET] b0155, shape=(13, 100)
# [DATASET] b0155_aug0, shape=(13, 100)
# [DATASET] b0155_aug1, shape=(13, 100)
# [DATASET] b0155_aug2, shape=(13, 100)
# [DATASET] b0156, shape=(13, 100)
# [DATASET] b0157, shape=(13, 100)
# [DATASET] b0158, shape=(13, 100)
# [DATASET] b0159, shape=(13, 100)
# [DATASET] b0159_aug0, shape=(13, 100)
# [DATASET] b0159_aug1, shape=(13, 100)
# [DATASET] b0159_aug2, shape=(13, 100)
# [DATASET] b0160, shape=(13, 100)
# [DATASET] b0161, shape=(13, 100)
# [DATASET] b0162, shape=(13, 100)
# [DATASET] b0163, shape=(13, 100)
# [DATASET] b0164, shape=(13, 100)
# [DATASET] b0164_aug0, shape=(13, 100)
# [DATASET] b0164_aug1, shape=(13, 100)
# [DATASET] b0164_aug2, shape=(13, 100)
# [DATASET] b0165, shape=(13, 100)
# [DATASET] b0166, shape=(13, 100)
# [DATASET] b0167, shape=(13, 100)
# [DATASET] b0168, shape=(13, 100)
# [DATASET] b0169, shape=(13, 100)
# [DATASET] b0170, shape=(13, 100)
# [DATASET] b0171, shape=(13, 100)
# [DATASET] b0171_aug0, shape=(13, 100)
# [DATASET] b0171_aug1, shape=(13, 100)
# [DATASET] b0171_aug2, shape=(13, 100)
# [DATASET] b0172, shape=(13, 100)
# [DATASET] b0173, shape=(13, 100)
# ...
# [DATASET] e01965, shape=(13, 100)
# [DATASET] e01966, shape=(13, 100)
# [DATASET] e01967, shape=(13, 100)
# [DATASET] e01967_aug0, shape=(13, 100)
# [DATASET] e01967_aug1, shape=(13, 100)
# [DATASET] e01967_aug2, shape=(13, 100)
# [DATASET] e01968, shape=(13, 100)
# [DATASET] e01969, shape=(13, 100)
# [DATASET] e01970, shape=(13, 100)
# [DATASET] e01971, shape=(13, 100)
# [DATASET] e01971_aug0, shape=(13, 100)
# [DATASET] e01971_aug1, shape=(13, 100)
# [DATASET] e01971_aug2, shape=(13, 100)
# [DATASET] e01972, shape=(13, 100)
# [DATASET] e01973, shape=(13, 100)
# [DATASET] e01974, shape=(13, 100)
# [DATASET] e01975, shape=(13, 100)
# [DATASET] e01976, shape=(13, 100)
# [DATASET] e01977, shape=(13, 100)
# [DATASET] e01978, shape=(13, 100)
# [DATASET] e01978_aug0, shape=(13, 100)
# [DATASET] e01978_aug1, shape=(13, 100)
# [DATASET] e01978_aug2, shape=(13, 100)
# [DATASET] e01979, shape=(13, 100)
# [DATASET] e01980, shape=(13, 100)
# [DATASET] e01981, shape=(13, 100)
# [DATASET] e01982, shape=(13, 100)
# [DATASET] e01983, shape=(13, 100)
# [DATASET] e01984, shape=(13, 100)
# [DATASET] e01985, shape=(13, 100)
# [DATASET] e01986, shape=(13, 100)
# [DATASET] e01987, shape=(13, 100)
# [DATASET] e01988, shape=(13, 100)
# [DATASET] e01989, shape=(13, 100)
# [DATASET] e01990, shape=(13, 100)
# [DATASET] e01991, shape=(13, 100)
# [DATASET] e01992, shape=(13, 100)
# [DATASET] e01992_aug0, shape=(13, 100)
# [DATASET] e01992_aug1, shape=(13, 100)
# [DATASET] e01992_aug2, shape=(13, 100)
# [DATASET] e01993, shape=(13, 100)
# [DATASET] e01994, shape=(13, 100)
# [DATASET] e01995, shape=(13, 100)
# [DATASET] e01995_aug0, shape=(13, 100)
# [DATASET] e01995_aug1, shape=(13, 100)
# [DATASET] e01995_aug2, shape=(13, 100)
# [DATASET] e01996, shape=(13, 100)
# [DATASET] e01997, shape=(13, 100)
# [DATASET] e01998, shape=(13, 100)
# [DATASET] e01999, shape=(13, 100)
# [DATASET] e02000, shape=(13, 100)
# [DATASET] e02001, shape=(13, 100)
# [DATASET] e02002, shape=(13, 100)
# [DATASET] e02003, shape=(13, 100)
# [DATASET] e02004, shape=(13, 100)
# [DATASET] e02005, shape=(13, 100)
# [DATASET] e02006, shape=(13, 100)
# [DATASET] e02007, shape=(13, 100)
# [DATASET] e02008, shape=(13, 100)
# [DATASET] e02009, shape=(13, 100)
# [DATASET] e02010, shape=(13, 100)
# [DATASET] e02011, shape=(13, 100)
# [DATASET] e02012, shape=(13, 100)
# [DATASET] e02013, shape=(13, 100)
# [DATASET] e02014, shape=(13, 100)
# [DATASET] e02015, shape=(13, 100)
# [DATASET] e02016, shape=(13, 100)
# [DATASET] e02017, shape=(13, 100)
# [DATASET] e02018, shape=(13, 100)
# [DATASET] e02019, shape=(13, 100)
# [DATASET] e02020, shape=(13, 100)
# [DATASET] e02021, shape=(13, 100)
# [DATASET] e02022, shape=(13, 100)
# [DATASET] e02023, shape=(13, 100)
# [DATASET] e02024, shape=(13, 100)
# [DATASET] e02025, shape=(13, 100)
# [DATASET] e02026, shape=(13, 100)
# [DATASET] e02027, shape=(13, 100)
# [DATASET] e02028, shape=(13, 100)
# [DATASET] e02029, shape=(13, 100)
# [DATASET] e02030, shape=(13, 100)
# [DATASET] e02030_aug0, shape=(13, 100)
# [DATASET] e02030_aug1, shape=(13, 100)
# [DATASET] e02030_aug2, shape=(13, 100)
# [DATASET] e02031, shape=(13, 100)
# [DATASET] e02032, shape=(13, 100)
# [DATASET] e02032_aug0, shape=(13, 100)
# [DATASET] e02032_aug1, shape=(13, 100)
# [DATASET] e02032_aug2, shape=(13, 100)
# [DATASET] e02033, shape=(13, 100)
# [DATASET] e02034, shape=(13, 100)
# [DATASET] e02035, shape=(13, 100)
# [DATASET] e02036, shape=(13, 100)
# [DATASET] e02037, shape=(13, 100)
# [DATASET] e02038, shape=(13, 100)
# [DATASET] e02039, shape=(13, 100)
# [DATASET] e02040, shape=(13, 100)
# [DATASET] e02041, shape=(13, 100)
# [DATASET] e02042, shape=(13, 100)
# [DATASET] e02043, shape=(13, 100)
# [DATASET] e02044, shape=(13, 100)
# [DATASET] e02044_aug0, shape=(13, 100)
# [DATASET] e02044_aug1, shape=(13, 100)
# [DATASET] e02044_aug2, shape=(13, 100)
# [DATASET] e02045, shape=(13, 100)
# [DATASET] e02046, shape=(13, 100)
# [DATASET] e02047, shape=(13, 100)
# [DATASET] e02048, shape=(13, 100)
# [DATASET] e02049, shape=(13, 100)
# [DATASET] e02050, shape=(13, 100)
# [DATASET] e02051, shape=(13, 100)
# [DATASET] e02052, shape=(13, 100)
# [DATASET] e02053, shape=(13, 100)
# [DATASET] e02054, shape=(13, 100)
# [DATASET] e02055, shape=(13, 100)
# [DATASET] e02056, shape=(13, 100)
# [DATASET] e02057, shape=(13, 100)
# [DATASET] e02058, shape=(13, 100)
# [DATASET] e02059, shape=(13, 100)
# [DATASET] e02060, shape=(13, 100)
# [DATASET] e02061, shape=(13, 100)
# [DATASET] e02062, shape=(13, 100)
# [DATASET] e02063, shape=(13, 100)
# [DATASET] e02064, shape=(13, 100)
# [DATASET] e02065, shape=(13, 100)
# [DATASET] e02065_aug0, shape=(13, 100)
# [DATASET] e02065_aug1, shape=(13, 100)
# [DATASET] e02065_aug2, shape=(13, 100)
# [DATASET] e02066, shape=(13, 100)
# [DATASET] e02067, shape=(13, 100)
# [DATASET] e02068, shape=(13, 100)
# [DATASET] e02069, shape=(13, 100)
# [DATASET] e02070, shape=(13, 100)
# [DATASET] e02071, shape=(13, 100)
# [DATASET] e02072, shape=(13, 100)
# [DATASET] e02073, shape=(13, 100)
# [DATASET] e02074, shape=(13, 100)
# [DATASET] e02074_aug0, shape=(13, 100)
# [DATASET] e02074_aug1, shape=(13, 100)
# [DATASET] e02074_aug2, shape=(13, 100)
# [DATASET] e02075, shape=(13, 100)
# [DATASET] e02076, shape=(13, 100)
# [DATASET] e02077, shape=(13, 100)
# [DATASET] e02078, shape=(13, 100)
# [DATASET] e02079, shape=(13, 100)
# [DATASET] e02080, shape=(13, 100)
# [DATASET] e02081, shape=(13, 100)
# [DATASET] e02082, shape=(13, 100)
# [DATASET] e02083, shape=(13, 100)
# [DATASET] e02084, shape=(13, 100)
# [DATASET] e02085, shape=(13, 100)
# [DATASET] e02085_aug0, shape=(13, 100)
# [DATASET] e02085_aug1, shape=(13, 100)
# [DATASET] e02085_aug2, shape=(13, 100)
# [DATASET] e02086, shape=(13, 100)
# [DATASET] e02087, shape=(13, 100)
# [DATASET] e02088, shape=(13, 100)
# [DATASET] e02089, shape=(13, 100)
# [DATASET] e02090, shape=(13, 100)
# [DATASET] e02091, shape=(13, 100)
# [DATASET] e02092, shape=(13, 100)
# [DATASET] e02093, shape=(13, 100)
# [DATASET] e02094, shape=(13, 100)
# [DATASET] e02095, shape=(13, 100)
# [DATASET] e02096, shape=(13, 100)
# [DATASET] e02097, shape=(13, 100)
# [DATASET] e02097_aug0, shape=(13, 100)
# [DATASET] e02097_aug1, shape=(13, 100)
# [DATASET] e02097_aug2, shape=(13, 100)
# [DATASET] e02098, shape=(13, 100)
# [DATASET] e02099, shape=(13, 100)
# [DATASET] e02100, shape=(13, 100)
# [DATASET] e02101, shape=(13, 100)
# [DATASET] e02101_aug0, shape=(13, 100)
# [DATASET] e02101_aug1, shape=(13, 100)
# [DATASET] e02101_aug2, shape=(13, 100)
# [DATASET] e02102, shape=(13, 100)
# [DATASET] e02102_aug0, shape=(13, 100)
# [DATASET] e02102_aug1, shape=(13, 100)
# [DATASET] e02102_aug2, shape=(13, 100)
# [DATASET] e02103, shape=(13, 100)
# [DATASET] e02104, shape=(13, 100)
# [DATASET] e02105, shape=(13, 100)
# [DATASET] e02106, shape=(13, 100)
# [DATASET] e02107, shape=(13, 100)
# [DATASET] e02108, shape=(13, 100)
# [DATASET] e02108_aug0, shape=(13, 100)
# [DATASET] e02108_aug1, shape=(13, 100)
# [DATASET] e02108_aug2, shape=(13, 100)
# [DATASET] e02109, shape=(13, 100)
# [DATASET] e02110, shape=(13, 100)
# [DATASET] e02111, shape=(13, 100)
# [DATASET] e02112, shape=(13, 100)
# [DATASET] e02113, shape=(13, 100)
# [DATASET] e02114, shape=(13, 100)
# [DATASET] e02115, shape=(13, 100)
# [DATASET] e02116, shape=(13, 100)
# [DATASET] e02117, shape=(13, 100)
# [DATASET] e02118, shape=(13, 100)
# [DATASET] e02119, shape=(13, 100)
# [DATASET] e02120, shape=(13, 100)
# [DATASET] e02121, shape=(13, 100)
# [DATASET] e02121_aug0, shape=(13, 100)
# [DATASET] e02121_aug1, shape=(13, 100)
# [DATASET] e02121_aug2, shape=(13, 100)
# [DATASET] e02122, shape=(13, 100)
# [DATASET] e02123, shape=(13, 100)
# [DATASET] e02124, shape=(13, 100)
# [DATASET] e02125, shape=(13, 100)
# [DATASET] e02126, shape=(13, 100)
# [DATASET] e02126_aug0, shape=(13, 100)
# [DATASET] e02126_aug1, shape=(13, 100)
# [DATASET] e02126_aug2, shape=(13, 100)
# [DATASET] e02127, shape=(13, 100)
# [DATASET] e02128, shape=(13, 100)
# [DATASET] e02129, shape=(13, 100)
# [DATASET] e02130, shape=(13, 100)
# [DATASET] e02131, shape=(13, 100)
# [DATASET] e02132, shape=(13, 100)
# [DATASET] e02133, shape=(13, 100)
# [DATASET] e02133_aug0, shape=(13, 100)
# [DATASET] e02133_aug1, shape=(13, 100)
# [DATASET] e02133_aug2, shape=(13, 100)
# [DATASET] e02134, shape=(13, 100)
# [DATASET] e02135, shape=(13, 100)
# [DATASET] e02135_aug0, shape=(13, 100)
# [DATASET] e02135_aug1, shape=(13, 100)
# [DATASET] e02135_aug2, shape=(13, 100)
# [DATASET] e02136, shape=(13, 100)
# [DATASET] e02137, shape=(13, 100)
# [DATASET] e02137_aug0, shape=(13, 100)
# [DATASET] e02137_aug1, shape=(13, 100)
# [DATASET] e02137_aug2, shape=(13, 100)
# [DATASET] e02138, shape=(13, 100)
# [DATASET] e02139, shape=(13, 100)
# [DATASET] e02140, shape=(13, 100)
# [DATASET] e02141, shape=(13, 100)
# [DATASET] f0001, shape=(13, 100)
# [DATASET] f0002, shape=(13, 100)
# [DATASET] f0003, shape=(13, 100)
# [DATASET] f0003_aug0, shape=(13, 100)
# [DATASET] f0003_aug1, shape=(13, 100)
# [DATASET] f0003_aug2, shape=(13, 100)
# [DATASET] f0004, shape=(13, 100)
# [DATASET] f0005, shape=(13, 100)
# [DATASET] f0006, shape=(13, 100)
# [DATASET] f0007, shape=(13, 100)
# [DATASET] f0007_aug0, shape=(13, 100)
# [DATASET] f0007_aug1, shape=(13, 100)
# [DATASET] f0007_aug2, shape=(13, 100)
# [DATASET] f0008, shape=(13, 100)
# [DATASET] f0008_aug0, shape=(13, 100)
# [DATASET] f0008_aug1, shape=(13, 100)
# [DATASET] f0008_aug2, shape=(13, 100)
# [DATASET] f0009, shape=(13, 100)
# [DATASET] f0010, shape=(13, 100)
# [DATASET] f0011, shape=(13, 100)
# [DATASET] f0012, shape=(13, 100)
# [DATASET] f0012_aug0, shape=(13, 100)
# [DATASET] f0012_aug1, shape=(13, 100)
# [DATASET] f0012_aug2, shape=(13, 100)
# [DATASET] f0013, shape=(13, 100)
# [DATASET] f0014, shape=(13, 100)
# [DATASET] f0015, shape=(13, 100)
# [DATASET] f0016, shape=(13, 100)
# [DATASET] f0017, shape=(13, 100)
# [DATASET] f0018, shape=(13, 100)
# [DATASET] f0018_aug0, shape=(13, 100)
# [DATASET] f0018_aug1, shape=(13, 100)
# [DATASET] f0018_aug2, shape=(13, 100)
# [DATASET] f0019, shape=(13, 100)
# [DATASET] f0020, shape=(13, 100)
# [DATASET] f0020_aug0, shape=(13, 100)
# [DATASET] f0020_aug1, shape=(13, 100)
# [DATASET] f0020_aug2, shape=(13, 100)
# [DATASET] f0021, shape=(13, 100)
# [DATASET] f0022, shape=(13, 100)
# [DATASET] f0023, shape=(13, 100)
# [DATASET] f0024, shape=(13, 100)
# [DATASET] f0025, shape=(13, 100)
# [DATASET] f0026, shape=(13, 100)
# [DATASET] f0027, shape=(13, 100)
# [DATASET] f0028, shape=(13, 100)
# [DATASET] f0029, shape=(13, 100)
# [DATASET] f0029_aug0, shape=(13, 100)
# [DATASET] f0029_aug1, shape=(13, 100)
# [DATASET] f0029_aug2, shape=(13, 100)
# [DATASET] f0030, shape=(13, 100)
# [DATASET] f0031, shape=(13, 100)
# [DATASET] f0032, shape=(13, 100)
# [DATASET] f0033, shape=(13, 100)
# [DATASET] f0034, shape=(13, 100)
# [DATASET] f0034_aug0, shape=(13, 100)
# [DATASET] f0034_aug1, shape=(13, 100)
# [DATASET] f0034_aug2, shape=(13, 100)
# [DATASET] f0035, shape=(13, 100)
# [DATASET] f0035_aug0, shape=(13, 100)
# [DATASET] f0035_aug1, shape=(13, 100)
# [DATASET] f0035_aug2, shape=(13, 100)
# [DATASET] f0036, shape=(13, 100)
# [DATASET] f0037, shape=(13, 100)
# [DATASET] f0038, shape=(13, 100)
# [DATASET] f0039, shape=(13, 100)
# [DATASET] f0040, shape=(13, 100)
# [DATASET] f0041, shape=(13, 100)
# [DATASET] f0041_aug0, shape=(13, 100)
# [DATASET] f0041_aug1, shape=(13, 100)
# [DATASET] f0041_aug2, shape=(13, 100)
# [DATASET] f0042, shape=(13, 100)
# [DATASET] f0043, shape=(13, 100)
# [DATASET] f0044, shape=(13, 100)
# [DATASET] f0045, shape=(13, 100)
# [DATASET] f0045_aug0, shape=(13, 100)
# [DATASET] f0045_aug1, shape=(13, 100)
# [DATASET] f0045_aug2, shape=(13, 100)
# [DATASET] f0046, shape=(13, 100)
# [DATASET] f0047, shape=(13, 100)
# [DATASET] f0047_aug0, shape=(13, 100)
# [DATASET] f0047_aug1, shape=(13, 100)
# [DATASET] f0047_aug2, shape=(13, 100)
# [DATASET] f0048, shape=(13, 100)
# [DATASET] f0049, shape=(13, 100)
# [DATASET] f0050, shape=(13, 100)
# [DATASET] f0050_aug0, shape=(13, 100)
# [DATASET] f0050_aug1, shape=(13, 100)
# [DATASET] f0050_aug2, shape=(13, 100)
# [DATASET] f0051, shape=(13, 100)
# [DATASET] f0052, shape=(13, 100)
# [DATASET] f0052_aug0, shape=(13, 100)
# [DATASET] f0052_aug1, shape=(13, 100)
# [DATASET] f0052_aug2, shape=(13, 100)
# [DATASET] f0053, shape=(13, 100)
# [DATASET] f0054, shape=(13, 100)
# [DATASET] f0055, shape=(13, 100)
# [DATASET] f0056, shape=(13, 100)
# [DATASET] f0056_aug0, shape=(13, 100)
# [DATASET] f0056_aug1, shape=(13, 100)
# [DATASET] f0056_aug2, shape=(13, 100)
# [DATASET] f0057, shape=(13, 100)
# [DATASET] f0057_aug0, shape=(13, 100)
# [DATASET] f0057_aug1, shape=(13, 100)
# [DATASET] f0057_aug2, shape=(13, 100)
# [DATASET] f0058, shape=(13, 100)
# [DATASET] f0059, shape=(13, 100)
# [DATASET] f0060, shape=(13, 100)
# [DATASET] f0060_aug0, shape=(13, 100)
# [DATASET] f0060_aug1, shape=(13, 100)
# [DATASET] f0060_aug2, shape=(13, 100)
# [DATASET] f0061, shape=(13, 100)
# [DATASET] f0062, shape=(13, 100)
# [DATASET] f0063, shape=(13, 100)
# [DATASET] f0063_aug0, shape=(13, 100)
# [DATASET] f0063_aug1, shape=(13, 100)
# [DATASET] f0063_aug2, shape=(13, 100)
# [DATASET] f0064, shape=(13, 100)
# [DATASET] f0064_aug0, shape=(13, 100)
# [DATASET] f0064_aug1, shape=(13, 100)
# [DATASET] f0064_aug2, shape=(13, 100)
# [DATASET] f0065, shape=(13, 100)
# [DATASET] f0066, shape=(13, 100)
# [DATASET] f0067, shape=(13, 100)
# [DATASET] f0067_aug0, shape=(13, 100)
# [DATASET] f0067_aug1, shape=(13, 100)
# [DATASET] f0067_aug2, shape=(13, 100)
# [DATASET] f0068, shape=(13, 100)
# [DATASET] f0068_aug0, shape=(13, 100)
# [DATASET] f0068_aug1, shape=(13, 100)
# [DATASET] f0068_aug2, shape=(13, 100)
# [DATASET] f0069, shape=(13, 100)
# [DATASET] f0069_aug0, shape=(13, 100)
# [DATASET] f0069_aug1, shape=(13, 100)
# [DATASET] f0069_aug2, shape=(13, 100)
# [DATASET] f0070, shape=(13, 100)
# [DATASET] f0071, shape=(13, 100)
# [DATASET] f0071_aug0, shape=(13, 100)
# [DATASET] f0071_aug1, shape=(13, 100)
# [DATASET] f0071_aug2, shape=(13, 100)
# [DATASET] f0072, shape=(13, 100)
# [DATASET] f0072_aug0, shape=(13, 100)
# [DATASET] f0072_aug1, shape=(13, 100)
# [DATASET] f0072_aug2, shape=(13, 100)
# [DATASET] f0073, shape=(13, 100)
# [DATASET] f0074, shape=(13, 100)
# [DATASET] f0075, shape=(13, 100)
# [DATASET] f0076, shape=(13, 100)
# [DATASET] f0077, shape=(13, 100)
# [DATASET] f0078, shape=(13, 100)
# [DATASET] f0079, shape=(13, 100)
# [DATASET] f0079_aug0, shape=(13, 100)
# [DATASET] f0079_aug1, shape=(13, 100)
# [DATASET] f0079_aug2, shape=(13, 100)
# [DATASET] f0080, shape=(13, 100)
# [DATASET] f0081, shape=(13, 100)
# [DATASET] f0082, shape=(13, 100)
# [DATASET] f0082_aug0, shape=(13, 100)
# [DATASET] f0082_aug1, shape=(13, 100)
# [DATASET] f0082_aug2, shape=(13, 100)
# [DATASET] f0083, shape=(13, 100)
# [DATASET] f0083_aug0, shape=(13, 100)
# [DATASET] f0083_aug1, shape=(13, 100)
# [DATASET] f0083_aug2, shape=(13, 100)
# [DATASET] f0084, shape=(13, 100)
# [DATASET] f0085, shape=(13, 100)
# [DATASET] f0085_aug0, shape=(13, 100)
# [DATASET] f0085_aug1, shape=(13, 100)
# [DATASET] f0085_aug2, shape=(13, 100)
# [DATASET] f0086, shape=(13, 100)
# [DATASET] f0087, shape=(13, 100)
# [DATASET] f0088, shape=(13, 100)
# [DATASET] f0089, shape=(13, 100)
# [DATASET] f0089_aug0, shape=(13, 100)
# [DATASET] f0089_aug1, shape=(13, 100)
# [DATASET] f0089_aug2, shape=(13, 100)
# [DATASET] f0090, shape=(13, 100)
# [DATASET] f0090_aug0, shape=(13, 100)
# [DATASET] f0090_aug1, shape=(13, 100)
# [DATASET] f0090_aug2, shape=(13, 100)
# [DATASET] f0091, shape=(13, 100)
# [DATASET] f0092, shape=(13, 100)
# [DATASET] f0093, shape=(13, 100)
# [DATASET] f0093_aug0, shape=(13, 100)
# [DATASET] f0093_aug1, shape=(13, 100)
# [DATASET] f0093_aug2, shape=(13, 100)
# [DATASET] f0094, shape=(13, 100)
# [DATASET] f0095, shape=(13, 100)
# [DATASET] f0096, shape=(13, 100)
# [DATASET] f0096_aug0, shape=(13, 100)
# [DATASET] f0096_aug1, shape=(13, 100)
# [DATASET] f0096_aug2, shape=(13, 100)
# [DATASET] f0097, shape=(13, 100)
# [DATASET] f0098, shape=(13, 100)
# [DATASET] f0099, shape=(13, 100)
# [DATASET] f0099_aug0, shape=(13, 100)
# [DATASET] f0099_aug1, shape=(13, 100)
# [DATASET] f0099_aug2, shape=(13, 100)
# [DATASET] f0100, shape=(13, 100)
# [DATASET] f0101, shape=(13, 100)
# [DATASET] f0102, shape=(13, 100)
# [DATASET] f0103, shape=(13, 100)
# [DATASET] f0103_aug0, shape=(13, 100)
# [DATASET] f0103_aug1, shape=(13, 100)
# [DATASET] f0103_aug2, shape=(13, 100)
# [DATASET] f0104, shape=(13, 100)
# [DATASET] f0105, shape=(13, 100)
# [DATASET] f0106, shape=(13, 100)
# [DATASET] f0107, shape=(13, 100)
# [DATASET] f0108, shape=(13, 100)
# [DATASET] f0109, shape=(13, 100)
# [DATASET] f0110, shape=(13, 100)
# [DATASET] f0111, shape=(13, 100)
# [DATASET] f0112, shape=(13, 100)
# [DATASET] f0113, shape=(13, 100)
# [DATASET] f0114, shape=(13, 100)

# %%
import pandas as pd
from pathlib import Path

# Load label gốc (FULL)
df_base = pd.read_csv(PROJECT_PATH / "data" / "label.csv")

# Chuẩn hoá ID gốc
df_base["id"] = df_base["filename"].apply(lambda x: Path(x).stem)

label_map = dict(zip(df_base["id"], df_base["label"]))

rows = []

with h5py.File(h5_path, "r") as f:
    for key in f.keys():
        base = key.split("_aug")[0]
        if base in label_map:
            rows.append({
                "filename": key,
                "label": label_map[base]
            })
        else:
            print("⚠️ Missing base label:", key)

df_full = pd.DataFrame(rows)
df_full.to_csv(PROJECT_PATH / "data" / "label_balanced.csv", index=False)

print("✅ label_balanced.csv created")
print(df_full["label"].value_counts())
# Out:
# ✅ label_balanced.csv created
# label
# 1    2660
# 0    2575
# Name: count, dtype: int64

# %%
# =========================
# Load label CSV
# =========================
label_csv = PROJECT_PATH / "data" / "label_balanced.csv"
df = pd.read_csv(label_csv)

# Map: base_id -> label
label_map = {
    row["filename"]: row["label"]
    for _, row in df.iterrows()
}

def base_id(sample_id: str) -> str:
    """Chuẩn hoá ID: bỏ _augX nếu có"""
    return sample_id.split("_aug")[0]

# =========================
# Count labels in HDF5
# =========================
label_counter = Counter()
unknown = []

with h5py.File(h5_path, "r") as f:
    for name in f.keys():
        bid = base_id(name)
        if bid in label_map:
            if label_map[bid] == 1:
                label_counter["Abnormal"] += 1
            else:
                label_counter["Normal"] += 1
        else:
            label_counter["Unknown"] += 1
            unknown.append(name)

# =========================
# Print statistics
# =========================
total = sum(label_counter.values())

print("\n=== CLASS DISTRIBUTION (CSV-BASED) ===")
print(f"Tổng số mẫu: {total}")

for cls, cnt in label_counter.items():
    print(f"{cls}: {cnt} ({cnt/total*100:.2f}%)")

if unknown:
    print(f"\n⚠️ Unknown samples: {len(unknown)}")
    print("Ví dụ:", unknown[:10])
# Out:
# === CLASS DISTRIBUTION (CSV-BASED) ===
# Tổng số mẫu: 5235
# Abnormal: 2660 (50.81%)
# Normal: 2575 (49.19%)

# %%
import h5py
import pandas as pd
from collections import Counter
from pathlib import Path

def print_class_distribution(h5_path, label_csv_path, title=None):
    """
    In ra tỷ lệ Normal / Abnormal trong file .h5
    """
    # Load label.csv
    df = pd.read_csv(label_csv_path)
    df["basename"] = df["filename"].apply(lambda x: Path(x).stem)

    label_dict = dict(zip(df["basename"], df["label"]))

    counter = Counter()

    with h5py.File(h5_path, "r") as f:
        for key in f.keys():
            if key not in label_dict:
                counter["Unknown"] += 1
                continue

            if label_dict[key] == 1:
                counter["Abnormal"] += 1
            else:
                counter["Normal"] += 1

    total = counter["Normal"] + counter["Abnormal"]

    if title:
        print(f"\n=== {title} ===")

    print(f"Tổng số mẫu: {total}")
    print(f"Normal  : {counter['Normal']} ({counter['Normal']/total*100:.2f}%)")
    print(f"Abnormal: {counter['Abnormal']} ({counter['Abnormal']/total*100:.2f}%)")

    if counter["Unknown"] > 0:
        print(f"⚠️ Unknown (không có nhãn): {counter['Unknown']}")

# %% [markdown]
# # Test

# %%
DATASET_PATH = Path('/content/drive/MyDrive/physionet2016')
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')

VALIDATION_FOLDER = DATASET_PATH / 'validation'

# %%
LOGMEL_FOLDER_VAL = PROJECT_PATH / 'logmel_features_validation'
LOGMEL_FOLDER_VAL.mkdir(parents=True, exist_ok=True)

MFCC_FOLDER_VAL = PROJECT_PATH / 'mfcc_features_validation'
MFCC_FOLDER_VAL.mkdir(parents=True, exist_ok=True)

# %%
OUTPUT_H5_VAL = PROJECT_PATH / 'data' / 'logmel_features_validation.h5'
OUTPUT_H5_VAL.parent.mkdir(parents=True, exist_ok=True)

# %%
ref_path = VALIDATION_FOLDER / 'REFERENCE.csv'
if not ref_path.exists():
    raise FileNotFoundError(f"Không tìm thấy REFERENCE.csv tại {ref_path}")

df_val = pd.read_csv(ref_path, header=None, names=['basename', 'label'])
df_val['filename'] = [str(VALIDATION_FOLDER / (base + '.wav')) for base in df_val['basename']]
df_val['label'] = (df_val['label'] + 1) // 2  # -1 -> 0, 1 -> 1 (giống training)

# Lưu label.csv cho validation (tùy chọn, để sau này dễ load)
val_label_path = PROJECT_PATH / 'data' / 'label_validation.csv'
df_val[['filename', 'label']].to_csv(val_label_path, index=False)
print(f"Đã tạo label_validation.csv với {len(df_val)} mẫu.")
# Out:
# Đã tạo label_validation.csv với 301 mẫu.

# %%
# -------------------------- Tham số trích xuất --------------------------
mel_bins = 128
hoplen = 15    # ms
winlen = 25    # ms
EPS = 1e-8

# %% [markdown]
# ## Convert to LogMel and MFCC

# %%
import os
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter
from pathlib import Path

# =========================
# read_audio()
# augment_audio()
# PROJECT_PATH
# MfccExtractor()
# LogMelExtractor()
# =========================

if __name__ == "__main__":

    df = pd.read_csv(PROJECT_PATH / "data" / "label_validation.csv")

    logmel_folder = PROJECT_PATH / 'logmel_features_validation'
    mfcc_folder   = PROJECT_PATH / 'mfcc_features_validation'

    os.makedirs(logmel_folder, exist_ok=True)
    os.makedirs(mfcc_folder, exist_ok=True)

    # ===== Class balancing =====
    label_counts = Counter(df["label"])
    n_normal   = label_counts[0]
    n_abnormal = label_counts[1]

    target_abnormal = n_normal
    augment_per_abnormal = int(
        np.ceil((target_abnormal - n_abnormal) / n_abnormal)
    )

    print("=== ORIGINAL DISTRIBUTION ===")
    print(f"Normal  : {n_normal}")
    print(f"Abnormal: {n_abnormal}")
    print(f"Augment per abnormal sample: {augment_per_abnormal}")

    # ===== Feature parameters =====
    mel_bins = 128
    n_mfcc   = 13
    hoplen   = 15   # ms
    winlen   = 25   # ms
    T_fixed  = 100
    # =========================
    # Feature extraction
    # =========================
    for _, row in tqdm(df.iterrows(), total=len(df)):

        filename = row["filename"]
        label    = row["label"]

        audio, fs = read_audio(filename, filter=True)
        basename = Path(filename).stem

        # ===== ORIGINAL SAMPLE =====
        logmel = LogMelExtractor(
            audio, fs,
            mel_bins=mel_bins,
            hoplen=hoplen,
            winlen=winlen
        )

        mfcc = MfccExtractor(
            audio, fs,
            n_mfcc=n_mfcc,
            hoplen=hoplen,
            winlen=winlen,
            T_fixed=T_fixed
        )

        np.save(logmel_folder / f"{basename}.npy", logmel)
        np.save(mfcc_folder   / f"{basename}.npy", mfcc)

    print("\n✅ Feature extraction + augmentation completed.")
# Out:
# === ORIGINAL DISTRIBUTION ===
# Normal  : 150
# Abnormal: 151
# Augment per abnormal sample: 0
# 100%|██████████| 301/301 [08:51<00:00,  1.76s/it]
# ✅ Feature extraction + augmentation completed.

# %% [markdown]
# ## LogMel to .h5

# %%
# Cell: Chuyển tất cả file .npy sang một file .h5 lớn (CHỈ CHẠY 1 LẦN)
import numpy as np
import h5py
from pathlib import Path
from tqdm.notebook import tqdm  # Để có progress bar đẹp

FEATURES_DIR = PROJECT_PATH /"logmel_features_validation"  # Thư mục chứa các .npy
OUTPUT_H5 = PROJECT_PATH /"data"/"logmel_features_validation.h5"   # File output

if OUTPUT_H5.exists():
    print(f"File {OUTPUT_H5} ĐÃ TỒN TẠI – bỏ qua việc tạo lại.")
    print("Nếu muốn tạo lại, xóa file này trước: !rm '{OUTPUT_H5}'")
else:
    print("Đang chuyển đổi tất cả .npy sang .h5 ... (có thể mất vài phút tùy số lượng file)")
    npy_files = list(FEATURES_DIR.glob("*.npy"))
    print(f"Tìm thấy {len(npy_files)} file .npy")

    with h5py.File(OUTPUT_H5, 'w') as f_out:
      for npy_file in tqdm(npy_files):
          key = npy_file.stem
          data = np.load(npy_file)

          # Chỉ chấp nhận (M, T)
          assert data.ndim == 2, f"{key} has invalid shape {data.shape}"

          f_out.create_dataset(
              key,
              data=data.astype(np.float32),
              compression="gzip"
          )

    print(f"HOÀN THÀNH! File đã tạo: {OUTPUT_H5}")
# Out:
# Đang chuyển đổi tất cả .npy sang .h5 ... (có thể mất vài phút tùy số lượng file)
# Tìm thấy 301 file .npy
#   0%|          | 0/301 [00:00<?, ?it/s]
# HOÀN THÀNH! File đã tạo: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/logmel_features_validation.h5

# %%
# =========================
# Load label CSV
# =========================
label_csv = PROJECT_PATH / "data" / "label_validation.csv"
df = pd.read_csv(label_csv)
h5_path = str(OUTPUT_H5)
# Map: base_id -> label
label_map = {
    Path(row["filename"]).stem: row["label"]
    for _, row in df.iterrows()
}

def base_id(sample_id: str) -> str:
    """Chuẩn hoá ID: bỏ _augX nếu có"""
    return sample_id.split("_aug")[0]

# =========================
# Count labels in HDF5
# =========================
label_counter = Counter()
unknown = []

with h5py.File(h5_path, "r") as f:
    for name in f.keys():
        bid = base_id(name)
        if bid in label_map:
            if label_map[bid] == 1:
                label_counter["Abnormal"] += 1
            else:
                label_counter["Normal"] += 1
        else:
            label_counter["Unknown"] += 1
            unknown.append(name)

# =========================
# Print statistics
# =========================
total = sum(label_counter.values())

print("\n=== CLASS DISTRIBUTION (CSV-BASED) ===")
print(f"Tổng số mẫu: {total}")

for cls, cnt in label_counter.items():
    print(f"{cls}: {cnt} ({cnt/total*100:.2f}%)")

if unknown:
    print(f"\n⚠️ Unknown samples: {len(unknown)}")
    print("Ví dụ:", unknown[:10])
# Out:
# === CLASS DISTRIBUTION (CSV-BASED) ===
# Tổng số mẫu: 301
# Abnormal: 151 (50.17%)
# Normal: 150 (49.83%)

# %% [markdown]
# ## MFCC to .h5

# %%
# ==============================
# MERGE MFCC .npy → HDF5
# ==============================
import numpy as np
import h5py
from pathlib import Path
from tqdm.notebook import tqdm

MFCC_DIR = PROJECT_PATH / "mfcc_features_validation"          # Thư mục chứa MFCC .npy
OUTPUT_H5 = PROJECT_PATH / "data" / "mfcc_features_validation.h5"

if OUTPUT_H5.exists():
    print(f"File {OUTPUT_H5} đã tồn tại – bỏ qua.")
else:
    npy_files = sorted(MFCC_DIR.glob("*.npy"))
    print(f"🔎 Found {len(npy_files)} MFCC files")

    with h5py.File(OUTPUT_H5, "w") as f_out:
        for npy_file in tqdm(npy_files, desc="Converting MFCC"):
            key = npy_file.stem
            data = np.load(npy_file)

            # MFCC chuẩn: (n_mfcc, time)
            assert data.ndim == 2, f"{key} invalid shape {data.shape}"

            f_out.create_dataset(
                key,
                data=data.astype(np.float32),
                compression="gzip"
            )

    print(f"✅ MFCC HDF5 created: {OUTPUT_H5}")
# Out:
# 🔎 Found 301 MFCC files
# Converting MFCC:   0%|          | 0/301 [00:00<?, ?it/s]
# ✅ MFCC HDF5 created: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/mfcc_features_validation.h5

# %%
# =========================
# Load label CSV
# =========================
label_csv = PROJECT_PATH / "data" / "label_validation.csv"
df = pd.read_csv(label_csv)
h5_path = str(OUTPUT_H5)
# Map: base_id -> label
label_map = {
    Path(row["filename"]).stem: row["label"]
    for _, row in df.iterrows()
}

def base_id(sample_id: str) -> str:
    """Chuẩn hoá ID: bỏ _augX nếu có"""
    return sample_id.split("_aug")[0]

# =========================
# Count labels in HDF5
# =========================
label_counter = Counter()
unknown = []

with h5py.File(h5_path, "r") as f:
    for name in f.keys():
        bid = base_id(name)
        if bid in label_map:
            if label_map[bid] == 1:
                label_counter["Abnormal"] += 1
            else:
                label_counter["Normal"] += 1
        else:
            label_counter["Unknown"] += 1
            unknown.append(name)

# =========================
# Print statistics
# =========================
total = sum(label_counter.values())

print("\n=== CLASS DISTRIBUTION (CSV-BASED) ===")
print(f"Tổng số mẫu: {total}")

for cls, cnt in label_counter.items():
    print(f"{cls}: {cnt} ({cnt/total*100:.2f}%)")

if unknown:
    print(f"\n⚠️ Unknown samples: {len(unknown)}")
    print("Ví dụ:", unknown[:10])
# Out:
# === CLASS DISTRIBUTION (CSV-BASED) ===
# Tổng số mẫu: 301
# Abnormal: 151 (50.17%)
# Normal: 150 (49.83%)
