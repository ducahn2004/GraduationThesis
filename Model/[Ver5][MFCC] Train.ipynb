# %%
import numpy as np
import pandas as pd
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import numpy as np
from torch.utils.data import DataLoader, Sampler
from torch.utils.data.dataloader import default_collate
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision.utils import make_grid

from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    balanced_accuracy_score,
    matthews_corrcoef
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
from pathlib import Path

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
sys.path.append(str(DATASET_PATH))

# %% [markdown]
# # Load Data

# %% [markdown]
# ## HeartSoundDataSet

# %%
def spec_augment(spec, F=8, T=40, num_masks=2):
    """SpecAugment cho MFCC"""
    cloned = spec.clone()
    num_mel_channels, num_frames = cloned.shape[-2:]

    # Frequency masking
    for _ in range(num_masks):
        f = np.random.randint(0, F)
        f0 = np.random.randint(0, num_mel_channels - f)
        cloned[..., f0:f0+f, :] = 0

    # Time masking
    for _ in range(num_masks):
        t = np.random.randint(0, T)
        t0 = np.random.randint(0, num_frames - t)
        cloned[..., :, t0:t0+t] = 0

    return cloned

# %%
import numpy as np
import h5py
import random
import torch
from pathlib import Path
import librosa  # cần import để tính delta

EPS = 1e-8

def standard_normal_variate(data):
    """Chuẩn hóa Z-score trên toàn bộ tensor."""
    mean = np.mean(data)
    std = np.std(data) + EPS
    return (data - mean) / std

class HeartSoundDataSet(torch.utils.data.Dataset):
    def __init__(self,
                 fea_path: str,              # đường dẫn file .h5
                 labels: pd.DataFrame,       # DataFrame với cột 'filename' và 'label'
                 duration: int = 5,          # giây
                 training: bool = True,
                 delta: bool = False,
                 norm: bool = True):
        self._fea_path = fea_path
        self._h5database = None
        self._labels = labels.reset_index(drop=True)
        self._colname = ['filename', 'label']
        self._len = len(self._labels)
        self._duration = duration
        self._delta = delta
        self.train = training
        self.hop_length = 15  # ms
        self.norm = norm

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
      row = self._labels.iloc[idx]
      filename = row['filename']
      target_bin = row['label']

      # Lấy key từ stem của filename
      key = Path(filename).stem if '/' in str(filename) else filename

      # Mở HDF5 nếu chưa mở
      if self._h5database is None:
          self._h5database = h5py.File(self._fea_path, 'r')

      if key not in self._h5database:
          available = list(self._h5database.keys())[:10]
          raise KeyError(f"Key '{key}' not found in HDF5. Sample keys: {available}")

      # Load feature từ HDF5
      feature = self._h5database[key][()]  # (mel_bins, T) hoặc (C, mel_bins, T)

      # Đảm bảo feature là 3D: (C, H, W)
      if feature.ndim == 2:
          feature = feature[np.newaxis, :, :]  # → (1, mel_bins, T)
      elif feature.ndim != 3:
          raise ValueError(f"Unexpected shape {feature.shape} for key '{key}'")

      # Chuẩn hóa toàn bộ tensor (nếu bật)
      if self.norm:
          feature = standard_normal_variate(feature)

      # Thêm delta features (nếu bật)
      if self._delta:
          orig = feature[0]  # (mel_bins, T)
          delta = librosa.feature.delta(orig)
          delta2 = librosa.feature.delta(delta)
          feature = np.stack([orig, delta, delta2], axis=0)  # → (3, mel_bins, T)

      # Lấy shape hiện tại
      channels, mel_bins, num_frames = feature.shape

      # Tính độ dài mong muốn (frames)
      cycle_len = int(self._duration * 1000 / self.hop_length)

      # Crop hoặc pad để đạt đúng cycle_len
      if num_frames >= cycle_len:
          if self.train:
              feature_tensor = spec_augment(feature_tensor, F=5, T=30, num_masks=1)
              #start_ind = random.randint(0, num_frames - cycle_len)
          else:
              start_ind = (num_frames - cycle_len) // 2
          feature = feature[:, :, start_ind:start_ind + cycle_len]
      elif num_frames < cycle_len:
          pad_width = ((0, 0), (0, 0), (0, cycle_len - num_frames))
          feature = np.pad(feature, pad_width, mode='wrap')

      # === Fix quan trọng cho model gốc: Làm cho tensor luôn là 3D (mel_bins, num_frames) ===
      feature_tensor = torch.from_numpy(feature).float()  # (C, mel_bins, T)

      if channels > 1:  # Có delta → C=3
          # Ghép 3 channels vào chiều mel_bins → (3 * mel_bins, T) = (384, T)
          # Model sẽ view thành (B, 3, 128, T) trong forward
          feature_tensor = feature_tensor.view(channels * mel_bins, -1)  # → (384, T)
      else:
          # Không delta → squeeze về (mel_bins, T) = (128, T)
          feature_tensor = feature_tensor.squeeze(0)

      return feature_tensor, torch.tensor(target_bin, dtype=torch.long)

    def __del__(self):
        """Đóng file HDF5 khi object bị hủy (tốt cho quản lý tài nguyên)."""
        if self._h5database is not None:
            self._h5database.close()

# %% [markdown]
# ## MinimumOccupancySampler

# %%
class MinimumOccupancySampler(Sampler):
    """
        samples at least one instance from each class sequentially
    """
    def __init__(self, labels, sampling_mode='over', random_state=None):
        data_samples = labels.shape
        n_labels = len(np.unique(labels))
        label_to_idx_list, label_to_length = [], []
        self.random_state = np.random.RandomState(seed=random_state)
        for lb_idx in range(n_labels):
            label_indexes = np.where(labels == lb_idx)[0]
            self.random_state.shuffle(label_indexes)
            label_to_length.append(len(label_indexes))
            label_to_idx_list.append(label_indexes)

        self.longest_seq = max(label_to_length)
        self.data_source = np.empty((self.longest_seq, len(label_to_length)), dtype=int)
        # Each column represents one "single instance per class" data piece
        for ix, leng in enumerate(label_to_length):
            self.data_source[:leng, ix] = label_to_idx_list[ix]
        self.label_to_length = label_to_length
        self.label_to_idx_list = label_to_idx_list

        if sampling_mode == 'same':
            self.data_length = data_samples
        elif sampling_mode == 'over':  # Sample all items
            self.data_length = np.prod(self.data_source.shape)

    def _resample(self):
        for ix, leng in enumerate(self.label_to_length):
            leftover = self.longest_seq - leng
            random_idxs = np.random.randint(leng, size=leftover)
            self.data_source[leng:, ix] = self.label_to_idx_list[ix][random_idxs]

    def __iter__(self):
        self._resample()
        n_samples = len(self.data_source)
        random_indices = self.random_state.permutation(n_samples)
        data = np.concatenate(
            self.data_source[random_indices])[:self.data_length]
        return iter(data)

    def __len__(self):
        return self.data_length

# %% [markdown]
# ## HeartSoundDataLoader

# %%
class BaseDataLoader(DataLoader):
    """
    Base class for all data loaders
    """
    def __init__(self, dataset, batch_size, shuffle, validation_split, num_workers, collate_fn=default_collate, sampler_type=None):
        self.validation_split = validation_split
        self.shuffle = shuffle

        self.batch_idx = 0
        self.n_samples = len(dataset)
        self.sampler_type = sampler_type
        self.sampler, self.valid_sampler = self._split_sampler(self.validation_split)
        self.init_kwargs = {
            'dataset': dataset,
            'batch_size': batch_size,
            'shuffle': self.shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.sampler, **self.init_kwargs)

    def _split_sampler(self, split):
        if split == 0.0:
            return None, None

        idx_full = np.arange(self.n_samples)

        np.random.seed(0)
        np.random.shuffle(idx_full)

        if isinstance(split, int):
            assert split > 0
            assert split < self.n_samples, "validation set size is configured to be larger than entire dataset."
            len_valid = split
        else:
            len_valid = int(self.n_samples * split)

        valid_idx = idx_full[0:len_valid]
        train_idx = np.delete(idx_full, np.arange(0, len_valid))
        if self.sampler_type == 'MinimumOccupancySampler':
            train_sampler = MinimumOccupancySampler(np.stack(self.label_df.iloc[train_idx]['label']), random_state=100)
        else:
            train_sampler = SubsetRandomSampler(train_idx)
        valid_sampler = SubsetRandomSampler(valid_idx)

        # turn off shuffle option which is mutually exclusive with sampler
        self.shuffle = False
        self.n_samples = len(train_idx)

        return train_sampler, valid_sampler

    def split_validation(self):
        if self.valid_sampler is None:
            return None
        else:
            return DataLoader(sampler=self.valid_sampler, **self.init_kwargs)

# %%
class HeartSoundDataLoader(DataLoader):
    def __init__(self,
                 fea_path,
                 label_df,
                 duration,
                 batch_size,
                 delta=False,
                 norm = False,
                 shuffle=True,
                 validation_split=0.0,
                 num_workers=1,
                 training=True,
                 collate_fn=None):
        if training:
            self.train_df, self.val_df = train_test_split(label_df, test_size=validation_split, shuffle=True)

            self.train_sampler = MinimumOccupancySampler(np.stack(self.train_df['label']), random_state=100)
            self.val_dataset = HeartSoundDataSet(fea_path, self.val_df, duration=duration, training=False, delta=delta, norm=norm)

        else:
            self.train_df = label_df
            self.train_sampler = None
        self.dataset = HeartSoundDataSet(fea_path, self.train_df, duration=duration,
                                               training=training, delta=delta, norm=norm)
        self.init_kwargs = {
            'batch_size': batch_size,
            'shuffle': shuffle,
            'collate_fn': collate_fn,
            'num_workers': num_workers
        }
        super().__init__(sampler=self.train_sampler,
                         dataset = self.dataset,
                         **self.init_kwargs)

    def split_validation(self):
        return DataLoader(dataset= self.val_dataset, **self.init_kwargs)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_balanced.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("MFCC (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0001_aug0', 'a0001_aug1', 'a0001_aug2', 'a0002', 'a0002_aug0', 'a0002_aug1', 'a0002_aug2', 'a0003', 'a0003_aug0']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 1 1 1]
# Value range: -4.155 ~ 1.561

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import h5py
from pathlib import Path

print("=== Debug DataLoader (FINAL FIXED VERSION) ===")
fea_path = str(DATASET_PATH/"mfcc_features_validation.h5")

# Load label CSV
label_df = pd.read_csv(DATASET_PATH / 'label_validation.csv')
print("Label CSV columns:", label_df.columns.tolist())

# Sửa filename thành stem
label_df['filename'] = label_df['filename'].apply(lambda x: Path(x).stem)

# Kiểm tra HDF5 keys
with h5py.File(fea_path, 'r') as f:
    print("First 10 HDF5 keys:", list(f.keys())[:10])

# Debug dataset
debug_dataset = HeartSoundDataSet(
    fea_path=fea_path,
    labels=label_df.head(8),
    duration=5,
    training=True,
    delta=True,   # Đang bật delta → 384 mel bins
    norm=True
)

debug_loader = DataLoader(debug_dataset, batch_size=4, shuffle=True, num_workers=0)

for data, target in debug_loader:
    print(f"Batch shape: {data.shape}")
    print(f"Targets: {target.numpy()}")
    print(f"Value range: {data.min().item():.3f} ~ {data.max().item():.3f}")

    # === PHẦN VISUALIZE ĐÃ FIX ===
    plt.figure(figsize=(16, 4))
    for i in range(data.shape[0]):
        plt.subplot(1, 4, i + 1)

        spectrogram = data[i].numpy()  # shape: (384, 333) nếu delta=True, hoặc (128, 333) nếu delta=False

        # Nếu dùng delta → tách ra để chỉ vẽ channel gốc (128 mel bins đầu tiên)
        if spectrogram.shape[0] == 384:  # 3 * 128
            img = spectrogram[:128, :]   # Chỉ lấy phần logmel gốc (channel 0)
        else:
            img = spectrogram            # Không delta → vẽ hết

        plt.imshow(img, aspect='auto', origin='lower', cmap='magma', interpolation='nearest')
        plt.title(f"Label: {target[i].item()}\nShape: {img.shape}")
        plt.xlabel("Time frames")
        plt.ylabel("Mel bins (orig)")
        plt.colorbar(format='%+2.0f dB')
        plt.tight_layout()

    plt.suptitle("Log-Mel Spectrogram (Original channel only)", fontsize=16, y=1.02)
    plt.show()
    break
# Out:
# === Debug DataLoader (FINAL FIXED VERSION) ===
# Label CSV columns: ['filename', 'label']
# First 10 HDF5 keys: ['a0001', 'a0002', 'a0003', 'a0004', 'a0005', 'a0006', 'a0007', 'a0008', 'a0009', 'a0010']
# Batch shape: torch.Size([4, 39, 333])
# Targets: [1 1 1 1]
# Value range: -4.085 ~ 1.410

# %% [markdown]
# # ConfigParser

# %%
# parse_config.py
import os
import logging
from pathlib import Path
from datetime import datetime
import argparse
import collections
import importlib.util

class ConfigParser:
    def __init__(self, config_dict, resume=None, modification=None, run_id=None):
        self._config = config_dict
        self.resume = resume

        # Apply CLI modifications
        if modification:
            for key_path, value in modification.items():
                keys = key_path.split(';')
                d = self._config
                for k in keys[:-1]:
                    d = d[k]
                d[keys[-1]] = value

        # Setup save and log directories
        save_dir = Path(self.config['trainer']['save_dir'])
        exper_name = self.config['name']
        if run_id is None:
            run_id = datetime.now().strftime(r'%m%d_%H%M%S')
        self._save_dir = save_dir / 'models' / exper_name / run_id
        self._log_dir = save_dir / 'log' / exper_name / run_id

        self.save_dir.mkdir(parents=True, exist_ok=True)
        self.log_dir.mkdir(parents=True, exist_ok=True)

        # Optional: setup logging
        # setup_logging(self.log_dir)

    @classmethod
    def from_args(cls, parser, options=None):
        """
        parser: argparse.ArgumentParser đã được add_argument xong
        options: list các CustomArgs để override
        """
        if options is None:
            options = []

        # Parse arguments (an toàn cho cả terminal và notebook)
        args = parser.parse_args()

        # Xử lý device
        if args.device is not None:
            os.environ["CUDA_VISIBLE_DEVICES"] = args.device

        # Xử lý resume
        if args.resume is not None:
            resume = Path(args.resume)
            cfg_fname = resume.parent / 'config.py'  # hoặc .json nếu bạn dùng cả 2
        else:
            resume = None
            assert args.config is not None, "Phải chỉ định -c config.py"
            cfg_fname = Path(args.config)

        # Đọc config từ file .py
        if not cfg_fname.exists():
            raise FileNotFoundError(f"Không tìm thấy config file: {cfg_fname}")

        if cfg_fname.suffix == '.py':
            spec = importlib.util.spec_from_file_location("config_module", cfg_fname)
            config_module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(config_module)
            if not hasattr(config_module, 'config'):
                raise ValueError(f"File {cfg_fname} phải định nghĩa biến 'config'")
            config_dict = config_module.config
        else:
            raise ValueError("Chỉ hỗ trợ file config .py")

        # Parse custom CLI overrides
        CustomArgs = collections.namedtuple('CustomArgs', 'flags type target')
        modification = {}
        for opt in options:
            for flag in opt.flags:
                arg_name = flag.lstrip('-').replace('-', '_')
                if hasattr(args, arg_name) and getattr(args, arg_name) is not None:
                    modification[opt.target] = opt.type(getattr(args, arg_name))

        return cls(config_dict, resume, modification)

    def init_obj(self, name, module, *args, **kwargs):
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def init_ftn(self, name, module, *args, **kwargs):
        from functools import partial
        module_name = self[name]['type']
        module_args = dict(self[name]['args'])
        module_args.update(kwargs)
        if isinstance(module, dict):
            obj_class = module[module_name]
        else:
            obj_class = getattr(module, module_name)

        return obj_class(*args, **module_args)

    def __getitem__(self, name):
        return self.config[name]

    def get_logger(self, name, verbosity=2):
        logger = logging.getLogger(name)
        logger.setLevel({0: logging.WARNING, 1: logging.INFO, 2: logging.DEBUG}[verbosity])
        return logger

    @property
    def config(self):
        return self._config

    @property
    def save_dir(self):
        return self._save_dir

    @property
    def log_dir(self):
        return self._log_dir

# %% [markdown]
# # Logging

# %%
def mixup_data(x, y, alpha=0.2):
    """Mixup augmentation"""
    lam = np.random.beta(alpha, alpha)
    batch_size = x.size(0)
    index = torch.randperm(batch_size).to(x.device)

    mixed_x = lam * x + (1 - lam) * x[index]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %% [markdown]
# #Loss

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=1.5):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# %%
class CBFocalLoss(nn.Module):
    def __init__(self, samples_per_class, beta=0.9999, gamma=2.0):
        super().__init__()
        effective_num = 1.0 - np.power(beta, samples_per_class)
        weights = (1.0 - beta) / np.array(effective_num)
        self.weights = weights / np.sum(weights) * len(samples_per_class)
        self.gamma = gamma

    def forward(self, inputs, targets):
        weights = torch.tensor(self.weights, device=inputs.device).float()
        ce_loss = F.cross_entropy(inputs, targets, weight=weights, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1-pt)**self.gamma * ce_loss
        return focal_loss.mean()

# Sử dụng:
# samples_per_class = [số_mẫu_abnormal, số_mẫu_normal]

# %%
class WeightedCELoss(nn.Module):
    """
    Weighted Cross Entropy Loss
    """
    def __init__(self, weights):
        super().__init__()
        self.register_buffer(
            "weights", torch.tensor(weights, dtype=torch.float)
        )

    def forward(self, logits, target):
        return F.cross_entropy(
            logits,
            target,
            weight=self.weights
        )

# %%
class CostSensitiveLoss(nn.Module):
    """
    Cost-sensitive Cross Entropy
    FN (abnormal → normal) bị phạt nặng hơn FP
    """
    def __init__(self, fn_cost=2.5, fp_cost=1.0):
        super().__init__()
        self.fn_cost = fn_cost
        self.fp_cost = fp_cost

    def forward(self, logits, target):
        weights = torch.tensor(
            [self.fp_cost, self.fn_cost],
            device=logits.device
        )

        return F.cross_entropy(
            logits,
            target,
            weight=weights
        )

# %%
import torch.nn.functional as F


def nll_loss(output, target):
    return F.nll_loss(output, target)

def ce_loss(output, target):
    return F.cross_entropy(output, target)

def focal_loss(output, target, alpha=0.75, gamma=2.0):
    return FocalLoss(alpha=alpha, gamma=gamma)(output, target)

# Dùng khi tỷ lệ abnormal ≪ normal.
def weighted_ce_loss(output, target, weights):
    return WeightedCELoss(weights)(output, target)

# Đặc biệt phù hợp bài toán y sinh, nơi bỏ sót bệnh (FN) nguy hiểm hơn FP.
def cost_sensitive_loss(output, target, fn_cost=2.5, fp_cost=1.0):
    return CostSensitiveLoss(fn_cost, fp_cost)(output, target)

LOSS_REGISTRY = {
    "ce_loss": lambda: nn.CrossEntropyLoss(),
    "focal_loss": lambda: FocalLoss(alpha=0.75, gamma=2.0),
    "cost_sensitive_loss": lambda: CostSensitiveLoss(fn_cost=2.5, fp_cost=1.0),
    "weighted_ce_loss": lambda weights: WeightedCELoss(weights),
}

# %% [markdown]
# # Metric

# %%
import torch


def accuracy(output, target):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        assert pred.shape[0] == len(target)
        correct = 0
        correct += torch.sum(pred == target).item()
    return correct / len(target)

import torch

def sensitivity(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)
        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()
    return tp / (tp + fn + eps)


def f1_score(output, target, positive_class=1, eps=1e-8):
    with torch.no_grad():
        pred = torch.argmax(output, dim=1)

        tp = torch.sum((pred == positive_class) & (target == positive_class)).item()
        fp = torch.sum((pred == positive_class) & (target != positive_class)).item()
        fn = torch.sum((pred != positive_class) & (target == positive_class)).item()

        precision = tp / (tp + fp + eps)
        recall    = tp / (tp + fn + eps)

        f1 = 2 * precision * recall / (precision + recall + eps)

    return f1

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

# Warmup scheduler
class WarmupCosineScheduler:
    def __init__(self, optimizer, warmup_epochs, total_epochs, lr_min=1e-6):
        self.optimizer = optimizer
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.lr_min = lr_min
        self.base_lr = optimizer.param_groups[0]['lr']

    def step(self, epoch):
        if epoch < self.warmup_epochs:
            lr = self.base_lr * (epoch + 1) / self.warmup_epochs
        else:
            progress = (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs)
            lr = self.lr_min + (self.base_lr - self.lr_min) * 0.5 * (1 + np.cos(np.pi * progress))

        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr
        return lr

# %%
class EarlyStopping:
    def __init__(self, patience=7, min_delta=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif val_loss > self.best_score - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        else:
            self.best_score = val_loss
            self.counter = 0
        return False

# %% [markdown]
# # Model

# %%
import torch.nn as nn
import numpy as np
from abc import abstractmethod


class BaseModel(nn.Module):
    """
    Base class for all models
    """
    @abstractmethod
    def forward(self, *inputs):
        """
        Forward pass logic

        :return: Model output
        """
        raise NotImplementedError

    def __str__(self):
        """
        Model prints with number of trainable parameters
        """
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        params = sum([np.prod(p.size()) for p in model_parameters])
        return super().__str__() + '\nTrainable parameters: {}'.format(params)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# functions of initializing layers
def init_layer(layer):
    """Initialize a Linear or Convolutional layer."""
    nn.init.xavier_uniform_(layer.weight)

    if hasattr(layer, 'bias'):
        if layer.bias is not None:
            layer.bias.data.fill_(0.)

def init_bn(bn):
    """Initialize a Batchnorm layer."""
    bn.bias.data.fill_(0.)
    bn.weight.data.fill_(1.)

def init_rnn(rnn):
    """init_rnn
    Initialized RNN weights, independent of type GRU/LSTM/RNN
    :param rnn: the rnn model
    """
    for name, param in rnn.named_parameters():
        if 'bias' in name:
            nn.init.constant_(param, 0.0)
        elif 'weight' in name:
            nn.init.xavier_uniform_(param)

def reset_parameters(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            init_layer(module)
        elif isinstance(module, nn.Linear):
            init_layer(module)
        elif isinstance(module, nn.BatchNorm2d):
            init_bn(module)
        elif isinstance(module, nn.LSTM):
            init_rnn(module)

# %% [markdown]
# ## Simple CNN Block

# %%
'''
class simple_cnn(BaseModel):
    def __init__(self, num_classes = 2, in_channel = 1):
        super(simple_cnn, self).__init__()
        self.in_channel = in_channel

        # -------- Block 1 --------
        #self.conv1 = nn.Conv2d(in_channel,16,3)
        self.conv1 = nn.Conv2d(in_channel, 8, kernel_size=3, padding=1)
        #self.bn1 = nn.BatchNorm2d(16)
        self.bn1 = nn.BatchNorm2d(8)

        # -------- Block 2 --------
        #self.conv2 = nn.Conv2d(16,32,3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(16)


        # -------- Global pooling --------
        self.gap = nn.AdaptiveAvgPool2d(1)

        # -------- Regularization + Classifier --------
        self.dropout = nn.Dropout(p=0.5)
        self.output = nn.Linear(16, num_classes)

        self.init_weights()

    def init_weights(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        #init_layer(self.conv3)
        #init_layer(self.fc)
        init_layer(self.output)
        init_bn(self.bn1)
        init_bn(self.bn2)


    def forward(self, x):
        """
        x: (B, mel_bins, time_frames)
        """
        B, mel_bins, num_frames = x.size()
        x = x.view(B, self.in_channel, mel_bins, num_frames)

        # -------- Block 1 --------
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, kernel_size=2)

        # -------- Block 2 --------
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, kernel_size=2)

        # -------- Global Average Pooling --------
        x = self.gap(x)                 # (B, 16, 1, 1)
        x = x.view(x.size(0), -1)       # (B, 16)

        # -------- Classifier --------
        x = self.dropout(x)
        out = self.output(x)

        return out
'''
# Out:
# '\nclass simple_cnn(BaseModel):\n    def __init__(self, num_classes = 2, in_channel = 1):\n        super(simple_cnn, self).__init__()\n        self.in_channel = in_channel\n\n        # -------- Block 1 --------\n        #self.conv1 = nn.Conv2d(in_channel,16,3)\n        self.conv1 = nn.Conv2d(in_channel, 8, kernel_size=3, padding=1)\n        #self.bn1 = nn.BatchNorm2d(16)\n        self.bn1 = nn.BatchNorm2d(8)\n\n        # -------- Block 2 --------\n        #self.conv2 = nn.Conv2d(16,32,3)\n        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)\n        self.bn2 = nn.BatchNorm2d(16)\n\n\n        # -------- Global pooling --------\n        self.gap = nn.AdaptiveAvgPool2d(1)\n\n        # -------- Regularization + Classifier --------\n        self.dropout = nn.Dropout(p=0.5)\n        self.output = nn.Linear(16, num_classes)\n\n        self.init_weights()\n\n    def init_weights(self):\n        init_layer(self.conv1)\n        init_layer(self.conv2)\n        #init_layer(self.conv3)\n        #init_layer(self.fc)\n        init_layer(self.output)\n        init_bn(self.bn1)\n        init_bn(self.bn2)\n\n\n    def forward(self, x):\n        """\n        x: (B, mel_bins, time_frames)\n        """\n        B, mel_bins, num_frames = x.size()\n        x = x.view(B, self.in_channel, mel_bins, num_frames)\n\n        # -------- Block 1 --------\n        x = self.conv1(x)\n        x = self.bn1(x)\n        x = F.relu(x)\n        x = F.max_pool2d(x, kernel_size=2)\n\n        # -------- Block 2 --------\n        x = self.conv2(x)\n        x = self.bn2(x)\n        x = F.relu(x)\n        x = F.max_pool2d(x, kernel_size=2)\n\n        # -------- Global Average Pooling --------\n        x = self.gap(x)                 # (B, 16, 1, 1)\n        x = x.view(x.size(0), -1)       # (B, 16)\n\n        # -------- Classifier --------\n        x = self.dropout(x)\n        out = self.output(x)\n\n        return out\n'

# %%
class simple_cnn(BaseModel):
    def __init__(self, num_classes=2, in_channel=1):
        super(simple_cnn, self).__init__()
        self.in_channel = in_channel

        # -------- Block 1 --------
        self.conv1 = nn.Conv2d(in_channel, 16, kernel_size=(3, 7), padding=(1, 3))
        self.bn1 = nn.BatchNorm2d(16)
        self.drop1 = nn.Dropout2d(p=0.1)

        # -------- Block 2 --------
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 7), padding=(1, 3))
        self.bn2 = nn.BatchNorm2d(32)
        self.drop2 = nn.Dropout2d(p=0.2)

        # -------- Block 3 --------
        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 5), padding=(1, 2))
        self.bn3 = nn.BatchNorm2d(64)
        self.drop3 = nn.Dropout2d(p=0.2)

        # -------- Global pooling --------
        self.gap = nn.AdaptiveAvgPool2d(1)

        # -------- Classifier --------
        self.classifier = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(32, num_classes)
        )

        self.init_weights()

    def init_weights(self):
        # Khởi tạo các lớp Conv
        init_layer(self.conv1)
        init_layer(self.conv2)
        init_layer(self.conv3) # Đừng quên lớp này nhé

        # Khởi tạo các lớp BatchNorm
        init_bn(self.bn1)
        init_bn(self.bn2)
        init_bn(self.bn3) # Khởi tạo thêm BN3

        # Khởi tạo các lớp Linear bên trong Sequential classifier
        for m in self.classifier.modules():
            if isinstance(m, nn.Linear):
                init_layer(m)

    def forward(self, x):
        B, mel_bins, num_frames = x.size()
        x = x.view(B, self.in_channel, mel_bins, num_frames)

        # Block 1
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.drop1(x)
        x = F.max_pool2d(x, kernel_size=(1, 2))

        # Block 2
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.drop2(x)
        x = F.max_pool2d(x, kernel_size=(1, 2))

        # Block 3
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.drop3(x)

        # GAP + Output
        x = self.gap(x).view(x.size(0), -1)
        out = self.classifier(x)
        return out

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size,
                                   stride, padding, groups=in_channels, bias=False)
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU6(inplace=True)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        x = self.bn(x)
        return self.relu(x)

class LightweightHeartSoundCNN(nn.Module):
    def __init__(self, num_classes=2, in_channel=1, dropout=0.2):
        super().__init__()
        self.in_channel = in_channel
        # Input: (B, 39, 333) → reshape thành (B, 1, 39, 333)
        self.stem = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU6(inplace=True)
        )

        self.features = nn.Sequential(
            DepthwiseSeparableConv(16, 32, stride=2),   # → (B, 32, 10, 83)
            DepthwiseSeparableConv(32, 64, stride=2),   # → (B, 64, 5, 41)
            DepthwiseSeparableConv(64, 128, stride=2),  # → (B, 128, 3, 20)
        )

        # Global Average Pooling (thay vì FC lớn)
        self.pool = nn.AdaptiveAvgPool2d(1)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
      """
      x:
        - delta = False: (B, 13, T)
        - delta = True : (B, 39, T)
      """
      B, F, T = x.shape

      # Reshape feature → (B, C, H, W)
      x = x.view(B, self.in_channel, F // self.in_channel, T)
      # (B, 1, 13, T) hoặc (B, 3, 13, T)

      x = self.stem(x)       # Conv2d expects 4D
      x = self.features(x)
      x = self.pool(x)
      x = x.flatten(1)
      return self.classifier(x)

# %% [markdown]
# ## Deeper CNN model, VGG like structure

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_channels = in_channels,
                               out_channels = out_channels,
                               kernel_size = (3,3),
                               stride = (1,1),
                               padding = (1,1),
                               bias =False)

        self.conv2 = nn.Conv2d(in_channels = out_channels,
                               out_channels = out_channels,
                               kernel_size = (3,3),
                               stride = (1,1),
                               padding = (1,1),
                               bias = False)

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.init_weights()

    def init_weights(self):
        init_layer(self.conv1)
        init_layer(self.conv2)
        init_bn(self.bn1)
        init_bn(self.bn2)

    def forward(self, input, pool_size=(2, 2), pool_type='max', activation = 'relu'):
        x = input
        x = F.relu_(self.bn1(self.conv1(x)))
        if activation == 'relu':
            x = F.relu_(self.bn2(self.conv2(x)))
        elif activation == 'sigmoid':
            x = torch.sigmoid(self.bn2(self.conv2(x)))

        if pool_type == 'max':
            x = F.max_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg':
            x = F.avg_pool2d(x, kernel_size=pool_size)
        elif pool_type == 'avg+max':
            x1 = F.avg_pool2d(x, kernel_size=pool_size)
            x2 = F.max_pool2d(x, kernel_size=pool_size)
            x = x1 + x2
        else:
            raise Exception('Incorrect argument!')

        return x

class VGG_11(BaseModel):
    def __init__(self, num_classes, in_channel):
        super(VGG_11, self).__init__()
        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)
        self.conv1 = ConvBlock(in_channels=in_channel, out_channels=64)
        self.conv2 = ConvBlock(in_channels=64, out_channels=128)
        self.conv3 = ConvBlock(in_channels=128, out_channels=256)
        self.conv4 = ConvBlock(in_channels=256, out_channels=512)
        self.fc_final = nn.Linear(512, num_classes)
        self.init_weights()

    def init_weights(self):
        init_bn(self.bn0)
        init_layer(self.fc_final)

    def forward(self, input):
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        # (samples_num, channel, mel_bins, time_stamps)
        x = self.conv1(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)

        output = F.max_pool2d(x, kernel_size=x.shape[2:])
        output = output.view(output.shape[0:2])
        output = F.log_softmax(self.fc_final(output), dim=-1)
        return output


class VGG_13(BaseModel):
    def __init__(self, num_classes, in_channel):
        super(VGG_13, self).__init__()
        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)
        self.conv1 = ConvBlock(in_channels=in_channel, out_channels=64)
        self.conv2 = ConvBlock(in_channels=64, out_channels=128)
        self.conv3 = ConvBlock(in_channels=128, out_channels=256)
        self.conv4 = ConvBlock(in_channels=256, out_channels=512)
        self.conv5 = ConvBlock(in_channels=512, out_channels=512)
        self.fc_1 = nn.Linear(512 * 4* 10, 4096)
        self.fc_2 = nn.Linear(4096, 4096)
        self.fc_final = nn.Linear(4096, num_classes)
        self.init_weights()

    def init_weights(self):
        init_bn(self.bn0)
        init_layer(self.fc_final)
        init_layer(self.fc_1)
        init_layer(self.fc_2)

    def forward(self, input):
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        # (samples_num, channel, time_stemps, mel_bins)
        x = self.conv1(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv5(x, pool_size=(2, 2), pool_type='max')
        x = F.dropout(x, p=0.2, training=self.training)
        #output = F.max_pool2d(x, kernel_size=x.shape[2:])
        #output = output.view(output.shape[0:2])
        x = x.view(x.shape[0], -1)
        x = F.relu_(self.fc_1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu_(self.fc_2(x))
        x = F.dropout(x, p=0.5, training=self.training)
        output = F.log_softmax(self.fc_final(x),dim=-1)
        #output = F.log_softmax(self.fc_final(output), dim=-1)
        return output

# %% [markdown]
# ## RNN - BiLTSM

# %%
class BiLSTM(BaseModel):
    def __init__(self,
                 input_dim=200,
                 hidden_dim=256,
                 num_layers =2,
                 dropout=0.2,
                 num_classes=2,
                 pooling='first',
                 model='lstm',
                 BN=False):
        super(BiLSTM,self).__init__()
        if model == 'lstm':
            self.LSTM = nn.LSTM(input_size=input_dim,
                                hidden_size =hidden_dim,
                                num_layers =num_layers,
                                batch_first =True,
                                dropout=dropout,
                                bidirectional=True)
        elif model == 'gru':
            self.LSTM = nn.GRU(input_size=input_dim,
                               hidden_size =hidden_dim,
                               num_layers =num_layers,
                               batch_first =True,
                               dropout=dropout,
                               bidirectional=True)
        init_rnn(self.LSTM)
        self.BN = BN
        if self.BN:
            self.BatchNorm=nn.BatchNorm1d(hidden_dim*2)

        self.layer_out = nn.Linear(hidden_dim*2,num_classes,bias=False)
        self.pooling=pooling

    def forward(self,x):
        x = x.transpose(2,1) #[Batchsize x Time_frames x Mel_bin]
        x,_ = self.LSTM(x)
        if self.BN:
            x = self.BatchNorm(x.transpose(1,2))
            x = x.transpose(1,2)
        dim =1
        x = self.layer_out(x)  #200,2
        if self.pooling == 'avg':
            x = x.mean(dim)   #average pooling
        elif self.pooling == 'first':
            x = x.select(dim,0)  #first time step
        elif self.pooling == 'last':
            x = x.select(dim,-1)  #first time step
        elif self.pooling == 'max':
            x = x.max(dim)[0]
        elif  self.pooling == 'linear':
            (x**2).sum(dim) / x.sum(dim)
        elif self.pooling == 'exp':
            (x.exp() * x).sum(dim) / x.exp().sum(dim)

        # print(out.shape)
        # out = self.LogSoftmax(out)#the input given is expected to contain log-probabilities. Obtaining log-probabilities in a neural network is easily achieved by adding a LogSoftmax layer in the last layer of your network.
        return x#,A

# %% [markdown]
# ## CRNN

# %%
class CNN_Encoder(nn.Module):
    def __init__(self, in_channels):
        super(CNN_Encoder, self).__init__()

        self.conv1 = ConvBlock(in_channels=in_channels, out_channels=32)
        self.conv2 = ConvBlock(in_channels=32, out_channels=64)
        self.conv3 = ConvBlock(in_channels=64, out_channels=128)
        self.conv4 = ConvBlock(in_channels=128, out_channels=256)
    def forward(self, input):
        x = input
        x = self.conv1(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv3(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training = self.training)
        x = self.conv4(x, pool_size=(2, 2))
        x = F.dropout(x, p=0.2, training=self.training)

        return x

class crnn(BaseModel):
    def __init__(self, in_channel,
                 hidden_dim=128,
                 num_layers = 2,
                 dropout = 0.2,
                 pooling = 'first',
                 model='lstm',
                 BN = True,
                 num_classes=2):
        super(crnn,self).__init__()

        self.in_channel = in_channel
        self.bn0 = nn.BatchNorm2d(128)

        self.cnn = CNN_Encoder(in_channels=in_channel)
        self.bilstm = BiLSTM(input_dim=256,
                             hidden_dim=hidden_dim,
                             num_layers =num_layers,
                             dropout =dropout,
                             num_classes=num_classes,
                             pooling=pooling,
                             model=model,
                             BN=BN)


    def forward(self,input):
        if isinstance(input, (tuple, list)):
          input = input[0]
        # (batch_size, 3, mel_bins, time_stamps)
        B, mel_bins, num_frames = input.size()
        x = input.view(B, self.in_channel, -1, num_frames)
        x = x.transpose(1, 2)
        x = self.bn0(x)
        x = x.transpose(1,2)

        x = self.cnn(x)
        x = F.max_pool2d(x,kernel_size=(x.size(-2), 1)) # pool mel dimension
        x = x.squeeze(-2)  # [B x C x Time_frames]
        output = self.bilstm(x)
        return output

# %% [markdown]
# # Config

# %% [markdown]
# ## CNN

# %%
from pathlib import Path

config_cnn = {
    "name": "Physionet_simple_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "simple_cnn",
        "args": {
            "num_classes": 2,
            "in_channel": 1 #Declare channel
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 3e-5, #2e-4
            "weight_decay": 1e-4, #0.0
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "focal_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "ReduceLROnPlateau",
        "args": {
            "mode": "max",
            "factor": 0.5,
            "patience": 7,
            #"verbose": True,
            "min_lr": 1e-6
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved"/"simple_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_sensitivity",
        "early_stop": 20,
        "tensorboard": True
    }
}

# %% [markdown]
# ## Lightweight CNN Architecture

# %%
from pathlib import Path

config_light_cnn = {
    "name": "Physionet_lightweight_cnn",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "LightweightHeartSoundCNN",
        "args": {
            "num_classes": 2,
            "in_channel": 1 #Declare channel
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel features directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 16,
            "delta": False, #Remove delta
            "norm": True,
            "shuffle": False,
            "validation_split": 0.2,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-3, #2e-4
            "weight_decay": 5e-4, #0.0
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss function and metrics
    # --------------------------------------------------------
    "loss": "focal_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "ReduceLROnPlateau",
        "args": {
            "mode": "max",
            "factor": 0.5,
            "patience": 7,
            #"verbose": True,
            "min_lr": 1e-3
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved"/"lightweight_cnn"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_sensitivity",
        "early_stop": 20,
        "tensorboard": True
    }
}

# %% [markdown]
# ## CRNN

# %%
from pathlib import Path

config_crnn = {
    "name": "Physionet_CRNN",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "crnn",
        "args": {
            "in_channel": 1,
            "hidden_dim": 256,
            "num_layers": 2,
            "dropout": 0.2,
            "pooling": "first",
            "model": "lstm",
            "BN": True,
            "num_classes": 2
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 64,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved" / "CRNN"),
        "save_period": 1,
        "verbosity": 2,
        "monitor": "max val_F1_score",
        "early_stop": 20,
        "tensorboard": True
    }
}

# %% [markdown]
# ## LTSM

# %%
from pathlib import Path

config_lstm = {
    "name": "Physionet_LSTM",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "BiLSTM",
        "args": {
            "input_dim": 128,
            "hidden_dim": 256,
            "num_layers": 2,
            "dropout": 0.2,
            "pooling": "first",
            "model": "lstm",
            "BN": True,
            "num_classes": 2
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 120,
        "save_dir": str(PROJECT_PATH / "saved" / "LSTM"),
        "save_period": 1,
        "verbosity": 2,

        "monitor": "max val_F1_score",
        "early_stop": 20,

        "tensorboard": True
    }
}

# %% [markdown]
# ## VGG

# %%
from pathlib import Path

config_vgg = {
    "name": "Physionet_VGG11",
    "n_gpu": 1,

    # --------------------------------------------------------
    # Model architecture
    # --------------------------------------------------------
    "arch": {
        "type": "VGG_11",
        "args": {
            "num_classes": 2,
            "in_channel": 3
        }
    },

    # --------------------------------------------------------
    # Data loader configuration
    # --------------------------------------------------------
    "data_loader": {
        "type": "HeartSoundDataLoader",
        "full_label_csv": str(DATASET_PATH/ "label_balanced.csv"),
        "args": {
            # Extracted Log-Mel feature directory
            "fea_path": str(DATASET_PATH/"mfcc_features.h5"),
            "duration": 5,
            "batch_size": 32,
            "delta": True,
            "norm": True,
            "shuffle": False,
            "validation_split": 0.1,
            "num_workers": 2,
            "label_df": pd.read_csv(str(DATASET_PATH/ "label_balanced.csv"))
        }
    },

    # --------------------------------------------------------
    # Optimizer
    # --------------------------------------------------------
    "optimizer": {
        "type": "Adam",
        "args": {
            "lr": 2e-4,
            "weight_decay": 0.0,
            "amsgrad": True
        }
    },

    # --------------------------------------------------------
    # Loss and metrics
    # --------------------------------------------------------
    "loss": "ce_loss",
    "metrics": [
    ],

    # --------------------------------------------------------
    # Learning rate scheduler
    # --------------------------------------------------------
    "lr_scheduler": {
        "type": "StepLR",
        "args": {
            "step_size": 20,
            "gamma": 0.9
        }
    },

    # --------------------------------------------------------
    # Trainer configuration
    # --------------------------------------------------------
    "trainer": {
        "epochs": 200,
        "save_dir": str(PROJECT_PATH / "saved" / "VGG11"),
        "save_period": 1,
        "verbosity": 2,

        "monitor": "max val_F1_score",
        "early_stop": 20,

        "tensorboard": True
    }
}

# %% [markdown]
# # Training

# %%
def prepare_device(n_gpu_use):
    """
    setup GPU device if available. get gpu device indices which are used for DataParallel
    """
    n_gpu = torch.cuda.device_count()
    if n_gpu_use > 0 and n_gpu == 0:
        print("Warning: There\'s no GPU available on this machine,"
              "training will be performed on CPU.")
        n_gpu_use = 0
    if n_gpu_use > n_gpu:
        print(f"Warning: The number of GPU\'s configured to use is {n_gpu_use}, but only {n_gpu} are "
              "available on this machine.")
        n_gpu_use = n_gpu
    device = torch.device('cuda:0' if n_gpu_use > 0 else 'cpu')
    list_ids = list(range(n_gpu_use))
    return device, list_ids

# %%
class MetricTracker:
    def __init__(self, *keys, writer=None):
        self.writer = writer
        self._data = pd.DataFrame(index=keys, columns=['total', 'counts', 'average'])
        self.reset()

    def reset(self):
        for col in self._data.columns:
            self._data[col].values[:] = 0

    def update(self, key, value, n=1):
        if self.writer is not None:
            self.writer.add_scalar(key, value)
        df = self._data

        df.loc[key, "total"] += value * n
        df.loc[key, "counts"] += n
        df.loc[key, "average"] = df.loc[key, "total"] / df.loc[key, "counts"]


    def avg(self, key):
        return self._data.average[key]

    def result(self):
        return dict(self._data.average)

# %%
def setup_logging(save_dir, log_config='logger/logger_config.json', default_level=logging.INFO):
    """
    Setup logging configuration
    """
    log_config = Path(log_config)
    if log_config.is_file():
        config = read_json(log_config)
        # modify logging paths based on run config
        for _, handler in config['handlers'].items():
            if 'filename' in handler:
                handler['filename'] = str(save_dir / handler['filename'])

        logging.config.dictConfig(config)
    else:
        print("Warning: logging configuration file is not found in {}.".format(log_config))
        logging.basicConfig(level=default_level)
import importlib
from datetime import datetime


class TensorboardWriter():
    def __init__(self, log_dir, logger, enabled):
        self.writer = None
        self.selected_module = ""

        if enabled:
            log_dir = str(log_dir)

            # Retrieve vizualization writer.
            succeeded = False
            for module in ["torch.utils.tensorboard", "tensorboardX"]:
                try:
                    self.writer = importlib.import_module(module).SummaryWriter(log_dir)
                    succeeded = True
                    break
                except ImportError:
                    succeeded = False
                self.selected_module = module

            if not succeeded:
                message = "Warning: visualization (Tensorboard) is configured to use, but currently not installed on " \
                    "this machine. Please install TensorboardX with 'pip install tensorboardx', upgrade PyTorch to " \
                    "version >= 1.1 to use 'torch.utils.tensorboard' or turn off the option in the 'config.json' file."
                logger.warning(message)

        self.step = 0
        self.mode = ''

        self.tb_writer_ftns = {
            'add_scalar', 'add_scalars', 'add_image', 'add_images', 'add_audio',
            'add_text', 'add_histogram', 'add_pr_curve', 'add_embedding'
        }
        self.tag_mode_exceptions = {'add_histogram', 'add_embedding'}
        self.timer = datetime.now()

    def set_step(self, step, mode='train'):
        self.mode = mode
        self.step = step
        if step == 0:
            self.timer = datetime.now()
        else:
            duration = datetime.now() - self.timer
            self.add_scalar('steps_per_sec', 1 / duration.total_seconds())
            self.timer = datetime.now()

    def __getattr__(self, name):
        """
        If visualization is configured to use:
            return add_data() methods of tensorboard with additional information (step, tag) added.
        Otherwise:
            return a blank function handle that does nothing
        """
        if name in self.tb_writer_ftns:
            add_data = getattr(self.writer, name, None)

            def wrapper(tag, data, *args, **kwargs):
                if add_data is not None:
                    # add mode(train/valid) tag
                    if name not in self.tag_mode_exceptions:
                        tag = '{}/{}'.format(tag, self.mode)
                    add_data(tag, data, self.step, *args, **kwargs)
            return wrapper
        else:
            # default action for returning methods defined in this class, set_step() for instance.
            try:
                attr = object.__getattr__(name)
            except AttributeError:
                raise AttributeError("type object '{}' has no attribute '{}'".format(self.selected_module, name))
            return attr

# %%
import torch
from abc import abstractmethod
from numpy import inf

def safe_append(lst, value):
    lst.append(value if value is not None else np.nan)

class BaseTrainer:
    """
    Base class for all trainers
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config):
        self.config = config
        self.logger = config.get_logger('trainer', config['trainer']['verbosity'])

        self.model = model
        self.criterion = criterion
        self.metric_ftns = metric_ftns
        self.optimizer = optimizer

        cfg_trainer = config['trainer']
        self.epochs = cfg_trainer['epochs']
        self.save_period = cfg_trainer['save_period']
        self.monitor = cfg_trainer.get('monitor', 'off')

        # configuration to monitor model performance and save best
        if self.monitor == 'off':
            self.mnt_mode = 'off'
            self.mnt_best = 0
        else:
            self.mnt_mode, self.mnt_metric = self.monitor.split()
            assert self.mnt_mode in ['min', 'max']

            self.mnt_best = inf if self.mnt_mode == 'min' else -inf
            self.early_stop = cfg_trainer.get('early_stop', inf)
            if self.early_stop <= 0:
                self.early_stop = inf

        self.start_epoch = 1

        self.checkpoint_dir = config.save_dir

        self.history = {
            "epoch": [],
            "train_loss": [],
            "train_accuracy": [],
            "val_loss": [],
            "val_accuracy": [],
            "val_F1_score": [],
            "val_sensitivity": [],
            "val_specificity": [],
            "val_MAcc": []
        }


        self.history_path = Path(self.checkpoint_dir) / "metrics.csv"

        # setup visualization writer instance
        self.writer = TensorboardWriter(config.log_dir, self.logger, cfg_trainer['tensorboard'])

        if config.resume is not None:
            self._resume_checkpoint(config.resume)

    @abstractmethod
    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Current epoch number
        """
        raise NotImplementedError

    def train(self):
        """
        Full training logic
        """
        not_improved_count = 0
        for epoch in range(self.start_epoch, self.epochs + 1):
            result = self._train_epoch(epoch)

            # save logged informations into log dict
            log = {'epoch': epoch}
            log.update(result)

            # ===== GHI METRICS SAU MỖI EPOCH =====
            safe_append(self.history["epoch"], epoch)
            safe_append(self.history["train_loss"], log.get("loss"))
            safe_append(self.history["train_accuracy"], log.get("accuracy"))

            safe_append(self.history["val_loss"], log.get("val_loss"))
            safe_append(self.history["val_accuracy"], log.get("val_accuracy"))
            safe_append(self.history["val_F1_score"], log.get("val_F1_score"))
            safe_append(self.history["val_sensitivity"], log.get("val_sensitivity"))
            safe_append(self.history["val_specificity"], log.get("val_specificity"))
            safe_append(self.history["val_MAcc"], log.get("val_MAcc"))



            pd.DataFrame(self.history).to_csv(self.history_path, index=False)

            # print logged informations to the screen
            for key, value in log.items():
                self.logger.info('    {:15s}: {}'.format(str(key), value))

            # evaluate model performance according to configured metric, save best checkpoint as model_best
            best = False
            if self.mnt_mode != 'off':
                try:
                    # check whether model performance improved or not, according to specified metric(mnt_metric)
                    improved = (self.mnt_mode == 'min' and log[self.mnt_metric] <= self.mnt_best) or \
                               (self.mnt_mode == 'max' and log[self.mnt_metric] >= self.mnt_best)
                except KeyError:
                    self.logger.warning("Warning: Metric '{}' is not found. "
                                        "Model performance monitoring is disabled.".format(self.mnt_metric))
                    self.mnt_mode = 'off'
                    improved = False

                if improved:
                    self.mnt_best = log[self.mnt_metric]
                    not_improved_count = 0
                    best = True
                else:
                    not_improved_count += 1

                if not_improved_count > self.early_stop:
                    self.logger.info("Validation performance didn\'t improve for {} epochs. "
                                     "Training stops.".format(self.early_stop))
                    break

            if best:
                self._save_best_model(epoch)

    def _save_checkpoint(self, epoch, save_best=False):
        """
        Saving checkpoints

        :param epoch: current epoch number
        :param log: logging information of the epoch
        :param save_best: if True, rename the saved checkpoint to 'model_best.pth'
        """
        arch = type(self.model).__name__
        state = {
            'arch': arch,
            'epoch': epoch,
            'state_dict': self.model.state_dict(),
            'optimizer': self.optimizer.state_dict(),
            'monitor_best': self.mnt_best,
            'config': self.config
        }
        filename = str(self.checkpoint_dir / 'checkpoint-epoch{}.pth'.format(epoch))
        torch.save(state, filename)
        self.logger.info("Saving checkpoint: {} ...".format(filename))
        if save_best:
            best_path = str(self.checkpoint_dir / 'model_best.pth')
            torch.save(state, best_path)
            self.logger.info("Saving current best: model_best.pth ...")

    def _resume_checkpoint(self, resume_path):
        """
        Resume from saved checkpoints

        :param resume_path: Checkpoint path to be resumed
        """
        resume_path = str(resume_path)
        self.logger.info("Loading checkpoint: {} ...".format(resume_path))
        checkpoint = torch.load(resume_path)
        self.start_epoch = checkpoint['epoch'] + 1
        self.mnt_best = checkpoint['monitor_best']

        # load architecture params from checkpoint.
        if checkpoint['config']['arch'] != self.config['arch']:
            self.logger.warning("Warning: Architecture configuration given in config file is different from that of "
                                "checkpoint. This may yield an exception while state_dict is being loaded.")
        self.model.load_state_dict(checkpoint['state_dict'])

        # load optimizer state from checkpoint only when optimizer type is not changed.
        if checkpoint['config']['optimizer']['type'] != self.config['optimizer']['type']:
            self.logger.warning("Warning: Optimizer type given in config file is different from that of checkpoint. "
                                "Optimizer parameters not being resumed.")
        else:
            self.optimizer.load_state_dict(checkpoint['optimizer'])

        self.logger.info("Checkpoint loaded. Resume training from epoch {}".format(self.start_epoch))

    def _save_best_model(self, epoch):
      """
      Save only the best model according to monitoring metric
      """
      arch = type(self.model).__name__
      state = {
          'arch': arch,
          'epoch': epoch,
          'state_dict': self.model.state_dict(),
          'optimizer': self.optimizer.state_dict(),
          'monitor_best': self.mnt_best,
          'config': self.config
      }

      best_path = self.checkpoint_dir / 'model_best.pth'
      torch.save(state, best_path)

      self.logger.info(
          f"Saving new best model at epoch {epoch}: model_best.pth"
      )

# %%
from itertools import repeat

def inf_loop(data_loader):
    ''' wrapper function for endless data loader. '''
    for loader in repeat(data_loader):
        yield from loader

# %%
class Trainer(BaseTrainer):
    """
    Trainer class
    """
    def __init__(self, model, criterion, metric_ftns, optimizer, config, device,
                 data_loader, valid_data_loader=None, lr_scheduler=None, len_epoch=None):
        super().__init__(model, criterion, metric_ftns, optimizer, config)
        self.config = config
        self.device = device
        self.data_loader = data_loader
        if len_epoch is None:
            # epoch-based training
            self.len_epoch = len(self.data_loader)
        else:
            # iteration-based training
            self.data_loader = inf_loop(data_loader)
            self.len_epoch = len_epoch
        self.valid_data_loader = valid_data_loader
        self.do_validation = self.valid_data_loader is not None
        self.lr_scheduler = lr_scheduler
        self.log_step = int(np.sqrt(data_loader.batch_size))

        self.train_metrics = MetricTracker('loss', *[m.__name__ for m in self.metric_ftns], writer=self.writer)
        self.valid_metrics = MetricTracker('loss',*[m.__name__ for m in self.metric_ftns],
                                           'sensitivity', 'specificity', 'MAcc', 'F1_score',
                                           writer = self.writer)


    def _train_epoch(self, epoch):
        """
        Training logic for an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains average loss and metric in this epoch.
        """
        self.model.train()
        self.train_metrics.reset()
        for batch_idx, (data, target) in enumerate(self.data_loader):
            data, target = data.to(self.device), target.to(self.device)

            self.optimizer.zero_grad()
            output = self.model(data.float())
            loss = self.criterion(output, target)
            loss.backward()
            self.optimizer.step()

            self.writer.set_step((epoch - 1) * self.len_epoch + batch_idx)
            self.train_metrics.update('loss', loss.item())
            for met in self.metric_ftns:
                self.train_metrics.update(met.__name__, met(output, target))

            if batch_idx % self.log_step == 0:
                self.logger.debug('Train Epoch: {} {} Loss: {:.6f}'.format(
                    epoch,
                    self._progress(batch_idx),
                    loss.item()))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

            if batch_idx == self.len_epoch:
                break
        log = self.train_metrics.result()

        if self.do_validation:
            val_log = self._valid_epoch(epoch)
            log.update(**{'val_'+k : v for k, v in val_log.items()})

        #if self.lr_scheduler is not None:
            #self.lr_scheduler.step()

        if self.lr_scheduler is not None:
            if isinstance(self.lr_scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                # ReduceLROnPlateau cần metric để theo dõi (thường là val_loss)
                # Lấy giá trị 'loss' từ kết quả của hàm _valid_epoch
                self.lr_scheduler.step(val_log['loss'])
            else:
                # Các scheduler khác như StepLR không cần tham số
                self.lr_scheduler.step()
        return log

    def _valid_epoch(self, epoch):
        """
        Validate after training an epoch

        :param epoch: Integer, current training epoch.
        :return: A log that contains information about validation
        """
        self.model.eval()
        self.valid_metrics.reset()
        val_pred_pos = 0
        val_pred_neg = 0
        val_condition_pos = 0
        val_condition_neg = 0
        val_TP = 0
        val_TN = 0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for batch_idx, (data, target) in enumerate(self.valid_data_loader):
                data, target = data.to(self.device), target.to(self.device)
                output = self.model(data.float())
                loss = self.criterion(output, target)

                _,indices = torch.max(output, 1)

                pred_pos_idx = [i for i, x in enumerate(indices) if x == 0]
                condition_pos_idx = [i for i, x in enumerate(target) if x == 0]
                pred_neg_idx = [i for i, x in enumerate(indices) if x == 1]
                condition_neg_idx = [i for i, x in enumerate(target) if x == 1]

                val_pred_pos += len(pred_pos_idx)
                val_condition_pos += len(condition_pos_idx)
                val_pred_neg += len(pred_neg_idx)
                val_condition_neg += len(condition_neg_idx)
                val_TP += len([x for x in pred_pos_idx if x in condition_pos_idx])
                val_TN += len([x for x in pred_neg_idx if x in condition_neg_idx])
                correct = (indices == target).float()
                val_correct += torch.sum(correct).item()
                val_total += target.shape[0]

                self.writer.set_step((epoch - 1) * len(self.valid_data_loader) + batch_idx, 'valid')
                self.valid_metrics.update('loss', loss.item())
                for met in self.metric_ftns:
                    self.valid_metrics.update(met.__name__, met(output, target))
                #self.writer.add_image('input', make_grid(data.cpu(), nrow=8, normalize=True))

        sensitivity = val_TP / val_condition_pos
        specificity = val_TN / val_condition_neg
        MAcc= (sensitivity + specificity) / 2
        if val_pred_pos == 0:
            precision = 0
            F1_score = 0
        else:
            precision = val_TP / val_pred_pos
            F1_score = 2 * (precision*sensitivity)/(precision+sensitivity)

        self.valid_metrics.update('sensitivity', sensitivity)
        self.valid_metrics.update('specificity', specificity)
        self.valid_metrics.update('MAcc',MAcc)
        self.valid_metrics.update('F1_score', F1_score)

        # add histogram of model parameters to the tensorboard
        for name, p in self.model.named_parameters():
            self.writer.add_histogram(name, p, bins='auto')
        return self.valid_metrics.result()

    def _progress(self, batch_idx):
        base = '[{}/{} ({:.0f}%)]'
        if hasattr(self.data_loader, 'n_samples'):
            current = batch_idx * self.data_loader.batch_size
            total = self.data_loader.n_samples
        else:
            current = batch_idx
            total = self.len_epoch
        return base.format(current, total, 100.0 * current / total)

# %% [markdown]
# ## Simple Train

# %%
#current_config = config_cnn
current_config = config_light_cnn
#current_config = config_crnn
#current_config = config_lstm
#current_config = config_vgg

# %%
import os
import argparse
import collections
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# fix random seeds for reproducibility
SEED = 123
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(SEED)

def main(config):

# Tạo ConfigParser từ biến config hiện tại
  config_parser = ConfigParser(config)

  # Train chính thức
  data_loader = config_parser.init_obj('data_loader', globals())  # hoặc import module phù hợp
  valid_data_loader = data_loader.split_validation()

  model = config_parser.init_obj('arch', globals())
  print(model)

  device, device_ids = prepare_device(config_parser['n_gpu'])
  model = model.to(device)
  if len(device_ids) > 1:
      model = torch.nn.DataParallel(model, device_ids=device_ids)

  #criterion = FocalLoss(alpha=0.25, gamma=2.0)
  criterion = CBFocalLoss(
      samples_per_class=[150, 150],
      beta=0.9999,
      gamma=2.0
  )
  #criterion = LOSS_REGISTRY["weighted_ce_loss"]([1.0, 2.5])
  metrics = [
      accuracy,
      f1_score
  ]

  optimizer = config_parser.init_obj('optimizer', torch.optim, filter(lambda p: p.requires_grad, model.parameters()))
  lr_scheduler = config_parser.init_obj('lr_scheduler', torch.optim.lr_scheduler, optimizer)

  trainer = Trainer(
      model=model,
      criterion=criterion,
      metric_ftns=metrics,
      optimizer=optimizer,
      config=config_parser,
      device=device,
      data_loader=data_loader,
      valid_data_loader=valid_data_loader,
      lr_scheduler=lr_scheduler
  )

  trainer.train()

  base_dir = (Path(config_parser['trainer']['save_dir'])/ "models"/ config_parser['name'])

  if not base_dir.exists():
    print("Models directory was not found.")
    return

  # Lấy run (timestamp) mới nhất
  latest_run = max(base_dir.iterdir(), key=os.path.getmtime)

  best_model_path = latest_run / "model_best.pth"

  if best_model_path.exists():
    print("\n=== HOÀN THÀNH TRAINING ===")
    print("Model tốt nhất được lưu tại:")
    print(best_model_path)
  else:
    print("The file 'model_best.pth' was not found.")

  metrics_path = Path(config_parser.save_dir) / "metrics.csv"

  if metrics_path.exists():
    df = pd.read_csv(metrics_path)
    epochs = df["epoch"]
  else:
    print("The file 'metrics.csv' was not found. Unable to display training results.")

  # ===== LOSS =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_loss"], label="Training Loss")
  plt.plot(epochs, df["val_loss"], label="Validation Loss")
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training and Validation Loss")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "loss_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== ACCURACY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["train_accuracy"], label="Training Accuracy")
  plt.plot(epochs, df["val_accuracy"], label="Validation Accuracy")
  plt.xlabel("Epoch")
  plt.ylabel("Accuracy")
  plt.title("Training and Validation Accuracy")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "accuracy_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== F1-SCORE =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_F1_score"], label="Validation F1-score")
  plt.xlabel("Epoch")
  plt.ylabel("F1-score")
  plt.title("Validation F1-score across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "f1_curve.png", dpi=300)
  plt.show()
  plt.close()

  # ===== SENSITIVITY =====
  plt.figure(figsize=(6,4))
  plt.plot(epochs, df["val_sensitivity"], label="Validation Sensitivity")
  plt.xlabel("Epoch")
  plt.ylabel("Sensitivity")
  plt.title("Validation Sensitivity across epochs")
  plt.legend()
  plt.grid(True)
  plt.tight_layout()
  plt.savefig(latest_run / "sensitivity_curve.png", dpi=300)
  plt.show()
  plt.close()

# %%
if __name__ == "__main__":
    # Train model với config hiện tại
    main(current_config)

    # Sau khi train xong, tự động test trên tập validation riêng (nếu có file)
    base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
# Out:
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (features): Sequential(
#     (0): DepthwiseSeparableConv(
#       (depthwise): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#       (pointwise): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (1): DepthwiseSeparableConv(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (pointwise): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (2): DepthwiseSeparableConv(
#       (depthwise): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#   )
#   (pool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
# Warning: There's no GPU available on this machine,training will be performed on CPU.
# DEBUG:trainer:Train Epoch: 1 [0/269 (0%)] Loss: 0.168291
# DEBUG:trainer:Train Epoch: 1 [4/269 (1%)] Loss: 0.241445
# DEBUG:trainer:Train Epoch: 1 [8/269 (3%)] Loss: 0.139950
# DEBUG:trainer:Train Epoch: 1 [12/269 (4%)] Loss: 0.118613
# DEBUG:trainer:Train Epoch: 1 [16/269 (6%)] Loss: 0.141446
# DEBUG:trainer:Train Epoch: 1 [20/269 (7%)] Loss: 0.087241
# DEBUG:trainer:Train Epoch: 1 [24/269 (9%)] Loss: 0.112182
# DEBUG:trainer:Train Epoch: 1 [28/269 (10%)] Loss: 0.122121
# DEBUG:trainer:Train Epoch: 1 [32/269 (12%)] Loss: 0.149770
# DEBUG:trainer:Train Epoch: 1 [36/269 (13%)] Loss: 0.128486
# DEBUG:trainer:Train Epoch: 1 [40/269 (15%)] Loss: 0.137411
# DEBUG:trainer:Train Epoch: 1 [44/269 (16%)] Loss: 0.154510
# DEBUG:trainer:Train Epoch: 1 [48/269 (18%)] Loss: 0.120187
# DEBUG:trainer:Train Epoch: 1 [52/269 (19%)] Loss: 0.124840
# DEBUG:trainer:Train Epoch: 1 [56/269 (21%)] Loss: 0.134795
# DEBUG:trainer:Train Epoch: 1 [60/269 (22%)] Loss: 0.088956
# DEBUG:trainer:Train Epoch: 1 [64/269 (24%)] Loss: 0.084439
# DEBUG:trainer:Train Epoch: 1 [68/269 (25%)] Loss: 0.075041
# DEBUG:trainer:Train Epoch: 1 [72/269 (27%)] Loss: 0.245096
# DEBUG:trainer:Train Epoch: 1 [76/269 (28%)] Loss: 0.183949
# DEBUG:trainer:Train Epoch: 1 [80/269 (30%)] Loss: 0.100811
# DEBUG:trainer:Train Epoch: 1 [84/269 (31%)] Loss: 0.150632
# DEBUG:trainer:Train Epoch: 1 [88/269 (33%)] Loss: 0.117127
# DEBUG:trainer:Train Epoch: 1 [92/269 (34%)] Loss: 0.077144
# DEBUG:trainer:Train Epoch: 1 [96/269 (36%)] Loss: 0.148123
# DEBUG:trainer:Train Epoch: 1 [100/269 (37%)] Loss: 0.118272
# DEBUG:trainer:Train Epoch: 1 [104/269 (39%)] Loss: 0.077853
# DEBUG:trainer:Train Epoch: 1 [108/269 (40%)] Loss: 0.106765
# DEBUG:trainer:Train Epoch: 1 [112/269 (42%)] Loss: 0.108125
# DEBUG:trainer:Train Epoch: 1 [116/269 (43%)] Loss: 0.087946
# DEBUG:trainer:Train Epoch: 1 [120/269 (45%)] Loss: 0.094325
# DEBUG:trainer:Train Epoch: 1 [124/269 (46%)] Loss: 0.102379
# DEBUG:trainer:Train Epoch: 1 [128/269 (48%)] Loss: 0.084890
# DEBUG:trainer:Train Epoch: 1 [132/269 (49%)] Loss: 0.082019
# DEBUG:trainer:Train Epoch: 1 [136/269 (51%)] Loss: 0.091733
# DEBUG:trainer:Train Epoch: 1 [140/269 (52%)] Loss: 0.133075
# DEBUG:trainer:Train Epoch: 1 [144/269 (54%)] Loss: 0.081768
# DEBUG:trainer:Train Epoch: 1 [148/269 (55%)] Loss: 0.119516
# DEBUG:trainer:Train Epoch: 1 [152/269 (57%)] Loss: 0.192505
# DEBUG:trainer:Train Epoch: 1 [156/269 (58%)] Loss: 0.096730
# DEBUG:trainer:Train Epoch: 1 [160/269 (59%)] Loss: 0.189753
# DEBUG:trainer:Train Epoch: 1 [164/269 (61%)] Loss: 0.156949
# DEBUG:trainer:Train Epoch: 1 [168/269 (62%)] Loss: 0.103882
# DEBUG:trainer:Train Epoch: 1 [172/269 (64%)] Loss: 0.126656
# DEBUG:trainer:Train Epoch: 1 [176/269 (65%)] Loss: 0.054419
# DEBUG:trainer:Train Epoch: 1 [180/269 (67%)] Loss: 0.080970
# DEBUG:trainer:Train Epoch: 1 [184/269 (68%)] Loss: 0.093283
# DEBUG:trainer:Train Epoch: 1 [188/269 (70%)] Loss: 0.158953
# DEBUG:trainer:Train Epoch: 1 [192/269 (71%)] Loss: 0.125961
# DEBUG:trainer:Train Epoch: 1 [196/269 (73%)] Loss: 0.141076
# DEBUG:trainer:Train Epoch: 1 [200/269 (74%)] Loss: 0.189401
# DEBUG:trainer:Train Epoch: 1 [204/269 (76%)] Loss: 0.092678
# DEBUG:trainer:Train Epoch: 1 [208/269 (77%)] Loss: 0.109585
# DEBUG:trainer:Train Epoch: 1 [212/269 (79%)] Loss: 0.092074
# DEBUG:trainer:Train Epoch: 1 [216/269 (80%)] Loss: 0.091764
# DEBUG:trainer:Train Epoch: 1 [220/269 (82%)] Loss: 0.086790
# DEBUG:trainer:Train Epoch: 1 [224/269 (83%)] Loss: 0.109412
# DEBUG:trainer:Train Epoch: 1 [228/269 (85%)] Loss: 0.088329
# DEBUG:trainer:Train Epoch: 1 [232/269 (86%)] Loss: 0.092063
# DEBUG:trainer:Train Epoch: 1 [236/269 (88%)] Loss: 0.046439
# DEBUG:trainer:Train Epoch: 1 [240/269 (89%)] Loss: 0.129939
# DEBUG:trainer:Train Epoch: 1 [244/269 (91%)] Loss: 0.124470
# DEBUG:trainer:Train Epoch: 1 [248/269 (92%)] Loss: 0.084906
# DEBUG:trainer:Train Epoch: 1 [252/269 (94%)] Loss: 0.123337
# DEBUG:trainer:Train Epoch: 1 [256/269 (95%)] Loss: 0.117458
# DEBUG:trainer:Train Epoch: 1 [260/269 (97%)] Loss: 0.105894
# DEBUG:trainer:Train Epoch: 1 [264/269 (98%)] Loss: 0.093588
# DEBUG:trainer:Train Epoch: 1 [268/269 (100%)] Loss: 0.099994
# INFO:trainer:    epoch          : 1
# INFO:trainer:    loss           : 0.11858365733218015
# INFO:trainer:    accuracy       : 0.7946096654275093
# INFO:trainer:    f1_score       : 0.803740059825037
# INFO:trainer:    val_loss       : 0.1043523232819456
# INFO:trainer:    val_accuracy   : 0.8211580086580086
# INFO:trainer:    val_f1_score   : 0.8141550732989526
# INFO:trainer:    val_sensitivity: 0.7800751879699248
# INFO:trainer:    val_specificity: 0.8679611650485437
# INFO:trainer:    val_MAcc       : 0.8240181765092343
# INFO:trainer:    val_F1_score   : 0.8177339901477833
# INFO:trainer:Saving new best model at epoch 1: model_best.pth
# DEBUG:trainer:Train Epoch: 2 [0/269 (0%)] Loss: 0.093965
# DEBUG:trainer:Train Epoch: 2 [4/269 (1%)] Loss: 0.097583
# DEBUG:trainer:Train Epoch: 2 [8/269 (3%)] Loss: 0.095715
# DEBUG:trainer:Train Epoch: 2 [12/269 (4%)] Loss: 0.093550
# DEBUG:trainer:Train Epoch: 2 [16/269 (6%)] Loss: 0.133438
# DEBUG:trainer:Train Epoch: 2 [20/269 (7%)] Loss: 0.155045
# DEBUG:trainer:Train Epoch: 2 [24/269 (9%)] Loss: 0.123268
# DEBUG:trainer:Train Epoch: 2 [28/269 (10%)] Loss: 0.100254
# DEBUG:trainer:Train Epoch: 2 [32/269 (12%)] Loss: 0.047612
# DEBUG:trainer:Train Epoch: 2 [36/269 (13%)] Loss: 0.078029
# DEBUG:trainer:Train Epoch: 2 [40/269 (15%)] Loss: 0.088962
# DEBUG:trainer:Train Epoch: 2 [44/269 (16%)] Loss: 0.086614
# DEBUG:trainer:Train Epoch: 2 [48/269 (18%)] Loss: 0.147537
# DEBUG:trainer:Train Epoch: 2 [52/269 (19%)] Loss: 0.161159
# DEBUG:trainer:Train Epoch: 2 [56/269 (21%)] Loss: 0.066437
# DEBUG:trainer:Train Epoch: 2 [60/269 (22%)] Loss: 0.103506
# DEBUG:trainer:Train Epoch: 2 [64/269 (24%)] Loss: 0.187415
# DEBUG:trainer:Train Epoch: 2 [68/269 (25%)] Loss: 0.066847
# DEBUG:trainer:Train Epoch: 2 [72/269 (27%)] Loss: 0.128749
# DEBUG:trainer:Train Epoch: 2 [76/269 (28%)] Loss: 0.174127
# DEBUG:trainer:Train Epoch: 2 [80/269 (30%)] Loss: 0.087200
# DEBUG:trainer:Train Epoch: 2 [84/269 (31%)] Loss: 0.055929
# DEBUG:trainer:Train Epoch: 2 [88/269 (33%)] Loss: 0.090611
# DEBUG:trainer:Train Epoch: 2 [92/269 (34%)] Loss: 0.033221
# DEBUG:trainer:Train Epoch: 2 [96/269 (36%)] Loss: 0.161621
# DEBUG:trainer:Train Epoch: 2 [100/269 (37%)] Loss: 0.038870
# DEBUG:trainer:Train Epoch: 2 [104/269 (39%)] Loss: 0.087608
# DEBUG:trainer:Train Epoch: 2 [108/269 (40%)] Loss: 0.142766
# DEBUG:trainer:Train Epoch: 2 [112/269 (42%)] Loss: 0.126877
# DEBUG:trainer:Train Epoch: 2 [116/269 (43%)] Loss: 0.129023
# DEBUG:trainer:Train Epoch: 2 [120/269 (45%)] Loss: 0.180964
# DEBUG:trainer:Train Epoch: 2 [124/269 (46%)] Loss: 0.070916
# DEBUG:trainer:Train Epoch: 2 [128/269 (48%)] Loss: 0.132910
# DEBUG:trainer:Train Epoch: 2 [132/269 (49%)] Loss: 0.105339
# DEBUG:trainer:Train Epoch: 2 [136/269 (51%)] Loss: 0.115902
# DEBUG:trainer:Train Epoch: 2 [140/269 (52%)] Loss: 0.069623
# DEBUG:trainer:Train Epoch: 2 [144/269 (54%)] Loss: 0.091648
# DEBUG:trainer:Train Epoch: 2 [148/269 (55%)] Loss: 0.097133
# DEBUG:trainer:Train Epoch: 2 [152/269 (57%)] Loss: 0.089145
# DEBUG:trainer:Train Epoch: 2 [156/269 (58%)] Loss: 0.092570
# DEBUG:trainer:Train Epoch: 2 [160/269 (59%)] Loss: 0.109717
# DEBUG:trainer:Train Epoch: 2 [164/269 (61%)] Loss: 0.100867
# DEBUG:trainer:Train Epoch: 2 [168/269 (62%)] Loss: 0.085058
# DEBUG:trainer:Train Epoch: 2 [172/269 (64%)] Loss: 0.147334
# DEBUG:trainer:Train Epoch: 2 [176/269 (65%)] Loss: 0.109329
# DEBUG:trainer:Train Epoch: 2 [180/269 (67%)] Loss: 0.198955
# DEBUG:trainer:Train Epoch: 2 [184/269 (68%)] Loss: 0.052995
# DEBUG:trainer:Train Epoch: 2 [188/269 (70%)] Loss: 0.128096
# DEBUG:trainer:Train Epoch: 2 [192/269 (71%)] Loss: 0.091055
# DEBUG:trainer:Train Epoch: 2 [196/269 (73%)] Loss: 0.229038
# DEBUG:trainer:Train Epoch: 2 [200/269 (74%)] Loss: 0.084555
# DEBUG:trainer:Train Epoch: 2 [204/269 (76%)] Loss: 0.131891
# DEBUG:trainer:Train Epoch: 2 [208/269 (77%)] Loss: 0.093323
# DEBUG:trainer:Train Epoch: 2 [212/269 (79%)] Loss: 0.079155
# DEBUG:trainer:Train Epoch: 2 [216/269 (80%)] Loss: 0.078968
# DEBUG:trainer:Train Epoch: 2 [220/269 (82%)] Loss: 0.062301
# DEBUG:trainer:Train Epoch: 2 [224/269 (83%)] Loss: 0.090718
# DEBUG:trainer:Train Epoch: 2 [228/269 (85%)] Loss: 0.067809
# DEBUG:trainer:Train Epoch: 2 [232/269 (86%)] Loss: 0.124295
# DEBUG:trainer:Train Epoch: 2 [236/269 (88%)] Loss: 0.078357
# DEBUG:trainer:Train Epoch: 2 [240/269 (89%)] Loss: 0.087010
# DEBUG:trainer:Train Epoch: 2 [244/269 (91%)] Loss: 0.085644
# DEBUG:trainer:Train Epoch: 2 [248/269 (92%)] Loss: 0.051526
# DEBUG:trainer:Train Epoch: 2 [252/269 (94%)] Loss: 0.101663
# DEBUG:trainer:Train Epoch: 2 [256/269 (95%)] Loss: 0.127165
# DEBUG:trainer:Train Epoch: 2 [260/269 (97%)] Loss: 0.057492
# DEBUG:trainer:Train Epoch: 2 [264/269 (98%)] Loss: 0.079362
# DEBUG:trainer:Train Epoch: 2 [268/269 (100%)] Loss: 0.025087
# INFO:trainer:    epoch          : 2
# INFO:trainer:    loss           : 0.09787125328077924
# INFO:trainer:    accuracy       : 0.8308550185873605
# INFO:trainer:    f1_score       : 0.8383568795238792
# INFO:trainer:    val_loss       : 0.08578293826995474
# INFO:trainer:    val_accuracy   : 0.8517316017316018
# INFO:trainer:    val_f1_score   : 0.8546439849088788
# INFO:trainer:    val_sensitivity: 0.7763157894736842
# INFO:trainer:    val_specificity: 0.9320388349514563
# INFO:trainer:    val_MAcc       : 0.8541773122125702
# INFO:trainer:    val_F1_score   : 0.842857142857143
# DEBUG:trainer:Train Epoch: 3 [0/269 (0%)] Loss: 0.045708
# DEBUG:trainer:Train Epoch: 3 [4/269 (1%)] Loss: 0.047023
# DEBUG:trainer:Train Epoch: 3 [8/269 (3%)] Loss: 0.097442
# DEBUG:trainer:Train Epoch: 3 [12/269 (4%)] Loss: 0.071632
# DEBUG:trainer:Train Epoch: 3 [16/269 (6%)] Loss: 0.126368
# DEBUG:trainer:Train Epoch: 3 [20/269 (7%)] Loss: 0.076870
# DEBUG:trainer:Train Epoch: 3 [24/269 (9%)] Loss: 0.108638
# DEBUG:trainer:Train Epoch: 3 [28/269 (10%)] Loss: 0.038593
# DEBUG:trainer:Train Epoch: 3 [32/269 (12%)] Loss: 0.064764
# DEBUG:trainer:Train Epoch: 3 [36/269 (13%)] Loss: 0.093007
# DEBUG:trainer:Train Epoch: 3 [40/269 (15%)] Loss: 0.154208
# DEBUG:trainer:Train Epoch: 3 [44/269 (16%)] Loss: 0.196767
# DEBUG:trainer:Train Epoch: 3 [48/269 (18%)] Loss: 0.048243
# DEBUG:trainer:Train Epoch: 3 [52/269 (19%)] Loss: 0.112396
# DEBUG:trainer:Train Epoch: 3 [56/269 (21%)] Loss: 0.120200
# DEBUG:trainer:Train Epoch: 3 [60/269 (22%)] Loss: 0.095317
# DEBUG:trainer:Train Epoch: 3 [64/269 (24%)] Loss: 0.051851
# DEBUG:trainer:Train Epoch: 3 [68/269 (25%)] Loss: 0.157355
# DEBUG:trainer:Train Epoch: 3 [72/269 (27%)] Loss: 0.080939
# DEBUG:trainer:Train Epoch: 3 [76/269 (28%)] Loss: 0.095977
# DEBUG:trainer:Train Epoch: 3 [80/269 (30%)] Loss: 0.117746
# DEBUG:trainer:Train Epoch: 3 [84/269 (31%)] Loss: 0.024522
# DEBUG:trainer:Train Epoch: 3 [88/269 (33%)] Loss: 0.059196
# DEBUG:trainer:Train Epoch: 3 [92/269 (34%)] Loss: 0.153333
# DEBUG:trainer:Train Epoch: 3 [96/269 (36%)] Loss: 0.055951
# DEBUG:trainer:Train Epoch: 3 [100/269 (37%)] Loss: 0.143891
# DEBUG:trainer:Train Epoch: 3 [104/269 (39%)] Loss: 0.055846
# DEBUG:trainer:Train Epoch: 3 [108/269 (40%)] Loss: 0.127016
# DEBUG:trainer:Train Epoch: 3 [112/269 (42%)] Loss: 0.066712
# DEBUG:trainer:Train Epoch: 3 [116/269 (43%)] Loss: 0.125216
# DEBUG:trainer:Train Epoch: 3 [120/269 (45%)] Loss: 0.125335
# DEBUG:trainer:Train Epoch: 3 [124/269 (46%)] Loss: 0.084008
# DEBUG:trainer:Train Epoch: 3 [128/269 (48%)] Loss: 0.147139
# DEBUG:trainer:Train Epoch: 3 [132/269 (49%)] Loss: 0.076724
# DEBUG:trainer:Train Epoch: 3 [136/269 (51%)] Loss: 0.073090
# DEBUG:trainer:Train Epoch: 3 [140/269 (52%)] Loss: 0.073273
# DEBUG:trainer:Train Epoch: 3 [144/269 (54%)] Loss: 0.129738
# DEBUG:trainer:Train Epoch: 3 [148/269 (55%)] Loss: 0.090544
# DEBUG:trainer:Train Epoch: 3 [152/269 (57%)] Loss: 0.104442
# DEBUG:trainer:Train Epoch: 3 [156/269 (58%)] Loss: 0.074214
# DEBUG:trainer:Train Epoch: 3 [160/269 (59%)] Loss: 0.070972
# DEBUG:trainer:Train Epoch: 3 [164/269 (61%)] Loss: 0.143500
# DEBUG:trainer:Train Epoch: 3 [168/269 (62%)] Loss: 0.143982
# DEBUG:trainer:Train Epoch: 3 [172/269 (64%)] Loss: 0.078268
# DEBUG:trainer:Train Epoch: 3 [176/269 (65%)] Loss: 0.105599
# DEBUG:trainer:Train Epoch: 3 [180/269 (67%)] Loss: 0.115705
# DEBUG:trainer:Train Epoch: 3 [184/269 (68%)] Loss: 0.048900
# DEBUG:trainer:Train Epoch: 3 [188/269 (70%)] Loss: 0.063818
# DEBUG:trainer:Train Epoch: 3 [192/269 (71%)] Loss: 0.046653
# DEBUG:trainer:Train Epoch: 3 [196/269 (73%)] Loss: 0.131337
# DEBUG:trainer:Train Epoch: 3 [200/269 (74%)] Loss: 0.125425
# DEBUG:trainer:Train Epoch: 3 [204/269 (76%)] Loss: 0.122007
# DEBUG:trainer:Train Epoch: 3 [208/269 (77%)] Loss: 0.035873
# DEBUG:trainer:Train Epoch: 3 [212/269 (79%)] Loss: 0.096224
# DEBUG:trainer:Train Epoch: 3 [216/269 (80%)] Loss: 0.115308
# DEBUG:trainer:Train Epoch: 3 [220/269 (82%)] Loss: 0.172383
# DEBUG:trainer:Train Epoch: 3 [224/269 (83%)] Loss: 0.062506
# DEBUG:trainer:Train Epoch: 3 [228/269 (85%)] Loss: 0.096118
# DEBUG:trainer:Train Epoch: 3 [232/269 (86%)] Loss: 0.079946
# DEBUG:trainer:Train Epoch: 3 [236/269 (88%)] Loss: 0.096372
# DEBUG:trainer:Train Epoch: 3 [240/269 (89%)] Loss: 0.038950
# DEBUG:trainer:Train Epoch: 3 [244/269 (91%)] Loss: 0.073308
# DEBUG:trainer:Train Epoch: 3 [248/269 (92%)] Loss: 0.076251
# DEBUG:trainer:Train Epoch: 3 [252/269 (94%)] Loss: 0.080423
# DEBUG:trainer:Train Epoch: 3 [256/269 (95%)] Loss: 0.079553
# DEBUG:trainer:Train Epoch: 3 [260/269 (97%)] Loss: 0.040584
# DEBUG:trainer:Train Epoch: 3 [264/269 (98%)] Loss: 0.101223
# DEBUG:trainer:Train Epoch: 3 [268/269 (100%)] Loss: 0.040793
# INFO:trainer:    epoch          : 3
# INFO:trainer:    loss           : 0.09024852923494954
# INFO:trainer:    accuracy       : 0.8485130111524164
# INFO:trainer:    f1_score       : 0.8550985474524179
# INFO:trainer:    val_loss       : 0.17989110122575905
# INFO:trainer:    val_accuracy   : 0.626758658008658
# INFO:trainer:    val_f1_score   : 0.43838734337446544
# INFO:trainer:    val_sensitivity: 0.9210526315789473
# INFO:trainer:    val_specificity: 0.3262135922330097
# INFO:trainer:    val_MAcc       : 0.6236331119059786
# INFO:trainer:    val_F1_score   : 0.7158509861212564
# INFO:trainer:Saving new best model at epoch 3: model_best.pth
# DEBUG:trainer:Train Epoch: 4 [0/269 (0%)] Loss: 0.090776
# DEBUG:trainer:Train Epoch: 4 [4/269 (1%)] Loss: 0.093883
# DEBUG:trainer:Train Epoch: 4 [8/269 (3%)] Loss: 0.114132
# DEBUG:trainer:Train Epoch: 4 [12/269 (4%)] Loss: 0.125947
# DEBUG:trainer:Train Epoch: 4 [16/269 (6%)] Loss: 0.061359
# DEBUG:trainer:Train Epoch: 4 [20/269 (7%)] Loss: 0.111223
# DEBUG:trainer:Train Epoch: 4 [24/269 (9%)] Loss: 0.053503
# DEBUG:trainer:Train Epoch: 4 [28/269 (10%)] Loss: 0.083011
# DEBUG:trainer:Train Epoch: 4 [32/269 (12%)] Loss: 0.066911
# DEBUG:trainer:Train Epoch: 4 [36/269 (13%)] Loss: 0.046985
# DEBUG:trainer:Train Epoch: 4 [40/269 (15%)] Loss: 0.057379
# DEBUG:trainer:Train Epoch: 4 [44/269 (16%)] Loss: 0.047030
# DEBUG:trainer:Train Epoch: 4 [48/269 (18%)] Loss: 0.025368
# DEBUG:trainer:Train Epoch: 4 [52/269 (19%)] Loss: 0.094970
# DEBUG:trainer:Train Epoch: 4 [56/269 (21%)] Loss: 0.099407
# DEBUG:trainer:Train Epoch: 4 [60/269 (22%)] Loss: 0.155806
# DEBUG:trainer:Train Epoch: 4 [64/269 (24%)] Loss: 0.067252
# DEBUG:trainer:Train Epoch: 4 [68/269 (25%)] Loss: 0.115950
# DEBUG:trainer:Train Epoch: 4 [72/269 (27%)] Loss: 0.032503
# DEBUG:trainer:Train Epoch: 4 [76/269 (28%)] Loss: 0.122992
# DEBUG:trainer:Train Epoch: 4 [80/269 (30%)] Loss: 0.033146
# DEBUG:trainer:Train Epoch: 4 [84/269 (31%)] Loss: 0.121168
# DEBUG:trainer:Train Epoch: 4 [88/269 (33%)] Loss: 0.118578
# DEBUG:trainer:Train Epoch: 4 [92/269 (34%)] Loss: 0.070210
# DEBUG:trainer:Train Epoch: 4 [96/269 (36%)] Loss: 0.079254
# DEBUG:trainer:Train Epoch: 4 [100/269 (37%)] Loss: 0.090436
# DEBUG:trainer:Train Epoch: 4 [104/269 (39%)] Loss: 0.050487
# DEBUG:trainer:Train Epoch: 4 [108/269 (40%)] Loss: 0.092103
# DEBUG:trainer:Train Epoch: 4 [112/269 (42%)] Loss: 0.079741
# DEBUG:trainer:Train Epoch: 4 [116/269 (43%)] Loss: 0.061745
# DEBUG:trainer:Train Epoch: 4 [120/269 (45%)] Loss: 0.082400
# DEBUG:trainer:Train Epoch: 4 [124/269 (46%)] Loss: 0.051294
# DEBUG:trainer:Train Epoch: 4 [128/269 (48%)] Loss: 0.070789
# DEBUG:trainer:Train Epoch: 4 [132/269 (49%)] Loss: 0.085888
# DEBUG:trainer:Train Epoch: 4 [136/269 (51%)] Loss: 0.099456
# DEBUG:trainer:Train Epoch: 4 [140/269 (52%)] Loss: 0.059969
# DEBUG:trainer:Train Epoch: 4 [144/269 (54%)] Loss: 0.077939
# DEBUG:trainer:Train Epoch: 4 [148/269 (55%)] Loss: 0.072492
# DEBUG:trainer:Train Epoch: 4 [152/269 (57%)] Loss: 0.066136
# DEBUG:trainer:Train Epoch: 4 [156/269 (58%)] Loss: 0.064100
# DEBUG:trainer:Train Epoch: 4 [160/269 (59%)] Loss: 0.066941
# DEBUG:trainer:Train Epoch: 4 [164/269 (61%)] Loss: 0.027658
# DEBUG:trainer:Train Epoch: 4 [168/269 (62%)] Loss: 0.068870
# DEBUG:trainer:Train Epoch: 4 [172/269 (64%)] Loss: 0.088568
# DEBUG:trainer:Train Epoch: 4 [176/269 (65%)] Loss: 0.137898
# DEBUG:trainer:Train Epoch: 4 [180/269 (67%)] Loss: 0.068726
# DEBUG:trainer:Train Epoch: 4 [184/269 (68%)] Loss: 0.065596
# DEBUG:trainer:Train Epoch: 4 [188/269 (70%)] Loss: 0.097483
# DEBUG:trainer:Train Epoch: 4 [192/269 (71%)] Loss: 0.061906
# DEBUG:trainer:Train Epoch: 4 [196/269 (73%)] Loss: 0.088693
# DEBUG:trainer:Train Epoch: 4 [200/269 (74%)] Loss: 0.104795
# DEBUG:trainer:Train Epoch: 4 [204/269 (76%)] Loss: 0.078522
# DEBUG:trainer:Train Epoch: 4 [208/269 (77%)] Loss: 0.063001
# DEBUG:trainer:Train Epoch: 4 [212/269 (79%)] Loss: 0.101657
# DEBUG:trainer:Train Epoch: 4 [216/269 (80%)] Loss: 0.042396
# DEBUG:trainer:Train Epoch: 4 [220/269 (82%)] Loss: 0.020877
# DEBUG:trainer:Train Epoch: 4 [224/269 (83%)] Loss: 0.047886
# DEBUG:trainer:Train Epoch: 4 [228/269 (85%)] Loss: 0.074098
# DEBUG:trainer:Train Epoch: 4 [232/269 (86%)] Loss: 0.030072
# DEBUG:trainer:Train Epoch: 4 [236/269 (88%)] Loss: 0.040113
# DEBUG:trainer:Train Epoch: 4 [240/269 (89%)] Loss: 0.092209
# DEBUG:trainer:Train Epoch: 4 [244/269 (91%)] Loss: 0.104725
# DEBUG:trainer:Train Epoch: 4 [248/269 (92%)] Loss: 0.063544
# DEBUG:trainer:Train Epoch: 4 [252/269 (94%)] Loss: 0.144974
# DEBUG:trainer:Train Epoch: 4 [256/269 (95%)] Loss: 0.091858
# DEBUG:trainer:Train Epoch: 4 [260/269 (97%)] Loss: 0.073595
# DEBUG:trainer:Train Epoch: 4 [264/269 (98%)] Loss: 0.101444
# DEBUG:trainer:Train Epoch: 4 [268/269 (100%)] Loss: 0.019019
# INFO:trainer:    epoch          : 4
# INFO:trainer:    loss           : 0.08361800368113588
# INFO:trainer:    accuracy       : 0.8552509293680297
# INFO:trainer:    f1_score       : 0.8613568103742373
# INFO:trainer:    val_loss       : 0.08233833064635594
# INFO:trainer:    val_accuracy   : 0.8541666666666666
# INFO:trainer:    val_f1_score   : 0.8585884207787756
# INFO:trainer:    val_sensitivity: 0.7593984962406015
# INFO:trainer:    val_specificity: 0.9495145631067962
# INFO:trainer:    val_MAcc       : 0.8544565296736988
# INFO:trainer:    val_F1_score   : 0.8399168399168399
# DEBUG:trainer:Train Epoch: 5 [0/269 (0%)] Loss: 0.054558
# DEBUG:trainer:Train Epoch: 5 [4/269 (1%)] Loss: 0.139327
# DEBUG:trainer:Train Epoch: 5 [8/269 (3%)] Loss: 0.066170
# DEBUG:trainer:Train Epoch: 5 [12/269 (4%)] Loss: 0.109476
# DEBUG:trainer:Train Epoch: 5 [16/269 (6%)] Loss: 0.074874
# DEBUG:trainer:Train Epoch: 5 [20/269 (7%)] Loss: 0.110816
# DEBUG:trainer:Train Epoch: 5 [24/269 (9%)] Loss: 0.078894
# DEBUG:trainer:Train Epoch: 5 [28/269 (10%)] Loss: 0.102068
# DEBUG:trainer:Train Epoch: 5 [32/269 (12%)] Loss: 0.049286
# DEBUG:trainer:Train Epoch: 5 [36/269 (13%)] Loss: 0.044530
# DEBUG:trainer:Train Epoch: 5 [40/269 (15%)] Loss: 0.032261
# DEBUG:trainer:Train Epoch: 5 [44/269 (16%)] Loss: 0.054267
# DEBUG:trainer:Train Epoch: 5 [48/269 (18%)] Loss: 0.033793
# DEBUG:trainer:Train Epoch: 5 [52/269 (19%)] Loss: 0.032903
# DEBUG:trainer:Train Epoch: 5 [56/269 (21%)] Loss: 0.122205
# DEBUG:trainer:Train Epoch: 5 [60/269 (22%)] Loss: 0.039607
# DEBUG:trainer:Train Epoch: 5 [64/269 (24%)] Loss: 0.049599
# DEBUG:trainer:Train Epoch: 5 [68/269 (25%)] Loss: 0.062598
# DEBUG:trainer:Train Epoch: 5 [72/269 (27%)] Loss: 0.044836
# DEBUG:trainer:Train Epoch: 5 [76/269 (28%)] Loss: 0.039263
# DEBUG:trainer:Train Epoch: 5 [80/269 (30%)] Loss: 0.049602
# DEBUG:trainer:Train Epoch: 5 [84/269 (31%)] Loss: 0.079943
# DEBUG:trainer:Train Epoch: 5 [88/269 (33%)] Loss: 0.108434
# DEBUG:trainer:Train Epoch: 5 [92/269 (34%)] Loss: 0.103378
# DEBUG:trainer:Train Epoch: 5 [96/269 (36%)] Loss: 0.060859
# DEBUG:trainer:Train Epoch: 5 [100/269 (37%)] Loss: 0.173589
# DEBUG:trainer:Train Epoch: 5 [104/269 (39%)] Loss: 0.095631
# DEBUG:trainer:Train Epoch: 5 [108/269 (40%)] Loss: 0.070994
# DEBUG:trainer:Train Epoch: 5 [112/269 (42%)] Loss: 0.043486
# DEBUG:trainer:Train Epoch: 5 [116/269 (43%)] Loss: 0.180171
# DEBUG:trainer:Train Epoch: 5 [120/269 (45%)] Loss: 0.081872
# DEBUG:trainer:Train Epoch: 5 [124/269 (46%)] Loss: 0.084742
# DEBUG:trainer:Train Epoch: 5 [128/269 (48%)] Loss: 0.074293
# DEBUG:trainer:Train Epoch: 5 [132/269 (49%)] Loss: 0.072927
# DEBUG:trainer:Train Epoch: 5 [136/269 (51%)] Loss: 0.088491
# DEBUG:trainer:Train Epoch: 5 [140/269 (52%)] Loss: 0.071003
# DEBUG:trainer:Train Epoch: 5 [144/269 (54%)] Loss: 0.144681
# DEBUG:trainer:Train Epoch: 5 [148/269 (55%)] Loss: 0.044983
# DEBUG:trainer:Train Epoch: 5 [152/269 (57%)] Loss: 0.053689
# DEBUG:trainer:Train Epoch: 5 [156/269 (58%)] Loss: 0.101979
# DEBUG:trainer:Train Epoch: 5 [160/269 (59%)] Loss: 0.055586
# DEBUG:trainer:Train Epoch: 5 [164/269 (61%)] Loss: 0.075467
# DEBUG:trainer:Train Epoch: 5 [168/269 (62%)] Loss: 0.092510
# DEBUG:trainer:Train Epoch: 5 [172/269 (64%)] Loss: 0.069709
# DEBUG:trainer:Train Epoch: 5 [176/269 (65%)] Loss: 0.084858
# DEBUG:trainer:Train Epoch: 5 [180/269 (67%)] Loss: 0.038002
# DEBUG:trainer:Train Epoch: 5 [184/269 (68%)] Loss: 0.039908
# DEBUG:trainer:Train Epoch: 5 [188/269 (70%)] Loss: 0.057833
# DEBUG:trainer:Train Epoch: 5 [192/269 (71%)] Loss: 0.060552
# DEBUG:trainer:Train Epoch: 5 [196/269 (73%)] Loss: 0.068138
# DEBUG:trainer:Train Epoch: 5 [200/269 (74%)] Loss: 0.092043
# DEBUG:trainer:Train Epoch: 5 [204/269 (76%)] Loss: 0.078401
# DEBUG:trainer:Train Epoch: 5 [208/269 (77%)] Loss: 0.029170
# DEBUG:trainer:Train Epoch: 5 [212/269 (79%)] Loss: 0.146483
# DEBUG:trainer:Train Epoch: 5 [216/269 (80%)] Loss: 0.109259
# DEBUG:trainer:Train Epoch: 5 [220/269 (82%)] Loss: 0.054292
# DEBUG:trainer:Train Epoch: 5 [224/269 (83%)] Loss: 0.128555
# DEBUG:trainer:Train Epoch: 5 [228/269 (85%)] Loss: 0.076252
# DEBUG:trainer:Train Epoch: 5 [232/269 (86%)] Loss: 0.105117
# DEBUG:trainer:Train Epoch: 5 [236/269 (88%)] Loss: 0.098843
# DEBUG:trainer:Train Epoch: 5 [240/269 (89%)] Loss: 0.036743
# DEBUG:trainer:Train Epoch: 5 [244/269 (91%)] Loss: 0.072427
# DEBUG:trainer:Train Epoch: 5 [248/269 (92%)] Loss: 0.086319
# DEBUG:trainer:Train Epoch: 5 [252/269 (94%)] Loss: 0.090351
# DEBUG:trainer:Train Epoch: 5 [256/269 (95%)] Loss: 0.135105
# DEBUG:trainer:Train Epoch: 5 [260/269 (97%)] Loss: 0.071908
# DEBUG:trainer:Train Epoch: 5 [264/269 (98%)] Loss: 0.056049
# DEBUG:trainer:Train Epoch: 5 [268/269 (100%)] Loss: 0.017282
# INFO:trainer:    epoch          : 5
# INFO:trainer:    loss           : 0.07872001864154543
# INFO:trainer:    accuracy       : 0.8698884758364313
# INFO:trainer:    f1_score       : 0.8758039025419393
# INFO:trainer:    val_loss       : 0.09308970984861706
# INFO:trainer:    val_accuracy   : 0.8346861471861472
# INFO:trainer:    val_f1_score   : 0.8296629145133638
# INFO:trainer:    val_sensitivity: 0.8214285714285714
# INFO:trainer:    val_specificity: 0.8504854368932039
# INFO:trainer:    val_MAcc       : 0.8359570041608877
# INFO:trainer:    val_F1_score   : 0.8355640535372849
# DEBUG:trainer:Train Epoch: 6 [0/269 (0%)] Loss: 0.079522
# DEBUG:trainer:Train Epoch: 6 [4/269 (1%)] Loss: 0.113847
# DEBUG:trainer:Train Epoch: 6 [8/269 (3%)] Loss: 0.051007
# DEBUG:trainer:Train Epoch: 6 [12/269 (4%)] Loss: 0.096755
# DEBUG:trainer:Train Epoch: 6 [16/269 (6%)] Loss: 0.053765
# DEBUG:trainer:Train Epoch: 6 [20/269 (7%)] Loss: 0.067129
# DEBUG:trainer:Train Epoch: 6 [24/269 (9%)] Loss: 0.086923
# DEBUG:trainer:Train Epoch: 6 [28/269 (10%)] Loss: 0.058963
# DEBUG:trainer:Train Epoch: 6 [32/269 (12%)] Loss: 0.091413
# DEBUG:trainer:Train Epoch: 6 [36/269 (13%)] Loss: 0.024099
# DEBUG:trainer:Train Epoch: 6 [40/269 (15%)] Loss: 0.030028
# DEBUG:trainer:Train Epoch: 6 [44/269 (16%)] Loss: 0.077224
# DEBUG:trainer:Train Epoch: 6 [48/269 (18%)] Loss: 0.038938
# DEBUG:trainer:Train Epoch: 6 [52/269 (19%)] Loss: 0.054760
# DEBUG:trainer:Train Epoch: 6 [56/269 (21%)] Loss: 0.155450
# DEBUG:trainer:Train Epoch: 6 [60/269 (22%)] Loss: 0.046336
# DEBUG:trainer:Train Epoch: 6 [64/269 (24%)] Loss: 0.032021
# DEBUG:trainer:Train Epoch: 6 [68/269 (25%)] Loss: 0.149988
# DEBUG:trainer:Train Epoch: 6 [72/269 (27%)] Loss: 0.119454
# DEBUG:trainer:Train Epoch: 6 [76/269 (28%)] Loss: 0.060934
# DEBUG:trainer:Train Epoch: 6 [80/269 (30%)] Loss: 0.031331
# DEBUG:trainer:Train Epoch: 6 [84/269 (31%)] Loss: 0.044538
# DEBUG:trainer:Train Epoch: 6 [88/269 (33%)] Loss: 0.055340
# DEBUG:trainer:Train Epoch: 6 [92/269 (34%)] Loss: 0.087434
# DEBUG:trainer:Train Epoch: 6 [96/269 (36%)] Loss: 0.053462
# DEBUG:trainer:Train Epoch: 6 [100/269 (37%)] Loss: 0.064530
# DEBUG:trainer:Train Epoch: 6 [104/269 (39%)] Loss: 0.060852
# DEBUG:trainer:Train Epoch: 6 [108/269 (40%)] Loss: 0.136746
# DEBUG:trainer:Train Epoch: 6 [112/269 (42%)] Loss: 0.112086
# DEBUG:trainer:Train Epoch: 6 [116/269 (43%)] Loss: 0.093974
# DEBUG:trainer:Train Epoch: 6 [120/269 (45%)] Loss: 0.112528
# DEBUG:trainer:Train Epoch: 6 [124/269 (46%)] Loss: 0.053898
# DEBUG:trainer:Train Epoch: 6 [128/269 (48%)] Loss: 0.105359
# DEBUG:trainer:Train Epoch: 6 [132/269 (49%)] Loss: 0.059301
# DEBUG:trainer:Train Epoch: 6 [136/269 (51%)] Loss: 0.061673
# DEBUG:trainer:Train Epoch: 6 [140/269 (52%)] Loss: 0.037181
# DEBUG:trainer:Train Epoch: 6 [144/269 (54%)] Loss: 0.083416
# DEBUG:trainer:Train Epoch: 6 [148/269 (55%)] Loss: 0.064438
# DEBUG:trainer:Train Epoch: 6 [152/269 (57%)] Loss: 0.072571
# DEBUG:trainer:Train Epoch: 6 [156/269 (58%)] Loss: 0.109119
# DEBUG:trainer:Train Epoch: 6 [160/269 (59%)] Loss: 0.080260
# DEBUG:trainer:Train Epoch: 6 [164/269 (61%)] Loss: 0.037383
# DEBUG:trainer:Train Epoch: 6 [168/269 (62%)] Loss: 0.087554
# DEBUG:trainer:Train Epoch: 6 [172/269 (64%)] Loss: 0.127781
# DEBUG:trainer:Train Epoch: 6 [176/269 (65%)] Loss: 0.050636
# DEBUG:trainer:Train Epoch: 6 [180/269 (67%)] Loss: 0.074958
# DEBUG:trainer:Train Epoch: 6 [184/269 (68%)] Loss: 0.056942
# DEBUG:trainer:Train Epoch: 6 [188/269 (70%)] Loss: 0.085209
# DEBUG:trainer:Train Epoch: 6 [192/269 (71%)] Loss: 0.074530
# DEBUG:trainer:Train Epoch: 6 [196/269 (73%)] Loss: 0.124922
# DEBUG:trainer:Train Epoch: 6 [200/269 (74%)] Loss: 0.067850
# DEBUG:trainer:Train Epoch: 6 [204/269 (76%)] Loss: 0.096675
# DEBUG:trainer:Train Epoch: 6 [208/269 (77%)] Loss: 0.027049
# DEBUG:trainer:Train Epoch: 6 [212/269 (79%)] Loss: 0.138537
# DEBUG:trainer:Train Epoch: 6 [216/269 (80%)] Loss: 0.134479
# DEBUG:trainer:Train Epoch: 6 [220/269 (82%)] Loss: 0.110420
# DEBUG:trainer:Train Epoch: 6 [224/269 (83%)] Loss: 0.045400
# DEBUG:trainer:Train Epoch: 6 [228/269 (85%)] Loss: 0.045378
# DEBUG:trainer:Train Epoch: 6 [232/269 (86%)] Loss: 0.040515
# DEBUG:trainer:Train Epoch: 6 [236/269 (88%)] Loss: 0.026117
# DEBUG:trainer:Train Epoch: 6 [240/269 (89%)] Loss: 0.113945
# DEBUG:trainer:Train Epoch: 6 [244/269 (91%)] Loss: 0.066152
# DEBUG:trainer:Train Epoch: 6 [248/269 (92%)] Loss: 0.050685
# DEBUG:trainer:Train Epoch: 6 [252/269 (94%)] Loss: 0.068897
# DEBUG:trainer:Train Epoch: 6 [256/269 (95%)] Loss: 0.098434
# DEBUG:trainer:Train Epoch: 6 [260/269 (97%)] Loss: 0.046723
# DEBUG:trainer:Train Epoch: 6 [264/269 (98%)] Loss: 0.080448
# DEBUG:trainer:Train Epoch: 6 [268/269 (100%)] Loss: 0.087331
# INFO:trainer:    epoch          : 6
# INFO:trainer:    loss           : 0.07517927806810597
# INFO:trainer:    accuracy       : 0.8701208178438662
# INFO:trainer:    f1_score       : 0.8760200749273764
# INFO:trainer:    val_loss       : 0.07385549798720714
# INFO:trainer:    val_accuracy   : 0.8798701298701298
# INFO:trainer:    val_f1_score   : 0.8761286004793566
# INFO:trainer:    val_sensitivity: 0.8627819548872181
# INFO:trainer:    val_specificity: 0.9029126213592233
# INFO:trainer:    val_MAcc       : 0.8828472881232208
# INFO:trainer:    val_F1_score   : 0.8818443804034581
# DEBUG:trainer:Train Epoch: 7 [0/269 (0%)] Loss: 0.101486
# DEBUG:trainer:Train Epoch: 7 [4/269 (1%)] Loss: 0.095985
# DEBUG:trainer:Train Epoch: 7 [8/269 (3%)] Loss: 0.094246
# DEBUG:trainer:Train Epoch: 7 [12/269 (4%)] Loss: 0.071148
# DEBUG:trainer:Train Epoch: 7 [16/269 (6%)] Loss: 0.046527
# DEBUG:trainer:Train Epoch: 7 [20/269 (7%)] Loss: 0.059282
# DEBUG:trainer:Train Epoch: 7 [24/269 (9%)] Loss: 0.079079
# DEBUG:trainer:Train Epoch: 7 [28/269 (10%)] Loss: 0.060780
# DEBUG:trainer:Train Epoch: 7 [32/269 (12%)] Loss: 0.082162
# DEBUG:trainer:Train Epoch: 7 [36/269 (13%)] Loss: 0.041452
# DEBUG:trainer:Train Epoch: 7 [40/269 (15%)] Loss: 0.032043
# DEBUG:trainer:Train Epoch: 7 [44/269 (16%)] Loss: 0.036977
# DEBUG:trainer:Train Epoch: 7 [48/269 (18%)] Loss: 0.152543
# DEBUG:trainer:Train Epoch: 7 [52/269 (19%)] Loss: 0.058977
# DEBUG:trainer:Train Epoch: 7 [56/269 (21%)] Loss: 0.060721
# DEBUG:trainer:Train Epoch: 7 [60/269 (22%)] Loss: 0.076451
# DEBUG:trainer:Train Epoch: 7 [64/269 (24%)] Loss: 0.059787
# DEBUG:trainer:Train Epoch: 7 [68/269 (25%)] Loss: 0.059367
# DEBUG:trainer:Train Epoch: 7 [72/269 (27%)] Loss: 0.093397
# DEBUG:trainer:Train Epoch: 7 [76/269 (28%)] Loss: 0.080456
# DEBUG:trainer:Train Epoch: 7 [80/269 (30%)] Loss: 0.062395
# DEBUG:trainer:Train Epoch: 7 [84/269 (31%)] Loss: 0.064961
# DEBUG:trainer:Train Epoch: 7 [88/269 (33%)] Loss: 0.099469
# DEBUG:trainer:Train Epoch: 7 [92/269 (34%)] Loss: 0.055682
# DEBUG:trainer:Train Epoch: 7 [96/269 (36%)] Loss: 0.084861
# DEBUG:trainer:Train Epoch: 7 [100/269 (37%)] Loss: 0.077586
# DEBUG:trainer:Train Epoch: 7 [104/269 (39%)] Loss: 0.053065
# DEBUG:trainer:Train Epoch: 7 [108/269 (40%)] Loss: 0.089985
# DEBUG:trainer:Train Epoch: 7 [112/269 (42%)] Loss: 0.091619
# DEBUG:trainer:Train Epoch: 7 [116/269 (43%)] Loss: 0.076182
# DEBUG:trainer:Train Epoch: 7 [120/269 (45%)] Loss: 0.062713
# DEBUG:trainer:Train Epoch: 7 [124/269 (46%)] Loss: 0.040589
# DEBUG:trainer:Train Epoch: 7 [128/269 (48%)] Loss: 0.121223
# DEBUG:trainer:Train Epoch: 7 [132/269 (49%)] Loss: 0.031412
# DEBUG:trainer:Train Epoch: 7 [136/269 (51%)] Loss: 0.040640
# DEBUG:trainer:Train Epoch: 7 [140/269 (52%)] Loss: 0.051747
# DEBUG:trainer:Train Epoch: 7 [144/269 (54%)] Loss: 0.097648
# DEBUG:trainer:Train Epoch: 7 [148/269 (55%)] Loss: 0.058415
# DEBUG:trainer:Train Epoch: 7 [152/269 (57%)] Loss: 0.084688
# DEBUG:trainer:Train Epoch: 7 [156/269 (58%)] Loss: 0.103846
# DEBUG:trainer:Train Epoch: 7 [160/269 (59%)] Loss: 0.023557
# DEBUG:trainer:Train Epoch: 7 [164/269 (61%)] Loss: 0.059762
# DEBUG:trainer:Train Epoch: 7 [168/269 (62%)] Loss: 0.076680
# DEBUG:trainer:Train Epoch: 7 [172/269 (64%)] Loss: 0.075637
# DEBUG:trainer:Train Epoch: 7 [176/269 (65%)] Loss: 0.054481
# DEBUG:trainer:Train Epoch: 7 [180/269 (67%)] Loss: 0.037474
# DEBUG:trainer:Train Epoch: 7 [184/269 (68%)] Loss: 0.029276
# DEBUG:trainer:Train Epoch: 7 [188/269 (70%)] Loss: 0.098176
# DEBUG:trainer:Train Epoch: 7 [192/269 (71%)] Loss: 0.044562
# DEBUG:trainer:Train Epoch: 7 [196/269 (73%)] Loss: 0.064609
# DEBUG:trainer:Train Epoch: 7 [200/269 (74%)] Loss: 0.116427
# DEBUG:trainer:Train Epoch: 7 [204/269 (76%)] Loss: 0.068338
# DEBUG:trainer:Train Epoch: 7 [208/269 (77%)] Loss: 0.034656
# DEBUG:trainer:Train Epoch: 7 [212/269 (79%)] Loss: 0.089688
# DEBUG:trainer:Train Epoch: 7 [216/269 (80%)] Loss: 0.060465
# DEBUG:trainer:Train Epoch: 7 [220/269 (82%)] Loss: 0.086692
# DEBUG:trainer:Train Epoch: 7 [224/269 (83%)] Loss: 0.075849
# DEBUG:trainer:Train Epoch: 7 [228/269 (85%)] Loss: 0.060611
# DEBUG:trainer:Train Epoch: 7 [232/269 (86%)] Loss: 0.028769
# DEBUG:trainer:Train Epoch: 7 [236/269 (88%)] Loss: 0.056847
# DEBUG:trainer:Train Epoch: 7 [240/269 (89%)] Loss: 0.023974
# DEBUG:trainer:Train Epoch: 7 [244/269 (91%)] Loss: 0.078705
# DEBUG:trainer:Train Epoch: 7 [248/269 (92%)] Loss: 0.093096
# DEBUG:trainer:Train Epoch: 7 [252/269 (94%)] Loss: 0.084685
# DEBUG:trainer:Train Epoch: 7 [256/269 (95%)] Loss: 0.072435
# DEBUG:trainer:Train Epoch: 7 [260/269 (97%)] Loss: 0.117381
# DEBUG:trainer:Train Epoch: 7 [264/269 (98%)] Loss: 0.061811
# DEBUG:trainer:Train Epoch: 7 [268/269 (100%)] Loss: 0.608011
# INFO:trainer:    epoch          : 7
# INFO:trainer:    loss           : 0.07565372978721409
# INFO:trainer:    accuracy       : 0.8705855018587361
# INFO:trainer:    f1_score       : 0.8755942208162495
# INFO:trainer:    val_loss       : 0.08397903589701111
# INFO:trainer:    val_accuracy   : 0.8574134199134199
# INFO:trainer:    val_f1_score   : 0.8472290131627862
# INFO:trainer:    val_sensitivity: 0.8665413533834586
# INFO:trainer:    val_specificity: 0.8504854368932039
# INFO:trainer:    val_MAcc       : 0.8585133951383312
# INFO:trainer:    val_F1_score   : 0.8616822429906543
# DEBUG:trainer:Train Epoch: 8 [0/269 (0%)] Loss: 0.043892
# DEBUG:trainer:Train Epoch: 8 [4/269 (1%)] Loss: 0.104297
# DEBUG:trainer:Train Epoch: 8 [8/269 (3%)] Loss: 0.097534
# DEBUG:trainer:Train Epoch: 8 [12/269 (4%)] Loss: 0.119278
# DEBUG:trainer:Train Epoch: 8 [16/269 (6%)] Loss: 0.067090
# DEBUG:trainer:Train Epoch: 8 [20/269 (7%)] Loss: 0.078759
# DEBUG:trainer:Train Epoch: 8 [24/269 (9%)] Loss: 0.129700
# DEBUG:trainer:Train Epoch: 8 [28/269 (10%)] Loss: 0.070603
# DEBUG:trainer:Train Epoch: 8 [32/269 (12%)] Loss: 0.103617
# DEBUG:trainer:Train Epoch: 8 [36/269 (13%)] Loss: 0.074499
# DEBUG:trainer:Train Epoch: 8 [40/269 (15%)] Loss: 0.148662
# DEBUG:trainer:Train Epoch: 8 [44/269 (16%)] Loss: 0.067598
# DEBUG:trainer:Train Epoch: 8 [48/269 (18%)] Loss: 0.084989
# DEBUG:trainer:Train Epoch: 8 [52/269 (19%)] Loss: 0.063119
# DEBUG:trainer:Train Epoch: 8 [56/269 (21%)] Loss: 0.053906
# DEBUG:trainer:Train Epoch: 8 [60/269 (22%)] Loss: 0.049549
# DEBUG:trainer:Train Epoch: 8 [64/269 (24%)] Loss: 0.078470
# DEBUG:trainer:Train Epoch: 8 [68/269 (25%)] Loss: 0.078430
# DEBUG:trainer:Train Epoch: 8 [72/269 (27%)] Loss: 0.062384
# DEBUG:trainer:Train Epoch: 8 [76/269 (28%)] Loss: 0.088297
# DEBUG:trainer:Train Epoch: 8 [80/269 (30%)] Loss: 0.068600
# DEBUG:trainer:Train Epoch: 8 [84/269 (31%)] Loss: 0.065013
# DEBUG:trainer:Train Epoch: 8 [88/269 (33%)] Loss: 0.068240
# DEBUG:trainer:Train Epoch: 8 [92/269 (34%)] Loss: 0.042048
# DEBUG:trainer:Train Epoch: 8 [96/269 (36%)] Loss: 0.076920
# DEBUG:trainer:Train Epoch: 8 [100/269 (37%)] Loss: 0.068933
# DEBUG:trainer:Train Epoch: 8 [104/269 (39%)] Loss: 0.031446
# DEBUG:trainer:Train Epoch: 8 [108/269 (40%)] Loss: 0.105030
# DEBUG:trainer:Train Epoch: 8 [112/269 (42%)] Loss: 0.056785
# DEBUG:trainer:Train Epoch: 8 [116/269 (43%)] Loss: 0.046377
# DEBUG:trainer:Train Epoch: 8 [120/269 (45%)] Loss: 0.057890
# DEBUG:trainer:Train Epoch: 8 [124/269 (46%)] Loss: 0.087371
# DEBUG:trainer:Train Epoch: 8 [128/269 (48%)] Loss: 0.094512
# DEBUG:trainer:Train Epoch: 8 [132/269 (49%)] Loss: 0.024963
# DEBUG:trainer:Train Epoch: 8 [136/269 (51%)] Loss: 0.082183
# DEBUG:trainer:Train Epoch: 8 [140/269 (52%)] Loss: 0.064408
# DEBUG:trainer:Train Epoch: 8 [144/269 (54%)] Loss: 0.079887
# DEBUG:trainer:Train Epoch: 8 [148/269 (55%)] Loss: 0.060167
# DEBUG:trainer:Train Epoch: 8 [152/269 (57%)] Loss: 0.033691
# DEBUG:trainer:Train Epoch: 8 [156/269 (58%)] Loss: 0.037873
# DEBUG:trainer:Train Epoch: 8 [160/269 (59%)] Loss: 0.041593
# DEBUG:trainer:Train Epoch: 8 [164/269 (61%)] Loss: 0.041125
# DEBUG:trainer:Train Epoch: 8 [168/269 (62%)] Loss: 0.122816
# DEBUG:trainer:Train Epoch: 8 [172/269 (64%)] Loss: 0.052897
# DEBUG:trainer:Train Epoch: 8 [176/269 (65%)] Loss: 0.048799
# DEBUG:trainer:Train Epoch: 8 [180/269 (67%)] Loss: 0.066227
# DEBUG:trainer:Train Epoch: 8 [184/269 (68%)] Loss: 0.069155
# DEBUG:trainer:Train Epoch: 8 [188/269 (70%)] Loss: 0.026108
# DEBUG:trainer:Train Epoch: 8 [192/269 (71%)] Loss: 0.070903
# DEBUG:trainer:Train Epoch: 8 [196/269 (73%)] Loss: 0.040374
# DEBUG:trainer:Train Epoch: 8 [200/269 (74%)] Loss: 0.030505
# DEBUG:trainer:Train Epoch: 8 [204/269 (76%)] Loss: 0.071557
# DEBUG:trainer:Train Epoch: 8 [208/269 (77%)] Loss: 0.051351
# DEBUG:trainer:Train Epoch: 8 [212/269 (79%)] Loss: 0.025129
# DEBUG:trainer:Train Epoch: 8 [216/269 (80%)] Loss: 0.069842
# DEBUG:trainer:Train Epoch: 8 [220/269 (82%)] Loss: 0.063835
# DEBUG:trainer:Train Epoch: 8 [224/269 (83%)] Loss: 0.055094
# DEBUG:trainer:Train Epoch: 8 [228/269 (85%)] Loss: 0.102784
# DEBUG:trainer:Train Epoch: 8 [232/269 (86%)] Loss: 0.173015
# DEBUG:trainer:Train Epoch: 8 [236/269 (88%)] Loss: 0.026582
# DEBUG:trainer:Train Epoch: 8 [240/269 (89%)] Loss: 0.050938
# DEBUG:trainer:Train Epoch: 8 [244/269 (91%)] Loss: 0.042384
# DEBUG:trainer:Train Epoch: 8 [248/269 (92%)] Loss: 0.113883
# DEBUG:trainer:Train Epoch: 8 [252/269 (94%)] Loss: 0.083464
# DEBUG:trainer:Train Epoch: 8 [256/269 (95%)] Loss: 0.155233
# DEBUG:trainer:Train Epoch: 8 [260/269 (97%)] Loss: 0.050316
# DEBUG:trainer:Train Epoch: 8 [264/269 (98%)] Loss: 0.036884
# DEBUG:trainer:Train Epoch: 8 [268/269 (100%)] Loss: 0.030459
# INFO:trainer:    epoch          : 8
# INFO:trainer:    loss           : 0.07310294542032325
# INFO:trainer:    accuracy       : 0.8803438661710037
# INFO:trainer:    f1_score       : 0.8846308298874624
# INFO:trainer:    val_loss       : 0.084028528325937
# INFO:trainer:    val_accuracy   : 0.8754058441558442
# INFO:trainer:    val_f1_score   : 0.8804687658813216
# INFO:trainer:    val_sensitivity: 0.7894736842105263
# INFO:trainer:    val_specificity: 0.9669902912621359
# INFO:trainer:    val_MAcc       : 0.8782319877363312
# INFO:trainer:    val_F1_score   : 0.8668730650154799
# DEBUG:trainer:Train Epoch: 9 [0/269 (0%)] Loss: 0.070220
# DEBUG:trainer:Train Epoch: 9 [4/269 (1%)] Loss: 0.065546
# DEBUG:trainer:Train Epoch: 9 [8/269 (3%)] Loss: 0.024785
# DEBUG:trainer:Train Epoch: 9 [12/269 (4%)] Loss: 0.068081
# DEBUG:trainer:Train Epoch: 9 [16/269 (6%)] Loss: 0.045260
# DEBUG:trainer:Train Epoch: 9 [20/269 (7%)] Loss: 0.062510
# DEBUG:trainer:Train Epoch: 9 [24/269 (9%)] Loss: 0.033751
# DEBUG:trainer:Train Epoch: 9 [28/269 (10%)] Loss: 0.123098
# DEBUG:trainer:Train Epoch: 9 [32/269 (12%)] Loss: 0.040300
# DEBUG:trainer:Train Epoch: 9 [36/269 (13%)] Loss: 0.084108
# DEBUG:trainer:Train Epoch: 9 [40/269 (15%)] Loss: 0.065838
# DEBUG:trainer:Train Epoch: 9 [44/269 (16%)] Loss: 0.065374
# DEBUG:trainer:Train Epoch: 9 [48/269 (18%)] Loss: 0.033492
# DEBUG:trainer:Train Epoch: 9 [52/269 (19%)] Loss: 0.071810
# DEBUG:trainer:Train Epoch: 9 [56/269 (21%)] Loss: 0.042478
# DEBUG:trainer:Train Epoch: 9 [60/269 (22%)] Loss: 0.093329
# DEBUG:trainer:Train Epoch: 9 [64/269 (24%)] Loss: 0.043141
# DEBUG:trainer:Train Epoch: 9 [68/269 (25%)] Loss: 0.049212
# DEBUG:trainer:Train Epoch: 9 [72/269 (27%)] Loss: 0.047939
# DEBUG:trainer:Train Epoch: 9 [76/269 (28%)] Loss: 0.067601
# DEBUG:trainer:Train Epoch: 9 [80/269 (30%)] Loss: 0.039774
# DEBUG:trainer:Train Epoch: 9 [84/269 (31%)] Loss: 0.067661
# DEBUG:trainer:Train Epoch: 9 [88/269 (33%)] Loss: 0.115342
# DEBUG:trainer:Train Epoch: 9 [92/269 (34%)] Loss: 0.135445
# DEBUG:trainer:Train Epoch: 9 [96/269 (36%)] Loss: 0.109053
# DEBUG:trainer:Train Epoch: 9 [100/269 (37%)] Loss: 0.069713
# DEBUG:trainer:Train Epoch: 9 [104/269 (39%)] Loss: 0.058910
# DEBUG:trainer:Train Epoch: 9 [108/269 (40%)] Loss: 0.058456
# DEBUG:trainer:Train Epoch: 9 [112/269 (42%)] Loss: 0.093859
# DEBUG:trainer:Train Epoch: 9 [116/269 (43%)] Loss: 0.064726
# DEBUG:trainer:Train Epoch: 9 [120/269 (45%)] Loss: 0.120198
# DEBUG:trainer:Train Epoch: 9 [124/269 (46%)] Loss: 0.062266
# DEBUG:trainer:Train Epoch: 9 [128/269 (48%)] Loss: 0.110965
# DEBUG:trainer:Train Epoch: 9 [132/269 (49%)] Loss: 0.075969
# DEBUG:trainer:Train Epoch: 9 [136/269 (51%)] Loss: 0.040418
# DEBUG:trainer:Train Epoch: 9 [140/269 (52%)] Loss: 0.045880
# DEBUG:trainer:Train Epoch: 9 [144/269 (54%)] Loss: 0.102397
# DEBUG:trainer:Train Epoch: 9 [148/269 (55%)] Loss: 0.040464
# DEBUG:trainer:Train Epoch: 9 [152/269 (57%)] Loss: 0.058440
# DEBUG:trainer:Train Epoch: 9 [156/269 (58%)] Loss: 0.054019
# DEBUG:trainer:Train Epoch: 9 [160/269 (59%)] Loss: 0.045359
# DEBUG:trainer:Train Epoch: 9 [164/269 (61%)] Loss: 0.022416
# DEBUG:trainer:Train Epoch: 9 [168/269 (62%)] Loss: 0.034482
# DEBUG:trainer:Train Epoch: 9 [172/269 (64%)] Loss: 0.096232
# DEBUG:trainer:Train Epoch: 9 [176/269 (65%)] Loss: 0.121476
# DEBUG:trainer:Train Epoch: 9 [180/269 (67%)] Loss: 0.055268
# DEBUG:trainer:Train Epoch: 9 [184/269 (68%)] Loss: 0.033508
# DEBUG:trainer:Train Epoch: 9 [188/269 (70%)] Loss: 0.083500
# DEBUG:trainer:Train Epoch: 9 [192/269 (71%)] Loss: 0.041374
# DEBUG:trainer:Train Epoch: 9 [196/269 (73%)] Loss: 0.051242
# DEBUG:trainer:Train Epoch: 9 [200/269 (74%)] Loss: 0.154659
# DEBUG:trainer:Train Epoch: 9 [204/269 (76%)] Loss: 0.167089
# DEBUG:trainer:Train Epoch: 9 [208/269 (77%)] Loss: 0.113370
# DEBUG:trainer:Train Epoch: 9 [212/269 (79%)] Loss: 0.067830
# DEBUG:trainer:Train Epoch: 9 [216/269 (80%)] Loss: 0.049328
# DEBUG:trainer:Train Epoch: 9 [220/269 (82%)] Loss: 0.056559
# DEBUG:trainer:Train Epoch: 9 [224/269 (83%)] Loss: 0.031315
# DEBUG:trainer:Train Epoch: 9 [228/269 (85%)] Loss: 0.045177
# DEBUG:trainer:Train Epoch: 9 [232/269 (86%)] Loss: 0.158534
# DEBUG:trainer:Train Epoch: 9 [236/269 (88%)] Loss: 0.070838
# DEBUG:trainer:Train Epoch: 9 [240/269 (89%)] Loss: 0.086813
# DEBUG:trainer:Train Epoch: 9 [244/269 (91%)] Loss: 0.041741
# DEBUG:trainer:Train Epoch: 9 [248/269 (92%)] Loss: 0.121945
# DEBUG:trainer:Train Epoch: 9 [252/269 (94%)] Loss: 0.053776
# DEBUG:trainer:Train Epoch: 9 [256/269 (95%)] Loss: 0.056360
# DEBUG:trainer:Train Epoch: 9 [260/269 (97%)] Loss: 0.045379
# DEBUG:trainer:Train Epoch: 9 [264/269 (98%)] Loss: 0.063369
# DEBUG:trainer:Train Epoch: 9 [268/269 (100%)] Loss: 0.092184
# INFO:trainer:    epoch          : 9
# INFO:trainer:    loss           : 0.06803625231421792
# INFO:trainer:    accuracy       : 0.8863847583643123
# INFO:trainer:    f1_score       : 0.8893398654494294
# INFO:trainer:    val_loss       : 0.07220219668339599
# INFO:trainer:    val_accuracy   : 0.8905573593073594
# INFO:trainer:    val_f1_score   : 0.8861338194316479
# INFO:trainer:    val_sensitivity: 0.881578947368421
# INFO:trainer:    val_specificity: 0.9029126213592233
# INFO:trainer:    val_MAcc       : 0.8922457843638222
# INFO:trainer:    val_F1_score   : 0.8924833491912464
# DEBUG:trainer:Train Epoch: 10 [0/269 (0%)] Loss: 0.037019
# DEBUG:trainer:Train Epoch: 10 [4/269 (1%)] Loss: 0.058942
# DEBUG:trainer:Train Epoch: 10 [8/269 (3%)] Loss: 0.060583
# DEBUG:trainer:Train Epoch: 10 [12/269 (4%)] Loss: 0.080402
# DEBUG:trainer:Train Epoch: 10 [16/269 (6%)] Loss: 0.084899
# DEBUG:trainer:Train Epoch: 10 [20/269 (7%)] Loss: 0.103166
# DEBUG:trainer:Train Epoch: 10 [24/269 (9%)] Loss: 0.138475
# DEBUG:trainer:Train Epoch: 10 [28/269 (10%)] Loss: 0.113876
# DEBUG:trainer:Train Epoch: 10 [32/269 (12%)] Loss: 0.097242
# DEBUG:trainer:Train Epoch: 10 [36/269 (13%)] Loss: 0.096434
# DEBUG:trainer:Train Epoch: 10 [40/269 (15%)] Loss: 0.053652
# DEBUG:trainer:Train Epoch: 10 [44/269 (16%)] Loss: 0.030405
# DEBUG:trainer:Train Epoch: 10 [48/269 (18%)] Loss: 0.078878
# DEBUG:trainer:Train Epoch: 10 [52/269 (19%)] Loss: 0.082959
# DEBUG:trainer:Train Epoch: 10 [56/269 (21%)] Loss: 0.056639
# DEBUG:trainer:Train Epoch: 10 [60/269 (22%)] Loss: 0.064368
# DEBUG:trainer:Train Epoch: 10 [64/269 (24%)] Loss: 0.057558
# DEBUG:trainer:Train Epoch: 10 [68/269 (25%)] Loss: 0.104067
# DEBUG:trainer:Train Epoch: 10 [72/269 (27%)] Loss: 0.034387
# DEBUG:trainer:Train Epoch: 10 [76/269 (28%)] Loss: 0.070556
# DEBUG:trainer:Train Epoch: 10 [80/269 (30%)] Loss: 0.047153
# DEBUG:trainer:Train Epoch: 10 [84/269 (31%)] Loss: 0.114353
# DEBUG:trainer:Train Epoch: 10 [88/269 (33%)] Loss: 0.054500
# DEBUG:trainer:Train Epoch: 10 [92/269 (34%)] Loss: 0.035452
# DEBUG:trainer:Train Epoch: 10 [96/269 (36%)] Loss: 0.051711
# DEBUG:trainer:Train Epoch: 10 [100/269 (37%)] Loss: 0.076751
# DEBUG:trainer:Train Epoch: 10 [104/269 (39%)] Loss: 0.074576
# DEBUG:trainer:Train Epoch: 10 [108/269 (40%)] Loss: 0.043805
# DEBUG:trainer:Train Epoch: 10 [112/269 (42%)] Loss: 0.054160
# DEBUG:trainer:Train Epoch: 10 [116/269 (43%)] Loss: 0.136218
# DEBUG:trainer:Train Epoch: 10 [120/269 (45%)] Loss: 0.026904
# DEBUG:trainer:Train Epoch: 10 [124/269 (46%)] Loss: 0.106693
# DEBUG:trainer:Train Epoch: 10 [128/269 (48%)] Loss: 0.039849
# DEBUG:trainer:Train Epoch: 10 [132/269 (49%)] Loss: 0.026007
# DEBUG:trainer:Train Epoch: 10 [136/269 (51%)] Loss: 0.026004
# DEBUG:trainer:Train Epoch: 10 [140/269 (52%)] Loss: 0.071668
# DEBUG:trainer:Train Epoch: 10 [144/269 (54%)] Loss: 0.062742
# DEBUG:trainer:Train Epoch: 10 [148/269 (55%)] Loss: 0.052462
# DEBUG:trainer:Train Epoch: 10 [152/269 (57%)] Loss: 0.047847
# DEBUG:trainer:Train Epoch: 10 [156/269 (58%)] Loss: 0.043303
# DEBUG:trainer:Train Epoch: 10 [160/269 (59%)] Loss: 0.091436
# DEBUG:trainer:Train Epoch: 10 [164/269 (61%)] Loss: 0.050766
# DEBUG:trainer:Train Epoch: 10 [168/269 (62%)] Loss: 0.061037
# DEBUG:trainer:Train Epoch: 10 [172/269 (64%)] Loss: 0.025015
# DEBUG:trainer:Train Epoch: 10 [176/269 (65%)] Loss: 0.053617
# DEBUG:trainer:Train Epoch: 10 [180/269 (67%)] Loss: 0.079507
# DEBUG:trainer:Train Epoch: 10 [184/269 (68%)] Loss: 0.046297
# DEBUG:trainer:Train Epoch: 10 [188/269 (70%)] Loss: 0.070647
# DEBUG:trainer:Train Epoch: 10 [192/269 (71%)] Loss: 0.074846
# DEBUG:trainer:Train Epoch: 10 [196/269 (73%)] Loss: 0.091968
# DEBUG:trainer:Train Epoch: 10 [200/269 (74%)] Loss: 0.046048
# DEBUG:trainer:Train Epoch: 10 [204/269 (76%)] Loss: 0.076991
# DEBUG:trainer:Train Epoch: 10 [208/269 (77%)] Loss: 0.102196
# DEBUG:trainer:Train Epoch: 10 [212/269 (79%)] Loss: 0.092248
# DEBUG:trainer:Train Epoch: 10 [216/269 (80%)] Loss: 0.050897
# DEBUG:trainer:Train Epoch: 10 [220/269 (82%)] Loss: 0.066280
# DEBUG:trainer:Train Epoch: 10 [224/269 (83%)] Loss: 0.025514
# DEBUG:trainer:Train Epoch: 10 [228/269 (85%)] Loss: 0.046955
# DEBUG:trainer:Train Epoch: 10 [232/269 (86%)] Loss: 0.042237
# DEBUG:trainer:Train Epoch: 10 [236/269 (88%)] Loss: 0.080121
# DEBUG:trainer:Train Epoch: 10 [240/269 (89%)] Loss: 0.074109
# DEBUG:trainer:Train Epoch: 10 [244/269 (91%)] Loss: 0.030721
# DEBUG:trainer:Train Epoch: 10 [248/269 (92%)] Loss: 0.170294
# DEBUG:trainer:Train Epoch: 10 [252/269 (94%)] Loss: 0.128724
# DEBUG:trainer:Train Epoch: 10 [256/269 (95%)] Loss: 0.050427
# DEBUG:trainer:Train Epoch: 10 [260/269 (97%)] Loss: 0.027114
# DEBUG:trainer:Train Epoch: 10 [264/269 (98%)] Loss: 0.108764
# DEBUG:trainer:Train Epoch: 10 [268/269 (100%)] Loss: 0.108394
# INFO:trainer:    epoch          : 10
# INFO:trainer:    loss           : 0.06833908705864808
# INFO:trainer:    accuracy       : 0.8887081784386617
# INFO:trainer:    f1_score       : 0.8921626752040727
# INFO:trainer:    val_loss       : 0.08135826888522416
# INFO:trainer:    val_accuracy   : 0.8555194805194806
# INFO:trainer:    val_f1_score   : 0.8644835675515183
# INFO:trainer:    val_sensitivity: 0.7481203007518797
# INFO:trainer:    val_specificity: 0.9689320388349515
# INFO:trainer:    val_MAcc       : 0.8585261697934157
# INFO:trainer:    val_F1_score   : 0.8414376321353066
# DEBUG:trainer:Train Epoch: 11 [0/269 (0%)] Loss: 0.025324
# ...
# DEBUG:trainer:Train Epoch: 35 [200/269 (74%)] Loss: 0.012415
# DEBUG:trainer:Train Epoch: 35 [204/269 (76%)] Loss: 0.025526
# DEBUG:trainer:Train Epoch: 35 [208/269 (77%)] Loss: 0.008767
# DEBUG:trainer:Train Epoch: 35 [212/269 (79%)] Loss: 0.032099
# DEBUG:trainer:Train Epoch: 35 [216/269 (80%)] Loss: 0.012052
# DEBUG:trainer:Train Epoch: 35 [220/269 (82%)] Loss: 0.010294
# DEBUG:trainer:Train Epoch: 35 [224/269 (83%)] Loss: 0.002190
# DEBUG:trainer:Train Epoch: 35 [228/269 (85%)] Loss: 0.014968
# DEBUG:trainer:Train Epoch: 35 [232/269 (86%)] Loss: 0.004993
# DEBUG:trainer:Train Epoch: 35 [236/269 (88%)] Loss: 0.020525
# DEBUG:trainer:Train Epoch: 35 [240/269 (89%)] Loss: 0.023545
# DEBUG:trainer:Train Epoch: 35 [244/269 (91%)] Loss: 0.009446
# DEBUG:trainer:Train Epoch: 35 [248/269 (92%)] Loss: 0.003686
# DEBUG:trainer:Train Epoch: 35 [252/269 (94%)] Loss: 0.000861
# DEBUG:trainer:Train Epoch: 35 [256/269 (95%)] Loss: 0.018638
# DEBUG:trainer:Train Epoch: 35 [260/269 (97%)] Loss: 0.009661
# DEBUG:trainer:Train Epoch: 35 [264/269 (98%)] Loss: 0.014353
# DEBUG:trainer:Train Epoch: 35 [268/269 (100%)] Loss: 0.002006
# INFO:trainer:    epoch          : 35
# INFO:trainer:    loss           : 0.01774455895671209
# INFO:trainer:    accuracy       : 0.9772304832713755
# INFO:trainer:    f1_score       : 0.9775297665084236
# INFO:trainer:    val_loss       : 0.06513336516394647
# INFO:trainer:    val_accuracy   : 0.9299242424242424
# INFO:trainer:    val_f1_score   : 0.9322681294326286
# INFO:trainer:    val_sensitivity: 0.8609022556390977
# INFO:trainer:    val_specificity: 1.0
# INFO:trainer:    val_MAcc       : 0.9304511278195489
# INFO:trainer:    val_F1_score   : 0.9252525252525252
# DEBUG:trainer:Train Epoch: 36 [0/269 (0%)] Loss: 0.012460
# DEBUG:trainer:Train Epoch: 36 [4/269 (1%)] Loss: 0.002488
# DEBUG:trainer:Train Epoch: 36 [8/269 (3%)] Loss: 0.009988
# DEBUG:trainer:Train Epoch: 36 [12/269 (4%)] Loss: 0.017271
# DEBUG:trainer:Train Epoch: 36 [16/269 (6%)] Loss: 0.009372
# DEBUG:trainer:Train Epoch: 36 [20/269 (7%)] Loss: 0.111277
# DEBUG:trainer:Train Epoch: 36 [24/269 (9%)] Loss: 0.004735
# DEBUG:trainer:Train Epoch: 36 [28/269 (10%)] Loss: 0.004236
# DEBUG:trainer:Train Epoch: 36 [32/269 (12%)] Loss: 0.020691
# DEBUG:trainer:Train Epoch: 36 [36/269 (13%)] Loss: 0.030194
# DEBUG:trainer:Train Epoch: 36 [40/269 (15%)] Loss: 0.037263
# DEBUG:trainer:Train Epoch: 36 [44/269 (16%)] Loss: 0.001489
# DEBUG:trainer:Train Epoch: 36 [48/269 (18%)] Loss: 0.055423
# DEBUG:trainer:Train Epoch: 36 [52/269 (19%)] Loss: 0.006147
# DEBUG:trainer:Train Epoch: 36 [56/269 (21%)] Loss: 0.007662
# DEBUG:trainer:Train Epoch: 36 [60/269 (22%)] Loss: 0.008683
# DEBUG:trainer:Train Epoch: 36 [64/269 (24%)] Loss: 0.008799
# DEBUG:trainer:Train Epoch: 36 [68/269 (25%)] Loss: 0.010568
# DEBUG:trainer:Train Epoch: 36 [72/269 (27%)] Loss: 0.003291
# DEBUG:trainer:Train Epoch: 36 [76/269 (28%)] Loss: 0.023559
# DEBUG:trainer:Train Epoch: 36 [80/269 (30%)] Loss: 0.010959
# DEBUG:trainer:Train Epoch: 36 [84/269 (31%)] Loss: 0.005917
# DEBUG:trainer:Train Epoch: 36 [88/269 (33%)] Loss: 0.005554
# DEBUG:trainer:Train Epoch: 36 [92/269 (34%)] Loss: 0.010442
# DEBUG:trainer:Train Epoch: 36 [96/269 (36%)] Loss: 0.005040
# DEBUG:trainer:Train Epoch: 36 [100/269 (37%)] Loss: 0.000511
# DEBUG:trainer:Train Epoch: 36 [104/269 (39%)] Loss: 0.012418
# DEBUG:trainer:Train Epoch: 36 [108/269 (40%)] Loss: 0.036736
# DEBUG:trainer:Train Epoch: 36 [112/269 (42%)] Loss: 0.006627
# DEBUG:trainer:Train Epoch: 36 [116/269 (43%)] Loss: 0.031394
# DEBUG:trainer:Train Epoch: 36 [120/269 (45%)] Loss: 0.018506
# DEBUG:trainer:Train Epoch: 36 [124/269 (46%)] Loss: 0.031436
# DEBUG:trainer:Train Epoch: 36 [128/269 (48%)] Loss: 0.006762
# DEBUG:trainer:Train Epoch: 36 [132/269 (49%)] Loss: 0.020708
# DEBUG:trainer:Train Epoch: 36 [136/269 (51%)] Loss: 0.002122
# DEBUG:trainer:Train Epoch: 36 [140/269 (52%)] Loss: 0.066606
# DEBUG:trainer:Train Epoch: 36 [144/269 (54%)] Loss: 0.021924
# DEBUG:trainer:Train Epoch: 36 [148/269 (55%)] Loss: 0.014652
# DEBUG:trainer:Train Epoch: 36 [152/269 (57%)] Loss: 0.023754
# DEBUG:trainer:Train Epoch: 36 [156/269 (58%)] Loss: 0.021000
# DEBUG:trainer:Train Epoch: 36 [160/269 (59%)] Loss: 0.045537
# DEBUG:trainer:Train Epoch: 36 [164/269 (61%)] Loss: 0.006333
# DEBUG:trainer:Train Epoch: 36 [168/269 (62%)] Loss: 0.014244
# DEBUG:trainer:Train Epoch: 36 [172/269 (64%)] Loss: 0.022032
# DEBUG:trainer:Train Epoch: 36 [176/269 (65%)] Loss: 0.003042
# DEBUG:trainer:Train Epoch: 36 [180/269 (67%)] Loss: 0.023725
# DEBUG:trainer:Train Epoch: 36 [184/269 (68%)] Loss: 0.025342
# DEBUG:trainer:Train Epoch: 36 [188/269 (70%)] Loss: 0.005336
# DEBUG:trainer:Train Epoch: 36 [192/269 (71%)] Loss: 0.010048
# DEBUG:trainer:Train Epoch: 36 [196/269 (73%)] Loss: 0.014706
# DEBUG:trainer:Train Epoch: 36 [200/269 (74%)] Loss: 0.006133
# DEBUG:trainer:Train Epoch: 36 [204/269 (76%)] Loss: 0.015230
# DEBUG:trainer:Train Epoch: 36 [208/269 (77%)] Loss: 0.064917
# DEBUG:trainer:Train Epoch: 36 [212/269 (79%)] Loss: 0.001398
# DEBUG:trainer:Train Epoch: 36 [216/269 (80%)] Loss: 0.008930
# DEBUG:trainer:Train Epoch: 36 [220/269 (82%)] Loss: 0.002151
# DEBUG:trainer:Train Epoch: 36 [224/269 (83%)] Loss: 0.035195
# DEBUG:trainer:Train Epoch: 36 [228/269 (85%)] Loss: 0.015006
# DEBUG:trainer:Train Epoch: 36 [232/269 (86%)] Loss: 0.005506
# DEBUG:trainer:Train Epoch: 36 [236/269 (88%)] Loss: 0.011368
# DEBUG:trainer:Train Epoch: 36 [240/269 (89%)] Loss: 0.010161
# DEBUG:trainer:Train Epoch: 36 [244/269 (91%)] Loss: 0.047744
# DEBUG:trainer:Train Epoch: 36 [248/269 (92%)] Loss: 0.010031
# DEBUG:trainer:Train Epoch: 36 [252/269 (94%)] Loss: 0.011988
# DEBUG:trainer:Train Epoch: 36 [256/269 (95%)] Loss: 0.018020
# DEBUG:trainer:Train Epoch: 36 [260/269 (97%)] Loss: 0.015574
# DEBUG:trainer:Train Epoch: 36 [264/269 (98%)] Loss: 0.130887
# DEBUG:trainer:Train Epoch: 36 [268/269 (100%)] Loss: 0.009502
# INFO:trainer:    epoch          : 36
# INFO:trainer:    loss           : 0.018135282367668686
# INFO:trainer:    accuracy       : 0.9763011152416357
# INFO:trainer:    f1_score       : 0.9765640211826206
# INFO:trainer:    val_loss       : 0.07286708698622092
# INFO:trainer:    val_accuracy   : 0.9180194805194806
# INFO:trainer:    val_f1_score   : 0.9234989528952775
# INFO:trainer:    val_sensitivity: 0.8458646616541353
# INFO:trainer:    val_specificity: 0.996116504854369
# INFO:trainer:    val_MAcc       : 0.9209905832542522
# INFO:trainer:    val_F1_score   : 0.9146341463414634
# DEBUG:trainer:Train Epoch: 37 [0/269 (0%)] Loss: 0.009304
# DEBUG:trainer:Train Epoch: 37 [4/269 (1%)] Loss: 0.095182
# DEBUG:trainer:Train Epoch: 37 [8/269 (3%)] Loss: 0.042564
# DEBUG:trainer:Train Epoch: 37 [12/269 (4%)] Loss: 0.004350
# DEBUG:trainer:Train Epoch: 37 [16/269 (6%)] Loss: 0.004276
# DEBUG:trainer:Train Epoch: 37 [20/269 (7%)] Loss: 0.029847
# DEBUG:trainer:Train Epoch: 37 [24/269 (9%)] Loss: 0.024577
# DEBUG:trainer:Train Epoch: 37 [28/269 (10%)] Loss: 0.026351
# DEBUG:trainer:Train Epoch: 37 [32/269 (12%)] Loss: 0.021229
# DEBUG:trainer:Train Epoch: 37 [36/269 (13%)] Loss: 0.016419
# DEBUG:trainer:Train Epoch: 37 [40/269 (15%)] Loss: 0.017171
# DEBUG:trainer:Train Epoch: 37 [44/269 (16%)] Loss: 0.005051
# DEBUG:trainer:Train Epoch: 37 [48/269 (18%)] Loss: 0.011095
# DEBUG:trainer:Train Epoch: 37 [52/269 (19%)] Loss: 0.004531
# DEBUG:trainer:Train Epoch: 37 [56/269 (21%)] Loss: 0.008689
# DEBUG:trainer:Train Epoch: 37 [60/269 (22%)] Loss: 0.007313
# DEBUG:trainer:Train Epoch: 37 [64/269 (24%)] Loss: 0.015288
# DEBUG:trainer:Train Epoch: 37 [68/269 (25%)] Loss: 0.009935
# DEBUG:trainer:Train Epoch: 37 [72/269 (27%)] Loss: 0.023961
# DEBUG:trainer:Train Epoch: 37 [76/269 (28%)] Loss: 0.042990
# DEBUG:trainer:Train Epoch: 37 [80/269 (30%)] Loss: 0.003492
# DEBUG:trainer:Train Epoch: 37 [84/269 (31%)] Loss: 0.029045
# DEBUG:trainer:Train Epoch: 37 [88/269 (33%)] Loss: 0.019413
# DEBUG:trainer:Train Epoch: 37 [92/269 (34%)] Loss: 0.025659
# DEBUG:trainer:Train Epoch: 37 [96/269 (36%)] Loss: 0.037565
# DEBUG:trainer:Train Epoch: 37 [100/269 (37%)] Loss: 0.003345
# DEBUG:trainer:Train Epoch: 37 [104/269 (39%)] Loss: 0.024139
# DEBUG:trainer:Train Epoch: 37 [108/269 (40%)] Loss: 0.013856
# DEBUG:trainer:Train Epoch: 37 [112/269 (42%)] Loss: 0.025644
# DEBUG:trainer:Train Epoch: 37 [116/269 (43%)] Loss: 0.020136
# DEBUG:trainer:Train Epoch: 37 [120/269 (45%)] Loss: 0.010847
# DEBUG:trainer:Train Epoch: 37 [124/269 (46%)] Loss: 0.006233
# DEBUG:trainer:Train Epoch: 37 [128/269 (48%)] Loss: 0.014147
# DEBUG:trainer:Train Epoch: 37 [132/269 (49%)] Loss: 0.009368
# DEBUG:trainer:Train Epoch: 37 [136/269 (51%)] Loss: 0.013032
# DEBUG:trainer:Train Epoch: 37 [140/269 (52%)] Loss: 0.009795
# DEBUG:trainer:Train Epoch: 37 [144/269 (54%)] Loss: 0.005319
# DEBUG:trainer:Train Epoch: 37 [148/269 (55%)] Loss: 0.023498
# DEBUG:trainer:Train Epoch: 37 [152/269 (57%)] Loss: 0.008277
# DEBUG:trainer:Train Epoch: 37 [156/269 (58%)] Loss: 0.016841
# DEBUG:trainer:Train Epoch: 37 [160/269 (59%)] Loss: 0.004182
# DEBUG:trainer:Train Epoch: 37 [164/269 (61%)] Loss: 0.007955
# DEBUG:trainer:Train Epoch: 37 [168/269 (62%)] Loss: 0.067786
# DEBUG:trainer:Train Epoch: 37 [172/269 (64%)] Loss: 0.016151
# DEBUG:trainer:Train Epoch: 37 [176/269 (65%)] Loss: 0.012969
# DEBUG:trainer:Train Epoch: 37 [180/269 (67%)] Loss: 0.003087
# DEBUG:trainer:Train Epoch: 37 [184/269 (68%)] Loss: 0.002039
# DEBUG:trainer:Train Epoch: 37 [188/269 (70%)] Loss: 0.040670
# DEBUG:trainer:Train Epoch: 37 [192/269 (71%)] Loss: 0.026263
# DEBUG:trainer:Train Epoch: 37 [196/269 (73%)] Loss: 0.043391
# DEBUG:trainer:Train Epoch: 37 [200/269 (74%)] Loss: 0.001436
# DEBUG:trainer:Train Epoch: 37 [204/269 (76%)] Loss: 0.054012
# DEBUG:trainer:Train Epoch: 37 [208/269 (77%)] Loss: 0.004666
# DEBUG:trainer:Train Epoch: 37 [212/269 (79%)] Loss: 0.062634
# DEBUG:trainer:Train Epoch: 37 [216/269 (80%)] Loss: 0.005323
# DEBUG:trainer:Train Epoch: 37 [220/269 (82%)] Loss: 0.017682
# DEBUG:trainer:Train Epoch: 37 [224/269 (83%)] Loss: 0.003853
# DEBUG:trainer:Train Epoch: 37 [228/269 (85%)] Loss: 0.000941
# DEBUG:trainer:Train Epoch: 37 [232/269 (86%)] Loss: 0.006742
# DEBUG:trainer:Train Epoch: 37 [236/269 (88%)] Loss: 0.012732
# DEBUG:trainer:Train Epoch: 37 [240/269 (89%)] Loss: 0.018920
# DEBUG:trainer:Train Epoch: 37 [244/269 (91%)] Loss: 0.018517
# DEBUG:trainer:Train Epoch: 37 [248/269 (92%)] Loss: 0.022821
# DEBUG:trainer:Train Epoch: 37 [252/269 (94%)] Loss: 0.013989
# DEBUG:trainer:Train Epoch: 37 [256/269 (95%)] Loss: 0.021098
# DEBUG:trainer:Train Epoch: 37 [260/269 (97%)] Loss: 0.003072
# DEBUG:trainer:Train Epoch: 37 [264/269 (98%)] Loss: 0.028654
# DEBUG:trainer:Train Epoch: 37 [268/269 (100%)] Loss: 0.018299
# INFO:trainer:    epoch          : 37
# INFO:trainer:    loss           : 0.019755740279871037
# INFO:trainer:    accuracy       : 0.9744423791821561
# INFO:trainer:    f1_score       : 0.9747971121119937
# INFO:trainer:    val_loss       : 0.05209412272652668
# INFO:trainer:    val_accuracy   : 0.950487012987013
# INFO:trainer:    val_f1_score   : 0.9513991964896058
# INFO:trainer:    val_sensitivity: 0.9116541353383458
# INFO:trainer:    val_specificity: 0.9922330097087378
# INFO:trainer:    val_MAcc       : 0.9519435725235419
# INFO:trainer:    val_F1_score   : 0.9500489715964741
# DEBUG:trainer:Train Epoch: 38 [0/269 (0%)] Loss: 0.015395
# DEBUG:trainer:Train Epoch: 38 [4/269 (1%)] Loss: 0.008689
# DEBUG:trainer:Train Epoch: 38 [8/269 (3%)] Loss: 0.001528
# DEBUG:trainer:Train Epoch: 38 [12/269 (4%)] Loss: 0.016469
# DEBUG:trainer:Train Epoch: 38 [16/269 (6%)] Loss: 0.008392
# DEBUG:trainer:Train Epoch: 38 [20/269 (7%)] Loss: 0.020640
# DEBUG:trainer:Train Epoch: 38 [24/269 (9%)] Loss: 0.002541
# DEBUG:trainer:Train Epoch: 38 [28/269 (10%)] Loss: 0.003659
# DEBUG:trainer:Train Epoch: 38 [32/269 (12%)] Loss: 0.005726
# DEBUG:trainer:Train Epoch: 38 [36/269 (13%)] Loss: 0.030076
# DEBUG:trainer:Train Epoch: 38 [40/269 (15%)] Loss: 0.003783
# DEBUG:trainer:Train Epoch: 38 [44/269 (16%)] Loss: 0.050186
# DEBUG:trainer:Train Epoch: 38 [48/269 (18%)] Loss: 0.017541
# DEBUG:trainer:Train Epoch: 38 [52/269 (19%)] Loss: 0.009828
# DEBUG:trainer:Train Epoch: 38 [56/269 (21%)] Loss: 0.004652
# DEBUG:trainer:Train Epoch: 38 [60/269 (22%)] Loss: 0.003759
# DEBUG:trainer:Train Epoch: 38 [64/269 (24%)] Loss: 0.005574
# DEBUG:trainer:Train Epoch: 38 [68/269 (25%)] Loss: 0.010610
# DEBUG:trainer:Train Epoch: 38 [72/269 (27%)] Loss: 0.009914
# DEBUG:trainer:Train Epoch: 38 [76/269 (28%)] Loss: 0.018153
# DEBUG:trainer:Train Epoch: 38 [80/269 (30%)] Loss: 0.035753
# DEBUG:trainer:Train Epoch: 38 [84/269 (31%)] Loss: 0.009690
# DEBUG:trainer:Train Epoch: 38 [88/269 (33%)] Loss: 0.035378
# DEBUG:trainer:Train Epoch: 38 [92/269 (34%)] Loss: 0.010504
# DEBUG:trainer:Train Epoch: 38 [96/269 (36%)] Loss: 0.033497
# DEBUG:trainer:Train Epoch: 38 [100/269 (37%)] Loss: 0.086617
# DEBUG:trainer:Train Epoch: 38 [104/269 (39%)] Loss: 0.007999
# DEBUG:trainer:Train Epoch: 38 [108/269 (40%)] Loss: 0.112288
# DEBUG:trainer:Train Epoch: 38 [112/269 (42%)] Loss: 0.006060
# DEBUG:trainer:Train Epoch: 38 [116/269 (43%)] Loss: 0.028036
# DEBUG:trainer:Train Epoch: 38 [120/269 (45%)] Loss: 0.010242
# DEBUG:trainer:Train Epoch: 38 [124/269 (46%)] Loss: 0.019699
# DEBUG:trainer:Train Epoch: 38 [128/269 (48%)] Loss: 0.045954
# DEBUG:trainer:Train Epoch: 38 [132/269 (49%)] Loss: 0.014651
# DEBUG:trainer:Train Epoch: 38 [136/269 (51%)] Loss: 0.026404
# DEBUG:trainer:Train Epoch: 38 [140/269 (52%)] Loss: 0.026344
# DEBUG:trainer:Train Epoch: 38 [144/269 (54%)] Loss: 0.003947
# DEBUG:trainer:Train Epoch: 38 [148/269 (55%)] Loss: 0.002676
# DEBUG:trainer:Train Epoch: 38 [152/269 (57%)] Loss: 0.022798
# DEBUG:trainer:Train Epoch: 38 [156/269 (58%)] Loss: 0.006694
# DEBUG:trainer:Train Epoch: 38 [160/269 (59%)] Loss: 0.017142
# DEBUG:trainer:Train Epoch: 38 [164/269 (61%)] Loss: 0.022393
# DEBUG:trainer:Train Epoch: 38 [168/269 (62%)] Loss: 0.013063
# DEBUG:trainer:Train Epoch: 38 [172/269 (64%)] Loss: 0.017669
# DEBUG:trainer:Train Epoch: 38 [176/269 (65%)] Loss: 0.010753
# DEBUG:trainer:Train Epoch: 38 [180/269 (67%)] Loss: 0.038391
# DEBUG:trainer:Train Epoch: 38 [184/269 (68%)] Loss: 0.007004
# DEBUG:trainer:Train Epoch: 38 [188/269 (70%)] Loss: 0.005135
# DEBUG:trainer:Train Epoch: 38 [192/269 (71%)] Loss: 0.010779
# DEBUG:trainer:Train Epoch: 38 [196/269 (73%)] Loss: 0.001600
# DEBUG:trainer:Train Epoch: 38 [200/269 (74%)] Loss: 0.019484
# DEBUG:trainer:Train Epoch: 38 [204/269 (76%)] Loss: 0.095811
# DEBUG:trainer:Train Epoch: 38 [208/269 (77%)] Loss: 0.003417
# DEBUG:trainer:Train Epoch: 38 [212/269 (79%)] Loss: 0.016077
# DEBUG:trainer:Train Epoch: 38 [216/269 (80%)] Loss: 0.011862
# DEBUG:trainer:Train Epoch: 38 [220/269 (82%)] Loss: 0.022305
# DEBUG:trainer:Train Epoch: 38 [224/269 (83%)] Loss: 0.023738
# DEBUG:trainer:Train Epoch: 38 [228/269 (85%)] Loss: 0.015269
# DEBUG:trainer:Train Epoch: 38 [232/269 (86%)] Loss: 0.010185
# DEBUG:trainer:Train Epoch: 38 [236/269 (88%)] Loss: 0.001796
# DEBUG:trainer:Train Epoch: 38 [240/269 (89%)] Loss: 0.028045
# DEBUG:trainer:Train Epoch: 38 [244/269 (91%)] Loss: 0.011468
# DEBUG:trainer:Train Epoch: 38 [248/269 (92%)] Loss: 0.018705
# DEBUG:trainer:Train Epoch: 38 [252/269 (94%)] Loss: 0.016020
# DEBUG:trainer:Train Epoch: 38 [256/269 (95%)] Loss: 0.006434
# DEBUG:trainer:Train Epoch: 38 [260/269 (97%)] Loss: 0.024058
# DEBUG:trainer:Train Epoch: 38 [264/269 (98%)] Loss: 0.016472
# DEBUG:trainer:Train Epoch: 38 [268/269 (100%)] Loss: 0.012166
# INFO:trainer:    epoch          : 38
# INFO:trainer:    loss           : 0.017502727582280397
# INFO:trainer:    accuracy       : 0.979089219330855
# INFO:trainer:    f1_score       : 0.9798047657286453
# INFO:trainer:    val_loss       : 0.04955656300334147
# INFO:trainer:    val_accuracy   : 0.9422348484848485
# INFO:trainer:    val_f1_score   : 0.9445928806327472
# INFO:trainer:    val_sensitivity: 0.8853383458646616
# INFO:trainer:    val_specificity: 1.0
# INFO:trainer:    val_MAcc       : 0.9426691729323309
# INFO:trainer:    val_F1_score   : 0.9391824526420737
# INFO:trainer:Validation performance didn't improve for 20 epochs. Training stops.
# === HOÀN THÀNH TRAINING ===
# Model tốt nhất được lưu tại:
# /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0203_153447/model_best.pth

# %% [markdown]
# # Test

# %%
from sklearn.metrics import f1_score, confusion_matrix
import torch
from torch.utils.data import DataLoader
from pathlib import Path
import pandas as pd

def test_model(config, best_model_path, validation_fea_path, validation_label_csv):
    config_parser = ConfigParser(config)
    device, _ = prepare_device(config_parser['n_gpu'])

    # Khởi tạo model từ config (đảm bảo architecture đúng)
    model = config_parser.init_obj('arch', globals())
    model = model.to(device)

    # === LOAD CHỈ STATE_DICT - AN TOÀN, KHÔNG CẦN WHITELIST ===
    try:
        # Cách 1: Dùng weights_only=True (mặc định từ PT 2.6), chỉ load weights
        checkpoint = torch.load(best_model_path, map_location=device, weights_only=True)
        model.load_state_dict(checkpoint)  # checkpoint ở đây chỉ là state_dict
        print("Loaded model weights with weights_only=True (safe mode)")
    except Exception as e1:
        print(f"weights_only=True failed: {e1}")
        try:
            # Cách 2: Tắt weights_only (chỉ dùng nếu bạn tin tưởng file)
            checkpoint = torch.load(best_model_path, map_location=device, weights_only=False)
            model.load_state_dict(checkpoint['state_dict'])
            print("Loaded with weights_only=False (full checkpoint)")
        except Exception as e2:
            print(f"Cả hai cách đều thất bại: {e2}")
            return

    model.eval()

    print("\n=== MODEL ARCHITECTURE ===")
    print(model)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\nSố tham số huấn luyện được: {trainable_params:,}")

    # === Xác định input shape từ config ===
    delta = config['data_loader']['args'].get('delta', False)
    n_mfcc = config['data_loader']['args'].get('n_mfcc', 39)
    time_frames = 333

    channels = 3 if delta else 1   # static + Δ + ΔΔ nếu có
    height = n_mfcc

    # === Kiểm tra forward với input giả ===
    print("\n=== KIỂM TRA FORWARD PASS ===")
    try:
        with torch.no_grad():
            dummy_input = torch.randn(2, channels * height, time_frames)
            output = model(dummy_input)
            print(f"Input shape: (B, {channels * height}, {time_frames})")
            print(f"Output shape: {output.shape} → OK")
    except Exception as e:
        print(f"Forward lỗi: {e}")

    # === Load validation data ===
    if not Path(validation_label_csv).exists() or not Path(validation_fea_path).exists():
        print("Không tìm thấy file validation → bỏ qua đánh giá")
        return

    validation_label_df = pd.read_csv(validation_label_csv)
    validation_label_df['filename'] = validation_label_df['filename'].apply(lambda x: Path(x).stem)

    validation_dataset = HeartSoundDataSet(
        fea_path=validation_fea_path,
        labels=validation_label_df,
        duration=config['data_loader']['args']['duration'],
        training=False,
        delta=delta,
        norm=config['data_loader']['args'].get('norm', True)
    )

    print("\n=== DEBUG: SAMPLE FEATURES ===")
    for i in range(min(5, len(validation_dataset))):
        fea, lab = validation_dataset[i]
        print(f"Sample {i}: shape = {fea.shape}, label = {lab.item()}")

    # Tắt pin_memory trên CPU
    pin_memory = (device.type == 'cuda')

    validation_dataloader = DataLoader(
        validation_dataset,
        batch_size=config['data_loader']['args']['batch_size'],
        shuffle=False,
        num_workers=config['data_loader']['args'].get('num_workers', 2),
        pin_memory=pin_memory
    )

    criterion = ce_loss

    print("\n=== ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===")
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    val_TP = val_TN = val_pred_pos = val_condition_pos = 0

    with torch.no_grad():
        for data, target in validation_dataloader:
            data, target = data.to(device).float(), target.to(device)
            output = model(data)
            loss = criterion(output, target)

            total_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, 1)
            total_correct += (pred == target).sum().item()
            total_samples += target.size(0)

            pred_pos_idx = (pred == 0)      # class 0 = abnormal (positive)
            condition_pos_idx = (target == 0)

            val_TP += (pred_pos_idx & condition_pos_idx).sum().item()
            val_TN += ((pred == 1) & (target == 1)).sum().item()
            val_pred_pos += pred_pos_idx.sum().item()
            val_condition_pos += condition_pos_idx.sum().item()

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    sensitivity = val_TP / val_condition_pos if val_condition_pos > 0 else 0
    specificity = val_TN / (total_samples - val_condition_pos) if (total_samples - val_condition_pos) > 0 else 0
    MAcc = (sensitivity + specificity) / 2
    precision = val_TP / val_pred_pos if val_pred_pos > 0 else 0
    F1_score = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0

    val_log = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'MAcc': MAcc,
        'F1_score': F1_score
    }

    print("\nKết quả đánh giá:")
    for k, v in val_log.items():
        print(f"    {k}: {v:.4f}")

    metrics_path = Path(best_model_path).parent / "test_on_validation_set_metrics.csv"
    pd.DataFrame([val_log]).to_csv(metrics_path, index=False)
    print(f"\nĐã lưu kết quả tại: {metrics_path}")

# %%
base_dir = Path(current_config['trainer']['save_dir']) / "models" / current_config['name']
if base_dir.exists():
        latest_run = max(base_dir.iterdir(), key=os.path.getmtime)
        best_model_path = latest_run / "model_best.pth"

        validation_fea_path = str(DATASET_PATH / "mfcc_features_validation.h5")
        validation_label_csv = str(DATASET_PATH / "label_validation.csv")  # Đảm bảo file này tồn tại!

        if Path(validation_fea_path).exists() and Path(validation_label_csv).exists():
            test_model(current_config, best_model_path, validation_fea_path, validation_label_csv)
        else:
            print("Không tìm thấy file validation .h5 hoặc label_validation.csv → Bỏ qua phần test.")

        size_bytes = os.path.getsize(best_model_path)
        size_mb = size_bytes / (1024 * 1024)

        print(f"Model size: {size_mb:.2f} MB")

else:
    print("Không tìm thấy thư mục saved models.")
# Out:
# Warning: There's no GPU available on this machine,training will be performed on CPU.
# weights_only=True failed: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL __main__.ConfigParser was not an allowed global by default. Please use `torch.serialization.add_safe_globals([__main__.ConfigParser])` or the `torch.serialization.safe_globals([__main__.ConfigParser])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Loaded with weights_only=False (full checkpoint)
#
# === MODEL ARCHITECTURE ===
# LightweightHeartSoundCNN(
#   (stem): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU6(inplace=True)
#   )
#   (features): Sequential(
#     (0): DepthwiseSeparableConv(
#       (depthwise): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#       (pointwise): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (1): DepthwiseSeparableConv(
#       (depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (pointwise): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#     (2): DepthwiseSeparableConv(
#       (depthwise): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU6(inplace=True)
#     )
#   )
#   (pool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=128, out_features=2, bias=True)
#   )
# )
#
# Số tham số huấn luyện được: 12,642
#
# === KIỂM TRA FORWARD PASS ===
# Input shape: (B, 39, 333)
# Output shape: torch.Size([2, 2]) → OK
#
# === DEBUG: SAMPLE FEATURES ===
# Sample 0: shape = torch.Size([13, 333]), label = 1
# Sample 1: shape = torch.Size([13, 333]), label = 1
# Sample 2: shape = torch.Size([13, 333]), label = 1
# Sample 3: shape = torch.Size([13, 333]), label = 1
# Sample 4: shape = torch.Size([13, 333]), label = 1
#
# === ĐÁNH GIÁ TRÊN TẬP VALIDATION RIÊNG ===
#
# Kết quả đánh giá:
#     loss: 0.8439
#     accuracy: 0.6013
#     sensitivity: 0.9600
#     specificity: 0.2450
#     MAcc: 0.6025
#     F1_score: 0.7059
#
# Đã lưu kết quả tại: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/saved/lightweight_cnn/models/Physionet_lightweight_cnn/0203_153447/test_on_validation_set_metrics.csv
# Model size: 0.35 MB
