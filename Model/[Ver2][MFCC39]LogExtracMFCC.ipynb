# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
from pathlib import Path
import matplotlib.pyplot as plt

# %%
import sys
from pathlib import Path
import matplotlib.pyplot as plt

# Define the project path
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')
sys.path.append(str(PROJECT_PATH))

# Define the dataset path
DATASET_PATH = Path('/content/drive/MyDrive/physionet2016')

# %% [markdown]
# ```
# <base>/
# ├── annotations/
# ├── papers/
# ├── sources/
# ├── training-a/
# ├── training-b/
# ├── training-c/
# ├── training-d/
# ├── training-e/
# ├── training-f/
# ├── validation/
# ├── training.zip
# ├── validation.zip
# └── README / figure / sample files
# ```

# %% [markdown]
# ```
# training-a/
# ├── a0001.wav
# ├── a0001.hea
# ├── a0001.dat
# ├── a0002.wav
# ├── a0002.hea
# ├── a0002.dat
# ├── ...
# ├── REFERENCE.csv
# ├── REFERENCE-SQI.csv
# ├── RECORDS
# ├── RECORDS-normal
# ├── RECORDS-abnormal
# ├── MD5SUMS / SHA1SUMS / SHA256SUMS
# ```

# %%
import numpy as np
import pandas as pd
import librosa
from tqdm import tqdm
import soundfile
import h5py
import random
import h5py
import torch
import torch.nn as nn
from torch.utils.data import Dataset, Sampler, DataLoader
import json
import torch
import librosa
from pathlib import Path
from itertools import repeat
from collections import OrderedDict
from scipy.signal import butter, lfilter
from sklearn.model_selection import train_test_split
import glob
import os
from collections import Counter

import librosa

# %%
wav_files = glob.glob("/content/drive/MyDrive/physionet2016/training-*/*.wav")

normal_files = []
abnormal_files = []

for f in wav_files:
    hea_file = f.replace(".wav", ".hea")
    if os.path.exists(hea_file):
        with open(hea_file, "r") as hf:
            for line in hf:
                line = line.strip().lower()
                if line.startswith("# normal"):
                    normal_files.append(f)
                    break
                elif line.startswith("# abnormal"):
                    abnormal_files.append(f)
                    break

print("Tổng số file:", len(wav_files))
print("Normal:", len(normal_files))
print("Abnormal:", len(abnormal_files))
# Out:
# Tổng số file: 3240
# Normal: 2575
# Abnormal: 665

# %% [markdown]
# # Đọc audio & tiền xử lý tín hiệu

# %%
lowcut = 20      # Hz
highcut = 600    # Hz
fs = 2000        # Hz
order = 4

# %%
def read_audio(path, target_fs=None, filter=False,
               lowcut=lowcut, hightcut=highcut):
    (audio, fs) = soundfile.read(path)

    if audio.ndim > 1:
        audio = np.mean(audio, axis=1)

    if target_fs is not None and fs != target_fs:
        audio = librosa.resample(audio, orig_sr = fs, target_sr = target_fs)
        fs = target_fs
    if filter:
        # apply bandpass filter
        audio = butter_bandpass_filter(audio, lowcut, hightcut, fs, order)
    return audio, fs

# %%
def butter_bandpass(lowcut, hightcut, fs, order=order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = hightcut / nyq
    b, a = butter(order, [low, high], btype='bandpass')
    return b, a

def butter_bandpass_filter(data, lowcut, hightcut, fs, order):
    b, a = butter_bandpass(lowcut, hightcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
'''
def augment_audio(audio, fs):
    """Apply random augmentations to audio signal."""
    if random.random() < 0.5:
        # Add Gaussian noise
        noise = np.random.normal(0, 0.01 * np.std(audio), len(audio))
        audio += noise

    if random.random() < 0.5:
        # Time shift (roll)
        shift = random.randint(-len(audio)//10, len(audio)//10)
        audio = np.roll(audio, shift)

    if random.random() < 0.5:
        # Pitch shift
        n_steps = random.uniform(-2, 2)
        audio = librosa.effects.pitch_shift(audio, sr=fs, n_steps=n_steps)

    if random.random() < 0.5:
        # Time stretch
        rate = random.uniform(0.8, 1.2)
        audio = librosa.effects.time_stretch(audio, rate=rate)

    if random.random() < 0.2:
        # Polarity inversion
        audio = -audio

    return audio
'''
# Out:
# '\ndef augment_audio(audio, fs):\n    """Apply random augmentations to audio signal."""\n    if random.random() < 0.5:\n        # Add Gaussian noise\n        noise = np.random.normal(0, 0.01 * np.std(audio), len(audio))\n        audio += noise\n\n    if random.random() < 0.5:\n        # Time shift (roll)\n        shift = random.randint(-len(audio)//10, len(audio)//10)\n        audio = np.roll(audio, shift)\n\n    if random.random() < 0.5:\n        # Pitch shift\n        n_steps = random.uniform(-2, 2)\n        audio = librosa.effects.pitch_shift(audio, sr=fs, n_steps=n_steps)\n\n    if random.random() < 0.5:\n        # Time stretch\n        rate = random.uniform(0.8, 1.2)\n        audio = librosa.effects.time_stretch(audio, rate=rate)\n\n    if random.random() < 0.2:\n        # Polarity inversion\n        audio = -audio\n\n    return audio\n'

# %%
import numpy as np
import random
import librosa

def augment_audio(audio, fs, label=None):
    """
    Data augmentation for PCG signals based on PhysioNet 2016 setting.

    Augmentations are preferentially applied to the abnormal class
    to mitigate class imbalance.

    Parameters
    ----------
    audio : np.ndarray
        Input PCG signal
    fs : int
        Sampling frequency (Hz), typically 2000
    label : int or None
        Class label (0: normal, 1: abnormal)

    Returns
    -------
    audio_aug : np.ndarray
        Augmented audio signal
    """

    audio_aug = audio.copy()

    # Only apply augmentation aggressively to abnormal class
    if label == 1 and random.random() < 0.5:

        # 1. Additive Gaussian noise (α = 0.005)
        if random.random() < 0.5:
            noise = np.random.normal(
                0,
                0.005 * np.std(audio_aug),
                size=len(audio_aug)
            )
            audio_aug = audio_aug + noise

        # 2. Time shift (Δ = ±0.05 * fs = ±100 samples)
        if random.random() < 0.5:
            shift = random.randint(-int(0.05 * fs), int(0.05 * fs))
            audio_aug = np.roll(audio_aug, shift)
            if shift > 0:
                audio_aug[:shift] = 0
            elif shift < 0:
                audio_aug[shift:] = 0

        # 3. Pitch shift (−2 to +2 semitones)
        if random.random() < 0.5:
            n_steps = random.uniform(-2, 2)
            audio_aug = librosa.effects.pitch_shift(
                audio_aug,
                sr=fs,
                n_steps=n_steps
            )

    return audio_aug

# %% [markdown]
# ## Test

# %%
def compute_fft(signal, fs):
    """
    Compute single-sided amplitude spectrum.
    """
    N = len(signal)
    fft_vals = np.fft.rfft(signal)
    fft_mag = np.abs(fft_vals) / N
    freqs = np.fft.rfftfreq(N, d=1/fs)
    return freqs, fft_mag

# %%
normal_file = Path(DATASET_PATH/'training-a/a0007.wav')
abnormal_file = Path(DATASET_PATH/'training-a/a0001.wav')

# %% [markdown]
# Normal

# %%
#Miền thời gian
audio_normal_raw, fs = read_audio(str(normal_file), filter=False)
audio_normal_filt, _ = read_audio(str(normal_file), filter=True)

plt.figure(figsize=(15, 6))

plt.subplot(2, 1, 1)
librosa.display.waveshow(audio_normal_raw, sr=fs)
plt.title("Normal PCG – Raw signal")
plt.ylabel("Amplitude")

plt.subplot(2, 1, 2)
librosa.display.waveshow(audio_normal_filt, sr=fs)
plt.title("Normal PCG – Filtered signal (Butterworth 20–600 Hz)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")

plt.tight_layout()
plt.show()

# %%
# Miền tần số
freqs_raw, fft_raw = compute_fft(audio_normal_raw, fs)
freqs_filt, fft_filt = compute_fft(audio_normal_filt, fs)

plt.figure(figsize=(14, 6))
plt.semilogy(freqs_raw, fft_raw, label="Raw")
plt.semilogy(freqs_filt, fft_filt, label="Filtered (20–600 Hz)")

plt.xlim(0, 1000)
plt.title("So sánh phổ tần số PCG Normal trước và sau lọc")
plt.xlabel("Tần số (Hz)")
plt.ylabel("Biên độ (log scale)")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.4)
plt.show()

# %% [markdown]
# Abnormal

# %%
#Miền thời gian
audio_abnormal_raw, fs = read_audio(str(abnormal_file), filter=False)
audio_abnormal_filt, _ = read_audio(str(abnormal_file), filter=True)
audio_abnormal_aug = augment_audio(audio_abnormal_filt, fs, label=1)

plt.figure(figsize=(15, 9))

plt.subplot(3, 1, 1)
librosa.display.waveshow(audio_abnormal_raw, sr=fs, color="gray")
plt.title("Abnormal PCG – Raw signal")

plt.subplot(3, 1, 2)
librosa.display.waveshow(audio_abnormal_filt, sr=fs, color="red")
plt.title("Abnormal PCG – Filtered signal")

plt.subplot(3, 1, 3)
librosa.display.waveshow(audio_abnormal_aug, sr=fs, color="orange")
plt.title("Abnormal PCG – Augmented signal")

plt.xlabel("Time (s)")
plt.tight_layout()
plt.show()

# %%
#Miền tần số
freqs_raw, fft_raw = compute_fft(audio_abnormal_raw, fs)
freqs_filt, fft_filt = compute_fft(audio_abnormal_filt, fs)
freqs_aug, fft_aug = compute_fft(audio_abnormal_aug, fs)

plt.figure(figsize=(14, 6))
plt.semilogy(freqs_raw, fft_raw, label="Raw")
plt.semilogy(freqs_filt, fft_filt, label="Filtered (20–600 Hz)")
plt.semilogy(freqs_aug, fft_aug, label="Augmented")

plt.xlim(0, 1000)
plt.title("So sánh phổ tần số PCG Abnormal: Raw – Filtered – Augmented")
plt.xlabel("Tần số (Hz)")
plt.ylabel("Biên độ (log scale)")
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.4)
plt.show()

# %% [markdown]
# # MFCC Extractor

# %%
import numpy as np
import librosa

import numpy as np
import librosa

def MfccExtractor(
    data,
    sr,
    n_mfcc=13,
    window='hamming',
    hoplen=15,   # ms
    winlen=25,   # ms
    T_fixed=333, # Đã tăng lên theo đề xuất (5s / 15ms ~ 333)
    snv=False
):
    """
    MFCC extraction pipeline following Viet Hung thesis:
    - Full signal MFCC
    - Temporal truncation / zero-padding to fixed T
    """

    MFCC_ARGS = {
        'n_mfcc': n_mfcc,
        'sr': sr,
        'window': window,
        'hop_length': int(sr * hoplen / 1000),
        'win_length': int(sr * winlen / 1000),
    }

    # 1. Trích xuất 13 hệ số tĩnh (Static)
    mfcc_static = librosa.feature.mfcc(y=data, **MFCC_ARGS)

    # 2. Tính Delta và Delta-Delta
    delta = librosa.feature.delta(mfcc_static)
    delta2 = librosa.feature.delta(mfcc_static, order=2)

    mfcc = np.concatenate((mfcc_static, delta, delta2), axis=0)

    if snv:
        mfcc = standard_normal_variate(mfcc)

    # ===== Temporal normalization (KEY STEP) =====
    T = mfcc.shape[1]

    if T >= T_fixed:
        mfcc = mfcc[:, :T_fixed]          # truncation
    else:
        pad = T_fixed - T
        mfcc = np.pad(
            mfcc,
            ((0, 0), (0, pad)),
            mode="constant"
        )

    return mfcc.astype(np.float32)  # (39, 333)

# %%
EPS = 1E-8
def LogMelExtractor(
    data,
    sr,
    mel_bins=128,
    hoplen=15,
    winlen=25,
    log=True,
    snv=False
):
    """
    Log-Mel spectrogram extractor
    """

    hop_length = int(sr * hoplen / 1000)
    win_length = int(sr * winlen / 1000)

    mel = librosa.feature.melspectrogram(
        y=data,
        sr=sr,
        n_mels=mel_bins,
        hop_length=hop_length,
        win_length=win_length
    )

    if log:
        mel = np.log(mel + EPS)

    if snv:
        mel = standard_normal_variate(mel)

    return mel.astype(np.float32)

# %%
def standard_normal_variate(data):
    mean = np.mean(data)
    std = np.std(data)

    return (data - mean) / std

# %%
data_processing_path = Path(PROJECT_PATH) / 'data_processing'
data_processing_path.mkdir(parents=True, exist_ok=True)

# %%
import pandas as pd
import os
import sys
from pathlib import Path
from tqdm import tqdm  # Included as in original, though not used here

# Define the training folders based on the provided dataset structure
folders = ['training-a', 'training-b', 'training-c', 'training-d', 'training-e', 'training-f']

# Collect labels from each folder's REFERENCE.csv
dfs = []
for folder in folders:
    ref_path = DATASET_PATH / folder / 'REFERENCE.csv'
    df = pd.read_csv(ref_path, header=None, names=['basename', 'label'])

    # Correct way to create full filenames
    df['filename'] = [str(DATASET_PATH / folder / (base + '.wav')) for base in df['basename']]

    # Convert labels: -1 → 0, 1 → 1 (or abnormal → 1)
    df['label'] = (df['label'] + 1) // 2

    dfs.append(df[['filename', 'label']])

# Concatenate all dataframes and save to label.csv
all_df = pd.concat(dfs, ignore_index=True)
save_path = PROJECT_PATH / 'data' / 'label.csv'
save_dir = save_path.parent
os.makedirs(str(save_dir), exist_ok=True)
all_df.to_csv(str(save_path), index=False)

print(f"Created {str(save_path)} with {len(all_df)} entries.")
# Out:
# Created /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/label.csv with 3240 entries.

# %%
print(type(df['filename']))
print(df['filename'].head(10))
print(repr(df['filename'].iloc[0]))
print("First element type:", type(df['filename'].iloc[0]) if len(df) > 0 else "empty")
# Out:
# <class 'pandas.core.series.Series'>
# 0    /content/drive/MyDrive/physionet2016/training-...
# 1    /content/drive/MyDrive/physionet2016/training-...
# 2    /content/drive/MyDrive/physionet2016/training-...
# 3    /content/drive/MyDrive/physionet2016/training-...
# 4    /content/drive/MyDrive/physionet2016/training-...
# 5    /content/drive/MyDrive/physionet2016/training-...
# 6    /content/drive/MyDrive/physionet2016/training-...
# 7    /content/drive/MyDrive/physionet2016/training-...
# 8    /content/drive/MyDrive/physionet2016/training-...
# 9    /content/drive/MyDrive/physionet2016/training-...
# Name: filename, dtype: object
# '/content/drive/MyDrive/physionet2016/training-f/f0001.wav'
# First element type: <class 'str'>

# %%
import os
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter
from pathlib import Path

# =========================
# read_audio()
# augment_audio()
# PROJECT_PATH
# MfccExtractor()
# LogMelExtractor()
# =========================

if __name__ == "__main__":

    df = pd.read_csv(PROJECT_PATH / "data" / "label.csv")

    logmel_folder = PROJECT_PATH / "logmel_features"
    mfcc_folder   = PROJECT_PATH / "mfcc_features"

    os.makedirs(logmel_folder, exist_ok=True)
    os.makedirs(mfcc_folder, exist_ok=True)

    # ===== Class balancing =====
    label_counts = Counter(df["label"])
    n_normal   = label_counts[0]
    n_abnormal = label_counts[1]

    target_abnormal = n_normal
    augment_per_abnormal = int(
        np.ceil((target_abnormal - n_abnormal) / n_abnormal)
    )

    print("=== ORIGINAL DISTRIBUTION ===")
    print(f"Normal  : {n_normal}")
    print(f"Abnormal: {n_abnormal}")
    print(f"Augment per abnormal sample: {augment_per_abnormal}")

    # ===== Feature parameters =====
    mel_bins = 128
    n_mfcc   = 13
    hoplen   = 15   # ms
    winlen   = 25   # ms
    T_fixed  = 333
    # =========================
    # Feature extraction
    # =========================
    for _, row in tqdm(df.iterrows(), total=len(df)):

        filename = row["filename"]
        label    = row["label"]

        audio, fs = read_audio(filename, filter=True)
        basename = Path(filename).stem

        # ===== ORIGINAL SAMPLE =====
        logmel = LogMelExtractor(
            audio, fs,
            mel_bins=mel_bins,
            hoplen=hoplen,
            winlen=winlen
        )

        mfcc = MfccExtractor(
            audio, fs,
            n_mfcc=n_mfcc,
            hoplen=hoplen,
            winlen=winlen,
            T_fixed=T_fixed
        )

        np.save(logmel_folder / f"{basename}.npy", logmel)
        np.save(mfcc_folder   / f"{basename}.npy", mfcc)

        # ===== AUGMENTATION (Abnormal only) =====
        if label == 1:
            for k in range(augment_per_abnormal):

                aug_audio = augment_audio(audio.copy(), fs)
                aug_name = f"{basename}_aug{k}"

                logmel_aug = LogMelExtractor(
                    aug_audio, fs,
                    mel_bins=mel_bins,
                    hoplen=hoplen,
                    winlen=winlen
                )

                mfcc_aug = MfccExtractor(
                    aug_audio, fs,
                    n_mfcc=n_mfcc,
                    hoplen=hoplen,
                    winlen=winlen,
                    T_fixed=T_fixed
                )

                np.save(logmel_folder / f"{aug_name}.npy", logmel_aug)
                np.save(mfcc_folder   / f"{aug_name}.npy", mfcc_aug)

    print("\n✅ Feature extraction + augmentation completed.")
# Out:
# === ORIGINAL DISTRIBUTION ===
# Normal  : 2575
# Abnormal: 665
# Augment per abnormal sample: 3
# 100%|██████████| 3240/3240 [52:47<00:00,  1.02it/s]
# ✅ Feature extraction + augmentation completed.

# %%
logmel_folder = PROJECT_PATH / "logmel_features"
mfcc_folder   = PROJECT_PATH / "mfcc_features"

label_counts = Counter(df["label"])
n_normal   = label_counts[0]
n_abnormal = label_counts[1]

target_abnormal = n_normal
augment_per_abnormal = int(
    np.ceil((target_abnormal - n_abnormal) / n_abnormal)
)

# %%
aug_rows = []

for _, row in df.iterrows():
    if row["label"] == 1:
        base = Path(row["filename"]).stem
        for k in range(augment_per_abnormal):
            aug_rows.append({
                "filename": f"{base}_aug{k}",  # hoặc .npy tùy Dataset loader
                "label": 1
            })

df_balanced = pd.concat([df, pd.DataFrame(aug_rows)], ignore_index=True)
df_balanced.to_csv(PROJECT_PATH / "data" / "label_balanced.csv", index=False)

# %% [markdown]
# # Test file

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from pathlib import Path

# Root dataset PhysioNet 2016
original_audio_root = Path("/content/drive/MyDrive/physionet2016")

logmel_folder = Path(logmel_folder)
mfcc_folder   = Path(mfcc_folder)

# %% [markdown]
# ## Normal

# %%
# ========================
# NORMAL SAMPLE
# ========================

normal_file = Path(normal_file)          # ví dụ: a0007.wav
normal_basename = normal_file.stem        # a0007
folder_letter = normal_basename[0]

wav_path = original_audio_root / f"training-{folder_letter}" / normal_file.name
print(f"[NORMAL] Audio path: {wav_path}")

# 1. Load raw audio
audio_norm, sr = librosa.load(wav_path, sr=None)
print(f"[NORMAL] Length: {len(audio_norm)} | Duration: {len(audio_norm)/sr:.2f}s | SR: {sr}")

# 2. Load Log-Mel
logmel_norm = np.load(logmel_folder / f"{normal_basename}.npy")
print(f"[NORMAL] LogMel shape: {logmel_norm.shape}")

# 3. Load MFCC
mfcc_norm = np.load(mfcc_folder / f"{normal_basename}.npy")
print(f"[NORMAL] MFCC shape: {mfcc_norm.shape}")

# 4. Visualization
plt.figure(figsize=(14, 8))

plt.subplot(3, 1, 1)
librosa.display.waveshow(audio_norm, sr=sr)
plt.title("Normal PCG – Waveform")

plt.subplot(3, 1, 2)
librosa.display.specshow(
    logmel_norm,
    sr=sr,
    hop_length=int(sr * 15 / 1000),
    x_axis='time',
    y_axis='mel',
    cmap='viridis'
)
plt.colorbar(format='%+2.0f dB')
plt.title("Normal PCG – Log Mel Spectrogram")

plt.subplot(3, 1, 3)
librosa.display.specshow(
    mfcc_norm,
    sr=sr,
    hop_length=int(sr * 15 / 1000),
    x_axis='time',
    cmap='viridis'
)
plt.colorbar()
plt.title("Normal PCG – MFCC")

plt.tight_layout()
plt.show()
# Out:
# [NORMAL] Audio path: /content/drive/MyDrive/physionet2016/training-a/a0007.wav
# [NORMAL] Length: 71332 | Duration: 35.67s | SR: 2000
# [NORMAL] LogMel shape: (128, 2378)
# [NORMAL] MFCC shape: (39, 333)

# %% [markdown]
# ## Abnormal

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from pathlib import Path

# ========================
# ABNORMAL SAMPLE (RAW + AUGMENTED)
# ========================

abnormal_file = Path(abnormal_file)          # ví dụ: a0077.wav hoặc a0001.wav
abnormal_basename = abnormal_file.stem        # a0077
folder_letter = abnormal_basename[0]

wav_path = original_audio_root / f"training-{folder_letter}" / abnormal_file.name
print(f"[ABNORMAL] Audio path: {wav_path}")

# 1. Load raw abnormal audio
audio_abn, sr = librosa.load(wav_path, sr=None)
print(f"[ABNORMAL] Length: {len(audio_abn)} | Duration: {len(audio_abn)/sr:.2f}s | SR: {sr}")

# 2. Load original features
logmel_abn = np.load(logmel_folder / f"{abnormal_basename}.npy")
mfcc_abn   = np.load(mfcc_folder / f"{abnormal_basename}.npy")

print(f"[ABNORMAL] LogMel original shape: {logmel_abn.shape}")
print(f"[ABNORMAL] MFCC original shape : {mfcc_abn.shape}")

# 3. Load augmented features (aug0, aug1, aug2)
aug_logmels = []
aug_mfccs   = []

for i in range(3):
    aug_name = f"{abnormal_basename}_aug{i}.npy"

    logmel_aug = np.load(logmel_folder / aug_name)
    mfcc_aug   = np.load(mfcc_folder / aug_name)

    aug_logmels.append(logmel_aug)
    aug_mfccs.append(mfcc_aug)

    print(f"[ABNORMAL] Loaded {aug_name} | LogMel shape: {logmel_aug.shape}")

# ========================
# Visualization
# ========================

plt.figure(figsize=(15, 12))

# (1) Waveform (raw)
plt.subplot(4, 1, 1)
librosa.display.waveshow(audio_abn, sr=sr, color="red")
plt.title("Abnormal PCG – Raw waveform")

# (2) Log-Mel original
plt.subplot(4, 1, 2)
librosa.display.specshow(
    logmel_abn,
    sr=sr,
    hop_length=int(sr * 15 / 1000),
    x_axis="time",
    y_axis="mel",
    cmap="viridis"
)
plt.colorbar(format="%+2.0f dB")
plt.title("Abnormal PCG – Log-Mel (Original)")

# (3) Log-Mel augmented (3 mẫu)
plt.subplot(4, 1, 3)
librosa.display.specshow(
    aug_logmels[0],
    sr=sr,
    hop_length=int(sr * 15 / 1000),
    x_axis="time",
    y_axis="mel",
    cmap="viridis"
)
plt.colorbar(format="%+2.0f dB")
plt.title("Abnormal PCG – Log-Mel (Augmented: aug0 / aug1 / aug2 tương tự)")

# (4) MFCC augmented (ví dụ aug1)
plt.subplot(4, 1, 4)
librosa.display.specshow(
    aug_mfccs[1],
    sr=sr,
    hop_length=int(sr * 15 / 1000),
    x_axis="time",
    cmap="viridis"
)
plt.colorbar()
plt.title("Abnormal PCG – MFCC (Augmented, aug1)")

plt.tight_layout()
plt.show()
# Out:
# [ABNORMAL] Audio path: /content/drive/MyDrive/physionet2016/training-a/a0001.wav
# [ABNORMAL] Length: 71332 | Duration: 35.67s | SR: 2000
# [ABNORMAL] LogMel original shape: (128, 2378)
# [ABNORMAL] MFCC original shape : (39, 333)
# [ABNORMAL] Loaded a0001_aug0.npy | LogMel shape: (128, 2378)
# [ABNORMAL] Loaded a0001_aug1.npy | LogMel shape: (128, 2378)
# [ABNORMAL] Loaded a0001_aug2.npy | LogMel shape: (128, 2378)

# %% [markdown]
# ## Create .h5py for MFCC

# %%
# ==============================
# MERGE MFCC .npy → HDF5
# ==============================
import numpy as np
import h5py
from pathlib import Path
from tqdm.notebook import tqdm

MFCC_DIR = PROJECT_PATH / "mfcc_features"          # Thư mục chứa MFCC .npy
OUTPUT_H5 = PROJECT_PATH / "data" / "mfcc_features.h5"

if OUTPUT_H5.exists():
    print(f"File {OUTPUT_H5} đã tồn tại – bỏ qua.")
else:
    npy_files = sorted(MFCC_DIR.glob("*.npy"))
    print(f"🔎 Found {len(npy_files)} MFCC files")

    with h5py.File(OUTPUT_H5, "w") as f_out:
        for npy_file in tqdm(npy_files, desc="Converting MFCC"):
            key = npy_file.stem
            data = np.load(npy_file)

            # MFCC chuẩn: (n_mfcc, time)
            assert data.ndim == 2, f"{key} invalid shape {data.shape}"

            f_out.create_dataset(
                key,
                data=data.astype(np.float32),
                compression="gzip"
            )

    print(f"✅ MFCC HDF5 created: {OUTPUT_H5}")
# Out:
# 🔎 Found 5235 MFCC files
# Converting MFCC:   0%|          | 0/5235 [00:00<?, ?it/s]
# ✅ MFCC HDF5 created: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/mfcc_features.h5

# %%
# ==============================
# INSPECT MFCC HDF5
# ==============================
import h5py

h5_path = str(PROJECT_PATH / "data" / "mfcc_features.h5")

with h5py.File(h5_path, "r") as f:
    print(f"Total samples: {len(f.keys())}\n")
    for i, key in enumerate(f.keys()):
        print(f"[DATASET] {key}, shape={f[key].shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [DATASET] a0075_aug1, shape=(39, 333)
# [DATASET] a0075_aug2, shape=(39, 333)
# [DATASET] a0076, shape=(39, 333)
# [DATASET] a0076_aug0, shape=(39, 333)
# [DATASET] a0076_aug1, shape=(39, 333)
# [DATASET] a0076_aug2, shape=(39, 333)
# [DATASET] a0077, shape=(39, 333)
# [DATASET] a0077_aug0, shape=(39, 333)
# [DATASET] a0077_aug1, shape=(39, 333)
# [DATASET] a0077_aug2, shape=(39, 333)
# [DATASET] a0078, shape=(39, 333)
# [DATASET] a0078_aug0, shape=(39, 333)
# [DATASET] a0078_aug1, shape=(39, 333)
# [DATASET] a0078_aug2, shape=(39, 333)
# [DATASET] a0079, shape=(39, 333)
# [DATASET] a0079_aug0, shape=(39, 333)
# [DATASET] a0079_aug1, shape=(39, 333)
# [DATASET] a0079_aug2, shape=(39, 333)
# [DATASET] a0080, shape=(39, 333)
# [DATASET] a0081, shape=(39, 333)
# [DATASET] a0082, shape=(39, 333)
# [DATASET] a0082_aug0, shape=(39, 333)
# [DATASET] a0082_aug1, shape=(39, 333)
# [DATASET] a0082_aug2, shape=(39, 333)
# [DATASET] a0083, shape=(39, 333)
# [DATASET] a0083_aug0, shape=(39, 333)
# [DATASET] a0083_aug1, shape=(39, 333)
# [DATASET] a0083_aug2, shape=(39, 333)
# [DATASET] a0084, shape=(39, 333)
# [DATASET] a0084_aug0, shape=(39, 333)
# [DATASET] a0084_aug1, shape=(39, 333)
# [DATASET] a0084_aug2, shape=(39, 333)
# [DATASET] a0085, shape=(39, 333)
# [DATASET] a0086, shape=(39, 333)
# [DATASET] a0087, shape=(39, 333)
# [DATASET] a0087_aug0, shape=(39, 333)
# [DATASET] a0087_aug1, shape=(39, 333)
# [DATASET] a0087_aug2, shape=(39, 333)
# [DATASET] a0088, shape=(39, 333)
# [DATASET] a0089, shape=(39, 333)
# [DATASET] a0089_aug0, shape=(39, 333)
# [DATASET] a0089_aug1, shape=(39, 333)
# [DATASET] a0089_aug2, shape=(39, 333)
# [DATASET] a0090, shape=(39, 333)
# [DATASET] a0090_aug0, shape=(39, 333)
# [DATASET] a0090_aug1, shape=(39, 333)
# [DATASET] a0090_aug2, shape=(39, 333)
# [DATASET] a0091, shape=(39, 333)
# [DATASET] a0092, shape=(39, 333)
# [DATASET] a0092_aug0, shape=(39, 333)
# [DATASET] a0092_aug1, shape=(39, 333)
# [DATASET] a0092_aug2, shape=(39, 333)
# [DATASET] a0093, shape=(39, 333)
# [DATASET] a0094, shape=(39, 333)
# [DATASET] a0095, shape=(39, 333)
# [DATASET] a0095_aug0, shape=(39, 333)
# [DATASET] a0095_aug1, shape=(39, 333)
# [DATASET] a0095_aug2, shape=(39, 333)
# [DATASET] a0096, shape=(39, 333)
# [DATASET] a0096_aug0, shape=(39, 333)
# [DATASET] a0096_aug1, shape=(39, 333)
# [DATASET] a0096_aug2, shape=(39, 333)
# [DATASET] a0097, shape=(39, 333)
# [DATASET] a0097_aug0, shape=(39, 333)
# [DATASET] a0097_aug1, shape=(39, 333)
# [DATASET] a0097_aug2, shape=(39, 333)
# [DATASET] a0098, shape=(39, 333)
# [DATASET] a0098_aug0, shape=(39, 333)
# [DATASET] a0098_aug1, shape=(39, 333)
# [DATASET] a0098_aug2, shape=(39, 333)
# [DATASET] a0099, shape=(39, 333)
# [DATASET] a0099_aug0, shape=(39, 333)
# [DATASET] a0099_aug1, shape=(39, 333)
# [DATASET] a0099_aug2, shape=(39, 333)
# [DATASET] a0100, shape=(39, 333)
# [DATASET] a0100_aug0, shape=(39, 333)
# [DATASET] a0100_aug1, shape=(39, 333)
# [DATASET] a0100_aug2, shape=(39, 333)
# [DATASET] a0101, shape=(39, 333)
# [DATASET] a0101_aug0, shape=(39, 333)
# [DATASET] a0101_aug1, shape=(39, 333)
# [DATASET] a0101_aug2, shape=(39, 333)
# [DATASET] a0102, shape=(39, 333)
# [DATASET] a0103, shape=(39, 333)
# [DATASET] a0103_aug0, shape=(39, 333)
# [DATASET] a0103_aug1, shape=(39, 333)
# [DATASET] a0103_aug2, shape=(39, 333)
# [DATASET] a0104, shape=(39, 333)
# [DATASET] a0104_aug0, shape=(39, 333)
# [DATASET] a0104_aug1, shape=(39, 333)
# [DATASET] a0104_aug2, shape=(39, 333)
# [DATASET] a0105, shape=(39, 333)
# [DATASET] a0106, shape=(39, 333)
# [DATASET] a0107, shape=(39, 333)
# [DATASET] a0107_aug0, shape=(39, 333)
# [DATASET] a0107_aug1, shape=(39, 333)
# [DATASET] a0107_aug2, shape=(39, 333)
# [DATASET] a0108, shape=(39, 333)
# [DATASET] a0109, shape=(39, 333)
# [DATASET] a0110, shape=(39, 333)
# [DATASET] a0110_aug0, shape=(39, 333)
# [DATASET] a0110_aug1, shape=(39, 333)
# [DATASET] a0110_aug2, shape=(39, 333)
# [DATASET] a0111, shape=(39, 333)
# [DATASET] a0111_aug0, shape=(39, 333)
# [DATASET] a0111_aug1, shape=(39, 333)
# [DATASET] a0111_aug2, shape=(39, 333)
# [DATASET] a0112, shape=(39, 333)
# [DATASET] a0112_aug0, shape=(39, 333)
# [DATASET] a0112_aug1, shape=(39, 333)
# [DATASET] a0112_aug2, shape=(39, 333)
# [DATASET] a0113, shape=(39, 333)
# [DATASET] a0113_aug0, shape=(39, 333)
# [DATASET] a0113_aug1, shape=(39, 333)
# [DATASET] a0113_aug2, shape=(39, 333)
# [DATASET] a0114, shape=(39, 333)
# [DATASET] a0114_aug0, shape=(39, 333)
# [DATASET] a0114_aug1, shape=(39, 333)
# [DATASET] a0114_aug2, shape=(39, 333)
# [DATASET] a0115, shape=(39, 333)
# [DATASET] a0115_aug0, shape=(39, 333)
# [DATASET] a0115_aug1, shape=(39, 333)
# [DATASET] a0115_aug2, shape=(39, 333)
# [DATASET] a0116, shape=(39, 333)
# [DATASET] a0116_aug0, shape=(39, 333)
# [DATASET] a0116_aug1, shape=(39, 333)
# [DATASET] a0116_aug2, shape=(39, 333)
# [DATASET] a0117, shape=(39, 333)
# [DATASET] a0117_aug0, shape=(39, 333)
# [DATASET] a0117_aug1, shape=(39, 333)
# [DATASET] a0117_aug2, shape=(39, 333)
# [DATASET] a0118, shape=(39, 333)
# [DATASET] a0119, shape=(39, 333)
# [DATASET] a0119_aug0, shape=(39, 333)
# [DATASET] a0119_aug1, shape=(39, 333)
# [DATASET] a0119_aug2, shape=(39, 333)
# [DATASET] a0120, shape=(39, 333)
# [DATASET] a0120_aug0, shape=(39, 333)
# [DATASET] a0120_aug1, shape=(39, 333)
# [DATASET] a0120_aug2, shape=(39, 333)
# [DATASET] a0121, shape=(39, 333)
# [DATASET] a0121_aug0, shape=(39, 333)
# [DATASET] a0121_aug1, shape=(39, 333)
# [DATASET] a0121_aug2, shape=(39, 333)
# [DATASET] a0122, shape=(39, 333)
# [DATASET] a0122_aug0, shape=(39, 333)
# [DATASET] a0122_aug1, shape=(39, 333)
# [DATASET] a0122_aug2, shape=(39, 333)
# [DATASET] a0123, shape=(39, 333)
# [DATASET] a0123_aug0, shape=(39, 333)
# [DATASET] a0123_aug1, shape=(39, 333)
# [DATASET] a0123_aug2, shape=(39, 333)
# [DATASET] a0124, shape=(39, 333)
# [DATASET] a0124_aug0, shape=(39, 333)
# [DATASET] a0124_aug1, shape=(39, 333)
# [DATASET] a0124_aug2, shape=(39, 333)
# [DATASET] a0125, shape=(39, 333)
# [DATASET] a0126, shape=(39, 333)
# [DATASET] a0126_aug0, shape=(39, 333)
# [DATASET] a0126_aug1, shape=(39, 333)
# [DATASET] a0126_aug2, shape=(39, 333)
# [DATASET] a0127, shape=(39, 333)
# [DATASET] a0128, shape=(39, 333)
# [DATASET] a0128_aug0, shape=(39, 333)
# [DATASET] a0128_aug1, shape=(39, 333)
# [DATASET] a0128_aug2, shape=(39, 333)
# [DATASET] a0129, shape=(39, 333)
# [DATASET] a0130, shape=(39, 333)
# [DATASET] a0130_aug0, shape=(39, 333)
# [DATASET] a0130_aug1, shape=(39, 333)
# [DATASET] a0130_aug2, shape=(39, 333)
# [DATASET] a0131, shape=(39, 333)
# [DATASET] a0131_aug0, shape=(39, 333)
# [DATASET] a0131_aug1, shape=(39, 333)
# [DATASET] a0131_aug2, shape=(39, 333)
# [DATASET] a0132, shape=(39, 333)
# [DATASET] a0132_aug0, shape=(39, 333)
# [DATASET] a0132_aug1, shape=(39, 333)
# [DATASET] a0132_aug2, shape=(39, 333)
# [DATASET] a0133, shape=(39, 333)
# [DATASET] a0133_aug0, shape=(39, 333)
# [DATASET] a0133_aug1, shape=(39, 333)
# [DATASET] a0133_aug2, shape=(39, 333)
# [DATASET] a0134, shape=(39, 333)
# [DATASET] a0134_aug0, shape=(39, 333)
# [DATASET] a0134_aug1, shape=(39, 333)
# [DATASET] a0134_aug2, shape=(39, 333)
# [DATASET] a0135, shape=(39, 333)
# [DATASET] a0135_aug0, shape=(39, 333)
# [DATASET] a0135_aug1, shape=(39, 333)
# [DATASET] a0135_aug2, shape=(39, 333)
# [DATASET] a0136, shape=(39, 333)
# [DATASET] a0137, shape=(39, 333)
# [DATASET] a0137_aug0, shape=(39, 333)
# [DATASET] a0137_aug1, shape=(39, 333)
# [DATASET] a0137_aug2, shape=(39, 333)
# [DATASET] a0138, shape=(39, 333)
# [DATASET] a0138_aug0, shape=(39, 333)
# [DATASET] a0138_aug1, shape=(39, 333)
# [DATASET] a0138_aug2, shape=(39, 333)
# [DATASET] a0139, shape=(39, 333)
# [DATASET] a0140, shape=(39, 333)
# [DATASET] a0141, shape=(39, 333)
# [DATASET] a0142, shape=(39, 333)
# [DATASET] a0142_aug0, shape=(39, 333)
# [DATASET] a0142_aug1, shape=(39, 333)
# [DATASET] a0142_aug2, shape=(39, 333)
# [DATASET] a0143, shape=(39, 333)
# [DATASET] a0143_aug0, shape=(39, 333)
# [DATASET] a0143_aug1, shape=(39, 333)
# [DATASET] a0143_aug2, shape=(39, 333)
# [DATASET] a0144, shape=(39, 333)
# [DATASET] a0144_aug0, shape=(39, 333)
# [DATASET] a0144_aug1, shape=(39, 333)
# [DATASET] a0144_aug2, shape=(39, 333)
# [DATASET] a0145, shape=(39, 333)
# [DATASET] a0145_aug0, shape=(39, 333)
# [DATASET] a0145_aug1, shape=(39, 333)
# [DATASET] a0145_aug2, shape=(39, 333)
# [DATASET] a0146, shape=(39, 333)
# [DATASET] a0146_aug0, shape=(39, 333)
# [DATASET] a0146_aug1, shape=(39, 333)
# [DATASET] a0146_aug2, shape=(39, 333)
# [DATASET] a0147, shape=(39, 333)
# [DATASET] a0147_aug0, shape=(39, 333)
# [DATASET] a0147_aug1, shape=(39, 333)
# [DATASET] a0147_aug2, shape=(39, 333)
# [DATASET] a0148, shape=(39, 333)
# [DATASET] a0148_aug0, shape=(39, 333)
# [DATASET] a0148_aug1, shape=(39, 333)
# [DATASET] a0148_aug2, shape=(39, 333)
# [DATASET] a0149, shape=(39, 333)
# [DATASET] a0149_aug0, shape=(39, 333)
# [DATASET] a0149_aug1, shape=(39, 333)
# [DATASET] a0149_aug2, shape=(39, 333)
# [DATASET] a0150, shape=(39, 333)
# [DATASET] a0150_aug0, shape=(39, 333)
# [DATASET] a0150_aug1, shape=(39, 333)
# [DATASET] a0150_aug2, shape=(39, 333)
# [DATASET] a0151, shape=(39, 333)
# [DATASET] a0151_aug0, shape=(39, 333)
# [DATASET] a0151_aug1, shape=(39, 333)
# [DATASET] a0151_aug2, shape=(39, 333)
# [DATASET] a0152, shape=(39, 333)
# [DATASET] a0152_aug0, shape=(39, 333)
# [DATASET] a0152_aug1, shape=(39, 333)
# [DATASET] a0152_aug2, shape=(39, 333)
# [DATASET] a0153, shape=(39, 333)
# [DATASET] a0154, shape=(39, 333)
# [DATASET] a0155, shape=(39, 333)
# [DATASET] a0156, shape=(39, 333)
# [DATASET] a0156_aug0, shape=(39, 333)
# [DATASET] a0156_aug1, shape=(39, 333)
# [DATASET] a0156_aug2, shape=(39, 333)
# [DATASET] a0157, shape=(39, 333)
# [DATASET] a0157_aug0, shape=(39, 333)
# [DATASET] a0157_aug1, shape=(39, 333)
# [DATASET] a0157_aug2, shape=(39, 333)
# [DATASET] a0158, shape=(39, 333)
# [DATASET] a0158_aug0, shape=(39, 333)
# [DATASET] a0158_aug1, shape=(39, 333)
# [DATASET] a0158_aug2, shape=(39, 333)
# [DATASET] a0159, shape=(39, 333)
# [DATASET] a0159_aug0, shape=(39, 333)
# [DATASET] a0159_aug1, shape=(39, 333)
# [DATASET] a0159_aug2, shape=(39, 333)
# [DATASET] a0160, shape=(39, 333)
# [DATASET] a0160_aug0, shape=(39, 333)
# [DATASET] a0160_aug1, shape=(39, 333)
# [DATASET] a0160_aug2, shape=(39, 333)
# [DATASET] a0161, shape=(39, 333)
# [DATASET] a0162, shape=(39, 333)
# [DATASET] a0162_aug0, shape=(39, 333)
# [DATASET] a0162_aug1, shape=(39, 333)
# [DATASET] a0162_aug2, shape=(39, 333)
# [DATASET] a0163, shape=(39, 333)
# [DATASET] a0163_aug0, shape=(39, 333)
# [DATASET] a0163_aug1, shape=(39, 333)
# [DATASET] a0163_aug2, shape=(39, 333)
# [DATASET] a0164, shape=(39, 333)
# [DATASET] a0164_aug0, shape=(39, 333)
# [DATASET] a0164_aug1, shape=(39, 333)
# [DATASET] a0164_aug2, shape=(39, 333)
# [DATASET] a0165, shape=(39, 333)
# [DATASET] a0166, shape=(39, 333)
# [DATASET] a0166_aug0, shape=(39, 333)
# [DATASET] a0166_aug1, shape=(39, 333)
# [DATASET] a0166_aug2, shape=(39, 333)
# [DATASET] a0167, shape=(39, 333)
# [DATASET] a0167_aug0, shape=(39, 333)
# [DATASET] a0167_aug1, shape=(39, 333)
# [DATASET] a0167_aug2, shape=(39, 333)
# [DATASET] a0168, shape=(39, 333)
# [DATASET] a0168_aug0, shape=(39, 333)
# [DATASET] a0168_aug1, shape=(39, 333)
# [DATASET] a0168_aug2, shape=(39, 333)
# [DATASET] a0169, shape=(39, 333)
# [DATASET] a0169_aug0, shape=(39, 333)
# [DATASET] a0169_aug1, shape=(39, 333)
# [DATASET] a0169_aug2, shape=(39, 333)
# [DATASET] a0170, shape=(39, 333)
# [DATASET] a0170_aug0, shape=(39, 333)
# [DATASET] a0170_aug1, shape=(39, 333)
# [DATASET] a0170_aug2, shape=(39, 333)
# [DATASET] a0171, shape=(39, 333)
# [DATASET] a0172, shape=(39, 333)
# [DATASET] a0172_aug0, shape=(39, 333)
# [DATASET] a0172_aug1, shape=(39, 333)
# [DATASET] a0172_aug2, shape=(39, 333)
# [DATASET] a0173, shape=(39, 333)
# [DATASET] a0173_aug0, shape=(39, 333)
# [DATASET] a0173_aug1, shape=(39, 333)
# [DATASET] a0173_aug2, shape=(39, 333)
# [DATASET] a0174, shape=(39, 333)
# [DATASET] a0174_aug0, shape=(39, 333)
# [DATASET] a0174_aug1, shape=(39, 333)
# [DATASET] a0174_aug2, shape=(39, 333)
# [DATASET] a0175, shape=(39, 333)
# [DATASET] a0175_aug0, shape=(39, 333)
# [DATASET] a0175_aug1, shape=(39, 333)
# [DATASET] a0175_aug2, shape=(39, 333)
# [DATASET] a0176, shape=(39, 333)
# [DATASET] a0176_aug0, shape=(39, 333)
# [DATASET] a0176_aug1, shape=(39, 333)
# [DATASET] a0176_aug2, shape=(39, 333)
# [DATASET] a0177, shape=(39, 333)
# [DATASET] a0177_aug0, shape=(39, 333)
# [DATASET] a0177_aug1, shape=(39, 333)
# [DATASET] a0177_aug2, shape=(39, 333)
# [DATASET] a0178, shape=(39, 333)
# [DATASET] a0179, shape=(39, 333)
# [DATASET] a0180, shape=(39, 333)
# [DATASET] a0180_aug0, shape=(39, 333)
# [DATASET] a0180_aug1, shape=(39, 333)
# [DATASET] a0180_aug2, shape=(39, 333)
# [DATASET] a0181, shape=(39, 333)
# [DATASET] a0182, shape=(39, 333)
# [DATASET] a0182_aug0, shape=(39, 333)
# [DATASET] a0182_aug1, shape=(39, 333)
# [DATASET] a0182_aug2, shape=(39, 333)
# [DATASET] a0183, shape=(39, 333)
# [DATASET] a0183_aug0, shape=(39, 333)
# [DATASET] a0183_aug1, shape=(39, 333)
# [DATASET] a0183_aug2, shape=(39, 333)
# [DATASET] a0184, shape=(39, 333)
# [DATASET] a0185, shape=(39, 333)
# [DATASET] a0186, shape=(39, 333)
# [DATASET] a0186_aug0, shape=(39, 333)
# [DATASET] a0186_aug1, shape=(39, 333)
# [DATASET] a0186_aug2, shape=(39, 333)
# [DATASET] a0187, shape=(39, 333)
# [DATASET] a0187_aug0, shape=(39, 333)
# [DATASET] a0187_aug1, shape=(39, 333)
# [DATASET] a0187_aug2, shape=(39, 333)
# [DATASET] a0188, shape=(39, 333)
# [DATASET] a0188_aug0, shape=(39, 333)
# [DATASET] a0188_aug1, shape=(39, 333)
# [DATASET] a0188_aug2, shape=(39, 333)
# [DATASET] a0189, shape=(39, 333)
# [DATASET] a0190, shape=(39, 333)
# [DATASET] a0190_aug0, shape=(39, 333)
# [DATASET] a0190_aug1, shape=(39, 333)
# [DATASET] a0190_aug2, shape=(39, 333)
# [DATASET] a0191, shape=(39, 333)
# [DATASET] a0191_aug0, shape=(39, 333)
# [DATASET] a0191_aug1, shape=(39, 333)
# [DATASET] a0191_aug2, shape=(39, 333)
# [DATASET] a0192, shape=(39, 333)
# [DATASET] a0192_aug0, shape=(39, 333)
# [DATASET] a0192_aug1, shape=(39, 333)
# [DATASET] a0192_aug2, shape=(39, 333)
# [DATASET] a0193, shape=(39, 333)
# [DATASET] a0194, shape=(39, 333)
# [DATASET] a0194_aug0, shape=(39, 333)
# [DATASET] a0194_aug1, shape=(39, 333)
# [DATASET] a0194_aug2, shape=(39, 333)
# [DATASET] a0195, shape=(39, 333)
# [DATASET] a0196, shape=(39, 333)
# [DATASET] a0197, shape=(39, 333)
# [DATASET] a0197_aug0, shape=(39, 333)
# [DATASET] a0197_aug1, shape=(39, 333)
# [DATASET] a0197_aug2, shape=(39, 333)
# [DATASET] a0198, shape=(39, 333)
# [DATASET] a0198_aug0, shape=(39, 333)
# [DATASET] a0198_aug1, shape=(39, 333)
# [DATASET] a0198_aug2, shape=(39, 333)
# [DATASET] a0199, shape=(39, 333)
# [DATASET] a0200, shape=(39, 333)
# [DATASET] a0200_aug0, shape=(39, 333)
# [DATASET] a0200_aug1, shape=(39, 333)
# [DATASET] a0200_aug2, shape=(39, 333)
# [DATASET] a0201, shape=(39, 333)
# [DATASET] a0201_aug0, shape=(39, 333)
# [DATASET] a0201_aug1, shape=(39, 333)
# [DATASET] a0201_aug2, shape=(39, 333)
# [DATASET] a0202, shape=(39, 333)
# [DATASET] a0202_aug0, shape=(39, 333)
# [DATASET] a0202_aug1, shape=(39, 333)
# [DATASET] a0202_aug2, shape=(39, 333)
# [DATASET] a0203, shape=(39, 333)
# [DATASET] a0203_aug0, shape=(39, 333)
# [DATASET] a0203_aug1, shape=(39, 333)
# [DATASET] a0203_aug2, shape=(39, 333)
# [DATASET] a0204, shape=(39, 333)
# [DATASET] a0205, shape=(39, 333)
# [DATASET] a0205_aug0, shape=(39, 333)
# [DATASET] a0205_aug1, shape=(39, 333)
# [DATASET] a0205_aug2, shape=(39, 333)
# [DATASET] a0206, shape=(39, 333)
# [DATASET] a0206_aug0, shape=(39, 333)
# [DATASET] a0206_aug1, shape=(39, 333)
# [DATASET] a0206_aug2, shape=(39, 333)
# [DATASET] a0207, shape=(39, 333)
# [DATASET] a0207_aug0, shape=(39, 333)
# [DATASET] a0207_aug1, shape=(39, 333)
# [DATASET] a0207_aug2, shape=(39, 333)
# [DATASET] a0208, shape=(39, 333)
# [DATASET] a0209, shape=(39, 333)
# [DATASET] a0209_aug0, shape=(39, 333)
# [DATASET] a0209_aug1, shape=(39, 333)
# [DATASET] a0209_aug2, shape=(39, 333)
# [DATASET] a0210, shape=(39, 333)
# [DATASET] a0211, shape=(39, 333)
# [DATASET] a0212, shape=(39, 333)
# [DATASET] a0213, shape=(39, 333)
# [DATASET] a0213_aug0, shape=(39, 333)
# [DATASET] a0213_aug1, shape=(39, 333)
# [DATASET] a0213_aug2, shape=(39, 333)
# [DATASET] a0214, shape=(39, 333)
# [DATASET] a0214_aug0, shape=(39, 333)
# [DATASET] a0214_aug1, shape=(39, 333)
# [DATASET] a0214_aug2, shape=(39, 333)
# [DATASET] a0215, shape=(39, 333)
# [DATASET] a0215_aug0, shape=(39, 333)
# [DATASET] a0215_aug1, shape=(39, 333)
# [DATASET] a0215_aug2, shape=(39, 333)
# [DATASET] a0216, shape=(39, 333)
# [DATASET] a0216_aug0, shape=(39, 333)
# [DATASET] a0216_aug1, shape=(39, 333)
# [DATASET] a0216_aug2, shape=(39, 333)
# [DATASET] a0217, shape=(39, 333)
# [DATASET] a0217_aug0, shape=(39, 333)
# [DATASET] a0217_aug1, shape=(39, 333)
# [DATASET] a0217_aug2, shape=(39, 333)
# [DATASET] a0218, shape=(39, 333)
# [DATASET] a0218_aug0, shape=(39, 333)
# [DATASET] a0218_aug1, shape=(39, 333)
# [DATASET] a0218_aug2, shape=(39, 333)
# [DATASET] a0219, shape=(39, 333)
# [DATASET] a0219_aug0, shape=(39, 333)
# [DATASET] a0219_aug1, shape=(39, 333)
# [DATASET] a0219_aug2, shape=(39, 333)
# [DATASET] a0220, shape=(39, 333)
# [DATASET] a0220_aug0, shape=(39, 333)
# [DATASET] a0220_aug1, shape=(39, 333)
# [DATASET] a0220_aug2, shape=(39, 333)
# [DATASET] a0221, shape=(39, 333)
# [DATASET] a0221_aug0, shape=(39, 333)
# [DATASET] a0221_aug1, shape=(39, 333)
# [DATASET] a0221_aug2, shape=(39, 333)
# [DATASET] a0222, shape=(39, 333)
# [DATASET] a0222_aug0, shape=(39, 333)
# [DATASET] a0222_aug1, shape=(39, 333)
# [DATASET] a0222_aug2, shape=(39, 333)
# [DATASET] a0223, shape=(39, 333)
# [DATASET] a0223_aug0, shape=(39, 333)
# [DATASET] a0223_aug1, shape=(39, 333)
# [DATASET] a0223_aug2, shape=(39, 333)
# [DATASET] a0224, shape=(39, 333)
# [DATASET] a0224_aug0, shape=(39, 333)
# [DATASET] a0224_aug1, shape=(39, 333)
# [DATASET] a0224_aug2, shape=(39, 333)
# [DATASET] a0225, shape=(39, 333)
# [DATASET] a0225_aug0, shape=(39, 333)
# [DATASET] a0225_aug1, shape=(39, 333)
# [DATASET] a0225_aug2, shape=(39, 333)
# [DATASET] a0226, shape=(39, 333)
# [DATASET] a0226_aug0, shape=(39, 333)
# [DATASET] a0226_aug1, shape=(39, 333)
# [DATASET] a0226_aug2, shape=(39, 333)
# [DATASET] a0227, shape=(39, 333)
# [DATASET] a0228, shape=(39, 333)
# [DATASET] a0228_aug0, shape=(39, 333)
# [DATASET] a0228_aug1, shape=(39, 333)
# [DATASET] a0228_aug2, shape=(39, 333)
# [DATASET] a0229, shape=(39, 333)
# [DATASET] a0230, shape=(39, 333)
# [DATASET] a0230_aug0, shape=(39, 333)
# [DATASET] a0230_aug1, shape=(39, 333)
# [DATASET] a0230_aug2, shape=(39, 333)
# [DATASET] a0231, shape=(39, 333)
# [DATASET] a0232, shape=(39, 333)
# [DATASET] a0232_aug0, shape=(39, 333)
# [DATASET] a0232_aug1, shape=(39, 333)
# [DATASET] a0232_aug2, shape=(39, 333)
# [DATASET] a0233, shape=(39, 333)
# [DATASET] a0233_aug0, shape=(39, 333)
# [DATASET] a0233_aug1, shape=(39, 333)
# [DATASET] a0233_aug2, shape=(39, 333)
# [DATASET] a0234, shape=(39, 333)
# [DATASET] a0234_aug0, shape=(39, 333)
# [DATASET] a0234_aug1, shape=(39, 333)
# [DATASET] a0234_aug2, shape=(39, 333)
# [DATASET] a0235, shape=(39, 333)
# [DATASET] a0236, shape=(39, 333)
# [DATASET] a0236_aug0, shape=(39, 333)
# [DATASET] a0236_aug1, shape=(39, 333)
# [DATASET] a0236_aug2, shape=(39, 333)
# [DATASET] a0237, shape=(39, 333)
# [DATASET] a0237_aug0, shape=(39, 333)
# [DATASET] a0237_aug1, shape=(39, 333)
# [DATASET] a0237_aug2, shape=(39, 333)
# [DATASET] a0238, shape=(39, 333)
# [DATASET] a0239, shape=(39, 333)
# [DATASET] a0239_aug0, shape=(39, 333)
# [DATASET] a0239_aug1, shape=(39, 333)
# [DATASET] a0239_aug2, shape=(39, 333)
# [DATASET] a0240, shape=(39, 333)
# [DATASET] a0240_aug0, shape=(39, 333)
# [DATASET] a0240_aug1, shape=(39, 333)
# [DATASET] a0240_aug2, shape=(39, 333)
# [DATASET] a0241, shape=(39, 333)
# [DATASET] a0242, shape=(39, 333)
# [DATASET] a0242_aug0, shape=(39, 333)
# [DATASET] a0242_aug1, shape=(39, 333)
# [DATASET] a0242_aug2, shape=(39, 333)
# [DATASET] a0243, shape=(39, 333)
# [DATASET] a0244, shape=(39, 333)
# [DATASET] a0244_aug0, shape=(39, 333)
# [DATASET] a0244_aug1, shape=(39, 333)
# [DATASET] a0244_aug2, shape=(39, 333)
# [DATASET] a0245, shape=(39, 333)
# [DATASET] a0245_aug0, shape=(39, 333)
# [DATASET] a0245_aug1, shape=(39, 333)
# [DATASET] a0245_aug2, shape=(39, 333)
# [DATASET] a0246, shape=(39, 333)
# [DATASET] a0246_aug0, shape=(39, 333)
# [DATASET] a0246_aug1, shape=(39, 333)
# [DATASET] a0246_aug2, shape=(39, 333)
# [DATASET] a0247, shape=(39, 333)
# [DATASET] a0247_aug0, shape=(39, 333)
# [DATASET] a0247_aug1, shape=(39, 333)
# [DATASET] a0247_aug2, shape=(39, 333)
# [DATASET] a0248, shape=(39, 333)
# [DATASET] a0248_aug0, shape=(39, 333)
# [DATASET] a0248_aug1, shape=(39, 333)
# [DATASET] a0248_aug2, shape=(39, 333)
# [DATASET] a0249, shape=(39, 333)
# [DATASET] a0249_aug0, shape=(39, 333)
# [DATASET] a0249_aug1, shape=(39, 333)
# [DATASET] a0249_aug2, shape=(39, 333)
# [DATASET] a0250, shape=(39, 333)
# [DATASET] a0251, shape=(39, 333)
# [DATASET] a0251_aug0, shape=(39, 333)
# [DATASET] a0251_aug1, shape=(39, 333)
# [DATASET] a0251_aug2, shape=(39, 333)
# [DATASET] a0252, shape=(39, 333)
# [DATASET] a0252_aug0, shape=(39, 333)
# [DATASET] a0252_aug1, shape=(39, 333)
# [DATASET] a0252_aug2, shape=(39, 333)
# [DATASET] a0253, shape=(39, 333)
# [DATASET] a0254, shape=(39, 333)
# [DATASET] a0254_aug0, shape=(39, 333)
# [DATASET] a0254_aug1, shape=(39, 333)
# [DATASET] a0254_aug2, shape=(39, 333)
# [DATASET] a0255, shape=(39, 333)
# [DATASET] a0255_aug0, shape=(39, 333)
# [DATASET] a0255_aug1, shape=(39, 333)
# [DATASET] a0255_aug2, shape=(39, 333)
# [DATASET] a0256, shape=(39, 333)
# [DATASET] a0256_aug0, shape=(39, 333)
# [DATASET] a0256_aug1, shape=(39, 333)
# [DATASET] a0256_aug2, shape=(39, 333)
# [DATASET] a0257, shape=(39, 333)
# [DATASET] a0257_aug0, shape=(39, 333)
# [DATASET] a0257_aug1, shape=(39, 333)
# [DATASET] a0257_aug2, shape=(39, 333)
# [DATASET] a0258, shape=(39, 333)
# [DATASET] a0258_aug0, shape=(39, 333)
# [DATASET] a0258_aug1, shape=(39, 333)
# [DATASET] a0258_aug2, shape=(39, 333)
# [DATASET] a0259, shape=(39, 333)
# [DATASET] a0259_aug0, shape=(39, 333)
# [DATASET] a0259_aug1, shape=(39, 333)
# [DATASET] a0259_aug2, shape=(39, 333)
# [DATASET] a0260, shape=(39, 333)
# [DATASET] a0260_aug0, shape=(39, 333)
# [DATASET] a0260_aug1, shape=(39, 333)
# [DATASET] a0260_aug2, shape=(39, 333)
# [DATASET] a0261, shape=(39, 333)
# [DATASET] a0261_aug0, shape=(39, 333)
# [DATASET] a0261_aug1, shape=(39, 333)
# [DATASET] a0261_aug2, shape=(39, 333)
# [DATASET] a0262, shape=(39, 333)
# [DATASET] a0262_aug0, shape=(39, 333)
# [DATASET] a0262_aug1, shape=(39, 333)
# [DATASET] a0262_aug2, shape=(39, 333)
# [DATASET] a0263, shape=(39, 333)
# [DATASET] a0263_aug0, shape=(39, 333)
# [DATASET] a0263_aug1, shape=(39, 333)
# [DATASET] a0263_aug2, shape=(39, 333)
# [DATASET] a0264, shape=(39, 333)
# [DATASET] a0265, shape=(39, 333)
# [DATASET] a0265_aug0, shape=(39, 333)
# [DATASET] a0265_aug1, shape=(39, 333)
# [DATASET] a0265_aug2, shape=(39, 333)
# [DATASET] a0266, shape=(39, 333)
# [DATASET] a0267, shape=(39, 333)
# [DATASET] a0267_aug0, shape=(39, 333)
# [DATASET] a0267_aug1, shape=(39, 333)
# [DATASET] a0267_aug2, shape=(39, 333)
# [DATASET] a0268, shape=(39, 333)
# [DATASET] a0268_aug0, shape=(39, 333)
# [DATASET] a0268_aug1, shape=(39, 333)
# [DATASET] a0268_aug2, shape=(39, 333)
# [DATASET] a0269, shape=(39, 333)
# [DATASET] a0269_aug0, shape=(39, 333)
# [DATASET] a0269_aug1, shape=(39, 333)
# [DATASET] a0269_aug2, shape=(39, 333)
# [DATASET] a0270, shape=(39, 333)
# [DATASET] a0271, shape=(39, 333)
# [DATASET] a0272, shape=(39, 333)
# [DATASET] a0272_aug0, shape=(39, 333)
# [DATASET] a0272_aug1, shape=(39, 333)
# [DATASET] a0272_aug2, shape=(39, 333)
# [DATASET] a0273, shape=(39, 333)
# [DATASET] a0273_aug0, shape=(39, 333)
# [DATASET] a0273_aug1, shape=(39, 333)
# [DATASET] a0273_aug2, shape=(39, 333)
# [DATASET] a0274, shape=(39, 333)
# [DATASET] a0275, shape=(39, 333)
# [DATASET] a0275_aug0, shape=(39, 333)
# [DATASET] a0275_aug1, shape=(39, 333)
# [DATASET] a0275_aug2, shape=(39, 333)
# [DATASET] a0276, shape=(39, 333)
# [DATASET] a0276_aug0, shape=(39, 333)
# [DATASET] a0276_aug1, shape=(39, 333)
# [DATASET] a0276_aug2, shape=(39, 333)
# [DATASET] a0277, shape=(39, 333)
# [DATASET] a0277_aug0, shape=(39, 333)
# [DATASET] a0277_aug1, shape=(39, 333)
# [DATASET] a0277_aug2, shape=(39, 333)
# [DATASET] a0278, shape=(39, 333)
# [DATASET] a0278_aug0, shape=(39, 333)
# [DATASET] a0278_aug1, shape=(39, 333)
# [DATASET] a0278_aug2, shape=(39, 333)
# [DATASET] a0279, shape=(39, 333)
# [DATASET] a0279_aug0, shape=(39, 333)
# [DATASET] a0279_aug1, shape=(39, 333)
# [DATASET] a0279_aug2, shape=(39, 333)
# [DATASET] a0280, shape=(39, 333)
# [DATASET] a0280_aug0, shape=(39, 333)
# [DATASET] a0280_aug1, shape=(39, 333)
# [DATASET] a0280_aug2, shape=(39, 333)
# [DATASET] a0281, shape=(39, 333)
# [DATASET] a0281_aug0, shape=(39, 333)
# [DATASET] a0281_aug1, shape=(39, 333)
# [DATASET] a0281_aug2, shape=(39, 333)
# [DATASET] a0282, shape=(39, 333)
# [DATASET] a0282_aug0, shape=(39, 333)
# [DATASET] a0282_aug1, shape=(39, 333)
# [DATASET] a0282_aug2, shape=(39, 333)
# [DATASET] a0283, shape=(39, 333)
# [DATASET] a0284, shape=(39, 333)
# [DATASET] a0284_aug0, shape=(39, 333)
# [DATASET] a0284_aug1, shape=(39, 333)
# [DATASET] a0284_aug2, shape=(39, 333)
# [DATASET] a0285, shape=(39, 333)
# [DATASET] a0286, shape=(39, 333)
# [DATASET] a0286_aug0, shape=(39, 333)
# [DATASET] a0286_aug1, shape=(39, 333)
# [DATASET] a0286_aug2, shape=(39, 333)
# [DATASET] a0287, shape=(39, 333)
# [DATASET] a0288, shape=(39, 333)
# [DATASET] a0288_aug0, shape=(39, 333)
# [DATASET] a0288_aug1, shape=(39, 333)
# [DATASET] a0288_aug2, shape=(39, 333)
# [DATASET] a0289, shape=(39, 333)
# [DATASET] a0290, shape=(39, 333)
# [DATASET] a0291, shape=(39, 333)
# [DATASET] a0291_aug0, shape=(39, 333)
# [DATASET] a0291_aug1, shape=(39, 333)
# [DATASET] a0291_aug2, shape=(39, 333)
# [DATASET] a0292, shape=(39, 333)
# [DATASET] a0292_aug0, shape=(39, 333)
# [DATASET] a0292_aug1, shape=(39, 333)
# [DATASET] a0292_aug2, shape=(39, 333)
# [DATASET] a0293, shape=(39, 333)
# [DATASET] a0294, shape=(39, 333)
# [DATASET] a0295, shape=(39, 333)
# [DATASET] a0295_aug0, shape=(39, 333)
# [DATASET] a0295_aug1, shape=(39, 333)
# [DATASET] a0295_aug2, shape=(39, 333)
# [DATASET] a0296, shape=(39, 333)
# [DATASET] a0296_aug0, shape=(39, 333)
# [DATASET] a0296_aug1, shape=(39, 333)
# [DATASET] a0296_aug2, shape=(39, 333)
# [DATASET] a0297, shape=(39, 333)
# [DATASET] a0297_aug0, shape=(39, 333)
# [DATASET] a0297_aug1, shape=(39, 333)
# [DATASET] a0297_aug2, shape=(39, 333)
# [DATASET] a0298, shape=(39, 333)
# [DATASET] a0299, shape=(39, 333)
# [DATASET] a0300, shape=(39, 333)
# [DATASET] a0300_aug0, shape=(39, 333)
# [DATASET] a0300_aug1, shape=(39, 333)
# [DATASET] a0300_aug2, shape=(39, 333)
# [DATASET] a0301, shape=(39, 333)
# [DATASET] a0302, shape=(39, 333)
# [DATASET] a0303, shape=(39, 333)
# [DATASET] a0303_aug0, shape=(39, 333)
# [DATASET] a0303_aug1, shape=(39, 333)
# [DATASET] a0303_aug2, shape=(39, 333)
# [DATASET] a0304, shape=(39, 333)
# [DATASET] a0305, shape=(39, 333)
# [DATASET] a0305_aug0, shape=(39, 333)
# [DATASET] a0305_aug1, shape=(39, 333)
# [DATASET] a0305_aug2, shape=(39, 333)
# [DATASET] a0306, shape=(39, 333)
# [DATASET] a0306_aug0, shape=(39, 333)
# [DATASET] a0306_aug1, shape=(39, 333)
# [DATASET] a0306_aug2, shape=(39, 333)
# [DATASET] a0307, shape=(39, 333)
# [DATASET] a0307_aug0, shape=(39, 333)
# [DATASET] a0307_aug1, shape=(39, 333)
# [DATASET] a0307_aug2, shape=(39, 333)
# [DATASET] a0308, shape=(39, 333)
# [DATASET] a0308_aug0, shape=(39, 333)
# [DATASET] a0308_aug1, shape=(39, 333)
# [DATASET] a0308_aug2, shape=(39, 333)
# [DATASET] a0309, shape=(39, 333)
# [DATASET] a0310, shape=(39, 333)
# [DATASET] a0311, shape=(39, 333)
# [DATASET] a0312, shape=(39, 333)
# [DATASET] a0312_aug0, shape=(39, 333)
# [DATASET] a0312_aug1, shape=(39, 333)
# [DATASET] a0312_aug2, shape=(39, 333)
# [DATASET] a0313, shape=(39, 333)
# [DATASET] a0313_aug0, shape=(39, 333)
# [DATASET] a0313_aug1, shape=(39, 333)
# [DATASET] a0313_aug2, shape=(39, 333)
# [DATASET] a0314, shape=(39, 333)
# [DATASET] a0314_aug0, shape=(39, 333)
# [DATASET] a0314_aug1, shape=(39, 333)
# [DATASET] a0314_aug2, shape=(39, 333)
# [DATASET] a0315, shape=(39, 333)
# [DATASET] a0315_aug0, shape=(39, 333)
# [DATASET] a0315_aug1, shape=(39, 333)
# [DATASET] a0315_aug2, shape=(39, 333)
# [DATASET] a0316, shape=(39, 333)
# [DATASET] a0316_aug0, shape=(39, 333)
# [DATASET] a0316_aug1, shape=(39, 333)
# [DATASET] a0316_aug2, shape=(39, 333)
# [DATASET] a0317, shape=(39, 333)
# [DATASET] a0317_aug0, shape=(39, 333)
# [DATASET] a0317_aug1, shape=(39, 333)
# [DATASET] a0317_aug2, shape=(39, 333)
# [DATASET] a0318, shape=(39, 333)
# [DATASET] a0318_aug0, shape=(39, 333)
# [DATASET] a0318_aug1, shape=(39, 333)
# [DATASET] a0318_aug2, shape=(39, 333)
# [DATASET] a0319, shape=(39, 333)
# [DATASET] a0319_aug0, shape=(39, 333)
# [DATASET] a0319_aug1, shape=(39, 333)
# [DATASET] a0319_aug2, shape=(39, 333)
# [DATASET] a0320, shape=(39, 333)
# [DATASET] a0320_aug0, shape=(39, 333)
# [DATASET] a0320_aug1, shape=(39, 333)
# [DATASET] a0320_aug2, shape=(39, 333)
# [DATASET] a0321, shape=(39, 333)
# [DATASET] a0321_aug0, shape=(39, 333)
# [DATASET] a0321_aug1, shape=(39, 333)
# [DATASET] a0321_aug2, shape=(39, 333)
# [DATASET] a0322, shape=(39, 333)
# [DATASET] a0322_aug0, shape=(39, 333)
# [DATASET] a0322_aug1, shape=(39, 333)
# [DATASET] a0322_aug2, shape=(39, 333)
# [DATASET] a0323, shape=(39, 333)
# [DATASET] a0324, shape=(39, 333)
# [DATASET] a0324_aug0, shape=(39, 333)
# [DATASET] a0324_aug1, shape=(39, 333)
# [DATASET] a0324_aug2, shape=(39, 333)
# [DATASET] a0325, shape=(39, 333)
# [DATASET] a0326, shape=(39, 333)
# [DATASET] a0326_aug0, shape=(39, 333)
# [DATASET] a0326_aug1, shape=(39, 333)
# [DATASET] a0326_aug2, shape=(39, 333)
# [DATASET] a0327, shape=(39, 333)
# [DATASET] a0327_aug0, shape=(39, 333)
# [DATASET] a0327_aug1, shape=(39, 333)
# [DATASET] a0327_aug2, shape=(39, 333)
# [DATASET] a0328, shape=(39, 333)
# [DATASET] a0329, shape=(39, 333)
# [DATASET] a0330, shape=(39, 333)
# [DATASET] a0331, shape=(39, 333)
# [DATASET] a0331_aug0, shape=(39, 333)
# [DATASET] a0331_aug1, shape=(39, 333)
# [DATASET] a0331_aug2, shape=(39, 333)
# [DATASET] a0332, shape=(39, 333)
# [DATASET] a0333, shape=(39, 333)
# [DATASET] a0333_aug0, shape=(39, 333)
# [DATASET] a0333_aug1, shape=(39, 333)
# [DATASET] a0333_aug2, shape=(39, 333)
# [DATASET] a0334, shape=(39, 333)
# [DATASET] a0335, shape=(39, 333)
# [DATASET] a0335_aug0, shape=(39, 333)
# [DATASET] a0335_aug1, shape=(39, 333)
# [DATASET] a0335_aug2, shape=(39, 333)
# [DATASET] a0336, shape=(39, 333)
# [DATASET] a0336_aug0, shape=(39, 333)
# [DATASET] a0336_aug1, shape=(39, 333)
# [DATASET] a0336_aug2, shape=(39, 333)
# [DATASET] a0337, shape=(39, 333)
# [DATASET] a0338, shape=(39, 333)
# [DATASET] a0338_aug0, shape=(39, 333)
# [DATASET] a0338_aug1, shape=(39, 333)
# [DATASET] a0338_aug2, shape=(39, 333)
# [DATASET] a0339, shape=(39, 333)
# [DATASET] a0339_aug0, shape=(39, 333)
# [DATASET] a0339_aug1, shape=(39, 333)
# [DATASET] a0339_aug2, shape=(39, 333)
# [DATASET] a0340, shape=(39, 333)
# [DATASET] a0341, shape=(39, 333)
# [DATASET] a0341_aug0, shape=(39, 333)
# [DATASET] a0341_aug1, shape=(39, 333)
# [DATASET] a0341_aug2, shape=(39, 333)
# [DATASET] a0342, shape=(39, 333)
# [DATASET] a0343, shape=(39, 333)
# [DATASET] a0343_aug0, shape=(39, 333)
# [DATASET] a0343_aug1, shape=(39, 333)
# [DATASET] a0343_aug2, shape=(39, 333)
# [DATASET] a0344, shape=(39, 333)
# [DATASET] a0344_aug0, shape=(39, 333)
# [DATASET] a0344_aug1, shape=(39, 333)
# [DATASET] a0344_aug2, shape=(39, 333)
# [DATASET] a0345, shape=(39, 333)
# [DATASET] a0345_aug0, shape=(39, 333)
# [DATASET] a0345_aug1, shape=(39, 333)
# [DATASET] a0345_aug2, shape=(39, 333)
# [DATASET] a0346, shape=(39, 333)
# [DATASET] a0346_aug0, shape=(39, 333)
# [DATASET] a0346_aug1, shape=(39, 333)
# [DATASET] a0346_aug2, shape=(39, 333)
# [DATASET] a0347, shape=(39, 333)
# [DATASET] a0347_aug0, shape=(39, 333)
# [DATASET] a0347_aug1, shape=(39, 333)
# [DATASET] a0347_aug2, shape=(39, 333)
# [DATASET] a0348, shape=(39, 333)
# [DATASET] a0348_aug0, shape=(39, 333)
# [DATASET] a0348_aug1, shape=(39, 333)
# [DATASET] a0348_aug2, shape=(39, 333)
# [DATASET] a0349, shape=(39, 333)
# [DATASET] a0349_aug0, shape=(39, 333)
# [DATASET] a0349_aug1, shape=(39, 333)
# [DATASET] a0349_aug2, shape=(39, 333)
# [DATASET] a0350, shape=(39, 333)
# [DATASET] a0350_aug0, shape=(39, 333)
# [DATASET] a0350_aug1, shape=(39, 333)
# [DATASET] a0350_aug2, shape=(39, 333)
# [DATASET] a0351, shape=(39, 333)
# [DATASET] a0352, shape=(39, 333)
# [DATASET] a0353, shape=(39, 333)
# [DATASET] a0354, shape=(39, 333)
# [DATASET] a0354_aug0, shape=(39, 333)
# [DATASET] a0354_aug1, shape=(39, 333)
# [DATASET] a0354_aug2, shape=(39, 333)
# [DATASET] a0355, shape=(39, 333)
# [DATASET] a0356, shape=(39, 333)
# [DATASET] a0356_aug0, shape=(39, 333)
# [DATASET] a0356_aug1, shape=(39, 333)
# [DATASET] a0356_aug2, shape=(39, 333)
# [DATASET] a0357, shape=(39, 333)
# [DATASET] a0357_aug0, shape=(39, 333)
# [DATASET] a0357_aug1, shape=(39, 333)
# [DATASET] a0357_aug2, shape=(39, 333)
# [DATASET] a0358, shape=(39, 333)
# [DATASET] a0358_aug0, shape=(39, 333)
# [DATASET] a0358_aug1, shape=(39, 333)
# [DATASET] a0358_aug2, shape=(39, 333)
# [DATASET] a0359, shape=(39, 333)
# [DATASET] a0360, shape=(39, 333)
# [DATASET] a0360_aug0, shape=(39, 333)
# [DATASET] a0360_aug1, shape=(39, 333)
# [DATASET] a0360_aug2, shape=(39, 333)
# [DATASET] a0361, shape=(39, 333)
# [DATASET] a0362, shape=(39, 333)
# [DATASET] a0362_aug0, shape=(39, 333)
# [DATASET] a0362_aug1, shape=(39, 333)
# [DATASET] a0362_aug2, shape=(39, 333)
# [DATASET] a0363, shape=(39, 333)
# [DATASET] a0363_aug0, shape=(39, 333)
# [DATASET] a0363_aug1, shape=(39, 333)
# [DATASET] a0363_aug2, shape=(39, 333)
# [DATASET] a0364, shape=(39, 333)
# [DATASET] a0364_aug0, shape=(39, 333)
# [DATASET] a0364_aug1, shape=(39, 333)
# [DATASET] a0364_aug2, shape=(39, 333)
# [DATASET] a0365, shape=(39, 333)
# [DATASET] a0365_aug0, shape=(39, 333)
# [DATASET] a0365_aug1, shape=(39, 333)
# [DATASET] a0365_aug2, shape=(39, 333)
# [DATASET] a0366, shape=(39, 333)
# [DATASET] a0366_aug0, shape=(39, 333)
# [DATASET] a0366_aug1, shape=(39, 333)
# [DATASET] a0366_aug2, shape=(39, 333)
# [DATASET] a0367, shape=(39, 333)
# [DATASET] a0367_aug0, shape=(39, 333)
# [DATASET] a0367_aug1, shape=(39, 333)
# [DATASET] a0367_aug2, shape=(39, 333)
# [DATASET] a0368, shape=(39, 333)
# [DATASET] a0368_aug0, shape=(39, 333)
# [DATASET] a0368_aug1, shape=(39, 333)
# [DATASET] a0368_aug2, shape=(39, 333)
# [DATASET] a0369, shape=(39, 333)
# [DATASET] a0369_aug0, shape=(39, 333)
# [DATASET] a0369_aug1, shape=(39, 333)
# [DATASET] a0369_aug2, shape=(39, 333)
# [DATASET] a0370, shape=(39, 333)
# [DATASET] a0370_aug0, shape=(39, 333)
# [DATASET] a0370_aug1, shape=(39, 333)
# [DATASET] a0370_aug2, shape=(39, 333)
# [DATASET] a0371, shape=(39, 333)
# [DATASET] a0371_aug0, shape=(39, 333)
# [DATASET] a0371_aug1, shape=(39, 333)
# [DATASET] a0371_aug2, shape=(39, 333)
# [DATASET] a0372, shape=(39, 333)
# [DATASET] a0372_aug0, shape=(39, 333)
# [DATASET] a0372_aug1, shape=(39, 333)
# [DATASET] a0372_aug2, shape=(39, 333)
# [DATASET] a0373, shape=(39, 333)
# [DATASET] a0373_aug0, shape=(39, 333)
# [DATASET] a0373_aug1, shape=(39, 333)
# [DATASET] a0373_aug2, shape=(39, 333)
# [DATASET] a0374, shape=(39, 333)
# [DATASET] a0374_aug0, shape=(39, 333)
# [DATASET] a0374_aug1, shape=(39, 333)
# [DATASET] a0374_aug2, shape=(39, 333)
# [DATASET] a0375, shape=(39, 333)
# [DATASET] a0375_aug0, shape=(39, 333)
# [DATASET] a0375_aug1, shape=(39, 333)
# [DATASET] a0375_aug2, shape=(39, 333)
# [DATASET] a0376, shape=(39, 333)
# [DATASET] a0376_aug0, shape=(39, 333)
# [DATASET] a0376_aug1, shape=(39, 333)
# [DATASET] a0376_aug2, shape=(39, 333)
# [DATASET] a0377, shape=(39, 333)
# [DATASET] a0377_aug0, shape=(39, 333)
# [DATASET] a0377_aug1, shape=(39, 333)
# [DATASET] a0377_aug2, shape=(39, 333)
# [DATASET] a0378, shape=(39, 333)
# [DATASET] a0378_aug0, shape=(39, 333)
# [DATASET] a0378_aug1, shape=(39, 333)
# [DATASET] a0378_aug2, shape=(39, 333)
# [DATASET] a0379, shape=(39, 333)
# [DATASET] a0379_aug0, shape=(39, 333)
# [DATASET] a0379_aug1, shape=(39, 333)
# [DATASET] a0379_aug2, shape=(39, 333)
# [DATASET] a0380, shape=(39, 333)
# [DATASET] a0380_aug0, shape=(39, 333)
# [DATASET] a0380_aug1, shape=(39, 333)
# [DATASET] a0380_aug2, shape=(39, 333)
# [DATASET] a0381, shape=(39, 333)
# [DATASET] a0381_aug0, shape=(39, 333)
# [DATASET] a0381_aug1, shape=(39, 333)
# [DATASET] a0381_aug2, shape=(39, 333)
# [DATASET] a0382, shape=(39, 333)
# [DATASET] a0382_aug0, shape=(39, 333)
# [DATASET] a0382_aug1, shape=(39, 333)
# [DATASET] a0382_aug2, shape=(39, 333)
# [DATASET] a0383, shape=(39, 333)
# [DATASET] a0383_aug0, shape=(39, 333)
# [DATASET] a0383_aug1, shape=(39, 333)
# [DATASET] a0383_aug2, shape=(39, 333)
# [DATASET] a0384, shape=(39, 333)
# [DATASET] a0384_aug0, shape=(39, 333)
# [DATASET] a0384_aug1, shape=(39, 333)
# [DATASET] a0384_aug2, shape=(39, 333)
# [DATASET] a0385, shape=(39, 333)
# [DATASET] a0386, shape=(39, 333)
# [DATASET] a0387, shape=(39, 333)
# [DATASET] a0387_aug0, shape=(39, 333)
# [DATASET] a0387_aug1, shape=(39, 333)
# [DATASET] a0387_aug2, shape=(39, 333)
# [DATASET] a0388, shape=(39, 333)
# [DATASET] a0388_aug0, shape=(39, 333)
# [DATASET] a0388_aug1, shape=(39, 333)
# [DATASET] a0388_aug2, shape=(39, 333)
# [DATASET] a0389, shape=(39, 333)
# [DATASET] a0389_aug0, shape=(39, 333)
# [DATASET] a0389_aug1, shape=(39, 333)
# [DATASET] a0389_aug2, shape=(39, 333)
# [DATASET] a0390, shape=(39, 333)
# [DATASET] a0390_aug0, shape=(39, 333)
# [DATASET] a0390_aug1, shape=(39, 333)
# [DATASET] a0390_aug2, shape=(39, 333)
# [DATASET] a0391, shape=(39, 333)
# [DATASET] a0391_aug0, shape=(39, 333)
# [DATASET] a0391_aug1, shape=(39, 333)
# [DATASET] a0391_aug2, shape=(39, 333)
# [DATASET] a0392, shape=(39, 333)
# [DATASET] a0392_aug0, shape=(39, 333)
# [DATASET] a0392_aug1, shape=(39, 333)
# [DATASET] a0392_aug2, shape=(39, 333)
# [DATASET] a0393, shape=(39, 333)
# [DATASET] a0394, shape=(39, 333)
# [DATASET] a0394_aug0, shape=(39, 333)
# [DATASET] a0394_aug1, shape=(39, 333)
# [DATASET] a0394_aug2, shape=(39, 333)
# [DATASET] a0395, shape=(39, 333)
# [DATASET] a0395_aug0, shape=(39, 333)
# [DATASET] a0395_aug1, shape=(39, 333)
# [DATASET] a0395_aug2, shape=(39, 333)
# [DATASET] a0396, shape=(39, 333)
# [DATASET] a0396_aug0, shape=(39, 333)
# [DATASET] a0396_aug1, shape=(39, 333)
# [DATASET] a0396_aug2, shape=(39, 333)
# [DATASET] a0397, shape=(39, 333)
# [DATASET] a0397_aug0, shape=(39, 333)
# [DATASET] a0397_aug1, shape=(39, 333)
# [DATASET] a0397_aug2, shape=(39, 333)
# [DATASET] a0398, shape=(39, 333)
# [DATASET] a0398_aug0, shape=(39, 333)
# [DATASET] a0398_aug1, shape=(39, 333)
# [DATASET] a0398_aug2, shape=(39, 333)
# [DATASET] a0399, shape=(39, 333)
# [DATASET] a0399_aug0, shape=(39, 333)
# [DATASET] a0399_aug1, shape=(39, 333)
# [DATASET] a0399_aug2, shape=(39, 333)
# [DATASET] a0400, shape=(39, 333)
# [DATASET] a0400_aug0, shape=(39, 333)
# [DATASET] a0400_aug1, shape=(39, 333)
# [DATASET] a0400_aug2, shape=(39, 333)
# [DATASET] a0401, shape=(39, 333)
# [DATASET] a0402, shape=(39, 333)
# [DATASET] a0402_aug0, shape=(39, 333)
# [DATASET] a0402_aug1, shape=(39, 333)
# [DATASET] a0402_aug2, shape=(39, 333)
# [DATASET] a0403, shape=(39, 333)
# [DATASET] a0403_aug0, shape=(39, 333)
# [DATASET] a0403_aug1, shape=(39, 333)
# [DATASET] a0403_aug2, shape=(39, 333)
# [DATASET] a0404, shape=(39, 333)
# [DATASET] a0404_aug0, shape=(39, 333)
# [DATASET] a0404_aug1, shape=(39, 333)
# [DATASET] a0404_aug2, shape=(39, 333)
# [DATASET] a0405, shape=(39, 333)
# [DATASET] a0406, shape=(39, 333)
# [DATASET] a0407, shape=(39, 333)
# [DATASET] a0408, shape=(39, 333)
# [DATASET] a0409, shape=(39, 333)
# [DATASET] b0001, shape=(39, 333)
# [DATASET] b0002, shape=(39, 333)
# [DATASET] b0003, shape=(39, 333)
# [DATASET] b0004, shape=(39, 333)
# [DATASET] b0005, shape=(39, 333)
# [DATASET] b0006, shape=(39, 333)
# [DATASET] b0007, shape=(39, 333)
# [DATASET] b0008, shape=(39, 333)
# [DATASET] b0008_aug0, shape=(39, 333)
# [DATASET] b0008_aug1, shape=(39, 333)
# [DATASET] b0008_aug2, shape=(39, 333)
# [DATASET] b0009, shape=(39, 333)
# [DATASET] b0010, shape=(39, 333)
# [DATASET] b0011, shape=(39, 333)
# [DATASET] b0012, shape=(39, 333)
# [DATASET] b0013, shape=(39, 333)
# [DATASET] b0013_aug0, shape=(39, 333)
# [DATASET] b0013_aug1, shape=(39, 333)
# [DATASET] b0013_aug2, shape=(39, 333)
# [DATASET] b0014, shape=(39, 333)
# [DATASET] b0015, shape=(39, 333)
# [DATASET] b0016, shape=(39, 333)
# [DATASET] b0016_aug0, shape=(39, 333)
# [DATASET] b0016_aug1, shape=(39, 333)
# [DATASET] b0016_aug2, shape=(39, 333)
# [DATASET] b0017, shape=(39, 333)
# [DATASET] b0018, shape=(39, 333)
# [DATASET] b0018_aug0, shape=(39, 333)
# [DATASET] b0018_aug1, shape=(39, 333)
# [DATASET] b0018_aug2, shape=(39, 333)
# [DATASET] b0019, shape=(39, 333)
# [DATASET] b0020, shape=(39, 333)
# [DATASET] b0021, shape=(39, 333)
# [DATASET] b0022, shape=(39, 333)
# [DATASET] b0022_aug0, shape=(39, 333)
# [DATASET] b0022_aug1, shape=(39, 333)
# [DATASET] b0022_aug2, shape=(39, 333)
# [DATASET] b0023, shape=(39, 333)
# [DATASET] b0023_aug0, shape=(39, 333)
# [DATASET] b0023_aug1, shape=(39, 333)
# [DATASET] b0023_aug2, shape=(39, 333)
# [DATASET] b0024, shape=(39, 333)
# [DATASET] b0025, shape=(39, 333)
# [DATASET] b0026, shape=(39, 333)
# [DATASET] b0027, shape=(39, 333)
# [DATASET] b0028, shape=(39, 333)
# [DATASET] b0029, shape=(39, 333)
# [DATASET] b0030, shape=(39, 333)
# [DATASET] b0030_aug0, shape=(39, 333)
# [DATASET] b0030_aug1, shape=(39, 333)
# [DATASET] b0030_aug2, shape=(39, 333)
# [DATASET] b0031, shape=(39, 333)
# [DATASET] b0032, shape=(39, 333)
# [DATASET] b0032_aug0, shape=(39, 333)
# [DATASET] b0032_aug1, shape=(39, 333)
# [DATASET] b0032_aug2, shape=(39, 333)
# [DATASET] b0033, shape=(39, 333)
# [DATASET] b0033_aug0, shape=(39, 333)
# [DATASET] b0033_aug1, shape=(39, 333)
# [DATASET] b0033_aug2, shape=(39, 333)
# [DATASET] b0034, shape=(39, 333)
# [DATASET] b0035, shape=(39, 333)
# [DATASET] b0036, shape=(39, 333)
# [DATASET] b0037, shape=(39, 333)
# [DATASET] b0037_aug0, shape=(39, 333)
# [DATASET] b0037_aug1, shape=(39, 333)
# [DATASET] b0037_aug2, shape=(39, 333)
# [DATASET] b0038, shape=(39, 333)
# [DATASET] b0039, shape=(39, 333)
# [DATASET] b0040, shape=(39, 333)
# [DATASET] b0040_aug0, shape=(39, 333)
# [DATASET] b0040_aug1, shape=(39, 333)
# [DATASET] b0040_aug2, shape=(39, 333)
# [DATASET] b0041, shape=(39, 333)
# [DATASET] b0041_aug0, shape=(39, 333)
# [DATASET] b0041_aug1, shape=(39, 333)
# [DATASET] b0041_aug2, shape=(39, 333)
# [DATASET] b0042, shape=(39, 333)
# [DATASET] b0043, shape=(39, 333)
# [DATASET] b0043_aug0, shape=(39, 333)
# [DATASET] b0043_aug1, shape=(39, 333)
# [DATASET] b0043_aug2, shape=(39, 333)
# [DATASET] b0044, shape=(39, 333)
# [DATASET] b0045, shape=(39, 333)
# [DATASET] b0046, shape=(39, 333)
# [DATASET] b0046_aug0, shape=(39, 333)
# [DATASET] b0046_aug1, shape=(39, 333)
# [DATASET] b0046_aug2, shape=(39, 333)
# [DATASET] b0047, shape=(39, 333)
# [DATASET] b0048, shape=(39, 333)
# [DATASET] b0048_aug0, shape=(39, 333)
# [DATASET] b0048_aug1, shape=(39, 333)
# [DATASET] b0048_aug2, shape=(39, 333)
# [DATASET] b0049, shape=(39, 333)
# [DATASET] b0050, shape=(39, 333)
# [DATASET] b0051, shape=(39, 333)
# [DATASET] b0052, shape=(39, 333)
# [DATASET] b0053, shape=(39, 333)
# [DATASET] b0054, shape=(39, 333)
# [DATASET] b0054_aug0, shape=(39, 333)
# [DATASET] b0054_aug1, shape=(39, 333)
# [DATASET] b0054_aug2, shape=(39, 333)
# [DATASET] b0055, shape=(39, 333)
# [DATASET] b0056, shape=(39, 333)
# [DATASET] b0057, shape=(39, 333)
# [DATASET] b0057_aug0, shape=(39, 333)
# [DATASET] b0057_aug1, shape=(39, 333)
# [DATASET] b0057_aug2, shape=(39, 333)
# [DATASET] b0058, shape=(39, 333)
# [DATASET] b0059, shape=(39, 333)
# [DATASET] b0060, shape=(39, 333)
# [DATASET] b0061, shape=(39, 333)
# [DATASET] b0062, shape=(39, 333)
# [DATASET] b0063, shape=(39, 333)
# [DATASET] b0063_aug0, shape=(39, 333)
# [DATASET] b0063_aug1, shape=(39, 333)
# [DATASET] b0063_aug2, shape=(39, 333)
# [DATASET] b0064, shape=(39, 333)
# [DATASET] b0065, shape=(39, 333)
# [DATASET] b0066, shape=(39, 333)
# [DATASET] b0067, shape=(39, 333)
# [DATASET] b0068, shape=(39, 333)
# [DATASET] b0068_aug0, shape=(39, 333)
# [DATASET] b0068_aug1, shape=(39, 333)
# [DATASET] b0068_aug2, shape=(39, 333)
# [DATASET] b0069, shape=(39, 333)
# [DATASET] b0070, shape=(39, 333)
# [DATASET] b0071, shape=(39, 333)
# [DATASET] b0072, shape=(39, 333)
# [DATASET] b0073, shape=(39, 333)
# [DATASET] b0074, shape=(39, 333)
# [DATASET] b0075, shape=(39, 333)
# [DATASET] b0076, shape=(39, 333)
# [DATASET] b0077, shape=(39, 333)
# [DATASET] b0077_aug0, shape=(39, 333)
# [DATASET] b0077_aug1, shape=(39, 333)
# [DATASET] b0077_aug2, shape=(39, 333)
# [DATASET] b0078, shape=(39, 333)
# [DATASET] b0079, shape=(39, 333)
# [DATASET] b0080, shape=(39, 333)
# [DATASET] b0081, shape=(39, 333)
# [DATASET] b0081_aug0, shape=(39, 333)
# [DATASET] b0081_aug1, shape=(39, 333)
# [DATASET] b0081_aug2, shape=(39, 333)
# [DATASET] b0082, shape=(39, 333)
# [DATASET] b0083, shape=(39, 333)
# [DATASET] b0084, shape=(39, 333)
# [DATASET] b0085, shape=(39, 333)
# [DATASET] b0086, shape=(39, 333)
# [DATASET] b0086_aug0, shape=(39, 333)
# [DATASET] b0086_aug1, shape=(39, 333)
# [DATASET] b0086_aug2, shape=(39, 333)
# [DATASET] b0087, shape=(39, 333)
# [DATASET] b0088, shape=(39, 333)
# [DATASET] b0089, shape=(39, 333)
# [DATASET] b0090, shape=(39, 333)
# [DATASET] b0091, shape=(39, 333)
# [DATASET] b0092, shape=(39, 333)
# [DATASET] b0093, shape=(39, 333)
# [DATASET] b0094, shape=(39, 333)
# [DATASET] b0095, shape=(39, 333)
# [DATASET] b0096, shape=(39, 333)
# [DATASET] b0096_aug0, shape=(39, 333)
# [DATASET] b0096_aug1, shape=(39, 333)
# [DATASET] b0096_aug2, shape=(39, 333)
# [DATASET] b0097, shape=(39, 333)
# [DATASET] b0098, shape=(39, 333)
# [DATASET] b0099, shape=(39, 333)
# [DATASET] b0100, shape=(39, 333)
# [DATASET] b0101, shape=(39, 333)
# [DATASET] b0102, shape=(39, 333)
# [DATASET] b0103, shape=(39, 333)
# [DATASET] b0104, shape=(39, 333)
# [DATASET] b0105, shape=(39, 333)
# [DATASET] b0106, shape=(39, 333)
# [DATASET] b0106_aug0, shape=(39, 333)
# [DATASET] b0106_aug1, shape=(39, 333)
# [DATASET] b0106_aug2, shape=(39, 333)
# [DATASET] b0107, shape=(39, 333)
# [DATASET] b0108, shape=(39, 333)
# [DATASET] b0109, shape=(39, 333)
# [DATASET] b0110, shape=(39, 333)
# [DATASET] b0111, shape=(39, 333)
# [DATASET] b0112, shape=(39, 333)
# [DATASET] b0113, shape=(39, 333)
# [DATASET] b0114, shape=(39, 333)
# [DATASET] b0115, shape=(39, 333)
# [DATASET] b0116, shape=(39, 333)
# [DATASET] b0117, shape=(39, 333)
# [DATASET] b0117_aug0, shape=(39, 333)
# [DATASET] b0117_aug1, shape=(39, 333)
# [DATASET] b0117_aug2, shape=(39, 333)
# [DATASET] b0118, shape=(39, 333)
# [DATASET] b0119, shape=(39, 333)
# [DATASET] b0120, shape=(39, 333)
# [DATASET] b0120_aug0, shape=(39, 333)
# [DATASET] b0120_aug1, shape=(39, 333)
# [DATASET] b0120_aug2, shape=(39, 333)
# [DATASET] b0121, shape=(39, 333)
# [DATASET] b0122, shape=(39, 333)
# [DATASET] b0123, shape=(39, 333)
# [DATASET] b0124, shape=(39, 333)
# [DATASET] b0125, shape=(39, 333)
# [DATASET] b0126, shape=(39, 333)
# [DATASET] b0127, shape=(39, 333)
# [DATASET] b0128, shape=(39, 333)
# [DATASET] b0129, shape=(39, 333)
# [DATASET] b0130, shape=(39, 333)
# [DATASET] b0130_aug0, shape=(39, 333)
# [DATASET] b0130_aug1, shape=(39, 333)
# [DATASET] b0130_aug2, shape=(39, 333)
# [DATASET] b0131, shape=(39, 333)
# [DATASET] b0132, shape=(39, 333)
# [DATASET] b0133, shape=(39, 333)
# [DATASET] b0134, shape=(39, 333)
# [DATASET] b0135, shape=(39, 333)
# [DATASET] b0136, shape=(39, 333)
# [DATASET] b0136_aug0, shape=(39, 333)
# [DATASET] b0136_aug1, shape=(39, 333)
# [DATASET] b0136_aug2, shape=(39, 333)
# [DATASET] b0137, shape=(39, 333)
# [DATASET] b0137_aug0, shape=(39, 333)
# [DATASET] b0137_aug1, shape=(39, 333)
# [DATASET] b0137_aug2, shape=(39, 333)
# [DATASET] b0138, shape=(39, 333)
# [DATASET] b0139, shape=(39, 333)
# [DATASET] b0140, shape=(39, 333)
# [DATASET] b0140_aug0, shape=(39, 333)
# [DATASET] b0140_aug1, shape=(39, 333)
# [DATASET] b0140_aug2, shape=(39, 333)
# [DATASET] b0141, shape=(39, 333)
# [DATASET] b0142, shape=(39, 333)
# [DATASET] b0143, shape=(39, 333)
# [DATASET] b0144, shape=(39, 333)
# [DATASET] b0145, shape=(39, 333)
# [DATASET] b0146, shape=(39, 333)
# [DATASET] b0147, shape=(39, 333)
# [DATASET] b0148, shape=(39, 333)
# [DATASET] b0148_aug0, shape=(39, 333)
# [DATASET] b0148_aug1, shape=(39, 333)
# [DATASET] b0148_aug2, shape=(39, 333)
# [DATASET] b0149, shape=(39, 333)
# [DATASET] b0150, shape=(39, 333)
# [DATASET] b0151, shape=(39, 333)
# [DATASET] b0152, shape=(39, 333)
# [DATASET] b0153, shape=(39, 333)
# [DATASET] b0154, shape=(39, 333)
# [DATASET] b0155, shape=(39, 333)
# [DATASET] b0155_aug0, shape=(39, 333)
# [DATASET] b0155_aug1, shape=(39, 333)
# [DATASET] b0155_aug2, shape=(39, 333)
# [DATASET] b0156, shape=(39, 333)
# [DATASET] b0157, shape=(39, 333)
# [DATASET] b0158, shape=(39, 333)
# [DATASET] b0159, shape=(39, 333)
# [DATASET] b0159_aug0, shape=(39, 333)
# [DATASET] b0159_aug1, shape=(39, 333)
# [DATASET] b0159_aug2, shape=(39, 333)
# [DATASET] b0160, shape=(39, 333)
# [DATASET] b0161, shape=(39, 333)
# [DATASET] b0162, shape=(39, 333)
# [DATASET] b0163, shape=(39, 333)
# [DATASET] b0164, shape=(39, 333)
# [DATASET] b0164_aug0, shape=(39, 333)
# [DATASET] b0164_aug1, shape=(39, 333)
# [DATASET] b0164_aug2, shape=(39, 333)
# [DATASET] b0165, shape=(39, 333)
# [DATASET] b0166, shape=(39, 333)
# [DATASET] b0167, shape=(39, 333)
# [DATASET] b0168, shape=(39, 333)
# [DATASET] b0169, shape=(39, 333)
# [DATASET] b0170, shape=(39, 333)
# [DATASET] b0171, shape=(39, 333)
# [DATASET] b0171_aug0, shape=(39, 333)
# [DATASET] b0171_aug1, shape=(39, 333)
# [DATASET] b0171_aug2, shape=(39, 333)
# [DATASET] b0172, shape=(39, 333)
# [DATASET] b0173, shape=(39, 333)
# ...
# [DATASET] e01965, shape=(39, 333)
# [DATASET] e01966, shape=(39, 333)
# [DATASET] e01967, shape=(39, 333)
# [DATASET] e01967_aug0, shape=(39, 333)
# [DATASET] e01967_aug1, shape=(39, 333)
# [DATASET] e01967_aug2, shape=(39, 333)
# [DATASET] e01968, shape=(39, 333)
# [DATASET] e01969, shape=(39, 333)
# [DATASET] e01970, shape=(39, 333)
# [DATASET] e01971, shape=(39, 333)
# [DATASET] e01971_aug0, shape=(39, 333)
# [DATASET] e01971_aug1, shape=(39, 333)
# [DATASET] e01971_aug2, shape=(39, 333)
# [DATASET] e01972, shape=(39, 333)
# [DATASET] e01973, shape=(39, 333)
# [DATASET] e01974, shape=(39, 333)
# [DATASET] e01975, shape=(39, 333)
# [DATASET] e01976, shape=(39, 333)
# [DATASET] e01977, shape=(39, 333)
# [DATASET] e01978, shape=(39, 333)
# [DATASET] e01978_aug0, shape=(39, 333)
# [DATASET] e01978_aug1, shape=(39, 333)
# [DATASET] e01978_aug2, shape=(39, 333)
# [DATASET] e01979, shape=(39, 333)
# [DATASET] e01980, shape=(39, 333)
# [DATASET] e01981, shape=(39, 333)
# [DATASET] e01982, shape=(39, 333)
# [DATASET] e01983, shape=(39, 333)
# [DATASET] e01984, shape=(39, 333)
# [DATASET] e01985, shape=(39, 333)
# [DATASET] e01986, shape=(39, 333)
# [DATASET] e01987, shape=(39, 333)
# [DATASET] e01988, shape=(39, 333)
# [DATASET] e01989, shape=(39, 333)
# [DATASET] e01990, shape=(39, 333)
# [DATASET] e01991, shape=(39, 333)
# [DATASET] e01992, shape=(39, 333)
# [DATASET] e01992_aug0, shape=(39, 333)
# [DATASET] e01992_aug1, shape=(39, 333)
# [DATASET] e01992_aug2, shape=(39, 333)
# [DATASET] e01993, shape=(39, 333)
# [DATASET] e01994, shape=(39, 333)
# [DATASET] e01995, shape=(39, 333)
# [DATASET] e01995_aug0, shape=(39, 333)
# [DATASET] e01995_aug1, shape=(39, 333)
# [DATASET] e01995_aug2, shape=(39, 333)
# [DATASET] e01996, shape=(39, 333)
# [DATASET] e01997, shape=(39, 333)
# [DATASET] e01998, shape=(39, 333)
# [DATASET] e01999, shape=(39, 333)
# [DATASET] e02000, shape=(39, 333)
# [DATASET] e02001, shape=(39, 333)
# [DATASET] e02002, shape=(39, 333)
# [DATASET] e02003, shape=(39, 333)
# [DATASET] e02004, shape=(39, 333)
# [DATASET] e02005, shape=(39, 333)
# [DATASET] e02006, shape=(39, 333)
# [DATASET] e02007, shape=(39, 333)
# [DATASET] e02008, shape=(39, 333)
# [DATASET] e02009, shape=(39, 333)
# [DATASET] e02010, shape=(39, 333)
# [DATASET] e02011, shape=(39, 333)
# [DATASET] e02012, shape=(39, 333)
# [DATASET] e02013, shape=(39, 333)
# [DATASET] e02014, shape=(39, 333)
# [DATASET] e02015, shape=(39, 333)
# [DATASET] e02016, shape=(39, 333)
# [DATASET] e02017, shape=(39, 333)
# [DATASET] e02018, shape=(39, 333)
# [DATASET] e02019, shape=(39, 333)
# [DATASET] e02020, shape=(39, 333)
# [DATASET] e02021, shape=(39, 333)
# [DATASET] e02022, shape=(39, 333)
# [DATASET] e02023, shape=(39, 333)
# [DATASET] e02024, shape=(39, 333)
# [DATASET] e02025, shape=(39, 333)
# [DATASET] e02026, shape=(39, 333)
# [DATASET] e02027, shape=(39, 333)
# [DATASET] e02028, shape=(39, 333)
# [DATASET] e02029, shape=(39, 333)
# [DATASET] e02030, shape=(39, 333)
# [DATASET] e02030_aug0, shape=(39, 333)
# [DATASET] e02030_aug1, shape=(39, 333)
# [DATASET] e02030_aug2, shape=(39, 333)
# [DATASET] e02031, shape=(39, 333)
# [DATASET] e02032, shape=(39, 333)
# [DATASET] e02032_aug0, shape=(39, 333)
# [DATASET] e02032_aug1, shape=(39, 333)
# [DATASET] e02032_aug2, shape=(39, 333)
# [DATASET] e02033, shape=(39, 333)
# [DATASET] e02034, shape=(39, 333)
# [DATASET] e02035, shape=(39, 333)
# [DATASET] e02036, shape=(39, 333)
# [DATASET] e02037, shape=(39, 333)
# [DATASET] e02038, shape=(39, 333)
# [DATASET] e02039, shape=(39, 333)
# [DATASET] e02040, shape=(39, 333)
# [DATASET] e02041, shape=(39, 333)
# [DATASET] e02042, shape=(39, 333)
# [DATASET] e02043, shape=(39, 333)
# [DATASET] e02044, shape=(39, 333)
# [DATASET] e02044_aug0, shape=(39, 333)
# [DATASET] e02044_aug1, shape=(39, 333)
# [DATASET] e02044_aug2, shape=(39, 333)
# [DATASET] e02045, shape=(39, 333)
# [DATASET] e02046, shape=(39, 333)
# [DATASET] e02047, shape=(39, 333)
# [DATASET] e02048, shape=(39, 333)
# [DATASET] e02049, shape=(39, 333)
# [DATASET] e02050, shape=(39, 333)
# [DATASET] e02051, shape=(39, 333)
# [DATASET] e02052, shape=(39, 333)
# [DATASET] e02053, shape=(39, 333)
# [DATASET] e02054, shape=(39, 333)
# [DATASET] e02055, shape=(39, 333)
# [DATASET] e02056, shape=(39, 333)
# [DATASET] e02057, shape=(39, 333)
# [DATASET] e02058, shape=(39, 333)
# [DATASET] e02059, shape=(39, 333)
# [DATASET] e02060, shape=(39, 333)
# [DATASET] e02061, shape=(39, 333)
# [DATASET] e02062, shape=(39, 333)
# [DATASET] e02063, shape=(39, 333)
# [DATASET] e02064, shape=(39, 333)
# [DATASET] e02065, shape=(39, 333)
# [DATASET] e02065_aug0, shape=(39, 333)
# [DATASET] e02065_aug1, shape=(39, 333)
# [DATASET] e02065_aug2, shape=(39, 333)
# [DATASET] e02066, shape=(39, 333)
# [DATASET] e02067, shape=(39, 333)
# [DATASET] e02068, shape=(39, 333)
# [DATASET] e02069, shape=(39, 333)
# [DATASET] e02070, shape=(39, 333)
# [DATASET] e02071, shape=(39, 333)
# [DATASET] e02072, shape=(39, 333)
# [DATASET] e02073, shape=(39, 333)
# [DATASET] e02074, shape=(39, 333)
# [DATASET] e02074_aug0, shape=(39, 333)
# [DATASET] e02074_aug1, shape=(39, 333)
# [DATASET] e02074_aug2, shape=(39, 333)
# [DATASET] e02075, shape=(39, 333)
# [DATASET] e02076, shape=(39, 333)
# [DATASET] e02077, shape=(39, 333)
# [DATASET] e02078, shape=(39, 333)
# [DATASET] e02079, shape=(39, 333)
# [DATASET] e02080, shape=(39, 333)
# [DATASET] e02081, shape=(39, 333)
# [DATASET] e02082, shape=(39, 333)
# [DATASET] e02083, shape=(39, 333)
# [DATASET] e02084, shape=(39, 333)
# [DATASET] e02085, shape=(39, 333)
# [DATASET] e02085_aug0, shape=(39, 333)
# [DATASET] e02085_aug1, shape=(39, 333)
# [DATASET] e02085_aug2, shape=(39, 333)
# [DATASET] e02086, shape=(39, 333)
# [DATASET] e02087, shape=(39, 333)
# [DATASET] e02088, shape=(39, 333)
# [DATASET] e02089, shape=(39, 333)
# [DATASET] e02090, shape=(39, 333)
# [DATASET] e02091, shape=(39, 333)
# [DATASET] e02092, shape=(39, 333)
# [DATASET] e02093, shape=(39, 333)
# [DATASET] e02094, shape=(39, 333)
# [DATASET] e02095, shape=(39, 333)
# [DATASET] e02096, shape=(39, 333)
# [DATASET] e02097, shape=(39, 333)
# [DATASET] e02097_aug0, shape=(39, 333)
# [DATASET] e02097_aug1, shape=(39, 333)
# [DATASET] e02097_aug2, shape=(39, 333)
# [DATASET] e02098, shape=(39, 333)
# [DATASET] e02099, shape=(39, 333)
# [DATASET] e02100, shape=(39, 333)
# [DATASET] e02101, shape=(39, 333)
# [DATASET] e02101_aug0, shape=(39, 333)
# [DATASET] e02101_aug1, shape=(39, 333)
# [DATASET] e02101_aug2, shape=(39, 333)
# [DATASET] e02102, shape=(39, 333)
# [DATASET] e02102_aug0, shape=(39, 333)
# [DATASET] e02102_aug1, shape=(39, 333)
# [DATASET] e02102_aug2, shape=(39, 333)
# [DATASET] e02103, shape=(39, 333)
# [DATASET] e02104, shape=(39, 333)
# [DATASET] e02105, shape=(39, 333)
# [DATASET] e02106, shape=(39, 333)
# [DATASET] e02107, shape=(39, 333)
# [DATASET] e02108, shape=(39, 333)
# [DATASET] e02108_aug0, shape=(39, 333)
# [DATASET] e02108_aug1, shape=(39, 333)
# [DATASET] e02108_aug2, shape=(39, 333)
# [DATASET] e02109, shape=(39, 333)
# [DATASET] e02110, shape=(39, 333)
# [DATASET] e02111, shape=(39, 333)
# [DATASET] e02112, shape=(39, 333)
# [DATASET] e02113, shape=(39, 333)
# [DATASET] e02114, shape=(39, 333)
# [DATASET] e02115, shape=(39, 333)
# [DATASET] e02116, shape=(39, 333)
# [DATASET] e02117, shape=(39, 333)
# [DATASET] e02118, shape=(39, 333)
# [DATASET] e02119, shape=(39, 333)
# [DATASET] e02120, shape=(39, 333)
# [DATASET] e02121, shape=(39, 333)
# [DATASET] e02121_aug0, shape=(39, 333)
# [DATASET] e02121_aug1, shape=(39, 333)
# [DATASET] e02121_aug2, shape=(39, 333)
# [DATASET] e02122, shape=(39, 333)
# [DATASET] e02123, shape=(39, 333)
# [DATASET] e02124, shape=(39, 333)
# [DATASET] e02125, shape=(39, 333)
# [DATASET] e02126, shape=(39, 333)
# [DATASET] e02126_aug0, shape=(39, 333)
# [DATASET] e02126_aug1, shape=(39, 333)
# [DATASET] e02126_aug2, shape=(39, 333)
# [DATASET] e02127, shape=(39, 333)
# [DATASET] e02128, shape=(39, 333)
# [DATASET] e02129, shape=(39, 333)
# [DATASET] e02130, shape=(39, 333)
# [DATASET] e02131, shape=(39, 333)
# [DATASET] e02132, shape=(39, 333)
# [DATASET] e02133, shape=(39, 333)
# [DATASET] e02133_aug0, shape=(39, 333)
# [DATASET] e02133_aug1, shape=(39, 333)
# [DATASET] e02133_aug2, shape=(39, 333)
# [DATASET] e02134, shape=(39, 333)
# [DATASET] e02135, shape=(39, 333)
# [DATASET] e02135_aug0, shape=(39, 333)
# [DATASET] e02135_aug1, shape=(39, 333)
# [DATASET] e02135_aug2, shape=(39, 333)
# [DATASET] e02136, shape=(39, 333)
# [DATASET] e02137, shape=(39, 333)
# [DATASET] e02137_aug0, shape=(39, 333)
# [DATASET] e02137_aug1, shape=(39, 333)
# [DATASET] e02137_aug2, shape=(39, 333)
# [DATASET] e02138, shape=(39, 333)
# [DATASET] e02139, shape=(39, 333)
# [DATASET] e02140, shape=(39, 333)
# [DATASET] e02141, shape=(39, 333)
# [DATASET] f0001, shape=(39, 333)
# [DATASET] f0002, shape=(39, 333)
# [DATASET] f0003, shape=(39, 333)
# [DATASET] f0003_aug0, shape=(39, 333)
# [DATASET] f0003_aug1, shape=(39, 333)
# [DATASET] f0003_aug2, shape=(39, 333)
# [DATASET] f0004, shape=(39, 333)
# [DATASET] f0005, shape=(39, 333)
# [DATASET] f0006, shape=(39, 333)
# [DATASET] f0007, shape=(39, 333)
# [DATASET] f0007_aug0, shape=(39, 333)
# [DATASET] f0007_aug1, shape=(39, 333)
# [DATASET] f0007_aug2, shape=(39, 333)
# [DATASET] f0008, shape=(39, 333)
# [DATASET] f0008_aug0, shape=(39, 333)
# [DATASET] f0008_aug1, shape=(39, 333)
# [DATASET] f0008_aug2, shape=(39, 333)
# [DATASET] f0009, shape=(39, 333)
# [DATASET] f0010, shape=(39, 333)
# [DATASET] f0011, shape=(39, 333)
# [DATASET] f0012, shape=(39, 333)
# [DATASET] f0012_aug0, shape=(39, 333)
# [DATASET] f0012_aug1, shape=(39, 333)
# [DATASET] f0012_aug2, shape=(39, 333)
# [DATASET] f0013, shape=(39, 333)
# [DATASET] f0014, shape=(39, 333)
# [DATASET] f0015, shape=(39, 333)
# [DATASET] f0016, shape=(39, 333)
# [DATASET] f0017, shape=(39, 333)
# [DATASET] f0018, shape=(39, 333)
# [DATASET] f0018_aug0, shape=(39, 333)
# [DATASET] f0018_aug1, shape=(39, 333)
# [DATASET] f0018_aug2, shape=(39, 333)
# [DATASET] f0019, shape=(39, 333)
# [DATASET] f0020, shape=(39, 333)
# [DATASET] f0020_aug0, shape=(39, 333)
# [DATASET] f0020_aug1, shape=(39, 333)
# [DATASET] f0020_aug2, shape=(39, 333)
# [DATASET] f0021, shape=(39, 333)
# [DATASET] f0022, shape=(39, 333)
# [DATASET] f0023, shape=(39, 333)
# [DATASET] f0024, shape=(39, 333)
# [DATASET] f0025, shape=(39, 333)
# [DATASET] f0026, shape=(39, 333)
# [DATASET] f0027, shape=(39, 333)
# [DATASET] f0028, shape=(39, 333)
# [DATASET] f0029, shape=(39, 333)
# [DATASET] f0029_aug0, shape=(39, 333)
# [DATASET] f0029_aug1, shape=(39, 333)
# [DATASET] f0029_aug2, shape=(39, 333)
# [DATASET] f0030, shape=(39, 333)
# [DATASET] f0031, shape=(39, 333)
# [DATASET] f0032, shape=(39, 333)
# [DATASET] f0033, shape=(39, 333)
# [DATASET] f0034, shape=(39, 333)
# [DATASET] f0034_aug0, shape=(39, 333)
# [DATASET] f0034_aug1, shape=(39, 333)
# [DATASET] f0034_aug2, shape=(39, 333)
# [DATASET] f0035, shape=(39, 333)
# [DATASET] f0035_aug0, shape=(39, 333)
# [DATASET] f0035_aug1, shape=(39, 333)
# [DATASET] f0035_aug2, shape=(39, 333)
# [DATASET] f0036, shape=(39, 333)
# [DATASET] f0037, shape=(39, 333)
# [DATASET] f0038, shape=(39, 333)
# [DATASET] f0039, shape=(39, 333)
# [DATASET] f0040, shape=(39, 333)
# [DATASET] f0041, shape=(39, 333)
# [DATASET] f0041_aug0, shape=(39, 333)
# [DATASET] f0041_aug1, shape=(39, 333)
# [DATASET] f0041_aug2, shape=(39, 333)
# [DATASET] f0042, shape=(39, 333)
# [DATASET] f0043, shape=(39, 333)
# [DATASET] f0044, shape=(39, 333)
# [DATASET] f0045, shape=(39, 333)
# [DATASET] f0045_aug0, shape=(39, 333)
# [DATASET] f0045_aug1, shape=(39, 333)
# [DATASET] f0045_aug2, shape=(39, 333)
# [DATASET] f0046, shape=(39, 333)
# [DATASET] f0047, shape=(39, 333)
# [DATASET] f0047_aug0, shape=(39, 333)
# [DATASET] f0047_aug1, shape=(39, 333)
# [DATASET] f0047_aug2, shape=(39, 333)
# [DATASET] f0048, shape=(39, 333)
# [DATASET] f0049, shape=(39, 333)
# [DATASET] f0050, shape=(39, 333)
# [DATASET] f0050_aug0, shape=(39, 333)
# [DATASET] f0050_aug1, shape=(39, 333)
# [DATASET] f0050_aug2, shape=(39, 333)
# [DATASET] f0051, shape=(39, 333)
# [DATASET] f0052, shape=(39, 333)
# [DATASET] f0052_aug0, shape=(39, 333)
# [DATASET] f0052_aug1, shape=(39, 333)
# [DATASET] f0052_aug2, shape=(39, 333)
# [DATASET] f0053, shape=(39, 333)
# [DATASET] f0054, shape=(39, 333)
# [DATASET] f0055, shape=(39, 333)
# [DATASET] f0056, shape=(39, 333)
# [DATASET] f0056_aug0, shape=(39, 333)
# [DATASET] f0056_aug1, shape=(39, 333)
# [DATASET] f0056_aug2, shape=(39, 333)
# [DATASET] f0057, shape=(39, 333)
# [DATASET] f0057_aug0, shape=(39, 333)
# [DATASET] f0057_aug1, shape=(39, 333)
# [DATASET] f0057_aug2, shape=(39, 333)
# [DATASET] f0058, shape=(39, 333)
# [DATASET] f0059, shape=(39, 333)
# [DATASET] f0060, shape=(39, 333)
# [DATASET] f0060_aug0, shape=(39, 333)
# [DATASET] f0060_aug1, shape=(39, 333)
# [DATASET] f0060_aug2, shape=(39, 333)
# [DATASET] f0061, shape=(39, 333)
# [DATASET] f0062, shape=(39, 333)
# [DATASET] f0063, shape=(39, 333)
# [DATASET] f0063_aug0, shape=(39, 333)
# [DATASET] f0063_aug1, shape=(39, 333)
# [DATASET] f0063_aug2, shape=(39, 333)
# [DATASET] f0064, shape=(39, 333)
# [DATASET] f0064_aug0, shape=(39, 333)
# [DATASET] f0064_aug1, shape=(39, 333)
# [DATASET] f0064_aug2, shape=(39, 333)
# [DATASET] f0065, shape=(39, 333)
# [DATASET] f0066, shape=(39, 333)
# [DATASET] f0067, shape=(39, 333)
# [DATASET] f0067_aug0, shape=(39, 333)
# [DATASET] f0067_aug1, shape=(39, 333)
# [DATASET] f0067_aug2, shape=(39, 333)
# [DATASET] f0068, shape=(39, 333)
# [DATASET] f0068_aug0, shape=(39, 333)
# [DATASET] f0068_aug1, shape=(39, 333)
# [DATASET] f0068_aug2, shape=(39, 333)
# [DATASET] f0069, shape=(39, 333)
# [DATASET] f0069_aug0, shape=(39, 333)
# [DATASET] f0069_aug1, shape=(39, 333)
# [DATASET] f0069_aug2, shape=(39, 333)
# [DATASET] f0070, shape=(39, 333)
# [DATASET] f0071, shape=(39, 333)
# [DATASET] f0071_aug0, shape=(39, 333)
# [DATASET] f0071_aug1, shape=(39, 333)
# [DATASET] f0071_aug2, shape=(39, 333)
# [DATASET] f0072, shape=(39, 333)
# [DATASET] f0072_aug0, shape=(39, 333)
# [DATASET] f0072_aug1, shape=(39, 333)
# [DATASET] f0072_aug2, shape=(39, 333)
# [DATASET] f0073, shape=(39, 333)
# [DATASET] f0074, shape=(39, 333)
# [DATASET] f0075, shape=(39, 333)
# [DATASET] f0076, shape=(39, 333)
# [DATASET] f0077, shape=(39, 333)
# [DATASET] f0078, shape=(39, 333)
# [DATASET] f0079, shape=(39, 333)
# [DATASET] f0079_aug0, shape=(39, 333)
# [DATASET] f0079_aug1, shape=(39, 333)
# [DATASET] f0079_aug2, shape=(39, 333)
# [DATASET] f0080, shape=(39, 333)
# [DATASET] f0081, shape=(39, 333)
# [DATASET] f0082, shape=(39, 333)
# [DATASET] f0082_aug0, shape=(39, 333)
# [DATASET] f0082_aug1, shape=(39, 333)
# [DATASET] f0082_aug2, shape=(39, 333)
# [DATASET] f0083, shape=(39, 333)
# [DATASET] f0083_aug0, shape=(39, 333)
# [DATASET] f0083_aug1, shape=(39, 333)
# [DATASET] f0083_aug2, shape=(39, 333)
# [DATASET] f0084, shape=(39, 333)
# [DATASET] f0085, shape=(39, 333)
# [DATASET] f0085_aug0, shape=(39, 333)
# [DATASET] f0085_aug1, shape=(39, 333)
# [DATASET] f0085_aug2, shape=(39, 333)
# [DATASET] f0086, shape=(39, 333)
# [DATASET] f0087, shape=(39, 333)
# [DATASET] f0088, shape=(39, 333)
# [DATASET] f0089, shape=(39, 333)
# [DATASET] f0089_aug0, shape=(39, 333)
# [DATASET] f0089_aug1, shape=(39, 333)
# [DATASET] f0089_aug2, shape=(39, 333)
# [DATASET] f0090, shape=(39, 333)
# [DATASET] f0090_aug0, shape=(39, 333)
# [DATASET] f0090_aug1, shape=(39, 333)
# [DATASET] f0090_aug2, shape=(39, 333)
# [DATASET] f0091, shape=(39, 333)
# [DATASET] f0092, shape=(39, 333)
# [DATASET] f0093, shape=(39, 333)
# [DATASET] f0093_aug0, shape=(39, 333)
# [DATASET] f0093_aug1, shape=(39, 333)
# [DATASET] f0093_aug2, shape=(39, 333)
# [DATASET] f0094, shape=(39, 333)
# [DATASET] f0095, shape=(39, 333)
# [DATASET] f0096, shape=(39, 333)
# [DATASET] f0096_aug0, shape=(39, 333)
# [DATASET] f0096_aug1, shape=(39, 333)
# [DATASET] f0096_aug2, shape=(39, 333)
# [DATASET] f0097, shape=(39, 333)
# [DATASET] f0098, shape=(39, 333)
# [DATASET] f0099, shape=(39, 333)
# [DATASET] f0099_aug0, shape=(39, 333)
# [DATASET] f0099_aug1, shape=(39, 333)
# [DATASET] f0099_aug2, shape=(39, 333)
# [DATASET] f0100, shape=(39, 333)
# [DATASET] f0101, shape=(39, 333)
# [DATASET] f0102, shape=(39, 333)
# [DATASET] f0103, shape=(39, 333)
# [DATASET] f0103_aug0, shape=(39, 333)
# [DATASET] f0103_aug1, shape=(39, 333)
# [DATASET] f0103_aug2, shape=(39, 333)
# [DATASET] f0104, shape=(39, 333)
# [DATASET] f0105, shape=(39, 333)
# [DATASET] f0106, shape=(39, 333)
# [DATASET] f0107, shape=(39, 333)
# [DATASET] f0108, shape=(39, 333)
# [DATASET] f0109, shape=(39, 333)
# [DATASET] f0110, shape=(39, 333)
# [DATASET] f0111, shape=(39, 333)
# [DATASET] f0112, shape=(39, 333)
# [DATASET] f0113, shape=(39, 333)
# [DATASET] f0114, shape=(39, 333)

# %%
import pandas as pd
from pathlib import Path

# Load label gốc (FULL)
df_base = pd.read_csv(PROJECT_PATH / "data" / "label.csv")

# Chuẩn hoá ID gốc
df_base["id"] = df_base["filename"].apply(lambda x: Path(x).stem)

label_map = dict(zip(df_base["id"], df_base["label"]))

rows = []

with h5py.File(h5_path, "r") as f:
    for key in f.keys():
        base = key.split("_aug")[0]
        if base in label_map:
            rows.append({
                "filename": key,
                "label": label_map[base]
            })
        else:
            print("⚠️ Missing base label:", key)

df_full = pd.DataFrame(rows)
df_full.to_csv(PROJECT_PATH / "data" / "label_balanced.csv", index=False)

print("✅ label_balanced.csv created")
print(df_full["label"].value_counts())
# Out:
# ✅ label_balanced.csv created
# label
# 1    2660
# 0    2575
# Name: count, dtype: int64

# %%
# =========================
# Load label CSV
# =========================
label_csv = PROJECT_PATH / "data" / "label_balanced.csv"
df = pd.read_csv(label_csv)

# Map: base_id -> label
label_map = {
    row["filename"]: row["label"]
    for _, row in df.iterrows()
}

def base_id(sample_id: str) -> str:
    """Chuẩn hoá ID: bỏ _augX nếu có"""
    return sample_id.split("_aug")[0]

# =========================
# Count labels in HDF5
# =========================
label_counter = Counter()
unknown = []

with h5py.File(h5_path, "r") as f:
    for name in f.keys():
        bid = base_id(name)
        if bid in label_map:
            if label_map[bid] == 1:
                label_counter["Abnormal"] += 1
            else:
                label_counter["Normal"] += 1
        else:
            label_counter["Unknown"] += 1
            unknown.append(name)

# =========================
# Print statistics
# =========================
total = sum(label_counter.values())

print("\n=== CLASS DISTRIBUTION (CSV-BASED) ===")
print(f"Tổng số mẫu: {total}")

for cls, cnt in label_counter.items():
    print(f"{cls}: {cnt} ({cnt/total*100:.2f}%)")

if unknown:
    print(f"\n⚠️ Unknown samples: {len(unknown)}")
    print("Ví dụ:", unknown[:10])
# Out:
# === CLASS DISTRIBUTION (CSV-BASED) ===
# Tổng số mẫu: 5235
# Abnormal: 2660 (50.81%)
# Normal: 2575 (49.19%)

# %%
import h5py
import pandas as pd
from collections import Counter
from pathlib import Path

def print_class_distribution(h5_path, label_csv_path, title=None):
    """
    In ra tỷ lệ Normal / Abnormal trong file .h5
    """
    # Load label.csv
    df = pd.read_csv(label_csv_path)
    df["basename"] = df["filename"].apply(lambda x: Path(x).stem)

    label_dict = dict(zip(df["basename"], df["label"]))

    counter = Counter()

    with h5py.File(h5_path, "r") as f:
        for key in f.keys():
            if key not in label_dict:
                counter["Unknown"] += 1
                continue

            if label_dict[key] == 1:
                counter["Abnormal"] += 1
            else:
                counter["Normal"] += 1

    total = counter["Normal"] + counter["Abnormal"]

    if title:
        print(f"\n=== {title} ===")

    print(f"Tổng số mẫu: {total}")
    print(f"Normal  : {counter['Normal']} ({counter['Normal']/total*100:.2f}%)")
    print(f"Abnormal: {counter['Abnormal']} ({counter['Abnormal']/total*100:.2f}%)")

    if counter["Unknown"] > 0:
        print(f"⚠️ Unknown (không có nhãn): {counter['Unknown']}")

# %% [markdown]
# ## Create .nqz for MFCC

# %%
import numpy as np
import h5py
import pandas as pd
from tqdm import tqdm

# Paths
h5_path = PROJECT_PATH / "data" / "mfcc_features.h5"
label_csv = PROJECT_PATH / "data" / "label_balanced.csv"
output_npz = PROJECT_PATH / "data" / "dataset_final.npz"

print(f"--- Packing data into .npz ---")

x_data, y_data = [], []
df_labels = pd.read_csv(label_csv)
label_map = dict(zip(df_labels['filename'], df_labels['label']))

with h5py.File(h5_path, "r") as f:
    for key in tqdm(f.keys(), desc="Loading data"):
        if key in label_map:
            # Load the MFCC array
            data = f[key][()]
            x_data.append(data)
            y_data.append(label_map[key])

# Convert to Numpy arrays
x_data = np.array(x_data)
y_data = np.array(y_data)

# Save to .npz
np.savez(output_npz, x=x_data, y=y_data)

print(f"✅ Saved to: {output_npz}")
print(f"Shape: X={x_data.shape}, Y={y_data.shape}")
# Out:
# --- Packing data into .npz ---
# Loading data: 100%|██████████| 5235/5235 [00:04<00:00, 1133.69it/s]
# ✅ Saved to: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/dataset_final.npz
# Shape: X=(5235, 39, 333), Y=(5235,)

# %% [markdown]
# # Test

# %%
DATASET_PATH = Path('/content/drive/MyDrive/physionet2016')
PROJECT_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main')

VALIDATION_FOLDER = DATASET_PATH / 'validation'

# %%
LOGMEL_FOLDER_VAL = PROJECT_PATH / 'logmel_features_validation'
LOGMEL_FOLDER_VAL.mkdir(parents=True, exist_ok=True)

MFCC_FOLDER_VAL = PROJECT_PATH / 'mfcc_features_validation'
MFCC_FOLDER_VAL.mkdir(parents=True, exist_ok=True)

# %%
OUTPUT_H5_VAL = PROJECT_PATH / 'data' / 'logmel_features_validation.h5'
OUTPUT_H5_VAL.parent.mkdir(parents=True, exist_ok=True)

# %%
ref_path = VALIDATION_FOLDER / 'REFERENCE.csv'
if not ref_path.exists():
    raise FileNotFoundError(f"Không tìm thấy REFERENCE.csv tại {ref_path}")

df_val = pd.read_csv(ref_path, header=None, names=['basename', 'label'])
df_val['filename'] = [str(VALIDATION_FOLDER / (base + '.wav')) for base in df_val['basename']]
df_val['label'] = (df_val['label'] + 1) // 2  # -1 -> 0, 1 -> 1 (giống training)

# Lưu label.csv cho validation (tùy chọn, để sau này dễ load)
val_label_path = PROJECT_PATH / 'data' / 'label_validation.csv'
df_val[['filename', 'label']].to_csv(val_label_path, index=False)
print(f"Đã tạo label_validation.csv với {len(df_val)} mẫu.")
# Out:
# Đã tạo label_validation.csv với 301 mẫu.

# %%
# -------------------------- Tham số trích xuất --------------------------
mel_bins = 128
hoplen = 15    # ms
winlen = 25    # ms
EPS = 1e-8

# %% [markdown]
# ## Convert to LogMel and MFCC

# %%
import os
import numpy as np
import pandas as pd

from tqdm import tqdm
from collections import Counter
from pathlib import Path

# =========================
# read_audio()
# augment_audio()
# PROJECT_PATH
# MfccExtractor()
# LogMelExtractor()
# =========================

if __name__ == "__main__":

    df = pd.read_csv(PROJECT_PATH / "data" / "label_validation.csv")

    logmel_folder = PROJECT_PATH / 'logmel_features_validation'
    mfcc_folder   = PROJECT_PATH / 'mfcc_features_validation'

    os.makedirs(logmel_folder, exist_ok=True)
    os.makedirs(mfcc_folder, exist_ok=True)

    # ===== Class balancing =====
    label_counts = Counter(df["label"])
    n_normal   = label_counts[0]
    n_abnormal = label_counts[1]

    target_abnormal = n_normal
    augment_per_abnormal = int(
        np.ceil((target_abnormal - n_abnormal) / n_abnormal)
    )

    print("=== ORIGINAL DISTRIBUTION ===")
    print(f"Normal  : {n_normal}")
    print(f"Abnormal: {n_abnormal}")
    print(f"Augment per abnormal sample: {augment_per_abnormal}")

    # ===== Feature parameters =====
    mel_bins = 128
    n_mfcc   = 13
    hoplen   = 15   # ms
    winlen   = 25   # ms
    T_fixed  = 333
    # =========================
    # Feature extraction
    # =========================
    for _, row in tqdm(df.iterrows(), total=len(df)):

        filename = row["filename"]
        label    = row["label"]

        audio, fs = read_audio(filename, filter=True)
        basename = Path(filename).stem

        # ===== ORIGINAL SAMPLE =====
        logmel = LogMelExtractor(
            audio, fs,
            mel_bins=mel_bins,
            hoplen=hoplen,
            winlen=winlen
        )

        mfcc = MfccExtractor(
            audio, fs,
            n_mfcc=n_mfcc,
            hoplen=hoplen,
            winlen=winlen,
            T_fixed=T_fixed
        )

        np.save(logmel_folder / f"{basename}.npy", logmel)
        np.save(mfcc_folder   / f"{basename}.npy", mfcc)

    print("\n✅ Feature extraction + augmentation completed.")
# Out:
# === ORIGINAL DISTRIBUTION ===
# Normal  : 150
# Abnormal: 151
# Augment per abnormal sample: 0
# 100%|██████████| 301/301 [03:55<00:00,  1.28it/s]
# ✅ Feature extraction + augmentation completed.

# %% [markdown]
# ## LogMel to .h5

# %% [markdown]
# ## MFCC to .h5

# %%
# ==============================
# MERGE MFCC .npy → HDF5
# ==============================
import numpy as np
import h5py
from pathlib import Path
from tqdm.notebook import tqdm

MFCC_DIR = PROJECT_PATH / "mfcc_features_validation"          # Thư mục chứa MFCC .npy
OUTPUT_H5 = PROJECT_PATH / "data" / "mfcc_features_validation.h5"

if OUTPUT_H5.exists():
    print(f"File {OUTPUT_H5} đã tồn tại – bỏ qua.")
else:
    npy_files = sorted(MFCC_DIR.glob("*.npy"))
    print(f"Found {len(npy_files)} MFCC files")

    with h5py.File(OUTPUT_H5, "w") as f_out:
        for npy_file in tqdm(npy_files, desc="Converting MFCC"):
            key = npy_file.stem
            data = np.load(npy_file)

            # MFCC chuẩn: (n_mfcc, time)
            assert data.ndim == 2, f"{key} invalid shape {data.shape}"

            f_out.create_dataset(
                key,
                data=data.astype(np.float32),
                compression="gzip"
            )

    print(f"✅ MFCC HDF5 created: {OUTPUT_H5}")
# Out:
# 🔎 Found 301 MFCC files
# Converting MFCC:   0%|          | 0/301 [00:00<?, ?it/s]
# ✅ MFCC HDF5 created: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/mfcc_features_validation.h5

# %%
# =========================
# Load label CSV
# =========================
label_csv = PROJECT_PATH / "data" / "label_validation.csv"
df = pd.read_csv(label_csv)
h5_path = str(OUTPUT_H5)
# Map: base_id -> label
label_map = {
    Path(row["filename"]).stem: row["label"]
    for _, row in df.iterrows()
}

def base_id(sample_id: str) -> str:
    """Chuẩn hoá ID: bỏ _augX nếu có"""
    return sample_id.split("_aug")[0]

# =========================
# Count labels in HDF5
# =========================
label_counter = Counter()
unknown = []

with h5py.File(h5_path, "r") as f:
    for name in f.keys():
        bid = base_id(name)
        if bid in label_map:
            if label_map[bid] == 1:
                label_counter["Abnormal"] += 1
            else:
                label_counter["Normal"] += 1
        else:
            label_counter["Unknown"] += 1
            unknown.append(name)

# =========================
# Print statistics
# =========================
total = sum(label_counter.values())

print("\n=== CLASS DISTRIBUTION (CSV-BASED) ===")
print(f"Tổng số mẫu: {total}")

for cls, cnt in label_counter.items():
    print(f"{cls}: {cnt} ({cnt/total*100:.2f}%)")

if unknown:
    print(f"\n⚠️ Unknown samples: {len(unknown)}")
    print("Ví dụ:", unknown[:10])
# Out:
# === CLASS DISTRIBUTION (CSV-BASED) ===
# Tổng số mẫu: 301
# Abnormal: 151 (50.17%)
# Normal: 150 (49.83%)

# %%
import numpy as np
import h5py
import pandas as pd
from tqdm import tqdm
DATASET_PATH = Path('/content/drive/MyDrive/AutomaticHeartSoundClassification-main/data')
# Paths
h5_path = DATASET_PATH / "mfcc_features_validation.h5"
label_csv = DATASET_PATH / "label_validation.csv"
output_npz = DATASET_PATH / "dataset_validation_.npz"

print(f"--- Packing data into .npz ---")

x_data, y_data = [], []
df_labels = pd.read_csv(label_csv)
#label_map = dict(zip(df_labels['filename'], df_labels['label']))
label_map = {Path(row['filename']).stem: row['label'] for _, row in df_labels.iterrows()}
with h5py.File(h5_path, "r") as f:
    for key in tqdm(f.keys(), desc="Loading data"):
        if key in label_map:
            # Load the MFCC array
            data = f[key][()]
            x_data.append(data)
            y_data.append(label_map[key])

# Convert to Numpy arrays
x_data = np.array(x_data)
y_data = np.array(y_data)

# Save to .npz
np.savez(output_npz, x=x_data, y=y_data)

print(f"✅ Saved to: {output_npz}")
print(f"Shape: X={x_data.shape}, Y={y_data.shape}")
# Out:
# --- Packing data into .npz ---
# Loading data: 100%|██████████| 301/301 [00:00<00:00, 743.64it/s]
# ✅ Saved to: /content/drive/MyDrive/AutomaticHeartSoundClassification-main/data/dataset_validation_.npz
# Shape: X=(301, 39, 333), Y=(301,)
